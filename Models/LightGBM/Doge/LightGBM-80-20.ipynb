# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import datetime as dt
# Out:
# c:\Users\takat\anaconda3\envs\tf\lib\site-packages\dask\dataframe\__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# Load the data
file_path = '../../../Dataset/Dodge-USD-3.2018-3.2024.csv'
df = pd.read_csv(file_path, parse_dates=True, index_col=0)
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2018-03-01  0.006042  0.006320  0.005945  0.006215   0.006215  15518400
# 2018-03-02  0.006174  0.006232  0.005447  0.005482   0.005482  22498100
# 2018-03-03  0.005494  0.005756  0.005181  0.005301   0.005301  21545000
# 2018-03-04  0.005234  0.005502  0.005164  0.005502   0.005502  12133500
# 2018-03-05  0.005462  0.005535  0.005157  0.005218   0.005218  13627700

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]
# Create the dataset with features
df_features = createFeatures(df)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()
# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2018-10-02  0.005824  0.000241         0.006478         0.005382  0.005966  0.005739
# 2018-10-03  0.005704  0.000213         0.006358         0.005417  0.005981  0.005736
# 2018-10-04  0.005645  0.000183         0.006322         0.005400  0.005979  0.005727
# 2018-10-05  0.005669  0.000159         0.006282         0.005391  0.005973  0.005722
# 2018-10-06  0.005545  0.000129         0.006110         0.005464  0.005921  0.005705

# %%
# Training and Test dataset
test_size = 0.2
train_size = int(len(df_filtered) * (1 - test_size))
train, test = df_filtered.iloc[0:train_size], df_filtered.iloc[train_size:len(df_filtered)]

# %%
X_train = train.drop('Close', axis=1)
y_train = train['Close']

X_test = test.drop('Close', axis=1)
y_test = test['Close']

# %%
# LightGBM
# LightGBM regression model
model = lgb.LGBMRegressor()
model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 1582, number of used features: 5
# [LightGBM] [Info] Start training from score 0.072785
# LGBMRegressor()

# %%
# Make predictions for validation and test sets
test_preds = model.predict(X_test)

# plot the predictions
plt.figure(figsize=(15, 7))
plt.plot(test.index, test_preds, label='Predictions')
plt.plot(test.index, test['Close'], label='True Close')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Create function to forecast next x days
def forecast_next_x_days(df, num_days, best_model):

    print(f"Forecasting for day {num_days}")
    # Predict 1 day ahead and use the forecasted value to create features for the next day
    df_forecast = df.copy()
    for i in range(num_days):
        # Create the forecast's exogenous variables
        lag_feature_input = df_forecast.iloc[-1].drop('Close').copy()
        print(f"Forecasting for day {i+1}")
        forecast_1_ahead = best_model.predict(lag_feature_input.values.reshape(1, -1))
        print(f"Forecasted value for day {i+1}: {forecast_1_ahead[0]}") 
        # Append the forecasted value to the dataset 
        lag_feature_input['Close'] = forecast_1_ahead[0]
        df_forecast_extend = pd.DataFrame([lag_feature_input], columns=df_forecast.columns)
        df_forecast = pd.concat([df_forecast, df_forecast_extend], axis=0)
        df_forecast.index = pd.date_range(start=df_forecast.index.min(), periods=len(df_forecast))
        # Create the features for the next day
        df_forecast = createFeatures(df_forecast)
        # Filter the data to the list of FEATURES
        df_forecast = df_forecast[FEATURES].copy()

        
    return df_forecast[-num_days:]

# %%
fc_90_day = forecast_next_x_days(df_filtered, 90, model)
fc_60_day = forecast_next_x_days(df_filtered, 60, model)
fc_30_day = forecast_next_x_days(df_filtered, 30, model)
# Out:
# Forecasting for day 90
# Forecasting for day 1
# Forecasted value for day 1: 0.10104564583689675
# Forecasting for day 2
# Forecasted value for day 2: 0.10597122239120314
# Forecasting for day 3
# Forecasted value for day 3: 0.11075593871361146
# Forecasting for day 4
# Forecasted value for day 4: 0.11478662986024268
# Forecasting for day 5
# Forecasted value for day 5: 0.114341890919414
# Forecasting for day 6
# Forecasted value for day 6: 0.11449941496246124
# Forecasting for day 7
# Forecasted value for day 7: 0.1142757434360457
# Forecasting for day 8
# Forecasted value for day 8: 0.11579409142783792
# Forecasting for day 9
# Forecasted value for day 9: 0.11579409142783792
# Forecasting for day 10
# Forecasted value for day 10: 0.11382074247982683
# Forecasting for day 11
# Forecasted value for day 11: 0.11496376828277195
# Forecasting for day 12
# Forecasted value for day 12: 0.11362079857093327
# Forecasting for day 13
# Forecasted value for day 13: 0.11212848463865617
# Forecasting for day 14
# Forecasted value for day 14: 0.11212848463865617
# Forecasting for day 15
# Forecasted value for day 15: 0.1115058933753633
# Forecasting for day 16
# Forecasted value for day 16: 0.10937934653252211
# Forecasting for day 17
# Forecasted value for day 17: 0.10937934653252211
# Forecasting for day 18
# Forecasted value for day 18: 0.1071731052506815
# Forecasting for day 19
# Forecasted value for day 19: 0.10629019945252934
# Forecasting for day 20
# Forecasted value for day 20: 0.10078994246236891
# Forecasting for day 21
# Forecasted value for day 21: 0.09807252923228872
# Forecasting for day 22
# Forecasted value for day 22: 0.09733334682835229
# Forecasting for day 23
# Forecasted value for day 23: 0.09309424770364734
# Forecasting for day 24
# Forecasted value for day 24: 0.09159020353332172
# Forecasting for day 25
# Forecasted value for day 25: 0.08640434877569227
# Forecasting for day 26
# Forecasted value for day 26: 0.0813813952466828
# Forecasting for day 27
# Forecasted value for day 27: 0.0800062032502062
# Forecasting for day 28
# Forecasted value for day 28: 0.07994738740834248
# Forecasting for day 29
# Forecasted value for day 29: 0.08242972698505671
# Forecasting for day 30
# Forecasted value for day 30: 0.08178352985254793
# Forecasting for day 31
# Forecasted value for day 31: 0.08219431032382488
# Forecasting for day 32
# Forecasted value for day 32: 0.08090939586594523
# Forecasting for day 33
# Forecasted value for day 33: 0.08090939586594523
# Forecasting for day 34
# Forecasted value for day 34: 0.08327759975248165
# Forecasting for day 35
# Forecasted value for day 35: 0.0829098157826873
# Forecasting for day 36
# Forecasted value for day 36: 0.07969436820264128
# Forecasting for day 37
# Forecasted value for day 37: 0.08016478513927709
# Forecasting for day 38
# Forecasted value for day 38: 0.08403878176301625
# Forecasting for day 39
# Forecasted value for day 39: 0.08294541445411066
# Forecasting for day 40
# Forecasted value for day 40: 0.08178719100186979
# Forecasting for day 41
# Forecasted value for day 41: 0.08243072253335866
# Forecasting for day 42
# Forecasted value for day 42: 0.08208499674267122
# Forecasting for day 43
# Forecasted value for day 43: 0.0820673937145159
# Forecasting for day 44
# Forecasted value for day 44: 0.0792214314968037
# Forecasting for day 45
# Forecasted value for day 45: 0.07982719763694635
# Forecasting for day 46
# Forecasted value for day 46: 0.07982719763694635
# Forecasting for day 47
# Forecasted value for day 47: 0.07652316658513326
# Forecasting for day 48
# Forecasted value for day 48: 0.07545502514859145
# Forecasting for day 49
# Forecasted value for day 49: 0.07487336822405875
# Forecasting for day 50
# Forecasted value for day 50: 0.07487258971886651
# Forecasting for day 51
# Forecasted value for day 51: 0.07480798951602943
# Forecasting for day 52
# Forecasted value for day 52: 0.07480798951602943
# Forecasting for day 53
# Forecasted value for day 53: 0.07380411708660972
# Forecasting for day 54
# Forecasted value for day 54: 0.07375301922238933
# Forecasting for day 55
# Forecasted value for day 55: 0.07299846658272761
# Forecasting for day 56
# Forecasted value for day 56: 0.07326098597222715
# Forecasting for day 57
# Forecasted value for day 57: 0.07326098597222715
# Forecasting for day 58
# Forecasted value for day 58: 0.07438342165553619
# Forecasting for day 59
# Forecasted value for day 59: 0.07438342165553619
# Forecasting for day 60
# Forecasted value for day 60: 0.07372152019055514
# Forecasting for day 61
# Forecasted value for day 61: 0.07400406121777316
# Forecasting for day 62
# Forecasted value for day 62: 0.07369970526266156
# Forecasting for day 63
# Forecasted value for day 63: 0.07369970526266156
# Forecasting for day 64
# Forecasted value for day 64: 0.07369970526266156
# Forecasting for day 65
# Forecasted value for day 65: 0.07392491294648151
# Forecasting for day 66
# Forecasted value for day 66: 0.07386156939897269
# Forecasting for day 67
# Forecasted value for day 67: 0.07415488641564505
# Forecasting for day 68
# Forecasted value for day 68: 0.07564908311149442
# Forecasting for day 69
# Forecasted value for day 69: 0.07569055946457386
# Forecasting for day 70
# Forecasted value for day 70: 0.07794159897660868
# Forecasting for day 71
# Forecasted value for day 71: 0.0841337143162796
# Forecasting for day 72
# Forecasted value for day 72: 0.08215868100120216
# Forecasting for day 73
# Forecasted value for day 73: 0.08352465688199169
# Forecasting for day 74
# Forecasted value for day 74: 0.08353813520644773
# Forecasting for day 75
# Forecasted value for day 75: 0.08342022756587027
# Forecasting for day 76
# Forecasted value for day 76: 0.08443798211358038
# Forecasting for day 77
# Forecasted value for day 77: 0.08656304918132438
# Forecasting for day 78
# Forecasted value for day 78: 0.08673980077214755
# Forecasting for day 79
# Forecasted value for day 79: 0.08603944697390482
# Forecasting for day 80
# Forecasted value for day 80: 0.08554714259339717
# Forecasting for day 81
# Forecasted value for day 81: 0.08550325678829634
# Forecasting for day 82
# Forecasted value for day 82: 0.08405301097826183
# Forecasting for day 83
# Forecasted value for day 83: 0.08635005597550038
# Forecasting for day 84
# Forecasted value for day 84: 0.08565459289155808
# Forecasting for day 85
# Forecasted value for day 85: 0.08592001841323088
# Forecasting for day 86
# Forecasted value for day 86: 0.08613316832219298
# Forecasting for day 87
# Forecasted value for day 87: 0.08613316832219298
# Forecasting for day 88
# Forecasted value for day 88: 0.08613316832219298
# Forecasting for day 89
# Forecasted value for day 89: 0.08652979313486073
# Forecasting for day 90
# Forecasted value for day 90: 0.08651118690742403
# Forecasting for day 60
# Forecasting for day 1
# Forecasted value for day 1: 0.10104564583689675
# Forecasting for day 2
# Forecasted value for day 2: 0.10597122239120314
# Forecasting for day 3
# Forecasted value for day 3: 0.11075593871361146
# Forecasting for day 4
# Forecasted value for day 4: 0.11478662986024268
# Forecasting for day 5
# Forecasted value for day 5: 0.114341890919414
# Forecasting for day 6
# Forecasted value for day 6: 0.11449941496246124
# Forecasting for day 7
# Forecasted value for day 7: 0.1142757434360457
# Forecasting for day 8
# Forecasted value for day 8: 0.11579409142783792
# Forecasting for day 9
# Forecasted value for day 9: 0.11579409142783792
# Forecasting for day 10
# Forecasted value for day 10: 0.11382074247982683
# Forecasting for day 11
# Forecasted value for day 11: 0.11496376828277195
# Forecasting for day 12
# Forecasted value for day 12: 0.11362079857093327
# Forecasting for day 13
# Forecasted value for day 13: 0.11212848463865617
# Forecasting for day 14
# Forecasted value for day 14: 0.11212848463865617
# Forecasting for day 15
# Forecasted value for day 15: 0.1115058933753633
# Forecasting for day 16
# Forecasted value for day 16: 0.10937934653252211
# Forecasting for day 17
# Forecasted value for day 17: 0.10937934653252211
# Forecasting for day 18
# Forecasted value for day 18: 0.1071731052506815
# Forecasting for day 19
# Forecasted value for day 19: 0.10629019945252934
# Forecasting for day 20
# Forecasted value for day 20: 0.10078994246236891
# Forecasting for day 21
# Forecasted value for day 21: 0.09807252923228872
# Forecasting for day 22
# Forecasted value for day 22: 0.09733334682835229
# Forecasting for day 23
# Forecasted value for day 23: 0.09309424770364734
# Forecasting for day 24
# Forecasted value for day 24: 0.09159020353332172
# Forecasting for day 25
# Forecasted value for day 25: 0.08640434877569227
# Forecasting for day 26
# Forecasted value for day 26: 0.0813813952466828
# Forecasting for day 27
# Forecasted value for day 27: 0.0800062032502062
# Forecasting for day 28
# Forecasted value for day 28: 0.07994738740834248
# Forecasting for day 29
# Forecasted value for day 29: 0.08242972698505671
# Forecasting for day 30
# Forecasted value for day 30: 0.08178352985254793
# Forecasting for day 31
# Forecasted value for day 31: 0.08219431032382488
# Forecasting for day 32
# Forecasted value for day 32: 0.08090939586594523
# Forecasting for day 33
# Forecasted value for day 33: 0.08090939586594523
# Forecasting for day 34
# Forecasted value for day 34: 0.08327759975248165
# Forecasting for day 35
# Forecasted value for day 35: 0.0829098157826873
# Forecasting for day 36
# Forecasted value for day 36: 0.07969436820264128
# Forecasting for day 37
# Forecasted value for day 37: 0.08016478513927709
# Forecasting for day 38
# Forecasted value for day 38: 0.08403878176301625
# Forecasting for day 39
# Forecasted value for day 39: 0.08294541445411066
# Forecasting for day 40
# Forecasted value for day 40: 0.08178719100186979
# Forecasting for day 41
# Forecasted value for day 41: 0.08243072253335866
# Forecasting for day 42
# Forecasted value for day 42: 0.08208499674267122
# Forecasting for day 43
# Forecasted value for day 43: 0.0820673937145159
# Forecasting for day 44
# Forecasted value for day 44: 0.0792214314968037
# Forecasting for day 45
# Forecasted value for day 45: 0.07982719763694635
# Forecasting for day 46
# Forecasted value for day 46: 0.07982719763694635
# Forecasting for day 47
# Forecasted value for day 47: 0.07652316658513326
# Forecasting for day 48
# Forecasted value for day 48: 0.07545502514859145
# Forecasting for day 49
# Forecasted value for day 49: 0.07487336822405875
# Forecasting for day 50
# Forecasted value for day 50: 0.07487258971886651
# Forecasting for day 51
# Forecasted value for day 51: 0.07480798951602943
# Forecasting for day 52
# Forecasted value for day 52: 0.07480798951602943
# Forecasting for day 53
# Forecasted value for day 53: 0.07380411708660972
# Forecasting for day 54
# Forecasted value for day 54: 0.07375301922238933
# Forecasting for day 55
# Forecasted value for day 55: 0.07299846658272761
# Forecasting for day 56
# Forecasted value for day 56: 0.07326098597222715
# Forecasting for day 57
# Forecasted value for day 57: 0.07326098597222715
# Forecasting for day 58
# Forecasted value for day 58: 0.07438342165553619
# Forecasting for day 59
# Forecasted value for day 59: 0.07438342165553619
# Forecasting for day 60
# Forecasted value for day 60: 0.07372152019055514
# Forecasting for day 30
# Forecasting for day 1
# Forecasted value for day 1: 0.10104564583689675
# Forecasting for day 2
# Forecasted value for day 2: 0.10597122239120314
# Forecasting for day 3
# Forecasted value for day 3: 0.11075593871361146
# Forecasting for day 4
# Forecasted value for day 4: 0.11478662986024268
# Forecasting for day 5
# Forecasted value for day 5: 0.114341890919414
# Forecasting for day 6
# Forecasted value for day 6: 0.11449941496246124
# Forecasting for day 7
# Forecasted value for day 7: 0.1142757434360457
# Forecasting for day 8
# Forecasted value for day 8: 0.11579409142783792
# Forecasting for day 9
# Forecasted value for day 9: 0.11579409142783792
# Forecasting for day 10
# Forecasted value for day 10: 0.11382074247982683
# Forecasting for day 11
# Forecasted value for day 11: 0.11496376828277195
# Forecasting for day 12
# Forecasted value for day 12: 0.11362079857093327
# Forecasting for day 13
# Forecasted value for day 13: 0.11212848463865617
# Forecasting for day 14
# Forecasted value for day 14: 0.11212848463865617
# Forecasting for day 15
# Forecasted value for day 15: 0.1115058933753633
# Forecasting for day 16
# Forecasted value for day 16: 0.10937934653252211
# Forecasting for day 17
# Forecasted value for day 17: 0.10937934653252211
# Forecasting for day 18
# Forecasted value for day 18: 0.1071731052506815
# Forecasting for day 19
# Forecasted value for day 19: 0.10629019945252934
# Forecasting for day 20
# Forecasted value for day 20: 0.10078994246236891
# Forecasting for day 21
# Forecasted value for day 21: 0.09807252923228872
# Forecasting for day 22
# Forecasted value for day 22: 0.09733334682835229
# Forecasting for day 23
# Forecasted value for day 23: 0.09309424770364734
# Forecasting for day 24
# Forecasted value for day 24: 0.09159020353332172
# Forecasting for day 25
# Forecasted value for day 25: 0.08640434877569227
# Forecasting for day 26
# Forecasted value for day 26: 0.0813813952466828
# Forecasting for day 27
# Forecasted value for day 27: 0.0800062032502062
# Forecasting for day 28
# Forecasted value for day 28: 0.07994738740834248
# Forecasting for day 29
# Forecasted value for day 29: 0.08242972698505671
# Forecasting for day 30
# Forecasted value for day 30: 0.08178352985254793

# %%
df_forecast_90 = fc_90_day.copy()
df_forecast_90.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_90))

df_forecast_60 = fc_60_day.copy()
df_forecast_60.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_60))

df_forecast_30 = fc_30_day.copy()
df_forecast_30.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_30))


# Plot the overall with connection to forecast
plt.figure(figsize=(15, 7))
# plt.plot(df_filtered['Close'], label='Train')
plt.plot(test.index, y_test, label='Actual Test')
plt.plot(test.index, test_preds, label='Forecast Test')
plt.plot(df_forecast_90.index, df_forecast_90['Close'], label='Forecast next 90 days', color='red')
plt.plot(df_forecast_60.index, df_forecast_60['Close'], label='Forecast next 60 days', color='black')
plt.plot(df_forecast_30.index, df_forecast_30['Close'], label='Forecast next 30 days', color='cyan')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Calculate the Model's RMSE, MAPE, and SMAPE
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape


# Calculate the metrics for the test data
rmse, mape, smape = calculate_metrics(y_test, test_preds)
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}")
print(f"SMAPE: {smape:.2f}")
# Out:
# RMSE: 0.01
# MAPE: 6.21
# SMAPE: 5.95
