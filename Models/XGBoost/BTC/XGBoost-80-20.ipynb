# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import datetime as dt

# %%
# Load the data
file_path = '../../../Dataset/BTC-USD.csv'
df = pd.read_csv(file_path, parse_dates=True, index_col=0)
df.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2018-03-01  10385.000000  11052.299805  10352.700195  10951.000000
# 2018-03-02  10977.400391  11189.000000  10850.099609  11086.400391
# 2018-03-03  11101.900391  11528.200195  11002.400391  11489.700195
# 2018-03-04  11497.400391  11512.599609  11136.099609  11512.599609
# 2018-03-05  11532.400391  11704.099609  11443.900391  11573.299805
#
#                Adj Close      Volume
# Date
# 2018-03-01  10951.000000  7317279744
# 2018-03-02  11086.400391  7620590080
# 2018-03-03  11489.700195  6690570240
# 2018-03-04  11512.599609  6084149760
# 2018-03-05  11573.299805  6468539904

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]
# Create the dataset with features
df_features = createFeatures(df)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()
# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Create the lineplot
plt.style.use('default')
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('BTC/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                   Close       MACD  Bollinger_Upper  Bollinger_Lower         MA26        EMA20
# Date
# 2018-10-02  6556.100098 -10.684094      6792.186134      6313.780956  6502.164645  6584.695354
# 2018-10-03  6502.589844 -16.371112      6792.002241      6312.492828  6503.530799  6576.875781
# 2018-10-04  6576.689941 -14.729068      6794.686803      6316.206264  6517.019644  6576.858082
# 2018-10-05  6622.479980  -9.621947      6800.417097      6318.403948  6529.389648  6581.203025
# 2018-10-06  6588.310059  -8.236796      6803.448380      6322.485653  6539.336182  6581.879885

# %%
# Training and Test dataset
test_size = 0.2
train_size = int(len(df_filtered) * (1 - test_size))
train, test = df_filtered.iloc[0:train_size], df_filtered.iloc[train_size:len(df_filtered)]

# %%
X_train = train.drop('Close', axis=1)
y_train = train['Close']

X_test = test.drop('Close', axis=1)
y_test = test['Close']

# %%
# XGBoost
# XGBoost Regressor
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train
        , y_train
        , eval_set=[(X_train, y_train), (X_test, y_test)]
        , early_stopping_rounds=50
       )
# Out:
# [0]	validation_0-rmse:12059.20352	validation_1-rmse:17979.80722
# [1]	validation_0-rmse:8561.24594	validation_1-rmse:13833.09229
# [2]	validation_0-rmse:6105.58755	validation_1-rmse:10899.25019
# [3]	validation_0-rmse:4391.78754	validation_1-rmse:8804.55947
# [4]	validation_0-rmse:3187.55470	validation_1-rmse:7339.74667
# [5]	validation_0-rmse:2350.04573	validation_1-rmse:6242.57703
# [6]	validation_0-rmse:1783.88184	validation_1-rmse:5466.67753
# [7]	validation_0-rmse:1395.92883	validation_1-rmse:4880.96432
# [8]	validation_0-rmse:1146.91720	validation_1-rmse:4461.13482
# [9]	validation_0-rmse:976.60008	validation_1-rmse:4200.74479
# [10]	validation_0-rmse:860.28026	validation_1-rmse:4039.45453
# [11]	validation_0-rmse:784.19203	validation_1-rmse:3942.54569
# [12]	validation_0-rmse:724.07168	validation_1-rmse:3837.58391
# [13]	validation_0-rmse:687.17012	validation_1-rmse:3774.89995
# [14]	validation_0-rmse:647.16881	validation_1-rmse:3730.43204
# [15]	validation_0-rmse:612.94152	validation_1-rmse:3716.25181
# [16]	validation_0-rmse:575.03484	validation_1-rmse:3715.38336
# [17]	validation_0-rmse:559.67494	validation_1-rmse:3717.75001
# [18]	validation_0-rmse:536.63694	validation_1-rmse:3704.33817
# [19]	validation_0-rmse:520.71374	validation_1-rmse:3702.84900
# [20]	validation_0-rmse:506.85179	validation_1-rmse:3687.09266
# [21]	validation_0-rmse:497.60435	validation_1-rmse:3661.69361
# [22]	validation_0-rmse:486.51945	validation_1-rmse:3648.29416
# [23]	validation_0-rmse:474.47764	validation_1-rmse:3640.98019
# [24]	validation_0-rmse:461.42281	validation_1-rmse:3638.39684
# [25]	validation_0-rmse:451.84676	validation_1-rmse:3647.96297
# [26]	validation_0-rmse:444.31351	validation_1-rmse:3668.12935
# C:\Users\lequo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [27]	validation_0-rmse:435.51053	validation_1-rmse:3668.02156
# [28]	validation_0-rmse:426.56214	validation_1-rmse:3675.38096
# [29]	validation_0-rmse:422.45912	validation_1-rmse:3674.75343
# [30]	validation_0-rmse:414.42928	validation_1-rmse:3674.62298
# [31]	validation_0-rmse:409.11328	validation_1-rmse:3677.43338
# [32]	validation_0-rmse:400.08027	validation_1-rmse:3672.15811
# [33]	validation_0-rmse:396.17262	validation_1-rmse:3672.67651
# [34]	validation_0-rmse:393.60520	validation_1-rmse:3673.57518
# [35]	validation_0-rmse:388.95565	validation_1-rmse:3681.25732
# [36]	validation_0-rmse:381.61533	validation_1-rmse:3680.88682
# [37]	validation_0-rmse:379.05720	validation_1-rmse:3680.52374
# [38]	validation_0-rmse:373.05613	validation_1-rmse:3675.16691
# [39]	validation_0-rmse:363.43716	validation_1-rmse:3677.50833
# [40]	validation_0-rmse:359.65303	validation_1-rmse:3683.71697
# [41]	validation_0-rmse:351.39074	validation_1-rmse:3685.46658
# [42]	validation_0-rmse:347.14661	validation_1-rmse:3688.20859
# [43]	validation_0-rmse:344.87744	validation_1-rmse:3668.49712
# [44]	validation_0-rmse:340.36502	validation_1-rmse:3667.93038
# [45]	validation_0-rmse:337.25720	validation_1-rmse:3668.05915
# [46]	validation_0-rmse:329.61738	validation_1-rmse:3670.43036
# [47]	validation_0-rmse:328.06104	validation_1-rmse:3654.79297
# [48]	validation_0-rmse:323.36964	validation_1-rmse:3654.65232
# [49]	validation_0-rmse:320.74940	validation_1-rmse:3654.15428
# [50]	validation_0-rmse:310.80458	validation_1-rmse:3653.88786
# [51]	validation_0-rmse:307.41153	validation_1-rmse:3658.60743
# [52]	validation_0-rmse:305.75873	validation_1-rmse:3651.02212
# [53]	validation_0-rmse:300.82149	validation_1-rmse:3651.80011
# [54]	validation_0-rmse:295.76357	validation_1-rmse:3652.12826
# [55]	validation_0-rmse:294.46462	validation_1-rmse:3654.98891
# [56]	validation_0-rmse:291.63327	validation_1-rmse:3644.07367
# [57]	validation_0-rmse:286.87930	validation_1-rmse:3643.42012
# [58]	validation_0-rmse:282.95848	validation_1-rmse:3645.86282
# [59]	validation_0-rmse:280.92817	validation_1-rmse:3645.79417
# [60]	validation_0-rmse:275.84304	validation_1-rmse:3647.11698
# [61]	validation_0-rmse:274.01364	validation_1-rmse:3639.98193
# [62]	validation_0-rmse:273.56352	validation_1-rmse:3639.89863
# [63]	validation_0-rmse:272.44877	validation_1-rmse:3633.98069
# [64]	validation_0-rmse:270.26390	validation_1-rmse:3633.40406
# [65]	validation_0-rmse:266.30452	validation_1-rmse:3636.17328
# [66]	validation_0-rmse:262.66485	validation_1-rmse:3638.44772
# [67]	validation_0-rmse:258.78614	validation_1-rmse:3637.32846
# [68]	validation_0-rmse:254.19079	validation_1-rmse:3641.63564
# [69]	validation_0-rmse:253.53749	validation_1-rmse:3637.17987
# [70]	validation_0-rmse:253.06320	validation_1-rmse:3632.75349
# [71]	validation_0-rmse:251.30878	validation_1-rmse:3632.66072
# [72]	validation_0-rmse:248.93745	validation_1-rmse:3632.35539
# [73]	validation_0-rmse:246.25205	validation_1-rmse:3632.06489
# [74]	validation_0-rmse:243.10471	validation_1-rmse:3630.37024
# [75]	validation_0-rmse:241.10840	validation_1-rmse:3631.31931
# [76]	validation_0-rmse:238.25831	validation_1-rmse:3631.23556
# [77]	validation_0-rmse:231.63938	validation_1-rmse:3634.41702
# [78]	validation_0-rmse:225.66180	validation_1-rmse:3636.16998
# [79]	validation_0-rmse:222.97810	validation_1-rmse:3635.02900
# [80]	validation_0-rmse:219.02307	validation_1-rmse:3635.25931
# [81]	validation_0-rmse:215.28630	validation_1-rmse:3635.66855
# [82]	validation_0-rmse:212.64971	validation_1-rmse:3635.85716
# [83]	validation_0-rmse:210.70951	validation_1-rmse:3637.61491
# [84]	validation_0-rmse:208.66571	validation_1-rmse:3638.26876
# [85]	validation_0-rmse:205.98088	validation_1-rmse:3640.23543
# [86]	validation_0-rmse:204.16150	validation_1-rmse:3640.14235
# [87]	validation_0-rmse:203.69911	validation_1-rmse:3640.09767
# [88]	validation_0-rmse:201.15633	validation_1-rmse:3640.03029
# [89]	validation_0-rmse:197.05996	validation_1-rmse:3639.96668
# [90]	validation_0-rmse:196.14649	validation_1-rmse:3640.11487
# [91]	validation_0-rmse:191.90445	validation_1-rmse:3639.81656
# [92]	validation_0-rmse:190.61199	validation_1-rmse:3641.46544
# [93]	validation_0-rmse:188.10742	validation_1-rmse:3638.87828
# [94]	validation_0-rmse:187.04436	validation_1-rmse:3638.03875
# [95]	validation_0-rmse:185.29368	validation_1-rmse:3638.41449
# [96]	validation_0-rmse:182.13097	validation_1-rmse:3638.36835
# [97]	validation_0-rmse:179.98202	validation_1-rmse:3638.60576
# [98]	validation_0-rmse:177.21473	validation_1-rmse:3640.58997
# [99]	validation_0-rmse:177.00854	validation_1-rmse:3640.59607
# [100]	validation_0-rmse:174.32378	validation_1-rmse:3640.43379
# [101]	validation_0-rmse:173.00642	validation_1-rmse:3638.43799
# [102]	validation_0-rmse:171.79097	validation_1-rmse:3639.08867
# [103]	validation_0-rmse:170.85087	validation_1-rmse:3641.31149
# [104]	validation_0-rmse:170.01654	validation_1-rmse:3641.33382
# [105]	validation_0-rmse:168.46859	validation_1-rmse:3642.23371
# [106]	validation_0-rmse:166.32096	validation_1-rmse:3641.48928
# [107]	validation_0-rmse:165.77475	validation_1-rmse:3643.72101
# [108]	validation_0-rmse:163.82217	validation_1-rmse:3640.21997
# [109]	validation_0-rmse:162.60797	validation_1-rmse:3641.26435
# [110]	validation_0-rmse:160.88160	validation_1-rmse:3641.32094
# [111]	validation_0-rmse:159.57456	validation_1-rmse:3636.90080
# [112]	validation_0-rmse:157.18121	validation_1-rmse:3636.62461
# [113]	validation_0-rmse:155.08314	validation_1-rmse:3636.58023
# [114]	validation_0-rmse:154.23666	validation_1-rmse:3636.71476
# [115]	validation_0-rmse:152.00259	validation_1-rmse:3636.37487
# [116]	validation_0-rmse:151.69033	validation_1-rmse:3636.42607
# [117]	validation_0-rmse:150.56183	validation_1-rmse:3636.45246
# [118]	validation_0-rmse:149.28199	validation_1-rmse:3635.73407
# [119]	validation_0-rmse:147.55149	validation_1-rmse:3636.76301
# [120]	validation_0-rmse:145.42952	validation_1-rmse:3636.71171
# [121]	validation_0-rmse:144.55958	validation_1-rmse:3636.80540
# [122]	validation_0-rmse:143.01833	validation_1-rmse:3635.94009
# [123]	validation_0-rmse:140.45297	validation_1-rmse:3638.72723
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Make predictions for validation and test sets
test_preds = reg.predict(X_test)

# plot the predictions
plt.figure(figsize=(15, 7))
plt.plot(test.index, test_preds, label='Predictions')
plt.plot(test.index, test['Close'], label='True Close')
plt.title('BTC/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Create function to forecast next x days
def forecast_next_x_days(df, num_days, best_model):

    print(f"Forecasting for day {num_days}")
    # Predict 1 day ahead and use the forecasted value to create features for the next day
    df_forecast = df.copy()
    for i in range(num_days):
        # Create the forecast's exogenous variables
        lag_feature_input = df_forecast.iloc[-1].drop('Close').copy()
        print(f"Forecasting for day {i+1}")
        forecast_1_ahead = best_model.predict(lag_feature_input.values.reshape(1, -1))
        print(f"Forecasted value for day {i+1}: {forecast_1_ahead[0]}") 
        # Append the forecasted value to the dataset 
        lag_feature_input['Close'] = forecast_1_ahead[0]
        df_forecast_extend = pd.DataFrame([lag_feature_input], columns=df_forecast.columns)
        df_forecast = pd.concat([df_forecast, df_forecast_extend], axis=0)
        df_forecast.index = pd.date_range(start=df_forecast.index.min(), periods=len(df_forecast))
        # Create the features for the next day
        df_forecast = createFeatures(df_forecast)
        # Filter the data to the list of FEATURES
        df_forecast = df_forecast[FEATURES].copy()

        
    return df_forecast[-num_days:]

# %%
fc_90_day = forecast_next_x_days(df_filtered, 90, reg)
fc_60_day = forecast_next_x_days(df_filtered, 60, reg)
fc_30_day = forecast_next_x_days(df_filtered, 30, reg)
# Out:
# Forecasting for day 90
# Forecasting for day 1
# Forecasted value for day 1: 59535.58203125
# Forecasting for day 2
# Forecasted value for day 2: 58521.99609375
# Forecasting for day 3
# Forecasted value for day 3: 57453.6484375
# Forecasting for day 4
# Forecasted value for day 4: 57499.12890625
# Forecasting for day 5
# Forecasted value for day 5: 54014.92578125
# Forecasting for day 6
# Forecasted value for day 6: 49891.640625
# Forecasting for day 7
# Forecasted value for day 7: 49963.15234375
# Forecasting for day 8
# Forecasted value for day 8: 49111.8828125
# Forecasting for day 9
# Forecasted value for day 9: 49162.69140625
# Forecasting for day 10
# Forecasted value for day 10: 50859.71875
# Forecasting for day 11
# Forecasted value for day 11: 49898.296875
# Forecasting for day 12
# Forecasted value for day 12: 48856.78515625
# Forecasting for day 13
# Forecasted value for day 13: 48003.08203125
# Forecasting for day 14
# Forecasted value for day 14: 46528.42578125
# Forecasting for day 15
# Forecasted value for day 15: 44916.71484375
# Forecasting for day 16
# Forecasted value for day 16: 45317.12109375
# Forecasting for day 17
# Forecasted value for day 17: 45573.64453125
# Forecasting for day 18
# Forecasted value for day 18: 40549.87109375
# Forecasting for day 19
# Forecasted value for day 19: 39918.88671875
# Forecasting for day 20
# Forecasted value for day 20: 36388.17578125
# Forecasting for day 21
# Forecasted value for day 21: 37128.20703125
# Forecasting for day 22
# Forecasted value for day 22: 35108.453125
# Forecasting for day 23
# Forecasted value for day 23: 34903.7109375
# Forecasting for day 24
# Forecasted value for day 24: 35948.0078125
# Forecasting for day 25
# Forecasted value for day 25: 36565.38671875
# Forecasting for day 26
# Forecasted value for day 26: 36500.03515625
# Forecasting for day 27
# Forecasted value for day 27: 35744.953125
# Forecasting for day 28
# Forecasted value for day 28: 36047.01953125
# Forecasting for day 29
# Forecasted value for day 29: 35699.1171875
# Forecasting for day 30
# Forecasted value for day 30: 35677.10546875
# Forecasting for day 31
# Forecasted value for day 31: 35936.9609375
# Forecasting for day 32
# Forecasted value for day 32: 36109.234375
# Forecasting for day 33
# Forecasted value for day 33: 36212.3828125
# Forecasting for day 34
# Forecasted value for day 34: 36360.8203125
# Forecasting for day 35
# Forecasted value for day 35: 36355.27734375
# Forecasting for day 36
# Forecasted value for day 36: 34485.03125
# Forecasting for day 37
# Forecasted value for day 37: 33559.40625
# Forecasting for day 38
# Forecasted value for day 38: 35051.2734375
# Forecasting for day 39
# Forecasted value for day 39: 34122.45703125
# Forecasting for day 40
# Forecasted value for day 40: 31899.412109375
# Forecasting for day 41
# Forecasted value for day 41: 33046.99609375
# Forecasting for day 42
# Forecasted value for day 42: 33624.796875
# Forecasting for day 43
# Forecasted value for day 43: 33362.27734375
# Forecasting for day 44
# Forecasted value for day 44: 32128.416015625
# Forecasting for day 45
# Forecasted value for day 45: 32316.630859375
# Forecasting for day 46
# Forecasted value for day 46: 32239.306640625
# Forecasting for day 47
# Forecasted value for day 47: 31640.458984375
# Forecasting for day 48
# Forecasted value for day 48: 31640.458984375
# Forecasting for day 49
# Forecasted value for day 49: 31764.685546875
# Forecasting for day 50
# Forecasted value for day 50: 31411.0859375
# Forecasting for day 51
# Forecasted value for day 51: 31549.70703125
# Forecasting for day 52
# Forecasted value for day 52: 31357.796875
# Forecasting for day 53
# Forecasted value for day 53: 31547.466796875
# Forecasting for day 54
# Forecasted value for day 54: 30550.818359375
# Forecasting for day 55
# Forecasted value for day 55: 30386.78125
# Forecasting for day 56
# Forecasted value for day 56: 29360.919921875
# Forecasting for day 57
# Forecasted value for day 57: 29656.119140625
# Forecasting for day 58
# Forecasted value for day 58: 29656.119140625
# Forecasting for day 59
# Forecasted value for day 59: 29656.119140625
# Forecasting for day 60
# Forecasted value for day 60: 29656.119140625
# Forecasting for day 61
# Forecasted value for day 61: 29404.66015625
# Forecasting for day 62
# Forecasted value for day 62: 29404.66015625
# Forecasting for day 63
# Forecasted value for day 63: 29404.66015625
# Forecasting for day 64
# Forecasted value for day 64: 29995.328125
# Forecasting for day 65
# Forecasted value for day 65: 31134.119140625
# Forecasting for day 66
# Forecasted value for day 66: 30991.328125
# Forecasting for day 67
# Forecasted value for day 67: 31858.8046875
# Forecasting for day 68
# Forecasted value for day 68: 31632.986328125
# Forecasting for day 69
# Forecasted value for day 69: 31786.724609375
# Forecasting for day 70
# Forecasted value for day 70: 32490.048828125
# Forecasting for day 71
# Forecasted value for day 71: 32044.654296875
# Forecasting for day 72
# Forecasted value for day 72: 32628.578125
# Forecasting for day 73
# Forecasted value for day 73: 32796.5625
# Forecasting for day 74
# Forecasted value for day 74: 32710.0546875
# Forecasting for day 75
# Forecasted value for day 75: 32784.02734375
# Forecasting for day 76
# Forecasted value for day 76: 34075.44921875
# Forecasting for day 77
# Forecasted value for day 77: 34101.90625
# Forecasting for day 78
# Forecasted value for day 78: 33948.26953125
# Forecasting for day 79
# Forecasted value for day 79: 34394.4296875
# Forecasting for day 80
# Forecasted value for day 80: 34222.78515625
# Forecasting for day 81
# Forecasted value for day 81: 34222.78515625
# Forecasting for day 82
# Forecasted value for day 82: 34240.48828125
# Forecasting for day 83
# Forecasted value for day 83: 36462.2734375
# Forecasting for day 84
# Forecasted value for day 84: 36786.10546875
# Forecasting for day 85
# Forecasted value for day 85: 36333.2421875
# Forecasting for day 86
# Forecasted value for day 86: 35829.5390625
# Forecasting for day 87
# Forecasted value for day 87: 35523.6015625
# Forecasting for day 88
# Forecasted value for day 88: 35553.015625
# Forecasting for day 89
# Forecasted value for day 89: 36388.61328125
# Forecasting for day 90
# Forecasted value for day 90: 37384.04296875
# Forecasting for day 60
# Forecasting for day 1
# Forecasted value for day 1: 59535.58203125
# Forecasting for day 2
# Forecasted value for day 2: 58521.99609375
# Forecasting for day 3
# Forecasted value for day 3: 57453.6484375
# Forecasting for day 4
# Forecasted value for day 4: 57499.12890625
# Forecasting for day 5
# Forecasted value for day 5: 54014.92578125
# Forecasting for day 6
# Forecasted value for day 6: 49891.640625
# Forecasting for day 7
# Forecasted value for day 7: 49963.15234375
# Forecasting for day 8
# Forecasted value for day 8: 49111.8828125
# Forecasting for day 9
# Forecasted value for day 9: 49162.69140625
# Forecasting for day 10
# Forecasted value for day 10: 50859.71875
# Forecasting for day 11
# Forecasted value for day 11: 49898.296875
# Forecasting for day 12
# Forecasted value for day 12: 48856.78515625
# Forecasting for day 13
# Forecasted value for day 13: 48003.08203125
# Forecasting for day 14
# Forecasted value for day 14: 46528.42578125
# Forecasting for day 15
# Forecasted value for day 15: 44916.71484375
# Forecasting for day 16
# Forecasted value for day 16: 45317.12109375
# Forecasting for day 17
# Forecasted value for day 17: 45573.64453125
# Forecasting for day 18
# Forecasted value for day 18: 40549.87109375
# Forecasting for day 19
# Forecasted value for day 19: 39918.88671875
# Forecasting for day 20
# Forecasted value for day 20: 36388.17578125
# Forecasting for day 21
# Forecasted value for day 21: 37128.20703125
# Forecasting for day 22
# Forecasted value for day 22: 35108.453125
# Forecasting for day 23
# Forecasted value for day 23: 34903.7109375
# Forecasting for day 24
# Forecasted value for day 24: 35948.0078125
# Forecasting for day 25
# Forecasted value for day 25: 36565.38671875
# Forecasting for day 26
# Forecasted value for day 26: 36500.03515625
# Forecasting for day 27
# Forecasted value for day 27: 35744.953125
# Forecasting for day 28
# Forecasted value for day 28: 36047.01953125
# Forecasting for day 29
# Forecasted value for day 29: 35699.1171875
# Forecasting for day 30
# Forecasted value for day 30: 35677.10546875
# Forecasting for day 31
# Forecasted value for day 31: 35936.9609375
# Forecasting for day 32
# Forecasted value for day 32: 36109.234375
# Forecasting for day 33
# Forecasted value for day 33: 36212.3828125
# Forecasting for day 34
# Forecasted value for day 34: 36360.8203125
# Forecasting for day 35
# Forecasted value for day 35: 36355.27734375
# Forecasting for day 36
# Forecasted value for day 36: 34485.03125
# Forecasting for day 37
# Forecasted value for day 37: 33559.40625
# Forecasting for day 38
# Forecasted value for day 38: 35051.2734375
# Forecasting for day 39
# Forecasted value for day 39: 34122.45703125
# Forecasting for day 40
# Forecasted value for day 40: 31899.412109375
# Forecasting for day 41
# Forecasted value for day 41: 33046.99609375
# Forecasting for day 42
# Forecasted value for day 42: 33624.796875
# Forecasting for day 43
# Forecasted value for day 43: 33362.27734375
# Forecasting for day 44
# Forecasted value for day 44: 32128.416015625
# Forecasting for day 45
# Forecasted value for day 45: 32316.630859375
# Forecasting for day 46
# Forecasted value for day 46: 32239.306640625
# Forecasting for day 47
# Forecasted value for day 47: 31640.458984375
# Forecasting for day 48
# Forecasted value for day 48: 31640.458984375
# Forecasting for day 49
# Forecasted value for day 49: 31764.685546875
# Forecasting for day 50
# Forecasted value for day 50: 31411.0859375
# Forecasting for day 51
# Forecasted value for day 51: 31549.70703125
# Forecasting for day 52
# Forecasted value for day 52: 31357.796875
# Forecasting for day 53
# Forecasted value for day 53: 31547.466796875
# Forecasting for day 54
# Forecasted value for day 54: 30550.818359375
# Forecasting for day 55
# Forecasted value for day 55: 30386.78125
# Forecasting for day 56
# Forecasted value for day 56: 29360.919921875
# Forecasting for day 57
# Forecasted value for day 57: 29656.119140625
# Forecasting for day 58
# Forecasted value for day 58: 29656.119140625
# Forecasting for day 59
# Forecasted value for day 59: 29656.119140625
# Forecasting for day 60
# Forecasted value for day 60: 29656.119140625
# Forecasting for day 30
# Forecasting for day 1
# Forecasted value for day 1: 59535.58203125
# Forecasting for day 2
# Forecasted value for day 2: 58521.99609375
# Forecasting for day 3
# Forecasted value for day 3: 57453.6484375
# Forecasting for day 4
# Forecasted value for day 4: 57499.12890625
# Forecasting for day 5
# Forecasted value for day 5: 54014.92578125
# Forecasting for day 6
# Forecasted value for day 6: 49891.640625
# Forecasting for day 7
# Forecasted value for day 7: 49963.15234375
# Forecasting for day 8
# Forecasted value for day 8: 49111.8828125
# Forecasting for day 9
# Forecasted value for day 9: 49162.69140625
# Forecasting for day 10
# Forecasted value for day 10: 50859.71875
# Forecasting for day 11
# Forecasted value for day 11: 49898.296875
# Forecasting for day 12
# Forecasted value for day 12: 48856.78515625
# Forecasting for day 13
# Forecasted value for day 13: 48003.08203125
# Forecasting for day 14
# Forecasted value for day 14: 46528.42578125
# Forecasting for day 15
# Forecasted value for day 15: 44916.71484375
# Forecasting for day 16
# Forecasted value for day 16: 45317.12109375
# Forecasting for day 17
# Forecasted value for day 17: 45573.64453125
# Forecasting for day 18
# Forecasted value for day 18: 40549.87109375
# Forecasting for day 19
# Forecasted value for day 19: 39918.88671875
# Forecasting for day 20
# Forecasted value for day 20: 36388.17578125
# Forecasting for day 21
# Forecasted value for day 21: 37128.20703125
# Forecasting for day 22
# Forecasted value for day 22: 35108.453125
# Forecasting for day 23
# Forecasted value for day 23: 34903.7109375
# Forecasting for day 24
# Forecasted value for day 24: 35948.0078125
# Forecasting for day 25
# Forecasted value for day 25: 36565.38671875
# Forecasting for day 26
# Forecasted value for day 26: 36500.03515625
# Forecasting for day 27
# Forecasted value for day 27: 35744.953125
# Forecasting for day 28
# Forecasted value for day 28: 36047.01953125
# Forecasting for day 29
# Forecasted value for day 29: 35699.1171875
# Forecasting for day 30
# Forecasted value for day 30: 35677.10546875

# %%
df_forecast_90 = fc_90_day.copy()
df_forecast_90.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_90))

df_forecast_60 = fc_60_day.copy()
df_forecast_60.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_60))

df_forecast_30 = fc_30_day.copy()
df_forecast_30.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_30))


forecast_30_label = f"Forecast next 30 days - " + \
    df_forecast_30.index[-1].strftime("%Y-%m-%d")
forecast_60_label = f"Forecast next 60 days - " + \
    df_forecast_60.index[-1].strftime("%Y-%m-%d")
forecast_90_label = f"Forecast next 90 days - " + \
    df_forecast_90.index[-1].strftime("%Y-%m-%d")

# Add last day of original data to the forecasted data
df_forecast_30 = pd.concat([df_filtered.tail(1), df_forecast_30])
df_forecast_30.index = pd.date_range(
    start=df_filtered.index.max(), periods=len(df_forecast_30))

# Plot the overall with connection to forecast
plt.figure(figsize=(15, 7))
plt.plot(df_filtered['Close'], label='Train')
plt.plot(test.index, y_test, label='Actual Test')
plt.plot(test.index, test_preds, label='Forecast Test')
plt.plot(df_forecast_90.index, 
         df_forecast_90['Close'], label=forecast_90_label)
plt.plot(df_forecast_60.index, 
         df_forecast_60['Close'], label=forecast_60_label)
plt.plot(df_forecast_30.index, 
         df_forecast_30['Close'], label= forecast_30_label)
plt.title('BTC/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Calculate the Model's RMSE, MAPE, and SMAPE
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape


# Calculate the metrics for the test data
rmse, mape, smape = calculate_metrics(y_test, test_preds)
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}")
print(f"SMAPE: {smape:.2f}")
# Out:
# RMSE: 3630.37
# MAPE: 6.43
# SMAPE: 6.70
