# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../../Dataset/BTC-USD.csv')
data.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2018-03-01  10385.000000  11052.299805  10352.700195  10951.000000
# 1  2018-03-02  10977.400391  11189.000000  10850.099609  11086.400391
# 2  2018-03-03  11101.900391  11528.200195  11002.400391  11489.700195
# 3  2018-03-04  11497.400391  11512.599609  11136.099609  11512.599609
# 4  2018-03-05  11532.400391  11704.099609  11443.900391  11573.299805
#
#       Adj Close      Volume
# 0  10951.000000  7317279744
# 1  11086.400391  7620590080
# 2  11489.700195  6690570240
# 3  11512.599609  6084149760
# 4  11573.299805  6468539904

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2018-03-01  10385.000000  11052.299805  10352.700195  10951.000000
# 2018-03-02  10977.400391  11189.000000  10850.099609  11086.400391
# 2018-03-03  11101.900391  11528.200195  11002.400391  11489.700195
# 2018-03-04  11497.400391  11512.599609  11136.099609  11512.599609
# 2018-03-05  11532.400391  11704.099609  11443.900391  11573.299805
#
#                Adj Close      Volume
# Date
# 2018-03-01  10951.000000  7317279744
# 2018-03-02  11086.400391  7620590080
# 2018-03-03  11489.700195  6690570240
# 2018-03-04  11512.599609  6084149760
# 2018-03-05  11573.299805  6468539904

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('BTC/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                   Close       MACD  Bollinger_Upper  Bollinger_Lower         MA26        EMA20
# Date
# 2018-10-02  6556.100098 -10.684094      6792.186134      6313.780956  6502.164645  6584.695354
# 2018-10-03  6502.589844 -16.371112      6792.002241      6312.492828  6503.530799  6576.875781
# 2018-10-04  6576.689941 -14.729068      6794.686803      6316.206264  6517.019644  6576.858082
# 2018-10-05  6622.479980  -9.621947      6800.417097      6318.403948  6529.389648  6581.203025
# 2018-10-06  6588.310059  -8.236796      6803.448380      6322.485653  6539.336182  6581.879885
#                   Close       MACD  Bollinger_Upper  Bollinger_Lower         MA26        EMA20
# Date
# 2018-10-02  6556.100098 -10.684094      6792.186134      6313.780956  6502.164645  6584.695354
# 2018-10-03  6502.589844 -16.371112      6792.002241      6312.492828  6503.530799  6576.875781
# 2018-10-04  6576.689941 -14.729068      6794.686803      6316.206264  6517.019644  6576.858082
# 2018-10-05  6622.479980  -9.621947      6800.417097      6318.403948  6529.389648  6581.203025
# 2018-10-06  6588.310059  -8.236796      6803.448380      6322.485653  6539.336182  6581.879885

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (2070, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.90)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1863, 6) (207, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1856, 7, 6) (1856,)
# (200, 7, 6) (200,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1856, 7, 6) (1856,)
# (200, 7, 6) (200,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
# model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
# model.add(Dense(1))
model.add(SimpleRNN(n_neurons, return_sequences=True,
          input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(SimpleRNN(n_neurons, return_sequences=True))
model.add(SimpleRNN(n_neurons))
model.add(Dense(1))


# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1872 - val_loss: 0.0527
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0100
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7805e-04 - val_loss: 0.0033
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4177e-04 - val_loss: 0.0026
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4287e-04 - val_loss: 0.0026
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1394e-04 - val_loss: 0.0023
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2601e-04 - val_loss: 0.0022
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6729e-04 - val_loss: 0.0023
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4309e-04 - val_loss: 0.0017
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6330e-04 - val_loss: 0.0015
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6550e-04 - val_loss: 0.0015
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9784e-04 - val_loss: 0.0012
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2310e-04 - val_loss: 0.0021
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7812e-04 - val_loss: 0.0016
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1034e-04 - val_loss: 0.0014
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5522e-04 - val_loss: 0.0018
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2210e-04 - val_loss: 0.0018
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3847e-04 - val_loss: 0.0017
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0332e-04 - val_loss: 0.0027
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2585e-04 - val_loss: 9.8645e-04
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1560e-04 - val_loss: 0.0012
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2264e-04 - val_loss: 0.0016
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5918e-04 - val_loss: 0.0015
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3623e-04 - val_loss: 0.0011
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2473e-04 - val_loss: 0.0019
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3946e-04 - val_loss: 0.0012
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0806e-04 - val_loss: 0.0022
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9805e-04 - val_loss: 0.0014
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2473e-04 - val_loss: 0.0016
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1724e-04 - val_loss: 0.0011
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3390e-04 - val_loss: 0.0016
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2429e-04 - val_loss: 9.5656e-04
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1351e-04 - val_loss: 0.0016
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1472e-04 - val_loss: 9.9737e-04
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5772e-04 - val_loss: 0.0011
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8708e-04 - val_loss: 0.0019
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0054e-04 - val_loss: 0.0016
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7185e-04 - val_loss: 0.0017
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3634e-04 - val_loss: 0.0012
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9597e-04 - val_loss: 0.0013
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1620e-04 - val_loss: 9.3610e-04
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4121e-04 - val_loss: 0.0012
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6301e-04 - val_loss: 0.0016
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1730e-04 - val_loss: 8.1989e-04
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0246e-04 - val_loss: 9.9663e-04
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3531e-04 - val_loss: 0.0017
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7203e-04 - val_loss: 0.0034
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8292e-04 - val_loss: 0.0012
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7723e-04 - val_loss: 0.0014
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5700e-04 - val_loss: 0.0017
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9097e-04 - val_loss: 9.6689e-04
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5507e-04 - val_loss: 0.0011
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7335e-04 - val_loss: 0.0019
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6487e-04 - val_loss: 0.0015
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4211e-04 - val_loss: 0.0014
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4755e-04 - val_loss: 0.0015
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8132e-04 - val_loss: 0.0013
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7624e-04 - val_loss: 0.0011
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1245e-04 - val_loss: 0.0015
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0332e-04 - val_loss: 0.0012
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6807e-04 - val_loss: 0.0013
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0668e-04 - val_loss: 0.0012
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5484e-04 - val_loss: 0.0015
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8028e-04 - val_loss: 0.0011
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2273e-04 - val_loss: 8.5120e-04
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1305e-04 - val_loss: 9.9747e-04
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0218e-04 - val_loss: 9.1902e-04
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4963e-04 - val_loss: 0.0013
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1309e-04 - val_loss: 0.0016
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5787e-04 - val_loss: 0.0012
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6190e-04 - val_loss: 0.0011
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4530e-04 - val_loss: 8.1529e-04
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1250e-04 - val_loss: 0.0010
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3713e-04 - val_loss: 0.0015
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5989e-04 - val_loss: 7.6078e-04
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6802e-04 - val_loss: 9.3695e-04
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0092e-04 - val_loss: 6.8080e-04
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8063e-04 - val_loss: 7.5633e-04
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4200e-04 - val_loss: 0.0031
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9139e-04 - val_loss: 0.0013
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6429e-04 - val_loss: 8.2401e-04
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3422e-04 - val_loss: 0.0011
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8734e-04 - val_loss: 0.0012
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8472e-04 - val_loss: 0.0015
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4502e-04 - val_loss: 7.0295e-04
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6873e-04 - val_loss: 8.9093e-04
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2009e-04 - val_loss: 8.0110e-04
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4742e-04 - val_loss: 8.7154e-04
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2602e-04 - val_loss: 0.0011
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7657e-04 - val_loss: 8.0025e-04
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2054e-04 - val_loss: 8.7772e-04
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1385e-04 - val_loss: 0.0011
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5181e-04 - val_loss: 0.0015
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1014e-04 - val_loss: 0.0011
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8793e-04 - val_loss: 0.0011
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1104e-04 - val_loss: 0.0011
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3769e-04 - val_loss: 0.0012
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6415e-04 - val_loss: 8.3436e-04

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('BTC/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (207, 7, 6)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.9346368  0.618906   0.93448627 0.88456359 0.94055658 0.96713398]
#   [0.94718515 0.62173632 0.93970788 0.88967608 0.94714786 0.97119683]
#   [0.9314602  0.61402545 0.9406081  0.89993145 0.95257492 0.97326914]
#   [0.92117876 0.60101521 0.94164573 0.90592024 0.95534871 0.9740956 ]
#   [0.93244484 0.59536796 0.93964267 0.92031712 0.95799546 0.97599225]
#   [0.91993777 0.58301309 0.93451863 0.93698097 0.96004273 0.97643281]
#   [0.92302343 0.57376916 0.92881735 0.9536227  0.96273176 0.97714608]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 1: [[64859.664]]
# x_pred_input of day 2:
# [[[0.94718515 0.62173632 0.93970788 0.88967608 0.94714786 0.97119683]
#   [0.9314602  0.61402545 0.9406081  0.89993145 0.95257492 0.97326914]
#   [0.92117876 0.60101521 0.94164573 0.90592024 0.95534871 0.9740956 ]
#   [0.93244484 0.59536796 0.93964267 0.92031712 0.95799546 0.97599225]
#   [0.91993777 0.58301309 0.93451863 0.93698097 0.96004273 0.97643281]
#   [0.92302343 0.57376916 0.92881735 0.9536227  0.96273176 0.97714608]
#   [0.88225884 0.54393622 0.92551797 0.9606062  0.96422559 0.97363432]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 2: [[63479.44]]
# x_pred_input of day 3:
# [[[0.9314602  0.61402545 0.9406081  0.89993145 0.95257492 0.97326914]
#   [0.92117876 0.60101521 0.94164573 0.90592024 0.95534871 0.9740956 ]
#   [0.93244484 0.59536796 0.93964267 0.92031712 0.95799546 0.97599225]
#   [0.91993777 0.58301309 0.93451863 0.93698097 0.96004273 0.97643281]
#   [0.92302343 0.57376916 0.92881735 0.9536227  0.96273176 0.97714608]
#   [0.88225884 0.54393622 0.92551797 0.9606062  0.96422559 0.97363432]
#   [0.86249811 0.50939214 0.91977346 0.97040574 0.96558135 0.96844185]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 3: [[61914.918]]
# x_pred_input of day 4:
# [[[0.92117876 0.60101521 0.94164573 0.90592024 0.95534871 0.9740956 ]
#   [0.93244484 0.59536796 0.93964267 0.92031712 0.95799546 0.97599225]
#   [0.91993777 0.58301309 0.93451863 0.93698097 0.96004273 0.97643281]
#   [0.92302343 0.57376916 0.92881735 0.9536227  0.96273176 0.97714608]
#   [0.88225884 0.54393622 0.92551797 0.9606062  0.96422559 0.97363432]
#   [0.86249811 0.50939214 0.91977346 0.97040574 0.96558135 0.96844185]
#   [0.84009873 0.47015873 0.92733618 0.95461475 0.9649098  0.96145964]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 4: [[60877.47]]
# x_pred_input of day 5:
# [[[0.93244484 0.59536796 0.93964267 0.92031712 0.95799546 0.97599225]
#   [0.91993777 0.58301309 0.93451863 0.93698097 0.96004273 0.97643281]
#   [0.92302343 0.57376916 0.92881735 0.9536227  0.96273176 0.97714608]
#   [0.88225884 0.54393622 0.92551797 0.9606062  0.96422559 0.97363432]
#   [0.86249811 0.50939214 0.91977346 0.97040574 0.96558135 0.96844185]
#   [0.84009873 0.47015873 0.92733618 0.95461475 0.9649098  0.96145964]
#   [0.82524551 0.43167917 0.93528548 0.93836816 0.96495991 0.9536277 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 5: [[60039.715]]
# x_pred_input of day 6:
# [[[0.91993777 0.58301309 0.93451863 0.93698097 0.96004273 0.97643281]
#   [0.92302343 0.57376916 0.92881735 0.9536227  0.96273176 0.97714608]
#   [0.88225884 0.54393622 0.92551797 0.9606062  0.96422559 0.97363432]
#   [0.86249811 0.50939214 0.91977346 0.97040574 0.96558135 0.96844185]
#   [0.84009873 0.47015873 0.92733618 0.95461475 0.9649098  0.96145964]
#   [0.82524551 0.43167917 0.93528548 0.93836816 0.96495991 0.9536277 ]
#   [0.81325133 0.39573693 0.94280121 0.91840034 0.96451381 0.94531851]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 6: [[59720.617]]
# x_pred_input of day 7:
# [[[0.92302343 0.57376916 0.92881735 0.9536227  0.96273176 0.97714608]
#   [0.88225884 0.54393622 0.92551797 0.9606062  0.96422559 0.97363432]
#   [0.86249811 0.50939214 0.91977346 0.97040574 0.96558135 0.96844185]
#   [0.84009873 0.47015873 0.92733618 0.95461475 0.9649098  0.96145964]
#   [0.82524551 0.43167917 0.93528548 0.93836816 0.96495991 0.9536277 ]
#   [0.81325133 0.39573693 0.94280121 0.91840034 0.96451381 0.94531851]
#   [0.80868279 0.36610936 0.94849256 0.9002401  0.96349157 0.93733478]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 7: [[59358.176]]
# x_pred_input of day 8:
# [[[0.88225884 0.54393622 0.92551797 0.9606062  0.96422559 0.97363432]
#   [0.86249811 0.50939214 0.91977346 0.97040574 0.96558135 0.96844185]
#   [0.84009873 0.47015873 0.92733618 0.95461475 0.9649098  0.96145964]
#   [0.82524551 0.43167917 0.93528548 0.93836816 0.96495991 0.9536277 ]
#   [0.81325133 0.39573693 0.94280121 0.91840034 0.96451381 0.94531851]
#   [0.80868279 0.36610936 0.94849256 0.9002401  0.96349157 0.93733478]
#   [0.8034937  0.34143946 0.95335089 0.88353369 0.9613952  0.92958223]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 8: [[59131.15]]
# x_pred_input of day 9:
# [[[0.86249811 0.50939214 0.91977346 0.97040574 0.96558135 0.96844185]
#   [0.84009873 0.47015873 0.92733618 0.95461475 0.9649098  0.96145964]
#   [0.82524551 0.43167917 0.93528548 0.93836816 0.96495991 0.9536277 ]
#   [0.81325133 0.39573693 0.94280121 0.91840034 0.96451381 0.94531851]
#   [0.80868279 0.36610936 0.94849256 0.9002401  0.96349157 0.93733478]
#   [0.8034937  0.34143946 0.95335089 0.88353369 0.9613952  0.92958223]
#   [0.80024333 0.32195763 0.94771192 0.87054506 0.95996244 0.92223655]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 9: [[58967.773]]
# x_pred_input of day 10:
# [[[0.84009873 0.47015873 0.92733618 0.95461475 0.9649098  0.96145964]
#   [0.82524551 0.43167917 0.93528548 0.93836816 0.96495991 0.9536277 ]
#   [0.81325133 0.39573693 0.94280121 0.91840034 0.96451381 0.94531851]
#   [0.80868279 0.36610936 0.94849256 0.9002401  0.96349157 0.93733478]
#   [0.8034937  0.34143946 0.95335089 0.88353369 0.9613952  0.92958223]
#   [0.80024333 0.32195763 0.94771192 0.87054506 0.95996244 0.92223655]
#   [0.79790428 0.30724328 0.94313207 0.85814205 0.95564358 0.91535192]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 10: [[58710.055]]
# x_pred_input of day 11:
# [[[0.82524551 0.43167917 0.93528548 0.93836816 0.96495991 0.9536277 ]
#   [0.81325133 0.39573693 0.94280121 0.91840034 0.96451381 0.94531851]
#   [0.80868279 0.36610936 0.94849256 0.9002401  0.96349157 0.93733478]
#   [0.8034937  0.34143946 0.95335089 0.88353369 0.9613952  0.92958223]
#   [0.80024333 0.32195763 0.94771192 0.87054506 0.95996244 0.92223655]
#   [0.79790428 0.30724328 0.94313207 0.85814205 0.95564358 0.91535192]
#   [0.79421451 0.29571928 0.93913452 0.84626015 0.95178513 0.9087467 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 11: [[58370.35]]
# x_pred_input of day 12:
# [[[0.81325133 0.39573693 0.94280121 0.91840034 0.96451381 0.94531851]
#   [0.80868279 0.36610936 0.94849256 0.9002401  0.96349157 0.93733478]
#   [0.8034937  0.34143946 0.95335089 0.88353369 0.9613952  0.92958223]
#   [0.80024333 0.32195763 0.94771192 0.87054506 0.95996244 0.92223655]
#   [0.79790428 0.30724328 0.94313207 0.85814205 0.95564358 0.91535192]
#   [0.79421451 0.29571928 0.93913452 0.84626015 0.95178513 0.9087467 ]
#   [0.78935096 0.28620699 0.93624176 0.83444058 0.94664873 0.90227457]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 12: [[58019.938]]
# x_pred_input of day 13:
# [[[0.80868279 0.36610936 0.94849256 0.9002401  0.96349157 0.93733478]
#   [0.8034937  0.34143946 0.95335089 0.88353369 0.9613952  0.92958223]
#   [0.80024333 0.32195763 0.94771192 0.87054506 0.95996244 0.92223655]
#   [0.79790428 0.30724328 0.94313207 0.85814205 0.95564358 0.91535192]
#   [0.79421451 0.29571928 0.93913452 0.84626015 0.95178513 0.9087467 ]
#   [0.78935096 0.28620699 0.93624176 0.83444058 0.94664873 0.90227457]
#   [0.78433406 0.27829833 0.93081469 0.82408502 0.94137071 0.89590722]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 13: [[57619.562]]
# x_pred_input of day 14:
# [[[0.8034937  0.34143946 0.95335089 0.88353369 0.9613952  0.92958223]
#   [0.80024333 0.32195763 0.94771192 0.87054506 0.95996244 0.92223655]
#   [0.79790428 0.30724328 0.94313207 0.85814205 0.95564358 0.91535192]
#   [0.79421451 0.29571928 0.93913452 0.84626015 0.95178513 0.9087467 ]
#   [0.78935096 0.28620699 0.93624176 0.83444058 0.94664873 0.90227457]
#   [0.78433406 0.27829833 0.93081469 0.82408502 0.94137071 0.89590722]
#   [0.77860187 0.27135888 0.9220297  0.81585139 0.93624775 0.88956172]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 14: [[57089.918]]
# x_pred_input of day 15:
# [[[0.80024333 0.32195763 0.94771192 0.87054506 0.95996244 0.92223655]
#   [0.79790428 0.30724328 0.94313207 0.85814205 0.95564358 0.91535192]
#   [0.79421451 0.29571928 0.93913452 0.84626015 0.95178513 0.9087467 ]
#   [0.78935096 0.28620699 0.93624176 0.83444058 0.94664873 0.90227457]
#   [0.78433406 0.27829833 0.93081469 0.82408502 0.94137071 0.89590722]
#   [0.77860187 0.27135888 0.9220297  0.81585139 0.93624775 0.88956172]
#   [0.77101891 0.26428156 0.91363707 0.80750504 0.9277527  0.88304726]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 15: [[56563.887]]
# x_pred_input of day 16:
# [[[0.79790428 0.30724328 0.94313207 0.85814205 0.95564358 0.91535192]
#   [0.79421451 0.29571928 0.93913452 0.84626015 0.95178513 0.9087467 ]
#   [0.78935096 0.28620699 0.93624176 0.83444058 0.94664873 0.90227457]
#   [0.78433406 0.27829833 0.93081469 0.82408502 0.94137071 0.89590722]
#   [0.77860187 0.27135888 0.9220297  0.81585139 0.93624775 0.88956172]
#   [0.77101891 0.26428156 0.91363707 0.80750504 0.9277527  0.88304726]
#   [0.76348769 0.25720416 0.90082266 0.80211037 0.91972248 0.8763852 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 16: [[55902.82]]
# x_pred_input of day 17:
# [[[0.79421451 0.29571928 0.93913452 0.84626015 0.95178513 0.9087467 ]
#   [0.78935096 0.28620699 0.93624176 0.83444058 0.94664873 0.90227457]
#   [0.78433406 0.27829833 0.93081469 0.82408502 0.94137071 0.89590722]
#   [0.77860187 0.27135888 0.9220297  0.81585139 0.93624775 0.88956172]
#   [0.77101891 0.26428156 0.91363707 0.80750504 0.9277527  0.88304726]
#   [0.76348769 0.25720416 0.90082266 0.80211037 0.91972248 0.8763852 ]
#   [0.75402316 0.2491875  0.88939106 0.79579051 0.91190118 0.86939244]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 17: [[55264.812]]
# x_pred_input of day 18:
# [[[0.78935096 0.28620699 0.93624176 0.83444058 0.94664873 0.90227457]
#   [0.78433406 0.27829833 0.93081469 0.82408502 0.94137071 0.89590722]
#   [0.77860187 0.27135888 0.9220297  0.81585139 0.93624775 0.88956172]
#   [0.77101891 0.26428156 0.91363707 0.80750504 0.9277527  0.88304726]
#   [0.76348769 0.25720416 0.90082266 0.80211037 0.91972248 0.8763852 ]
#   [0.75402316 0.2491875  0.88939106 0.79579051 0.91190118 0.86939244]
#   [0.74488877 0.24070047 0.87821818 0.78929486 0.9044081  0.86213416]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 18: [[54559.734]]
# x_pred_input of day 19:
# [[[0.78433406 0.27829833 0.93081469 0.82408502 0.94137071 0.89590722]
#   [0.77860187 0.27135888 0.9220297  0.81585139 0.93624775 0.88956172]
#   [0.77101891 0.26428156 0.91363707 0.80750504 0.9277527  0.88304726]
#   [0.76348769 0.25720416 0.90082266 0.80211037 0.91972248 0.8763852 ]
#   [0.75402316 0.2491875  0.88939106 0.79579051 0.91190118 0.86939244]
#   [0.74488877 0.24070047 0.87821818 0.78929486 0.9044081  0.86213416]
#   [0.73479412 0.23143507 0.8619669  0.78637822 0.89614493 0.8545377 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 19: [[53773.453]]
# x_pred_input of day 20:
# [[[0.77860187 0.27135888 0.9220297  0.81585139 0.93624775 0.88956172]
#   [0.77101891 0.26428156 0.91363707 0.80750504 0.9277527  0.88304726]
#   [0.76348769 0.25720416 0.90082266 0.80211037 0.91972248 0.8763852 ]
#   [0.75402316 0.2491875  0.88939106 0.79579051 0.91190118 0.86939244]
#   [0.74488877 0.24070047 0.87821818 0.78929486 0.9044081  0.86213416]
#   [0.73479412 0.23143507 0.8619669  0.78637822 0.89614493 0.8545377 ]
#   [0.72353688 0.22105216 0.84612319 0.78312272 0.88697883 0.84651672]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 20: [[52948.73]]
# x_pred_input of day 21:
# [[[0.77101891 0.26428156 0.91363707 0.80750504 0.9277527  0.88304726]
#   [0.76348769 0.25720416 0.90082266 0.80211037 0.91972248 0.8763852 ]
#   [0.75402316 0.2491875  0.88939106 0.79579051 0.91190118 0.86939244]
#   [0.74488877 0.24070047 0.87821818 0.78929486 0.9044081  0.86213416]
#   [0.73479412 0.23143507 0.8619669  0.78637822 0.89614493 0.8545377 ]
#   [0.72353688 0.22105216 0.84612319 0.78312272 0.88697883 0.84651672]
#   [0.71172928 0.20962169 0.82578275 0.78348318 0.87776725 0.83805552]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 21: [[51996.09]]
# x_pred_input of day 22:
# [[[0.76348769 0.25720416 0.90082266 0.80211037 0.91972248 0.8763852 ]
#   [0.75402316 0.2491875  0.88939106 0.79579051 0.91190118 0.86939244]
#   [0.74488877 0.24070047 0.87821818 0.78929486 0.9044081  0.86213416]
#   [0.73479412 0.23143507 0.8619669  0.78637822 0.89614493 0.8545377 ]
#   [0.72353688 0.22105216 0.84612319 0.78312272 0.88697883 0.84651672]
#   [0.71172928 0.20962169 0.82578275 0.78348318 0.87776725 0.83805552]
#   [0.69809027 0.19653466 0.81468504 0.77602379 0.86747348 0.82900926]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 22: [[51189.73]]
# x_pred_input of day 23:
# [[[0.75402316 0.2491875  0.88939106 0.79579051 0.91190118 0.86939244]
#   [0.74488877 0.24070047 0.87821818 0.78929486 0.9044081  0.86213416]
#   [0.73479412 0.23143507 0.8619669  0.78637822 0.89614493 0.8545377 ]
#   [0.72353688 0.22105216 0.84612319 0.78312272 0.88697883 0.84651672]
#   [0.71172928 0.20962169 0.82578275 0.78348318 0.87776725 0.83805552]
#   [0.69809027 0.19653466 0.81468504 0.77602379 0.86747348 0.82900926]
#   [0.68654557 0.18340366 0.80677488 0.76574101 0.85735246 0.81964725]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 23: [[50441.016]]
# x_pred_input of day 24:
# [[[0.74488877 0.24070047 0.87821818 0.78929486 0.9044081  0.86213416]
#   [0.73479412 0.23143507 0.8619669  0.78637822 0.89614493 0.8545377 ]
#   [0.72353688 0.22105216 0.84612319 0.78312272 0.88697883 0.84651672]
#   [0.71172928 0.20962169 0.82578275 0.78348318 0.87776725 0.83805552]
#   [0.69809027 0.19653466 0.81468504 0.77602379 0.86747348 0.82900926]
#   [0.68654557 0.18340366 0.80677488 0.76574101 0.85735246 0.81964725]
#   [0.67582617 0.17082323 0.80238484 0.75262995 0.84721335 0.81008371]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 24: [[49877.08]]
# x_pred_input of day 25:
# [[[0.73479412 0.23143507 0.8619669  0.78637822 0.89614493 0.8545377 ]
#   [0.72353688 0.22105216 0.84612319 0.78312272 0.88697883 0.84651672]
#   [0.71172928 0.20962169 0.82578275 0.78348318 0.87776725 0.83805552]
#   [0.69809027 0.19653466 0.81468504 0.77602379 0.86747348 0.82900926]
#   [0.68654557 0.18340366 0.80677488 0.76574101 0.85735246 0.81964725]
#   [0.67582617 0.17082323 0.80238484 0.75262995 0.84721335 0.81008371]
#   [0.66775225 0.16021304 0.79920154 0.73885777 0.83627501 0.80060761]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 25: [[49356.453]]
# x_pred_input of day 26:
# [[[0.72353688 0.22105216 0.84612319 0.78312272 0.88697883 0.84651672]
#   [0.71172928 0.20962169 0.82578275 0.78348318 0.87776725 0.83805552]
#   [0.69809027 0.19653466 0.81468504 0.77602379 0.86747348 0.82900926]
#   [0.68654557 0.18340366 0.80677488 0.76574101 0.85735246 0.81964725]
#   [0.67582617 0.17082323 0.80238484 0.75262995 0.84721335 0.81008371]
#   [0.66775225 0.16021304 0.79920154 0.73885777 0.83627501 0.80060761]
#   [0.66029843 0.15159453 0.79652905 0.72499143 0.8255455  0.79127387]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 26: [[48878.492]]
# x_pred_input of day 27:
# [[[0.71172928 0.20962169 0.82578275 0.78348318 0.87776725 0.83805552]
#   [0.69809027 0.19653466 0.81468504 0.77602379 0.86747348 0.82900926]
#   [0.68654557 0.18340366 0.80677488 0.76574101 0.85735246 0.81964725]
#   [0.67582617 0.17082323 0.80238484 0.75262995 0.84721335 0.81008371]
#   [0.66775225 0.16021304 0.79920154 0.73885777 0.83627501 0.80060761]
#   [0.66029843 0.15159453 0.79652905 0.72499143 0.8255455  0.79127387]
#   [0.65345543 0.14495687 0.79300014 0.71187621 0.81440568 0.78213123]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 27: [[48502.508]]
# x_pred_input of day 28:
# [[[0.69809027 0.19653466 0.81468504 0.77602379 0.86747348 0.82900926]
#   [0.68654557 0.18340366 0.80677488 0.76574101 0.85735246 0.81964725]
#   [0.67582617 0.17082323 0.80238484 0.75262995 0.84721335 0.81008371]
#   [0.66775225 0.16021304 0.79920154 0.73885777 0.83627501 0.80060761]
#   [0.66029843 0.15159453 0.79652905 0.72499143 0.8255455  0.79127387]
#   [0.65345543 0.14495687 0.79300014 0.71187621 0.81440568 0.78213123]
#   [0.64807244 0.14071699 0.78860019 0.69976051 0.80472801 0.77331036]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 28: [[48117.234]]
# x_pred_input of day 29:
# [[[0.68654557 0.18340366 0.80677488 0.76574101 0.85735246 0.81964725]
#   [0.67582617 0.17082323 0.80238484 0.75262995 0.84721335 0.81008371]
#   [0.66775225 0.16021304 0.79920154 0.73885777 0.83627501 0.80060761]
#   [0.66029843 0.15159453 0.79652905 0.72499143 0.8255455  0.79127387]
#   [0.65345543 0.14495687 0.79300014 0.71187621 0.81440568 0.78213123]
#   [0.64807244 0.14071699 0.78860019 0.69976051 0.80472801 0.77331036]
#   [0.64255646 0.13833387 0.78305248 0.68873843 0.79563899 0.76476706]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 29: [[47755.66]]
# x_pred_input of day 30:
# [[[0.67582617 0.17082323 0.80238484 0.75262995 0.84721335 0.81008371]
#   [0.66775225 0.16021304 0.79920154 0.73885777 0.83627501 0.80060761]
#   [0.66029843 0.15159453 0.79652905 0.72499143 0.8255455  0.79127387]
#   [0.65345543 0.14495687 0.79300014 0.71187621 0.81440568 0.78213123]
#   [0.64807244 0.14071699 0.78860019 0.69976051 0.80472801 0.77331036]
#   [0.64255646 0.13833387 0.78305248 0.68873843 0.79563899 0.76476706]
#   [0.63737978 0.13761162 0.77614163 0.67899889 0.78726169 0.7565095 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 30: [[47383.125]]
# x_pred_input of day 31:
# [[[0.66775225 0.16021304 0.79920154 0.73885777 0.83627501 0.80060761]
#   [0.66029843 0.15159453 0.79652905 0.72499143 0.8255455  0.79127387]
#   [0.65345543 0.14495687 0.79300014 0.71187621 0.81440568 0.78213123]
#   [0.64807244 0.14071699 0.78860019 0.69976051 0.80472801 0.77331036]
#   [0.64255646 0.13833387 0.78305248 0.68873843 0.79563899 0.76476706]
#   [0.63737978 0.13761162 0.77614163 0.67899889 0.78726169 0.7565095 ]
#   [0.63204617 0.13811607 0.7681009  0.67040113 0.77927779 0.74849447]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 31: [[47010.504]]
# x_pred_input of day 32:
# [[[0.66029843 0.15159453 0.79652905 0.72499143 0.8255455  0.79127387]
#   [0.65345543 0.14495687 0.79300014 0.71187621 0.81440568 0.78213123]
#   [0.64807244 0.14071699 0.78860019 0.69976051 0.80472801 0.77331036]
#   [0.64255646 0.13833387 0.78305248 0.68873843 0.79563899 0.76476706]
#   [0.63737978 0.13761162 0.77614163 0.67899889 0.78726169 0.7565095 ]
#   [0.63204617 0.13811607 0.7681009  0.67040113 0.77927779 0.74849447]
#   [0.62671133 0.13957522 0.7591254  0.66284674 0.77156909 0.74069873]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 32: [[46649.832]]
# x_pred_input of day 33:
# [[[0.65345543 0.14495687 0.79300014 0.71187621 0.81440568 0.78213123]
#   [0.64807244 0.14071699 0.78860019 0.69976051 0.80472801 0.77331036]
#   [0.64255646 0.13833387 0.78305248 0.68873843 0.79563899 0.76476706]
#   [0.63737978 0.13761162 0.77614163 0.67899889 0.78726169 0.7565095 ]
#   [0.63204617 0.13811607 0.7681009  0.67040113 0.77927779 0.74849447]
#   [0.62671133 0.13957522 0.7591254  0.66284674 0.77156909 0.74069873]
#   [0.62154757 0.14185596 0.74918723 0.65640451 0.76383578 0.73311885]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 33: [[46294.227]]
# x_pred_input of day 34:
# [[[0.64807244 0.14071699 0.78860019 0.69976051 0.80472801 0.77331036]
#   [0.64255646 0.13833387 0.78305248 0.68873843 0.79563899 0.76476706]
#   [0.63737978 0.13761162 0.77614163 0.67899889 0.78726169 0.7565095 ]
#   [0.63204617 0.13811607 0.7681009  0.67040113 0.77927779 0.74849447]
#   [0.62671133 0.13957522 0.7591254  0.66284674 0.77156909 0.74069873]
#   [0.62154757 0.14185596 0.74918723 0.65640451 0.76383578 0.73311885]
#   [0.61645634 0.14479268 0.7383781  0.65105447 0.75610652 0.72574167]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 34: [[45948.3]]
# x_pred_input of day 35:
# [[[0.64255646 0.13833387 0.78305248 0.68873843 0.79563899 0.76476706]
#   [0.63737978 0.13761162 0.77614163 0.67899889 0.78726169 0.7565095 ]
#   [0.63204617 0.13811607 0.7681009  0.67040113 0.77927779 0.74849447]
#   [0.62671133 0.13957522 0.7591254  0.66284674 0.77156909 0.74069873]
#   [0.62154757 0.14185596 0.74918723 0.65640451 0.76383578 0.73311885]
#   [0.61645634 0.14479268 0.7383781  0.65105447 0.75610652 0.72574167]
#   [0.6115037  0.14828298 0.72706589 0.64658649 0.74830692 0.71856201]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 35: [[45610.707]]
# x_pred_input of day 36:
# [[[0.63737978 0.13761162 0.77614163 0.67899889 0.78726169 0.7565095 ]
#   [0.63204617 0.13811607 0.7681009  0.67040113 0.77927779 0.74849447]
#   [0.62671133 0.13957522 0.7591254  0.66284674 0.77156909 0.74069873]
#   [0.62154757 0.14185596 0.74918723 0.65640451 0.76383578 0.73311885]
#   [0.61645634 0.14479268 0.7383781  0.65105447 0.75610652 0.72574167]
#   [0.6115037  0.14828298 0.72706589 0.64658649 0.74830692 0.71856201]
#   [0.60667035 0.15223015 0.71521177 0.6430536  0.74040424 0.71157324]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 36: [[45281.883]]
# x_pred_input of day 37:
# [[[0.63204617 0.13811607 0.7681009  0.67040113 0.77927779 0.74849447]
#   [0.62671133 0.13957522 0.7591254  0.66284674 0.77156909 0.74069873]
#   [0.62154757 0.14185596 0.74918723 0.65640451 0.76383578 0.73311885]
#   [0.61645634 0.14479268 0.7383781  0.65105447 0.75610652 0.72574167]
#   [0.6115037  0.14828298 0.72706589 0.64658649 0.74830692 0.71856201]
#   [0.60667035 0.15223015 0.71521177 0.6430536  0.74040424 0.71157324]
#   [0.60196256 0.1565565  0.70327562 0.64014552 0.73245949 0.70476997]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 37: [[44962.65]]
# x_pred_input of day 38:
# [[[0.62671133 0.13957522 0.7591254  0.66284674 0.77156909 0.74069873]
#   [0.62154757 0.14185596 0.74918723 0.65640451 0.76383578 0.73311885]
#   [0.61645634 0.14479268 0.7383781  0.65105447 0.75610652 0.72574167]
#   [0.6115037  0.14828298 0.72706589 0.64658649 0.74830692 0.71856201]
#   [0.60667035 0.15223015 0.71521177 0.6430536  0.74040424 0.71157324]
#   [0.60196256 0.1565565  0.70327562 0.64014552 0.73245949 0.70476997]
#   [0.59739206 0.16120308 0.69120016 0.63790796 0.72452685 0.69814853]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 38: [[44652.824]]
# x_pred_input of day 39:
# [[[0.62154757 0.14185596 0.74918723 0.65640451 0.76383578 0.73311885]
#   [0.61645634 0.14479268 0.7383781  0.65105447 0.75610652 0.72574167]
#   [0.6115037  0.14828298 0.72706589 0.64658649 0.74830692 0.71856201]
#   [0.60667035 0.15223015 0.71521177 0.6430536  0.74040424 0.71157324]
#   [0.60196256 0.1565565  0.70327562 0.64014552 0.73245949 0.70476997]
#   [0.59739206 0.16120308 0.69120016 0.63790796 0.72452685 0.69814853]
#   [0.59295629 0.16611864 0.67926729 0.63613218 0.71661822 0.69170536]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 39: [[44356.25]]
# x_pred_input of day 40:
# [[[0.61645634 0.14479268 0.7383781  0.65105447 0.75610652 0.72574167]
#   [0.6115037  0.14828298 0.72706589 0.64658649 0.74830692 0.71856201]
#   [0.60667035 0.15223015 0.71521177 0.6430536  0.74040424 0.71157324]
#   [0.60196256 0.1565565  0.70327562 0.64014552 0.73245949 0.70476997]
#   [0.59739206 0.16120308 0.69120016 0.63790796 0.72452685 0.69814853]
#   [0.59295629 0.16611864 0.67926729 0.63613218 0.71661822 0.69170536]
#   [0.58871021 0.17128902 0.66786783 0.63451035 0.70877101 0.68544282]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 40: [[44076.086]]
# x_pred_input of day 41:
# [[[0.6115037  0.14828298 0.72706589 0.64658649 0.74830692 0.71856201]
#   [0.60667035 0.15223015 0.71521177 0.6430536  0.74040424 0.71157324]
#   [0.60196256 0.1565565  0.70327562 0.64014552 0.73245949 0.70476997]
#   [0.59739206 0.16120308 0.69120016 0.63790796 0.72452685 0.69814853]
#   [0.59295629 0.16611864 0.67926729 0.63613218 0.71661822 0.69170536]
#   [0.58871021 0.17128902 0.66786783 0.63451035 0.70877101 0.68544282]
#   [0.58469909 0.17672404 0.65728213 0.63280111 0.7010714  0.67936766]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# y_pred of day 41: [[43822.3]]
# x_pred_input of day 42:
# [[[0.60667035 0.15223015 0.71521177 0.6430536  0.74040424 0.71157324]
#   [0.60196256 0.1565565  0.70327562 0.64014552 0.73245949 0.70476997]
#   [0.59739206 0.16120308 0.69120016 0.63790796 0.72452685 0.69814853]
#   [0.59295629 0.16611864 0.67926729 0.63613218 0.71661822 0.69170536]
#   [0.58871021 0.17128902 0.66786783 0.63451035 0.70877101 0.68544282]
#   [0.58469909 0.17672404 0.65728213 0.63280111 0.7010714  0.67936766]
#   [0.58106563 0.1825037  0.6481617  0.63048625 0.69353287 0.67350055]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 42: [[43610.496]]
# x_pred_input of day 43:
# [[[0.60196256 0.1565565  0.70327562 0.64014552 0.73245949 0.70476997]
#   [0.59739206 0.16120308 0.69120016 0.63790796 0.72452685 0.69814853]
#   [0.59295629 0.16611864 0.67926729 0.63613218 0.71661822 0.69170536]
#   [0.58871021 0.17128902 0.66786783 0.63451035 0.70877101 0.68544282]
#   [0.58469909 0.17672404 0.65728213 0.63280111 0.7010714  0.67936766]
#   [0.58106563 0.1825037  0.6481617  0.63048625 0.69353287 0.67350055]
#   [0.57803321 0.18880456 0.64009969 0.62787673 0.68626014 0.66788297]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 43: [[43437.78]]
# x_pred_input of day 44:
# [[[0.59739206 0.16120308 0.69120016 0.63790796 0.72452685 0.69814853]
#   [0.59295629 0.16611864 0.67926729 0.63613218 0.71661822 0.69170536]
#   [0.58871021 0.17128902 0.66786783 0.63451035 0.70877101 0.68544282]
#   [0.58469909 0.17672404 0.65728213 0.63280111 0.7010714  0.67936766]
#   [0.58106563 0.1825037  0.6481617  0.63048625 0.69353287 0.67350055]
#   [0.57803321 0.18880456 0.64009969 0.62787673 0.68626014 0.66788297]
#   [0.57556044 0.1957372  0.63299029 0.62506706 0.6792627  0.66254823]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 44: [[43304.406]]
# x_pred_input of day 45:
# [[[0.59295629 0.16611864 0.67926729 0.63613218 0.71661822 0.69170536]
#   [0.58871021 0.17128902 0.66786783 0.63451035 0.70877101 0.68544282]
#   [0.58469909 0.17672404 0.65728213 0.63280111 0.7010714  0.67936766]
#   [0.58106563 0.1825037  0.6481617  0.63048625 0.69353287 0.67350055]
#   [0.57803321 0.18880456 0.64009969 0.62787673 0.68626014 0.66788297]
#   [0.57556044 0.1957372  0.63299029 0.62506706 0.6792627  0.66254823]
#   [0.5736509  0.20338292 0.62626676 0.62249018 0.67260351 0.65752683]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 45: [[43191.434]]
# x_pred_input of day 46:
# [[[0.58871021 0.17128902 0.66786783 0.63451035 0.70877101 0.68544282]
#   [0.58469909 0.17672404 0.65728213 0.63280111 0.7010714  0.67936766]
#   [0.58106563 0.1825037  0.6481617  0.63048625 0.69353287 0.67350055]
#   [0.57803321 0.18880456 0.64009969 0.62787673 0.68626014 0.66788297]
#   [0.57556044 0.1957372  0.63299029 0.62506706 0.6792627  0.66254823]
#   [0.5736509  0.20338292 0.62626676 0.62249018 0.67260351 0.65752683]
#   [0.57203347 0.21165428 0.61985995 0.62019069 0.66634268 0.65281872]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 46: [[43093.477]]
# x_pred_input of day 47:
# [[[0.58469909 0.17672404 0.65728213 0.63280111 0.7010714  0.67936766]
#   [0.58106563 0.1825037  0.6481617  0.63048625 0.69353287 0.67350055]
#   [0.57803321 0.18880456 0.64009969 0.62787673 0.68626014 0.66788297]
#   [0.57556044 0.1957372  0.63299029 0.62506706 0.6792627  0.66254823]
#   [0.5736509  0.20338292 0.62626676 0.62249018 0.67260351 0.65752683]
#   [0.57203347 0.21165428 0.61985995 0.62019069 0.66634268 0.65281872]
#   [0.57063101 0.22043497 0.61370432 0.61820141 0.66051184 0.64841598]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 47: [[43005.09]]
# x_pred_input of day 48:
# [[[0.58106563 0.1825037  0.6481617  0.63048625 0.69353287 0.67350055]
#   [0.57803321 0.18880456 0.64009969 0.62787673 0.68626014 0.66788297]
#   [0.57556044 0.1957372  0.63299029 0.62506706 0.6792627  0.66254823]
#   [0.5736509  0.20338292 0.62626676 0.62249018 0.67260351 0.65752683]
#   [0.57203347 0.21165428 0.61985995 0.62019069 0.66634268 0.65281872]
#   [0.57063101 0.22043497 0.61370432 0.61820141 0.66051184 0.64841598]
#   [0.56936557 0.22958691 0.60752157 0.61670154 0.65519233 0.6443035 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 48: [[42919.824]]
# x_pred_input of day 49:
# [[[0.57803321 0.18880456 0.64009969 0.62787673 0.68626014 0.66788297]
#   [0.57556044 0.1957372  0.63299029 0.62506706 0.6792627  0.66254823]
#   [0.5736509  0.20338292 0.62626676 0.62249018 0.67260351 0.65752683]
#   [0.57203347 0.21165428 0.61985995 0.62019069 0.66634268 0.65281872]
#   [0.57063101 0.22043497 0.61370432 0.61820141 0.66051184 0.64841598]
#   [0.56936557 0.22958691 0.60752157 0.61670154 0.65519233 0.6443035 ]
#   [0.56814482 0.23894899 0.601398   0.61560967 0.65029946 0.64045819]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 49: [[42837.348]]
# x_pred_input of day 50:
# [[[0.57556044 0.1957372  0.63299029 0.62506706 0.6792627  0.66254823]
#   [0.5736509  0.20338292 0.62626676 0.62249018 0.67260351 0.65752683]
#   [0.57203347 0.21165428 0.61985995 0.62019069 0.66634268 0.65281872]
#   [0.57063101 0.22043497 0.61370432 0.61820141 0.66051184 0.64841598]
#   [0.56936557 0.22958691 0.60752157 0.61670154 0.65519233 0.6443035 ]
#   [0.56814482 0.23894899 0.601398   0.61560967 0.65029946 0.64045819]
#   [0.566964   0.2483901  0.59530374 0.61492754 0.64580076 0.63685868]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 50: [[42752.125]]
# x_pred_input of day 51:
# [[[0.5736509  0.20338292 0.62626676 0.62249018 0.67260351 0.65752683]
#   [0.57203347 0.21165428 0.61985995 0.62019069 0.66634268 0.65281872]
#   [0.57063101 0.22043497 0.61370432 0.61820141 0.66051184 0.64841598]
#   [0.56936557 0.22958691 0.60752157 0.61670154 0.65519233 0.6443035 ]
#   [0.56814482 0.23894899 0.601398   0.61560967 0.65029946 0.64045819]
#   [0.566964   0.2483901  0.59530374 0.61492754 0.64580076 0.63685868]
#   [0.56574386 0.25776478 0.58933324 0.61455751 0.6415853  0.63347756]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 51: [[42669.746]]
# x_pred_input of day 52:
# [[[0.57203347 0.21165428 0.61985995 0.62019069 0.66634268 0.65281872]
#   [0.57063101 0.22043497 0.61370432 0.61820141 0.66051184 0.64841598]
#   [0.56936557 0.22958691 0.60752157 0.61670154 0.65519233 0.6443035 ]
#   [0.56814482 0.23894899 0.601398   0.61560967 0.65029946 0.64045819]
#   [0.566964   0.2483901  0.59530374 0.61492754 0.64580076 0.63685868]
#   [0.56574386 0.25776478 0.58933324 0.61455751 0.6415853  0.63347756]
#   [0.56456444 0.26700207 0.58354307 0.61443792 0.63762912 0.63029817]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 52: [[42589.98]]
# x_pred_input of day 53:
# [[[0.57063101 0.22043497 0.61370432 0.61820141 0.66051184 0.64841598]
#   [0.56936557 0.22958691 0.60752157 0.61670154 0.65519233 0.6443035 ]
#   [0.56814482 0.23894899 0.601398   0.61560967 0.65029946 0.64045819]
#   [0.566964   0.2483901  0.59530374 0.61492754 0.64580076 0.63685868]
#   [0.56574386 0.25776478 0.58933324 0.61455751 0.6415853  0.63347756]
#   [0.56456444 0.26700207 0.58354307 0.61443792 0.63762912 0.63029817]
#   [0.56342243 0.27604617 0.57794799 0.61453661 0.63390854 0.62730512]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 53: [[42512.902]]
# x_pred_input of day 54:
# [[[0.56936557 0.22958691 0.60752157 0.61670154 0.65519233 0.6443035 ]
#   [0.56814482 0.23894899 0.601398   0.61560967 0.65029946 0.64045819]
#   [0.566964   0.2483901  0.59530374 0.61492754 0.64580076 0.63685868]
#   [0.56574386 0.25776478 0.58933324 0.61455751 0.6415853  0.63347756]
#   [0.56456444 0.26700207 0.58354307 0.61443792 0.63762912 0.63029817]
#   [0.56342243 0.27604617 0.57794799 0.61453661 0.63390854 0.62730512]
#   [0.56231889 0.28485616 0.57258942 0.61480125 0.6303648  0.62448459]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 54: [[42438.8]]
# x_pred_input of day 55:
# [[[0.56814482 0.23894899 0.601398   0.61560967 0.65029946 0.64045819]
#   [0.566964   0.2483901  0.59530374 0.61492754 0.64580076 0.63685868]
#   [0.56574386 0.25776478 0.58933324 0.61455751 0.6415853  0.63347756]
#   [0.56456444 0.26700207 0.58354307 0.61443792 0.63762912 0.63029817]
#   [0.56342243 0.27604617 0.57794799 0.61453661 0.63390854 0.62730512]
#   [0.56231889 0.28485616 0.57258942 0.61480125 0.6303648  0.62448459]
#   [0.56125798 0.2934048  0.56749432 0.61518958 0.62700517 0.62182449]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 55: [[42364.68]]
# x_pred_input of day 56:
# [[[0.566964   0.2483901  0.59530374 0.61492754 0.64580076 0.63685868]
#   [0.56574386 0.25776478 0.58933324 0.61455751 0.6415853  0.63347756]
#   [0.56456444 0.26700207 0.58354307 0.61443792 0.63762912 0.63029817]
#   [0.56342243 0.27604617 0.57794799 0.61453661 0.63390854 0.62730512]
#   [0.56231889 0.28485616 0.57258942 0.61480125 0.6303648  0.62448459]
#   [0.56125798 0.2934048  0.56749432 0.61518958 0.62700517 0.62182449]
#   [0.56019678 0.30165112 0.56270152 0.61564276 0.62381561 0.61930951]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 56: [[42292.027]]
# x_pred_input of day 57:
# [[[0.56574386 0.25776478 0.58933324 0.61455751 0.6415853  0.63347756]
#   [0.56456444 0.26700207 0.58354307 0.61443792 0.63762912 0.63029817]
#   [0.56342243 0.27604617 0.57794799 0.61453661 0.63390854 0.62730512]
#   [0.56231889 0.28485616 0.57258942 0.61480125 0.6303648  0.62448459]
#   [0.56125798 0.2934048  0.56749432 0.61518958 0.62700517 0.62182449]
#   [0.56019678 0.30165112 0.56270152 0.61564276 0.62381561 0.61930951]
#   [0.55915661 0.30957769 0.55825244 0.61610067 0.62080347 0.61692798]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 57: [[42219.88]]
# x_pred_input of day 58:
# [[[0.56456444 0.26700207 0.58354307 0.61443792 0.63762912 0.63029817]
#   [0.56342243 0.27604617 0.57794799 0.61453661 0.63390854 0.62730512]
#   [0.56231889 0.28485616 0.57258942 0.61480125 0.6303648  0.62448459]
#   [0.56125798 0.2934048  0.56749432 0.61518958 0.62700517 0.62182449]
#   [0.56019678 0.30165112 0.56270152 0.61564276 0.62381561 0.61930951]
#   [0.55915661 0.30957769 0.55825244 0.61610067 0.62080347 0.61692798]
#   [0.55812366 0.31716722 0.55419328 0.61649465 0.6179691  0.61466793]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 58: [[42148.73]]
# x_pred_input of day 59:
# [[[0.56342243 0.27604617 0.57794799 0.61453661 0.63390854 0.62730512]
#   [0.56231889 0.28485616 0.57258942 0.61480125 0.6303648  0.62448459]
#   [0.56125798 0.2934048  0.56749432 0.61518958 0.62700517 0.62182449]
#   [0.56019678 0.30165112 0.56270152 0.61564276 0.62381561 0.61930951]
#   [0.55915661 0.30957769 0.55825244 0.61610067 0.62080347 0.61692798]
#   [0.55812366 0.31716722 0.55419328 0.61649465 0.6179691  0.61466793]
#   [0.55710502 0.32441375 0.55057792 0.61674816 0.61530604 0.61251923]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 59: [[42080.37]]
# x_pred_input of day 60:
# [[[0.56231889 0.28485616 0.57258942 0.61480125 0.6303648  0.62448459]
#   [0.56125798 0.2934048  0.56749432 0.61518958 0.62700517 0.62182449]
#   [0.56019678 0.30165112 0.56270152 0.61564276 0.62381561 0.61930951]
#   [0.55915661 0.30957769 0.55825244 0.61610067 0.62080347 0.61692798]
#   [0.55812366 0.31716722 0.55419328 0.61649465 0.6179691  0.61466793]
#   [0.55710502 0.32441375 0.55057792 0.61674816 0.61530604 0.61251923]
#   [0.55612632 0.33133003 0.54744601 0.61679811 0.61281292 0.61047537]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 60: [[42015.99]]
# x_pred_input of day 61:
# [[[0.56125798 0.2934048  0.56749432 0.61518958 0.62700517 0.62182449]
#   [0.56019678 0.30165112 0.56270152 0.61564276 0.62381561 0.61930951]
#   [0.55915661 0.30957769 0.55825244 0.61610067 0.62080347 0.61692798]
#   [0.55812366 0.31716722 0.55419328 0.61649465 0.6179691  0.61466793]
#   [0.55710502 0.32441375 0.55057792 0.61674816 0.61530604 0.61251923]
#   [0.55612632 0.33133003 0.54744601 0.61679811 0.61281292 0.61047537]
#   [0.55520455 0.33793878 0.54481793 0.61660081 0.61048637 0.60853216]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 61: [[41957.598]]
# x_pred_input of day 62:
# [[[0.56019678 0.30165112 0.56270152 0.61564276 0.62381561 0.61930951]
#   [0.55915661 0.30957769 0.55825244 0.61610067 0.62080347 0.61692798]
#   [0.55812366 0.31716722 0.55419328 0.61649465 0.6179691  0.61466793]
#   [0.55710502 0.32441375 0.55057792 0.61674816 0.61530604 0.61251923]
#   [0.55612632 0.33133003 0.54744601 0.61679811 0.61281292 0.61047537]
#   [0.55520455 0.33793878 0.54481793 0.61660081 0.61048637 0.60853216]
#   [0.55436856 0.34427653 0.54265679 0.61616705 0.60832502 0.60668877]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 62: [[41905.47]]
# x_pred_input of day 63:
# [[[0.55915661 0.30957769 0.55825244 0.61610067 0.62080347 0.61692798]
#   [0.55812366 0.31716722 0.55419328 0.61649465 0.6179691  0.61466793]
#   [0.55710502 0.32441375 0.55057792 0.61674816 0.61530604 0.61251923]
#   [0.55612632 0.33133003 0.54744601 0.61679811 0.61281292 0.61047537]
#   [0.55520455 0.33793878 0.54481793 0.61660081 0.61048637 0.60853216]
#   [0.55436856 0.34427653 0.54265679 0.61616705 0.60832502 0.60668877]
#   [0.55362223 0.35037703 0.54084867 0.61557356 0.60632737 0.60494483]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 63: [[41858.297]]
# x_pred_input of day 64:
# [[[0.55812366 0.31716722 0.55419328 0.61649465 0.6179691  0.61466793]
#   [0.55710502 0.32441375 0.55057792 0.61674816 0.61530604 0.61251923]
#   [0.55612632 0.33133003 0.54744601 0.61679811 0.61281292 0.61047537]
#   [0.55520455 0.33793878 0.54481793 0.61660081 0.61048637 0.60853216]
#   [0.55436856 0.34427653 0.54265679 0.61616705 0.60832502 0.60668877]
#   [0.55362223 0.35037703 0.54084867 0.61557356 0.60632737 0.60494483]
#   [0.55294687 0.35625956 0.53928263 0.61489604 0.60449069 0.6032981 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 64: [[41813.668]]
# x_pred_input of day 65:
# [[[0.55710502 0.32441375 0.55057792 0.61674816 0.61530604 0.61251923]
#   [0.55612632 0.33133003 0.54744601 0.61679811 0.61281292 0.61047537]
#   [0.55520455 0.33793878 0.54481793 0.61660081 0.61048637 0.60853216]
#   [0.55436856 0.34427653 0.54265679 0.61616705 0.60832502 0.60668877]
#   [0.55362223 0.35037703 0.54084867 0.61557356 0.60632737 0.60494483]
#   [0.55294687 0.35625956 0.53928263 0.61489604 0.60449069 0.6032981 ]
#   [0.55230791 0.36192349 0.53784567 0.61420843 0.60281091 0.60174305]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 65: [[41768.97]]
# x_pred_input of day 66:
# [[[0.55612632 0.33133003 0.54744601 0.61679811 0.61281292 0.61047537]
#   [0.55520455 0.33793878 0.54481793 0.61660081 0.61048637 0.60853216]
#   [0.55436856 0.34427653 0.54265679 0.61616705 0.60832502 0.60668877]
#   [0.55362223 0.35037703 0.54084867 0.61557356 0.60632737 0.60494483]
#   [0.55294687 0.35625956 0.53928263 0.61489604 0.60449069 0.6032981 ]
#   [0.55230791 0.36192349 0.53784567 0.61420843 0.60281091 0.60174305]
#   [0.55166795 0.36735107 0.53648879 0.61353559 0.60128015 0.60027083]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 66: [[41723.574]]
# x_pred_input of day 67:
# [[[0.55520455 0.33793878 0.54481793 0.61660081 0.61048637 0.60853216]
#   [0.55436856 0.34427653 0.54265679 0.61616705 0.60832502 0.60668877]
#   [0.55362223 0.35037703 0.54084867 0.61557356 0.60632737 0.60494483]
#   [0.55294687 0.35625956 0.53928263 0.61489604 0.60449069 0.6032981 ]
#   [0.55230791 0.36192349 0.53784567 0.61420843 0.60281091 0.60174305]
#   [0.55166795 0.36735107 0.53648879 0.61353559 0.60128015 0.60027083]
#   [0.55101804 0.37252638 0.53517791 0.61289246 0.59988829 0.59887255]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 67: [[41677.637]]
# x_pred_input of day 68:
# [[[0.55436856 0.34427653 0.54265679 0.61616705 0.60832502 0.60668877]
#   [0.55362223 0.35037703 0.54084867 0.61557356 0.60632737 0.60494483]
#   [0.55294687 0.35625956 0.53928263 0.61489604 0.60449069 0.6032981 ]
#   [0.55230791 0.36192349 0.53784567 0.61420843 0.60281091 0.60174305]
#   [0.55166795 0.36735107 0.53648879 0.61353559 0.60128015 0.60027083]
#   [0.55101804 0.37252638 0.53517791 0.61289246 0.59988829 0.59887255]
#   [0.55036035 0.37744095 0.53389334 0.61228603 0.5986194  0.59754037]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 68: [[41632.24]]
# x_pred_input of day 69:
# [[[0.55362223 0.35037703 0.54084867 0.61557356 0.60632737 0.60494483]
#   [0.55294687 0.35625956 0.53928263 0.61489604 0.60449069 0.6032981 ]
#   [0.55230791 0.36192349 0.53784567 0.61420843 0.60281091 0.60174305]
#   [0.55166795 0.36735107 0.53648879 0.61353559 0.60128015 0.60027083]
#   [0.55101804 0.37252638 0.53517791 0.61289246 0.59988829 0.59887255]
#   [0.55036035 0.37744095 0.53389334 0.61228603 0.5986194  0.59754037]
#   [0.54971037 0.38209931 0.53263345 0.61171411 0.59744897 0.59626878]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 69: [[41588.273]]
# x_pred_input of day 70:
# [[[0.55294687 0.35625956 0.53928263 0.61489604 0.60449069 0.6032981 ]
#   [0.55230791 0.36192349 0.53784567 0.61420843 0.60281091 0.60174305]
#   [0.55166795 0.36735107 0.53648879 0.61353559 0.60128015 0.60027083]
#   [0.55101804 0.37252638 0.53517791 0.61289246 0.59988829 0.59887255]
#   [0.55036035 0.37744095 0.53389334 0.61228603 0.5986194  0.59754037]
#   [0.54971037 0.38209931 0.53263345 0.61171411 0.59744897 0.59626878]
#   [0.54908093 0.38651468 0.53139588 0.6111773  0.59635471 0.5950541 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 70: [[41546.31]]
# x_pred_input of day 71:
# [[[0.55230791 0.36192349 0.53784567 0.61420843 0.60281091 0.60174305]
#   [0.55166795 0.36735107 0.53648879 0.61353559 0.60128015 0.60027083]
#   [0.55101804 0.37252638 0.53517791 0.61289246 0.59988829 0.59887255]
#   [0.55036035 0.37744095 0.53389334 0.61228603 0.5986194  0.59754037]
#   [0.54971037 0.38209931 0.53263345 0.61171411 0.59744897 0.59626878]
#   [0.54908093 0.38651468 0.53139588 0.6111773  0.59635471 0.5950541 ]
#   [0.54848011 0.39070445 0.53019694 0.61066405 0.59531454 0.59389384]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 71: [[41507.36]]
# x_pred_input of day 72:
# [[[0.55166795 0.36735107 0.53648879 0.61353559 0.60128015 0.60027083]
#   [0.55101804 0.37252638 0.53517791 0.61289246 0.59988829 0.59887255]
#   [0.55036035 0.37744095 0.53389334 0.61228603 0.5986194  0.59754037]
#   [0.54971037 0.38209931 0.53263345 0.61171411 0.59744897 0.59626878]
#   [0.54908093 0.38651468 0.53139588 0.6111773  0.59635471 0.5950541 ]
#   [0.54848011 0.39070445 0.53019694 0.61066405 0.59531454 0.59389384]
#   [0.54792247 0.39469251 0.52903336 0.61017845 0.59431816 0.59278721]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 72: [[41471.57]]
# x_pred_input of day 73:
# [[[0.55101804 0.37252638 0.53517791 0.61289246 0.59988829 0.59887255]
#   [0.55036035 0.37744095 0.53389334 0.61228603 0.5986194  0.59754037]
#   [0.54971037 0.38209931 0.53263345 0.61171411 0.59744897 0.59626878]
#   [0.54908093 0.38651468 0.53139588 0.6111773  0.59635471 0.5950541 ]
#   [0.54848011 0.39070445 0.53019694 0.61066405 0.59531454 0.59389384]
#   [0.54792247 0.39469251 0.52903336 0.61017845 0.59431816 0.59278721]
#   [0.54741008 0.39850094 0.52790243 0.60972455 0.59335856 0.59173372]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 73: [[41439.02]]
# x_pred_input of day 74:
# [[[0.55036035 0.37744095 0.53389334 0.61228603 0.5986194  0.59754037]
#   [0.54971037 0.38209931 0.53263345 0.61171411 0.59744897 0.59626878]
#   [0.54908093 0.38651468 0.53139588 0.6111773  0.59635471 0.5950541 ]
#   [0.54848011 0.39070445 0.53019694 0.61066405 0.59531454 0.59389384]
#   [0.54792247 0.39469251 0.52903336 0.61017845 0.59431816 0.59278721]
#   [0.54741008 0.39850094 0.52790243 0.60972455 0.59335856 0.59173372]
#   [0.54694405 0.4021497  0.52680104 0.60930688 0.592432   0.59073304]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 74: [[41409.117]]
# x_pred_input of day 75:
# [[[0.54971037 0.38209931 0.53263345 0.61171411 0.59744897 0.59626878]
#   [0.54908093 0.38651468 0.53139588 0.6111773  0.59635471 0.5950541 ]
#   [0.54848011 0.39070445 0.53019694 0.61066405 0.59531454 0.59389384]
#   [0.54792247 0.39469251 0.52903336 0.61017845 0.59431816 0.59278721]
#   [0.54741008 0.39850094 0.52790243 0.60972455 0.59335856 0.59173372]
#   [0.54694405 0.4021497  0.52680104 0.60930688 0.592432   0.59073304]
#   [0.54651593 0.40565178 0.52572578 0.6089289  0.59153819 0.589784  ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# y_pred of day 75: [[41381.312]]
# x_pred_input of day 76:
# [[[0.54908093 0.38651468 0.53139588 0.6111773  0.59635471 0.5950541 ]
#   [0.54848011 0.39070445 0.53019694 0.61066405 0.59531454 0.59389384]
#   [0.54792247 0.39469251 0.52903336 0.61017845 0.59431816 0.59278721]
#   [0.54741008 0.39850094 0.52790243 0.60972455 0.59335856 0.59173372]
#   [0.54694405 0.4021497  0.52680104 0.60930688 0.592432   0.59073304]
#   [0.54651593 0.40565178 0.52572578 0.6089289  0.59153819 0.589784  ]
#   [0.54611785 0.40901487 0.52468475 0.6085845  0.59067673 0.58888475]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# y_pred of day 76: [[41355.426]]
# x_pred_input of day 77:
# [[[0.54848011 0.39070445 0.53019694 0.61066405 0.59531454 0.59389384]
#   [0.54792247 0.39469251 0.52903336 0.61017845 0.59431816 0.59278721]
#   [0.54741008 0.39850094 0.52790243 0.60972455 0.59335856 0.59173372]
#   [0.54694405 0.4021497  0.52680104 0.60930688 0.592432   0.59073304]
#   [0.54651593 0.40565178 0.52572578 0.6089289  0.59153819 0.589784  ]
#   [0.54611785 0.40901487 0.52468475 0.6085845  0.59067673 0.58888475]
#   [0.54574723 0.41224523 0.52368171 0.60826997 0.58985038 0.58803335]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# y_pred of day 77: [[41331.105]]
# x_pred_input of day 78:
# [[[0.54792247 0.39469251 0.52903336 0.61017845 0.59431816 0.59278721]
#   [0.54741008 0.39850094 0.52790243 0.60972455 0.59335856 0.59173372]
#   [0.54694405 0.4021497  0.52680104 0.60930688 0.592432   0.59073304]
#   [0.54651593 0.40565178 0.52572578 0.6089289  0.59153819 0.589784  ]
#   [0.54611785 0.40901487 0.52468475 0.6085845  0.59067673 0.58888475]
#   [0.54574723 0.41224523 0.52368171 0.60826997 0.58985038 0.58803335]
#   [0.54539904 0.41534661 0.52272481 0.60797746 0.58905837 0.58722753]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 78: [[41308.434]]
# x_pred_input of day 79:
# [[[0.54741008 0.39850094 0.52790243 0.60972455 0.59335856 0.59173372]
#   [0.54694405 0.4021497  0.52680104 0.60930688 0.592432   0.59073304]
#   [0.54651593 0.40565178 0.52572578 0.6089289  0.59153819 0.589784  ]
#   [0.54611785 0.40901487 0.52468475 0.6085845  0.59067673 0.58888475]
#   [0.54574723 0.41224523 0.52368171 0.60826997 0.58985038 0.58803335]
#   [0.54539904 0.41534661 0.52272481 0.60797746 0.58905837 0.58722753]
#   [0.54507444 0.41832405 0.52182087 0.60770002 0.58830015 0.58646535]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 79: [[41287.18]]
# x_pred_input of day 80:
# [[[0.54694405 0.4021497  0.52680104 0.60930688 0.592432   0.59073304]
#   [0.54651593 0.40565178 0.52572578 0.6089289  0.59153819 0.589784  ]
#   [0.54611785 0.40901487 0.52468475 0.6085845  0.59067673 0.58888475]
#   [0.54574723 0.41224523 0.52368171 0.60826997 0.58985038 0.58803335]
#   [0.54539904 0.41534661 0.52272481 0.60797746 0.58905837 0.58722753]
#   [0.54507444 0.41832405 0.52182087 0.60770002 0.58830015 0.58646535]
#   [0.54477015 0.42118116 0.52097079 0.60743438 0.58757495 0.58574472]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 80: [[41267.31]]
# x_pred_input of day 81:
# [[[0.54651593 0.40565178 0.52572578 0.6089289  0.59153819 0.589784  ]
#   [0.54611785 0.40901487 0.52468475 0.6085845  0.59067673 0.58888475]
#   [0.54574723 0.41224523 0.52368171 0.60826997 0.58985038 0.58803335]
#   [0.54539904 0.41534661 0.52272481 0.60797746 0.58905837 0.58722753]
#   [0.54507444 0.41832405 0.52182087 0.60770002 0.58830015 0.58646535]
#   [0.54477015 0.42118116 0.52097079 0.60743438 0.58757495 0.58574472]
#   [0.54448565 0.42392188 0.5201709  0.60718074 0.58688184 0.58506372]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 81: [[41248.61]]
# x_pred_input of day 82:
# [[[0.54611785 0.40901487 0.52468475 0.6085845  0.59067673 0.58888475]
#   [0.54574723 0.41224523 0.52368171 0.60826997 0.58985038 0.58803335]
#   [0.54539904 0.41534661 0.52272481 0.60797746 0.58905837 0.58722753]
#   [0.54507444 0.41832405 0.52182087 0.60770002 0.58830015 0.58646535]
#   [0.54477015 0.42118116 0.52097079 0.60743438 0.58757495 0.58574472]
#   [0.54448565 0.42392188 0.5201709  0.60718074 0.58688184 0.58506372]
#   [0.54421793 0.42654903 0.51940979 0.60694479 0.58622152 0.58442027]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 82: [[41230.59]]
# x_pred_input of day 83:
# [[[0.54574723 0.41224523 0.52368171 0.60826997 0.58985038 0.58803335]
#   [0.54539904 0.41534661 0.52272481 0.60797746 0.58905837 0.58722753]
#   [0.54507444 0.41832405 0.52182087 0.60770002 0.58830015 0.58646535]
#   [0.54477015 0.42118116 0.52097079 0.60743438 0.58757495 0.58574472]
#   [0.54448565 0.42392188 0.5201709  0.60718074 0.58688184 0.58506372]
#   [0.54421793 0.42654903 0.51940979 0.60694479 0.58622152 0.58442027]
#   [0.54395995 0.42906239 0.51867418 0.60673324 0.58559352 0.5838118 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 83: [[41212.81]]
# x_pred_input of day 84:
# [[[0.54539904 0.41534661 0.52272481 0.60797746 0.58905837 0.58722753]
#   [0.54507444 0.41832405 0.52182087 0.60770002 0.58830015 0.58646535]
#   [0.54477015 0.42118116 0.52097079 0.60743438 0.58757495 0.58574472]
#   [0.54448565 0.42392188 0.5201709  0.60718074 0.58688184 0.58506372]
#   [0.54421793 0.42654903 0.51940979 0.60694479 0.58622152 0.58442027]
#   [0.54395995 0.42906239 0.51867418 0.60673324 0.58559352 0.5838118 ]
#   [0.54370537 0.43145976 0.51795397 0.60655039 0.58499769 0.58323531]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 84: [[41194.723]]
# x_pred_input of day 85:
# [[[0.54507444 0.41832405 0.52182087 0.60770002 0.58830015 0.58646535]
#   [0.54477015 0.42118116 0.52097079 0.60743438 0.58757495 0.58574472]
#   [0.54448565 0.42392188 0.5201709  0.60718074 0.58688184 0.58506372]
#   [0.54421793 0.42654903 0.51940979 0.60694479 0.58622152 0.58442027]
#   [0.54395995 0.42906239 0.51867418 0.60673324 0.58559352 0.5838118 ]
#   [0.54370537 0.43145976 0.51795397 0.60655039 0.58499769 0.58323531]
#   [0.54344644 0.43373663 0.51724672 0.60639459 0.58443325 0.58268732]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 85: [[41176.14]]
# x_pred_input of day 86:
# [[[0.54477015 0.42118116 0.52097079 0.60743438 0.58757495 0.58574472]
#   [0.54448565 0.42392188 0.5201709  0.60718074 0.58688184 0.58506372]
#   [0.54421793 0.42654903 0.51940979 0.60694479 0.58622152 0.58442027]
#   [0.54395995 0.42906239 0.51867418 0.60673324 0.58559352 0.5838118 ]
#   [0.54370537 0.43145976 0.51795397 0.60655039 0.58499769 0.58323531]
#   [0.54344644 0.43373663 0.51724672 0.60639459 0.58443325 0.58268732]
#   [0.5431804  0.4358894  0.51655915 0.60625727 0.58389827 0.58216439]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 86: [[41157.105]]
# x_pred_input of day 87:
# [[[0.54448565 0.42392188 0.5201709  0.60718074 0.58688184 0.58506372]
#   [0.54421793 0.42654903 0.51940979 0.60694479 0.58622152 0.58442027]
#   [0.54395995 0.42906239 0.51867418 0.60673324 0.58559352 0.5838118 ]
#   [0.54370537 0.43145976 0.51795397 0.60655039 0.58499769 0.58323531]
#   [0.54344644 0.43373663 0.51724672 0.60639459 0.58443325 0.58268732]
#   [0.5431804  0.4358894  0.51655915 0.60625727 0.58389827 0.58216439]
#   [0.54290787 0.43791699 0.515901   0.60612742 0.58339011 0.58166347]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 87: [[41137.85]]
# x_pred_input of day 88:
# [[[0.54421793 0.42654903 0.51940979 0.60694479 0.58622152 0.58442027]
#   [0.54395995 0.42906239 0.51867418 0.60673324 0.58559352 0.5838118 ]
#   [0.54370537 0.43145976 0.51795397 0.60655039 0.58499769 0.58323531]
#   [0.54344644 0.43373663 0.51724672 0.60639459 0.58443325 0.58268732]
#   [0.5431804  0.4358894  0.51655915 0.60625727 0.58389827 0.58216439]
#   [0.54290787 0.43791699 0.515901   0.60612742 0.58339011 0.58166347]
#   [0.54263221 0.43982173 0.51528222 0.60599387 0.58290511 0.58118214]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 88: [[41118.758]]
# x_pred_input of day 89:
# [[[0.54395995 0.42906239 0.51867418 0.60673324 0.58559352 0.5838118 ]
#   [0.54370537 0.43145976 0.51795397 0.60655039 0.58499769 0.58323531]
#   [0.54344644 0.43373663 0.51724672 0.60639459 0.58443325 0.58268732]
#   [0.5431804  0.4358894  0.51655915 0.60625727 0.58389827 0.58216439]
#   [0.54290787 0.43791699 0.515901   0.60612742 0.58339011 0.58166347]
#   [0.54263221 0.43982173 0.51528222 0.60599387 0.58290511 0.58118214]
#   [0.54235884 0.44160974 0.51470903 0.60584872 0.58243966 0.58071878]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 89: [[41100.125]]
# x_pred_input of day 90:
# [[[0.54370537 0.43145976 0.51795397 0.60655039 0.58499769 0.58323531]
#   [0.54344644 0.43373663 0.51724672 0.60639459 0.58443325 0.58268732]
#   [0.5431804  0.4358894  0.51655915 0.60625727 0.58389827 0.58216439]
#   [0.54290787 0.43791699 0.515901   0.60612742 0.58339011 0.58166347]
#   [0.54263221 0.43982173 0.51528222 0.60599387 0.58290511 0.58118214]
#   [0.54235884 0.44160974 0.51470903 0.60584872 0.58243966 0.58071878]
#   [0.54209207 0.44328939 0.51418402 0.60568741 0.58199108 0.58027234]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 90: [[41082.07]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#              Close        MACD  Bollinger_Upper  Bollinger_Lower  \
# 0      6556.100098    0.000000     41082.070312     41082.070312
# 1      6502.589844   -4.268624     41082.070312     41082.070312
# 2      6576.689941   -1.653224     41082.070312     41082.070312
# 3      6622.479980    4.067486     41082.070312     41082.070312
# 4      6588.310059    5.777365     41082.070312     41082.070312
# ...            ...         ...              ...              ...
# 2155  41157.105469 -427.830821     41686.723462     41055.503100
# 2156  41137.851562 -407.712177     41641.138110     41047.109937
# 2157  41118.757812 -388.826562     41598.911833     41037.988167
# 2158  41100.125000 -371.085447     41560.234501     41027.850655
# 2159  41082.070312 -354.397079     41525.097165     41016.564163
#
#               MA26         EMA20
# 0     41082.070312   6556.100098
# 1     41082.070312   6551.003883
# 2     41082.070312   6553.450175
# 3     41082.070312   6560.024442
# 4     41082.070312   6562.718310
# ...            ...           ...
# 2155  41478.839994  41467.518992
# 2156  41447.311298  41436.122094
# 2157  41417.053185  41405.896925
# 2158  41387.892728  41376.775789
# 2159  41359.754357  41348.708601
#
# [2160 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
df_forecast_90 = df_forecast_unscale.copy()
df_forecast_90.index = pd.to_datetime(df_forecast_90.index)

df_forecast_60 = df_forecast_90.head(60)
df_forecast_30 = df_forecast_90.head(30)


# Label the forecasted data
forecast_30_label = f"Forecast next 30 days - " + df_forecast_30.index[-1].strftime("%Y-%m-%d")
forecast_60_label = f"Forecast next 60 days - " + df_forecast_60.index[-1].strftime("%Y-%m-%d")
forecast_90_label = f"Forecast next 90 days - " + df_forecast_90.index[-1].strftime("%Y-%m-%d")

# Add last day of original data to the forecasted data
df_forecast_30 = pd.concat([df_filtered.tail(1), df_forecast_30])
df_forecast_30.index = pd.date_range(start=df_filtered.index.max(), periods=len(df_forecast_30))

# Plot the overall with connection to forecast
plt.figure(figsize=(15, 7))
plt.plot(df_filtered['Close'], label='Train')
plt.plot(df_test.index, df_test['Y_test'], label='Actual Test')
plt.plot(df_test.index, df_test['Y_test_pred'], label='Forecast Test')
plt.plot(df_forecast_90.index, df_forecast_90['Close'], label=forecast_90_label)
plt.plot(df_forecast_60.index, df_forecast_60['Close'], label=forecast_60_label)
plt.plot(df_forecast_30.index, df_forecast_30['Close'], label=forecast_30_label)
plt.title('BTC/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  2009.3612987943422
# MAPE:  2.622838478938733
# SMAPE:  2.6585445859159837
