# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../../Dataset/ETH-USD.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 1  2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2  2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 3  2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 4  2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#        Volume
# 0  1868519936
# 1  1894419968
# 2  1699369984
# 3  1697939968
# 4  1898489984

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#                 Volume
# Date
# 2018-03-01  1868519936
# 2018-03-02  1894419968
# 2018-03-03  1699369984
# 2018-03-04  1697939968
# 2018-03-05  1898489984

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('ETH/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (2070, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.80)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1656, 6) (414, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1649, 7, 6) (1649,)
# (407, 7, 6) (407,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1649, 7, 6) (1649,)
# (407, 7, 6) (407,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
# model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
# model.add(Dense(1))
model.add(SimpleRNN(n_neurons, return_sequences=True,
          input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(SimpleRNN(n_neurons, return_sequences=True))
model.add(SimpleRNN(n_neurons))
model.add(Dense(1))


# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0700 - val_loss: 0.0047
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 8.4218e-04
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4934e-04 - val_loss: 6.0397e-04
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2935e-04 - val_loss: 5.1661e-04
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2635e-04 - val_loss: 4.9757e-04
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9181e-04 - val_loss: 4.6395e-04
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7537e-04 - val_loss: 4.6164e-04
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7035e-04 - val_loss: 0.0014
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 9.9176e-04
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2403e-04 - val_loss: 0.0015
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - val_loss: 4.4626e-04
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7861e-04 - val_loss: 5.0584e-04
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3325e-04 - val_loss: 4.9358e-04
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3681e-04 - val_loss: 4.4134e-04
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6922e-04 - val_loss: 0.0016
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9082e-04 - val_loss: 0.0014
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6530e-04 - val_loss: 6.2099e-04
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4997e-04 - val_loss: 4.8657e-04
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8539e-04 - val_loss: 3.6921e-04
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6627e-04 - val_loss: 3.8847e-04
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8008e-04 - val_loss: 6.2693e-04
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2258e-04 - val_loss: 3.8841e-04
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4511e-04 - val_loss: 3.5743e-04
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6082e-04 - val_loss: 0.0026
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1686e-04 - val_loss: 3.3281e-04
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9207e-04 - val_loss: 5.1757e-04
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5191e-04 - val_loss: 5.5237e-04
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5364e-04 - val_loss: 3.3780e-04
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2675e-04 - val_loss: 4.1734e-04
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5769e-04 - val_loss: 4.9706e-04
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1244e-04 - val_loss: 5.4182e-04
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9552e-04 - val_loss: 7.0153e-04
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8144e-04 - val_loss: 3.4447e-04
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3044e-04 - val_loss: 3.9639e-04
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8064e-04 - val_loss: 3.7200e-04
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6490e-04 - val_loss: 6.4231e-04
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1510e-04 - val_loss: 3.9691e-04
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3704e-04 - val_loss: 3.9742e-04
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7179e-04 - val_loss: 4.1341e-04
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6840e-04 - val_loss: 0.0014
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0198e-04 - val_loss: 6.7541e-04
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8530e-04 - val_loss: 6.4426e-04
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5834e-04 - val_loss: 7.4304e-04
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5302e-04 - val_loss: 3.0621e-04
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2443e-04 - val_loss: 3.3564e-04
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4519e-04 - val_loss: 3.2733e-04
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4548e-04 - val_loss: 6.5512e-04
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3189e-04 - val_loss: 3.4666e-04
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1889e-04 - val_loss: 3.0048e-04
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0219e-04 - val_loss: 4.7741e-04
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2435e-04 - val_loss: 3.2925e-04
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7114e-04 - val_loss: 6.0491e-04
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9192e-04 - val_loss: 7.6869e-04
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6860e-04 - val_loss: 2.9983e-04
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0599e-04 - val_loss: 2.9150e-04
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9018e-04 - val_loss: 7.0022e-04
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4791e-04 - val_loss: 4.7823e-04
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3615e-04 - val_loss: 3.6310e-04
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1047e-04 - val_loss: 3.0324e-04
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4587e-04 - val_loss: 0.0014
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1791e-04 - val_loss: 3.2786e-04
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7393e-04 - val_loss: 4.7496e-04
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9451e-04 - val_loss: 8.0224e-04
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2661e-04 - val_loss: 5.2181e-04
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6564e-04 - val_loss: 2.7708e-04
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8754e-04 - val_loss: 5.8411e-04
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8621e-04 - val_loss: 3.0975e-04
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1163e-04 - val_loss: 4.9853e-04
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0045e-04 - val_loss: 8.5475e-04
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2192e-04 - val_loss: 2.7820e-04
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2255e-04 - val_loss: 3.9752e-04
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9945e-04 - val_loss: 2.8332e-04
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4657e-04 - val_loss: 4.3089e-04
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6557e-04 - val_loss: 4.7060e-04
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5592e-04 - val_loss: 7.2093e-04
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3887e-04 - val_loss: 3.2430e-04
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3603e-04 - val_loss: 3.0887e-04
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7574e-04 - val_loss: 2.9734e-04
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8415e-04 - val_loss: 2.7676e-04
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1002e-04 - val_loss: 2.6470e-04
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5388e-04 - val_loss: 4.9084e-04
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7781e-04 - val_loss: 5.2456e-04
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6453e-04 - val_loss: 8.1111e-04
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8020e-04 - val_loss: 0.0020
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3511e-04 - val_loss: 5.2484e-04
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5346e-04 - val_loss: 3.1019e-04
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7321e-04 - val_loss: 2.7279e-04
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6947e-04 - val_loss: 2.7693e-04
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8364e-04 - val_loss: 3.6512e-04
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0196e-04 - val_loss: 3.2397e-04
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8738e-04 - val_loss: 4.3774e-04
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4704e-04 - val_loss: 0.0015
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2745e-04 - val_loss: 2.9600e-04
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8319e-04 - val_loss: 2.8490e-04
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4812e-04 - val_loss: 4.0298e-04
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3118e-04 - val_loss: 2.9293e-04
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6534e-04 - val_loss: 5.7740e-04
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2026e-04 - val_loss: 0.0011

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (414, 7, 6)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.79140524 0.65029013 0.80801116 0.58957954 0.713215   0.7523103 ]
#   [0.80538842 0.66965243 0.82563172 0.59043785 0.72134724 0.76292399]
#   [0.79444237 0.67662558 0.83854701 0.59633976 0.72886102 0.77140374]
#   [0.778143   0.67121779 0.84751084 0.6034821  0.73467792 0.77740352]
#   [0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247713]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735351]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291943]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 1: [[3952.0574]]
# x_pred_input of day 2:
# [[[0.80538842 0.66965243 0.82563172 0.59043785 0.72134724 0.76292403]
#   [0.79444237 0.67662558 0.83854701 0.59633976 0.72886102 0.77140378]
#   [0.778143   0.67121779 0.84751084 0.6034821  0.73467792 0.77740356]
#   [0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247717]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.81809006 0.65878518 0.86551567 0.66900497 0.76067365 0.80096885]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 2: [[4060.5027]]
# x_pred_input of day 3:
# [[[0.79444237 0.67662558 0.83854701 0.59633976 0.72886102 0.77140378]
#   [0.778143   0.67121779 0.84751084 0.6034821  0.73467792 0.77740356]
#   [0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247717]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.81809006 0.65878518 0.86551567 0.66900497 0.76067365 0.80096885]
#   [0.84102795 0.67385563 0.86921619 0.6932558  0.77025755 0.81060515]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 3: [[4157.2383]]
# x_pred_input of day 4:
# [[[0.778143   0.67121779 0.84751084 0.6034821  0.73467792 0.77740356]
#   [0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247717]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.81809006 0.65878518 0.86551567 0.66900497 0.76067365 0.80096885]
#   [0.84102795 0.67385563 0.86921619 0.6932558  0.77025755 0.81060515]
#   [0.86148906 0.69264208 0.87730526 0.71094341 0.78014455 0.82142309]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 4: [[4253.7656]]
# x_pred_input of day 5:
# [[[0.77468537 0.66239613 0.85290614 0.60830637 0.7402269  0.78247717]
#   [0.77747252 0.65402732 0.85668314 0.62421013 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.64146574 0.75233632 0.79291947]
#   [0.81809006 0.65878518 0.86551567 0.6590892  0.76067365 0.80096885]
#   [0.84102795 0.67385563 0.86921619 0.68298059 0.77025755 0.81060515]
#   [0.86148906 0.69264208 0.87730526 0.70040604 0.78014455 0.82142309]
#   [0.88190612 0.71410449 0.88144899 0.72687338 0.79199584 0.83330561]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 5: [[4347.912]]
# x_pred_input of day 6:
# [[[0.77747252 0.65402732 0.85668314 0.61048988 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.62736621 0.75233632 0.79291947]
#   [0.81809006 0.65878518 0.86551567 0.64460229 0.76067365 0.80096885]
#   [0.84102795 0.67385563 0.86921619 0.66796855 0.77025755 0.81060515]
#   [0.86148906 0.69264208 0.87730526 0.68501098 0.78014455 0.82142309]
#   [0.88190612 0.71410449 0.88144899 0.71089657 0.79199584 0.83330561]
#   [0.90181959 0.73717475 0.89001108 0.73052568 0.80466135 0.84609967]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 6: [[4439.7324]]
# x_pred_input of day 7:
# [[[0.78871931 0.65020925 0.86003398 0.61419955 0.75233632 0.79291947]
#   [0.81809006 0.65878518 0.86551567 0.6310739  0.76067365 0.80096885]
#   [0.84102795 0.67385563 0.86921619 0.65394976 0.77025755 0.81060515]
#   [0.86148906 0.69264208 0.87730526 0.67063452 0.78014455 0.82142309]
#   [0.88190612 0.71410449 0.88144899 0.69597685 0.79199584 0.83330561]
#   [0.90181959 0.73717475 0.89001108 0.71519399 0.80466135 0.84609967]
#   [0.92124104 0.76100332 0.89844193 0.7359956  0.81798575 0.85966796]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 7: [[4525.213]]
# x_pred_input of day 8:
# [[[0.81809006 0.65878518 0.86551567 0.6189802  0.7499812  0.80096885]
#   [0.84102795 0.67385563 0.86921619 0.64141767 0.75943038 0.81060515]
#   [0.86148906 0.69264208 0.87730526 0.65778269 0.7691784  0.82142309]
#   [0.88190612 0.71410449 0.88144899 0.68263937 0.7808631  0.83330561]
#   [0.90181959 0.73717475 0.89001108 0.70148824 0.79335058 0.84609967]
#   [0.92124104 0.76100332 0.89844193 0.72189121 0.80648769 0.85966796]
#   [0.93932151 0.78450447 0.90135525 0.75132333 0.82018837 0.87379915]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 8: [[4596.7046]]
# x_pred_input of day 9:
# [[[0.84102795 0.67385563 0.86921619 0.63129948 0.74735277 0.81060515]
#   [0.86148906 0.69264208 0.87730526 0.64740634 0.75694576 0.82142309]
#   [0.88190612 0.71410449 0.88144899 0.67187091 0.76844463 0.83330561]
#   [0.90181959 0.73717475 0.89001108 0.69042244 0.78073352 0.84609967]
#   [0.92124104 0.76100332 0.89844193 0.71050356 0.7936617  0.85966796]
#   [0.93932151 0.78450447 0.90135525 0.7394714  0.80714449 0.87379915]
#   [0.95444313 0.80604704 0.92320468 0.73679807 0.82182249 0.88813606]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 9: [[4663.736]]
# x_pred_input of day 10:
# [[[0.86148906 0.69264208 0.87730526 0.63797042 0.74582457 0.82142309]
#   [0.88190612 0.71410449 0.88144899 0.66207841 0.75715449 0.83330561]
#   [0.90181959 0.73717475 0.89001108 0.68035956 0.76926282 0.84609967]
#   [0.92124104 0.76100332 0.89844193 0.700148   0.78200106 0.85966796]
#   [0.93932151 0.78450447 0.90135525 0.72869363 0.79528577 0.87379915]
#   [0.95444313 0.80604704 0.92320468 0.72605926 0.80974811 0.88813606]
#   [0.9686213  0.8253523  0.94570299 0.72147389 0.82346128 0.90256228]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 10: [[4716.238]]
# x_pred_input of day 11:
# [[[0.88190612 0.71410449 0.88144899 0.65460557 0.74854058 0.83330561]
#   [0.90181959 0.73717475 0.89001108 0.67268039 0.76051116 0.84609967]
#   [0.92124104 0.76100332 0.89844193 0.69224547 0.77310448 0.85966796]
#   [0.93932151 0.78450447 0.90135525 0.72046891 0.78623805 0.87379915]
#   [0.95444313 0.80604704 0.92320468 0.71786428 0.80053586 0.88813606]
#   [0.9686213  0.8253523  0.94570299 0.71333066 0.81409302 0.90256228]
#   [0.97972629 0.84119504 0.96666728 0.71263655 0.82885388 0.91675398]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 11: [[4772.9897]]
# x_pred_input of day 12:
# [[[0.90181959 0.73717475 0.89001108 0.6645722  0.7512723  0.84609967]
#   [0.92124104 0.76100332 0.89844193 0.68390146 0.76371263 0.85966796]
#   [0.93932151 0.78450447 0.90135525 0.71178471 0.77668665 0.87379915]
#   [0.95444313 0.80604704 0.92320468 0.70921147 0.79081077 0.88813606]
#   [0.9686213  0.8253523  0.94570299 0.70473249 0.80420323 0.90256228]
#   [0.97972629 0.84119504 0.96666728 0.70404675 0.81878478 0.91675398]
#   [0.99173023 0.85458018 0.98715987 0.70420626 0.83260694 0.93082575]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 12: [[4802.2866]]
# x_pred_input of day 13:
# [[[0.92124104 0.76100332 0.89406417 0.67967229 0.75895306 0.85966796]
#   [0.93932151 0.78450447 0.89696329 0.70738312 0.77184622 0.87379915]
#   [0.95444313 0.80604704 0.91870626 0.70482579 0.78588231 0.88813606]
#   [0.9686213  0.8253523  0.94109494 0.70037451 0.79919132 0.90256228]
#   [0.97972629 0.84119504 0.96195708 0.69969301 0.81368198 0.91675398]
#   [0.99173023 0.85458018 0.98234982 0.69985153 0.82741801 0.93082575]
#   [0.99792698 0.86307243 1.         0.70448987 0.84115785 0.94419316]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 13: [[4824.6196]]
# x_pred_input of day 14:
# [[[0.93683817 0.78450447 0.88320659 0.70406418 0.76819669 0.87379915]
#   [0.95191982 0.80604704 0.90461608 0.70151885 0.78216642 0.88813606]
#   [0.9660605  0.8253523  0.92666139 0.69708845 0.79541249 0.90256228]
#   [0.97713614 0.84119504 0.94720357 0.69641015 0.80983464 0.91675398]
#   [0.98910834 0.85458018 0.96728354 0.69656792 0.82350572 0.93082575]
#   [0.9952887  0.86307243 0.98466302 0.70118451 0.83718059 0.94419316]
#   [1.         0.86692047 1.         0.70791424 0.85145348 0.95677216]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 14: [[4839.1074]]
# x_pred_input of day 15:
# [[[0.94901933 0.80604704 0.89213171 0.69939012 0.77977459 0.88813606]
#   [0.96311693 0.8253523  0.91387278 0.69497318 0.79298016 0.90256228]
#   [0.97415882 0.84119504 0.93413146 0.69429693 0.80735821 0.91675398]
#   [0.98609454 0.85458018 0.95393432 0.69445422 0.82098748 0.93082575]
#   [0.99225608 0.86307243 0.97107394 0.6990568  0.83462053 0.94419316]
#   [0.99695302 0.86692047 0.98619926 0.70576611 0.84884978 0.95677216]
#   [1.         0.86628168 1.         0.71255814 0.85839061 0.96846757]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 15: [[4825.2104]]
# x_pred_input of day 16:
# [[[0.96311693 0.8253523  0.90341287 0.69700194 0.79531301 0.90256228]
#   [0.97415882 0.84119504 0.92343967 0.69632372 0.80973335 0.91675398]
#   [0.98609454 0.85458018 0.94301587 0.69648147 0.82340272 0.93082575]
#   [0.99225608 0.86307243 0.95995932 0.70109749 0.83707588 0.94419316]
#   [0.99695302 0.86692047 0.97491152 0.70782638 0.85134699 0.95677216]
#   [1.         0.86628168 0.9885543  0.71463824 0.86091589 0.96846757]
#   [0.99707727 0.85922466 1.         0.72210005 0.86935016 0.97874755]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 16: [[4809.065]]
# x_pred_input of day 17:
# [[[0.97415882 0.84119504 0.9161964  0.69869336 0.81251041 0.91675398]
#   [0.98609454 0.85458018 0.93561905 0.69885165 0.82622666 0.93082575]
#   [0.99225608 0.86307243 0.9524296  0.70348337 0.83994672 0.94419316]
#   [0.99695302 0.86692047 0.96726451 0.71023516 0.85426676 0.95677216]
#   [1.         0.86628168 0.98080028 0.7170702  0.86386848 0.96846757]
#   [0.99707727 0.85922466 0.9921562  0.7245574  0.87233168 0.97874755]
#   [0.99368165 0.846989   1.         0.7365628  0.88108859 0.98769808]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 17: [[4792.656]]
# x_pred_input of day 18:
# [[[0.98609454 0.85458018 0.93265111 0.70127712 0.82911663 0.93082575]
#   [0.99225608 0.86307243 0.94940833 0.70592491 0.84288468 0.94419316]
#   [0.99695302 0.86692047 0.96419619 0.71270014 0.85725482 0.95677216]
#   [1.         0.86628168 0.97768902 0.7195589  0.86689012 0.96846757]
#   [0.99707727 0.85922466 0.98900892 0.72707209 0.87538292 0.97874755]
#   [0.99368165 0.846989   0.99682783 0.73911915 0.88417046 0.98769808]
#   [0.99023057 0.8308084  1.         0.75746717 0.89249791 0.99544006]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 18: [[4771.2236]]
# x_pred_input of day 19:
# [[[0.99225608 0.86307243 0.94940833 0.70913947 0.84675306 0.94232774]
#   [0.99695302 0.86692047 0.96419619 0.71594554 0.86118915 0.95488188]
#   [1.         0.86628168 0.97768902 0.72283554 0.87086867 0.9665542 ]
#   [0.99707727 0.85922466 0.98900892 0.73038294 0.87940046 0.97681386]
#   [0.99368165 0.846989   0.99682783 0.74248486 0.88822832 0.98574671]
#   [0.99023057 0.8308084  1.         0.76091643 0.89659399 0.9934734 ]
#   [0.9857231  0.81120645 0.99883746 0.78394244 0.90519489 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 19: [[4747.9287]]
# x_pred_input of day 20:
# [[[0.99695302 0.86692047 0.96419619 0.71950672 0.86550661 0.94975278]
#   [1.         0.86628168 0.97768902 0.72643098 0.87523466 0.96136239]
#   [0.99707727 0.85922466 0.98900892 0.73401592 0.88380921 0.97156694]
#   [0.99368165 0.846989   0.99682783 0.74617804 0.89268134 0.98045181]
#   [0.99023057 0.8308084  1.         0.76470129 0.90108895 0.98813699]
#   [0.9857231  0.81120645 0.99883746 0.78784184 0.90973296 0.99462854]
#   [0.98082386 0.78895636 0.99341851 0.81484414 0.91799955 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 20: [[4723.5293]]
# x_pred_input of day 21:
# [[[1.         0.86628168 0.97768902 0.73023545 0.87985483 0.95721358]
#   [0.99707727 0.85922466 0.98900892 0.73786011 0.88847465 0.9673741 ]
#   [0.99368165 0.846989   0.99682783 0.75008593 0.89739361 0.97622062]
#   [0.99023057 0.8308084  1.         0.76870619 0.9058456  0.98387264]
#   [0.9857231  0.81120645 0.99883746 0.79196793 0.91453525 0.99033617]
#   [0.98082386 0.78895636 0.99341851 0.81911164 0.92284547 0.99568445]
#   [0.97569232 0.76477182 0.98446628 0.84846261 0.93031477 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 21: [[4699.899]]
# x_pred_input of day 22:
# [[[0.99707727 0.85922466 0.98900892 0.74162172 0.89304024 0.96409841]
#   [0.99368165 0.846989   0.99682783 0.75390986 0.90200503 0.97291498]
#   [0.99023057 0.8308084  1.         0.77262505 0.91050045 0.98054109]
#   [0.9857231  0.81120645 0.99883746 0.79600537 0.91923475 0.98698273]
#   [0.98082386 0.78895636 0.99341851 0.82328747 0.92758768 0.9923129 ]
#   [0.97569232 0.76477182 0.98446628 0.85278807 0.93509535 0.99661384]
#   [0.97072253 0.73942616 0.97562439 0.87866161 0.94185246 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 22: [[4681.7095]]
# x_pred_input of day 23:
# [[[0.99368165 0.846989   0.99682783 0.75687999 0.90558707 0.97031954]
#   [0.99023057 0.8308084  1.         0.77566891 0.91411622 0.97792531]
#   [0.9857231  0.81120645 0.99883746 0.79914134 0.92288521 0.98434977]
#   [0.98082386 0.78895636 0.99341851 0.82653092 0.93127131 0.98966572]
#   [0.97569232 0.76477182 0.98446628 0.85614774 0.9388088  0.99395518]
#   [0.97072253 0.73942616 0.97562439 0.88212322 0.94559274 0.99733231]
#   [0.96689703 0.71401745 0.96647701 0.90569377 0.95265849 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# y_pred of day 23: [[4671.7993]]
# x_pred_input of day 24:
# [[[0.99023057 0.8308084  1.         0.77733741 0.91609832 0.97577632]
#   [0.9857231  0.81120645 0.99883746 0.80086034 0.92488632 0.98218666]
#   [0.98082386 0.78895636 0.99341851 0.82830883 0.9332906  0.98749093]
#   [0.97569232 0.76477182 0.98446628 0.85798936 0.94084444 0.99177097]
#   [0.97072253 0.73942616 0.97562439 0.88402071 0.94764309 0.99514067]
#   [0.96689703 0.71401745 0.96647701 0.90764196 0.95472416 0.9978025 ]
#   [0.96481279 0.68969776 0.95717091 0.92912431 0.96237032 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 24: [[4670.7188]]
# x_pred_input of day 25:
# [[[0.9857231  0.81120645 0.99883746 0.80104822 0.92510504 0.98026023]
#   [0.98082386 0.78895636 0.99341851 0.82850315 0.93351131 0.9855541 ]
#   [0.97569232 0.76477182 0.98446628 0.85819064 0.94106693 0.98982574]
#   [0.97072253 0.73942616 0.97562439 0.88422809 0.94786719 0.99318884]
#   [0.96689703 0.71401745 0.96647701 0.90785489 0.95494993 0.99584544]
#   [0.96481279 0.68969776 0.95717091 0.92934228 0.9625979  0.99803863]
#   [0.96458553 0.6674137  0.94831871 0.94820739 0.97037437 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 25: [[4674.523]]
# x_pred_input of day 26:
# [[[0.98082386 0.78895636 0.99341851 0.82781944 0.93273476 0.98372894]
#   [0.97569232 0.76477182 0.98446628 0.85748243 0.9402841  0.98799267]
#   [0.97072253 0.73942616 0.97562439 0.8834984  0.9470787  0.99134954]
#   [0.96689703 0.71401745 0.96647701 0.9071057  0.95415556 0.99400123]
#   [0.96481279 0.68969776 0.95717091 0.92857536 0.96179716 0.99619036]
#   [0.96458553 0.6674137  0.94831871 0.94742489 0.96956716 0.99814809]
#   [0.96538561 0.64747928 0.94049139 0.96317951 0.97725833 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 26: [[4682.6133]]
# x_pred_input of day 27:
# [[[0.97569232 0.76477182 0.98446628 0.85598018 0.93862359 0.98617122]
#   [0.97072253 0.73942616 0.97562439 0.88195057 0.94540619 0.98952191]
#   [0.96689703 0.71401745 0.96647701 0.90551651 0.95247055 0.99216871]
#   [0.96481279 0.68969776 0.95717091 0.92694855 0.96009866 0.9943538 ]
#   [0.96458553 0.6674137  0.94831871 0.94576507 0.96785493 0.99630792]
#   [0.96538561 0.64747928 0.94049139 0.96149208 0.97553252 0.99815642]
#   [0.96708712 0.63005235 0.93439985 0.97348677 0.98283163 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 27: [[4693.645]]
# x_pred_input of day 28:
# [[[0.97072253 0.73942616 0.97562439 0.87984871 0.9431351  0.98764404]
#   [0.96689703 0.71401745 0.96647701 0.90335849 0.95018249 0.99028581]
#   [0.96481279 0.68969776 0.95717091 0.92473946 0.95779227 0.99246675]
#   [0.96458553 0.6674137  0.94831871 0.94351113 0.96552992 0.99441717]
#   [0.96538561 0.64747928 0.94049139 0.95920066 0.97318906 0.99626216]
#   [0.96708712 0.63005235 0.93439985 0.97116677 0.98047064 0.99810224]
#   [0.96940725 0.61509016 0.93053482 0.97906865 0.98668162 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 28: [[4704.9565]]
# x_pred_input of day 29:
# [[[0.96689703 0.71401745 0.96647701 0.90115639 0.94784779 0.98835275]
#   [0.96481279 0.68969776 0.95717091 0.92248524 0.95543888 0.99052944]
#   [0.96458553 0.6674137  0.94831871 0.94121115 0.96315751 0.99247605]
#   [0.96538561 0.64747928 0.94049139 0.95686244 0.97079783 0.99431743]
#   [0.96708712 0.63005235 0.93439985 0.96879938 0.97806151 0.99615392]
#   [0.96940725 0.61509016 0.93053482 0.976682   0.98425724 0.99804798]
#   [0.97178622 0.60225822 0.92865193 0.98108668 0.98964145 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 29: [[4716.6265]]
# x_pred_input of day 30:
# [[[0.96481279 0.68969776 0.95717091 0.92017109 0.953023   0.98854046]
#   [0.96458553 0.6674137  0.94831871 0.93885003 0.96072211 0.99048317]
#   [0.96538561 0.64747928 0.94049139 0.95446205 0.96834312 0.99232085]
#   [0.96708712 0.63005235 0.93439985 0.96636904 0.97558843 0.99415366]
#   [0.96940725 0.61509016 0.93053482 0.97423189 0.9817685  0.99604391]
#   [0.97178622 0.60225822 0.92865193 0.97862552 0.98713909 0.99799201]
#   [0.97424056 0.59127826 0.92826087 0.9801917  0.99180078 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 30: [[4728.1353]]
# x_pred_input of day 31:
# [[[0.96458553 0.6674137  0.94831871 0.93653308 0.95833238 0.98844817]
#   [0.96538561 0.64747928 0.94049139 0.95210657 0.96593443 0.99028208]
#   [0.96708712 0.63005235 0.93439985 0.96398418 0.97316172 0.99211112]
#   [0.96940725 0.61509016 0.93053482 0.97182762 0.97932641 0.99399749]
#   [0.97178622 0.60225822 0.92865193 0.97621041 0.98468364 0.99594159]
#   [0.97424056 0.59127826 0.92826087 0.97777272 0.98933374 0.99794545]
#   [0.97666102 0.5818579  0.92829654 0.97798879 0.99327709 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 31: [[4738.263]]
# x_pred_input of day 32:
# [[[0.96538561 0.64747928 0.94049139 0.95004331 0.96382463 0.98823502]
#   [0.96708712 0.63005235 0.93439985 0.96189517 0.97103614 0.99006028]
#   [0.96940725 0.61509016 0.93053482 0.96972162 0.97718736 0.99194275]
#   [0.97178622 0.60225822 0.92865193 0.97409491 0.9825329  0.99388283]
#   [0.97424056 0.59127826 0.92826087 0.97565384 0.98717284 0.99588255]
#   [0.97666102 0.5818579  0.92829654 0.97586943 0.99110758 0.99793285]
#   [0.97879106 0.57362521 0.92777292 0.97569844 0.99434541 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 32: [[4746.1514]]
# x_pred_input of day 33:
# [[[0.96708712 0.63005235 0.93439985 0.9602744  0.96938704 0.98804913]
#   [0.96940725 0.61509016 0.93053482 0.96808766 0.97552782 0.98992777]
#   [0.97178622 0.60225822 0.92865193 0.97245358 0.98086427 0.99186391]
#   [0.97424056 0.59127826 0.92826087 0.97400988 0.98549633 0.99385957]
#   [0.97666102 0.5818579  0.92829654 0.97422512 0.98942439 0.99590571]
#   [0.97879106 0.57362521 0.92777292 0.97405441 0.99265672 0.99796866]
#   [0.98045006 0.56618722 0.92649448 0.97424967 0.99519405 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 33: [[4751.3516]]
# x_pred_input of day 34:
# [[[0.96940725 0.61509016 0.93053482 0.9670135  0.97443686 0.98800455]
#   [0.97178622 0.60225822 0.92865193 0.97137458 0.97976735 0.98993693]
#   [0.97424056 0.59127826 0.92826087 0.97292915 0.98439423 0.99192871]
#   [0.97666102 0.5818579  0.92829654 0.97314415 0.98831789 0.99397087]
#   [0.97879106 0.57362521 0.92777292 0.97297363 0.99154661 0.99602981]
#   [0.98045006 0.56618722 0.92649448 0.97316867 0.9940811  0.99805721]
#   [0.98154373 0.55918104 0.92429942 0.97399674 0.99595157 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 34: [[4753.3184]]
# x_pred_input of day 35:
# [[[0.97178622 0.60225822 0.92865193 0.97096711 0.97935311 0.98815944]
#   [0.97424056 0.59127826 0.92826087 0.97252103 0.98397804 0.99014764]
#   [0.97666102 0.5818579  0.92829654 0.97273593 0.98790004 0.99218614]
#   [0.97879106 0.57362521 0.92777292 0.97256549 0.9911274  0.99424138]
#   [0.98045006 0.56618722 0.92649448 0.97276045 0.99366081 0.99626514]
#   [0.98154373 0.55918104 0.92429942 0.97358817 0.99553049 0.99820444]
#   [0.98195737 0.55226151 0.92111652 0.97522459 0.99682534 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 35: [[4751.821]]
# x_pred_input of day 36:
# [[[0.97424056 0.59127826 0.92826087 0.97283175 0.9842949  0.98857248]
#   [0.97666102 0.5818579  0.92829654 0.97304673 0.98821817 0.99060773]
#   [0.97879106 0.57362521 0.92777292 0.97287623 0.99144656 0.99265971]
#   [0.98045006 0.56618722 0.92649448 0.97307125 0.9939808  0.99468025]
#   [0.98154373 0.55918104 0.92429942 0.97389923 0.99585107 0.99661646]
#   [0.98195737 0.55226151 0.92111652 0.97553618 0.99714635 0.99840916]
#   [0.98164242 0.54513352 0.91825869 0.97708356 0.99787485 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 36: [[4747.6646]]
# x_pred_input of day 37:
# [[[0.97666102 0.5818579  0.92829654 0.97391032 0.98910216 0.98926933]
#   [0.97879106 0.57362521 0.92777292 0.97373967 0.99233344 0.99131853]
#   [0.98045006 0.56618722 0.92649448 0.97393487 0.99486994 0.99333634]
#   [0.98154373 0.55918104 0.92429942 0.97476359 0.99674189 0.99526994]
#   [0.98195737 0.55226151 0.92111652 0.97640198 0.99803832 0.99706022]
#   [0.98164242 0.54513352 0.91825869 0.97795074 0.99876748 0.99864891]
#   [0.9807683  0.53765086 0.91585683 0.97925836 0.99902763 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 37: [[4741.077]]
# x_pred_input of day 38:
# [[[0.97879106 0.57362521 0.92777292 0.97511133 0.9932993  0.99024347]
#   [0.98045006 0.56618722 0.92649448 0.97530679 0.99583827 0.99225909]
#   [0.98154373 0.55918104 0.92429942 0.97613668 0.99771204 0.99419059]
#   [0.98195737 0.55226151 0.92111652 0.97777739 0.99900973 0.99597893]
#   [0.98164242 0.54513352 0.91825869 0.97932832 0.9997396  0.9975659 ]
#   [0.9807683  0.53765086 0.91585683 0.98063779 1.         0.99891552]
#   [0.97938288 0.52972634 0.91392696 0.98164194 0.99973557 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 38: [[4732.322]]
# x_pred_input of day 39:
# [[[0.98045006 0.56618722 0.92649448 0.97713623 0.99583827 0.9914663 ]
#   [0.98154373 0.55918104 0.92429942 0.97796768 0.99771204 0.99339626]
#   [0.98195737 0.55226151 0.92111652 0.97961146 0.99900973 0.99518317]
#   [0.98164242 0.54513352 0.91825869 0.9811653  0.9997396  0.99676886]
#   [0.9807683  0.53765086 0.91585683 0.98247722 1.         0.99811741]
#   [0.97938288 0.52972634 0.91392696 0.98348326 0.99973557 0.99920102]
#   [0.9775415  0.52132367 0.91270124 0.98399063 0.99915585 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 39: [[4721.2705]]
# x_pred_input of day 40:
# [[[0.98154373 0.55918104 0.92429942 0.98028864 0.99771204 0.99290588]
#   [0.98195737 0.55226151 0.92111652 0.98193632 0.99900973 0.99469191]
#   [0.98164242 0.54513352 0.91825869 0.98349385 0.9997396  0.99627683]
#   [0.9807683  0.53765086 0.91585683 0.98480888 1.         0.99762471]
#   [0.97938288 0.52972634 0.91392696 0.98581731 0.99973557 0.99870778]
#   [0.9775415  0.52132367 0.91270124 0.98632588 0.99915585 0.99950637]
#   [0.97521727 0.51240674 0.91211936 0.98639142 0.9982995  1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 40: [[4708.598]]
# x_pred_input of day 41:
# [[[0.98195737 0.55226151 0.92111652 0.98461583 0.99900973 0.99450878]
#   [0.98164242 0.54513352 0.91825869 0.98617761 0.9997396  0.9960934 ]
#   [0.9807683  0.53765086 0.91585683 0.98749623 1.         0.99744103]
#   [0.97938288 0.52972634 0.91392696 0.98850741 0.99973557 0.99852391]
#   [0.9775415  0.52132367 0.91270124 0.98901737 0.99915585 0.99932234]
#   [0.97521727 0.51240674 0.91211936 0.98908309 0.9982995  0.99981589]
#   [0.97255209 0.50302231 0.91197453 0.9889208  0.99721811 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 41: [[4694.885]]
# x_pred_input of day 42:
# [[[0.98164242 0.54513352 0.91825869 0.98909839 0.9997396  0.9960934 ]
#   [0.9807683  0.53765086 0.91585683 0.99042091 1.         0.99744103]
#   [0.97938288 0.52972634 0.91392696 0.99143508 0.99973557 0.99852391]
#   [0.9775415  0.52132367 0.91270124 0.99194656 0.99915585 0.99932234]
#   [0.97521727 0.51240674 0.91211936 0.99201247 0.9982995  0.99981589]
#   [0.97255209 0.50302231 0.91197453 0.9918497  0.99721811 1.        ]
#   [0.96966798 0.49327183 0.91198975 0.99172462 0.99613824 0.9998826 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 42: [[4680.461]]
# x_pred_input of day 43:
# [[[0.9807683  0.53765086 0.91585683 0.99351587 1.         0.99744103]
#   [0.97938288 0.52972634 0.91392696 0.9945332  0.99973557 0.99852391]
#   [0.9775415  0.52132367 0.91270124 0.99504628 0.99915585 0.99932234]
#   [0.97521727 0.51240674 0.91211936 0.9951124  0.9982995  0.99981589]
#   [0.97255209 0.50302231 0.91197453 0.99494912 0.99721811 1.        ]
#   [0.96966798 0.49327183 0.91198975 0.99482365 0.99613824 0.9998826 ]
#   [0.96663445 0.48327282 0.91200755 0.99477692 0.99507264 0.99947769]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 43: [[4665.1787]]
# x_pred_input of day 44:
# [[[0.97938288 0.52972634 0.91392696 0.9978369  0.99973557 0.99852391]
#   [0.9775415  0.52132367 0.91270124 0.99835168 0.99915585 0.99932234]
#   [0.97521727 0.51240674 0.91211936 0.99841802 0.9982995  0.99981589]
#   [0.97255209 0.50302231 0.91197453 0.99825419 0.99721811 1.        ]
#   [0.96966798 0.49327183 0.91198975 0.99812831 0.99613824 0.9998826 ]
#   [0.96663445 0.48327282 0.91200755 0.99808142 0.99507264 0.99947769]
#   [0.96342039 0.47310505 0.91215695 0.9977717  0.99401637 0.99879487]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 44: [[4649.255]]
# x_pred_input of day 45:
# [[[0.9775415  0.52132367 0.91270124 0.99993355 0.99915585 0.99932234]
#   [0.97521727 0.51240674 0.91211936 1.         0.9982995  0.99981589]
#   [0.97255209 0.50302231 0.91197453 0.99983592 0.99721811 1.        ]
#   [0.96966798 0.49327183 0.91198975 0.99970984 0.99613824 0.9998826 ]
#   [0.96663445 0.48327282 0.91200755 0.99966287 0.99507264 0.99947769]
#   [0.96342039 0.47310505 0.91215695 0.99935266 0.99401637 0.99879487]
#   [0.96007139 0.46285514 0.91272397 0.99825506 0.99300574 0.99784732]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 45: [[4633.5605]]
# x_pred_input of day 46:
# [[[0.97521727 0.51240674 0.91211936 1.         0.9982995  0.99981589]
#   [0.97255209 0.50302231 0.91197453 0.99983592 0.99721811 1.        ]
#   [0.96966798 0.49327183 0.91198975 0.99970984 0.99613824 0.9998826 ]
#   [0.96663445 0.48327282 0.91200755 0.99966287 0.99507264 0.99947769]
#   [0.96342039 0.47310505 0.91215695 0.99935266 0.99401637 0.99879487]
#   [0.96007139 0.46285514 0.91272397 0.99825506 0.99300574 0.99784732]
#   [0.95677065 0.45268122 0.91379    0.99617825 0.99205809 0.99666502]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 46: [[4618.7783]]
# x_pred_input of day 47:
# [[[0.97255209 0.50302231 0.91197453 0.99983592 0.99721811 1.        ]
#   [0.96966798 0.49327183 0.91198975 0.99970984 0.99613824 0.9998826 ]
#   [0.96663445 0.48327282 0.91200755 0.99966287 0.99507264 0.99947769]
#   [0.96342039 0.47310505 0.91215695 0.99935266 0.99401637 0.99879487]
#   [0.96007139 0.46285514 0.91272397 0.99825506 0.99300574 0.99784732]
#   [0.95677065 0.45268122 0.91379    0.99617825 0.99205809 0.99666502]
#   [0.95366174 0.44277628 0.91520966 0.99321037 0.99119013 0.9952892 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 47: [[4605.1675]]
# x_pred_input of day 48:
# [[[0.96966798 0.49327183 0.91198975 0.99970984 0.99613824 0.9998826 ]
#   [0.96663445 0.48327282 0.91200755 0.99966287 0.99507264 0.99947769]
#   [0.96342039 0.47310505 0.91215695 0.99935266 0.99401637 0.99879487]
#   [0.96007139 0.46285514 0.91272397 0.99825506 0.99300574 0.99784732]
#   [0.95677065 0.45268122 0.91379    0.99617825 0.99205809 0.99666502]
#   [0.95366174 0.44277628 0.91520966 0.99321037 0.99119013 0.9952892 ]
#   [0.9507992  0.43331507 0.9167112  0.989615   0.99040519 0.99376255]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 48: [[4592.8647]]
# x_pred_input of day 49:
# [[[0.96663445 0.48327282 0.91200755 0.99966287 0.99507264 0.99947769]
#   [0.96342039 0.47310505 0.91215695 0.99935266 0.99401637 0.99879487]
#   [0.96007139 0.46285514 0.91272397 0.99825506 0.99300574 0.99784732]
#   [0.95677065 0.45268122 0.91379    0.99617825 0.99205809 0.99666502]
#   [0.95366174 0.44277628 0.91520966 0.99321037 0.99119013 0.9952892 ]
#   [0.9507992  0.43331507 0.9167112  0.989615   0.99040519 0.99376255]
#   [0.94821176 0.42444344 0.91803995 0.98569757 0.98966903 0.99212653]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 49: [[4581.8794]]
# x_pred_input of day 50:
# [[[0.96342039 0.47310505 0.91215695 0.99935266 0.99401637 0.99879487]
#   [0.96007139 0.46285514 0.91272397 0.99825506 0.99300574 0.99784732]
#   [0.95677065 0.45268122 0.91379    0.99617825 0.99205809 0.99666502]
#   [0.95366174 0.44277628 0.91520966 0.99321037 0.99119013 0.9952892 ]
#   [0.9507992  0.43331507 0.9167112  0.989615   0.99040519 0.99376255]
#   [0.94821176 0.42444344 0.91803995 0.98569757 0.98966903 0.99212653]
#   [0.94590139 0.4162699  0.91900365 0.98169271 0.98892396 0.99041884]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 50: [[4572.06]]
# x_pred_input of day 51:
# [[[0.96007139 0.46285514 0.91272397 0.99825506 0.99300574 0.99784732]
#   [0.95677065 0.45268122 0.91379    0.99617825 0.99205809 0.99666502]
#   [0.95366174 0.44277628 0.91520966 0.99321037 0.99119013 0.9952892 ]
#   [0.9507992  0.43331507 0.9167112  0.989615   0.99040519 0.99376255]
#   [0.94821176 0.42444344 0.91803995 0.98569757 0.98966903 0.99212653]
#   [0.94590139 0.4162699  0.91900365 0.98169271 0.98892396 0.99041884]
#   [0.94383625 0.408856   0.9194628  0.97778438 0.98810648 0.98867044]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 51: [[4563.142]]
# x_pred_input of day 52:
# [[[0.95677065 0.45268122 0.91379    0.99617825 0.99205809 0.99666502]
#   [0.95366174 0.44277628 0.91520966 0.99321037 0.99119013 0.9952892 ]
#   [0.9507992  0.43331507 0.9167112  0.989615   0.99040519 0.99376255]
#   [0.94821176 0.42444344 0.91803995 0.98569757 0.98966903 0.99212653]
#   [0.94590139 0.4162699  0.91900365 0.98169271 0.98892396 0.99041884]
#   [0.94383625 0.408856   0.9194628  0.97778438 0.98810648 0.98867044]
#   [0.94196067 0.40221414 0.91934    0.97410829 0.98718358 0.98690387]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 52: [[4554.8804]]
# x_pred_input of day 53:
# [[[0.95366174 0.44277628 0.91520966 0.99321037 0.99119013 0.9952892 ]
#   [0.9507992  0.43331507 0.9167112  0.989615   0.99040519 0.99376255]
#   [0.94821176 0.42444344 0.91803995 0.98569757 0.98966903 0.99212653]
#   [0.94590139 0.4162699  0.91900365 0.98169271 0.98892396 0.99041884]
#   [0.94383625 0.408856   0.9194628  0.97778438 0.98810648 0.98867044]
#   [0.94196067 0.40221414 0.91934    0.97410829 0.98718358 0.98690387]
#   [0.94022312 0.39632015 0.91861145 0.97075396 0.9861252  0.98513447]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 53: [[4547.005]]
# x_pred_input of day 54:
# [[[0.9507992  0.43331507 0.9167112  0.989615   0.99040519 0.99376255]
#   [0.94821176 0.42444344 0.91803995 0.98569757 0.98966903 0.99212653]
#   [0.94590139 0.4162699  0.91900365 0.98169271 0.98892396 0.99041884]
#   [0.94383625 0.408856   0.9194628  0.97778438 0.98810648 0.98867044]
#   [0.94196067 0.40221414 0.91934    0.97410829 0.98718358 0.98690387]
#   [0.94022312 0.39632015 0.91861145 0.97075396 0.9861252  0.98513447]
#   [0.9385668  0.39111885 0.91729362 0.96777001 0.98491014 0.98337049]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 54: [[4539.2676]]
# x_pred_input of day 55:
# [[[0.94821176 0.42444344 0.91803995 0.98569757 0.98966903 0.99212653]
#   [0.94590139 0.4162699  0.91900365 0.98169271 0.98892396 0.99041884]
#   [0.94383625 0.408856   0.9194628  0.97778438 0.98810648 0.98867044]
#   [0.94196067 0.40221414 0.91934    0.97410829 0.98718358 0.98690387]
#   [0.94022312 0.39632015 0.91861145 0.97075396 0.9861252  0.98513447]
#   [0.9385668  0.39111885 0.91729362 0.96777001 0.98491014 0.98337049]
#   [0.93693954 0.38653371 0.91544537 0.96516441 0.98353725 0.98161429]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 55: [[4531.4727]]
# x_pred_input of day 56:
# [[[0.94590139 0.4162699  0.91900365 0.98169271 0.98892396 0.99041884]
#   [0.94383625 0.408856   0.9194628  0.97778438 0.98810648 0.98867044]
#   [0.94196067 0.40221414 0.91934    0.97410829 0.98718358 0.98690387]
#   [0.94022312 0.39632015 0.91861145 0.97075396 0.9861252  0.98513447]
#   [0.9385668  0.39111885 0.91729362 0.96777001 0.98491014 0.98337049]
#   [0.93693954 0.38653371 0.91544537 0.96516441 0.98353725 0.98161429]
#   [0.93530016 0.38247765 0.91315773 0.96291014 0.98200308 0.97986392]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 56: [[4523.458]]
# x_pred_input of day 57:
# [[[0.94383625 0.408856   0.9194628  0.97778438 0.98810648 0.98867044]
#   [0.94196067 0.40221414 0.91934    0.97410829 0.98718358 0.98690387]
#   [0.94022312 0.39632015 0.91861145 0.97075396 0.9861252  0.98513447]
#   [0.9385668  0.39111885 0.91729362 0.96777001 0.98491014 0.98337049]
#   [0.93693954 0.38653371 0.91544537 0.96516441 0.98353725 0.98161429]
#   [0.93530016 0.38247765 0.91315773 0.96291014 0.98200308 0.97986392]
#   [0.93361456 0.37885981 0.91050886 0.96097342 0.98030714 0.97811428]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 57: [[4515.0874]]
# x_pred_input of day 58:
# [[[0.94196067 0.40221414 0.91934    0.97410829 0.98718358 0.98690387]
#   [0.94022312 0.39632015 0.91861145 0.97075396 0.9861252  0.98513447]
#   [0.9385668  0.39111885 0.91729362 0.96777001 0.98491014 0.98337049]
#   [0.93693954 0.38653371 0.91544537 0.96516441 0.98353725 0.98161429]
#   [0.93530016 0.38247765 0.91315773 0.96291014 0.98200308 0.97986392]
#   [0.93361456 0.37885981 0.91050886 0.96097342 0.98030714 0.97811428]
#   [0.93185411 0.37559005 0.90758221 0.95930665 0.97845791 0.97635794]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 58: [[4506.281]]
# x_pred_input of day 59:
# [[[0.94022312 0.39632015 0.91861145 0.97075396 0.9861252  0.98513447]
#   [0.9385668  0.39111885 0.91729362 0.96777001 0.98491014 0.98337049]
#   [0.93693954 0.38653371 0.91544537 0.96516441 0.98353725 0.98161429]
#   [0.93530016 0.38247765 0.91315773 0.96291014 0.98200308 0.97986392]
#   [0.93361456 0.37885981 0.91050886 0.96097342 0.98030714 0.97811428]
#   [0.93185411 0.37559005 0.90758221 0.95930665 0.97845791 0.97635794]
#   [0.93000195 0.37258554 0.90446368 0.95785207 0.97647036 0.97458649]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 59: [[4497.006]]
# x_pred_input of day 60:
# [[[0.9385668  0.39111885 0.91729362 0.96777001 0.98491014 0.98337049]
#   [0.93693954 0.38653371 0.91544537 0.96516441 0.98353725 0.98161429]
#   [0.93530016 0.38247765 0.91315773 0.96291014 0.98200308 0.97986392]
#   [0.93361456 0.37885981 0.91050886 0.96097342 0.98030714 0.97811428]
#   [0.93185411 0.37559005 0.90758221 0.95930665 0.97845791 0.97635794]
#   [0.93000195 0.37258554 0.90446368 0.95785207 0.97647036 0.97458649]
#   [0.92805131 0.36977509 0.90126089 0.95652983 0.97436287 0.97279169]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 60: [[4487.27]]
# x_pred_input of day 61:
# [[[0.93693954 0.38653371 0.91544537 0.96516441 0.98353725 0.98161429]
#   [0.93530016 0.38247765 0.91315773 0.96291014 0.98200308 0.97986392]
#   [0.93361456 0.37885981 0.91050886 0.96097342 0.98030714 0.97811428]
#   [0.93185411 0.37559005 0.90758221 0.95930665 0.97845791 0.97635794]
#   [0.93000195 0.37258554 0.90446368 0.95785207 0.97647036 0.97458649]
#   [0.92805131 0.36977509 0.90126089 0.95652983 0.97436287 0.97279169]
#   [0.92600373 0.36710145 0.89806433 0.95526459 0.9721584  0.97096621]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 61: [[4477.1235]]
# x_pred_input of day 62:
# [[[0.93530016 0.38247765 0.91315773 0.96291014 0.98200308 0.97986392]
#   [0.93361456 0.37885981 0.91050886 0.96097342 0.98030714 0.97811428]
#   [0.93185411 0.37559005 0.90758221 0.95930665 0.97845791 0.97635794]
#   [0.93000195 0.37258554 0.90446368 0.95785207 0.97647036 0.97458649]
#   [0.92805131 0.36977509 0.90126089 0.95652983 0.97436287 0.97279169]
#   [0.92600373 0.36710145 0.89806433 0.95526459 0.9721584  0.97096621]
#   [0.92386978 0.36452336 0.89494648 0.95398951 0.96988228 0.96910446]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# y_pred of day 62: [[4466.6343]]
# x_pred_input of day 63:
# [[[0.93361456 0.37885981 0.91050886 0.96097342 0.98030714 0.97811428]
#   [0.93185411 0.37559005 0.90758221 0.95930665 0.97845791 0.97635794]
#   [0.93000195 0.37258554 0.90446368 0.95785207 0.97647036 0.97458649]
#   [0.92805131 0.36977509 0.90126089 0.95652983 0.97436287 0.97279169]
#   [0.92600373 0.36710145 0.89806433 0.95526459 0.9721584  0.97096621]
#   [0.92386978 0.36452336 0.89494648 0.95398951 0.96988228 0.96910446]
#   [0.92166375 0.36201437 0.89197023 0.95264268 0.96755368 0.96720282]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 63: [[4455.8926]]
# x_pred_input of day 64:
# [[[0.93185411 0.37559005 0.90758221 0.95930665 0.97845791 0.97635794]
#   [0.93000195 0.37258554 0.90446368 0.95785207 0.97647036 0.97458649]
#   [0.92805131 0.36977509 0.90126089 0.95652983 0.97436287 0.97279169]
#   [0.92600373 0.36710145 0.89806433 0.95526459 0.9721584  0.97096621]
#   [0.92386978 0.36452336 0.89494648 0.95398951 0.96988228 0.96910446]
#   [0.92166375 0.36201437 0.89197023 0.95264268 0.96755368 0.96720282]
#   [0.91940462 0.35956222 0.8892104  0.95115414 0.96519065 0.96525983]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 64: [[4445.0293]]
# x_pred_input of day 65:
# [[[0.93000195 0.37258554 0.90446368 0.95785207 0.97647036 0.97458649]
#   [0.92805131 0.36977509 0.90126089 0.95652983 0.97436287 0.97279169]
#   [0.92600373 0.36710145 0.89806433 0.95526459 0.9721584  0.97096621]
#   [0.92386978 0.36452336 0.89494648 0.95398951 0.96988228 0.96910446]
#   [0.92166375 0.36201437 0.89197023 0.95264268 0.96755368 0.96720282]
#   [0.91940462 0.35956222 0.8892104  0.95115414 0.96519065 0.96525983]
#   [0.91711992 0.3571701  0.88672986 0.9494653  0.96281016 0.96327694]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 65: [[4434.197]]
# x_pred_input of day 66:
# [[[0.92805131 0.36977509 0.90126089 0.95652983 0.97436287 0.97279169]
#   [0.92600373 0.36710145 0.89806433 0.95526459 0.9721584  0.97096621]
#   [0.92386978 0.36452336 0.89494648 0.95398951 0.96988228 0.96910446]
#   [0.92166375 0.36201437 0.89197023 0.95264268 0.96755368 0.96720282]
#   [0.91940462 0.35956222 0.8892104  0.95115414 0.96519065 0.96525983]
#   [0.91711992 0.3571701  0.88672986 0.9494653  0.96281016 0.96327694]
#   [0.91484169 0.35485541 0.88453918 0.94756011 0.96043149 0.96125857]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 66: [[4423.543]]
# x_pred_input of day 67:
# [[[0.92600373 0.36710145 0.89806433 0.95526459 0.9721584  0.97096621]
#   [0.92386978 0.36452336 0.89494648 0.95398951 0.96988228 0.96910446]
#   [0.92166375 0.36201437 0.89197023 0.95264268 0.96755368 0.96720282]
#   [0.91940462 0.35956222 0.8892104  0.95115414 0.96519065 0.96525983]
#   [0.91711992 0.3571701  0.88672986 0.9494653  0.96281016 0.96327694]
#   [0.91484169 0.35485541 0.88453918 0.94756011 0.96043149 0.96125857]
#   [0.91260105 0.3526461  0.88260385 0.94546095 0.95806954 0.9592118 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 67: [[4413.1855]]
# x_pred_input of day 68:
# [[[0.92386978 0.36452336 0.89494648 0.95398951 0.96988228 0.96910446]
#   [0.92166375 0.36201437 0.89197023 0.95264268 0.96755368 0.96720282]
#   [0.91940462 0.35956222 0.8892104  0.95115414 0.96519065 0.96525983]
#   [0.91711992 0.3571701  0.88672986 0.9494653  0.96281016 0.96327694]
#   [0.91484169 0.35485541 0.88453918 0.94756011 0.96043149 0.96125857]
#   [0.91260105 0.3526461  0.88260385 0.94546095 0.95806954 0.9592118 ]
#   [0.91042274 0.35057491 0.88086822 0.94321062 0.95573539 0.95714547]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 68: [[4403.2236]]
# x_pred_input of day 69:
# [[[0.92166375 0.36201437 0.89197023 0.95264268 0.96755368 0.96720282]
#   [0.91940462 0.35956222 0.8892104  0.95115414 0.96519065 0.96525983]
#   [0.91711992 0.3571701  0.88672986 0.9494653  0.96281016 0.96327694]
#   [0.91484169 0.35485541 0.88453918 0.94756011 0.96043149 0.96125857]
#   [0.91260105 0.3526461  0.88260385 0.94546095 0.95806954 0.9592118 ]
#   [0.91042274 0.35057491 0.88086822 0.94321062 0.95573539 0.95714547]
#   [0.90832761 0.34867608 0.87926562 0.94086338 0.95343822 0.95506965]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 69: [[4393.7256]]
# x_pred_input of day 70:
# [[[0.91940462 0.35956222 0.8892104  0.95115414 0.96519065 0.96525983]
#   [0.91711992 0.3571701  0.88672986 0.9494653  0.96281016 0.96327694]
#   [0.91484169 0.35485541 0.88453918 0.94756011 0.96043149 0.96125857]
#   [0.91260105 0.3526461  0.88260385 0.94546095 0.95806954 0.9592118 ]
#   [0.91042274 0.35057491 0.88086822 0.94321062 0.95573539 0.95714547]
#   [0.90832761 0.34867608 0.87926562 0.94086338 0.95343822 0.95506965]
#   [0.90633004 0.3469815  0.87772785 0.93847645 0.95118898 0.95299483]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 70: [[4384.733]]
# x_pred_input of day 71:
# [[[0.91711992 0.3571701  0.88672986 0.9494653  0.96281016 0.96327694]
#   [0.91484169 0.35485541 0.88453918 0.94756011 0.96043149 0.96125857]
#   [0.91260105 0.3526461  0.88260385 0.94546095 0.95806954 0.9592118 ]
#   [0.91042274 0.35057491 0.88086822 0.94321062 0.95573539 0.95714547]
#   [0.90832761 0.34867608 0.87926562 0.94086338 0.95343822 0.95506965]
#   [0.90633004 0.3469815  0.87772785 0.93847645 0.95118898 0.95299483]
#   [0.90443876 0.34551806 0.87619398 0.93610318 0.94899716 0.9509314 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 71: [[4376.257]]
# x_pred_input of day 72:
# [[[0.91484169 0.35485541 0.88453918 0.94756011 0.96043149 0.96125857]
#   [0.91260105 0.3526461  0.88260385 0.94546095 0.95806954 0.9592118 ]
#   [0.91042274 0.35057491 0.88086822 0.94321062 0.95573539 0.95714547]
#   [0.90832761 0.34867608 0.87926562 0.94086338 0.95343822 0.95506965]
#   [0.90633004 0.3469815  0.87772785 0.93847645 0.95118898 0.95299483]
#   [0.90443876 0.34551806 0.87619398 0.93610318 0.94899716 0.9509314 ]
#   [0.90265612 0.34430536 0.87461568 0.93378894 0.94686516 0.94888895]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 72: [[4368.277]]
# x_pred_input of day 73:
# [[[0.91260105 0.3526461  0.88260385 0.94546095 0.95806954 0.9592118 ]
#   [0.91042274 0.35057491 0.88086822 0.94321062 0.95573539 0.95714547]
#   [0.90832761 0.34867608 0.87926562 0.94086338 0.95343822 0.95506965]
#   [0.90633004 0.3469815  0.87772785 0.93847645 0.95118898 0.95299483]
#   [0.90443876 0.34551806 0.87619398 0.93610318 0.94899716 0.9509314 ]
#   [0.90265612 0.34430536 0.87461568 0.93378894 0.94686516 0.94888895]
#   [0.90097782 0.3433538  0.87295633 0.93157091 0.94478952 0.94687578]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 73: [[4360.7515]]
# x_pred_input of day 74:
# [[[0.91042274 0.35057491 0.88086822 0.94321062 0.95573539 0.95714547]
#   [0.90832761 0.34867608 0.87926562 0.94086338 0.95343822 0.95506965]
#   [0.90633004 0.3469815  0.87772785 0.93847645 0.95118898 0.95299483]
#   [0.90443876 0.34551806 0.87619398 0.93610318 0.94899716 0.9509314 ]
#   [0.90265612 0.34430536 0.87461568 0.93378894 0.94686516 0.94888895]
#   [0.90097782 0.3433538  0.87295633 0.93157091 0.94478952 0.94687578]
#   [0.89939513 0.34266427 0.87119193 0.92947728 0.9427643  0.94489849]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 74: [[4353.6343]]
# x_pred_input of day 75:
# [[[0.90832761 0.34867608 0.87926562 0.94086338 0.95343822 0.95506965]
#   [0.90633004 0.3469815  0.87772785 0.93847645 0.95118898 0.95299483]
#   [0.90443876 0.34551806 0.87619398 0.93610318 0.94899716 0.9509314 ]
#   [0.90265612 0.34430536 0.87461568 0.93378894 0.94686516 0.94888895]
#   [0.90097782 0.3433538  0.87295633 0.93157091 0.94478952 0.94687578]
#   [0.89939513 0.34266427 0.87119193 0.92947728 0.9427643  0.94489849]
#   [0.89789829 0.34222976 0.86931001 0.92752779 0.94078205 0.94296214]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 75: [[4346.8735]]
# x_pred_input of day 76:
# [[[0.90633004 0.3469815  0.87772785 0.93847645 0.95118898 0.95299483]
#   [0.90443876 0.34551806 0.87619398 0.93610318 0.94899716 0.9509314 ]
#   [0.90265612 0.34430536 0.87461568 0.93378894 0.94686516 0.94888895]
#   [0.90097782 0.3433538  0.87295633 0.93157091 0.94478952 0.94687578]
#   [0.89939513 0.34266427 0.87119193 0.92947728 0.9427643  0.94489849]
#   [0.89789829 0.34222976 0.86931001 0.92752779 0.94078205 0.94296214]
#   [0.89647641 0.34203654 0.86730767 0.92573468 0.9388348  0.94107019]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 76: [[4340.414]]
# x_pred_input of day 77:
# [[[0.90443876 0.34551806 0.87619398 0.93610318 0.94899716 0.9509314 ]
#   [0.90265612 0.34430536 0.87461568 0.93378894 0.94686516 0.94888895]
#   [0.90097782 0.3433538  0.87295633 0.93157091 0.94478952 0.94687578]
#   [0.89939513 0.34266427 0.87119193 0.92947728 0.9427643  0.94489849]
#   [0.89789829 0.34222976 0.86931001 0.92752779 0.94078205 0.94296214]
#   [0.89647641 0.34203654 0.86730767 0.92573468 0.9388348  0.94107019]
#   [0.89511789 0.34206546 0.86519058 0.92410298 0.9369154  0.93922467]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 77: [[4334.202]]
# x_pred_input of day 78:
# [[[0.90265612 0.34430536 0.87461568 0.93378894 0.94686516 0.94888895]
#   [0.90097782 0.3433538  0.87295633 0.93157091 0.94478952 0.94687578]
#   [0.89939513 0.34266427 0.87119193 0.92947728 0.9427643  0.94489849]
#   [0.89789829 0.34222976 0.86931001 0.92752779 0.94078205 0.94296214]
#   [0.89647641 0.34203654 0.86730767 0.92573468 0.9388348  0.94107019]
#   [0.89511789 0.34206546 0.86519058 0.92410298 0.9369154  0.93922467]
#   [0.89381144 0.34229346 0.86297252 0.92263051 0.93501841 0.93742627]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 78: [[4328.192]]
# x_pred_input of day 79:
# [[[0.90097782 0.3433538  0.87295633 0.93157091 0.94478952 0.94687578]
#   [0.89939513 0.34266427 0.87119193 0.92947728 0.9427643  0.94489849]
#   [0.89789829 0.34222976 0.86931001 0.92752779 0.94078205 0.94296214]
#   [0.89647641 0.34203654 0.86730767 0.92573468 0.9388348  0.94107019]
#   [0.89511789 0.34206546 0.86519058 0.92410298 0.9369154  0.93922467]
#   [0.89381144 0.34229346 0.86297252 0.92263051 0.93501841 0.93742627]
#   [0.8925474  0.34269553 0.86067344 0.92130899 0.93314009 0.93567468]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 79: [[4322.335]]
# x_pred_input of day 80:
# [[[0.89939513 0.34266427 0.87119193 0.92947728 0.9427643  0.94489849]
#   [0.89789829 0.34222976 0.86931001 0.92752779 0.94078205 0.94296214]
#   [0.89647641 0.34203654 0.86730767 0.92573468 0.9388348  0.94107019]
#   [0.89511789 0.34206546 0.86519058 0.92410298 0.9369154  0.93922467]
#   [0.89381144 0.34229346 0.86297252 0.92263051 0.93501841 0.93742627]
#   [0.8925474  0.34269553 0.86067344 0.92130899 0.93314009 0.93567468]
#   [0.89131561 0.34324511 0.858318   0.92012454 0.93127848 0.93396863]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 80: [[4316.6016]]
# x_pred_input of day 81:
# [[[0.89789829 0.34222976 0.86931001 0.92752779 0.94078205 0.94296214]
#   [0.89647641 0.34203654 0.86730767 0.92573468 0.9388348  0.94107019]
#   [0.89511789 0.34206546 0.86519058 0.92410298 0.9369154  0.93922467]
#   [0.89381144 0.34229346 0.86297252 0.92263051 0.93501841 0.93742627]
#   [0.8925474  0.34269553 0.86067344 0.92130899 0.93314009 0.93567468]
#   [0.89131561 0.34324511 0.858318   0.92012454 0.93127848 0.93396863]
#   [0.89010979 0.34391666 0.85593386 0.91905913 0.92943349 0.93230633]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 81: [[4310.96]]
# x_pred_input of day 82:
# [[[0.89647641 0.34203654 0.86730767 0.92573468 0.9388348  0.94107019]
#   [0.89511789 0.34206546 0.86519058 0.92410298 0.9369154  0.93922467]
#   [0.89381144 0.34229346 0.86297252 0.92263051 0.93501841 0.93742627]
#   [0.8925474  0.34269553 0.86067344 0.92130899 0.93314009 0.93567468]
#   [0.89131561 0.34324511 0.858318   0.92012454 0.93127848 0.93396863]
#   [0.89010979 0.34391666 0.85593386 0.91905913 0.92943349 0.93230633]
#   [0.88892329 0.34468553 0.85355002 0.91809146 0.92760633 0.93068551]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 82: [[4305.396]]
# x_pred_input of day 83:
# [[[0.89511789 0.34206546 0.86519058 0.92410298 0.9369154  0.93922467]
#   [0.89381144 0.34229346 0.86297252 0.92263051 0.93501841 0.93742627]
#   [0.8925474  0.34269553 0.86067344 0.92130899 0.93314009 0.93567468]
#   [0.89131561 0.34324511 0.858318   0.92012454 0.93127848 0.93396863]
#   [0.89010979 0.34391666 0.85593386 0.91905913 0.92943349 0.93230633]
#   [0.88892329 0.34468553 0.85355002 0.91809146 0.92760633 0.93068551]
#   [0.88775311 0.34552985 0.85119564 0.91719827 0.92579948 0.92910384]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 83: [[4299.9053]]
# x_pred_input of day 84:
# [[[0.89381144 0.34229346 0.86297252 0.92263051 0.93501841 0.93742627]
#   [0.8925474  0.34269553 0.86067344 0.92130899 0.93314009 0.93567468]
#   [0.89131561 0.34324511 0.858318   0.92012454 0.93127848 0.93396863]
#   [0.89010979 0.34391666 0.85593386 0.91905913 0.92943349 0.93230633]
#   [0.88892329 0.34468553 0.85355002 0.91809146 0.92760633 0.93068551]
#   [0.88775311 0.34552985 0.85119564 0.91719827 0.92579948 0.92910384]
#   [0.88659833 0.34643117 0.8488986  0.91635565 0.92401649 0.9275591 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 84: [[4294.4927]]
# x_pred_input of day 85:
# [[[0.8925474  0.34269553 0.86067344 0.92130899 0.93314009 0.93567468]
#   [0.89131561 0.34324511 0.858318   0.92012454 0.93127848 0.93396863]
#   [0.89010979 0.34391666 0.85593386 0.91905913 0.92943349 0.93230633]
#   [0.88892329 0.34468553 0.85355002 0.91809146 0.92760633 0.93068551]
#   [0.88775311 0.34552985 0.85119564 0.91719827 0.92579948 0.92910384]
#   [0.88659833 0.34643117 0.8488986  0.91635565 0.92401649 0.9275591 ]
#   [0.88545999 0.34737488 0.84668277 0.91554143 0.92226163 0.92604939]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 85: [[4289.1777]]
# x_pred_input of day 86:
# [[[0.89131561 0.34324511 0.858318   0.92012454 0.93127848 0.93396863]
#   [0.89010979 0.34391666 0.85593386 0.91905913 0.92943349 0.93230633]
#   [0.88892329 0.34468553 0.85355002 0.91809146 0.92760633 0.93068551]
#   [0.88775311 0.34552985 0.85119564 0.91719827 0.92579948 0.92910384]
#   [0.88659833 0.34643117 0.8488986  0.91635565 0.92401649 0.9275591 ]
#   [0.88545999 0.34737488 0.84668277 0.91554143 0.92226163 0.92604939]
#   [0.88434218 0.34835106 0.84456571 0.91473755 0.92053958 0.9245734 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 86: [[4283.984]]
# x_pred_input of day 87:
# [[[0.89010979 0.34391666 0.85593386 0.91905913 0.92943349 0.93230633]
#   [0.88892329 0.34468553 0.85355002 0.91809146 0.92760633 0.93068551]
#   [0.88775311 0.34552985 0.85119564 0.91719827 0.92579948 0.92910384]
#   [0.88659833 0.34643117 0.8488986  0.91635565 0.92401649 0.9275591 ]
#   [0.88545999 0.34737488 0.84668277 0.91554143 0.92226163 0.92604939]
#   [0.88434218 0.34835106 0.84456571 0.91473755 0.92053958 0.9245734 ]
#   [0.88324984 0.34935398 0.84255779 0.91393121 0.91885516 0.92313043]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# y_pred of day 87: [[4278.9424]]
# x_pred_input of day 88:
# [[[0.88892329 0.34468553 0.85355002 0.91809146 0.92760633 0.93068551]
#   [0.88775311 0.34552985 0.85119564 0.91719827 0.92579948 0.92910384]
#   [0.88659833 0.34643117 0.8488986  0.91635565 0.92401649 0.9275591 ]
#   [0.88545999 0.34737488 0.84668277 0.91554143 0.92226163 0.92604939]
#   [0.88434218 0.34835106 0.84456571 0.91473755 0.92053958 0.9245734 ]
#   [0.88324984 0.34935398 0.84255779 0.91393121 0.91885516 0.92313043]
#   [0.88218955 0.35038203 0.84066266 0.91311523 0.91721304 0.92172048]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# y_pred of day 88: [[4274.079]]
# x_pred_input of day 89:
# [[[0.88775311 0.34552985 0.85119564 0.91719827 0.92579948 0.92910384]
#   [0.88659833 0.34643117 0.8488986  0.91635565 0.92401649 0.9275591 ]
#   [0.88545999 0.34737488 0.84668277 0.91554143 0.92226163 0.92604939]
#   [0.88434218 0.34835106 0.84456571 0.91473755 0.92053958 0.9245734 ]
#   [0.88324984 0.34935398 0.84255779 0.91393121 0.91885516 0.92313043]
#   [0.88218955 0.35038203 0.84066266 0.91311523 0.91721304 0.92172048]
#   [0.88116673 0.35143633 0.83887763 0.91228786 0.91561754 0.9203441 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 89: [[4269.4272]]
# x_pred_input of day 90:
# [[[0.88659833 0.34643117 0.8488986  0.91635565 0.92401649 0.9275591 ]
#   [0.88545999 0.34737488 0.84668277 0.91554143 0.92226163 0.92604939]
#   [0.88434218 0.34835106 0.84456571 0.91473755 0.92053958 0.9245734 ]
#   [0.88324984 0.34935398 0.84255779 0.91393121 0.91885516 0.92313043]
#   [0.88218955 0.35038203 0.84066266 0.91311523 0.91721304 0.92172048]
#   [0.88116673 0.35143633 0.83887763 0.91228786 0.91561754 0.9203441 ]
#   [0.88018838 0.35252086 0.8371947  0.9114525  0.9140725  0.91900247]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 90: [[4265.0117]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#             Close       MACD  Bollinger_Upper  Bollinger_Lower         MA26  \
# 0      227.181000   0.000000      4265.011719      4265.011719  4265.011719
# 1      220.488998  -0.533835      4265.011719      4265.011719  4265.011719
# 2      222.218002  -0.808072      4265.011719      4265.011719  4265.011719
# 3      227.600998  -0.584308      4265.011719      4265.011719  4265.011719
# 4      225.119995  -0.600251      4265.011719      4265.011719  4265.011719
# ...           ...        ...              ...              ...          ...
# 2155  4283.983887 -51.832900      4420.065230      4262.566850  4366.490009
# 2156  4278.942383 -51.033012      4410.388899      4258.818865  4358.867657
# 2157  4274.079102 -50.212699      4401.274755      4255.018555  4351.461689
# 2158  4269.427246 -49.368868      4392.681906      4251.181571  4344.289945
# 2159  4265.011719 -48.497375      4384.549465      4247.341892  4337.366192
#
#             EMA20
# 0      227.181000
# 1      226.543666
# 2      226.131698
# 3      226.271632
# 4      226.161952
# ...           ...
# 2155  4347.028589
# 2156  4340.544188
# 2157  4334.214180
# 2158  4328.043996
# 2159  4322.040922
#
# [2160 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
# Dateframe of Close training set
df_train = df_filtered['Close'][:train_size].copy()

# Plot the forecast for df_val, df_test and df_forecast
plt.figure(figsize=(15, 7))
plt.plot(df_train, label='Train')
plt.plot(df_test['Y_test_pred'], label='Test prediction')
plt.plot(df_test['Y_test'], label='Test')
plt.plot(df_forecast_unscale['Close'], label='Forecast next 30 days')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  159.94567955773852
# MAPE:  6.313693914356519
# SMAPE:  6.098662705798807
