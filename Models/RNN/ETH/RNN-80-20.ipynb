# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../../.Dataset/ETH-USD-3.2018-3.2024.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 1  2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2  2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 3  2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 4  2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#        Volume
# 0  1868519936
# 1  1894419968
# 2  1699369984
# 3  1697939968
# 4  1898489984

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#                 Volume
# Date
# 2018-03-01  1868519936
# 2018-03-02  1894419968
# 2018-03-03  1699369984
# 2018-03-04  1697939968
# 2018-03-05  1898489984

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('ETH/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (1978, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.80)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1582, 6) (396, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1575, 7, 6) (1575,)
# (389, 7, 6) (389,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1575, 7, 6) (1575,)
# (389, 7, 6) (389,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
# model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
# model.add(Dense(1))
model.add(SimpleRNN(n_neurons, return_sequences=True,
          input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(SimpleRNN(n_neurons, return_sequences=True))
model.add(SimpleRNN(n_neurons))
model.add(Dense(1))


# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# 25/25 [==============================] - 5s 44ms/step - loss: 0.0494 - val_loss: 0.0049
# Epoch 2/100
# 25/25 [==============================] - 1s 28ms/step - loss: 0.0037 - val_loss: 4.8801e-04
# Epoch 3/100
# 25/25 [==============================] - 1s 31ms/step - loss: 0.0015 - val_loss: 3.9699e-04
# Epoch 4/100
# 25/25 [==============================] - 1s 30ms/step - loss: 0.0012 - val_loss: 3.9090e-04
# Epoch 5/100
# 25/25 [==============================] - 1s 28ms/step - loss: 0.0011 - val_loss: 4.5146e-04
# Epoch 6/100
# 25/25 [==============================] - 1s 27ms/step - loss: 9.9862e-04 - val_loss: 4.3305e-04
# Epoch 7/100
# 25/25 [==============================] - 1s 30ms/step - loss: 9.6889e-04 - val_loss: 2.9820e-04
# Epoch 8/100
# 25/25 [==============================] - 1s 30ms/step - loss: 8.5052e-04 - val_loss: 2.9605e-04
# Epoch 9/100
# 25/25 [==============================] - 1s 40ms/step - loss: 8.1655e-04 - val_loss: 4.7937e-04
# Epoch 10/100
# 25/25 [==============================] - 1s 37ms/step - loss: 8.2585e-04 - val_loss: 5.0748e-04
# Epoch 11/100
# 25/25 [==============================] - 1s 29ms/step - loss: 7.7896e-04 - val_loss: 6.0960e-04
# Epoch 12/100
# 25/25 [==============================] - 1s 31ms/step - loss: 7.8053e-04 - val_loss: 5.1920e-04
# Epoch 13/100
# 25/25 [==============================] - 1s 29ms/step - loss: 8.0684e-04 - val_loss: 2.8098e-04
# Epoch 14/100
# 25/25 [==============================] - 1s 27ms/step - loss: 6.9413e-04 - val_loss: 6.5801e-04
# Epoch 15/100
# 25/25 [==============================] - 1s 31ms/step - loss: 6.9989e-04 - val_loss: 2.5147e-04
# Epoch 16/100
# 25/25 [==============================] - 1s 28ms/step - loss: 7.3767e-04 - val_loss: 6.9999e-04
# Epoch 17/100
# 25/25 [==============================] - 1s 31ms/step - loss: 8.0320e-04 - val_loss: 3.7972e-04
# Epoch 18/100
# 25/25 [==============================] - 1s 30ms/step - loss: 9.0163e-04 - val_loss: 0.0026
# Epoch 19/100
# 25/25 [==============================] - 1s 26ms/step - loss: 8.3347e-04 - val_loss: 2.4032e-04
# Epoch 20/100
# 25/25 [==============================] - 1s 29ms/step - loss: 6.5918e-04 - val_loss: 2.2442e-04
# Epoch 21/100
# 25/25 [==============================] - 1s 31ms/step - loss: 6.5822e-04 - val_loss: 5.4683e-04
# Epoch 22/100
# 25/25 [==============================] - 1s 29ms/step - loss: 6.9436e-04 - val_loss: 8.2443e-04
# Epoch 23/100
# 25/25 [==============================] - 1s 33ms/step - loss: 6.6095e-04 - val_loss: 2.6085e-04
# Epoch 24/100
# 25/25 [==============================] - 1s 25ms/step - loss: 7.5134e-04 - val_loss: 7.3869e-04
# Epoch 25/100
# 25/25 [==============================] - 1s 25ms/step - loss: 6.3900e-04 - val_loss: 2.6847e-04
# Epoch 26/100
# 25/25 [==============================] - 1s 29ms/step - loss: 7.1738e-04 - val_loss: 0.0011
# Epoch 27/100
# 25/25 [==============================] - 1s 27ms/step - loss: 6.0860e-04 - val_loss: 3.1439e-04
# Epoch 28/100
# 25/25 [==============================] - 1s 31ms/step - loss: 7.0017e-04 - val_loss: 5.4434e-04
# Epoch 29/100
# 25/25 [==============================] - 1s 38ms/step - loss: 5.3444e-04 - val_loss: 2.7463e-04
# Epoch 30/100
# 25/25 [==============================] - 1s 49ms/step - loss: 5.3593e-04 - val_loss: 1.9299e-04
# Epoch 31/100
# 25/25 [==============================] - 1s 33ms/step - loss: 5.1450e-04 - val_loss: 7.0026e-04
# Epoch 32/100
# 25/25 [==============================] - 1s 29ms/step - loss: 6.0955e-04 - val_loss: 5.9680e-04
# Epoch 33/100
# 25/25 [==============================] - 1s 31ms/step - loss: 5.5967e-04 - val_loss: 4.2314e-04
# Epoch 34/100
# 25/25 [==============================] - 1s 26ms/step - loss: 6.1428e-04 - val_loss: 3.6097e-04
# Epoch 35/100
# 25/25 [==============================] - 1s 39ms/step - loss: 6.1801e-04 - val_loss: 4.0905e-04
# Epoch 36/100
# 25/25 [==============================] - 1s 39ms/step - loss: 9.1231e-04 - val_loss: 2.5864e-04
# Epoch 37/100
# 25/25 [==============================] - 1s 32ms/step - loss: 5.3303e-04 - val_loss: 0.0011
# Epoch 38/100
# 25/25 [==============================] - 1s 32ms/step - loss: 6.0910e-04 - val_loss: 2.8845e-04
# Epoch 39/100
# 25/25 [==============================] - 1s 32ms/step - loss: 4.7430e-04 - val_loss: 2.3151e-04
# Epoch 40/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.5248e-04 - val_loss: 1.9840e-04
# Epoch 41/100
# 25/25 [==============================] - 1s 33ms/step - loss: 5.2958e-04 - val_loss: 1.8041e-04
# Epoch 42/100
# 25/25 [==============================] - 1s 30ms/step - loss: 5.0656e-04 - val_loss: 1.6637e-04
# Epoch 43/100
# 25/25 [==============================] - 1s 36ms/step - loss: 5.0174e-04 - val_loss: 1.7256e-04
# Epoch 44/100
# 25/25 [==============================] - 1s 30ms/step - loss: 6.9146e-04 - val_loss: 0.0014
# Epoch 45/100
# 25/25 [==============================] - 1s 33ms/step - loss: 6.1840e-04 - val_loss: 1.9466e-04
# Epoch 46/100
# 25/25 [==============================] - 1s 29ms/step - loss: 5.8711e-04 - val_loss: 3.2937e-04
# Epoch 47/100
# 25/25 [==============================] - 1s 32ms/step - loss: 5.4010e-04 - val_loss: 3.9235e-04
# Epoch 48/100
# 25/25 [==============================] - 1s 30ms/step - loss: 5.7847e-04 - val_loss: 0.0011
# Epoch 49/100
# 25/25 [==============================] - 1s 32ms/step - loss: 7.5777e-04 - val_loss: 5.8599e-04
# Epoch 50/100
# 25/25 [==============================] - 1s 29ms/step - loss: 5.5047e-04 - val_loss: 3.9533e-04
# Epoch 51/100
# 25/25 [==============================] - 1s 30ms/step - loss: 5.3357e-04 - val_loss: 3.7368e-04
# Epoch 52/100
# 25/25 [==============================] - 1s 28ms/step - loss: 5.8823e-04 - val_loss: 1.5157e-04
# Epoch 53/100
# 25/25 [==============================] - 1s 27ms/step - loss: 5.6519e-04 - val_loss: 2.0262e-04
# Epoch 54/100
# 25/25 [==============================] - 1s 31ms/step - loss: 5.0401e-04 - val_loss: 1.8870e-04
# Epoch 55/100
# 25/25 [==============================] - 1s 28ms/step - loss: 5.5740e-04 - val_loss: 2.5064e-04
# Epoch 56/100
# 25/25 [==============================] - 1s 26ms/step - loss: 5.1532e-04 - val_loss: 1.7680e-04
# Epoch 57/100
# 25/25 [==============================] - 1s 35ms/step - loss: 4.7509e-04 - val_loss: 2.7689e-04
# Epoch 58/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.7557e-04 - val_loss: 1.7269e-04
# Epoch 59/100
# 25/25 [==============================] - 1s 29ms/step - loss: 4.6433e-04 - val_loss: 0.0012
# Epoch 60/100
# 25/25 [==============================] - 1s 29ms/step - loss: 6.0281e-04 - val_loss: 7.2245e-04
# Epoch 61/100
# 25/25 [==============================] - 1s 32ms/step - loss: 5.5049e-04 - val_loss: 1.7306e-04
# Epoch 62/100
# 25/25 [==============================] - 1s 31ms/step - loss: 5.8573e-04 - val_loss: 1.5601e-04
# Epoch 63/100
# 25/25 [==============================] - 1s 34ms/step - loss: 4.6240e-04 - val_loss: 2.7310e-04
# Epoch 64/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.9654e-04 - val_loss: 9.3395e-04
# Epoch 65/100
# 25/25 [==============================] - 1s 30ms/step - loss: 6.2099e-04 - val_loss: 0.0022
# Epoch 66/100
# 25/25 [==============================] - 1s 29ms/step - loss: 7.6377e-04 - val_loss: 3.3259e-04
# Epoch 67/100
# 25/25 [==============================] - 1s 28ms/step - loss: 4.3678e-04 - val_loss: 3.3065e-04
# Epoch 68/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.0853e-04 - val_loss: 1.4890e-04
# Epoch 69/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.6874e-04 - val_loss: 6.1044e-04
# Epoch 70/100
# 25/25 [==============================] - 1s 35ms/step - loss: 4.6679e-04 - val_loss: 1.4176e-04
# Epoch 71/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.7606e-04 - val_loss: 4.6052e-04
# Epoch 72/100
# 25/25 [==============================] - 1s 30ms/step - loss: 6.4375e-04 - val_loss: 2.9156e-04
# Epoch 73/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.8101e-04 - val_loss: 1.4898e-04
# Epoch 74/100
# 25/25 [==============================] - 1s 28ms/step - loss: 5.5354e-04 - val_loss: 6.4881e-04
# Epoch 75/100
# 25/25 [==============================] - 1s 29ms/step - loss: 7.1971e-04 - val_loss: 1.5137e-04
# Epoch 76/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.8746e-04 - val_loss: 1.4153e-04
# Epoch 77/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.6223e-04 - val_loss: 2.2987e-04
# Epoch 78/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.9837e-04 - val_loss: 1.6054e-04
# Epoch 79/100
# 25/25 [==============================] - 1s 28ms/step - loss: 4.2669e-04 - val_loss: 5.6521e-04
# Epoch 80/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.9393e-04 - val_loss: 5.3667e-04
# Epoch 81/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.5347e-04 - val_loss: 1.4938e-04
# Epoch 82/100
# 25/25 [==============================] - 1s 36ms/step - loss: 4.9350e-04 - val_loss: 4.8963e-04
# Epoch 83/100
# 25/25 [==============================] - 1s 29ms/step - loss: 5.0462e-04 - val_loss: 1.3905e-04
# Epoch 84/100
# 25/25 [==============================] - 1s 31ms/step - loss: 6.0050e-04 - val_loss: 1.4463e-04
# Epoch 85/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.6262e-04 - val_loss: 6.0461e-04
# Epoch 86/100
# 25/25 [==============================] - 1s 27ms/step - loss: 6.3493e-04 - val_loss: 3.5856e-04
# Epoch 87/100
# 25/25 [==============================] - 1s 27ms/step - loss: 5.5881e-04 - val_loss: 1.3751e-04
# Epoch 88/100
# 25/25 [==============================] - 1s 28ms/step - loss: 5.3672e-04 - val_loss: 2.8028e-04
# Epoch 89/100
# 25/25 [==============================] - 1s 34ms/step - loss: 5.6076e-04 - val_loss: 1.3308e-04
# Epoch 90/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.7994e-04 - val_loss: 2.2165e-04
# Epoch 91/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.0212e-04 - val_loss: 1.6062e-04
# Epoch 92/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.5028e-04 - val_loss: 3.1094e-04
# Epoch 93/100
# 25/25 [==============================] - 1s 28ms/step - loss: 5.0800e-04 - val_loss: 3.8417e-04
# Epoch 94/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.8039e-04 - val_loss: 4.6300e-04
# Epoch 95/100
# 25/25 [==============================] - 1s 33ms/step - loss: 4.8476e-04 - val_loss: 6.8199e-04
# Epoch 96/100
# 25/25 [==============================] - 1s 33ms/step - loss: 5.4850e-04 - val_loss: 1.3495e-04
# Epoch 97/100
# 25/25 [==============================] - 1s 29ms/step - loss: 3.7813e-04 - val_loss: 1.8599e-04
# Epoch 98/100
# 25/25 [==============================] - 1s 32ms/step - loss: 4.9640e-04 - val_loss: 1.3028e-04
# Epoch 99/100
# 25/25 [==============================] - 1s 28ms/step - loss: 5.0936e-04 - val_loss: 0.0010
# Epoch 100/100
# 25/25 [==============================] - 1s 28ms/step - loss: 5.1930e-04 - val_loss: 0.0013

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (396, 7, 6)
# 13/13 [==============================] - 0s 5ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.61510439 0.61955538 0.63512207 0.52653685 0.57656614 0.60530042]
#   [0.64055213 0.63046936 0.64170957 0.53855599 0.58334023 0.61300222]
#   [0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140929]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043776]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.6416704 ]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088305]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123953]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 1: [[3614.9204]]
# x_pred_input of day 2:
# [[[0.64055213 0.63046936 0.64170957 0.53855599 0.58334023 0.61300228]
#   [0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140936]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.74678026 0.73204539 0.71351982 0.58761943 0.63997203 0.67451326]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 2: [[3759.1155]]
# x_pred_input of day 3:
# [[[0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140936]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.74678026 0.73204539 0.71351982 0.58761943 0.63997203 0.67451326]
#   [0.7772798  0.76403924 0.73816555 0.58548959 0.65220195 0.68965214]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 3: [[3898.9766]]
# x_pred_input of day 4:
# [[[0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.74678026 0.73204539 0.71351982 0.58761943 0.63997203 0.67451326]
#   [0.7772798  0.76403924 0.73816555 0.58548959 0.65220195 0.68965214]
#   [0.80686263 0.79947854 0.76500221 0.58457377 0.66521068 0.70638453]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 4: [[4049.6133]]
# x_pred_input of day 5:
# [[[0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.74678026 0.73204539 0.71351982 0.58761943 0.63997203 0.67451326]
#   [0.7772798  0.76403924 0.73816555 0.58548959 0.65220195 0.68965214]
#   [0.80686263 0.79947854 0.76500221 0.58457377 0.66521068 0.70638453]
#   [0.83872467 0.83831819 0.79686163 0.57814849 0.67958158 0.72479253]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 5: [[4173.226]]
# x_pred_input of day 6:
# [[[0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.74678026 0.73204539 0.71351982 0.58761943 0.63997203 0.67451326]
#   [0.7772798  0.76403924 0.73816555 0.58548959 0.65220195 0.68965214]
#   [0.80686263 0.79947854 0.76500221 0.58457377 0.66521068 0.70638453]
#   [0.83872467 0.83831819 0.79686163 0.57814849 0.67958158 0.72479253]
#   [0.86487073 0.87660863 0.82984169 0.57228238 0.69444632 0.74413007]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 6: [[4284.007]]
# x_pred_input of day 7:
# [[[0.70873566 0.70548169 0.69610186 0.56842995 0.62836714 0.66123959]
#   [0.74678026 0.73204539 0.71351982 0.57476072 0.63997203 0.67451326]
#   [0.7772798  0.76403924 0.73816555 0.57267748 0.65220195 0.68965214]
#   [0.80686263 0.79947854 0.76500221 0.5717817  0.66521068 0.70638453]
#   [0.83872467 0.83831819 0.79686163 0.56549702 0.67958158 0.72479253]
#   [0.86487073 0.87660863 0.82984169 0.55975928 0.69444632 0.74413007]
#   [0.88830261 0.91271681 0.86213288 0.55792498 0.71016702 0.76403014]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 7: [[4396.479]]
# x_pred_input of day 8:
# [[[0.74678026 0.73204539 0.71351982 0.55983749 0.63997203 0.67451326]
#   [0.7772798  0.76403924 0.73816555 0.55780835 0.65220195 0.68965214]
#   [0.80686263 0.79947854 0.76500221 0.55693582 0.66521068 0.70638453]
#   [0.83872467 0.83831819 0.79686163 0.55081432 0.67958158 0.72479253]
#   [0.86487073 0.87660863 0.82984169 0.54522556 0.69444632 0.74413007]
#   [0.88830261 0.91271681 0.86213288 0.54343888 0.71016702 0.76403014]
#   [0.91209226 0.94687717 0.89363527 0.54551992 0.72682359 0.78447588]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 8: [[4475.0527]]
# x_pred_input of day 9:
# [[[0.7772798  0.76403924 0.73816555 0.54787064 0.65040895 0.68965214]
#   [0.80686263 0.79947854 0.76500221 0.54701366 0.66338191 0.70638453]
#   [0.83872467 0.83831819 0.79686163 0.54100122 0.67771331 0.72479253]
#   [0.86487073 0.87660863 0.82984169 0.53551203 0.69253719 0.74413007]
#   [0.88830261 0.91271681 0.86213288 0.53375718 0.70821467 0.76403014]
#   [0.91209226 0.94687717 0.89363527 0.53580114 0.72482544 0.78447588]
#   [0.92871184 0.97564667 0.92423661 0.53851885 0.7408033  0.80467963]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 9: [[4531.407]]
# x_pred_input of day 10:
# [[[0.80686263 0.79947854 0.76500221 0.54011228 0.65494304 0.70638453]
#   [0.83872467 0.83831819 0.79686163 0.53417569 0.66909213 0.72479253]
#   [0.86487073 0.87660863 0.82984169 0.52875575 0.68372743 0.74413007]
#   [0.88830261 0.91271681 0.86213288 0.52702305 0.69920548 0.76403014]
#   [0.91209226 0.94687717 0.89363527 0.52904122 0.71560495 0.78447588]
#   [0.92871184 0.97564667 0.92423661 0.53172464 0.73137956 0.80467963]
#   [0.94063171 0.99758664 0.95267169 0.53656347 0.74778174 0.82418224]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 10: [[4549.41]]
# x_pred_input of day 11:
# [[[0.83872467 0.83002313 0.79686163 0.53203137 0.66638406 0.72479253]
#   [0.86487073 0.8679347  0.82984169 0.52663319 0.68096013 0.74413007]
#   [0.88830261 0.90368559 0.86213288 0.52490744 0.69637553 0.76403014]
#   [0.91209226 0.93750793 0.89363527 0.52691751 0.71270862 0.78447588]
#   [0.92871184 0.96599276 0.92423661 0.52959015 0.72841939 0.80467963]
#   [0.94063171 0.98771564 0.95267169 0.53440957 0.74475519 0.82418224]
#   [0.94443961 1.         0.97767181 0.54176591 0.76007313 0.84221817]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 11: [[4541.679]]
# x_pred_input of day 12:
# [[[0.86487073 0.86608369 0.82984169 0.52754259 0.68214574 0.74413007]
#   [0.88830261 0.90175834 0.86213288 0.52581386 0.69758798 0.76403014]
#   [0.91209226 0.93550855 0.89363527 0.5278274  0.71394951 0.78447588]
#   [0.92871184 0.96393263 0.92423661 0.53050466 0.72968762 0.80467963]
#   [0.94063171 0.98560918 0.95267169 0.53533239 0.74605187 0.82418224]
#   [0.94443961 0.99786734 0.97767181 0.54270144 0.76139649 0.84221817]
#   [0.94280439 1.         0.99701113 0.55696106 0.77627156 0.85836861]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 12: [[4525.6196]]
# x_pred_input of day 13:
# [[[0.88830261 0.90175834 0.85258239 0.5277068  0.70012015 0.76403014]
#   [0.91209226 0.93550855 0.8837358  0.5297276  0.71654107 0.78447588]
#   [0.92871184 0.96393263 0.91399815 0.53241449 0.73233631 0.80467963]
#   [0.94063171 0.98560918 0.94211824 0.5372596  0.74875996 0.82418224]
#   [0.94443961 0.99786734 0.96684141 0.54465519 0.76416027 0.84221817]
#   [0.94280439 1.         0.98596649 0.55896613 0.77908935 0.85836861]
#   [0.93940754 0.99333162 1.         0.57847004 0.79405865 0.87263238]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 13: [[4510.592]]
# x_pred_input of day 14:
# [[[0.91209226 0.93550855 0.87696518 0.53151815 0.71898323 0.78447588]
#   [0.92871184 0.96393263 0.90699568 0.53421413 0.73483231 0.80467963]
#   [0.94063171 0.98560918 0.93490032 0.53907562 0.75131193 0.82418224]
#   [0.94443961 0.99786734 0.95943408 0.5464962  0.76676474 0.84221817]
#   [0.94280439 1.         0.97841264 0.56085552 0.78174469 0.85836861]
#   [0.93940754 0.99333162 0.99233863 0.58042535 0.79676501 0.87263238]
#   [0.93622891 0.97994833 1.         0.60769365 0.81180271 0.88521155]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 14: [[4489.0527]]
# x_pred_input of day 15:
# [[[0.92871184 0.96393263 0.90354801 0.53681482 0.73843959 0.80467963]
#   [0.94063171 0.98560918 0.93134658 0.54169998 0.75500011 0.82418224]
#   [0.94443961 0.99786734 0.95578708 0.54915668 0.77052877 0.84221817]
#   [0.94280439 1.         0.9746935  0.56358591 0.78558226 0.85836861]
#   [0.93940754 0.99333162 0.98856656 0.58325101 0.80067632 0.87263238]
#   [0.93622891 0.97994833 0.9961988  0.61065206 0.81578783 0.88521155]
#   [0.93167306 0.96079705 1.         0.64024037 0.82990123 0.89612527]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 15: [[4463.4043]]
# x_pred_input of day 16:
# [[[0.94063171 0.98560918 0.92990452 0.54485856 0.75943945 0.82418224]
#   [0.94443961 0.99786734 0.95430718 0.55235874 0.77505942 0.84221817]
#   [0.94280439 1.         0.97318432 0.5668721  0.79020142 0.85836861]
#   [0.93940754 0.99333162 0.9870359  0.58665187 0.80538423 0.87263238]
#   [0.93622891 0.97994833 0.99465633 0.61421269 0.82058459 0.88521155]
#   [0.93167306 0.96079705 0.99845164 0.64397352 0.83478098 0.89612527]
#   [0.92624801 0.93692865 1.         0.67294062 0.84818182 0.90544295]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 16: [[4430.076]]
# x_pred_input of day 17:
# [[[0.94443961 0.99786734 0.95430718 0.55657578 0.77512614 0.84221817]
#   [0.94280439 1.         0.97318432 0.57119994 0.79026944 0.85836861]
#   [0.93940754 0.99333162 0.9870359  0.59113072 0.80545356 0.87263238]
#   [0.93622891 0.97994833 0.99465633 0.61890196 0.82065523 0.88521155]
#   [0.93167306 0.96079705 0.99845164 0.64889    0.83485284 0.89612527]
#   [0.92624801 0.93692865 1.         0.67807825 0.84825483 0.90544295]
#   [0.91919859 0.90885861 0.99804223 0.70895364 0.8607463  0.91314993]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 17: [[4398.6265]]
# x_pred_input of day 18:
# [[[0.94280439 1.         0.97318432 0.5753449  0.79026944 0.85836861]
#   [0.93940754 0.99333162 0.9870359  0.5954203  0.80545356 0.87263238]
#   [0.93622891 0.97994833 0.99465633 0.62339307 0.82065523 0.88521155]
#   [0.93167306 0.96079705 0.99845164 0.65359872 0.83485284 0.89612527]
#   [0.92624801 0.93692865 1.         0.68299878 0.84825483 0.90544295]
#   [0.91919859 0.90885861 0.99804223 0.71409822 0.8607463  0.91314993]
#   [0.91254648 0.87800684 0.99272573 0.74679009 0.87334092 0.91944039]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 18: [[4373.041]]
# x_pred_input of day 19:
# [[[0.93940754 0.99333162 0.9870359  0.59895623 0.80545356 0.87263238]
#   [0.93622891 0.97994833 0.99465633 0.62709511 0.82065523 0.88521155]
#   [0.93167306 0.96079705 0.99845164 0.65748015 0.83485284 0.89612527]
#   [0.92624801 0.93692865 1.         0.6870548  0.84825483 0.90544295]
#   [0.91919859 0.90885861 0.99804223 0.71833892 0.8607463  0.91314993]
#   [0.91254648 0.87800684 0.99272573 0.75122493 0.87334092 0.91944039]
#   [0.90713475 0.84592126 0.98696557 0.78074902 0.88570418 0.92457649]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 19: [[4364.201]]
# x_pred_input of day 20:
# [[[0.93622891 0.97994833 0.99465633 0.62838442 0.82065523 0.88521155]
#   [0.93167306 0.96079705 0.99845164 0.65883193 0.83485284 0.89612527]
#   [0.92624801 0.93692865 1.         0.68846738 0.84825483 0.90544295]
#   [0.91919859 0.90885861 0.99804223 0.71981582 0.8607463  0.91314993]
#   [0.91254648 0.87800684 0.99272573 0.75276945 0.87334092 0.91944039]
#   [0.90713475 0.84592126 0.98696557 0.78235424 0.88570418 0.92457649]
#   [0.90526498 0.81493093 0.97426289 0.82073179 0.89842465 0.92903159]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 20: [[4385.4683]]
# x_pred_input of day 21:
# [[[0.93167306 0.96079705 0.99845164 0.65558914 0.83485284 0.89612527]
#   [0.92624801 0.93692865 1.         0.68507873 0.84825483 0.90544295]
#   [0.91919859 0.90885861 0.99804223 0.71627287 0.8607463  0.91314993]
#   [0.91254648 0.87800684 0.99272573 0.7490643  0.87334092 0.91944039]
#   [0.90713475 0.84592126 0.98696557 0.77850347 0.88570418 0.92457649]
#   [0.90526498 0.81493093 0.97426289 0.81669212 0.89842465 0.92903159]
#   [0.90976331 0.78820155 0.95878483 0.85639193 0.91070897 0.93352394]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 21: [[4409.721]]
# x_pred_input of day 22:
# [[[0.92624801 0.93692865 1.         0.6812548  0.84825483 0.90544295]
#   [0.91919859 0.90885861 0.99804223 0.71227483 0.8607463  0.91314993]
#   [0.91254648 0.87800684 0.99272573 0.74488322 0.87334092 0.91944039]
#   [0.90713475 0.84592126 0.98696557 0.77415807 0.88570418 0.92457649]
#   [0.90526498 0.81493093 0.97426289 0.81213356 0.89842465 0.92903159]
#   [0.90976331 0.78820155 0.95878483 0.85161177 0.91070897 0.93352394]
#   [0.91489319 0.7654176  0.94490608 0.88568953 0.92214624 0.93811479]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 22: [[4446.2305]]
# x_pred_input of day 23:
# [[[0.91919859 0.90885861 0.99804223 0.70633981 0.8607463  0.91314993]
#   [0.91254648 0.87800684 0.99272573 0.73867649 0.87334092 0.91944039]
#   [0.90713475 0.84592126 0.98696557 0.76770742 0.88570418 0.92457649]
#   [0.90526498 0.81493093 0.97426289 0.80536648 0.89842465 0.92903159]
#   [0.90976331 0.78820155 0.95878483 0.84451574 0.91070897 0.93352394]
#   [0.91489319 0.7654176  0.94490608 0.87830954 0.92214624 0.93811479]
#   [0.92261548 0.74722595 0.93187152 0.90869347 0.93332085 0.94306076]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 23: [[4492.54]]
# x_pred_input of day 24:
# [[[0.91254648 0.87800684 0.99272573 0.73095093 0.86747156 0.91944039]
#   [0.90713475 0.84592126 0.98696557 0.75967823 0.87975173 0.92457649]
#   [0.90526498 0.81493093 0.97426289 0.79694343 0.89238672 0.92903159]
#   [0.90976331 0.78820155 0.95878483 0.83568324 0.90458848 0.93352394]
#   [0.91489319 0.7654176  0.94490608 0.8691236  0.91594889 0.93811479]
#   [0.92261548 0.74722595 0.93187152 0.89918976 0.9270484  0.94306076]
#   [0.93241068 0.73383229 0.92043319 0.92536152 0.9379796  0.94854071]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 24: [[4538.495]]
# x_pred_input of day 25:
# [[[0.90713475 0.84592126 0.98696557 0.75187483 0.8706402  0.92457649]
#   [0.90526498 0.81493093 0.97426289 0.78875724 0.88314432 0.92903159]
#   [0.90976331 0.78820155 0.95878483 0.82709911 0.89521972 0.93352394]
#   [0.91489319 0.7654176  0.94490608 0.86019598 0.90646247 0.93811479]
#   [0.92261548 0.74722595 0.93187152 0.88995329 0.91744702 0.94306076]
#   [0.93241068 0.73383229 0.92043319 0.91585622 0.928265   0.94854071]
#   [0.94213091 0.72431447 0.91291515 0.9350887  0.93825752 0.95449609]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 25: [[4591.9165]]
# x_pred_input of day 26:
# [[[0.90526498 0.81493093 0.97426289 0.77944993 0.87263809 0.92903159]
#   [0.90976331 0.78820155 0.95878483 0.81733937 0.88456983 0.93352394]
#   [0.91489319 0.7654176  0.94490608 0.85004569 0.89567883 0.93811479]
#   [0.92261548 0.74722595 0.93187152 0.87945187 0.9065327  0.94306076]
#   [0.93241068 0.73383229 0.92043319 0.90504914 0.91722199 0.94854071]
#   [0.94213091 0.72431447 0.91291515 0.92405469 0.92709564 0.95449609]
#   [0.95343038 0.71869805 0.91029822 0.93615962 0.93780185 0.96104366]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 26: [[4653.6523]]
# x_pred_input of day 27:
# [[[0.90976331 0.78820155 0.95878483 0.80634366 0.87257373 0.93352394]
#   [0.91489319 0.7654176  0.94490608 0.83860998 0.88353208 0.93811479]
#   [0.92261548 0.74722595 0.93187152 0.86762056 0.89423876 0.94306076]
#   [0.93241068 0.73383229 0.92043319 0.89287347 0.90478308 0.94854071]
#   [0.94213091 0.72431447 0.91291515 0.91162333 0.91452283 0.95449609]
#   [0.95343038 0.71869805 0.91029822 0.92356542 0.92508385 0.96104366]
#   [0.96648848 0.7170445  0.91401166 0.92762133 0.93537959 0.96830746]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 27: [[4713.404]]
# x_pred_input of day 28:
# [[[0.91489319 0.7654176  0.94490608 0.8278311  0.87208544 0.93811479]
#   [0.92261548 0.74722595 0.93187152 0.85646879 0.88265341 0.94306076]
#   [0.93241068 0.73383229 0.92043319 0.88139712 0.89306113 0.94854071]
#   [0.94213091 0.72431447 0.91291515 0.89990598 0.90267469 0.95449609]
#   [0.95343038 0.71869805 0.91029822 0.91169458 0.91309889 0.96104366]
#   [0.96648848 0.7170445  0.91401166 0.91569836 0.92326124 0.96830746]
#   [0.97912686 0.71831359 0.92266371 0.91331784 0.93242191 0.97617621]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 28: [[4777.6665]]
# x_pred_input of day 29:
# [[[0.92261548 0.74722595 0.93187152 0.84479067 0.8705238  0.94306076]
#   [0.93241068 0.73383229 0.92043319 0.86937909 0.8807885  0.94854071]
#   [0.94213091 0.72431447 0.91291515 0.88763558 0.89026995 0.95449609]
#   [0.95343038 0.71869805 0.91029822 0.89926344 0.9005509  0.96104366]
#   [0.96648848 0.7170445  0.91401166 0.90321262 0.9105736  0.96830746]
#   [0.97912686 0.71831359 0.92266371 0.90086456 0.91960838 0.97617621]
#   [0.99271944 0.72231502 0.9336283  0.8957879  0.92798573 0.98469022]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 29: [[4837.0874]]
# x_pred_input of day 30:
# [[[0.92750613 0.73383229 0.92043319 0.85855454 0.86973691 0.94854071]
#   [0.93717522 0.72431447 0.91291515 0.87658372 0.8790994  0.95449609]
#   [0.94841525 0.71869805 0.91029822 0.8880668  0.88925134 0.96104366]
#   [0.96140467 0.7170445  0.91401166 0.89196681 0.89914828 0.96830746]
#   [0.97397657 0.71831359 0.92266371 0.88964799 0.9080697  0.97617621]
#   [0.98749765 0.72231502 0.9336283  0.88463454 0.91634195 0.98469022]
#   [1.         0.7279211  0.94562038 0.87862133 0.92396089 0.99368293]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 30: [[4880.913]]
# x_pred_input of day 31:
# [[[0.92861243 0.72431447 0.91291515 0.8686072  0.87103856 0.95185913]
#   [0.93974976 0.71869805 0.91029822 0.87998579 0.88109742 0.95838861]
#   [0.9526205  0.7170445  0.91401166 0.88385031 0.89090362 0.96563235]
#   [0.96507753 0.71831359 0.92266371 0.88155259 0.89974323 0.97347937]
#   [0.97847507 0.72231502 0.9336283  0.87658476 0.90793962 0.98196985]
#   [0.99086319 0.7279211  0.94562038 0.87062627 0.9154887  0.99093772]
#   [1.         0.73314079 0.95788732 0.8649219  0.92217826 1.        ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 31: [[4896.8325]]
# x_pred_input of day 32:
# [[[0.93664115 0.71869805 0.91029822 0.8770867  0.87817246 0.95026975]
#   [0.94946931 0.7170445  0.91401166 0.88093849 0.8879461  0.95745213]
#   [0.96188514 0.71831359 0.92266371 0.87864834 0.89675637 0.96523267]
#   [0.97523836 0.72231502 0.9336283  0.87369687 0.90492555 0.97365122]
#   [0.98758549 0.7279211  0.94562038 0.86775801 0.91244957 0.98254313]
#   [0.99669208 0.73314079 0.95788732 0.86207244 0.91911692 0.99152864]
#   [1.         0.73517147 0.9692381  0.8578133  0.92492053 1.        ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 32: [[4901.445]]
# x_pred_input of day 33:
# [[[0.94856021 0.7170445  0.91401166 0.88009844 0.88709289 0.95007617]
#   [0.96096415 0.71831359 0.92266371 0.87781046 0.89589469 0.95779677]
#   [0.97430459 0.72231502 0.9336283  0.87286372 0.90405602 0.96615047]
#   [0.9866399  0.7279211  0.94562038 0.86693053 0.91157281 0.97497387]
#   [0.99573777 0.73314079 0.95788732 0.86125038 0.91823376 0.98389016]
#   [0.99904252 0.73517147 0.9692381  0.8569953  0.92403179 0.99229627]
#   [1.         0.73353516 0.97941127 0.85437085 0.92897913 1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 33: [[4896.928]]
# x_pred_input of day 34:
# [[[0.96096415 0.71831359 0.92266371 0.87863093 0.89673847 0.95125795]
#   [0.97430459 0.72231502 0.9336283  0.87367957 0.90490749 0.95955462]
#   [0.9866399  0.7279211  0.94562038 0.86774083 0.91243136 0.96831778]
#   [0.99573777 0.73314079 0.95788732 0.86205537 0.91909858 0.9771732 ]
#   [0.99904252 0.73517147 0.9692381  0.85779631 0.92490207 0.98552192]
#   [1.         0.73353516 0.97941127 0.85516941 0.92985407 0.99317306]
#   [0.99906239 0.72811976 0.98819738 0.85417861 0.93386779 1.        ]]]
# 1/1 [==============================] - 0s 28ms/step
# y_pred of day 34: [[4884.6895]]
# x_pred_input of day 35:
# [[[0.97430459 0.72231502 0.9336283  0.87589798 0.90722282 0.95390945]
#   [0.9866399  0.7279211  0.94562038 0.86994415 0.91476593 0.96262106]
#   [0.99573777 0.73314079 0.95788732 0.86424426 0.92145021 0.97142438]
#   [0.99904252 0.73517147 0.9692381  0.85997439 0.92726856 0.97972398]
#   [1.         0.73353516 0.97941127 0.85734081 0.93223322 0.98733011]
#   [0.99906239 0.72811976 0.98819738 0.8563475  0.93625721 0.99411689]
#   [0.99652172 0.71902304 0.99546396 0.85710513 0.939551   1.        ]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 35: [[4870.9883]]
# x_pred_input of day 36:
# [[[0.9866399  0.7279211  0.94445898 0.87242407 0.91739368 0.95779877]
#   [0.99573777 0.73314079 0.95671085 0.86670792 0.92409716 0.96655799]
#   [0.99904252 0.73517147 0.96804769 0.86242588 0.92993222 0.97481601]
#   [1.         0.73353516 0.97820837 0.8597848  0.93491115 0.98238404]
#   [0.99906239 0.72811976 0.98698369 0.85878865 0.9389467  0.98913682]
#   [0.99652172 0.71902304 0.99424135 0.85954844 0.94224995 0.99499046]
#   [0.99367746 0.70699762 1.         0.86210004 0.94498828 1.        ]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 36: [[4852.0063]]
# x_pred_input of day 37:
# [[[0.99573777 0.73314079 0.95291579 0.87014445 0.92778954 0.96257738]
#   [0.99904252 0.73517147 0.96420766 0.86584543 0.93364791 0.97080139]
#   [1.         0.73353516 0.97432804 0.86319387 0.93864673 0.97833825]
#   [0.99906239 0.72811976 0.98306854 0.86219377 0.9426984  0.98506322]
#   [0.99652172 0.71902304 0.99029741 0.86295658 0.94601485 0.99089275]
#   [0.99367746 0.70699762 0.99603322 0.86551829 0.94876413 0.99588166]
#   [0.98973696 0.69227976 1.         0.87021541 0.95121397 1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 37: [[4833.243]]
# x_pred_input of day 38:
# [[[0.99904252 0.73517147 0.96223461 0.86925232 0.93735008 0.96757431]
#   [1.         0.73353516 0.97233428 0.86659033 0.94236872 0.97508611]
#   [0.99906239 0.72811976 0.9810569  0.8655863  0.94643646 0.98178873]
#   [0.99652172 0.71902304 0.98827098 0.8663521  0.94976606 0.98759888]
#   [0.99367746 0.70699762 0.99399505 0.8689239  0.95252623 0.99257121]
#   [0.98973696 0.69227976 0.99795371 0.8736395  0.95498579 0.99667586]
#   [0.98584187 0.67564233 1.         0.88061752 0.95735567 1.        ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 38: [[4813.748]]
# x_pred_input of day 39:
# [[[1.         0.73353516 0.97233428 0.87014771 0.9462673  0.97255477]
#   [0.99906239 0.72811976 0.9810569  0.86913955 0.95035187 0.97923999]
#   [0.99652172 0.71902304 0.98827098 0.8699085  0.95369524 0.98503506]
#   [0.99367746 0.70699762 0.99399505 0.87249086 0.95646683 0.98999448]
#   [0.98973696 0.69227976 0.99795371 0.87722582 0.95893656 0.99408847]
#   [0.98584187 0.67564233 1.         0.88423248 0.96131625 0.99740398]
#   [0.98179483 0.65761641 0.99993148 0.89358414 0.9636679  1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 39: [[4794.1567]]
# x_pred_input of day 40:
# [[[0.99906239 0.72811976 0.9810569  0.87273985 0.95431936 0.97734096]
#   [0.99652172 0.71902304 0.98827098 0.87351199 0.9576767  0.98312479]
#   [0.99367746 0.70699762 0.99399505 0.87610504 0.96045986 0.98807459]
#   [0.98973696 0.69227976 0.99795371 0.88085961 0.9629399  0.99216064]
#   [0.98584187 0.67564233 1.         0.8878953  0.96532952 0.99546972]
#   [0.98179483 0.65761641 0.99993148 0.8972857  0.96769099 0.99806071]
#   [0.97772783 0.63869832 0.9978164  0.90860288 0.97001505 1.        ]]]
# 1/1 [==============================] - 0s 26ms/step
# y_pred of day 40: [[4776.5557]]
# x_pred_input of day 41:
# [[[0.99652172 0.71902304 0.98827098 0.87677496 0.96128214 0.98175936]
#   [0.99367746 0.70699762 0.99399505 0.8793777  0.96407578 0.98670229]
#   [0.98973696 0.69227976 0.99795371 0.88415003 0.96656516 0.99078266]
#   [0.98584187 0.67564233 1.         0.891212   0.96896378 0.99408715]
#   [0.98179483 0.65761641 0.99993148 0.90063748 0.97133413 0.99667454]
#   [0.97772783 0.63869832 0.9978164  0.91199693 0.97366695 0.99861114]
#   [0.97407398 0.61949844 0.99440813 0.92389773 0.97603216 1.        ]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 41: [[4759.1084]]
# x_pred_input of day 42:
# [[[0.99367746 0.70699762 0.99399505 0.88264598 0.96768708 0.98581853]
#   [0.98973696 0.69227976 0.99795371 0.88743605 0.97018578 0.98989525]
#   [0.98584187 0.67564233 1.         0.89452426 0.97259338 0.99319678]
#   [0.98179483 0.65761641 0.99993148 0.90398477 0.97497262 0.99578185]
#   [0.97772783 0.63869832 0.9978164  0.91538644 0.97731417 0.99771671]
#   [0.97407398 0.61949844 0.99440813 0.92733147 0.97968824 0.99910433]
#   [0.97045207 0.60031217 0.98980472 0.93965555 0.98213003 1.        ]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 42: [[4741.041]]
# x_pred_input of day 43:
# [[[0.98973696 0.69227976 0.99795371 0.8908647  0.97396378 0.98946208]
#   [0.98584187 0.67564233 1.         0.8979803  0.97638076 0.99276216]
#   [0.98179483 0.65761641 0.99993148 0.90747736 0.97876926 0.9953461 ]
#   [0.97772783 0.63869832 0.9978164  0.91892308 0.98111993 0.99728012]
#   [0.97407398 0.61949844 0.99440813 0.93091426 0.98350325 0.99866713]
#   [0.97045207 0.60031217 0.98980472 0.94328595 0.98595455 0.99956241]
#   [0.96670142 0.58129238 0.98454245 0.95519192 0.98853235 1.        ]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 43: [[4727.212]]
# x_pred_input of day 44:
# [[[0.98584187 0.67564233 1.         0.90064371 0.97929968 0.99265212]
#   [0.98179483 0.65761641 0.99993148 0.91016894 0.98169532 0.99523577]
#   [0.97772783 0.63869832 0.9978164  0.92164861 0.98405302 0.99716957]
#   [0.97407398 0.61949844 0.99440813 0.93367535 0.98644346 0.99855643]
#   [0.97045207 0.60031217 0.98980472 0.94608374 0.98890209 0.99945161]
#   [0.96670142 0.58129238 0.98454245 0.95802502 0.9914876  0.99988915]
#   [0.96383061 0.5630491  0.97934354 0.96860884 0.99421962 1.        ]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 44: [[4712.2505]]
# x_pred_input of day 45:
# [[[0.98179483 0.65761641 0.99993148 0.91309894 0.9846098  0.99523577]
#   [0.97772783 0.63869832 0.9978164  0.92461556 0.98697449 0.99716957]
#   [0.97407398 0.61949844 0.99440813 0.93668102 0.98937203 0.99855643]
#   [0.97045207 0.60031217 0.98980472 0.94912936 0.99183796 0.99945161]
#   [0.96670142 0.58129238 0.98454245 0.96110908 0.99443114 0.99988915]
#   [0.96383061 0.5630491  0.97934354 0.97172697 0.99717127 1.        ]
#   [0.96072473 0.54550739 0.9746759  0.98046511 1.         0.99979192]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 45: [[4700.538]]
# x_pred_input of day 46:
# [[[0.97772783 0.63869832 0.9978164  0.92695158 0.984214   0.99716957]
#   [0.97407398 0.61949844 0.99440813 0.93904752 0.98660483 0.99855643]
#   [0.97045207 0.60031217 0.98980472 0.95152731 0.98906386 0.99945161]
#   [0.96670142 0.58129238 0.98454245 0.9635373  0.99164979 0.99988915]
#   [0.96383061 0.5630491  0.97934354 0.97418201 0.99438226 1.        ]
#   [0.96072473 0.54550739 0.9746759  0.98294223 0.99720307 0.99979192]
#   [0.95829333 0.52904438 0.97149361 0.98870245 1.         0.99936227]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 46: [[4687.9966]]
# x_pred_input of day 47:
# [[[0.97407398 0.61949844 0.99440813 0.94159484 0.98412898 0.99855643]
#   [0.97045207 0.60031217 0.98980472 0.95410848 0.98658184 0.99945161]
#   [0.96670142 0.58129238 0.98454245 0.96615104 0.98916128 0.99988915]
#   [0.96383061 0.5630491  0.97934354 0.97682463 0.99188689 1.        ]
#   [0.96072473 0.54550739 0.9746759  0.98560861 0.99470063 0.99979192]
#   [0.95829333 0.52904438 0.97149361 0.99138446 0.99749053 0.99936227]
#   [0.95568981 0.51353011 0.97056676 0.99312527 1.         0.99871504]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 47: [[4677.5635]]
# x_pred_input of day 48:
# [[[0.97045207 0.60031217 0.98980472 0.95626641 0.98439476 0.99945161]
#   [0.96670142 0.58129238 0.98454245 0.96833621 0.98696849 0.99988915]
#   [0.96383061 0.5630491  0.97934354 0.97903394 0.98968806 1.        ]
#   [0.96072473 0.54550739 0.9746759  0.98783779 0.99249555 0.99979192]
#   [0.95829333 0.52904438 0.97149361 0.9936267  0.99527928 0.99936227]
#   [0.95568981 0.51353011 0.97056676 0.99537145 0.99778318 0.99871504]
#   [0.95352398 0.49914954 0.9712876  0.99381659 1.         0.99791442]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 48: [[4667.3096]]
# x_pred_input of day 49:
# [[[0.96670142 0.58129238 0.98454245 0.9704935  0.98516585 0.99988915]
#   [0.96383061 0.5630491  0.97934354 0.98121507 0.98788045 1.        ]
#   [0.96072473 0.54550739 0.9746759  0.99003852 0.99068282 0.99979192]
#   [0.95829333 0.52904438 0.97149361 0.99584034 0.99346146 0.99936227]
#   [0.95568981 0.51353011 0.97056676 0.99758897 0.99596079 0.99871504]
#   [0.95352398 0.49914954 0.9712876  0.99603064 0.99817356 0.99791442]
#   [0.95139535 0.48583923 0.97242472 0.99240309 1.         0.99697871]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 49: [[4664.081]]
# x_pred_input of day 50:
# [[[0.96383061 0.5630491  0.97934354 0.98190382 0.98648243 1.        ]
#   [0.96072473 0.54550739 0.9746759  0.99073347 0.98928083 0.99979192]
#   [0.95829333 0.52904438 0.97149361 0.99653936 0.99205554 0.99936227]
#   [0.95568981 0.51353011 0.97056676 0.99828922 0.99455133 0.99871504]
#   [0.95352398 0.49914954 0.9712876  0.9967298  0.99676097 0.99791442]
#   [0.95139535 0.48583923 0.97242472 0.9930997  0.99858482 0.99697871]
#   [0.95072513 0.47423076 0.97246196 0.98929791 1.         0.99606557]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 50: [[4658.2305]]
# x_pred_input of day 51:
# [[[0.96072473 0.54550739 0.9746759  0.99199532 0.98830459 0.99979192]
#   [0.95829333 0.52904438 0.97149361 0.9978086  0.99107656 0.99936227]
#   [0.95568981 0.51353011 0.97056676 0.99956069 0.99356989 0.99871504]
#   [0.95352398 0.49914954 0.9712876  0.99799928 0.99577735 0.99791442]
#   [0.95139535 0.48583923 0.97242472 0.99436456 0.9975994  0.99697871]
#   [0.95072513 0.47423076 0.97246196 0.99055793 0.99901318 0.99606557]
#   [0.9495106  0.46382234 0.97086474 0.98744112 1.         0.99511882]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 51: [[4654.9487]]
# x_pred_input of day 52:
# [[[0.95829333 0.52904438 0.97149361 0.99824714 0.99056198 0.99936227]
#   [0.95568981 0.51353011 0.97056676 1.         0.99305401 0.99871504]
#   [0.95352398 0.49914954 0.9712876  0.99843791 0.99526032 0.99791442]
#   [0.95139535 0.48583923 0.97242472 0.99480159 0.99708143 0.99697871]
#   [0.95072513 0.47423076 0.97246196 0.99099328 0.99849448 0.99606557]
#   [0.9495106  0.46382234 0.97086474 0.98787511 0.99948078 0.99511882]
#   [0.94882933 0.45473294 0.96807491 0.98563174 1.         0.99419459]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 52: [[4647.939]]
# x_pred_input of day 53:
# [[[0.95568981 0.51353011 0.97056676 1.         0.99305401 0.99871504]
#   [0.95352398 0.49914954 0.9712876  0.99843791 0.99526032 0.99791442]
#   [0.95139535 0.48583923 0.97242472 0.99480159 0.99708143 0.99697871]
#   [0.95072513 0.47423076 0.97246196 0.99099328 0.99849448 0.99606557]
#   [0.9495106  0.46382234 0.97086474 0.98787511 0.99948078 0.99511882]
#   [0.94882933 0.45473294 0.96807491 0.98563174 1.         0.99419459]
#   [0.94737416 0.44640293 0.96444072 0.98405067 0.99995294 0.99321391]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 53: [[4637.87]]
# x_pred_input of day 54:
# [[[0.95352398 0.49914954 0.9712876  0.99843791 0.99526032 0.99791442]
#   [0.95139535 0.48583923 0.97242472 0.99480159 0.99708143 0.99697871]
#   [0.95072513 0.47423076 0.97246196 0.99099328 0.99849448 0.99606557]
#   [0.9495106  0.46382234 0.97086474 0.98787511 0.99948078 0.99511882]
#   [0.94882933 0.45473294 0.96807491 0.98563174 1.         0.99419459]
#   [0.94737416 0.44640293 0.96444072 0.98405067 0.99995294 0.99321391]
#   [0.94528395 0.43845292 0.96031466 0.98288197 0.99933074 0.9921191 ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 54: [[4622.019]]
# x_pred_input of day 55:
# [[[0.95139535 0.48583923 0.97242472 0.99480159 0.99708143 0.99697871]
#   [0.95072513 0.47423076 0.97246196 0.99099328 0.99849448 0.99606557]
#   [0.9495106  0.46382234 0.97086474 0.98787511 0.99948078 0.99511882]
#   [0.94882933 0.45473294 0.96807491 0.98563174 1.         0.99419459]
#   [0.94737416 0.44640293 0.96444072 0.98405067 0.99995294 0.99321391]
#   [0.94528395 0.43845292 0.96031466 0.98288197 0.99933074 0.9921191 ]
#   [0.94199339 0.43030554 0.95612663 0.98170178 0.99804861 0.99080186]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 55: [[4606.5605]]
# x_pred_input of day 56:
# [[[0.95072513 0.47423076 0.97246196 0.99099328 0.99849448 0.99606557]
#   [0.9495106  0.46382234 0.97086474 0.98787511 0.99948078 0.99511882]
#   [0.94882933 0.45473294 0.96807491 0.98563174 1.         0.99419459]
#   [0.94737416 0.44640293 0.96444072 0.98405067 0.99995294 0.99321391]
#   [0.94528395 0.43845292 0.96031466 0.98288197 0.99933074 0.9921191 ]
#   [0.94199339 0.43030554 0.95612663 0.98170178 0.99804861 0.99080186]
#   [0.93878432 0.42213612 0.95193544 0.98048673 0.99614968 0.98929146]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 56: [[4585.806]]
# x_pred_input of day 57:
# [[[0.9495106  0.46382234 0.97086474 0.98787511 0.99948078 0.99511882]
#   [0.94882933 0.45473294 0.96807491 0.98563174 1.         0.99419459]
#   [0.94737416 0.44640293 0.96444072 0.98405067 0.99995294 0.99321391]
#   [0.94528395 0.43845292 0.96031466 0.98288197 0.99933074 0.9921191 ]
#   [0.94199339 0.43030554 0.95612663 0.98170178 0.99804861 0.99080186]
#   [0.93878432 0.42213612 0.95193544 0.98048673 0.99614968 0.98929146]
#   [0.93447587 0.41350608 0.94816717 0.97877457 0.99371878 0.98749715]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 57: [[4563.598]]
# x_pred_input of day 58:
# [[[0.94882933 0.45473294 0.96807491 0.98563174 1.         0.99419459]
#   [0.94737416 0.44640293 0.96444072 0.98405067 0.99995294 0.99321391]
#   [0.94528395 0.43845292 0.96031466 0.98288197 0.99933074 0.9921191 ]
#   [0.94199339 0.43030554 0.95612663 0.98170178 0.99804861 0.99080186]
#   [0.93878432 0.42213612 0.95193544 0.98048673 0.99614968 0.98929146]
#   [0.93447587 0.41350608 0.94816717 0.97877457 0.99371878 0.98749715]
#   [0.92986566 0.40446627 0.94490188 0.97644207 0.99097381 0.985416  ]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 58: [[4543.1675]]
# x_pred_input of day 59:
# [[[0.94737416 0.44640293 0.96444072 0.98405067 0.99995294 0.99321391]
#   [0.94528395 0.43845292 0.96031466 0.98288197 0.99933074 0.9921191 ]
#   [0.94199339 0.43030554 0.95612663 0.98170178 0.99804861 0.99080186]
#   [0.93878432 0.42213612 0.95193544 0.98048673 0.99614968 0.98929146]
#   [0.93447587 0.41350608 0.94816717 0.97877457 0.99371878 0.98749715]
#   [0.92986566 0.40446627 0.94490188 0.97644207 0.99097381 0.985416  ]
#   [0.92562442 0.39538847 0.94215941 0.97352236 0.98802255 0.98311197]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 59: [[4516.5156]]
# x_pred_input of day 60:
# [[[0.94528395 0.43845292 0.96031466 0.98288197 0.99933074 0.9921191 ]
#   [0.94199339 0.43030554 0.95612663 0.98170178 0.99804861 0.99080186]
#   [0.93878432 0.42213612 0.95193544 0.98048673 0.99614968 0.98929146]
#   [0.93447587 0.41350608 0.94816717 0.97877457 0.99371878 0.98749715]
#   [0.92986566 0.40446627 0.94490188 0.97644207 0.99097381 0.985416  ]
#   [0.92562442 0.39538847 0.94215941 0.97352236 0.98802255 0.98311197]
#   [0.9200917  0.38575416 0.94014294 0.96966176 0.98488895 0.98047806]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 60: [[4491.3184]]
# x_pred_input of day 61:
# [[[0.94199339 0.43030554 0.95612663 0.98170178 0.99804861 0.99080186]
#   [0.93878432 0.42213612 0.95193544 0.98048673 0.99614968 0.98929146]
#   [0.93447587 0.41350608 0.94816717 0.97877457 0.99371878 0.98749715]
#   [0.92986566 0.40446627 0.94490188 0.97644207 0.99097381 0.985416  ]
#   [0.92562442 0.39538847 0.94215941 0.97352236 0.98802255 0.98311197]
#   [0.9200917  0.38575416 0.94014294 0.96966176 0.98488895 0.98047806]
#   [0.91486094 0.375941   0.93865552 0.96506216 0.98164861 0.97757566]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 61: [[4463.313]]
# x_pred_input of day 62:
# [[[0.93878432 0.42213612 0.95193544 0.98048673 0.99614968 0.98929146]
#   [0.93447587 0.41350608 0.94816717 0.97877457 0.99371878 0.98749715]
#   [0.92986566 0.40446627 0.94490188 0.97644207 0.99097381 0.985416  ]
#   [0.92562442 0.39538847 0.94215941 0.97352236 0.98802255 0.98311197]
#   [0.9200917  0.38575416 0.94014294 0.96966176 0.98488895 0.98047806]
#   [0.91486094 0.375941   0.93865552 0.96506216 0.98164861 0.97757566]
#   [0.90904725 0.36581508 0.93770648 0.9596489  0.97829044 0.97437247]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 62: [[4441.208]]
# x_pred_input of day 63:
# [[[0.93447587 0.41350608 0.94816717 0.97877457 0.99371878 0.98749715]
#   [0.92986566 0.40446627 0.94490188 0.97644207 0.99097381 0.985416  ]
#   [0.92562442 0.39538847 0.94215941 0.97352236 0.98802255 0.98311197]
#   [0.9200917  0.38575416 0.94014294 0.96966176 0.98488895 0.98047806]
#   [0.91486094 0.375941   0.93865552 0.96506216 0.98164861 0.97757566]
#   [0.90904725 0.36581508 0.93770648 0.9596489  0.97829044 0.97437247]
#   [0.90445842 0.3561572  0.93701237 0.95387133 0.97490655 0.97101876]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 63: [[4414.7334]]
# x_pred_input of day 64:
# [[[0.92986566 0.40446627 0.94490188 0.97644207 0.99097381 0.985416  ]
#   [0.92562442 0.39538847 0.94215941 0.97352236 0.98802255 0.98311197]
#   [0.9200917  0.38575416 0.94014294 0.96966176 0.98488895 0.98047806]
#   [0.91486094 0.375941   0.93865552 0.96506216 0.98164861 0.97757566]
#   [0.90904725 0.36581508 0.93770648 0.9596489  0.97829044 0.97437247]
#   [0.90445842 0.3561572  0.93701237 0.95387133 0.97490655 0.97101876]
#   [0.8989625  0.34653346 0.93648485 0.94763772 0.97145913 0.96743878]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 64: [[4387.902]]
# x_pred_input of day 65:
# [[[0.92562442 0.39538847 0.94215941 0.97352236 0.98802255 0.98311197]
#   [0.9200917  0.38575416 0.94014294 0.96966176 0.98488895 0.98047806]
#   [0.91486094 0.375941   0.93865552 0.96506216 0.98164861 0.97757566]
#   [0.90904725 0.36581508 0.93770648 0.9596489  0.97829044 0.97437247]
#   [0.90445842 0.3561572  0.93701237 0.95387133 0.97490655 0.97101876]
#   [0.8989625  0.34653346 0.93648485 0.94763772 0.97145913 0.96743878]
#   [0.89339248 0.33700998 0.93610242 0.94098831 0.96795128 0.96364674]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 65: [[4361.643]]
# x_pred_input of day 66:
# [[[0.9200917  0.38575416 0.94014294 0.96966176 0.98488895 0.98047806]
#   [0.91486094 0.375941   0.93865552 0.96506216 0.98164861 0.97757566]
#   [0.90904725 0.36581508 0.93770648 0.9596489  0.97829044 0.97437247]
#   [0.90445842 0.3561572  0.93701237 0.95387133 0.97490655 0.97101876]
#   [0.8989625  0.34653346 0.93648485 0.94763772 0.97145913 0.96743878]
#   [0.89339248 0.33700998 0.93610242 0.94098831 0.96795128 0.96364674]
#   [0.88794136 0.3277316  0.93565783 0.93408947 0.96438851 0.95967464]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 66: [[4337.452]]
# x_pred_input of day 67:
# [[[0.91486094 0.375941   0.93865552 0.96506216 0.98164861 0.97757566]
#   [0.90904725 0.36581508 0.93770648 0.9596489  0.97829044 0.97437247]
#   [0.90445842 0.3561572  0.93701237 0.95387133 0.97490655 0.97101876]
#   [0.8989625  0.34653346 0.93648485 0.94763772 0.97145913 0.96743878]
#   [0.89339248 0.33700998 0.93610242 0.94098831 0.96795128 0.96364674]
#   [0.88794136 0.3277316  0.93565783 0.93408947 0.96438851 0.95967464]
#   [0.88291952 0.31896046 0.93506915 0.92709313 0.96077146 0.95558224]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 67: [[4312.716]]
# x_pred_input of day 68:
# [[[0.90904725 0.36581508 0.93770648 0.9596489  0.97829044 0.97437247]
#   [0.90445842 0.3561572  0.93701237 0.95387133 0.97490655 0.97101876]
#   [0.8989625  0.34653346 0.93648485 0.94763772 0.97145913 0.96743878]
#   [0.89339248 0.33700998 0.93610242 0.94098831 0.96795128 0.96364674]
#   [0.88794136 0.3277316  0.93565783 0.93408947 0.96438851 0.95967464]
#   [0.88291952 0.31896046 0.93506915 0.92709313 0.96077146 0.95558224]
#   [0.87778445 0.31063142 0.93424808 0.92003724 0.95709436 0.95136976]]]
# 1/1 [==============================] - 0s 40ms/step
# y_pred of day 68: [[4289.89]]
# x_pred_input of day 69:
# [[[0.90445842 0.3561572  0.93701237 0.95387133 0.97490655 0.97101876]
#   [0.8989625  0.34653346 0.93648485 0.94763772 0.97145913 0.96743878]
#   [0.89339248 0.33700998 0.93610242 0.94098831 0.96795128 0.96364674]
#   [0.88794136 0.3277316  0.93565783 0.93408947 0.96438851 0.95967464]
#   [0.88291952 0.31896046 0.93506915 0.92709313 0.96077146 0.95558224]
#   [0.87778445 0.31063142 0.93424808 0.92003724 0.95709436 0.95136976]
#   [0.87304601 0.30293724 0.93310496 0.9130567  0.95337807 0.94708802]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 69: [[4268.4434]]
# x_pred_input of day 70:
# [[[0.8989625  0.34653346 0.93648485 0.94763772 0.97145913 0.96743878]
#   [0.89339248 0.33700998 0.93610242 0.94098831 0.96795128 0.96364674]
#   [0.88794136 0.3277316  0.93565783 0.93408947 0.96438851 0.95967464]
#   [0.88291952 0.31896046 0.93506915 0.92709313 0.96077146 0.95558224]
#   [0.87778445 0.31063142 0.93424808 0.92003724 0.95709436 0.95136976]
#   [0.87304601 0.30293724 0.93310496 0.9130567  0.95337807 0.94708802]
#   [0.86859383 0.29596779 0.9313249  0.90636993 0.94959903 0.94277203]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 70: [[4244.998]]
# x_pred_input of day 71:
# [[[0.89339248 0.33700998 0.93610242 0.94098831 0.96795128 0.96364674]
#   [0.88794136 0.3277316  0.93565783 0.93408947 0.96438851 0.95967464]
#   [0.88291952 0.31896046 0.93506915 0.92709313 0.96077146 0.95558224]
#   [0.87778445 0.31063142 0.93424808 0.92003724 0.95709436 0.95136976]
#   [0.87304601 0.30293724 0.93310496 0.9130567  0.95337807 0.94708802]
#   [0.86859383 0.29596779 0.9313249  0.90636993 0.94959903 0.94277203]
#   [0.86372677 0.28944314 0.92901722 0.89987199 0.9457501  0.93838387]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 71: [[4227.1865]]
# x_pred_input of day 72:
# [[[0.88794136 0.3277316  0.93565783 0.93408947 0.96438851 0.95967464]
#   [0.88291952 0.31896046 0.93506915 0.92709313 0.96077146 0.95558224]
#   [0.87778445 0.31063142 0.93424808 0.92003724 0.95709436 0.95136976]
#   [0.87304601 0.30293724 0.93310496 0.9130567  0.95337807 0.94708802]
#   [0.86859383 0.29596779 0.9313249  0.90636993 0.94959903 0.94277203]
#   [0.86372677 0.28944314 0.92901722 0.89987199 0.9457501  0.93838387]
#   [0.86002923 0.28391202 0.9258899  0.89394624 0.94185093 0.93404652]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 72: [[4206.099]]
# x_pred_input of day 73:
# [[[0.88291952 0.31896046 0.93506915 0.92709313 0.96077146 0.95558224]
#   [0.87778445 0.31063142 0.93424808 0.92003724 0.95709436 0.95136976]
#   [0.87304601 0.30293724 0.93310496 0.9130567  0.95337807 0.94708802]
#   [0.86859383 0.29596779 0.9313249  0.90636993 0.94959903 0.94277203]
#   [0.86372677 0.28944314 0.92901722 0.89987199 0.9457501  0.93838387]
#   [0.86002923 0.28391202 0.9258899  0.89394624 0.94185093 0.93404652]
#   [0.85565165 0.2788905  0.92212776 0.88840215 0.93788137 0.92968762]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 73: [[4188.848]]
# x_pred_input of day 74:
# [[[0.87778445 0.31063142 0.93424808 0.92003724 0.95709436 0.95136976]
#   [0.87304601 0.30293724 0.93310496 0.9130567  0.95337807 0.94708802]
#   [0.86859383 0.29596779 0.9313249  0.90636993 0.94959903 0.94277203]
#   [0.86372677 0.28944314 0.92901722 0.89987199 0.9457501  0.93838387]
#   [0.86002923 0.28391202 0.9258899  0.89394624 0.94185093 0.93404652]
#   [0.85565165 0.2788905  0.92212776 0.88840215 0.93788137 0.92968762]
#   [0.85207048 0.27471408 0.91772104 0.88340048 0.93385564 0.92538831]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 74: [[4170.6265]]
# x_pred_input of day 75:
# [[[0.87304601 0.30293724 0.93310496 0.9130567  0.95337807 0.94708802]
#   [0.86859383 0.29596779 0.9313249  0.90636993 0.94959903 0.94277203]
#   [0.86372677 0.28944314 0.92901722 0.89987199 0.9457501  0.93838387]
#   [0.86002923 0.28391202 0.9258899  0.89394624 0.94185093 0.93404652]
#   [0.85565165 0.2788905  0.92212776 0.88840215 0.93788137 0.92968762]
#   [0.85207048 0.27471408 0.91772104 0.88340048 0.93385564 0.92538831]
#   [0.8482878  0.27114904 0.91292085 0.87877375 0.92976428 0.92112289]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 75: [[4152.9395]]
# x_pred_input of day 76:
# [[[0.86859383 0.29596779 0.9313249  0.90636993 0.94959903 0.94277203]
#   [0.86372677 0.28944314 0.92901722 0.89987199 0.9457501  0.93838387]
#   [0.86002923 0.28391202 0.9258899  0.89394624 0.94185093 0.93404652]
#   [0.85565165 0.2788905  0.92212776 0.88840215 0.93788137 0.92968762]
#   [0.85207048 0.27471408 0.91772104 0.88340048 0.93385564 0.92538831]
#   [0.8482878  0.27114904 0.91292085 0.87877375 0.92976428 0.92112289]
#   [0.84461612 0.26815779 0.90767972 0.87457656 0.92555383 0.91689916]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 76: [[4134.4004]]
# x_pred_input of day 77:
# [[[0.86372677 0.28944314 0.92901722 0.89987199 0.9457501  0.93838387]
#   [0.86002923 0.28391202 0.9258899  0.89394624 0.94185093 0.93404652]
#   [0.85565165 0.2788905  0.92212776 0.88840215 0.93788137 0.92968762]
#   [0.85207048 0.27471408 0.91772104 0.88340048 0.93385564 0.92538831]
#   [0.8482878  0.27114904 0.91292085 0.87877375 0.92976428 0.92112289]
#   [0.84461612 0.26815779 0.90767972 0.87457656 0.92555383 0.91689916]
#   [0.84076755 0.26556387 0.90224829 0.87063392 0.92123885 0.91269559]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 77: [[4116.2017]]
# x_pred_input of day 78:
# [[[0.86002923 0.28391202 0.9258899  0.89394624 0.94185093 0.93404652]
#   [0.85565165 0.2788905  0.92212776 0.88840215 0.93788137 0.92968762]
#   [0.85207048 0.27471408 0.91772104 0.88340048 0.93385564 0.92538831]
#   [0.8482878  0.27114904 0.91292085 0.87877375 0.92976428 0.92112289]
#   [0.84461612 0.26815779 0.90767972 0.87457656 0.92555383 0.91689916]
#   [0.84076755 0.26556387 0.90224829 0.87063392 0.92123885 0.91269559]
#   [0.83698964 0.26334528 0.89669082 0.86691526 0.91680099 0.90851727]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 78: [[4094.1843]]
# x_pred_input of day 79:
# [[[0.85565165 0.2788905  0.92212776 0.88840215 0.93788137 0.92968762]
#   [0.85207048 0.27471408 0.91772104 0.88340048 0.93385564 0.92538831]
#   [0.8482878  0.27114904 0.91292085 0.87877375 0.92976428 0.92112289]
#   [0.84461612 0.26815779 0.90767972 0.87457656 0.92555383 0.91689916]
#   [0.84076755 0.26556387 0.90224829 0.87063392 0.92123885 0.91269559]
#   [0.83698964 0.26334528 0.89669082 0.86691526 0.91680099 0.90851727]
#   [0.83241901 0.26105923 0.89100641 0.86329966 0.91223952 0.9042831 ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 79: [[4075.608]]
# x_pred_input of day 80:
# [[[0.85207048 0.27471408 0.91772104 0.88340048 0.93385564 0.92538831]
#   [0.8482878  0.27114904 0.91292085 0.87877375 0.92976428 0.92112289]
#   [0.84461612 0.26815779 0.90767972 0.87457656 0.92555383 0.91689916]
#   [0.84076755 0.26556387 0.90224829 0.87063392 0.92123885 0.91269559]
#   [0.83698964 0.26334528 0.89669082 0.86691526 0.91680099 0.90851727]
#   [0.83241901 0.26105923 0.89100641 0.86329966 0.91223952 0.9042831 ]
#   [0.82856269 0.25909493 0.88542485 0.85974843 0.90760796 0.90006931]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 80: [[4052.609]]
# x_pred_input of day 81:
# [[[0.8482878  0.27114904 0.91292085 0.87877375 0.92976428 0.92112289]
#   [0.84461612 0.26815779 0.90767972 0.87457656 0.92555383 0.91689916]
#   [0.84076755 0.26556387 0.90224829 0.87063392 0.92123885 0.91269559]
#   [0.83698964 0.26334528 0.89669082 0.86691526 0.91680099 0.90851727]
#   [0.83241901 0.26105923 0.89100641 0.86329966 0.91223952 0.9042831 ]
#   [0.82856269 0.25909493 0.88542485 0.85974843 0.90760796 0.90006931]
#   [0.82378827 0.2569571  0.88000056 0.85607457 0.90291752 0.8957828 ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 81: [[4028.6277]]
# x_pred_input of day 82:
# [[[0.84461612 0.26815779 0.90767972 0.87457656 0.92555383 0.91689916]
#   [0.84076755 0.26556387 0.90224829 0.87063392 0.92123885 0.91269559]
#   [0.83698964 0.26334528 0.89669082 0.86691526 0.91680099 0.90851727]
#   [0.83241901 0.26105923 0.89100641 0.86329966 0.91223952 0.9042831 ]
#   [0.82856269 0.25909493 0.88542485 0.85974843 0.90760796 0.90006931]
#   [0.82378827 0.2569571  0.88000056 0.85607457 0.90291752 0.8957828 ]
#   [0.81880996 0.25460819 0.87491449 0.85212167 0.89815688 0.89141027]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 82: [[4003.5994]]
# x_pred_input of day 83:
# [[[0.84076755 0.26556387 0.90224829 0.87063392 0.92123885 0.91269559]
#   [0.83698964 0.26334528 0.89669082 0.86691526 0.91680099 0.90851727]
#   [0.83241901 0.26105923 0.89100641 0.86329966 0.91223952 0.9042831 ]
#   [0.82856269 0.25909493 0.88542485 0.85974843 0.90760796 0.90006931]
#   [0.82378827 0.2569571  0.88000056 0.85607457 0.90291752 0.8957828 ]
#   [0.81880996 0.25460819 0.87491449 0.85212167 0.89815688 0.89141027]
#   [0.81361428 0.25201461 0.86991658 0.84800952 0.89336103 0.88693832]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 83: [[3978.093]]
# x_pred_input of day 84:
# [[[0.83698964 0.26334528 0.89669082 0.86691526 0.91680099 0.90851727]
#   [0.83241901 0.26105923 0.89100641 0.86329966 0.91223952 0.9042831 ]
#   [0.82856269 0.25909493 0.88542485 0.85974843 0.90760796 0.90006931]
#   [0.82378827 0.2569571  0.88000056 0.85607457 0.90291752 0.8957828 ]
#   [0.81880996 0.25460819 0.87491449 0.85212167 0.89815688 0.89141027]
#   [0.81361428 0.25201461 0.86991658 0.84800952 0.89336103 0.88693832]
#   [0.80831936 0.24921047 0.86523665 0.8435737  0.88853802 0.88236657]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 84: [[3953.1096]]
# x_pred_input of day 85:
# [[[0.83241901 0.26105923 0.89100641 0.86329966 0.91223952 0.9042831 ]
#   [0.82856269 0.25909493 0.88542485 0.85974843 0.90760796 0.90006931]
#   [0.82378827 0.2569571  0.88000056 0.85607457 0.90291752 0.8957828 ]
#   [0.81880996 0.25460819 0.87491449 0.85212167 0.89815688 0.89141027]
#   [0.81361428 0.25201461 0.86991658 0.84800952 0.89336103 0.88693832]
#   [0.80831936 0.24921047 0.86523665 0.8435737  0.88853802 0.88236657]
#   [0.803133   0.24632628 0.86088673 0.83882036 0.8836775  0.8777153 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 85: [[3929.7449]]
# x_pred_input of day 86:
# [[[0.82856269 0.25909493 0.88542485 0.85974843 0.90760796 0.90006931]
#   [0.82378827 0.2569571  0.88000056 0.85607457 0.90291752 0.8957828 ]
#   [0.81880996 0.25460819 0.87491449 0.85212167 0.89815688 0.89141027]
#   [0.81361428 0.25201461 0.86991658 0.84800952 0.89336103 0.88693832]
#   [0.80831936 0.24921047 0.86523665 0.8435737  0.88853802 0.88236657]
#   [0.803133   0.24632628 0.86088673 0.83882036 0.8836775  0.8777153 ]
#   [0.79828266 0.24357621 0.85680078 0.83384385 0.87884405 0.87302544]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 86: [[3905.0745]]
# x_pred_input of day 87:
# [[[0.82378827 0.2569571  0.88000056 0.85607457 0.90291752 0.8957828 ]
#   [0.81880996 0.25460819 0.87491449 0.85212167 0.89815688 0.89141027]
#   [0.81361428 0.25201461 0.86991658 0.84800952 0.89336103 0.88693832]
#   [0.80831936 0.24921047 0.86523665 0.8435737  0.88853802 0.88236657]
#   [0.803133   0.24632628 0.86088673 0.83882036 0.8836775  0.8777153 ]
#   [0.79828266 0.24357621 0.85680078 0.83384385 0.87884405 0.87302544]
#   [0.79316128 0.24083031 0.85291827 0.82863634 0.87401495 0.86827377]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 87: [[3875.9404]]
# x_pred_input of day 88:
# [[[0.81880996 0.25460819 0.87491449 0.85212167 0.89815688 0.89141027]
#   [0.81361428 0.25201461 0.86991658 0.84800952 0.89336103 0.88693832]
#   [0.80831936 0.24921047 0.86523665 0.8435737  0.88853802 0.88236657]
#   [0.803133   0.24632628 0.86088673 0.83882036 0.8836775  0.8777153 ]
#   [0.79828266 0.24357621 0.85680078 0.83384385 0.87884405 0.87302544]
#   [0.79316128 0.24083031 0.85291827 0.82863634 0.87401495 0.86827377]
#   [0.78711328 0.23766681 0.84937588 0.8229643  0.86917655 0.86337416]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 88: [[3850.5327]]
# x_pred_input of day 89:
# [[[0.81361428 0.25201461 0.86991658 0.84800952 0.89336103 0.88693832]
#   [0.80831936 0.24921047 0.86523665 0.8435737  0.88853802 0.88236657]
#   [0.803133   0.24632628 0.86088673 0.83882036 0.8836775  0.8777153 ]
#   [0.79828266 0.24357621 0.85680078 0.83384385 0.87884405 0.87302544]
#   [0.79316128 0.24083031 0.85291827 0.82863634 0.87401495 0.86827377]
#   [0.78711328 0.23766681 0.84937588 0.8229643  0.86917655 0.86337416]
#   [0.78183884 0.23458965 0.84595917 0.81709976 0.86431095 0.85841752]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 89: [[3824.1606]]
# x_pred_input of day 90:
# [[[0.80831936 0.24921047 0.86523665 0.8435737  0.88853802 0.88236657]
#   [0.803133   0.24632628 0.86088673 0.83882036 0.8836775  0.8777153 ]
#   [0.79828266 0.24357621 0.85680078 0.83384385 0.87884405 0.87302544]
#   [0.79316128 0.24083031 0.85291827 0.82863634 0.87401495 0.86827377]
#   [0.78711328 0.23766681 0.84937588 0.8229643  0.86917655 0.86337416]
#   [0.78183884 0.23458965 0.84595917 0.81709976 0.86431095 0.85841752]
#   [0.7763642  0.23151751 0.8426155  0.81104877 0.85944619 0.85338939]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 90: [[3800.9973]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#             Close        MACD  Bollinger_Upper  Bollinger_Lower         MA26  \
# 0      227.181000    0.000000      3800.997314      3800.997314  3800.997314
# 1      220.488998   -0.533835      3800.997314      3800.997314  3800.997314
# 2      222.218002   -0.808072      3800.997314      3800.997314  3800.997314
# 3      227.600998   -0.584308      3800.997314      3800.997314  3800.997314
# 4      225.119995   -0.600251      3800.997314      3800.997314  3800.997314
# ...           ...         ...              ...              ...          ...
# 2063  3905.074463 -133.994024      4363.911224      3869.388703  4182.278874
# 2064  3875.940430 -136.485337      4346.277104      3843.345283  4159.687622
# 2065  3850.532715 -138.908659      4329.268619      3816.418027  4136.969342
# 2066  3824.160645 -141.328023      4312.623772      3788.634602  4114.255005
# 2067  3800.997314 -143.460747      4296.256867      3760.601434  4091.681753
#
#             EMA20
# 0      227.181000
# 1      226.543666
# 2      226.131698
# 3      226.271632
# 4      226.161952
# ...           ...
# 2063  4113.662586
# 2064  4091.022381
# 2065  4068.118603
# 2066  4044.884512
# 2067  4021.657160
#
# [2068 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
# Dateframe of Close training set
df_train = df_filtered['Close'][:train_size].copy()

# Plot the forecast for df_val, df_test and df_forecast
plt.figure(figsize=(15, 7))
plt.plot(df_train, label='Train')
plt.plot(df_test['Y_test_pred'], label='Test prediction')
plt.plot(df_test['Y_test'], label='Test')
plt.plot(df_forecast_unscale['Close'], label='Forecast next 30 days')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  169.19437123213334
# MAPE:  8.527199896546218
# SMAPE:  8.141745675998676
