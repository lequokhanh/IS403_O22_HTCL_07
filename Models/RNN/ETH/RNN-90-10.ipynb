# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../../Dataset/ETH-USD.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 1  2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2  2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 3  2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 4  2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#        Volume
# 0  1868519936
# 1  1894419968
# 2  1699369984
# 3  1697939968
# 4  1898489984

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#                 Volume
# Date
# 2018-03-01  1868519936
# 2018-03-02  1894419968
# 2018-03-03  1699369984
# 2018-03-04  1697939968
# 2018-03-05  1898489984

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('ETH/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (2070, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.90)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1863, 6) (207, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1856, 7, 6) (1856,)
# (200, 7, 6) (200,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1856, 7, 6) (1856,)
# (200, 7, 6) (200,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
# model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
# model.add(Dense(1))
model.add(SimpleRNN(n_neurons, return_sequences=True,
          input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(SimpleRNN(n_neurons, return_sequences=True))
model.add(SimpleRNN(n_neurons))
model.add(Dense(1))


# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1825 - val_loss: 0.0031
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3921e-04 - val_loss: 0.0013
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4689e-04 - val_loss: 0.0013
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6392e-04 - val_loss: 0.0012
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0038e-04 - val_loss: 0.0011
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6745e-04 - val_loss: 0.0012
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6101e-04 - val_loss: 9.0364e-04
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1585e-04 - val_loss: 0.0011
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0429e-04 - val_loss: 9.3732e-04
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5000e-04 - val_loss: 0.0010
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9763e-04 - val_loss: 0.0012
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6954e-04 - val_loss: 7.6578e-04
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8733e-04 - val_loss: 7.9031e-04
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8156e-04 - val_loss: 7.8253e-04
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5876e-04 - val_loss: 0.0017
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5767e-04 - val_loss: 9.3583e-04
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1065e-04 - val_loss: 7.6040e-04
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9340e-04 - val_loss: 6.9503e-04
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3382e-04 - val_loss: 7.4850e-04
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9411e-04 - val_loss: 6.9999e-04
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1251e-04 - val_loss: 7.6018e-04
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8676e-04 - val_loss: 7.5038e-04
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0039e-04 - val_loss: 6.6258e-04
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8810e-04 - val_loss: 9.8655e-04
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3910e-04 - val_loss: 6.2117e-04
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2603e-04 - val_loss: 0.0014
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7166e-04 - val_loss: 6.4826e-04
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1158e-04 - val_loss: 6.4172e-04
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2364e-04 - val_loss: 6.0278e-04
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4229e-04 - val_loss: 7.2000e-04
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7567e-04 - val_loss: 8.9194e-04
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6690e-04 - val_loss: 6.9735e-04
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4550e-04 - val_loss: 7.1372e-04
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7514e-04 - val_loss: 5.8392e-04
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0924e-04 - val_loss: 5.8081e-04
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7226e-04 - val_loss: 0.0010
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6778e-04 - val_loss: 6.3491e-04
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1991e-04 - val_loss: 5.8496e-04
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1118e-04 - val_loss: 7.3207e-04
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1259e-04 - val_loss: 8.2342e-04
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0979e-04 - val_loss: 6.7933e-04
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1238e-04 - val_loss: 5.5061e-04
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8909e-04 - val_loss: 5.3167e-04
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9590e-04 - val_loss: 6.2454e-04
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2359e-04 - val_loss: 6.1602e-04
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8387e-04 - val_loss: 0.0015
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5757e-04 - val_loss: 5.9259e-04
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7232e-04 - val_loss: 5.2549e-04
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7714e-04 - val_loss: 8.0536e-04
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2756e-04 - val_loss: 6.2400e-04
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8168e-04 - val_loss: 5.1902e-04
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7302e-04 - val_loss: 5.3050e-04
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1489e-04 - val_loss: 5.2466e-04
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7056e-04 - val_loss: 0.0012
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5990e-04 - val_loss: 5.6901e-04
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6941e-04 - val_loss: 5.7086e-04
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4943e-04 - val_loss: 5.0440e-04
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0250e-04 - val_loss: 7.6284e-04
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6237e-04 - val_loss: 5.1850e-04
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3492e-04 - val_loss: 5.0439e-04
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8781e-04 - val_loss: 5.0800e-04
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3983e-04 - val_loss: 6.4858e-04
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0363e-04 - val_loss: 6.1884e-04
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4744e-04 - val_loss: 5.9540e-04
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7943e-04 - val_loss: 5.1530e-04
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5690e-04 - val_loss: 7.0899e-04
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0038e-04 - val_loss: 5.1797e-04
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9041e-04 - val_loss: 5.5929e-04
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9861e-04 - val_loss: 5.2599e-04
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9909e-04 - val_loss: 5.0859e-04
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0236e-04 - val_loss: 5.8007e-04
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3269e-04 - val_loss: 4.8716e-04
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2355e-04 - val_loss: 4.8862e-04
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4301e-04 - val_loss: 5.2500e-04
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2354e-04 - val_loss: 6.8418e-04
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3090e-04 - val_loss: 7.2274e-04
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7457e-04 - val_loss: 5.2193e-04
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2541e-04 - val_loss: 5.7183e-04
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8241e-04 - val_loss: 0.0011
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5846e-04 - val_loss: 5.7055e-04
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2224e-04 - val_loss: 5.0003e-04
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4445e-04 - val_loss: 4.7948e-04
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3132e-04 - val_loss: 5.8222e-04
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5608e-04 - val_loss: 4.8523e-04
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3541e-04 - val_loss: 0.0011
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2810e-04 - val_loss: 5.2567e-04
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6711e-04 - val_loss: 5.0695e-04
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4703e-04 - val_loss: 5.2460e-04
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2250e-04 - val_loss: 5.2752e-04
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4374e-04 - val_loss: 6.3627e-04
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0267e-04 - val_loss: 6.1808e-04
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5105e-04 - val_loss: 5.9541e-04
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4167e-04 - val_loss: 5.7720e-04
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8216e-04 - val_loss: 4.8982e-04
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5339e-04 - val_loss: 7.0132e-04
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9597e-04 - val_loss: 6.9862e-04

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (207, 7, 6)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.79140524 0.65029013 0.80801116 0.58957954 0.713215   0.7523103 ]
#   [0.80538842 0.66965243 0.82563172 0.59043785 0.72134724 0.76292399]
#   [0.79444237 0.67662558 0.83854701 0.59633976 0.72886102 0.77140374]
#   [0.778143   0.67121779 0.84751084 0.6034821  0.73467792 0.77740352]
#   [0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247713]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735351]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291943]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 1: [[3719.7104]]
# x_pred_input of day 2:
# [[[0.80538842 0.66965243 0.82563172 0.59043785 0.72134724 0.76292403]
#   [0.79444237 0.67662558 0.83854701 0.59633976 0.72886102 0.77140378]
#   [0.778143   0.67121779 0.84751084 0.6034821  0.73467792 0.77740356]
#   [0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247717]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.76894501 0.63496346 0.85915608 0.67080861 0.7586248  0.79592639]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 2: [[3646.9546]]
# x_pred_input of day 3:
# [[[0.79444237 0.67662558 0.83854701 0.59633976 0.72886102 0.77140378]
#   [0.778143   0.67121779 0.84751084 0.6034821  0.73467792 0.77740356]
#   [0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247717]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.76894501 0.63496346 0.85915608 0.67080861 0.7586248  0.79592639]
#   [0.753556   0.61306372 0.85217787 0.697521   0.76456199 0.79706796]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 3: [[3561.5771]]
# x_pred_input of day 4:
# [[[0.778143   0.67121779 0.84751084 0.6034821  0.73467792 0.77740356]
#   [0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247717]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.76894501 0.63496346 0.85915608 0.67080861 0.7586248  0.79592639]
#   [0.753556   0.61306372 0.85217787 0.697521   0.76456199 0.79706796]
#   [0.73549732 0.58490629 0.8464671  0.71690563 0.7691964  0.79624792]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 4: [[3476.3862]]
# x_pred_input of day 5:
# [[[0.77468537 0.66239613 0.85290614 0.61745814 0.7402269  0.78247717]
#   [0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.76894501 0.63496346 0.85915608 0.67080861 0.7586248  0.79592639]
#   [0.753556   0.61306372 0.85217787 0.697521   0.76456199 0.79706796]
#   [0.73549732 0.58490629 0.8464671  0.71690563 0.7691964  0.79624792]
#   [0.71747809 0.55218611 0.83437454 0.74391295 0.77419268 0.79365714]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 5: [[3395.0276]]
# x_pred_input of day 6:
# [[[0.77747252 0.65402732 0.85668314 0.63360116 0.74571861 0.78735354]
#   [0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.76894501 0.63496346 0.85915608 0.67080861 0.7586248  0.79592639]
#   [0.753556   0.61306372 0.85217787 0.697521   0.76456199 0.79706796]
#   [0.73549732 0.58490629 0.8464671  0.71690563 0.7691964  0.79624792]
#   [0.71747809 0.55218611 0.83437454 0.74391295 0.77419268 0.79365714]
#   [0.70026945 0.51665694 0.82644019 0.76047842 0.77845557 0.78954743]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 6: [[3329.618]]
# x_pred_input of day 7:
# [[[0.78871931 0.65020925 0.86003398 0.65111638 0.75233632 0.79291947]
#   [0.76894501 0.63496346 0.85915608 0.67080861 0.7586248  0.79592639]
#   [0.753556   0.61306372 0.85217787 0.697521   0.76456199 0.79706796]
#   [0.73549732 0.58490629 0.8464671  0.71690563 0.7691964  0.79624792]
#   [0.71747809 0.55218611 0.83437454 0.74391295 0.77419268 0.79365714]
#   [0.70026945 0.51665694 0.82644019 0.76047842 0.77845557 0.78954743]
#   [0.68643428 0.48096705 0.81947854 0.77362343 0.78199089 0.78440958]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 7: [[3268.4773]]
# x_pred_input of day 8:
# [[[0.76894501 0.63496346 0.85915608 0.67080861 0.7586248  0.79592639]
#   [0.753556   0.61306372 0.85217787 0.697521   0.76456199 0.79706796]
#   [0.73549732 0.58490629 0.8464671  0.71690563 0.7691964  0.79624792]
#   [0.71747809 0.55218611 0.83437454 0.74391295 0.77419268 0.79365714]
#   [0.70026945 0.51665694 0.82644019 0.76047842 0.77845557 0.78954743]
#   [0.68643428 0.48096705 0.81947854 0.77362343 0.78199089 0.78440958]
#   [0.67350207 0.44599567 0.8102369  0.78919031 0.78480489 0.77843416]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 8: [[3215.56]]
# x_pred_input of day 9:
# [[[0.753556   0.61306372 0.85217787 0.697521   0.76456199 0.79706796]
#   [0.73549732 0.58490629 0.8464671  0.71690563 0.7691964  0.79624792]
#   [0.71747809 0.55218611 0.83437454 0.74391295 0.77419268 0.79365714]
#   [0.70026945 0.51665694 0.82644019 0.76047842 0.77845557 0.78954743]
#   [0.68643428 0.48096705 0.81947854 0.77362343 0.78199089 0.78440958]
#   [0.67350207 0.44599567 0.8102369  0.78919031 0.78480489 0.77843416]
#   [0.66230923 0.41282887 0.81707748 0.77033206 0.78775368 0.77187939]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 9: [[3183.8945]]
# x_pred_input of day 10:
# [[[0.73549732 0.58490629 0.8464671  0.71690563 0.7691964  0.79624792]
#   [0.71747809 0.55218611 0.83437454 0.74391295 0.77419268 0.79365714]
#   [0.70026945 0.51665694 0.82644019 0.76047842 0.77845557 0.78954743]
#   [0.68643428 0.48096705 0.81947854 0.77362343 0.78199089 0.78440958]
#   [0.67350207 0.44599567 0.8102369  0.78919031 0.78480489 0.77843416]
#   [0.66230923 0.41282887 0.81707748 0.77033206 0.78775368 0.77187939]
#   [0.65561148 0.38363274 0.82001566 0.75222804 0.78904851 0.76526167]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 10: [[3173.5708]]
# x_pred_input of day 11:
# [[[0.71747809 0.55218611 0.83437454 0.74391295 0.77419268 0.79365714]
#   [0.70026945 0.51665694 0.82644019 0.76047842 0.77845557 0.78954743]
#   [0.68643428 0.48096705 0.81947854 0.77362343 0.78199089 0.78440958]
#   [0.67350207 0.44599567 0.8102369  0.78919031 0.78480489 0.77843416]
#   [0.66230923 0.41282887 0.81707748 0.77033206 0.78775368 0.77187939]
#   [0.65561148 0.38363274 0.82001566 0.75222804 0.78904851 0.76526167]
#   [0.65342784 0.36006836 0.8221023  0.73613149 0.79106291 0.75905017]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 11: [[3170.3572]]
# x_pred_input of day 12:
# [[[0.70026945 0.51665694 0.82644019 0.76047842 0.77845557 0.78954743]
#   [0.68643428 0.48096705 0.81947854 0.77362343 0.78199089 0.78440958]
#   [0.67350207 0.44599567 0.8102369  0.78919031 0.78480489 0.77843416]
#   [0.66230923 0.41282887 0.81707748 0.77033206 0.78775368 0.77187939]
#   [0.65561148 0.38363274 0.82001566 0.75222804 0.78904851 0.76526167]
#   [0.65342784 0.36006836 0.8221023  0.73613149 0.79106291 0.75905017]
#   [0.65274811 0.34191384 0.82130381 0.72236725 0.79173519 0.75336049]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 12: [[3157.6533]]
# x_pred_input of day 13:
# [[[0.68643428 0.48096705 0.81947854 0.77362343 0.78199089 0.78440958]
#   [0.67350207 0.44599567 0.8102369  0.78919031 0.78480489 0.77843416]
#   [0.66230923 0.41282887 0.81707748 0.77033206 0.78775368 0.77187939]
#   [0.65561148 0.38363274 0.82001566 0.75222804 0.78904851 0.76526167]
#   [0.65342784 0.36006836 0.8221023  0.73613149 0.79106291 0.75905017]
#   [0.65274811 0.34191384 0.82130381 0.72236725 0.79173519 0.75336049]
#   [0.65006104 0.3272317  0.82039984 0.70962984 0.79204122 0.74793698]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 13: [[3132.1982]]
# x_pred_input of day 14:
# [[[0.67350207 0.44599567 0.8102369  0.78919031 0.78480489 0.77843416]
#   [0.66230923 0.41282887 0.81707748 0.77033206 0.78775368 0.77187939]
#   [0.65561148 0.38363274 0.82001566 0.75222804 0.78904851 0.76526167]
#   [0.65342784 0.36006836 0.8221023  0.73613149 0.79106291 0.75905017]
#   [0.65274811 0.34191384 0.82130381 0.72236725 0.79173519 0.75336049]
#   [0.65006104 0.3272317  0.82039984 0.70962984 0.79204122 0.74793698]
#   [0.64467689 0.31413005 0.81783659 0.69767472 0.79257344 0.74247756]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 14: [[3100.4443]]
# x_pred_input of day 15:
# [[[0.66230923 0.41282887 0.81707748 0.77033206 0.78775368 0.77187939]
#   [0.65561148 0.38363274 0.82001566 0.75222804 0.78904851 0.76526167]
#   [0.65342784 0.36006836 0.8221023  0.73613149 0.79106291 0.75905017]
#   [0.65274811 0.34191384 0.82130381 0.72236725 0.79173519 0.75336049]
#   [0.65006104 0.3272317  0.82039984 0.70962984 0.79204122 0.74793698]
#   [0.64467689 0.31413005 0.81783659 0.69767472 0.79257344 0.74247756]
#   [0.63796044 0.30177021 0.81157284 0.68741806 0.78760523 0.73684896]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 15: [[3067.5095]]
# x_pred_input of day 16:
# [[[0.65561148 0.38363274 0.82001566 0.75222804 0.78904851 0.76526167]
#   [0.65342784 0.36006836 0.8221023  0.73613149 0.79106291 0.75905017]
#   [0.65274811 0.34191384 0.82130381 0.72236725 0.79173519 0.75336049]
#   [0.65006104 0.3272317  0.82039984 0.70962984 0.79204122 0.74793698]
#   [0.64467689 0.31413005 0.81783659 0.69767472 0.79257344 0.74247756]
#   [0.63796044 0.30177021 0.81157284 0.68741806 0.78760523 0.73684896]
#   [0.63099421 0.29001132 0.80090735 0.67990658 0.7812403  0.73104165]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# y_pred of day 16: [[3033.8]]
# x_pred_input of day 17:
# [[[0.65342784 0.36006836 0.8221023  0.73613149 0.79106291 0.75905017]
#   [0.65274811 0.34191384 0.82130381 0.72236725 0.79173519 0.75336049]
#   [0.65006104 0.3272317  0.82039984 0.70962984 0.79204122 0.74793698]
#   [0.64467689 0.31413005 0.81783659 0.69767472 0.79257344 0.74247756]
#   [0.63796044 0.30177021 0.81157284 0.68741806 0.78760523 0.73684896]
#   [0.63099421 0.29001132 0.80090735 0.67990658 0.7812403  0.73104165]
#   [0.62386412 0.27877785 0.79056298 0.6724569  0.7750375  0.72505584]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# y_pred of day 17: [[2990.929]]
# x_pred_input of day 18:
# [[[0.65274811 0.34191384 0.82130381 0.72236725 0.79173519 0.75336049]
#   [0.65006104 0.3272317  0.82039984 0.70962984 0.79204122 0.74793698]
#   [0.64467689 0.31413005 0.81783659 0.69767472 0.79257344 0.74247756]
#   [0.63796044 0.30177021 0.81157284 0.68741806 0.78760523 0.73684896]
#   [0.63099421 0.29001132 0.80090735 0.67990658 0.7812403  0.73104165]
#   [0.62386412 0.27877785 0.79056298 0.6724569  0.7750375  0.72505584]
#   [0.61479621 0.26714473 0.78190406 0.66386556 0.7681065  0.71870971]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 18: [[2939.5107]]
# x_pred_input of day 19:
# [[[0.65006104 0.3272317  0.82039984 0.70962984 0.79204122 0.74793698]
#   [0.64467689 0.31413005 0.81783659 0.69767472 0.79257344 0.74247756]
#   [0.63796044 0.30177021 0.81157284 0.68741806 0.78760523 0.73684896]
#   [0.63099421 0.29001132 0.80090735 0.67990658 0.7812403  0.73104165]
#   [0.62386412 0.27877785 0.79056298 0.6724569  0.7750375  0.72505584]
#   [0.61479621 0.26714473 0.78190406 0.66386556 0.7681065  0.71870971]
#   [0.60392044 0.25445478 0.77248094 0.65531767 0.76116292 0.71185207]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 19: [[2885.22]]
# x_pred_input of day 20:
# [[[0.64467689 0.31413005 0.81783659 0.69767472 0.79257344 0.74247756]
#   [0.63796044 0.30177021 0.81157284 0.68741806 0.78760523 0.73684896]
#   [0.63099421 0.29001132 0.80090735 0.67990658 0.7812403  0.73104165]
#   [0.62386412 0.27877785 0.79056298 0.6724569  0.7750375  0.72505584]
#   [0.61479621 0.26714473 0.78190406 0.66386556 0.7681065  0.71870971]
#   [0.60392044 0.25445478 0.77248094 0.65531767 0.76116292 0.71185207]
#   [0.59243709 0.24078691 0.76070556 0.64788448 0.75354395 0.70446931]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# y_pred of day 20: [[2827.8704]]
# x_pred_input of day 21:
# [[[0.63796044 0.30177021 0.81157284 0.68741806 0.78760523 0.73684896]
#   [0.63099421 0.29001132 0.80090735 0.67990658 0.7812403  0.73104165]
#   [0.62386412 0.27877785 0.79056298 0.6724569  0.7750375  0.72505584]
#   [0.61479621 0.26714473 0.78190406 0.66386556 0.7681065  0.71870971]
#   [0.60392044 0.25445478 0.77248094 0.65531767 0.76116292 0.71185207]
#   [0.59243709 0.24078691 0.76070556 0.64788448 0.75354395 0.70446931]
#   [0.58030674 0.22619502 0.74354158 0.64407186 0.74474326 0.69654505]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 21: [[2762.958]]
# x_pred_input of day 22:
# [[[0.63099421 0.29001132 0.80090735 0.67990658 0.7812403  0.73104165]
#   [0.62386412 0.27877785 0.79056298 0.6724569  0.7750375  0.72505584]
#   [0.61479621 0.26714473 0.78190406 0.66386556 0.7681065  0.71870971]
#   [0.60392044 0.25445478 0.77248094 0.65531767 0.76116292 0.71185207]
#   [0.59243709 0.24078691 0.76070556 0.64788448 0.75354395 0.70446931]
#   [0.58030674 0.22619502 0.74354158 0.64407186 0.74474326 0.69654505]
#   [0.56657675 0.21027009 0.72915274 0.63770788 0.7347872  0.68796673]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 22: [[2686.9001]]
# x_pred_input of day 23:
# [[[0.62386412 0.27877785 0.79056298 0.6724569  0.7750375  0.72505584]
#   [0.61479621 0.26714473 0.78190406 0.66386556 0.7681065  0.71870971]
#   [0.60392044 0.25445478 0.77248094 0.65531767 0.76116292 0.71185207]
#   [0.59243709 0.24078691 0.76070556 0.64788448 0.75354395 0.70446931]
#   [0.58030674 0.22619502 0.74354158 0.64407186 0.74474326 0.69654505]
#   [0.56657675 0.21027009 0.72915274 0.63770788 0.7347872  0.68796673]
#   [0.55048931 0.19233953 0.71694885 0.62870997 0.72461681 0.67855476]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 23: [[2601.1973]]
# x_pred_input of day 24:
# [[[0.61479621 0.26714473 0.78190406 0.66386556 0.7681065  0.71870971]
#   [0.60392044 0.25445478 0.77248094 0.65531767 0.76116292 0.71185207]
#   [0.59243709 0.24078691 0.76070556 0.64788448 0.75354395 0.70446931]
#   [0.58030674 0.22619502 0.74354158 0.64407186 0.74474326 0.69654505]
#   [0.56657675 0.21027009 0.72915274 0.63770788 0.7347872  0.68796673]
#   [0.55048931 0.19233953 0.71694885 0.62870997 0.72461681 0.67855476]
#   [0.53236179 0.17205306 0.70813706 0.61573923 0.71437019 0.66817922]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 24: [[2514.1296]]
# x_pred_input of day 25:
# [[[0.60392044 0.25445478 0.77248094 0.65531767 0.76116292 0.71185207]
#   [0.59243709 0.24078691 0.76070556 0.64788448 0.75354395 0.70446931]
#   [0.58030674 0.22619502 0.74354158 0.64407186 0.74474326 0.69654505]
#   [0.56657675 0.21027009 0.72915274 0.63770788 0.7347872  0.68796673]
#   [0.55048931 0.19233953 0.71694885 0.62870997 0.72461681 0.67855476]
#   [0.53236179 0.17205306 0.70813706 0.61573923 0.71437019 0.66817922]
#   [0.51394562 0.15001207 0.70264108 0.59884725 0.70349996 0.65690225]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 25: [[2429.8457]]
# x_pred_input of day 26:
# [[[0.59243709 0.24078691 0.76070556 0.64788448 0.75354395 0.70446931]
#   [0.58030674 0.22619502 0.74354158 0.64407186 0.74474326 0.69654505]
#   [0.56657675 0.21027009 0.72915274 0.63770788 0.7347872  0.68796673]
#   [0.55048931 0.19233953 0.71694885 0.62870997 0.72461681 0.67855476]
#   [0.53236179 0.17205306 0.70813706 0.61573923 0.71437019 0.66817922]
#   [0.51394562 0.15001207 0.70264108 0.59884725 0.70349996 0.65690225]
#   [0.49611823 0.12713303 0.69977884 0.57880588 0.6917703  0.64487012]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 26: [[2348.165]]
# x_pred_input of day 27:
# [[[0.58030674 0.22619502 0.74354158 0.64407186 0.74474326 0.69654505]
#   [0.56657675 0.21027009 0.72915274 0.63770788 0.7347872  0.68796673]
#   [0.55048931 0.19233953 0.71694885 0.62870997 0.72461681 0.67855476]
#   [0.53236179 0.17205306 0.70813706 0.61573923 0.71437019 0.66817922]
#   [0.51394562 0.15001207 0.70264108 0.59884725 0.70349996 0.65690225]
#   [0.49611823 0.12713303 0.69977884 0.57880588 0.6917703  0.64487012]
#   [0.47884148 0.10412503 0.69832406 0.55672511 0.6788515  0.63221125]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 27: [[2268.98]]
# x_pred_input of day 28:
# [[[0.56657675 0.21027009 0.72915274 0.63770788 0.7347872  0.68796673]
#   [0.55048931 0.19233953 0.71694885 0.62870997 0.72461681 0.67855476]
#   [0.53236179 0.17205306 0.70813706 0.61573923 0.71437019 0.66817922]
#   [0.51394562 0.15001207 0.70264108 0.59884725 0.70349996 0.65690225]
#   [0.49611823 0.12713303 0.69977884 0.57880588 0.6917703  0.64487012]
#   [0.47884148 0.10412503 0.69832406 0.55672511 0.6788515  0.63221125]
#   [0.46209259 0.08153406 0.69770472 0.53323058 0.66605883 0.61903949]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 28: [[2191.747]]
# x_pred_input of day 29:
# [[[0.55048931 0.19233953 0.71694885 0.62870997 0.72461681 0.67855476]
#   [0.53236179 0.17205306 0.70813706 0.61573923 0.71437019 0.66817922]
#   [0.51394562 0.15001207 0.70264108 0.59884725 0.70349996 0.65690225]
#   [0.49611823 0.12713303 0.69977884 0.57880588 0.6917703  0.64487012]
#   [0.47884148 0.10412503 0.69832406 0.55672511 0.6788515  0.63221125]
#   [0.46209259 0.08153406 0.69770472 0.53323058 0.66605883 0.61903949]
#   [0.44575661 0.05972742 0.69733328 0.50885712 0.65322668 0.60544605]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# y_pred of day 29: [[2116.15]]
# x_pred_input of day 30:
# [[[0.53236179 0.17205306 0.70813706 0.61573923 0.71437019 0.66817922]
#   [0.51394562 0.15001207 0.70264108 0.59884725 0.70349996 0.65690225]
#   [0.49611823 0.12713303 0.69977884 0.57880588 0.6917703  0.64487012]
#   [0.47884148 0.10412503 0.69832406 0.55672511 0.6788515  0.63221125]
#   [0.46209259 0.08153406 0.69770472 0.53323058 0.66605883 0.61903949]
#   [0.44575661 0.05972742 0.69733328 0.50885712 0.65322668 0.60544605]
#   [0.42976661 0.0389515  0.6962736  0.48422362 0.64048078 0.59150658]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# y_pred of day 30: [[2044.8606]]
# x_pred_input of day 31:
# [[[0.51394562 0.15001207 0.70264108 0.59884725 0.70349996 0.65690225]
#   [0.49611823 0.12713303 0.69977884 0.57880588 0.6917703  0.64487012]
#   [0.47884148 0.10412503 0.69832406 0.55672511 0.6788515  0.63221125]
#   [0.46209259 0.08153406 0.69770472 0.53323058 0.66605883 0.61903949]
#   [0.44575661 0.05972742 0.69733328 0.50885712 0.65322668 0.60544605]
#   [0.42976661 0.0389515  0.6962736  0.48422362 0.64048078 0.59150658]
#   [0.4146878  0.01966155 0.69353534 0.46007495 0.62785746 0.57734754]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 31: [[1980.2678]]
# x_pred_input of day 32:
# [[[0.49611823 0.12713303 0.69977884 0.57880588 0.6917703  0.64487012]
#   [0.47884148 0.10412503 0.69832406 0.55672511 0.6788515  0.63221125]
#   [0.46209259 0.08153406 0.69770472 0.53323058 0.66605883 0.61903949]
#   [0.44575661 0.05972742 0.69733328 0.50885712 0.65322668 0.60544605]
#   [0.42976661 0.0389515  0.6962736  0.48422362 0.64048078 0.59150658]
#   [0.4146878  0.01966155 0.69353534 0.46007495 0.62785746 0.57734754]
#   [0.4010254  0.00244223 0.68853651 0.43708132 0.61538198 0.56313517]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 32: [[1922.9489]]
# x_pred_input of day 33:
# [[[0.47884148 0.11493418 0.69832406 0.55672511 0.6788515  0.63221125]
#   [0.46209259 0.09261578 0.69770472 0.53323058 0.66605883 0.61903949]
#   [0.44575661 0.07107225 0.69733328 0.50885712 0.65322668 0.60544605]
#   [0.42976661 0.050547   0.6962736  0.48422362 0.64048078 0.59150658]
#   [0.4146878  0.03148979 0.69353534 0.46007495 0.62785746 0.57734754]
#   [0.4010254  0.01447823 0.68853651 0.43708132 0.61538198 0.56313517]
#   [0.38890154 0.         0.68132626 0.41559153 0.60297784 0.5490324 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 33: [[1878.7906]]
# x_pred_input of day 34:
# [[[0.46209259 0.10248431 0.69770472 0.53323058 0.66605883 0.61903949]
#   [0.44575661 0.08117508 0.69733328 0.50885712 0.65322668 0.60544605]
#   [0.42976661 0.06087306 0.6962736  0.48422362 0.64048078 0.59150658]
#   [0.4146878  0.04202311 0.69353534 0.46007495 0.62785746 0.57734754]
#   [0.4010254  0.02519656 0.68853651 0.43708132 0.61538198 0.56313517]
#   [0.38890154 0.0108758  0.68132626 0.41559153 0.60297784 0.5490324 ]
#   [0.37956138 0.         0.67202771 0.3960895  0.59072346 0.53531442]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 34: [[1844.5946]]
# x_pred_input of day 35:
# [[[0.44575661 0.08761172 0.69733328 0.50885712 0.65322668 0.60544605]
#   [0.42976661 0.06745192 0.6962736  0.48422362 0.64048078 0.59150658]
#   [0.4146878  0.04873403 0.69353534 0.46007495 0.62785746 0.57734754]
#   [0.4010254  0.03202535 0.68853651 0.43708132 0.61538198 0.56313517]
#   [0.38890154 0.01780491 0.68132626 0.41559153 0.60297784 0.5490324 ]
#   [0.37956138 0.0070053  0.67202771 0.3960895  0.59072346 0.53531442]
#   [0.37232837 0.         0.66069881 0.37890153 0.57863417 0.52216077]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 35: [[1818.317]]
# x_pred_input of day 36:
# [[[0.42976661 0.07039407 0.6962736  0.48422362 0.64048078 0.59150658]
#   [0.4146878  0.05173523 0.69353534 0.46007495 0.62785746 0.57734754]
#   [0.4010254  0.03507927 0.68853651 0.43708132 0.61538198 0.56313517]
#   [0.38890154 0.02090369 0.68132626 0.41559153 0.60297784 0.5490324 ]
#   [0.37956138 0.01013815 0.67202771 0.3960895  0.59072346 0.53531442]
#   [0.37232837 0.00315495 0.66069881 0.37890153 0.57863417 0.52216077]
#   [0.36677025 0.         0.64727408 0.36432461 0.56659238 0.50968957]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 36: [[1797.4679]]
# x_pred_input of day 37:
# [[[4.14687796e-01 5.17352260e-02 6.93535337e-01 4.60074945e-01
#    6.27857456e-01 5.77347543e-01]
#   [4.01025404e-01 3.50792666e-02 6.88536511e-01 4.37081324e-01
#    6.15381978e-01 5.63135169e-01]
#   [3.88901536e-01 2.09036866e-02 6.81326261e-01 4.15591527e-01
#    6.02977845e-01 5.49032400e-01]
#   [3.79561378e-01 1.01381503e-02 6.72027707e-01 3.96089504e-01
#    5.90723464e-01 5.35314416e-01]
#   [3.72328374e-01 3.15495384e-03 6.60698805e-01 3.78901528e-01
#    5.78634168e-01 5.22160773e-01]
#   [3.66770249e-01 0.00000000e+00 6.47274080e-01 3.64324613e-01
#    5.66592384e-01 5.09689573e-01]
#   [3.62360331e-01 4.18688262e-04 6.31715711e-01 3.52553272e-01
#    5.54457786e-01 4.97953632e-01]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 37: [[1780.053]]
# x_pred_input of day 38:
# [[[4.01025404e-01 3.50792666e-02 6.88536511e-01 4.37081324e-01
#    6.15381978e-01 5.63135169e-01]
#   [3.88901536e-01 2.09036866e-02 6.81326261e-01 4.15591527e-01
#    6.02977845e-01 5.49032400e-01]
#   [3.79561378e-01 1.01381503e-02 6.72027707e-01 3.96089504e-01
#    5.90723464e-01 5.35314416e-01]
#   [3.72328374e-01 3.15495384e-03 6.60698805e-01 3.78901528e-01
#    5.78634168e-01 5.22160773e-01]
#   [3.66770249e-01 0.00000000e+00 6.47274080e-01 3.64324613e-01
#    5.66592384e-01 5.09689573e-01]
#   [3.62360331e-01 4.18688262e-04 6.31715711e-01 3.52553272e-01
#    5.54457786e-01 4.97953632e-01]
#   [3.58676800e-01 3.97304464e-03 6.14396236e-01 3.43457262e-01
#    5.42197959e-01 4.86957455e-01]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 38: [[1764.3519]]
# x_pred_input of day 39:
# [[[3.88901536e-01 2.09036866e-02 6.81326261e-01 4.15591527e-01
#    6.02977845e-01 5.49032400e-01]
#   [3.79561378e-01 1.01381503e-02 6.72027707e-01 3.96089504e-01
#    5.90723464e-01 5.35314416e-01]
#   [3.72328374e-01 3.15495384e-03 6.60698805e-01 3.78901528e-01
#    5.78634168e-01 5.22160773e-01]
#   [3.66770249e-01 0.00000000e+00 6.47274080e-01 3.64324613e-01
#    5.66592384e-01 5.09689573e-01]
#   [3.62360331e-01 4.18688262e-04 6.31715711e-01 3.52553272e-01
#    5.54457786e-01 4.97953632e-01]
#   [3.58676800e-01 3.97304464e-03 6.14396236e-01 3.43457262e-01
#    5.42197959e-01 4.86957455e-01]
#   [3.55355780e-01 1.01135835e-02 5.95720981e-01 3.36811437e-01
#    5.29911703e-01 4.76667784e-01]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 39: [[1749.1516]]
# x_pred_input of day 40:
# [[[3.79561378e-01 1.01381503e-02 6.72027707e-01 3.96089504e-01
#    5.90723464e-01 5.35314416e-01]
#   [3.72328374e-01 3.15495384e-03 6.60698805e-01 3.78901528e-01
#    5.78634168e-01 5.22160773e-01]
#   [3.66770249e-01 0.00000000e+00 6.47274080e-01 3.64324613e-01
#    5.66592384e-01 5.09689573e-01]
#   [3.62360331e-01 4.18688262e-04 6.31715711e-01 3.52553272e-01
#    5.54457786e-01 4.97953632e-01]
#   [3.58676800e-01 3.97304464e-03 6.14396236e-01 3.43457262e-01
#    5.42197959e-01 4.86957455e-01]
#   [3.55355780e-01 1.01135835e-02 5.95720981e-01 3.36811437e-01
#    5.29911703e-01 4.76667784e-01]
#   [3.52140673e-01 1.82600147e-02 5.75847095e-01 3.32513846e-01
#    5.17715875e-01 4.67028200e-01]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 40: [[1733.5927]]
# x_pred_input of day 41:
# [[[3.72328374e-01 3.15495384e-03 6.60698805e-01 3.78901528e-01
#    5.78634168e-01 5.22160773e-01]
#   [3.66770249e-01 0.00000000e+00 6.47274080e-01 3.64324613e-01
#    5.66592384e-01 5.09689573e-01]
#   [3.62360331e-01 4.18688262e-04 6.31715711e-01 3.52553272e-01
#    5.54457786e-01 4.97953632e-01]
#   [3.58676800e-01 3.97304464e-03 6.14396236e-01 3.43457262e-01
#    5.42197959e-01 4.86957455e-01]
#   [3.55355780e-01 1.01135835e-02 5.95720981e-01 3.36811437e-01
#    5.29911703e-01 4.76667784e-01]
#   [3.52140673e-01 1.82600147e-02 5.75847095e-01 3.32513846e-01
#    5.17715875e-01 4.67028200e-01]
#   [3.48849707e-01 2.78496099e-02 5.54928376e-01 3.30450147e-01
#    5.05662855e-01 4.57969005e-01]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 41: [[1716.8695]]
# x_pred_input of day 42:
# [[[3.66770249e-01 0.00000000e+00 6.47274080e-01 3.64324613e-01
#    5.66592384e-01 5.09689573e-01]
#   [3.62360331e-01 4.18688262e-04 6.31715711e-01 3.52553272e-01
#    5.54457786e-01 4.97953632e-01]
#   [3.58676800e-01 3.97304464e-03 6.14396236e-01 3.43457262e-01
#    5.42197959e-01 4.86957455e-01]
#   [3.55355780e-01 1.01135835e-02 5.95720981e-01 3.36811437e-01
#    5.29911703e-01 4.76667784e-01]
#   [3.52140673e-01 1.82600147e-02 5.75847095e-01 3.32513846e-01
#    5.17715875e-01 4.67028200e-01]
#   [3.48849707e-01 2.78496099e-02 5.54928376e-01 3.30450147e-01
#    5.05662855e-01 4.57969005e-01]
#   [3.45312498e-01 3.83451512e-02 5.33367922e-01 3.30304210e-01
#    4.93752791e-01 4.49409660e-01]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 42: [[1697.6982]]
# x_pred_input of day 43:
# [[[3.62360331e-01 4.18688262e-04 6.31715711e-01 3.52553272e-01
#    5.54457786e-01 4.97953632e-01]
#   [3.58676800e-01 3.97304464e-03 6.14396236e-01 3.43457262e-01
#    5.42197959e-01 4.86957455e-01]
#   [3.55355780e-01 1.01135835e-02 5.95720981e-01 3.36811437e-01
#    5.29911703e-01 4.76667784e-01]
#   [3.52140673e-01 1.82600147e-02 5.75847095e-01 3.32513846e-01
#    5.17715875e-01 4.67028200e-01]
#   [3.48849707e-01 2.78496099e-02 5.54928376e-01 3.30450147e-01
#    5.05662855e-01 4.57969005e-01]
#   [3.45312498e-01 3.83451512e-02 5.33367922e-01 3.30304210e-01
#    4.93752791e-01 4.49409660e-01]
#   [3.41257472e-01 4.91880867e-02 5.11857799e-01 3.31477841e-01
#    4.81970926e-01 4.41249430e-01]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 43: [[1674.8528]]
# x_pred_input of day 44:
# [[[0.3586768  0.00397304 0.61439624 0.34345726 0.54219796 0.48695746]
#   [0.35535578 0.01011358 0.59572098 0.33681144 0.5299117  0.47666778]
#   [0.35214067 0.01826001 0.57584709 0.33251385 0.51771587 0.4670282 ]
#   [0.34884971 0.02784961 0.55492838 0.33045015 0.50566285 0.45796901]
#   [0.3453125  0.03834515 0.53336792 0.33030421 0.49375279 0.44940966]
#   [0.34125747 0.04918809 0.5118578  0.33147784 0.48197093 0.44124943]
#   [0.3364253  0.05981525 0.49115054 0.3332361  0.47036565 0.43337056]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 44: [[1647.7125]]
# x_pred_input of day 45:
# [[[0.35535578 0.01011358 0.59572098 0.33681144 0.5299117  0.47666778]
#   [0.35214067 0.01826001 0.57584709 0.33251385 0.51771587 0.4670282 ]
#   [0.34884971 0.02784961 0.55492838 0.33045015 0.50566285 0.45796901]
#   [0.3453125  0.03834515 0.53336792 0.33030421 0.49375279 0.44940966]
#   [0.34125747 0.04918809 0.5118578  0.33147784 0.48197093 0.44124943]
#   [0.3364253  0.05981525 0.49115054 0.3332361  0.47036565 0.43337056]
#   [0.3306847  0.06972634 0.47162658 0.33506332 0.45897446 0.42565306]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 45: [[1616.3411]]
# x_pred_input of day 46:
# [[[0.35214067 0.01826001 0.57584709 0.33251385 0.51771587 0.4670282 ]
#   [0.34884971 0.02784961 0.55492838 0.33045015 0.50566285 0.45796901]
#   [0.3453125  0.03834515 0.53336792 0.33030421 0.49375279 0.44940966]
#   [0.34125747 0.04918809 0.5118578  0.33147784 0.48197093 0.44124943]
#   [0.3364253  0.05981525 0.49115054 0.3332361  0.47036565 0.43337056]
#   [0.3306847  0.06972634 0.47162658 0.33506332 0.45897446 0.42565306]
#   [0.32404914 0.07854383 0.45346852 0.33657605 0.44778537 0.41798972]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 46: [[1581.0718]]
# x_pred_input of day 47:
# [[[0.34884971 0.02784961 0.55492838 0.33045015 0.50566285 0.45796901]
#   [0.3453125  0.03834515 0.53336792 0.33030421 0.49375279 0.44940966]
#   [0.34125747 0.04918809 0.5118578  0.33147784 0.48197093 0.44124943]
#   [0.3364253  0.05981525 0.49115054 0.3332361  0.47036565 0.43337056]
#   [0.3306847  0.06972634 0.47162658 0.33506332 0.45897446 0.42565306]
#   [0.32404914 0.07854383 0.45346852 0.33657605 0.44778537 0.41798972]
#   [0.31658913 0.08601747 0.43691216 0.3373412  0.43679099 0.4102908 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 47: [[1542.0952]]
# x_pred_input of day 48:
# [[[0.3453125  0.03834515 0.53336792 0.33030421 0.49375279 0.44940966]
#   [0.34125747 0.04918809 0.5118578  0.33147784 0.48197093 0.44124943]
#   [0.3364253  0.05981525 0.49115054 0.3332361  0.47036565 0.43337056]
#   [0.3306847  0.06972634 0.47162658 0.33506332 0.45897446 0.42565306]
#   [0.32404914 0.07854383 0.45346852 0.33657605 0.44778537 0.41798972]
#   [0.31658913 0.08601747 0.43691216 0.3373412  0.43679099 0.4102908 ]
#   [0.30834497 0.09198541 0.42225862 0.33685646 0.42602531 0.40247923]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 48: [[1499.6687]]
# x_pred_input of day 49:
# [[[0.34125747 0.04918809 0.5118578  0.33147784 0.48197093 0.44124943]
#   [0.3364253  0.05981525 0.49115054 0.3332361  0.47036565 0.43337056]
#   [0.3306847  0.06972634 0.47162658 0.33506332 0.45897446 0.42565306]
#   [0.32404914 0.07854383 0.45346852 0.33657605 0.44778537 0.41798972]
#   [0.31658913 0.08601747 0.43691216 0.3373412  0.43679099 0.4102908 ]
#   [0.30834497 0.09198541 0.42225862 0.33685646 0.42602531 0.40247923]
#   [0.29937109 0.09636352 0.40988964 0.33454474 0.4155562  0.39449086]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 49: [[1454.6089]]
# x_pred_input of day 50:
# [[[0.3364253  0.05981525 0.49115054 0.3332361  0.47036565 0.43337056]
#   [0.3306847  0.06972634 0.47162658 0.33506332 0.45897446 0.42565306]
#   [0.32404914 0.07854383 0.45346852 0.33657605 0.44778537 0.41798972]
#   [0.31658913 0.08601747 0.43691216 0.3373412  0.43679099 0.4102908 ]
#   [0.30834497 0.09198541 0.42225862 0.33685646 0.42602531 0.40247923]
#   [0.29937109 0.09636352 0.40988964 0.33454474 0.4155562  0.39449086]
#   [0.28984023 0.099185   0.40016697 0.32987975 0.40544548 0.38628539]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 50: [[1408.2504]]
# x_pred_input of day 51:
# [[[0.3306847  0.06972634 0.47162658 0.33506332 0.45897446 0.42565306]
#   [0.32404914 0.07854383 0.45346852 0.33657605 0.44778537 0.41798972]
#   [0.31658913 0.08601747 0.43691216 0.3373412  0.43679099 0.4102908 ]
#   [0.30834497 0.09198541 0.42225862 0.33685646 0.42602531 0.40247923]
#   [0.29937109 0.09636352 0.40988964 0.33454474 0.4155562  0.39449086]
#   [0.28984023 0.099185   0.40016697 0.32987975 0.40544548 0.38628539]
#   [0.28003467 0.10062594 0.39310214 0.32271218 0.39569374 0.3778553 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 51: [[1362.2523]]
# x_pred_input of day 52:
# [[[0.32404914 0.07854383 0.45346852 0.33657605 0.44778537 0.41798972]
#   [0.31658913 0.08601747 0.43691216 0.3373412  0.43679099 0.4102908 ]
#   [0.30834497 0.09198541 0.42225862 0.33685646 0.42602531 0.40247923]
#   [0.29937109 0.09636352 0.40988964 0.33454474 0.4155562  0.39449086]
#   [0.28984023 0.099185   0.40016697 0.32987975 0.40544548 0.38628539]
#   [0.28003467 0.10062594 0.39310214 0.32271218 0.39569374 0.3778553 ]
#   [0.27030536 0.10100459 0.38831087 0.31333766 0.3862796  0.36922982]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 52: [[1318.2133]]
# x_pred_input of day 53:
# [[[0.31658913 0.08601747 0.43691216 0.3373412  0.43679099 0.4102908 ]
#   [0.30834497 0.09198541 0.42225862 0.33685646 0.42602531 0.40247923]
#   [0.29937109 0.09636352 0.40988964 0.33454474 0.4155562  0.39449086]
#   [0.28984023 0.099185   0.40016697 0.32987975 0.40544548 0.38628539]
#   [0.28003467 0.10062594 0.39310214 0.32271218 0.39569374 0.3778553 ]
#   [0.27030536 0.10100459 0.38831087 0.31333766 0.3862796  0.36922982]
#   [0.2609904  0.10074093 0.38520285 0.30231742 0.3771974  0.36047005]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 53: [[1277.126]]
# x_pred_input of day 54:
# [[[0.30834497 0.09198541 0.42225862 0.33685646 0.42602531 0.40247923]
#   [0.29937109 0.09636352 0.40988964 0.33454474 0.4155562  0.39449086]
#   [0.28984023 0.099185   0.40016697 0.32987975 0.40544548 0.38628539]
#   [0.28003467 0.10062594 0.39310214 0.32271218 0.39569374 0.3778553 ]
#   [0.27030536 0.10100459 0.38831087 0.31333766 0.3862796  0.36922982]
#   [0.2609904  0.10074093 0.38520285 0.30231742 0.3771974  0.36047005]
#   [0.25229979 0.10026977 0.38291116 0.29041741 0.36845114 0.35165287]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 54: [[1239.4153]]
# x_pred_input of day 55:
# [[[0.29937109 0.09636352 0.40988964 0.33454474 0.4155562  0.39449086]
#   [0.28984023 0.099185   0.40016697 0.32987975 0.40544548 0.38628539]
#   [0.28003467 0.10062594 0.39310214 0.32271218 0.39569374 0.3778553 ]
#   [0.27030536 0.10100459 0.38831087 0.31333766 0.3862796  0.36922982]
#   [0.2609904  0.10074093 0.38520285 0.30231742 0.3771974  0.36047005]
#   [0.25229979 0.10026977 0.38291116 0.29041741 0.36845114 0.35165287]
#   [0.24432338 0.09997627 0.38081383 0.27820504 0.36005339 0.342857  ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 55: [[1205.2218]]
# x_pred_input of day 56:
# [[[0.28984023 0.099185   0.40016697 0.32987975 0.40544548 0.38628539]
#   [0.28003467 0.10062594 0.39310214 0.32271218 0.39569374 0.3778553 ]
#   [0.27030536 0.10100459 0.38831087 0.31333766 0.3862796  0.36922982]
#   [0.2609904  0.10074093 0.38520285 0.30231742 0.3771974  0.36047005]
#   [0.25229979 0.10026977 0.38291116 0.29041741 0.36845114 0.35165287]
#   [0.24432338 0.09997627 0.38081383 0.27820504 0.36005339 0.342857  ]
#   [0.23709092 0.10017412 0.37845458 0.26610702 0.35202075 0.33415676]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 56: [[1174.4457]]
# x_pred_input of day 57:
# [[[0.28003467 0.10062594 0.39310214 0.32271218 0.39569374 0.3778553 ]
#   [0.27030536 0.10100459 0.38831087 0.31333766 0.3862796  0.36922982]
#   [0.2609904  0.10074093 0.38520285 0.30231742 0.3771974  0.36047005]
#   [0.25229979 0.10026977 0.38291116 0.29041741 0.36845114 0.35165287]
#   [0.24432338 0.09997627 0.38081383 0.27820504 0.36005339 0.342857  ]
#   [0.23709092 0.10017412 0.37845458 0.26610702 0.35202075 0.33415676]
#   [0.23058129 0.10109358 0.37552548 0.25443454 0.34434535 0.3256172 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 57: [[1147.1047]]
# x_pred_input of day 58:
# [[[0.27030536 0.10100459 0.38831087 0.31333766 0.3862796  0.36922982]
#   [0.2609904  0.10074093 0.38520285 0.30231742 0.3771974  0.36047005]
#   [0.25229979 0.10026977 0.38291116 0.29041741 0.36845114 0.35165287]
#   [0.24432338 0.09997627 0.38081383 0.27820504 0.36005339 0.342857  ]
#   [0.23709092 0.10017412 0.37845458 0.26610702 0.35202075 0.33415676]
#   [0.23058129 0.10109358 0.37552548 0.25443454 0.34434535 0.3256172 ]
#   [0.22479824 0.1029086  0.37181511 0.24343476 0.33699845 0.31729756]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 58: [[1123.294]]
# x_pred_input of day 59:
# [[[0.2609904  0.10074093 0.38520285 0.30231742 0.3771974  0.36047005]
#   [0.25229979 0.10026977 0.38291116 0.29041741 0.36845114 0.35165287]
#   [0.24432338 0.09997627 0.38081383 0.27820504 0.36005339 0.342857  ]
#   [0.23709092 0.10017412 0.37845458 0.26610702 0.35202075 0.33415676]
#   [0.23058129 0.10109358 0.37552548 0.25443454 0.34434535 0.3256172 ]
#   [0.22479824 0.1029086  0.37181511 0.24343476 0.33699845 0.31729756]
#   [0.21976189 0.10575468 0.36718352 0.23331528 0.32994702 0.30925353]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 59: [[1102.8105]]
# x_pred_input of day 60:
# [[[0.25229979 0.10026977 0.38291116 0.29041741 0.36845114 0.35165287]
#   [0.24432338 0.09997627 0.38081383 0.27820504 0.36005339 0.342857  ]
#   [0.23709092 0.10017412 0.37845458 0.26610702 0.35202075 0.33415676]
#   [0.23058129 0.10109358 0.37552548 0.25443454 0.34434535 0.3256172 ]
#   [0.22479824 0.1029086  0.37181511 0.24343476 0.33699845 0.31729756]
#   [0.21976189 0.10575468 0.36718352 0.23331528 0.32994702 0.30925353]
#   [0.21542932 0.10970612 0.36154562 0.22424402 0.32310436 0.30153105]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 60: [[1085.1313]]
# x_pred_input of day 61:
# [[[0.24432338 0.09997627 0.38081383 0.27820504 0.36005339 0.342857  ]
#   [0.23709092 0.10017412 0.37845458 0.26610702 0.35202075 0.33415676]
#   [0.23058129 0.10109358 0.37552548 0.25443454 0.34434535 0.3256172 ]
#   [0.22479824 0.1029086  0.37181511 0.24343476 0.33699845 0.31729756]
#   [0.21976189 0.10575468 0.36718352 0.23331528 0.32994702 0.30925353]
#   [0.21542932 0.10970612 0.36154562 0.22424402 0.32310436 0.30153105]
#   [0.21168989 0.11475665 0.35486061 0.21634532 0.31640734 0.29416037]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# y_pred of day 61: [[1069.4612]]
# x_pred_input of day 62:
# [[[0.23709092 0.10017412 0.37845458 0.26610702 0.35202075 0.33415676]
#   [0.23058129 0.10109358 0.37552548 0.25443454 0.34434535 0.3256172 ]
#   [0.22479824 0.1029086  0.37181511 0.24343476 0.33699845 0.31729756]
#   [0.21976189 0.10575468 0.36718352 0.23331528 0.32994702 0.30925353]
#   [0.21542932 0.10970612 0.36154562 0.22424402 0.32310436 0.30153105]
#   [0.21168989 0.11475665 0.35486061 0.21634532 0.31640734 0.29416037]
#   [0.2083754  0.12080998 0.34713133 0.20969276 0.30980386 0.28715158]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 62: [[1054.7657]]
# x_pred_input of day 63:
# [[[0.23058129 0.10109358 0.37552548 0.25443454 0.34434535 0.3256172 ]
#   [0.22479824 0.1029086  0.37181511 0.24343476 0.33699845 0.31729756]
#   [0.21976189 0.10575468 0.36718352 0.23331528 0.32994702 0.30925353]
#   [0.21542932 0.10970612 0.36154562 0.22424402 0.32310436 0.30153105]
#   [0.21168989 0.11475665 0.35486061 0.21634532 0.31640734 0.29416037]
#   [0.2083754  0.12080998 0.34713133 0.20969276 0.30980386 0.28715158]
#   [0.20526709 0.12767666 0.33842941 0.20428554 0.30325465 0.28049137]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 63: [[1039.9381]]
# x_pred_input of day 64:
# [[[0.22479824 0.1029086  0.37181511 0.24343476 0.33699845 0.31729756]
#   [0.21976189 0.10575468 0.36718352 0.23331528 0.32994702 0.30925353]
#   [0.21542932 0.10970612 0.36154562 0.22424402 0.32310436 0.30153105]
#   [0.21168989 0.11475665 0.35486061 0.21634532 0.31640734 0.29416037]
#   [0.2083754  0.12080998 0.34713133 0.20969276 0.30980386 0.28715158]
#   [0.20526709 0.12767666 0.33842941 0.20428554 0.30325465 0.28049137]
#   [0.20213081 0.13508921 0.32890087 0.20003882 0.29672825 0.27414367]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 64: [[1023.9949]]
# x_pred_input of day 65:
# [[[0.21976189 0.10575468 0.36718352 0.23331528 0.32994702 0.30925353]
#   [0.21542932 0.10970612 0.36154562 0.22424402 0.32310436 0.30153105]
#   [0.21168989 0.11475665 0.35486061 0.21634532 0.31640734 0.29416037]
#   [0.2083754  0.12080998 0.34713133 0.20969276 0.30980386 0.28715158]
#   [0.20526709 0.12767666 0.33842941 0.20428554 0.30325465 0.28049137]
#   [0.20213081 0.13508921 0.32890087 0.20003882 0.29672825 0.27414367]
#   [0.19875856 0.14273433 0.31874578 0.19679576 0.29019972 0.26805451]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 65: [[1006.1685]]
# x_pred_input of day 66:
# [[[0.21542932 0.10970612 0.36154562 0.22424402 0.32310436 0.30153105]
#   [0.21168989 0.11475665 0.35486061 0.21634532 0.31640734 0.29416037]
#   [0.2083754  0.12080998 0.34713133 0.20969276 0.30980386 0.28715158]
#   [0.20526709 0.12767666 0.33842941 0.20428554 0.30325465 0.28049137]
#   [0.20213081 0.13508921 0.32890087 0.20003882 0.29672825 0.27414367]
#   [0.19875856 0.14273433 0.31874578 0.19679576 0.29019972 0.26805451]
#   [0.19498801 0.15028779 0.30819057 0.19434861 0.28364802 0.2621584 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 66: [[986.00323]]
# x_pred_input of day 67:
# [[[0.21168989 0.11475665 0.35486061 0.21634532 0.31640734 0.29416037]
#   [0.2083754  0.12080998 0.34713133 0.20969276 0.30980386 0.28715158]
#   [0.20526709 0.12767666 0.33842941 0.20428554 0.30325465 0.28049137]
#   [0.20213081 0.13508921 0.32890087 0.20003882 0.29672825 0.27414367]
#   [0.19875856 0.14273433 0.31874578 0.19679576 0.29019972 0.26805451]
#   [0.19498801 0.15028779 0.30819057 0.19434861 0.28364802 0.2621584 ]
#   [0.19072273 0.1574514  0.29747762 0.1924518  0.27705571 0.25638618]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 67: [[963.31647]]
# x_pred_input of day 68:
# [[[0.2083754  0.12080998 0.34713133 0.20969276 0.30980386 0.28715158]
#   [0.20526709 0.12767666 0.33842941 0.20428554 0.30325465 0.28049137]
#   [0.20213081 0.13508921 0.32890087 0.20003882 0.29672825 0.27414367]
#   [0.19875856 0.14273433 0.31874578 0.19679576 0.29019972 0.26805451]
#   [0.19498801 0.15028779 0.30819057 0.19434861 0.28364802 0.2621584 ]
#   [0.19072273 0.1574514  0.29747762 0.1924518  0.27705571 0.25638618]
#   [0.18592412 0.16397787 0.28687942 0.19081558 0.27041082 0.25067135]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 68: [[938.1598]]
# x_pred_input of day 69:
# [[[0.20526709 0.12767666 0.33842941 0.20428554 0.30325465 0.28049137]
#   [0.20213081 0.13508921 0.32890087 0.20003882 0.29672825 0.27414367]
#   [0.19875856 0.14273433 0.31874578 0.19679576 0.29019972 0.26805451]
#   [0.19498801 0.15028779 0.30819057 0.19434861 0.28364802 0.2621584 ]
#   [0.19072273 0.1574514  0.29747762 0.1924518  0.27705571 0.25638618]
#   [0.18592412 0.16397787 0.28687942 0.19081558 0.27041082 0.25067135]
#   [0.18060309 0.16968583 0.27670278 0.18910507 0.26371314 0.24495482]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 69: [[910.7975]]
# x_pred_input of day 70:
# [[[0.20213081 0.13508921 0.32890087 0.20003882 0.29672825 0.27414367]
#   [0.19875856 0.14273433 0.31874578 0.19679576 0.29019972 0.26805451]
#   [0.19498801 0.15028779 0.30819057 0.19434861 0.28364802 0.2621584 ]
#   [0.19072273 0.1574514  0.29747762 0.1924518  0.27705571 0.25638618]
#   [0.18592412 0.16397787 0.28687942 0.19081558 0.27041082 0.25067135]
#   [0.18060309 0.16968583 0.27670278 0.18910507 0.26371314 0.24495482]
#   [0.17481553 0.17446873 0.26725568 0.18697065 0.25697563 0.23918891]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 70: [[881.728]]
# x_pred_input of day 71:
# [[[0.19875856 0.14273433 0.31874578 0.19679576 0.29019972 0.26805451]
#   [0.19498801 0.15028779 0.30819057 0.19434861 0.28364802 0.2621584 ]
#   [0.19072273 0.1574514  0.29747762 0.1924518  0.27705571 0.25638618]
#   [0.18592412 0.16397787 0.28687942 0.19081558 0.27041082 0.25067135]
#   [0.18060309 0.16968583 0.27670278 0.18910507 0.26371314 0.24495482]
#   [0.17481553 0.17446873 0.26725568 0.18697065 0.25697563 0.23918891]
#   [0.16866688 0.17830306 0.25879577 0.18410125 0.25022111 0.23334125]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 71: [[851.6523]]
# x_pred_input of day 72:
# [[[0.19498801 0.15028779 0.30819057 0.19434861 0.28364802 0.2621584 ]
#   [0.19072273 0.1574514  0.29747762 0.1924518  0.27705571 0.25638618]
#   [0.18592412 0.16397787 0.28687942 0.19081558 0.27041082 0.25067135]
#   [0.18060309 0.16968583 0.27670278 0.18910507 0.26371314 0.24495482]
#   [0.17481553 0.17446873 0.26725568 0.18697065 0.25697563 0.23918891]
#   [0.16866688 0.17830306 0.25879577 0.18410125 0.25022111 0.23334125]
#   [0.16230538 0.18125072 0.25147282 0.1802887  0.24347802 0.2273978 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 72: [[821.3929]]
# x_pred_input of day 73:
# [[[0.19072273 0.1574514  0.29747762 0.1924518  0.27705571 0.25638618]
#   [0.18592412 0.16397787 0.28687942 0.19081558 0.27041082 0.25067135]
#   [0.18060309 0.16968583 0.27670278 0.18910507 0.26371314 0.24495482]
#   [0.17481553 0.17446873 0.26725568 0.18697065 0.25697563 0.23918891]
#   [0.16866688 0.17830306 0.25879577 0.18410125 0.25022111 0.23334125]
#   [0.16230538 0.18125072 0.25147282 0.1802887  0.24347802 0.2273978 ]
#   [0.15590504 0.18345188 0.2452937  0.17547303 0.2367791  0.22136369]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 73: [[791.74194]]
# x_pred_input of day 74:
# [[[0.18592412 0.16397787 0.28687942 0.19081558 0.27041082 0.25067135]
#   [0.18060309 0.16968583 0.27670278 0.18910507 0.26371314 0.24495482]
#   [0.17481553 0.17446873 0.26725568 0.18697065 0.25697563 0.23918891]
#   [0.16866688 0.17830306 0.25879577 0.18410125 0.25022111 0.23334125]
#   [0.16230538 0.18125072 0.25147282 0.1802887  0.24347802 0.2273978 ]
#   [0.15590504 0.18345188 0.2452937  0.17547303 0.2367791  0.22136369]
#   [0.1496334  0.18510344 0.24014088 0.16973486 0.23016242 0.21526076]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 74: [[763.3242]]
# x_pred_input of day 75:
# [[[0.18060309 0.16968583 0.27670278 0.18910507 0.26371314 0.24495482]
#   [0.17481553 0.17446873 0.26725568 0.18697065 0.25697563 0.23918891]
#   [0.16866688 0.17830306 0.25879577 0.18410125 0.25022111 0.23334125]
#   [0.16230538 0.18125072 0.25147282 0.1802887  0.24347802 0.2273978 ]
#   [0.15590504 0.18345188 0.2452937  0.17547303 0.2367791  0.22136369]
#   [0.1496334  0.18510344 0.24014088 0.16973486 0.23016242 0.21526076]
#   [0.1436226  0.18642788 0.23581671 0.16325329 0.22366927 0.20912234]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 75: [[736.52246]]
# x_pred_input of day 76:
# [[[0.17481553 0.17446873 0.26725568 0.18697065 0.25697563 0.23918891]
#   [0.16866688 0.17830306 0.25879577 0.18410125 0.25022111 0.23334125]
#   [0.16230538 0.18125072 0.25147282 0.1802887  0.24347802 0.2273978 ]
#   [0.15590504 0.18345188 0.2452937  0.17547303 0.2367791  0.22136369]
#   [0.1496334  0.18510344 0.24014088 0.16973486 0.23016242 0.21526076]
#   [0.1436226  0.18642788 0.23581671 0.16325329 0.22366927 0.20912234]
#   [0.1379536  0.1876412  0.23208837 0.15625437 0.21733712 0.20298686]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 76: [[711.504]]
# x_pred_input of day 77:
# [[[0.16866688 0.17830306 0.25879577 0.18410125 0.25022111 0.23334125]
#   [0.16230538 0.18125072 0.25147282 0.1802887  0.24347802 0.2273978 ]
#   [0.15590504 0.18345188 0.2452937  0.17547303 0.2367791  0.22136369]
#   [0.1496334  0.18510344 0.24014088 0.16973486 0.23016242 0.21526076]
#   [0.1436226  0.18642788 0.23581671 0.16325329 0.22366927 0.20912234]
#   [0.1379536  0.1876412  0.23208837 0.15625437 0.21733712 0.20298686]
#   [0.13266181 0.18893048 0.22872786 0.148965   0.21119315 0.19689276]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 77: [[688.3099]]
# x_pred_input of day 78:
# [[[0.16230538 0.18125072 0.25147282 0.1802887  0.24347802 0.2273978 ]
#   [0.15590504 0.18345188 0.2452937  0.17547303 0.2367791  0.22136369]
#   [0.1496334  0.18510344 0.24014088 0.16973486 0.23016242 0.21526076]
#   [0.1436226  0.18642788 0.23581671 0.16325329 0.22366927 0.20912234]
#   [0.1379536  0.1876412  0.23208837 0.15625437 0.21733712 0.20298686]
#   [0.13266181 0.18893048 0.22872786 0.148965   0.21119315 0.19689276]
#   [0.12775588 0.1904455  0.22552218 0.14159515 0.20525026 0.19087568]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 78: [[666.9137]]
# x_pred_input of day 79:
# [[[0.15590504 0.18345188 0.2452937  0.17547303 0.2367791  0.22136369]
#   [0.1496334  0.18510344 0.24014088 0.16973486 0.23016242 0.21526076]
#   [0.1436226  0.18642788 0.23581671 0.16325329 0.22366927 0.20912234]
#   [0.1379536  0.1876412  0.23208837 0.15625437 0.21733712 0.20298686]
#   [0.13266181 0.18893048 0.22872786 0.148965   0.21119315 0.19689276]
#   [0.12775588 0.1904455  0.22552218 0.14159515 0.20525026 0.19087568]
#   [0.12323025 0.19229843 0.22227392 0.13433357 0.19950704 0.18496732]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# y_pred of day 79: [[647.2563]]
# x_pred_input of day 80:
# [[[0.1496334  0.18510344 0.24014088 0.16973486 0.23016242 0.21526076]
#   [0.1436226  0.18642788 0.23581671 0.16325329 0.22366927 0.20912234]
#   [0.1379536  0.1876412  0.23208837 0.15625437 0.21733712 0.20298686]
#   [0.13266181 0.18893048 0.22872786 0.148965   0.21119315 0.19689276]
#   [0.12775588 0.1904455  0.22552218 0.14159515 0.20525026 0.19087568]
#   [0.12323025 0.19229843 0.22227392 0.13433357 0.19950704 0.18496732]
#   [0.1190724  0.19456742 0.21880978 0.12734435 0.1939528  0.17919504]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 80: [[629.21533]]
# x_pred_input of day 81:
# [[[0.1436226  0.18642788 0.23581671 0.16325329 0.22366927 0.20912234]
#   [0.1379536  0.1876412  0.23208837 0.15625437 0.21733712 0.20298686]
#   [0.13266181 0.18893048 0.22872786 0.148965   0.21119315 0.19689276]
#   [0.12775588 0.1904455  0.22552218 0.14159515 0.20525026 0.19087568]
#   [0.12323025 0.19229843 0.22227392 0.13433357 0.19950704 0.18496732]
#   [0.1190724  0.19456742 0.21880978 0.12734435 0.1939528  0.17919504]
#   [0.11525645 0.19729684 0.21498699 0.12076558 0.188572   0.17358097]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 81: [[612.56696]]
# x_pred_input of day 82:
# [[[0.1379536  0.1876412  0.23208837 0.15625437 0.21733712 0.20298686]
#   [0.13266181 0.18893048 0.22872786 0.148965   0.21119315 0.19689276]
#   [0.12775588 0.1904455  0.22552218 0.14159515 0.20525026 0.19087568]
#   [0.12323025 0.19229843 0.22227392 0.13433357 0.19950704 0.18496732]
#   [0.1190724  0.19456742 0.21880978 0.12734435 0.1939528  0.17919504]
#   [0.11525645 0.19729684 0.21498699 0.12076558 0.188572   0.17358097]
#   [0.11173506 0.20049399 0.21069906 0.1147068  0.18334592 0.16814026]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 82: [[596.98376]]
# x_pred_input of day 83:
# [[[0.13266181 0.18893048 0.22872786 0.148965   0.21119315 0.19689276]
#   [0.12775588 0.1904455  0.22552218 0.14159515 0.20525026 0.19087568]
#   [0.12323025 0.19229843 0.22227392 0.13433357 0.19950704 0.18496732]
#   [0.1190724  0.19456742 0.21880978 0.12734435 0.1939528  0.17919504]
#   [0.11525645 0.19729684 0.21498699 0.12076558 0.188572   0.17358097]
#   [0.11173506 0.20049399 0.21069906 0.1147068  0.18334592 0.16814026]
#   [0.10843896 0.2041268  0.2058834  0.10924334 0.17825381 0.16287953]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# y_pred of day 83: [[582.06067]]
# x_pred_input of day 84:
# [[[0.12775588 0.1904455  0.22552218 0.14159515 0.20525026 0.19087568]
#   [0.12323025 0.19229843 0.22227392 0.13433357 0.19950704 0.18496732]
#   [0.1190724  0.19456742 0.21880978 0.12734435 0.1939528  0.17919504]
#   [0.11525645 0.19729684 0.21498699 0.12076558 0.188572   0.17358097]
#   [0.11173506 0.20049399 0.21069906 0.1147068  0.18334592 0.16814026]
#   [0.10843896 0.2041268  0.2058834  0.10924334 0.17825381 0.16287953]
#   [0.10528249 0.208125   0.20052589 0.10441094 0.1732712  0.15779595]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 84: [[567.3467]]
# x_pred_input of day 85:
# [[[0.12323025 0.19229843 0.22227392 0.13433357 0.19950704 0.18496732]
#   [0.1190724  0.19456742 0.21880978 0.12734435 0.1939528  0.17919504]
#   [0.11525645 0.19729684 0.21498699 0.12076558 0.188572   0.17358097]
#   [0.11173506 0.20049399 0.21069906 0.1147068  0.18334592 0.16814026]
#   [0.10843896 0.2041268  0.2058834  0.10924334 0.17825381 0.16287953]
#   [0.10528249 0.208125   0.20052589 0.10441094 0.1732712  0.15779595]
#   [0.10217025 0.21238466 0.19466005 0.10020249 0.1683688  0.1528772 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 85: [[552.39764]]
# x_pred_input of day 86:
# [[[0.1190724  0.19456742 0.21880978 0.12734435 0.1939528  0.17919504]
#   [0.11525645 0.19729684 0.21498699 0.12076558 0.188572   0.17358097]
#   [0.11173506 0.20049399 0.21069906 0.1147068  0.18334592 0.16814026]
#   [0.10843896 0.2041268  0.2058834  0.10924334 0.17825381 0.16287953]
#   [0.10528249 0.208125   0.20052589 0.10441094 0.1732712  0.15779595]
#   [0.10217025 0.21238466 0.19466005 0.10020249 0.1683688  0.1528772 ]
#   [0.09900829 0.2167773  0.18836337 0.09656735 0.16351521 0.14810247]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 86: [[536.82056]]
# x_pred_input of day 87:
# [[[0.11525645 0.19729684 0.21498699 0.12076558 0.188572   0.17358097]
#   [0.11173506 0.20049399 0.21069906 0.1147068  0.18334592 0.16814026]
#   [0.10843896 0.2041268  0.2058834  0.10924334 0.17825381 0.16287953]
#   [0.10528249 0.208125   0.20052589 0.10441094 0.1732712  0.15779595]
#   [0.10217025 0.21238466 0.19466005 0.10020249 0.1683688  0.1528772 ]
#   [0.09900829 0.2167773  0.18836337 0.09656735 0.16351521 0.14810247]
#   [0.09571349 0.22116178 0.18174882 0.09341496 0.15868016 0.14344441]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 87: [[520.2981]]
# x_pred_input of day 88:
# [[[0.11173506 0.20049399 0.21069906 0.1147068  0.18334592 0.16814026]
#   [0.10843896 0.2041268  0.2058834  0.10924334 0.17825381 0.16287953]
#   [0.10528249 0.208125   0.20052589 0.10441094 0.1732712  0.15779595]
#   [0.10217025 0.21238466 0.19466005 0.10020249 0.1683688  0.1528772 ]
#   [0.09900829 0.2167773  0.18836337 0.09656735 0.16351521 0.14810247]
#   [0.09571349 0.22116178 0.18174882 0.09341496 0.15868016 0.14344441]
#   [0.09221873 0.22539616 0.17495691 0.09061922 0.15383759 0.13887141]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 88: [[502.61133]]
# x_pred_input of day 89:
# [[[0.10843896 0.2041268  0.2058834  0.10924334 0.17825381 0.16287953]
#   [0.10528249 0.208125   0.20052589 0.10441094 0.1732712  0.15779595]
#   [0.10217025 0.21238466 0.19466005 0.10020249 0.1683688  0.1528772 ]
#   [0.09900829 0.2167773  0.18836337 0.09656735 0.16351521 0.14810247]
#   [0.09571349 0.22116178 0.18174882 0.09341496 0.15868016 0.14344441]
#   [0.09221873 0.22539616 0.17495691 0.09061922 0.15383759 0.13887141]
#   [0.0884777  0.22934921 0.16814773 0.08802467 0.14896864 0.13435008]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 89: [[483.6644]]
# x_pred_input of day 90:
# [[[0.10528249 0.208125   0.20052589 0.10441094 0.1732712  0.15779595]
#   [0.10217025 0.21238466 0.19466005 0.10020249 0.1683688  0.1528772 ]
#   [0.09900829 0.2167773  0.18836337 0.09656735 0.16351521 0.14810247]
#   [0.09571349 0.22116178 0.18174882 0.09341496 0.15868016 0.14344441]
#   [0.09221873 0.22539616 0.17495691 0.09061922 0.15383759 0.13887141]
#   [0.0884777  0.22934921 0.16814773 0.08802467 0.14896864 0.13435008]
#   [0.08447013 0.23291183 0.16149065 0.08545626 0.14406337 0.12984817]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 90: [[463.49182]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#            Close        MACD  Bollinger_Upper  Bollinger_Lower        MA26  \
# 0     227.181000    0.000000       463.491821       463.491821  463.491821
# 1     220.488998   -0.533835       463.491821       463.491821  463.491821
# 2     222.218002   -0.808072       463.491821       463.491821  463.491821
# 3     227.600998   -0.584308       463.491821       463.491821  463.491821
# 4     225.119995   -0.600251       463.491821       463.491821  463.491821
# ...          ...         ...              ...              ...         ...
# 2155  536.820557 -172.071058       994.808202       450.192903  793.474720
# 2156  520.298096 -168.665009       962.044386       438.654882  772.353063
# 2157  502.611328 -165.485254       929.197250       427.947171  751.116354
# 2158  483.664398 -162.619557       897.083795       417.347317  729.721211
# 2159  463.491821 -160.130346       866.487484       406.120008  708.163402
#
#            EMA20
# 0     227.181000
# 1     226.543666
# 2     226.131698
# 3     226.271632
# 4     226.161952
# ...          ...
# 2155  731.013073
# 2156  710.944980
# 2157  691.103680
# 2158  671.347558
# 2159  651.551773
#
# [2160 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
# Dateframe of Close training set
df_train = df_filtered['Close'][:train_size].copy()

# Plot the forecast for df_val, df_test and df_forecast
plt.figure(figsize=(15, 7))
plt.plot(df_train, label='Train')
plt.plot(df_test['Y_test_pred'], label='Test prediction')
plt.plot(df_test['Y_test'], label='Test')
plt.plot(df_forecast_unscale['Close'], label='Forecast next 30 days')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  131.77894090556322
# MAPE:  3.6375506267662416
# SMAPE:  3.734877623300008
