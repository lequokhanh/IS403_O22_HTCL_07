# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../.dataset/ETH-USD-3.2018-3.2024.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 1  2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2  2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 3  2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 4  2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#        Volume
# 0  1868519936
# 1  1894419968
# 2  1699369984
# 3  1697939968
# 4  1898489984

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#                 Volume
# Date
# 2018-03-01  1868519936
# 2018-03-02  1894419968
# 2018-03-03  1699369984
# 2018-03-04  1697939968
# 2018-03-05  1898489984

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('ETH/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (1978, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.90)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1780, 6) (198, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1773, 7, 6) (1773,)
# (191, 7, 6) (191,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1773, 7, 6) (1773,)
# (191, 7, 6) (191,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
# model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
# model.add(Dense(1))
model.add(SimpleRNN(n_neurons, return_sequences=True,
          input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(SimpleRNN(n_neurons, return_sequences=True))
model.add(SimpleRNN(n_neurons))
model.add(Dense(1))


# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# 28/28 [==============================] - 8s 74ms/step - loss: 0.0519 - val_loss: 0.0022
# Epoch 2/100
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 3/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.0012 - val_loss: 4.8821e-04
# Epoch 4/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.0010 - val_loss: 7.2362e-04
# Epoch 5/100
# 28/28 [==============================] - 1s 30ms/step - loss: 8.8811e-04 - val_loss: 5.5403e-04
# Epoch 6/100
# 28/28 [==============================] - 1s 34ms/step - loss: 8.4987e-04 - val_loss: 9.9231e-04
# Epoch 7/100
# 28/28 [==============================] - 1s 30ms/step - loss: 8.1081e-04 - val_loss: 5.4379e-04
# Epoch 8/100
# 28/28 [==============================] - 1s 27ms/step - loss: 6.9833e-04 - val_loss: 4.5241e-04
# Epoch 9/100
# 28/28 [==============================] - 1s 27ms/step - loss: 6.8667e-04 - val_loss: 3.0586e-04
# Epoch 10/100
# 28/28 [==============================] - 1s 31ms/step - loss: 6.4728e-04 - val_loss: 3.8582e-04
# Epoch 11/100
# 28/28 [==============================] - 1s 29ms/step - loss: 6.0761e-04 - val_loss: 3.2349e-04
# Epoch 12/100
# 28/28 [==============================] - 1s 31ms/step - loss: 5.9175e-04 - val_loss: 2.7059e-04
# Epoch 13/100
# 28/28 [==============================] - 1s 28ms/step - loss: 6.0408e-04 - val_loss: 3.0230e-04
# Epoch 14/100
# 28/28 [==============================] - 1s 25ms/step - loss: 5.7524e-04 - val_loss: 3.0218e-04
# Epoch 15/100
# 28/28 [==============================] - 1s 29ms/step - loss: 5.6378e-04 - val_loss: 2.7388e-04
# Epoch 16/100
# 28/28 [==============================] - 1s 26ms/step - loss: 5.6143e-04 - val_loss: 3.9018e-04
# Epoch 17/100
# 28/28 [==============================] - 1s 25ms/step - loss: 5.5096e-04 - val_loss: 2.8226e-04
# Epoch 18/100
# 28/28 [==============================] - 1s 30ms/step - loss: 5.1024e-04 - val_loss: 2.4185e-04
# Epoch 19/100
# 28/28 [==============================] - 1s 25ms/step - loss: 5.6565e-04 - val_loss: 2.3958e-04
# Epoch 20/100
# 28/28 [==============================] - 1s 28ms/step - loss: 5.7504e-04 - val_loss: 2.8525e-04
# Epoch 21/100
# 28/28 [==============================] - 1s 27ms/step - loss: 5.2519e-04 - val_loss: 2.8525e-04
# Epoch 22/100
# 28/28 [==============================] - 1s 25ms/step - loss: 5.3723e-04 - val_loss: 3.0922e-04
# Epoch 23/100
# 28/28 [==============================] - 1s 28ms/step - loss: 4.7359e-04 - val_loss: 2.7858e-04
# Epoch 24/100
# 28/28 [==============================] - 1s 28ms/step - loss: 5.0266e-04 - val_loss: 3.4673e-04
# Epoch 25/100
# 28/28 [==============================] - 1s 26ms/step - loss: 4.6813e-04 - val_loss: 2.4823e-04
# Epoch 26/100
# 28/28 [==============================] - 1s 24ms/step - loss: 5.0403e-04 - val_loss: 3.7626e-04
# Epoch 27/100
# 28/28 [==============================] - 1s 31ms/step - loss: 4.6332e-04 - val_loss: 5.3262e-04
# Epoch 28/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.6148e-04 - val_loss: 2.2744e-04
# Epoch 29/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.3148e-04 - val_loss: 2.1973e-04
# Epoch 30/100
# 28/28 [==============================] - 1s 28ms/step - loss: 4.5631e-04 - val_loss: 3.1269e-04
# Epoch 31/100
# 28/28 [==============================] - 1s 31ms/step - loss: 4.7782e-04 - val_loss: 2.8486e-04
# Epoch 32/100
# 28/28 [==============================] - 1s 28ms/step - loss: 4.5494e-04 - val_loss: 3.1315e-04
# Epoch 33/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.2014e-04 - val_loss: 2.0306e-04
# Epoch 34/100
# 28/28 [==============================] - 1s 30ms/step - loss: 5.0490e-04 - val_loss: 2.1342e-04
# Epoch 35/100
# 28/28 [==============================] - 1s 32ms/step - loss: 5.3634e-04 - val_loss: 2.2974e-04
# Epoch 36/100
# 28/28 [==============================] - 1s 30ms/step - loss: 4.7212e-04 - val_loss: 3.2568e-04
# Epoch 37/100
# 28/28 [==============================] - 1s 26ms/step - loss: 4.5299e-04 - val_loss: 1.9018e-04
# Epoch 38/100
# 28/28 [==============================] - 1s 24ms/step - loss: 4.1133e-04 - val_loss: 3.2089e-04
# Epoch 39/100
# 28/28 [==============================] - 1s 28ms/step - loss: 4.5319e-04 - val_loss: 2.8841e-04
# Epoch 40/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.9065e-04 - val_loss: 2.0061e-04
# Epoch 41/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.2505e-04 - val_loss: 8.4552e-04
# Epoch 42/100
# 28/28 [==============================] - 1s 32ms/step - loss: 6.7706e-04 - val_loss: 2.4596e-04
# Epoch 43/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.7142e-04 - val_loss: 2.4177e-04
# Epoch 44/100
# 28/28 [==============================] - 1s 25ms/step - loss: 4.0373e-04 - val_loss: 2.2241e-04
# Epoch 45/100
# 28/28 [==============================] - 1s 25ms/step - loss: 4.2496e-04 - val_loss: 1.7849e-04
# Epoch 46/100
# 28/28 [==============================] - 1s 30ms/step - loss: 4.3981e-04 - val_loss: 1.7834e-04
# Epoch 47/100
# 28/28 [==============================] - 1s 25ms/step - loss: 4.8202e-04 - val_loss: 2.4735e-04
# Epoch 48/100
# 28/28 [==============================] - 1s 28ms/step - loss: 5.2147e-04 - val_loss: 3.7956e-04
# Epoch 49/100
# 28/28 [==============================] - 1s 24ms/step - loss: 3.8296e-04 - val_loss: 9.4203e-04
# Epoch 50/100
# 28/28 [==============================] - 1s 26ms/step - loss: 4.2812e-04 - val_loss: 1.7788e-04
# Epoch 51/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.1659e-04 - val_loss: 3.3150e-04
# Epoch 52/100
# 28/28 [==============================] - 1s 25ms/step - loss: 4.4388e-04 - val_loss: 2.2250e-04
# Epoch 53/100
# 28/28 [==============================] - 1s 27ms/step - loss: 3.8892e-04 - val_loss: 1.7393e-04
# Epoch 54/100
# 28/28 [==============================] - 1s 23ms/step - loss: 4.6178e-04 - val_loss: 4.9113e-04
# Epoch 55/100
# 28/28 [==============================] - 1s 24ms/step - loss: 6.4472e-04 - val_loss: 2.0056e-04
# Epoch 56/100
# 28/28 [==============================] - 1s 24ms/step - loss: 4.0652e-04 - val_loss: 1.7167e-04
# Epoch 57/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.7462e-04 - val_loss: 1.8666e-04
# Epoch 58/100
# 28/28 [==============================] - 1s 24ms/step - loss: 3.9296e-04 - val_loss: 1.7122e-04
# Epoch 59/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.7932e-04 - val_loss: 1.7756e-04
# Epoch 60/100
# 28/28 [==============================] - 1s 31ms/step - loss: 3.5863e-04 - val_loss: 1.9901e-04
# Epoch 61/100
# 28/28 [==============================] - 1s 25ms/step - loss: 5.8687e-04 - val_loss: 1.8143e-04
# Epoch 62/100
# 28/28 [==============================] - 1s 30ms/step - loss: 4.2078e-04 - val_loss: 2.3527e-04
# Epoch 63/100
# 28/28 [==============================] - 1s 25ms/step - loss: 4.5238e-04 - val_loss: 2.7419e-04
# Epoch 64/100
# 28/28 [==============================] - 1s 32ms/step - loss: 4.8658e-04 - val_loss: 1.6674e-04
# Epoch 65/100
# 28/28 [==============================] - 1s 25ms/step - loss: 4.3681e-04 - val_loss: 5.5134e-04
# Epoch 66/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.1757e-04 - val_loss: 1.7093e-04
# Epoch 67/100
# 28/28 [==============================] - 1s 25ms/step - loss: 5.3572e-04 - val_loss: 3.2109e-04
# Epoch 68/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.3179e-04 - val_loss: 3.2945e-04
# Epoch 69/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.5172e-04 - val_loss: 2.2699e-04
# Epoch 70/100
# 28/28 [==============================] - 1s 25ms/step - loss: 6.2554e-04 - val_loss: 4.6073e-04
# Epoch 71/100
# 28/28 [==============================] - 1s 26ms/step - loss: 5.3431e-04 - val_loss: 1.7335e-04
# Epoch 72/100
# 28/28 [==============================] - 1s 27ms/step - loss: 3.4259e-04 - val_loss: 1.8364e-04
# Epoch 73/100
# 28/28 [==============================] - 1s 30ms/step - loss: 4.5850e-04 - val_loss: 7.3020e-04
# Epoch 74/100
# 28/28 [==============================] - 1s 24ms/step - loss: 6.2543e-04 - val_loss: 4.4681e-04
# Epoch 75/100
# 28/28 [==============================] - 1s 26ms/step - loss: 4.5175e-04 - val_loss: 0.0011
# Epoch 76/100
# 28/28 [==============================] - 1s 26ms/step - loss: 3.8887e-04 - val_loss: 1.6311e-04
# Epoch 77/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.3564e-04 - val_loss: 2.6139e-04
# Epoch 78/100
# 28/28 [==============================] - 1s 26ms/step - loss: 4.0167e-04 - val_loss: 2.1000e-04
# Epoch 79/100
# 28/28 [==============================] - 1s 24ms/step - loss: 4.0476e-04 - val_loss: 1.5814e-04
# Epoch 80/100
# 28/28 [==============================] - 1s 27ms/step - loss: 3.2045e-04 - val_loss: 2.1637e-04
# Epoch 81/100
# 28/28 [==============================] - 1s 25ms/step - loss: 3.7231e-04 - val_loss: 1.6621e-04
# Epoch 82/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.2029e-04 - val_loss: 1.6582e-04
# Epoch 83/100
# 28/28 [==============================] - 1s 27ms/step - loss: 4.0338e-04 - val_loss: 2.3756e-04
# Epoch 84/100
# 28/28 [==============================] - 1s 27ms/step - loss: 3.3639e-04 - val_loss: 2.7417e-04
# Epoch 85/100
# 28/28 [==============================] - 1s 27ms/step - loss: 3.4218e-04 - val_loss: 3.7739e-04
# Epoch 86/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.9111e-04 - val_loss: 1.6046e-04
# Epoch 87/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.3252e-04 - val_loss: 5.7828e-04
# Epoch 88/100
# 28/28 [==============================] - 1s 25ms/step - loss: 3.5928e-04 - val_loss: 3.5328e-04
# Epoch 89/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.6764e-04 - val_loss: 4.4704e-04
# Epoch 90/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.0605e-04 - val_loss: 2.9754e-04
# Epoch 91/100
# 28/28 [==============================] - 1s 30ms/step - loss: 3.6716e-04 - val_loss: 3.6408e-04
# Epoch 92/100
# 28/28 [==============================] - 1s 32ms/step - loss: 3.8299e-04 - val_loss: 1.8775e-04
# Epoch 93/100
# 28/28 [==============================] - 1s 25ms/step - loss: 5.2943e-04 - val_loss: 2.0889e-04
# Epoch 94/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.3284e-04 - val_loss: 1.8585e-04
# Epoch 95/100
# 28/28 [==============================] - 1s 24ms/step - loss: 3.4556e-04 - val_loss: 1.7960e-04
# Epoch 96/100
# 28/28 [==============================] - 1s 25ms/step - loss: 3.3900e-04 - val_loss: 3.5087e-04
# Epoch 97/100
# 28/28 [==============================] - 1s 27ms/step - loss: 4.9705e-04 - val_loss: 1.6017e-04
# Epoch 98/100
# 28/28 [==============================] - 1s 27ms/step - loss: 3.7736e-04 - val_loss: 4.1817e-04
# Epoch 99/100
# 28/28 [==============================] - 1s 28ms/step - loss: 4.6686e-04 - val_loss: 1.6533e-04
# Epoch 100/100
# 28/28 [==============================] - 1s 24ms/step - loss: 4.2397e-04 - val_loss: 3.9223e-04

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (198, 7, 6)
# 7/7 [==============================] - 0s 4ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.61510439 0.61955538 0.63512207 0.52653685 0.57656614 0.60530042]
#   [0.64055213 0.63046936 0.64170957 0.53855599 0.58334023 0.61300222]
#   [0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140929]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043776]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.6416704 ]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088305]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123953]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 1: [[3402.0342]]
# x_pred_input of day 2:
# [[[0.64055213 0.63046936 0.64170957 0.53855599 0.58334023 0.61300228]
#   [0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140936]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70175146 0.7102189  0.70247318 0.59537319 0.63809478 0.66989313]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 2: [[3383.509]]
# x_pred_input of day 3:
# [[[0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140936]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70175146 0.7102189  0.70247318 0.59537319 0.63809478 0.66989313]
#   [0.6978331  0.70867783 0.70924409 0.60503558 0.64701257 0.67732049]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 3: [[3366.6135]]
# x_pred_input of day 4:
# [[[0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70175146 0.7102189  0.70247318 0.59537319 0.63809478 0.66989313]
#   [0.6978331  0.70867783 0.70924409 0.60503558 0.64701257 0.67732049]
#   [0.69425943 0.70240253 0.71250903 0.61877263 0.65532687 0.68367381]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 4: [[3347.683]]
# x_pred_input of day 5:
# [[[0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70175146 0.7102189  0.70247318 0.59537319 0.63809478 0.66989313]
#   [0.6978331  0.70867783 0.70924409 0.60503558 0.64701257 0.67732049]
#   [0.69425943 0.70240253 0.71250903 0.61877263 0.65532687 0.68367381]
#   [0.69025535 0.69228094 0.71636467 0.62807202 0.66350809 0.68901122]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 5: [[3312.5874]]
# x_pred_input of day 6:
# [[[0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70175146 0.7102189  0.70247318 0.59537319 0.63809478 0.66989313]
#   [0.6978331  0.70867783 0.70924409 0.60503558 0.64701257 0.67732049]
#   [0.69425943 0.70240253 0.71250903 0.61877263 0.65532687 0.68367381]
#   [0.69025535 0.69228094 0.71636467 0.62807202 0.66350809 0.68901122]
#   [0.68283205 0.67760386 0.71864407 0.63723729 0.67078365 0.69307864]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 6: [[3282.9092]]
# x_pred_input of day 7:
# [[[0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70175146 0.7102189  0.70247318 0.59537319 0.63809478 0.66989313]
#   [0.6978331  0.70867783 0.70924409 0.60503558 0.64701257 0.67732049]
#   [0.69425943 0.70240253 0.71250903 0.61877263 0.65532687 0.68367381]
#   [0.69025535 0.69228094 0.71636467 0.62807202 0.66350809 0.68901122]
#   [0.68283205 0.67760386 0.71864407 0.63723729 0.67078365 0.69307864]
#   [0.67655464 0.66008035 0.71837197 0.6491671  0.67767658 0.69611461]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 7: [[3245.6218]]
# x_pred_input of day 8:
# [[[0.70175146 0.7102189  0.70247318 0.59537319 0.63809478 0.66989313]
#   [0.6978331  0.70867783 0.70924409 0.60503558 0.64701257 0.67732049]
#   [0.69425943 0.70240253 0.71250903 0.61877263 0.65532687 0.68367381]
#   [0.69025535 0.69228094 0.71636467 0.62807202 0.66350809 0.68901122]
#   [0.68283205 0.67760386 0.71864407 0.63723729 0.67078365 0.69307864]
#   [0.67655464 0.66008035 0.71837197 0.6491671  0.67767658 0.69611461]
#   [0.66866777 0.63974631 0.71518326 0.66401492 0.68418478 0.69805221]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 8: [[3205.625]]
# x_pred_input of day 9:
# [[[0.6978331  0.70867783 0.70924409 0.60503558 0.64701257 0.67732049]
#   [0.69425943 0.70240253 0.71250903 0.61877263 0.65532687 0.68367381]
#   [0.69025535 0.69228094 0.71636467 0.62807202 0.66350809 0.68901122]
#   [0.68283205 0.67760386 0.71864407 0.63723729 0.67078365 0.69307864]
#   [0.67655464 0.66008035 0.71837197 0.6491671  0.67767658 0.69611461]
#   [0.66866777 0.63974631 0.71518326 0.66401492 0.68418478 0.69805221]
#   [0.66020781 0.6171642  0.71265233 0.67488764 0.68901276 0.69893726]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 9: [[3168.2097]]
# x_pred_input of day 10:
# [[[0.69425943 0.70240253 0.71250903 0.61877263 0.65532687 0.68367381]
#   [0.69025535 0.69228094 0.71636467 0.62807202 0.66350809 0.68901122]
#   [0.68283205 0.67760386 0.71864407 0.63723729 0.67078365 0.69307864]
#   [0.67655464 0.66008035 0.71837197 0.6491671  0.67767658 0.69611461]
#   [0.66866777 0.63974631 0.71518326 0.66401492 0.68418478 0.69805221]
#   [0.66020781 0.6171642  0.71265233 0.67488764 0.68901276 0.69893726]
#   [0.65229389 0.59334282 0.71061115 0.68271657 0.69365129 0.69892601]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 10: [[3131.4175]]
# x_pred_input of day 11:
# [[[0.69025535 0.69228094 0.71636467 0.62807202 0.66350809 0.68901122]
#   [0.68283205 0.67760386 0.71864407 0.63723729 0.67078365 0.69307864]
#   [0.67655464 0.66008035 0.71837197 0.6491671  0.67767658 0.69611461]
#   [0.66866777 0.63974631 0.71518326 0.66401492 0.68418478 0.69805221]
#   [0.66020781 0.6171642  0.71265233 0.67488764 0.68901276 0.69893726]
#   [0.65229389 0.59334282 0.71061115 0.68271657 0.69365129 0.69892601]
#   [0.64451175 0.56888584 0.7095532  0.6868103  0.69676862 0.69811736]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 11: [[3092.735]]
# x_pred_input of day 12:
# [[[0.68283205 0.67760386 0.71864407 0.63723729 0.67078365 0.69307864]
#   [0.67655464 0.66008035 0.71837197 0.6491671  0.67767658 0.69611461]
#   [0.66866777 0.63974631 0.71518326 0.66401492 0.68418478 0.69805221]
#   [0.66020781 0.6171642  0.71265233 0.67488764 0.68901276 0.69893726]
#   [0.65229389 0.59334282 0.71061115 0.68271657 0.69365129 0.69892601]
#   [0.64451175 0.56888584 0.7095532  0.6868103  0.69676862 0.69811736]
#   [0.63632982 0.54401582 0.70755335 0.69211321 0.69913501 0.69654623]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 12: [[3056.0876]]
# x_pred_input of day 13:
# [[[0.67655464 0.66008035 0.71837197 0.6491671  0.67767658 0.69611461]
#   [0.66866777 0.63974631 0.71518326 0.66401492 0.68418478 0.69805221]
#   [0.66020781 0.6171642  0.71265233 0.67488764 0.68901276 0.69893726]
#   [0.65229389 0.59334282 0.71061115 0.68271657 0.69365129 0.69892601]
#   [0.64451175 0.56888584 0.7095532  0.6868103  0.69676862 0.69811736]
#   [0.63632982 0.54401582 0.70755335 0.69211321 0.69913501 0.69654623]
#   [0.6285783  0.51931423 0.70576585 0.69626412 0.70136066 0.69432939]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 13: [[3019.8494]]
# x_pred_input of day 14:
# [[[0.66866777 0.63974631 0.71518326 0.66401492 0.68418478 0.69805221]
#   [0.66020781 0.6171642  0.71265233 0.67488764 0.68901276 0.69893726]
#   [0.65229389 0.59334282 0.71061115 0.68271657 0.69365129 0.69892601]
#   [0.64451175 0.56888584 0.7095532  0.6868103  0.69676862 0.69811736]
#   [0.63632982 0.54401582 0.70755335 0.69211321 0.69913501 0.69654623]
#   [0.6285783  0.51931423 0.70576585 0.69626412 0.70136066 0.69432939]
#   [0.62091333 0.49506805 0.70281003 0.70209833 0.70341684 0.69153723]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 14: [[2982.6267]]
# x_pred_input of day 15:
# [[[0.66020781 0.6171642  0.71265233 0.67488764 0.68901276 0.69893726]
#   [0.65229389 0.59334282 0.71061115 0.68271657 0.69365129 0.69892601]
#   [0.64451175 0.56888584 0.7095532  0.6868103  0.69676862 0.69811736]
#   [0.63632982 0.54401582 0.70755335 0.69211321 0.69913501 0.69654623]
#   [0.6285783  0.51931423 0.70576585 0.69626412 0.70136066 0.69432939]
#   [0.62091333 0.49506805 0.70281003 0.70209833 0.70341684 0.69153723]
#   [0.61304015 0.47135407 0.70309369 0.70153031 0.70433064 0.68820316]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 15: [[2946.2546]]
# x_pred_input of day 16:
# [[[0.65229389 0.59334282 0.71061115 0.68271657 0.69365129 0.69892601]
#   [0.64451175 0.56888584 0.7095532  0.6868103  0.69676862 0.69811736]
#   [0.63632982 0.54401582 0.70755335 0.69211321 0.69913501 0.69654623]
#   [0.6285783  0.51931423 0.70576585 0.69626412 0.70136066 0.69432939]
#   [0.62091333 0.49506805 0.70281003 0.70209833 0.70341684 0.69153723]
#   [0.61304015 0.47135407 0.70309369 0.70153031 0.70433064 0.68820316]
#   [0.60534688 0.4484145  0.70645678 0.69356626 0.70435427 0.68439727]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 16: [[2913.907]]
# x_pred_input of day 17:
# [[[0.64451175 0.56888584 0.7095532  0.6868103  0.69676862 0.69811736]
#   [0.63632982 0.54401582 0.70755335 0.69211321 0.69913501 0.69654623]
#   [0.6285783  0.51931423 0.70576585 0.69626412 0.70136066 0.69432939]
#   [0.62091333 0.49506805 0.70281003 0.70209833 0.70341684 0.69153723]
#   [0.61304015 0.47135407 0.70309369 0.70153031 0.70433064 0.68820316]
#   [0.60534688 0.4484145  0.70645678 0.69356626 0.70435427 0.68439727]
#   [0.59850484 0.4267557  0.71008143 0.68290628 0.70347602 0.68025183]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 17: [[2883.2964]]
# x_pred_input of day 18:
# [[[0.63632982 0.54401582 0.70755335 0.69211321 0.69913501 0.69654623]
#   [0.6285783  0.51931423 0.70576585 0.69626412 0.70136066 0.69432939]
#   [0.62091333 0.49506805 0.70281003 0.70209833 0.70341684 0.69153723]
#   [0.61304015 0.47135407 0.70309369 0.70153031 0.70433064 0.68820316]
#   [0.60534688 0.4484145  0.70645678 0.69356626 0.70435427 0.68439727]
#   [0.59850484 0.4267557  0.71008143 0.68290628 0.70347602 0.68025183]
#   [0.59203022 0.40652526 0.71273643 0.67105027 0.70270833 0.67583687]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 18: [[2858.3352]]
# x_pred_input of day 19:
# [[[0.6285783  0.51931423 0.70576585 0.69626412 0.70136066 0.69432939]
#   [0.62091333 0.49506805 0.70281003 0.70209833 0.70341684 0.69153723]
#   [0.61304015 0.47135407 0.70309369 0.70153031 0.70433064 0.68820316]
#   [0.60534688 0.4484145  0.70645678 0.69356626 0.70435427 0.68439727]
#   [0.59850484 0.4267557  0.71008143 0.68290628 0.70347602 0.68025183]
#   [0.59203022 0.40652526 0.71273643 0.67105027 0.70270833 0.67583687]
#   [0.58675053 0.38822367 0.71100035 0.66030105 0.70171477 0.67130066]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 19: [[2831.3374]]
# x_pred_input of day 20:
# [[[0.62091333 0.49506805 0.70281003 0.70209833 0.70341684 0.69153723]
#   [0.61304015 0.47135407 0.70309369 0.70153031 0.70433064 0.68820316]
#   [0.60534688 0.4484145  0.70645678 0.69356626 0.70435427 0.68439727]
#   [0.59850484 0.4267557  0.71008143 0.68290628 0.70347602 0.68025183]
#   [0.59203022 0.40652526 0.71273643 0.67105027 0.70270833 0.67583687]
#   [0.58675053 0.38822367 0.71100035 0.66030105 0.70171477 0.67130066]
#   [0.58104007 0.37143305 0.70968807 0.64946322 0.70091832 0.66661056]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 20: [[2806.8538]]
# x_pred_input of day 21:
# [[[0.61304015 0.47135407 0.70309369 0.70153031 0.70433064 0.68820316]
#   [0.60534688 0.4484145  0.70645678 0.69356626 0.70435427 0.68439727]
#   [0.59850484 0.4267557  0.71008143 0.68290628 0.70347602 0.68025183]
#   [0.59203022 0.40652526 0.71273643 0.67105027 0.70270833 0.67583687]
#   [0.58675053 0.38822367 0.71100035 0.66030105 0.70171477 0.67130066]
#   [0.58104007 0.37143305 0.70968807 0.64946322 0.70091832 0.66661056]
#   [0.57586139 0.35627534 0.70363165 0.64132072 0.69928228 0.66183579]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 21: [[2774.4604]]
# x_pred_input of day 22:
# [[[0.60534688 0.4484145  0.70645678 0.69356626 0.70435427 0.68439727]
#   [0.59850484 0.4267557  0.71008143 0.68290628 0.70347602 0.68025183]
#   [0.59203022 0.40652526 0.71273643 0.67105027 0.70270833 0.67583687]
#   [0.58675053 0.38822367 0.71100035 0.66030105 0.70171477 0.67130066]
#   [0.58104007 0.37143305 0.70968807 0.64946322 0.70091832 0.66661056]
#   [0.57586139 0.35627534 0.70363165 0.64132072 0.69928228 0.66183579]
#   [0.5690097  0.34175878 0.697668   0.63308496 0.69629968 0.65681274]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 22: [[2740.006]]
# x_pred_input of day 23:
# [[[0.59850484 0.4267557  0.71008143 0.68290628 0.70347602 0.68025183]
#   [0.59203022 0.40652526 0.71273643 0.67105027 0.70270833 0.67583687]
#   [0.58675053 0.38822367 0.71100035 0.66030105 0.70171477 0.67130066]
#   [0.58104007 0.37143305 0.70968807 0.64946322 0.70091832 0.66661056]
#   [0.57586139 0.35627534 0.70363165 0.64132072 0.69928228 0.66183579]
#   [0.5690097  0.34175878 0.697668   0.63308496 0.69629968 0.65681274]
#   [0.56172206 0.32769865 0.69118262 0.62507307 0.69242864 0.65152034]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 23: [[2698.4175]]
# x_pred_input of day 24:
# [[[0.59203022 0.40652526 0.71273643 0.67105027 0.70270833 0.67583687]
#   [0.58675053 0.38822367 0.71100035 0.66030105 0.70171477 0.67130066]
#   [0.58104007 0.37143305 0.70968807 0.64946322 0.70091832 0.66661056]
#   [0.57586139 0.35627534 0.70363165 0.64132072 0.69928228 0.66183579]
#   [0.5690097  0.34175878 0.697668   0.63308496 0.69629968 0.65681274]
#   [0.56172206 0.32769865 0.69118262 0.62507307 0.69242864 0.65152034]
#   [0.55292541 0.3134249  0.68419184 0.6170536  0.68761307 0.64582941]]]
# 1/1 [==============================] - 0s 59ms/step
# y_pred of day 24: [[2653.5332]]
# x_pred_input of day 25:
# [[[0.58675053 0.38822367 0.71100035 0.66030105 0.70171477 0.67130066]
#   [0.58104007 0.37143305 0.70968807 0.64946322 0.70091832 0.66661056]
#   [0.57586139 0.35627534 0.70363165 0.64132072 0.69928228 0.66183579]
#   [0.5690097  0.34175878 0.697668   0.63308496 0.69629968 0.65681274]
#   [0.56172206 0.32769865 0.69118262 0.62507307 0.69242864 0.65152034]
#   [0.55292541 0.3134249  0.68419184 0.6170536  0.68761307 0.64582941]
#   [0.54343167 0.29880857 0.67676773 0.60891175 0.68115672 0.63970638]]]
# 1/1 [==============================] - 0s 26ms/step
# y_pred of day 25: [[2602.3152]]
# x_pred_input of day 26:
# [[[0.58104007 0.37143305 0.70968807 0.64946322 0.70091832 0.66661056]
#   [0.57586139 0.35627534 0.70363165 0.64132072 0.69928228 0.66183579]
#   [0.5690097  0.34175878 0.697668   0.63308496 0.69629968 0.65681274]
#   [0.56172206 0.32769865 0.69118262 0.62507307 0.69242864 0.65152034]
#   [0.55292541 0.3134249  0.68419184 0.6170536  0.68761307 0.64582941]
#   [0.54343167 0.29880857 0.67676773 0.60891175 0.68115672 0.63970638]
#   [0.53259825 0.28344101 0.66978958 0.59985798 0.67463482 0.63305494]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 26: [[2546.9146]]
# x_pred_input of day 27:
# [[[0.57586139 0.35627534 0.70363165 0.64132072 0.69928228 0.66183579]
#   [0.5690097  0.34175878 0.697668   0.63308496 0.69629968 0.65681274]
#   [0.56172206 0.32769865 0.69118262 0.62507307 0.69242864 0.65152034]
#   [0.55292541 0.3134249  0.68419184 0.6170536  0.68761307 0.64582941]
#   [0.54343167 0.29880857 0.67676773 0.60891175 0.68115672 0.63970638]
#   [0.53259825 0.28344101 0.66978958 0.59985798 0.67463482 0.63305494]
#   [0.52088014 0.26723119 0.66305994 0.58989046 0.66680313 0.62583465]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 27: [[2486.5293]]
# x_pred_input of day 28:
# [[[0.5690097  0.34175878 0.697668   0.63308496 0.69629968 0.65681274]
#   [0.56172206 0.32769865 0.69118262 0.62507307 0.69242864 0.65152034]
#   [0.55292541 0.3134249  0.68419184 0.6170536  0.68761307 0.64582941]
#   [0.54343167 0.29880857 0.67676773 0.60891175 0.68115672 0.63970638]
#   [0.53259825 0.28344101 0.66978958 0.59985798 0.67463482 0.63305494]
#   [0.52088014 0.26723119 0.66305994 0.58989046 0.66680313 0.62583465]
#   [0.50810771 0.25003515 0.65702316 0.57855341 0.65873013 0.61799151]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 28: [[2423.5483]]
# x_pred_input of day 29:
# [[[0.56172206 0.32769865 0.69118262 0.62507307 0.69242864 0.65152034]
#   [0.55292541 0.3134249  0.68419184 0.6170536  0.68761307 0.64582941]
#   [0.54343167 0.29880857 0.67676773 0.60891175 0.68115672 0.63970638]
#   [0.53259825 0.28344101 0.66978958 0.59985798 0.67463482 0.63305494]
#   [0.52088014 0.26723119 0.66305994 0.58989046 0.66680313 0.62583465]
#   [0.50810771 0.25003515 0.65702316 0.57855341 0.65873013 0.61799151]
#   [0.49478624 0.23199627 0.65179508 0.56571416 0.65026511 0.6095285 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 29: [[2358.9778]]
# x_pred_input of day 30:
# [[[0.55292541 0.3134249  0.68419184 0.6170536  0.68761307 0.64582941]
#   [0.54343167 0.29880857 0.67676773 0.60891175 0.68115672 0.63970638]
#   [0.53259825 0.28344101 0.66978958 0.59985798 0.67463482 0.63305494]
#   [0.52088014 0.26723119 0.66305994 0.58989046 0.66680313 0.62583465]
#   [0.50810771 0.25003515 0.65702316 0.57855341 0.65873013 0.61799151]
#   [0.49478624 0.23199627 0.65179508 0.56571416 0.65026511 0.6095285 ]
#   [0.48112855 0.21333964 0.64717578 0.55150534 0.64137969 0.60047016]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 30: [[2290.6384]]
# x_pred_input of day 31:
# [[[0.54343167 0.29880857 0.67676773 0.60891175 0.68115672 0.63970638]
#   [0.53259825 0.28344101 0.66978958 0.59985798 0.67463482 0.63305494]
#   [0.52088014 0.26723119 0.66305994 0.58989046 0.66680313 0.62583465]
#   [0.50810771 0.25003515 0.65702316 0.57855341 0.65873013 0.61799151]
#   [0.49478624 0.23199627 0.65179508 0.56571416 0.65026511 0.6095285 ]
#   [0.48112855 0.21333964 0.64717578 0.55150534 0.64137969 0.60047016]
#   [0.46667369 0.19402522 0.64310498 0.53589098 0.63205857 0.5907914 ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 31: [[2219.5027]]
# x_pred_input of day 32:
# [[[0.53259825 0.28344101 0.66978958 0.59985798 0.67463482 0.63305494]
#   [0.52088014 0.26723119 0.66305994 0.58989046 0.66680313 0.62583465]
#   [0.50810771 0.25003515 0.65702316 0.57855341 0.65873013 0.61799151]
#   [0.49478624 0.23199627 0.65179508 0.56571416 0.65026511 0.6095285 ]
#   [0.48112855 0.21333964 0.64717578 0.55150534 0.64137969 0.60047016]
#   [0.46667369 0.19402522 0.64310498 0.53589098 0.63205857 0.5907914 ]
#   [0.45162736 0.17412885 0.63958013 0.51885211 0.62241966 0.58049061]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 32: [[2148.1172]]
# x_pred_input of day 33:
# [[[0.52088014 0.26723119 0.66305994 0.58989046 0.66680313 0.62583465]
#   [0.50810771 0.25003515 0.65702316 0.57855341 0.65873013 0.61799151]
#   [0.49478624 0.23199627 0.65179508 0.56571416 0.65026511 0.6095285 ]
#   [0.48112855 0.21333964 0.64717578 0.55150534 0.64137969 0.60047016]
#   [0.46667369 0.19402522 0.64310498 0.53589098 0.63205857 0.5907914 ]
#   [0.45162736 0.17412885 0.63958013 0.51885211 0.62241966 0.58049061]
#   [0.4365282  0.15397766 0.63633158 0.50064856 0.61241296 0.56962162]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 33: [[2075.2634]]
# x_pred_input of day 34:
# [[[0.50810771 0.25003515 0.65702316 0.57855341 0.65873013 0.61799151]
#   [0.49478624 0.23199627 0.65179508 0.56571416 0.65026511 0.6095285 ]
#   [0.48112855 0.21333964 0.64717578 0.55150534 0.64137969 0.60047016]
#   [0.46667369 0.19402522 0.64310498 0.53589098 0.63205857 0.5907914 ]
#   [0.45162736 0.17412885 0.63958013 0.51885211 0.62241966 0.58049061]
#   [0.4365282  0.15397766 0.63633158 0.50064856 0.61241296 0.56962162]
#   [0.42111848 0.13370594 0.63321083 0.4814084  0.60209263 0.55820667]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 34: [[2004.8551]]
# x_pred_input of day 35:
# [[[0.49478624 0.23199627 0.65179508 0.56571416 0.65026511 0.6095285 ]
#   [0.48112855 0.21333964 0.64717578 0.55150534 0.64137969 0.60047016]
#   [0.46667369 0.19402522 0.64310498 0.53589098 0.63205857 0.5907914 ]
#   [0.45162736 0.17412885 0.63958013 0.51885211 0.62241966 0.58049061]
#   [0.4365282  0.15397766 0.63633158 0.50064856 0.61241296 0.56962162]
#   [0.42111848 0.13370594 0.63321083 0.4814084  0.60209263 0.55820667]
#   [0.406226   0.11382153 0.63001345 0.46145372 0.59150414 0.54635084]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 35: [[1936.3047]]
# x_pred_input of day 36:
# [[[0.48112855 0.21333964 0.64717578 0.55150534 0.64137969 0.60047016]
#   [0.46667369 0.19402522 0.64310498 0.53589098 0.63205857 0.5907914 ]
#   [0.45162736 0.17412885 0.63958013 0.51885211 0.62241966 0.58049061]
#   [0.4365282  0.15397766 0.63633158 0.50064856 0.61241296 0.56962162]
#   [0.42111848 0.13370594 0.63321083 0.4814084  0.60209263 0.55820667]
#   [0.406226   0.11382153 0.63001345 0.46145372 0.59150414 0.54635084]
#   [0.39172651 0.09465764 0.62651706 0.44106883 0.58064109 0.53413643]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 36: [[1870.9103]]
# x_pred_input of day 37:
# [[[0.46667369 0.19402522 0.64310498 0.53589098 0.63205857 0.5907914 ]
#   [0.45162736 0.17412885 0.63958013 0.51885211 0.62241966 0.58049061]
#   [0.4365282  0.15397766 0.63633158 0.50064856 0.61241296 0.56962162]
#   [0.42111848 0.13370594 0.63321083 0.4814084  0.60209263 0.55820667]
#   [0.406226   0.11382153 0.63001345 0.46145372 0.59150414 0.54635084]
#   [0.39172651 0.09465764 0.62651706 0.44106883 0.58064109 0.53413643]
#   [0.37789456 0.07660024 0.62236515 0.42064942 0.56952582 0.52166609]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 37: [[1808.0425]]
# x_pred_input of day 38:
# [[[0.45162736 0.17412885 0.63958013 0.51885211 0.62241966 0.58049061]
#   [0.4365282  0.15397766 0.63633158 0.50064856 0.61241296 0.56962162]
#   [0.42111848 0.13370594 0.63321083 0.4814084  0.60209263 0.55820667]
#   [0.406226   0.11382153 0.63001345 0.46145372 0.59150414 0.54635084]
#   [0.39172651 0.09465764 0.62651706 0.44106883 0.58064109 0.53413643]
#   [0.37789456 0.07660024 0.62236515 0.42064942 0.56952582 0.52166609]
#   [0.36459702 0.05987457 0.61733873 0.40047059 0.55819729 0.50901902]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 38: [[1748.8846]]
# x_pred_input of day 39:
# [[[0.4365282  0.15397766 0.63633158 0.50064856 0.61241296 0.56962162]
#   [0.42111848 0.13370594 0.63321083 0.4814084  0.60209263 0.55820667]
#   [0.406226   0.11382153 0.63001345 0.46145372 0.59150414 0.54635084]
#   [0.39172651 0.09465764 0.62651706 0.44106883 0.58064109 0.53413643]
#   [0.37789456 0.07660024 0.62236515 0.42064942 0.56952582 0.52166609]
#   [0.36459702 0.05987457 0.61733873 0.40047059 0.55819729 0.50901902]
#   [0.3520842  0.04476326 0.61104056 0.38094966 0.54667026 0.49629257]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 39: [[1697.0043]]
# x_pred_input of day 40:
# [[[0.42111848 0.13370594 0.63321083 0.4814084  0.60209263 0.55820667]
#   [0.406226   0.11382153 0.63001345 0.46145372 0.59150414 0.54635084]
#   [0.39172651 0.09465764 0.62651706 0.44106883 0.58064109 0.53413643]
#   [0.37789456 0.07660024 0.62236515 0.42064942 0.56952582 0.52166609]
#   [0.36459702 0.05987457 0.61733873 0.40047059 0.55819729 0.50901902]
#   [0.3520842  0.04476326 0.61104056 0.38094966 0.54667026 0.49629257]
#   [0.34111069 0.03183509 0.60329919 0.36251274 0.53500529 0.48365224]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 40: [[1651.1976]]
# x_pred_input of day 41:
# [[[0.406226   0.11382153 0.63001345 0.46145372 0.59150414 0.54635084]
#   [0.39172651 0.09465764 0.62651706 0.44106883 0.58064109 0.53413643]
#   [0.37789456 0.07660024 0.62236515 0.42064942 0.56952582 0.52166609]
#   [0.36459702 0.05987457 0.61733873 0.40047059 0.55819729 0.50901902]
#   [0.3520842  0.04476326 0.61104056 0.38094966 0.54667026 0.49629257]
#   [0.34111069 0.03183509 0.60329919 0.36251274 0.53500529 0.48365224]
#   [0.33142186 0.02138742 0.5938185  0.3455922  0.52326463 0.47122164]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 41: [[1614.4434]]
# x_pred_input of day 42:
# [[[0.39172651 0.09465764 0.62651706 0.44106883 0.58064109 0.53413643]
#   [0.37789456 0.07660024 0.62236515 0.42064942 0.56952582 0.52166609]
#   [0.36459702 0.05987457 0.61733873 0.40047059 0.55819729 0.50901902]
#   [0.3520842  0.04476326 0.61104056 0.38094966 0.54667026 0.49629257]
#   [0.34111069 0.03183509 0.60329919 0.36251274 0.53500529 0.48365224]
#   [0.33142186 0.02138742 0.5938185  0.3455922  0.52326463 0.47122164]
#   [0.32364775 0.01393032 0.58269639 0.33048459 0.5115206  0.45917726]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 42: [[1580.598]]
# x_pred_input of day 43:
# [[[0.37789456 0.07660024 0.62236515 0.42064942 0.56952582 0.52166609]
#   [0.36459702 0.05987457 0.61733873 0.40047059 0.55819729 0.50901902]
#   [0.3520842  0.04476326 0.61104056 0.38094966 0.54667026 0.49629257]
#   [0.34111069 0.03183509 0.60329919 0.36251274 0.53500529 0.48365224]
#   [0.33142186 0.02138742 0.5938185  0.3455922  0.52326463 0.47122164]
#   [0.32364775 0.01393032 0.58269639 0.33048459 0.5115206  0.45917726]
#   [0.31648892 0.00919949 0.56996821 0.31726903 0.49976336 0.44754543]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 43: [[1556.2454]]
# x_pred_input of day 44:
# [[[0.36459702 0.05987457 0.61733873 0.40047059 0.55819729 0.50901902]
#   [0.3520842  0.04476326 0.61104056 0.38094966 0.54667026 0.49629257]
#   [0.34111069 0.03183509 0.60329919 0.36251274 0.53500529 0.48365224]
#   [0.33142186 0.02138742 0.5938185  0.3455922  0.52326463 0.47122164]
#   [0.32364775 0.01393032 0.58269639 0.33048459 0.5115206  0.45917726]
#   [0.31648892 0.00919949 0.56996821 0.31726903 0.49976336 0.44754543]
#   [0.31133795 0.00763179 0.55576968 0.30618978 0.48806131 0.43649289]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 44: [[1531.5078]]
# x_pred_input of day 45:
# [[[0.3520842  0.04476326 0.61104056 0.38094966 0.54667026 0.49629257]
#   [0.34111069 0.03183509 0.60329919 0.36251274 0.53500529 0.48365224]
#   [0.33142186 0.02138742 0.5938185  0.3455922  0.52326463 0.47122164]
#   [0.32364775 0.01393032 0.58269639 0.33048459 0.5115206  0.45917726]
#   [0.31648892 0.00919949 0.56996821 0.31726903 0.49976336 0.44754543]
#   [0.31133795 0.00763179 0.55576968 0.30618978 0.48806131 0.43649289]
#   [0.30610557 0.00852073 0.54030416 0.29707963 0.47636123 0.42595611]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 45: [[1514.314]]
# x_pred_input of day 46:
# [[[0.34111069 0.03183509 0.60329919 0.36251274 0.53500529 0.48365224]
#   [0.33142186 0.02138742 0.5938185  0.3455922  0.52326463 0.47122164]
#   [0.32364775 0.01393032 0.58269639 0.33048459 0.5115206  0.45917726]
#   [0.31648892 0.00919949 0.56996821 0.31726903 0.49976336 0.44754543]
#   [0.31133795 0.00763179 0.55576968 0.30618978 0.48806131 0.43649289]
#   [0.30610557 0.00852073 0.54030416 0.29707963 0.47636123 0.42595611]
#   [0.3024688  0.01209768 0.52377281 0.29003973 0.4647476  0.41604968]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 46: [[1498.2902]]
# x_pred_input of day 47:
# [[[0.33142186 0.02138742 0.5938185  0.3455922  0.52326463 0.47122164]
#   [0.32364775 0.01393032 0.58269639 0.33048459 0.5115206  0.45917726]
#   [0.31648892 0.00919949 0.56996821 0.31726903 0.49976336 0.44754543]
#   [0.31133795 0.00763179 0.55576968 0.30618978 0.48806131 0.43649289]
#   [0.30610557 0.00852073 0.54030416 0.29707963 0.47636123 0.42595611]
#   [0.3024688  0.01209768 0.52377281 0.29003973 0.4647476  0.41604968]
#   [0.29907951 0.01785982 0.50642915 0.28490344 0.45320857 0.40673897]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 47: [[1486.155]]
# x_pred_input of day 48:
# [[[0.32364775 0.01393032 0.58269639 0.33048459 0.5115206  0.45917726]
#   [0.31648892 0.00919949 0.56996821 0.31726903 0.49976336 0.44754543]
#   [0.31133795 0.00763179 0.55576968 0.30618978 0.48806131 0.43649289]
#   [0.30610557 0.00852073 0.54030416 0.29707963 0.47636123 0.42595611]
#   [0.3024688  0.01209768 0.52377281 0.29003973 0.4647476  0.41604968]
#   [0.29907951 0.01785982 0.50642915 0.28490344 0.45320857 0.40673897]
#   [0.29651274 0.02566704 0.48854146 0.28157219 0.44184817 0.39805164]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 48: [[1473.6711]]
# x_pred_input of day 49:
# [[[0.31648892 0.00919949 0.56996821 0.31726903 0.49976336 0.44754543]
#   [0.31133795 0.00763179 0.55576968 0.30618978 0.48806131 0.43649289]
#   [0.30610557 0.00852073 0.54030416 0.29707963 0.47636123 0.42595611]
#   [0.3024688  0.01209768 0.52377281 0.29003973 0.4647476  0.41604968]
#   [0.29907951 0.01785982 0.50642915 0.28490344 0.45320857 0.40673897]
#   [0.29651274 0.02566704 0.48854146 0.28157219 0.44184817 0.39805164]
#   [0.2938722  0.0349518  0.4703475  0.27982251 0.43068152 0.38992074]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 49: [[1461.9143]]
# x_pred_input of day 50:
# [[[0.31133795 0.00763179 0.55576968 0.30618978 0.48806131 0.43649289]
#   [0.30610557 0.00852073 0.54030416 0.29707963 0.47636123 0.42595611]
#   [0.3024688  0.01209768 0.52377281 0.29003973 0.4647476  0.41604968]
#   [0.29907951 0.01785982 0.50642915 0.28490344 0.45320857 0.40673897]
#   [0.29651274 0.02566704 0.48854146 0.28157219 0.44184817 0.39805164]
#   [0.2938722  0.0349518  0.4703475  0.27982251 0.43068152 0.38992074]
#   [0.29138544 0.0453629  0.45201903 0.27950977 0.41977792 0.38230906]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 50: [[1447.1733]]
# x_pred_input of day 51:
# [[[0.30610557 0.00852073 0.54030416 0.29707963 0.47636123 0.42595611]
#   [0.3024688  0.01209768 0.52377281 0.29003973 0.4647476  0.41604968]
#   [0.29907951 0.01785982 0.50642915 0.28490344 0.45320857 0.40673897]
#   [0.29651274 0.02566704 0.48854146 0.28157219 0.44184817 0.39805164]
#   [0.2938722  0.0349518  0.4703475  0.27982251 0.43068152 0.38992074]
#   [0.29138544 0.0453629  0.45201903 0.27950977 0.41977792 0.38230906]
#   [0.2882675  0.05623187 0.43391775 0.28023019 0.40914013 0.37510239]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 51: [[1428.9417]]
# x_pred_input of day 52:
# [[[0.3024688  0.01209768 0.52377281 0.29003973 0.4647476  0.41604968]
#   [0.29907951 0.01785982 0.50642915 0.28490344 0.45320857 0.40673897]
#   [0.29651274 0.02566704 0.48854146 0.28157219 0.44184817 0.39805164]
#   [0.2938722  0.0349518  0.4703475  0.27982251 0.43068152 0.38992074]
#   [0.29138544 0.0453629  0.45201903 0.27950977 0.41977792 0.38230906]
#   [0.2882675  0.05623187 0.43391775 0.28023019 0.40914013 0.37510239]
#   [0.28441121 0.06697782 0.41639498 0.2815563  0.39879322 0.3681864 ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 52: [[1409.6052]]
# x_pred_input of day 53:
# [[[0.29907951 0.01785982 0.50642915 0.28490344 0.45320857 0.40673897]
#   [0.29651274 0.02566704 0.48854146 0.28157219 0.44184817 0.39805164]
#   [0.2938722  0.0349518  0.4703475  0.27982251 0.43068152 0.38992074]
#   [0.29138544 0.0453629  0.45201903 0.27950977 0.41977792 0.38230906]
#   [0.2882675  0.05623187 0.43391775 0.28023019 0.40914013 0.37510239]
#   [0.28441121 0.06697782 0.41639498 0.2815563  0.39879322 0.3681864 ]
#   [0.28032125 0.07739165 0.39965911 0.28322381 0.38876433 0.36150943]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 53: [[1384.0365]]
# x_pred_input of day 54:
# [[[0.29651274 0.02566704 0.48854146 0.28157219 0.44184817 0.39805164]
#   [0.2938722  0.0349518  0.4703475  0.27982251 0.43068152 0.38992074]
#   [0.29138544 0.0453629  0.45201903 0.27950977 0.41977792 0.38230906]
#   [0.2882675  0.05623187 0.43391775 0.28023019 0.40914013 0.37510239]
#   [0.28441121 0.06697782 0.41639498 0.2815563  0.39879322 0.3681864 ]
#   [0.28032125 0.07739165 0.39965911 0.28322381 0.38876433 0.36150943]
#   [0.27491306 0.08678762 0.38412021 0.28463796 0.37904245 0.35491346]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 54: [[1356.3342]]
# x_pred_input of day 55:
# [[[0.2938722  0.0349518  0.4703475  0.27982251 0.43068152 0.38992074]
#   [0.29138544 0.0453629  0.45201903 0.27950977 0.41977792 0.38230906]
#   [0.2882675  0.05623187 0.43391775 0.28023019 0.40914013 0.37510239]
#   [0.28441121 0.06697782 0.41639498 0.2815563  0.39879322 0.3681864 ]
#   [0.28032125 0.07739165 0.39965911 0.28322381 0.38876433 0.36150943]
#   [0.27491306 0.08678762 0.38412021 0.28463796 0.37904245 0.35491346]
#   [0.26905359 0.09506031 0.36994523 0.28549265 0.36963166 0.34834447]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 55: [[1325.0616]]
# x_pred_input of day 56:
# [[[0.29138544 0.0453629  0.45201903 0.27950977 0.41977792 0.38230906]
#   [0.2882675  0.05623187 0.43391775 0.28023019 0.40914013 0.37510239]
#   [0.28441121 0.06697782 0.41639498 0.2815563  0.39879322 0.3681864 ]
#   [0.28032125 0.07739165 0.39965911 0.28322381 0.38876433 0.36150943]
#   [0.27491306 0.08678762 0.38412021 0.28463796 0.37904245 0.35491346]
#   [0.26905359 0.09506031 0.36994523 0.28549265 0.36963166 0.34834447]
#   [0.26243894 0.10199261 0.35741057 0.28533327 0.36051449 0.34172242]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 56: [[1289.4907]]
# x_pred_input of day 57:
# [[[0.2882675  0.05623187 0.43391775 0.28023019 0.40914013 0.37510239]
#   [0.28441121 0.06697782 0.41639498 0.2815563  0.39879322 0.3681864 ]
#   [0.28032125 0.07739165 0.39965911 0.28322381 0.38876433 0.36150943]
#   [0.27491306 0.08678762 0.38412021 0.28463796 0.37904245 0.35491346]
#   [0.26905359 0.09506031 0.36994523 0.28549265 0.36963166 0.34834447]
#   [0.26243894 0.10199261 0.35741057 0.28533327 0.36051449 0.34172242]
#   [0.25491513 0.10735504 0.34677054 0.28368197 0.35168628 0.33495906]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 57: [[1253.4552]]
# x_pred_input of day 58:
# [[[0.28441121 0.06697782 0.41639498 0.2815563  0.39879322 0.3681864 ]
#   [0.28032125 0.07739165 0.39965911 0.28322381 0.38876433 0.36150943]
#   [0.27491306 0.08678762 0.38412021 0.28463796 0.37904245 0.35491346]
#   [0.26905359 0.09506031 0.36994523 0.28549265 0.36963166 0.34834447]
#   [0.26243894 0.10199261 0.35741057 0.28533327 0.36051449 0.34172242]
#   [0.25491513 0.10735504 0.34677054 0.28368197 0.35168628 0.33495906]
#   [0.24729305 0.11137878 0.33821121 0.28024874 0.34316759 0.32805778]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 58: [[1211.2067]]
# x_pred_input of day 59:
# [[[0.28032125 0.07739165 0.39965911 0.28322381 0.38876433 0.36150943]
#   [0.27491306 0.08678762 0.38412021 0.28463796 0.37904245 0.35491346]
#   [0.26905359 0.09506031 0.36994523 0.28549265 0.36963166 0.34834447]
#   [0.26243894 0.10199261 0.35741057 0.28533327 0.36051449 0.34172242]
#   [0.25491513 0.10735504 0.34677054 0.28368197 0.35168628 0.33495906]
#   [0.24729305 0.11137878 0.33821121 0.28024874 0.34316759 0.32805778]
#   [0.23835681 0.11367084 0.33191646 0.27457823 0.33490583 0.32089687]]]
# 1/1 [==============================] - 0s 33ms/step
# y_pred of day 59: [[1169.4735]]
# x_pred_input of day 60:
# [[[0.27491306 0.08678762 0.38412021 0.28463796 0.37904245 0.35491346]
#   [0.26905359 0.09506031 0.36994523 0.28549265 0.36963166 0.34834447]
#   [0.26243894 0.10199261 0.35741057 0.28533327 0.36051449 0.34172242]
#   [0.25491513 0.10735504 0.34677054 0.28368197 0.35168628 0.33495906]
#   [0.24729305 0.11137878 0.33821121 0.28024874 0.34316759 0.32805778]
#   [0.23835681 0.11367084 0.33191646 0.27457823 0.33490583 0.32089687]
#   [0.22952959 0.11463288 0.32750736 0.26694951 0.32691849 0.31351225]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 60: [[1125.5256]]
# x_pred_input of day 61:
# [[[0.26905359 0.09506031 0.36994523 0.28549265 0.36963166 0.34834447]
#   [0.26243894 0.10199261 0.35741057 0.28533327 0.36051449 0.34172242]
#   [0.25491513 0.10735504 0.34677054 0.28368197 0.35168628 0.33495906]
#   [0.24729305 0.11137878 0.33821121 0.28024874 0.34316759 0.32805778]
#   [0.23835681 0.11367084 0.33191646 0.27457823 0.33490583 0.32089687]
#   [0.22952959 0.11463288 0.32750736 0.26694951 0.32691849 0.31351225]
#   [0.22023392 0.11431485 0.32464393 0.25755914 0.31916449 0.30587716]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 61: [[1082.3372]]
# x_pred_input of day 62:
# [[[0.26243894 0.10199261 0.35741057 0.28533327 0.36051449 0.34172242]
#   [0.25491513 0.10735504 0.34677054 0.28368197 0.35168628 0.33495906]
#   [0.24729305 0.11137878 0.33821121 0.28024874 0.34316759 0.32805778]
#   [0.23835681 0.11367084 0.33191646 0.27457823 0.33490583 0.32089687]
#   [0.22952959 0.11463288 0.32750736 0.26694951 0.32691849 0.31351225]
#   [0.22023392 0.11431485 0.32464393 0.25755914 0.31916449 0.30587716]
#   [0.21109888 0.11307541 0.32270485 0.2469324  0.31163413 0.29803192]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 62: [[1037.0177]]
# x_pred_input of day 63:
# [[[0.25491513 0.10735504 0.34677054 0.28368197 0.35168628 0.33495906]
#   [0.24729305 0.11137878 0.33821121 0.28024874 0.34316759 0.32805778]
#   [0.23835681 0.11367084 0.33191646 0.27457823 0.33490583 0.32089687]
#   [0.22952959 0.11463288 0.32750736 0.26694951 0.32691849 0.31351225]
#   [0.22023392 0.11431485 0.32464393 0.25755914 0.31916449 0.30587716]
#   [0.21109888 0.11307541 0.32270485 0.2469324  0.31163413 0.29803192]
#   [0.2015131  0.1109097  0.32147756 0.23519565 0.30428079 0.28995031]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 63: [[989.8034]]
# x_pred_input of day 64:
# [[[0.24729305 0.11137878 0.33821121 0.28024874 0.34316759 0.32805778]
#   [0.23835681 0.11367084 0.33191646 0.27457823 0.33490583 0.32089687]
#   [0.22952959 0.11463288 0.32750736 0.26694951 0.32691849 0.31351225]
#   [0.22023392 0.11431485 0.32464393 0.25755914 0.31916449 0.30587716]
#   [0.21109888 0.11307541 0.32270485 0.2469324  0.31163413 0.29803192]
#   [0.2015131  0.1109097  0.32147756 0.23519565 0.30428079 0.28995031]
#   [0.19152653 0.1078487  0.32048987 0.22262489 0.29706548 0.28161372]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 64: [[941.4416]]
# x_pred_input of day 65:
# [[[0.23835681 0.11367084 0.33191646 0.27457823 0.33490583 0.32089687]
#   [0.22952959 0.11463288 0.32750736 0.26694951 0.32691849 0.31351225]
#   [0.22023392 0.11431485 0.32464393 0.25755914 0.31916449 0.30587716]
#   [0.21109888 0.11307541 0.32270485 0.2469324  0.31163413 0.29803192]
#   [0.2015131  0.1109097  0.32147756 0.23519565 0.30428079 0.28995031]
#   [0.19152653 0.1078487  0.32048987 0.22262489 0.29706548 0.28161372]
#   [0.18129724 0.10400348 0.31966442 0.20929206 0.28994538 0.27302153]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 65: [[891.6656]]
# x_pred_input of day 66:
# [[[0.22952959 0.11463288 0.32750736 0.26694951 0.32691849 0.31351225]
#   [0.22023392 0.11431485 0.32464393 0.25755914 0.31916449 0.30587716]
#   [0.21109888 0.11307541 0.32270485 0.2469324  0.31163413 0.29803192]
#   [0.2015131  0.1109097  0.32147756 0.23519565 0.30428079 0.28995031]
#   [0.19152653 0.1078487  0.32048987 0.22262489 0.29706548 0.28161372]
#   [0.18129724 0.10400348 0.31966442 0.20929206 0.28994538 0.27302153]
#   [0.17076883 0.09944268 0.31863959 0.1954028  0.28284383 0.26416738]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 66: [[840.5102]]
# x_pred_input of day 67:
# [[[0.22023392 0.11431485 0.32464393 0.25755914 0.31916449 0.30587716]
#   [0.21109888 0.11307541 0.32270485 0.2469324  0.31163413 0.29803192]
#   [0.2015131  0.1109097  0.32147756 0.23519565 0.30428079 0.28995031]
#   [0.19152653 0.1078487  0.32048987 0.22262489 0.29706548 0.28161372]
#   [0.18129724 0.10400348 0.31966442 0.20929206 0.28994538 0.27302153]
#   [0.17076883 0.09944268 0.31863959 0.1954028  0.28284383 0.26416738]
#   [0.15994865 0.09423179 0.31729657 0.18103419 0.27569511 0.2550463 ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 67: [[792.2829]]
# x_pred_input of day 68:
# [[[0.21109888 0.11307541 0.32270485 0.2469324  0.31163413 0.29803192]
#   [0.2015131  0.1109097  0.32147756 0.23519565 0.30428079 0.28995031]
#   [0.19152653 0.1078487  0.32048987 0.22262489 0.29706548 0.28161372]
#   [0.18129724 0.10400348 0.31966442 0.20929206 0.28994538 0.27302153]
#   [0.17076883 0.09944268 0.31863959 0.1954028  0.28284383 0.26416738]
#   [0.15994865 0.09423179 0.31729657 0.18103419 0.27569511 0.2550463 ]
#   [0.14974782 0.08887116 0.31528186 0.16657618 0.26844523 0.24574725]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 68: [[742.0172]]
# x_pred_input of day 69:
# [[[0.2015131  0.1109097  0.32147756 0.23519565 0.30428079 0.28995031]
#   [0.19152653 0.1078487  0.32048987 0.22262489 0.29706548 0.28161372]
#   [0.18129724 0.10400348 0.31966442 0.20929206 0.28994538 0.27302153]
#   [0.17076883 0.09944268 0.31863959 0.1954028  0.28284383 0.26416738]
#   [0.15994865 0.09423179 0.31729657 0.18103419 0.27569511 0.2550463 ]
#   [0.14974782 0.08887116 0.31528186 0.16657618 0.26844523 0.24574725]
#   [0.13911583 0.08324532 0.31256772 0.15202023 0.26105055 0.23624294]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 69: [[693.3565]]
# x_pred_input of day 70:
# [[[0.19152653 0.1078487  0.32048987 0.22262489 0.29706548 0.28161372]
#   [0.18129724 0.10400348 0.31966442 0.20929206 0.28994538 0.27302153]
#   [0.17076883 0.09944268 0.31863959 0.1954028  0.28284383 0.26416738]
#   [0.15994865 0.09423179 0.31729657 0.18103419 0.27569511 0.2550463 ]
#   [0.14974782 0.08887116 0.31528186 0.16657618 0.26844523 0.24574725]
#   [0.13911583 0.08324532 0.31256772 0.15202023 0.26105055 0.23624294]
#   [0.12882332 0.07764035 0.30896547 0.13760815 0.25344152 0.22658775]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 70: [[641.97894]]
# x_pred_input of day 71:
# [[[0.18129724 0.10400348 0.31966442 0.20929206 0.28994538 0.27302153]
#   [0.17076883 0.09944268 0.31863959 0.1954028  0.28284383 0.26416738]
#   [0.15994865 0.09423179 0.31729657 0.18103419 0.27569511 0.2550463 ]
#   [0.14974782 0.08887116 0.31528186 0.16657618 0.26844523 0.24574725]
#   [0.13911583 0.08324532 0.31256772 0.15202023 0.26105055 0.23624294]
#   [0.12882332 0.07764035 0.30896547 0.13760815 0.25344152 0.22658775]
#   [0.11795616 0.07183705 0.30456344 0.12324321 0.24559757 0.21673709]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 71: [[590.7603]]
# x_pred_input of day 72:
# [[[0.17076883 0.09944268 0.31863959 0.1954028  0.28284383 0.26416738]
#   [0.15994865 0.09423179 0.31729657 0.18103419 0.27569511 0.2550463 ]
#   [0.14974782 0.08887116 0.31528186 0.16657618 0.26844523 0.24574725]
#   [0.13911583 0.08324532 0.31256772 0.15202023 0.26105055 0.23624294]
#   [0.12882332 0.07764035 0.30896547 0.13760815 0.25344152 0.22658775]
#   [0.11795616 0.07183705 0.30456344 0.12324321 0.24559757 0.21673709]
#   [0.10712261 0.06596081 0.29938657 0.10898465 0.2374536  0.20671302]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 72: [[536.94714]]
# x_pred_input of day 73:
# [[[0.15994865 0.09423179 0.31729657 0.18103419 0.27569511 0.2550463 ]
#   [0.14974782 0.08887116 0.31528186 0.16657618 0.26844523 0.24574725]
#   [0.13911583 0.08324532 0.31256772 0.15202023 0.26105055 0.23624294]
#   [0.12882332 0.07764035 0.30896547 0.13760815 0.25344152 0.22658775]
#   [0.11795616 0.07183705 0.30456344 0.12324321 0.24559757 0.21673709]
#   [0.10712261 0.06596081 0.29938657 0.10898465 0.2374536  0.20671302]
#   [0.09574027 0.05982837 0.29344298 0.0947869  0.22897639 0.19647576]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 73: [[480.99643]]
# x_pred_input of day 74:
# [[[0.14974782 0.08887116 0.31528186 0.16657618 0.26844523 0.24574725]
#   [0.13911583 0.08324532 0.31256772 0.15202023 0.26105055 0.23624294]
#   [0.12882332 0.07764035 0.30896547 0.13760815 0.25344152 0.22658775]
#   [0.11795616 0.07183705 0.30456344 0.12324321 0.24559757 0.21673709]
#   [0.10712261 0.06596081 0.29938657 0.10898465 0.2374536  0.20671302]
#   [0.09574027 0.05982837 0.29344298 0.0947869  0.22897639 0.19647576]
#   [0.08390581 0.05334594 0.28694556 0.08050033 0.22011281 0.18599921]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 74: [[418.22433]]
# x_pred_input of day 75:
# [[[0.13911583 0.08324532 0.31256772 0.15202023 0.26105055 0.23624294]
#   [0.12882332 0.07764035 0.30896547 0.13760815 0.25344152 0.22658775]
#   [0.11795616 0.07183705 0.30456344 0.12324321 0.24559757 0.21673709]
#   [0.10712261 0.06596081 0.29938657 0.10898465 0.2374536  0.20671302]
#   [0.09574027 0.05982837 0.29344298 0.0947869  0.22897639 0.19647576]
#   [0.08390581 0.05334594 0.28694556 0.08050033 0.22011281 0.18599921]
#   [0.07062852 0.04596379 0.28006476 0.06581212 0.21080578 0.17515813]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 75: [[348.9151]]
# x_pred_input of day 76:
# [[[0.12882332 0.07764035 0.30896547 0.13760815 0.25344152 0.22658775]
#   [0.11795616 0.07183705 0.30456344 0.12324321 0.24559757 0.21673709]
#   [0.10712261 0.06596081 0.29938657 0.10898465 0.2374536  0.20671302]
#   [0.09574027 0.05982837 0.29344298 0.0947869  0.22897639 0.19647576]
#   [0.08390581 0.05334594 0.28694556 0.08050033 0.22011281 0.18599921]
#   [0.07062852 0.04596379 0.28006476 0.06581212 0.21080578 0.17515813]
#   [0.05596852 0.03729064 0.27301227 0.05040295 0.20099126 0.16384536]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 76: [[272.13516]]
# x_pred_input of day 77:
# [[[0.11795616 0.07183705 0.30456344 0.12324321 0.24559757 0.21673709]
#   [0.10712261 0.06596081 0.29938657 0.10898465 0.2374536  0.20671302]
#   [0.09574027 0.05982837 0.29344298 0.0947869  0.22897639 0.19647576]
#   [0.08390581 0.05334594 0.28694556 0.08050033 0.22011281 0.18599921]
#   [0.07062852 0.04596379 0.28006476 0.06581212 0.21080578 0.17515813]
#   [0.05596852 0.03729064 0.27301227 0.05040295 0.20099126 0.16384536]
#   [0.03972835 0.02693891 0.26605225 0.03388717 0.19062967 0.1519437 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 77: [[182.72798]]
# x_pred_input of day 78:
# [[[0.10712261 0.06596081 0.29938657 0.10898465 0.2374536  0.20671302]
#   [0.09574027 0.05982837 0.29344298 0.0947869  0.22897639 0.19647576]
#   [0.08390581 0.05334594 0.28694556 0.08050033 0.22011281 0.18599921]
#   [0.07062852 0.04596379 0.28006476 0.06581212 0.21080578 0.17515813]
#   [0.05596852 0.03729064 0.27301227 0.05040295 0.20099126 0.16384536]
#   [0.03972835 0.02693891 0.26605225 0.03388717 0.19062967 0.1519437 ]
#   [0.02081732 0.0140954  0.25941377 0.01570231 0.17964044 0.13923518]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 78: [[79.18526]]
# x_pred_input of day 79:
# [[[0.09671907 0.06170802 0.29909151 0.09922691 0.23287737 0.19647576]
#   [0.08489742 0.05523854 0.29264604 0.08501041 0.22405864 0.18599921]
#   [0.0716345  0.04787116 0.28582025 0.07039425 0.2147987  0.17515813]
#   [0.05699037 0.03921535 0.27882413 0.05506066 0.20503383 0.16384536]
#   [0.04076778 0.02888431 0.27191975 0.03862589 0.19472466 0.1519437 ]
#   [0.02187722 0.01606648 0.26533434 0.02053023 0.18379104 0.13923518]
#   [0.         0.         0.25956484 0.         0.17211863 0.12548988]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 79: [[-28.485409]]
# x_pred_input of day 80:
# [[[0.10525239 0.07271872 0.30796871 0.10547776 0.24265952 0.18599921]
#   [0.09228448 0.06548765 0.30129078 0.09118855 0.23362156 0.17515813]
#   [0.07796608 0.05699199 0.29444621 0.07619795 0.22409077 0.16384536]
#   [0.06210434 0.0468521  0.28769139 0.06013081 0.21402874 0.1519437 ]
#   [0.04363397 0.03427143 0.28124864 0.04243993 0.20335722 0.13923518]
#   [0.02224337 0.01850221 0.27560411 0.02236894 0.19196462 0.12548988]
#   [0.         0.         0.27059428 0.         0.17986898 0.11071695]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 80: [[-48.658592]]
# x_pred_input of day 81:
# [[[0.0960517  0.07624512 0.30411508 0.10839907 0.23704828 0.17515813]
#   [0.08179273 0.06784726 0.29729818 0.09369237 0.22756011 0.16384536]
#   [0.06599682 0.0578241  0.29057067 0.07792949 0.21754307 0.1519437 ]
#   [0.0476031  0.04538824 0.28415396 0.06057363 0.20691926 0.13923518]
#   [0.02630128 0.02980055 0.27853225 0.04088274 0.1955776  0.12548988]
#   [0.00415022 0.01151132 0.27354266 0.0189374  0.18353604 0.11071695]
#   [0.         0.         0.26642326 0.         0.17155866 0.09691316]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 81: [[-56.939816]]
# x_pred_input of day 82:
# [[[0.08335442 0.07238263 0.29846227 0.10774475 0.22897533 0.16384536]
#   [0.06758536 0.06240823 0.29174591 0.09222628 0.21897664 0.1519437 ]
#   [0.04922293 0.05003288 0.28533982 0.07513953 0.2083723  0.13923518]
#   [0.02795734 0.03452103 0.27972743 0.05575394 0.19705142 0.12548988]
#   [0.00584396 0.01632079 0.27474611 0.03414887 0.18503192 0.11071695]
#   [0.0017008  0.00486548 0.2676385  0.0155051  0.17307649 0.09691316]
#   [0.         0.         0.25847144 0.         0.16131669 0.0842443 ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 82: [[-43.17393]]
# x_pred_input of day 83:
# [[[0.06758536 0.06240823 0.28979016 0.10282863 0.21659071 0.1519437 ]
#   [0.04922293 0.05003288 0.28336639 0.08594144 0.20595397 0.13923518]
#   [0.02795734 0.03452103 0.2777385  0.06678227 0.19459851 0.12548988]
#   [0.00584396 0.01632079 0.27274342 0.04542954 0.18254229 0.11071695]
#   [0.0017008  0.00486548 0.26561619 0.02700351 0.17055034 0.09691316]
#   [0.         0.         0.25642382 0.01167951 0.15875462 0.0842443 ]
#   [0.00282724 0.00253096 0.2451677  0.         0.14738    0.07308075]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 83: [[-21.188366]]
# x_pred_input of day 84:
# [[[0.04922293 0.05003288 0.28019191 0.09341727 0.20206086 0.13923518]
#   [0.02795734 0.03452103 0.27453908 0.0744148  0.19064973 0.12548988]
#   [0.00584396 0.01632079 0.26952188 0.0532367  0.1785344  0.11071695]
#   [0.0017008  0.00486548 0.26236308 0.03496138 0.16648365 0.09691316]
#   [0.         0.         0.25312998 0.0197627  0.1546301  0.0842443 ]
#   [0.00282724 0.00253096 0.24182401 0.00817872 0.14319971 0.07308075]
#   [0.00734263 0.01164003 0.22883802 0.         0.13226698 0.06345753]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 84: [[-5.0726786]]
# x_pred_input of day 85:
# [[[0.02795734 0.03452103 0.27217581 0.07944673 0.18773054 0.12548988]
#   [0.00584396 0.01632079 0.26714227 0.05838378 0.17557151 0.11071695]
#   [0.0017008  0.00486548 0.25996014 0.0402078  0.1634773  0.09691316]
#   [0.         0.         0.25069697 0.02509176 0.15158099 0.0842443 ]
#   [0.00282724 0.00253096 0.23935417 0.01357075 0.14010938 0.07308075]
#   [0.00734263 0.01164003 0.22632587 0.00543649 0.12913721 0.06345753]
#   [0.01065246 0.0252192  0.21214408 0.         0.11866745 0.05510055]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 85: [[23.995338]]
# x_pred_input of day 86:
# [[[0.00584396 0.01632079 0.2628107  0.06087636 0.17017293 0.11071695]
#   [0.0017008  0.00486548 0.25558612 0.0427485  0.15799951 0.09691316]
#   [0.         0.         0.2462682  0.02767247 0.14602531 0.0842443 ]
#   [0.00282724 0.00253096 0.23485836 0.01618196 0.13447858 0.07308075]
#   [0.00734263 0.01164003 0.22175306 0.00806923 0.12343456 0.06345753]
#   [0.01065246 0.0252192  0.20748745 0.00264713 0.11289624 0.05510055]
#   [0.01662245 0.04342538 0.19227617 0.         0.10297136 0.04817032]]]
# 1/1 [==============================] - 0s 38ms/step
# y_pred of day 86: [[60.83847]]
# x_pred_input of day 87:
# [[[1.70079626e-03 4.86547812e-03 2.49967281e-01 4.28074724e-02
#    1.50952583e-01 9.69131625e-02]
#   [0.00000000e+00 0.00000000e+00 2.40579030e-01 2.77323693e-02
#    1.38878161e-01 8.42442997e-02]
#   [2.82723505e-03 2.53096253e-03 2.29083063e-01 1.62425678e-02
#    1.27234791e-01 7.30807470e-02]
#   [7.34262677e-03 1.16400308e-02 2.15878844e-01 8.13034418e-03
#    1.16098345e-01 6.34575277e-02]
#   [1.06524640e-02 2.52191974e-02 2.01505558e-01 2.70857510e-03
#    1.05471823e-01 5.51005534e-02]
#   [1.66224485e-02 4.34253810e-02 1.86179465e-01 6.16085156e-05
#    9.54638837e-02 4.81703250e-02]
#   [2.41892848e-02 6.58173407e-02 1.70263444e-01 0.00000000e+00
#    8.61618083e-02 4.26997000e-02]]]
# 1/1 [==============================] - 0s 26ms/step
# y_pred of day 87: [[114.05686]]
# x_pred_input of day 88:
# [[[0.00000000e+00 0.00000000e+00 2.32207956e-01 2.77323693e-02
#    1.30876973e-01 8.42442997e-02]
#   [2.82723505e-03 2.53096253e-03 2.20585270e-01 1.62425678e-02
#    1.19125417e-01 7.30807470e-02]
#   [7.34262677e-03 1.16400308e-02 2.07235501e-01 8.13034418e-03
#    1.07885497e-01 6.34575277e-02]
#   [1.06524640e-02 2.52191974e-02 1.92703779e-01 2.70857510e-03
#    9.71602369e-02 5.51005534e-02]
#   [1.66224485e-02 4.34253810e-02 1.77208747e-01 6.16085156e-05
#    8.70593082e-02 4.81703250e-02]
#   [2.41892848e-02 6.58173407e-02 1.61117284e-01 0.00000000e+00
#    7.76708018e-02 4.26997000e-02]
#   [3.51192692e-02 9.28512758e-02 1.44653023e-01 2.58241584e-03
#    6.91324198e-02 3.89050498e-02]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 88: [[191.27089]]
# x_pred_input of day 89:
# [[[2.82723505e-03 2.53096253e-03 2.19938335e-01 1.62425678e-02
#    1.19125417e-01 7.30807470e-02]
#   [7.34262677e-03 1.16400308e-02 2.06577486e-01 8.13034418e-03
#    1.07885497e-01 6.34575277e-02]
#   [1.06524640e-02 2.52191974e-02 1.92033702e-01 2.70857510e-03
#    9.71602369e-02 5.51005534e-02]
#   [1.66224485e-02 4.34253810e-02 1.76525809e-01 6.16085156e-05
#    8.70593082e-02 4.81703250e-02]
#   [2.41892848e-02 6.58173407e-02 1.60420989e-01 0.00000000e+00
#    7.76708018e-02 4.26997000e-02]
#   [3.51192692e-02 9.28512758e-02 1.43943063e-01 2.58241584e-03
#    6.91324198e-02 3.89050498e-02]
#   [5.09774733e-02 1.25584519e-01 1.27909577e-01 7.51214108e-03
#    6.16745490e-02 3.71475188e-02]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 89: [[307.03455]]
# x_pred_input of day 90:
# [[[7.34262677e-03 1.16400308e-02 2.06577486e-01 8.13034418e-03
#    1.07885497e-01 6.34575277e-02]
#   [1.06524640e-02 2.52191974e-02 1.92033702e-01 2.70857510e-03
#    9.71602369e-02 5.51005534e-02]
#   [1.66224485e-02 4.34253810e-02 1.76525809e-01 6.16085156e-05
#    8.70593082e-02 4.81703250e-02]
#   [2.41892848e-02 6.58173407e-02 1.60420989e-01 0.00000000e+00
#    7.76708018e-02 4.26997000e-02]
#   [3.51192692e-02 9.28512758e-02 1.43943063e-01 2.58241584e-03
#    6.91324198e-02 3.89050498e-02]
#   [5.09774733e-02 1.25584519e-01 1.27909577e-01 7.51214108e-03
#    6.16745490e-02 3.71475188e-02]
#   [7.47529938e-02 1.66218295e-01 1.13977901e-01 1.38371934e-02
#    5.56538323e-02 3.80697124e-02]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 90: [[465.6818]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#            Close        MACD  Bollinger_Upper  Bollinger_Lower        MA26  \
# 0     227.181000    0.000000       465.681793       465.681793  465.681793
# 1     220.488998   -0.533835       465.681793       465.681793  465.681793
# 2     222.218002   -0.808072       465.681793       465.681793  465.681793
# 3     227.600998   -0.584308       465.681793       465.681793  465.681793
# 4     225.119995   -0.600251       465.681793       465.681793  465.681793
# ...          ...         ...              ...              ...         ...
# 2063   60.838470 -299.939261       891.923817      -325.839587  440.139151
# 2064  114.056862 -278.109433       812.435109      -314.173483  402.897601
# 2065  191.270889 -251.677430       735.090365      -291.903371  370.368878
# 2066  307.034546 -218.865770       667.884646      -263.329848  344.108537
# 2067  465.681793 -178.008810       629.773248      -242.848165  325.810083
#
#            EMA20
# 0     227.181000
# 1     226.543666
# 2     226.131698
# 3     226.271632
# 4     226.161952
# ...          ...
# 2063  288.906792
# 2064  272.254418
# 2065  264.541701
# 2066  268.588639
# 2067  287.359415
#
# [2068 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
# Dateframe of Close training set
df_train = df_filtered['Close'][:train_size].copy()

# Plot the forecast for df_val, df_test and df_forecast
plt.figure(figsize=(15, 7))
plt.plot(df_train, label='Train')
plt.plot(df_test['Y_test_pred'], label='Test prediction')
plt.plot(df_test['Y_test'], label='Test')
plt.plot(df_forecast_unscale['Close'], label='Forecast next 30 days')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  93.7316539905461
# MAPE:  4.011923886309631
# SMAPE:  4.104274753326421
