# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../../Dataset/DOGE-USD.csv')
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2018-03-01  0.006042  0.006320  0.005945  0.006215   0.006215  15518400
# 1  2018-03-02  0.006174  0.006232  0.005447  0.005482   0.005482  22498100
# 2  2018-03-03  0.005494  0.005756  0.005181  0.005301   0.005301  21545000
# 3  2018-03-04  0.005234  0.005502  0.005164  0.005502   0.005502  12133500
# 4  2018-03-05  0.005462  0.005535  0.005157  0.005218   0.005218  13627700

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2018-03-01  0.006042  0.006320  0.005945  0.006215   0.006215  15518400
# 2018-03-02  0.006174  0.006232  0.005447  0.005482   0.005482  22498100
# 2018-03-03  0.005494  0.005756  0.005181  0.005301   0.005301  21545000
# 2018-03-04  0.005234  0.005502  0.005164  0.005502   0.005502  12133500
# 2018-03-05  0.005462  0.005535  0.005157  0.005218   0.005218  13627700

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2018-10-02  0.005824  0.000241         0.006478         0.005382  0.005966  0.005739
# 2018-10-03  0.005704  0.000213         0.006358         0.005417  0.005981  0.005736
# 2018-10-04  0.005645  0.000183         0.006322         0.005400  0.005979  0.005727
# 2018-10-05  0.005669  0.000159         0.006282         0.005391  0.005973  0.005722
# 2018-10-06  0.005545  0.000129         0.006110         0.005464  0.005921  0.005705
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2018-10-02  0.005824  0.000241         0.006478         0.005382  0.005966  0.005739
# 2018-10-03  0.005704  0.000213         0.006358         0.005417  0.005981  0.005736
# 2018-10-04  0.005645  0.000183         0.006322         0.005400  0.005979  0.005727
# 2018-10-05  0.005669  0.000159         0.006282         0.005391  0.005973  0.005722
# 2018-10-06  0.005545  0.000129         0.006110         0.005464  0.005921  0.005705

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (2070, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.90)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1863, 6) (207, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1856, 7, 6) (1856,)
# (200, 7, 6) (200,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1856, 7, 6) (1856,)
# (200, 7, 6) (200,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
# model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
# model.add(Dense(1))
model.add(SimpleRNN(n_neurons, return_sequences=True,
          input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(SimpleRNN(n_neurons, return_sequences=True))
model.add(SimpleRNN(n_neurons))
model.add(Dense(1))


# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0628 - val_loss: 0.0080
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - val_loss: 6.5628e-04
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0538e-04 - val_loss: 5.5187e-04
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6285e-04 - val_loss: 4.2326e-04
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1304e-04 - val_loss: 3.2807e-04
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4422e-04 - val_loss: 3.0725e-04
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7907e-04 - val_loss: 4.1082e-04
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7569e-04 - val_loss: 2.5767e-04
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6346e-04 - val_loss: 2.5149e-04
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6139e-04 - val_loss: 4.3632e-04
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9590e-04 - val_loss: 0.0013
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3105e-04 - val_loss: 2.9528e-04
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8026e-04 - val_loss: 2.4079e-04
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0466e-04 - val_loss: 2.0931e-04
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5862e-04 - val_loss: 2.7718e-04
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3468e-04 - val_loss: 2.1913e-04
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5524e-04 - val_loss: 3.8198e-04
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9003e-04 - val_loss: 2.2396e-04
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6402e-04 - val_loss: 8.0941e-04
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4293e-04 - val_loss: 8.1606e-04
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6639e-04 - val_loss: 5.7946e-04
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2207e-04 - val_loss: 4.5142e-04
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8145e-04 - val_loss: 2.8992e-04
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5317e-04 - val_loss: 6.1500e-04
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0252e-04 - val_loss: 2.1311e-04
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0758e-04 - val_loss: 6.4366e-04
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7193e-04 - val_loss: 3.1470e-04
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5238e-04 - val_loss: 2.4561e-04
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2180e-04 - val_loss: 5.4313e-04
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9577e-04 - val_loss: 2.0841e-04
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1251e-04 - val_loss: 2.2766e-04
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9650e-04 - val_loss: 1.8925e-04
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6066e-04 - val_loss: 4.3399e-04
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9908e-04 - val_loss: 2.0424e-04
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8333e-04 - val_loss: 2.5255e-04
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2879e-04 - val_loss: 2.3151e-04
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0031e-04 - val_loss: 5.7038e-04
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0107e-04 - val_loss: 3.2392e-04
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6019e-04 - val_loss: 1.9425e-04
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0827e-04 - val_loss: 2.3971e-04
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5304e-04 - val_loss: 4.5185e-04
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1321e-04 - val_loss: 2.5263e-04
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4536e-04 - val_loss: 3.7802e-04
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7681e-04 - val_loss: 2.2536e-04
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4048e-04 - val_loss: 2.4108e-04
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8372e-04 - val_loss: 3.0285e-04
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5911e-04 - val_loss: 1.7572e-04
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0935e-04 - val_loss: 3.0845e-04
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1990e-04 - val_loss: 1.9764e-04
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2683e-04 - val_loss: 1.7718e-04
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9328e-04 - val_loss: 2.7654e-04
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1373e-04 - val_loss: 4.6327e-04
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0967e-04 - val_loss: 4.3707e-04
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9528e-04 - val_loss: 3.1871e-04
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0517e-04 - val_loss: 0.0015
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8701e-04 - val_loss: 3.2647e-04
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5237e-04 - val_loss: 4.7737e-04
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5419e-04 - val_loss: 5.5908e-04
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0020e-04 - val_loss: 2.7575e-04
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1370e-04 - val_loss: 1.6414e-04
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6550e-04 - val_loss: 2.1997e-04
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8678e-04 - val_loss: 3.6670e-04
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6281e-04 - val_loss: 4.2163e-04
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8608e-04 - val_loss: 3.6069e-04
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6137e-04 - val_loss: 1.8187e-04
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7764e-04 - val_loss: 2.3782e-04
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6439e-04 - val_loss: 2.9508e-04
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2747e-04 - val_loss: 1.5859e-04
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5365e-04 - val_loss: 2.0635e-04
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3333e-04 - val_loss: 2.3505e-04
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7515e-04 - val_loss: 3.7806e-04
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1699e-04 - val_loss: 2.3254e-04
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3410e-04 - val_loss: 1.5212e-04
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0254e-04 - val_loss: 4.1007e-04
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1047e-04 - val_loss: 2.1865e-04
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4481e-04 - val_loss: 5.1988e-04
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0922e-04 - val_loss: 3.4246e-04
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2156e-04 - val_loss: 1.8008e-04
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7217e-04 - val_loss: 2.9083e-04
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1719e-04 - val_loss: 3.8446e-04
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8358e-04 - val_loss: 3.5725e-04
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6371e-04 - val_loss: 3.0899e-04
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1114e-04 - val_loss: 4.8291e-04
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0718e-04 - val_loss: 3.9513e-04
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4256e-04 - val_loss: 7.4433e-04
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6214e-04 - val_loss: 2.2313e-04
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3697e-04 - val_loss: 1.6730e-04
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8839e-04 - val_loss: 5.6139e-04
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1550e-04 - val_loss: 1.6311e-04
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3043e-04 - val_loss: 1.5378e-04
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7652e-04 - val_loss: 6.2162e-04
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9301e-04 - val_loss: 4.2929e-04
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2220e-04 - val_loss: 2.2309e-04
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7948e-04 - val_loss: 1.7427e-04
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4442e-04 - val_loss: 1.9003e-04
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0379e-04 - val_loss: 5.5371e-04
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1157e-04 - val_loss: 5.0195e-04
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8598e-04 - val_loss: 2.8755e-04
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3401e-04 - val_loss: 3.7106e-04
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5332e-04 - val_loss: 4.1731e-04

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (207, 7, 6)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.24103243 0.26288379 0.23926162 0.58421003 0.32771357 0.33664058]
#   [0.24523301 0.26491795 0.24174481 0.58444537 0.33095653 0.33879269]
#   [0.23919121 0.26410255 0.24257393 0.58827836 0.33369168 0.33989533]
#   [0.23733681 0.26252351 0.24350212 0.58946971 0.33515258 0.34063376]
#   [0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 1: [[0.17125925]]
# x_pred_input of day 2:
# [[[0.24523301 0.26491795 0.24174481 0.58444537 0.33095653 0.33879269]
#   [0.23919121 0.26410255 0.24257393 0.58827836 0.33369168 0.33989533]
#   [0.23733681 0.26252351 0.24350212 0.58946971 0.33515258 0.34063376]
#   [0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24840796 0.25710014 0.24216229 0.60980891 0.33699369 0.34245619]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 2: [[0.1791886]]
# x_pred_input of day 3:
# [[[0.23919121 0.26410255 0.24257393 0.58827836 0.33369168 0.33989533]
#   [0.23733681 0.26252351 0.24350212 0.58946971 0.33515258 0.34063376]
#   [0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24840796 0.25710014 0.24216229 0.60980891 0.33699369 0.34245619]
#   [0.26001346 0.26384927 0.24471906 0.61354947 0.33998179 0.34612041]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 3: [[0.18854953]]
# x_pred_input of day 4:
# [[[0.23733681 0.26252351 0.24350212 0.58946971 0.33515258 0.34063376]
#   [0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24840796 0.25710014 0.24216229 0.60980891 0.33699369 0.34245619]
#   [0.26001346 0.26384927 0.24471906 0.61354947 0.33998179 0.34612041]
#   [0.27371426 0.27362199 0.25161407 0.60944667 0.34301468 0.35135071]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 4: [[0.19948784]]
# x_pred_input of day 5:
# [[[0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24840796 0.25710014 0.24216229 0.60980891 0.33699369 0.34245619]
#   [0.26001346 0.26384927 0.24471906 0.61354947 0.33998179 0.34612041]
#   [0.27371426 0.27362199 0.25161407 0.60944667 0.34301468 0.35135071]
#   [0.28972372 0.286457   0.26108255 0.60491305 0.34763129 0.35832066]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# y_pred of day 5: [[0.21009307]]
# x_pred_input of day 6:
# [[[0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24840796 0.25710014 0.24216229 0.60980891 0.33699369 0.34245619]
#   [0.26001346 0.26384927 0.24471906 0.61354947 0.33998179 0.34612041]
#   [0.27371426 0.27362199 0.25161407 0.60944667 0.34301468 0.35135071]
#   [0.28972372 0.286457   0.26108255 0.60491305 0.34763129 0.35832066]
#   [0.30524569 0.30137505 0.27350024 0.59631529 0.35322289 0.36679642]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 6: [[0.21931471]]
# x_pred_input of day 7:
# [[[0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24840796 0.25710014 0.24216229 0.60980891 0.33699369 0.34245619]
#   [0.26001346 0.26384927 0.24471906 0.61354947 0.33998179 0.34612041]
#   [0.27371426 0.27362199 0.25161407 0.60944667 0.34301468 0.35135071]
#   [0.28972372 0.286457   0.26108255 0.60491305 0.34763129 0.35832066]
#   [0.30524569 0.30137505 0.27350024 0.59631529 0.35322289 0.36679642]
#   [0.31874262 0.31704921 0.2867929  0.58903456 0.35972311 0.37635154]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 7: [[0.22843838]]
# x_pred_input of day 8:
# [[[0.24840796 0.25710014 0.24216229 0.60980891 0.33699369 0.34245619]
#   [0.26001346 0.26384927 0.24471906 0.61354947 0.33998179 0.34612041]
#   [0.27371426 0.27362199 0.25161407 0.60944667 0.34301468 0.35135071]
#   [0.28972372 0.286457   0.26108255 0.60491305 0.34763129 0.35832066]
#   [0.30524569 0.30137505 0.27350024 0.59631529 0.35322289 0.36679642]
#   [0.31874262 0.31704921 0.2867929  0.58903456 0.35972311 0.37635154]
#   [0.33209616 0.33308716 0.30045718 0.58429857 0.36638321 0.38686316]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 8: [[0.23767962]]
# x_pred_input of day 9:
# [[[0.26001346 0.26384927 0.24471906 0.61354947 0.33998179 0.34612041]
#   [0.27371426 0.27362199 0.25161407 0.60944667 0.34301468 0.35135071]
#   [0.28972372 0.286457   0.26108255 0.60491305 0.34763129 0.35832066]
#   [0.30524569 0.30137505 0.27350024 0.59631529 0.35322289 0.36679642]
#   [0.31874262 0.31704921 0.2867929  0.58903456 0.35972311 0.37635154]
#   [0.33209616 0.33308716 0.30045718 0.58429857 0.36638321 0.38686316]
#   [0.34562177 0.34928734 0.31594522 0.57454763 0.37406361 0.39826426]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 9: [[0.24632531]]
# x_pred_input of day 10:
# [[[0.27371426 0.27362199 0.25161407 0.60944667 0.34301468 0.35135071]
#   [0.28972372 0.286457   0.26108255 0.60491305 0.34763129 0.35832066]
#   [0.30524569 0.30137505 0.27350024 0.59631529 0.35322289 0.36679642]
#   [0.31874262 0.31704921 0.2867929  0.58903456 0.35972311 0.37635154]
#   [0.33209616 0.33308716 0.30045718 0.58429857 0.36638321 0.38686316]
#   [0.34562177 0.34928734 0.31594522 0.57454763 0.37406361 0.39826426]
#   [0.35827574 0.36512617 0.33192472 0.56487236 0.38162236 0.41034827]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 10: [[0.25684705]]
# x_pred_input of day 11:
# [[[0.28972372 0.286457   0.26108255 0.60491305 0.34763129 0.35832066]
#   [0.30524569 0.30137505 0.27350024 0.59631529 0.35322289 0.36679642]
#   [0.31874262 0.31704921 0.2867929  0.58903456 0.35972311 0.37635154]
#   [0.33209616 0.33308716 0.30045718 0.58429857 0.36638321 0.38686316]
#   [0.34562177 0.34928734 0.31594522 0.57454763 0.37406361 0.39826426]
#   [0.35827574 0.36512617 0.33192472 0.56487236 0.38162236 0.41034827]
#   [0.37367551 0.38145852 0.34894792 0.55698016 0.39054724 0.42343397]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 11: [[0.26927286]]
# x_pred_input of day 12:
# [[[0.30524569 0.30137505 0.27350024 0.59631529 0.35322289 0.36679642]
#   [0.31874262 0.31704921 0.2867929  0.58903456 0.35972311 0.37635154]
#   [0.33209616 0.33308716 0.30045718 0.58429857 0.36638321 0.38686316]
#   [0.34562177 0.34928734 0.31594522 0.57454763 0.37406361 0.39826426]
#   [0.35827574 0.36512617 0.33192472 0.56487236 0.38162236 0.41034827]
#   [0.37367551 0.38145852 0.34894792 0.55698016 0.39054724 0.42343397]
#   [0.3918621  0.39896285 0.36712149 0.5516955  0.40001322 0.43781548]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 12: [[0.28209087]]
# x_pred_input of day 13:
# [[[0.31874262 0.31704921 0.2867929  0.58903456 0.35972311 0.37635154]
#   [0.33209616 0.33308716 0.30045718 0.58429857 0.36638321 0.38686316]
#   [0.34562177 0.34928734 0.31594522 0.57454763 0.37406361 0.39826426]
#   [0.35827574 0.36512617 0.33192472 0.56487236 0.38162236 0.41034827]
#   [0.37367551 0.38145852 0.34894792 0.55698016 0.39054724 0.42343397]
#   [0.3918621  0.39896285 0.36712149 0.5516955  0.40001322 0.43781548]
#   [0.41062273 0.41738601 0.3867991  0.5458641  0.41075321 0.45344965]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 13: [[0.2957992]]
# x_pred_input of day 14:
# [[[0.33209616 0.33308716 0.30045718 0.58429857 0.36638321 0.38686316]
#   [0.34562177 0.34928734 0.31594522 0.57454763 0.37406361 0.39826426]
#   [0.35827574 0.36512617 0.33192472 0.56487236 0.38162236 0.41034827]
#   [0.37367551 0.38145852 0.34894792 0.55698016 0.39054724 0.42343397]
#   [0.3918621  0.39896285 0.36712149 0.5516955  0.40001322 0.43781548]
#   [0.41062273 0.41738601 0.3867991  0.5458641  0.41075321 0.45344965]
#   [0.43068643 0.43677333 0.40829831 0.53768407 0.42296486 0.47039929]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 14: [[0.31157464]]
# x_pred_input of day 15:
# [[[0.34562177 0.34928734 0.31594522 0.56540724 0.37406361 0.39826426]
#   [0.35827574 0.36512617 0.33192472 0.5558859  0.38162236 0.41034827]
#   [0.37367551 0.38145852 0.34894792 0.54811926 0.39054724 0.42343397]
#   [0.3918621  0.39896285 0.36712149 0.54291866 0.40001322 0.43781548]
#   [0.41062273 0.41738601 0.3867991  0.53718003 0.41075321 0.45344965]
#   [0.43068643 0.43677333 0.40829831 0.52913015 0.42296486 0.47039929]
#   [0.4537756  0.45774972 0.43122745 0.52425263 0.43510944 0.48896203]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 15: [[0.33030233]]
# x_pred_input of day 16:
# [[[0.35827574 0.36512617 0.33192472 0.53192022 0.38162236 0.41034827]
#   [0.37367551 0.38145852 0.34894792 0.52448842 0.39054724 0.42343397]
#   [0.3918621  0.39896285 0.36712149 0.51951204 0.40001322 0.43781548]
#   [0.41062273 0.41738601 0.3867991  0.51402082 0.41075321 0.45344965]
#   [0.43068643 0.43677333 0.40829831 0.50631798 0.42296486 0.47039929]
#   [0.4537756  0.45774972 0.43122745 0.50165075 0.43510944 0.48896203]
#   [0.48118571 0.48123826 0.45672515 0.49636279 0.44841463 0.50958821]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 16: [[0.35094553]]
# x_pred_input of day 17:
# [[[0.37367551 0.38145852 0.34894792 0.50069431 0.39054724 0.42343397]
#   [0.3918621  0.39896285 0.36712149 0.49594368 0.40001322 0.43781548]
#   [0.41062273 0.41738601 0.3867991  0.49070158 0.41075321 0.45344965]
#   [0.43068643 0.43677333 0.40829831 0.48334819 0.42296486 0.47039929]
#   [0.4537756  0.45774972 0.43122745 0.47889269 0.43510944 0.48896203]
#   [0.48118571 0.48123826 0.45672515 0.47384463 0.44841463 0.50958821]
#   [0.51139941 0.50740461 0.48443372 0.47073073 0.46379718 0.53247318]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 17: [[0.37319317]]
# x_pred_input of day 18:
# [[[0.3918621  0.39896285 0.36712149 0.47282612 0.40001322 0.43781548]
#   [0.41062273 0.41738601 0.3867991  0.46782837 0.41075321 0.45344965]
#   [0.43068643 0.43677333 0.40829831 0.46081775 0.42296486 0.47039929]
#   [0.4537756  0.45774972 0.43122745 0.45656993 0.43510944 0.48896203]
#   [0.48118571 0.48123826 0.45672515 0.45175718 0.44841463 0.50958821]
#   [0.51139941 0.50740461 0.48443372 0.44878843 0.46379718 0.53247318]
#   [0.54396138 0.53618933 0.5144869  0.44719795 0.48157703 0.55773006]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 18: [[0.39745408]]
# x_pred_input of day 19:
# [[[0.41062273 0.41738601 0.3867991  0.44519828 0.41075321 0.45344965]
#   [0.43068643 0.43677333 0.40829831 0.43852678 0.42296486 0.47039929]
#   [0.4537756  0.45774972 0.43122745 0.43448445 0.43510944 0.48896203]
#   [0.48118571 0.48123826 0.45672515 0.4299045  0.44841463 0.50958821]
#   [0.51139941 0.50740461 0.48443372 0.42707935 0.46379718 0.53247318]
#   [0.54396138 0.53618933 0.5144869  0.42556581 0.48157703 0.55773006]
#   [0.57947    0.5677246  0.54660236 0.42674697 0.50102773 0.58554482]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 19: [[0.42309391]]
# x_pred_input of day 20:
# [[[0.43068643 0.43677333 0.40829831 0.41719875 0.42296486 0.47039929]
#   [0.4537756  0.45774972 0.43122745 0.41335302 0.43510944 0.48896203]
#   [0.48118571 0.48123826 0.45672515 0.40899582 0.44841463 0.50958821]
#   [0.51139941 0.50740461 0.48443372 0.40630807 0.46379718 0.53247318]
#   [0.54396138 0.53618933 0.5144869  0.40486815 0.48157703 0.55773006]
#   [0.57947    0.5677246  0.54660236 0.40599186 0.50102773 0.58554482]
#   [0.61699683 0.60175897 0.58093712 0.40901563 0.52176731 0.61595597]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 20: [[0.4496169]]
# x_pred_input of day 21:
# [[[0.4537756  0.45774972 0.43122745 0.39355302 0.43510944 0.48896203]
#   [0.48118571 0.48123826 0.45672515 0.38940453 0.44841463 0.50958821]
#   [0.51139941 0.50740461 0.48443372 0.38684553 0.46379718 0.53247318]
#   [0.54396138 0.53618933 0.5144869  0.38547458 0.48157703 0.55773006]
#   [0.57947    0.5677246  0.54660236 0.38654447 0.50102773 0.58554482]
#   [0.61699683 0.60175897 0.58093712 0.38942339 0.52176731 0.61595597]
#   [0.65581627 0.63781407 0.6172821  0.39427777 0.54535919 0.6488969 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 21: [[0.47586176]]
# x_pred_input of day 22:
# [[[0.48118571 0.48123826 0.45672515 0.37178255 0.43699587 0.50958821]
#   [0.51139941 0.50740461 0.48443372 0.36933936 0.45198671 0.53247318]
#   [0.54396138 0.53618933 0.5144869  0.36803044 0.4693138  0.55773006]
#   [0.57947    0.5677246  0.54660236 0.36905192 0.48826919 0.58554482]
#   [0.61699683 0.60175897 0.58093712 0.37180056 0.50848065 0.61595597]
#   [0.65581627 0.63781407 0.6172821  0.37643526 0.53147176 0.6488969 ]
#   [0.69422861 0.67489956 0.65625785 0.38041165 0.5563592  0.68406977]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 22: [[0.50385493]]
# x_pred_input of day 23:
# [[[0.51139941 0.50740461 0.48443372 0.35233286 0.42678667 0.53247318]
#   [0.54396138 0.53618933 0.5144869  0.35108422 0.44314771 0.55773006]
#   [0.57947    0.5677246  0.54660236 0.35205865 0.46104626 0.58554482]
#   [0.61699683 0.60175897 0.58093712 0.35468073 0.48013085 0.61595597]
#   [0.65581627 0.63781407 0.6172821  0.35910202 0.50184012 0.6488969 ]
#   [0.69422861 0.67489956 0.65625785 0.36289532 0.52533999 0.68406977]
#   [0.73519983 0.71326169 0.6975754  0.36720641 0.55130046 0.7216197 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 23: [[0.53439885]]
# x_pred_input of day 24:
# [[[0.54396138 0.53618933 0.5144869  0.33428906 0.41773511 0.55773006]
#   [0.57947    0.5677246  0.54660236 0.33521688 0.43460725 0.58554482]
#   [0.61699683 0.60175897 0.58093712 0.33771352 0.45259743 0.61595597]
#   [0.65581627 0.63781407 0.6172821  0.34192331 0.47306176 0.6488969 ]
#   [0.69422861 0.67489956 0.65625785 0.34553514 0.49521401 0.68406977]
#   [0.73519983 0.71326169 0.6975754  0.34964    0.51968576 0.7216197 ]
#   [0.77990436 0.75348822 0.74177787 0.3537987  0.5464546  0.76184214]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 24: [[0.56492764]]
# x_pred_input of day 25:
# [[[0.57947    0.5677246  0.54660236 0.31992013 0.41104716 0.58554482]
#   [0.61699683 0.60175897 0.58093712 0.32230285 0.42806208 0.61595597]
#   [0.65581627 0.63781407 0.6172821  0.32632053 0.44741704 0.6488969 ]
#   [0.69422861 0.67489956 0.65625785 0.32976755 0.46836842 0.68406977]
#   [0.73519983 0.71326169 0.6975754  0.33368509 0.49151355 0.7216197 ]
#   [0.77990436 0.75348822 0.74177787 0.33765402 0.51683126 0.76184214]
#   [0.82458673 0.79470931 0.78844862 0.34188614 0.54451746 0.80447945]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 25: [[0.5931188]]
# x_pred_input of day 26:
# [[[0.61699683 0.60175897 0.58093712 0.30927072 0.40765522 0.61595597]
#   [0.65581627 0.63781407 0.6172821  0.31312595 0.42608748 0.6488969 ]
#   [0.69422861 0.67489956 0.65625785 0.31643359 0.44604004 0.68406977]
#   [0.73519983 0.71326169 0.6975754  0.32019273 0.46808179 0.7216197 ]
#   [0.77990436 0.75348822 0.74177787 0.32400118 0.49219253 0.76184214]
#   [0.82458673 0.79470931 0.78844862 0.32806218 0.51855885 0.80447945]
#   [0.86584771 0.83504723 0.83620458 0.33352117 0.54678528 0.84882342]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 26: [[0.61723775]]
# x_pred_input of day 27:
# [[[0.65581627 0.63781407 0.6172821  0.30265596 0.40938994 0.6488969 ]
#   [0.69422861 0.67489956 0.65625785 0.30585301 0.4285606  0.68406977]
#   [0.73519983 0.71326169 0.6975754  0.30948645 0.44973857 0.7216197 ]
#   [0.77990436 0.75348822 0.74177787 0.31316756 0.47290446 0.76184214]
#   [0.82458673 0.79470931 0.78844862 0.31709277 0.49823754 0.80447945]
#   [0.86584771 0.83504723 0.83620458 0.32236923 0.52535783 0.84882342]
#   [0.90114857 0.87215593 0.88315313 0.33051952 0.55391886 0.89387842]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 27: [[0.6356766]]
# x_pred_input of day 28:
# [[[0.69422861 0.67489956 0.65625785 0.29822952 0.41609475 0.68406977]
#   [0.73519983 0.71326169 0.6975754  0.3017724  0.4366567  0.7216197 ]
#   [0.77990436 0.75348822 0.74177787 0.30536175 0.45914875 0.76184214]
#   [0.82458673 0.79470931 0.78844862 0.30918913 0.48374495 0.80447945]
#   [0.86584771 0.83504723 0.83620458 0.31433407 0.51007637 0.84882342]
#   [0.90114857 0.87215593 0.88315313 0.32228121 0.53780663 0.89387842]
#   [0.92813597 0.90341383 0.92730548 0.33421795 0.56598463 0.9384147 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 28: [[0.6480207]]
# x_pred_input of day 29:
# [[[0.73519983 0.71326169 0.6975754  0.29681953 0.4283161  0.7216197 ]
#   [0.77990436 0.75348822 0.74177787 0.30034997 0.45037852 0.76184214]
#   [0.82458673 0.79470931 0.78844862 0.30411453 0.4745049  0.80447945]
#   [0.86584771 0.83504723 0.83620458 0.30917503 0.50033337 0.84882342]
#   [0.90114857 0.87215593 0.88315313 0.31699174 0.52753395 0.89387842]
#   [0.92813597 0.90341383 0.92730548 0.32873256 0.55517372 0.9384147 ]
#   [0.94620292 0.92662204 0.96690704 0.34525665 0.58307624 0.98123478]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 29: [[0.65543735]]
# x_pred_input of day 30:
# [[[0.77990436 0.75348822 0.74123518 0.29741709 0.44526841 0.74581162]
#   [0.82458673 0.79470931 0.78787179 0.30114489 0.46912105 0.78755177]
#   [0.86584771 0.83504723 0.83559281 0.30615598 0.49465646 0.83096266]
#   [0.90114857 0.87215593 0.88250701 0.31389636 0.52154842 0.87506962]
#   [0.92813597 0.90341383 0.92662706 0.32552253 0.54887458 0.91866878]
#   [0.94620292 0.92662204 0.96619965 0.34188526 0.57646051 0.96058785]
#   [0.95705806 0.94074515 1.         0.36357992 0.60393204 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 30: [[0.66266245]]
# x_pred_input of day 31:
# [[[0.82458673 0.79470931 0.76598699 0.2983072  0.46399246 0.75937469]
#   [0.86584771 0.83504723 0.81238246 0.30327107 0.48924871 0.80123243]
#   [0.90114857 0.87215593 0.85799352 0.31093851 0.51584667 0.84376133]
#   [0.92813597 0.90341383 0.90088804 0.32245513 0.5428741  0.88580059]
#   [0.94620292 0.92662204 0.93936142 0.33866368 0.57015845 0.92621988]
#   [0.95705806 0.94074515 0.97222289 0.3601539  0.59732965 0.96422194]
#   [0.96763282 0.94749161 1.         0.38614458 0.62428476 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 31: [[0.6707682]]
# x_pred_input of day 32:
# [[[0.86584771 0.83504723 0.79381527 0.30009856 0.48332084 0.77493432]
#   [0.90114857 0.87215593 0.83838388 0.30768579 0.50959653 0.81606733]
#   [0.92813597 0.90341383 0.88029803 0.31908193 0.53629649 0.85672678]
#   [0.94620292 0.92662204 0.91789209 0.33512092 0.56325026 0.89581942]
#   [0.95705806 0.94074515 0.95000251 0.35638634 0.59009224 0.93257417]
#   [0.96763282 0.94749161 0.97714476 0.38210513 0.61672075 0.96717792]
#   [0.97949652 0.94883106 1.         0.41147633 0.64320557 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 32: [[0.679614]]
# x_pred_input of day 33:
# [[[0.90114857 0.87215593 0.82285695 0.30421287 0.50294633 0.79126258]
#   [0.92813597 0.90341383 0.86399485 0.31548039 0.52929786 0.83068616]
#   [0.94620292 0.92662204 0.90089267 0.33133834 0.55589988 0.86859057]
#   [0.95705806 0.94074515 0.9324084  0.35236373 0.58239158 0.90422814]
#   [0.96763282 0.94749161 0.95904798 0.37779223 0.60867259 0.93778009]
#   [0.97949652 0.94883106 0.98147994 0.40683191 0.63481178 0.96960453]
#   [0.99244337 0.94629656 1.         0.43923459 0.66092964 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 33: [[0.68830526]]
# x_pred_input of day 34:
# [[[0.92336769 0.90341383 0.85151485 0.31202009 0.52259716 0.80721666]
#   [0.94134182 0.92662204 0.8878797  0.32770411 0.54886241 0.84405014]
#   [0.95214119 0.94074515 0.9189402  0.34849888 0.57501874 0.87868085]
#   [0.96266162 0.94749161 0.94519498 0.37364847 0.60096704 0.91128485]
#   [0.97446437 0.94883106 0.96730292 0.40236963 0.62677532 0.94221015]
#   [0.98734471 0.94629656 0.98555547 0.43441691 0.65256254 0.97174685]
#   [1.         0.94067694 1.         0.46961143 0.67832553 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 34: [[0.6933772]]
# x_pred_input of day 35:
# [[[0.93444077 0.92662204 0.87902202 0.32561989 0.5448373  0.82229635]
#   [0.94516097 0.94074515 0.90977265 0.34628241 0.57080181 0.85603452]
#   [0.95560427 0.94749161 0.93576551 0.37127204 0.59655982 0.88779821]
#   [0.96732049 0.94883106 0.9576529  0.39981053 0.62217882 0.91792647]
#   [0.9801064  0.94629656 0.97572336 0.43165399 0.64777693 0.94670192]
#   [0.99266892 0.94067694 0.99002378 0.46662467 0.67335099 0.9742269 ]
#   [1.         0.93085771 1.         0.50456167 0.69869319 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 35: [[0.69272274]]
# x_pred_input of day 36:
# [[[0.94516097 0.94074515 0.90526863 0.34656682 0.57134246 0.83661965]
#   [0.95560427 0.94749161 0.93113281 0.37157699 0.59712487 0.86766295]
#   [0.96732049 0.94883106 0.95291183 0.40013891 0.62276814 0.8971079 ]
#   [0.9801064  0.94629656 0.97089283 0.43200853 0.6483905  0.92523072]
#   [0.99266892 0.94067694 0.98512246 0.46700793 0.67398878 0.95213143]
#   [1.         0.93085771 0.99504929 0.50497609 0.69935498 0.97732   ]
#   [0.99905403 0.91493856 1.         0.54549861 0.7242035  1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 36: [[0.6874485]]
# x_pred_input of day 37:
# [[[0.95560427 0.94749161 0.93113281 0.37405291 0.60171795 0.85095339]
#   [0.96732049 0.94883106 0.95291183 0.40280516 0.62755848 0.87983129]
#   [0.9801064  0.94629656 0.97089283 0.43488712 0.65337792 0.90741251]
#   [0.99266892 0.94067694 0.98512246 0.47011974 0.67917311 0.93379517]
#   [1.         0.93085771 0.99504929 0.5083409  0.70473442 0.95849866]
#   [0.99905403 0.91493856 1.         0.54913342 0.72977407 0.98074188]
#   [0.99143054 0.89206472 0.99962191 0.59202747 0.75392768 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 37: [[0.676102]]
# x_pred_input of day 38:
# [[[0.96732049 0.94883106 0.95291183 0.40866326 0.63811798 0.86635132]
#   [0.9801064  0.94629656 0.97089283 0.44121181 0.66437187 0.89350998]
#   [0.99266892 0.94067694 0.98512246 0.47695682 0.69060109 0.91948842]
#   [1.         0.93085771 0.99504929 0.51573384 0.71659252 0.94381342]
#   [0.99905403 0.91493856 1.         0.55711962 0.74205349 0.96571586]
#   [0.99143054 0.89206472 0.99962191 0.60063749 0.76661351 0.98467892]
#   [0.97503005 0.86090473 0.9935069  0.64572121 0.78981765 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 38: [[0.6579275]]
# x_pred_input of day 39:
# [[[0.9801064  0.94629656 0.97089283 0.45173494 0.68277388 0.88385727]
#   [0.99266892 0.94067694 0.98512246 0.48833249 0.70972961 0.90955507]
#   [1.         0.93085771 0.99504929 0.52803436 0.73644095 0.93361728]
#   [0.99905403 0.91493856 1.         0.57040722 0.76260715 0.9552831 ]
#   [0.99143054 0.89206472 0.99962191 0.61496301 0.78784745 0.9740413 ]
#   [0.97503005 0.86090473 0.9935069  0.661122   0.8116943  0.98919687]
#   [0.9487603  0.8201243  0.98173063 0.70764465 0.83372448 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 39: [[0.6316853]]
# x_pred_input of day 40:
# [[[0.99266892 0.94067694 0.98512246 0.50574942 0.73929689 0.90451341]
#   [1.         0.93085771 0.99504929 0.54686731 0.76712103 0.92844225]
#   [0.99905403 0.91493856 1.         0.59075144 0.79437731 0.94998797]
#   [0.99143054 0.89206472 0.99962191 0.63689637 0.82066912 0.9686422 ]
#   [0.97503005 0.86090473 0.9935069  0.68470167 0.84550942 0.98371376]
#   [0.9487603  0.8201243  0.98173063 0.7328836  0.86845738 0.99445701]
#   [0.91082929 0.76815517 0.9650798  0.77930446 0.88896603 1.        ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 40: [[0.5952143]]
# x_pred_input of day 41:
# [[[1.         0.93085771 0.99504929 0.57538831 0.81426565 0.92844225]
#   [0.99905403 0.91493856 1.         0.62156115 0.84319701 0.94998797]
#   [0.99143054 0.89206472 0.99962191 0.67011269 0.87110462 0.9686422 ]
#   [0.97503005 0.86090473 0.9935069  0.7204112  0.89747153 0.98371376]
#   [0.9487603  0.8201243  0.98173063 0.77110599 0.92182979 0.99445701]
#   [0.91082929 0.76815517 0.9650798  0.81994785 0.94359883 1.        ]
#   [0.85811335 0.70279359 0.94628268 0.86223241 0.96198173 0.99920982]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 41: [[0.54498565]]
# x_pred_input of day 42:
# [[[0.99905403 0.91493856 1.         0.66966074 0.86402385 0.94998797]
#   [0.99143054 0.89206472 0.99962191 0.72196945 0.89262078 0.9686422 ]
#   [0.97503005 0.86090473 0.9935069  0.77616032 0.91963895 0.98371376]
#   [0.9487603  0.8201243  0.98173063 0.83077813 0.94459885 0.99445701]
#   [0.91082929 0.76815517 0.9650798  0.88339963 0.96690558 1.        ]
#   [0.85811335 0.70279359 0.94628268 0.92895639 0.98574254 0.99920982]
#   [0.78551182 0.62066524 0.93279047 0.95620483 1.         0.99049977]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 42: [[0.49068233]]
# x_pred_input of day 43:
# [[[0.99143054 0.89206472 0.99962191 0.7550364  0.8844133  0.9686422 ]
#   [0.97503005 0.86090473 0.9935069  0.81170926 0.91118304 0.98371376]
#   [0.9487603  0.8201243  0.98173063 0.86882862 0.93591344 0.99445701]
#   [0.91082929 0.76815517 0.9650798  0.92386024 0.95801506 1.        ]
#   [0.85811335 0.70279359 0.94628268 0.97150355 0.97667882 0.99920982]
#   [0.78551182 0.62066524 0.93279047 1.         0.99080519 0.99049977]
#   [0.70702069 0.52425761 0.93595537 0.99380564 1.         0.97397552]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 43: [[0.44565105]]
# x_pred_input of day 44:
# [[[0.97503005 0.86090473 0.9935069  0.81170926 0.90685932 0.98371376]
#   [0.9487603  0.8201243  0.98173063 0.86882862 0.93147237 0.99445701]
#   [0.91082929 0.76815517 0.9650798  0.92386024 0.95346912 1.        ]
#   [0.85811335 0.70279359 0.94628268 0.97150355 0.97204431 0.99920982]
#   [0.78551182 0.62066524 0.93279047 1.         0.98610365 0.99049977]
#   [0.70702069 0.52425761 0.93595537 0.99380564 0.99525483 0.97397552]
#   [0.64193156 0.42249166 0.95568677 0.95412001 1.         0.95185718]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 44: [[0.41404486]]
# x_pred_input of day 45:
# [[[0.9487603  0.8201243  0.98173063 0.86882862 0.93046142 0.99445701]
#   [0.91082929 0.76815517 0.9650798  0.92386024 0.95243429 1.        ]
#   [0.85811335 0.70279359 0.94628268 0.97150355 0.97098932 0.99920982]
#   [0.78551182 0.62066524 0.93279047 1.         0.9850334  0.99049977]
#   [0.70702069 0.52425761 0.93595537 0.99380564 0.99417465 0.97397552]
#   [0.64193156 0.42249166 0.95568677 0.95412001 0.99891467 0.95185718]
#   [0.59624731 0.32453663 0.98104076 0.89718906 1.         0.92681443]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 45: [[0.39280936]]
# x_pred_input of day 46:
# [[[0.91082929 0.76815517 0.96129999 0.92386024 0.95243429 1.        ]
#   [0.85811335 0.70279359 0.94257649 0.97150355 0.97098932 0.99920982]
#   [0.78551182 0.62066524 0.92913713 1.         0.9850334  0.99049977]
#   [0.70702069 0.52425761 0.93228963 0.99380564 0.99417465 0.97397552]
#   [0.64193156 0.42249166 0.95194375 0.95412001 0.99891467 0.95185718]
#   [0.59624731 0.32453663 0.97719844 0.89718906 1.         0.92681443]
#   [0.56555309 0.23597467 1.         0.83546297 0.99801886 0.90077655]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 46: [[0.3815821]]
# x_pred_input of day 47:
# [[[0.85811335 0.70279359 0.92745076 0.97150355 0.97098932 0.99920982]
#   [0.78551182 0.62066524 0.91422706 1.         0.9850334  0.99049977]
#   [0.70702069 0.52425761 0.91732898 0.99380564 0.99417465 0.97397552]
#   [0.64193156 0.42249166 0.9366677  0.95412001 0.99891467 0.95185718]
#   [0.59624731 0.32453663 0.96151712 0.89718906 1.         0.92681443]
#   [0.56555309 0.23597467 0.98395278 0.83546297 0.99801886 0.90077655]
#   [0.54932499 0.16088728 1.         0.77642809 0.99356818 0.87543138]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 47: [[0.37806863]]
# x_pred_input of day 48:
# [[[0.78551182 0.62066524 0.90647914 1.         0.9850334  0.99049977]
#   [0.70702069 0.52425761 0.90955477 0.99380564 0.99417465 0.97397552]
#   [0.64193156 0.42249166 0.92872961 0.95412001 0.99891467 0.95185718]
#   [0.59624731 0.32453663 0.95336843 0.89718906 1.         0.92681443]
#   [0.56555309 0.23597467 0.97561395 0.83546297 0.99801886 0.90077655]
#   [0.54932499 0.16088728 0.99152517 0.77642809 0.99356818 0.87543138]
#   [0.54424653 0.10114805 1.         0.72370156 0.98717079 0.85194077]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# y_pred of day 48: [[0.3784061]]
# x_pred_input of day 49:
# [[[0.70702069 0.52425761 0.90807665 0.99380564 0.99417465 0.97397552]
#   [0.64193156 0.42249166 0.92722032 0.95412001 0.99891467 0.95185718]
#   [0.59624731 0.32453663 0.9518191  0.89718906 1.         0.92681443]
#   [0.56555309 0.23597467 0.97402847 0.83546297 0.99801886 0.90077655]
#   [0.54932499 0.16088728 0.98991384 0.77642809 0.99356818 0.87543138]
#   [0.54424653 0.10114805 0.99837489 0.72370156 0.98717079 0.85194077]
#   [0.54473433 0.05607924 1.         0.67810564 0.97896422 0.83074108]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 49: [[0.38121578]]
# x_pred_input of day 50:
# [[[0.64193156 0.42249166 0.92722032 0.95412001 0.99891467 0.95185718]
#   [0.59624731 0.32453663 0.9518191  0.89718906 1.         0.92681443]
#   [0.56555309 0.23597467 0.97402847 0.83546297 0.99801886 0.90077655]
#   [0.54932499 0.16088728 0.98991384 0.77642809 0.99356818 0.87543138]
#   [0.54424653 0.10114805 0.99837489 0.72370156 0.98717079 0.85194077]
#   [0.54473433 0.05607924 1.         0.67810564 0.97896422 0.83074108]
#   [0.54879549 0.02427924 0.99570667 0.63961587 0.96894335 0.81200764]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 50: [[0.38720402]]
# x_pred_input of day 51:
# [[[0.59624731 0.32453663 0.9518191  0.89718906 1.         0.92681443]
#   [0.56555309 0.23597467 0.97402847 0.83546297 0.99801886 0.90077655]
#   [0.54932499 0.16088728 0.98991384 0.77642809 0.99356818 0.87543138]
#   [0.54424653 0.10114805 0.99837489 0.72370156 0.98717079 0.85194077]
#   [0.54473433 0.05607924 1.         0.67810564 0.97896422 0.83074108]
#   [0.54879549 0.02427924 0.99570667 0.63961587 0.96894335 0.81200764]
#   [0.55745102 0.00485909 0.9856599  0.60855645 0.95731709 0.79601151]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 51: [[0.39559388]]
# x_pred_input of day 52:
# [[[0.56555309 0.23857506 0.97402847 0.83546297 0.99801886 0.90077655]
#   [0.54932499 0.16374323 0.98991384 0.77642809 0.99356818 0.87543138]
#   [0.54424653 0.10420733 0.99837489 0.72370156 0.98717079 0.85194077]
#   [0.54473433 0.05929192 1.         0.67810564 0.97896422 0.83074108]
#   [0.54879549 0.02760015 0.99570667 0.63961587 0.96894335 0.81200764]
#   [0.55745102 0.00824609 0.9856599  0.60855645 0.95731709 0.79601151]
#   [0.56957789 0.         0.9698107  0.58523739 0.94439548 0.78287428]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 52: [[0.40536073]]
# x_pred_input of day 53:
# [[[0.54932499 0.16374323 0.98991384 0.77642809 0.99356818 0.87543138]
#   [0.54424653 0.10420733 0.99837489 0.72370156 0.98717079 0.85194077]
#   [0.54473433 0.05929192 1.         0.67810564 0.97896422 0.83074108]
#   [0.54879549 0.02760015 0.99570667 0.63961587 0.96894335 0.81200764]
#   [0.55745102 0.00824609 0.9856599  0.60855645 0.95731709 0.79601151]
#   [0.56957789 0.         0.9698107  0.58523739 0.94439548 0.78287428]
#   [0.58369509 0.00125083 0.94799716 0.56997603 0.93053499 0.77254285]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 53: [[0.4153883]]
# x_pred_input of day 54:
# [[[0.54424653 0.10420733 0.99837489 0.72370156 0.98717079 0.85194077]
#   [0.54473433 0.05929192 1.         0.67810564 0.97896422 0.83074108]
#   [0.54879549 0.02760015 0.99570667 0.63961587 0.96894335 0.81200764]
#   [0.55745102 0.00824609 0.9856599  0.60855645 0.95731709 0.79601151]
#   [0.56957789 0.         0.9698107  0.58523739 0.94439548 0.78287428]
#   [0.58369509 0.00125083 0.94799716 0.56997603 0.93053499 0.77254285]
#   [0.59818913 0.01006057 0.92000728 0.56312042 0.91612425 0.7647915 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 54: [[0.4246848]]
# x_pred_input of day 55:
# [[[0.54473433 0.05929192 1.         0.67810564 0.97896422 0.83074108]
#   [0.54879549 0.02760015 0.99570667 0.63961587 0.96894335 0.81200764]
#   [0.55745102 0.00824609 0.9856599  0.60855645 0.95731709 0.79601151]
#   [0.56957789 0.         0.9698107  0.58523739 0.94439548 0.78287428]
#   [0.58369509 0.00125083 0.94799716 0.56997603 0.93053499 0.77254285]
#   [0.59818913 0.01006057 0.92000728 0.56312042 0.91612425 0.7647915 ]
#   [0.61162649 0.02432044 0.88621089 0.56464549 0.90151414 0.75925814]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 55: [[0.4319853]]
# x_pred_input of day 56:
# [[[0.54879549 0.02760015 0.99570667 0.63961587 0.96894335 0.81200764]
#   [0.55745102 0.00824609 0.9856599  0.60855645 0.95731709 0.79601151]
#   [0.56957789 0.         0.9698107  0.58523739 0.94439548 0.78287428]
#   [0.58369509 0.00125083 0.94799716 0.56997603 0.93053499 0.77254285]
#   [0.59818913 0.01006057 0.92000728 0.56312042 0.91612425 0.7647915 ]
#   [0.61162649 0.02432044 0.88621089 0.56464549 0.90151414 0.75925814]
#   [0.62217878 0.04167297 0.84746753 0.57401244 0.88689644 0.75541382]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 56: [[0.43653342]]
# x_pred_input of day 57:
# [[[0.55745102 0.00824609 0.9856599  0.60855645 0.95731709 0.79601151]
#   [0.56957789 0.         0.9698107  0.58523739 0.94439548 0.78287428]
#   [0.58369509 0.00125083 0.94799716 0.56997603 0.93053499 0.77254285]
#   [0.59818913 0.01006057 0.92000728 0.56312042 0.91612425 0.7647915 ]
#   [0.61162649 0.02432044 0.88621089 0.56464549 0.90151414 0.75925814]
#   [0.62217878 0.04167297 0.84746753 0.57401244 0.88689644 0.75541382]
#   [0.62875274 0.05985133 0.80424755 0.59089844 0.87210362 0.75265958]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 57: [[0.43799448]]
# x_pred_input of day 58:
# [[[0.56957789 0.         0.9698107  0.58523739 0.94439548 0.78287428]
#   [0.58369509 0.00125083 0.94799716 0.56997603 0.93053499 0.77254285]
#   [0.59818913 0.01006057 0.92000728 0.56312042 0.91612425 0.7647915 ]
#   [0.61162649 0.02432044 0.88621089 0.56464549 0.90151414 0.75925814]
#   [0.62217878 0.04167297 0.84746753 0.57401244 0.88689644 0.75541382]
#   [0.62875274 0.05985133 0.80424755 0.59089844 0.87210362 0.75265958]
#   [0.63086459 0.07689993 0.75733969 0.61473851 0.85687611 0.7504002 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 58: [[0.43632892]]
# x_pred_input of day 59:
# [[[0.58369509 0.00125083 0.94799716 0.56997603 0.93053499 0.77254285]
#   [0.59818913 0.01006057 0.92000728 0.56312042 0.91612425 0.7647915 ]
#   [0.61162649 0.02432044 0.88621089 0.56464549 0.90151414 0.75925814]
#   [0.62217878 0.04167297 0.84746753 0.57401244 0.88689644 0.75541382]
#   [0.62875274 0.05985133 0.80424755 0.59089844 0.87210362 0.75265958]
#   [0.63086459 0.07689993 0.75733969 0.61473851 0.85687611 0.7504002 ]
#   [0.62845715 0.09127937 0.70776804 0.64477097 0.84096098 0.74809089]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 59: [[0.43163186]]
# x_pred_input of day 60:
# [[[0.59818913 0.01006057 0.92000728 0.56312042 0.91612425 0.7647915 ]
#   [0.61162649 0.02432044 0.88621089 0.56464549 0.90151414 0.75925814]
#   [0.62217878 0.04167297 0.84746753 0.57401244 0.88689644 0.75541382]
#   [0.62875274 0.05985133 0.80424755 0.59089844 0.87210362 0.75265958]
#   [0.63086459 0.07689993 0.75733969 0.61473851 0.85687611 0.7504002 ]
#   [0.62845715 0.09127937 0.70776804 0.64477097 0.84096098 0.74809089]
#   [0.62166793 0.10186234 0.65719189 0.67960691 0.82417001 0.74525387]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 60: [[0.42435843]]
# x_pred_input of day 61:
# [[[0.61162649 0.02432044 0.88621089 0.56464549 0.90151414 0.75925814]
#   [0.62217878 0.04167297 0.84746753 0.57401244 0.88689644 0.75541382]
#   [0.62875274 0.05985133 0.80424755 0.59089844 0.87210362 0.75265958]
#   [0.63086459 0.07689993 0.75733969 0.61473851 0.85687611 0.7504002 ]
#   [0.62845715 0.09127937 0.70776804 0.64477097 0.84096098 0.74809089]
#   [0.62166793 0.10186234 0.65719189 0.67960691 0.82417001 0.74525387]
#   [0.61115476 0.10804032 0.60907231 0.71588956 0.80657144 0.74152929]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 61: [[0.4153673]]
# x_pred_input of day 62:
# [[[0.62217878 0.04167297 0.84746753 0.57401244 0.88689644 0.75541382]
#   [0.62875274 0.05985133 0.80424755 0.59089844 0.87210362 0.75265958]
#   [0.63086459 0.07689993 0.75733969 0.61473851 0.85687611 0.7504002 ]
#   [0.62845715 0.09127937 0.70776804 0.64477097 0.84096098 0.74809089]
#   [0.62166793 0.10186234 0.65719189 0.67960691 0.82417001 0.74525387]
#   [0.61115476 0.10804032 0.60907231 0.71588956 0.80657144 0.74152929]
#   [0.5981588  0.10982331 0.57170996 0.74455134 0.78842751 0.73672827]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 62: [[0.40610301]]
# x_pred_input of day 63:
# [[[0.62875274 0.05985133 0.80424755 0.59089844 0.87210362 0.75265958]
#   [0.63086459 0.07689993 0.75733969 0.61473851 0.85687611 0.7504002 ]
#   [0.62845715 0.09127937 0.70776804 0.64477097 0.84096098 0.74809089]
#   [0.62166793 0.10186234 0.65719189 0.67960691 0.82417001 0.74525387]
#   [0.61115476 0.10804032 0.60907231 0.71588956 0.80657144 0.74152929]
#   [0.5981588  0.10982331 0.57170996 0.74455134 0.78842751 0.73672827]
#   [0.58476801 0.10800374 0.55163734 0.75754203 0.77002255 0.73090985]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 63: [[0.3983825]]
# x_pred_input of day 64:
# [[[0.63086459 0.07689993 0.75733969 0.61473851 0.85687611 0.7504002 ]
#   [0.62845715 0.09127937 0.70776804 0.64477097 0.84096098 0.74809089]
#   [0.62166793 0.10186234 0.65719189 0.67960691 0.82417001 0.74525387]
#   [0.61115476 0.10804032 0.60907231 0.71588956 0.80657144 0.74152929]
#   [0.5981588  0.10982331 0.57170996 0.74455134 0.78842751 0.73672827]
#   [0.58476801 0.10800374 0.55163734 0.75754203 0.77002255 0.73090985]
#   [0.57360864 0.10416732 0.54538301 0.75821987 0.75185481 0.72441665]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 64: [[0.39304572]]
# x_pred_input of day 65:
# [[[0.62845715 0.09127937 0.70776804 0.64477097 0.84096098 0.74809089]
#   [0.62166793 0.10186234 0.65719189 0.67960691 0.82417001 0.74525387]
#   [0.61115476 0.10804032 0.60907231 0.71588956 0.80657144 0.74152929]
#   [0.5981588  0.10982331 0.57170996 0.74455134 0.78842751 0.73672827]
#   [0.58476801 0.10800374 0.55163734 0.75754203 0.77002255 0.73090985]
#   [0.57360864 0.10416732 0.54538301 0.75821987 0.75185481 0.72441665]
#   [0.56589473 0.10000647 0.54468787 0.75575827 0.73452687 0.71769238]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 65: [[0.38831356]]
# x_pred_input of day 66:
# [[[0.62166793 0.10186234 0.65719189 0.67960691 0.82417001 0.74525387]
#   [0.61115476 0.10804032 0.60907231 0.71588956 0.80657144 0.74152929]
#   [0.5981588  0.10982331 0.57170996 0.74455134 0.78842751 0.73672827]
#   [0.58476801 0.10800374 0.55163734 0.75754203 0.77002255 0.73090985]
#   [0.57360864 0.10416732 0.54538301 0.75821987 0.75185481 0.72441665]
#   [0.56589473 0.10000647 0.54468787 0.75575827 0.73452687 0.71769238]
#   [0.55905477 0.09594628 0.54486941 0.75479317 0.71860606 0.71085527]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 66: [[0.38115263]]
# x_pred_input of day 67:
# [[[0.61115476 0.10804032 0.60907231 0.71588956 0.80657144 0.74152929]
#   [0.5981588  0.10982331 0.57170996 0.74455134 0.78842751 0.73672827]
#   [0.58476801 0.10800374 0.55163734 0.75754203 0.77002255 0.73090985]
#   [0.57360864 0.10416732 0.54538301 0.75821987 0.75185481 0.72441665]
#   [0.56589473 0.10000647 0.54468787 0.75575827 0.73452687 0.71769238]
#   [0.55905477 0.09594628 0.54486941 0.75479317 0.71860606 0.71085527]
#   [0.54870421 0.0907763  0.54490969 0.75467055 0.70460266 0.70352947]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 67: [[0.3707451]]
# x_pred_input of day 68:
# [[[0.5981588  0.10982331 0.57170996 0.74455134 0.78842751 0.73672827]
#   [0.58476801 0.10800374 0.55163734 0.75754203 0.77002255 0.73090985]
#   [0.57360864 0.10416732 0.54538301 0.75821987 0.75185481 0.72441665]
#   [0.56589473 0.10000647 0.54468787 0.75575827 0.73452687 0.71769238]
#   [0.55905477 0.09594628 0.54486941 0.75479317 0.71860606 0.71085527]
#   [0.54870421 0.0907763  0.54490969 0.75467055 0.70460266 0.70352947]
#   [0.53366094 0.08314502 0.54587135 0.75221531 0.69320425 0.69524475]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 68: [[0.3591145]]
# x_pred_input of day 69:
# [[[0.58476801 0.10800374 0.55163734 0.75754203 0.77002255 0.73090985]
#   [0.57360864 0.10416732 0.54538301 0.75821987 0.75185481 0.72441665]
#   [0.56589473 0.10000647 0.54468787 0.75575827 0.73452687 0.71769238]
#   [0.55905477 0.09594628 0.54486941 0.75479317 0.71860606 0.71085527]
#   [0.54870421 0.0907763  0.54490969 0.75467055 0.70460266 0.70352947]
#   [0.53366094 0.08314502 0.54587135 0.75221531 0.69320425 0.69524475]
#   [0.51684984 0.07305047 0.54875858 0.74527825 0.6845974  0.68589776]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 69: [[0.34849653]]
# x_pred_input of day 70:
# [[[0.57360864 0.10416732 0.54538301 0.75821987 0.75185481 0.72441665]
#   [0.56589473 0.10000647 0.54468787 0.75575827 0.73452687 0.71769238]
#   [0.55905477 0.09594628 0.54486941 0.75479317 0.71860606 0.71085527]
#   [0.54870421 0.0907763  0.54490969 0.75467055 0.70460266 0.70352947]
#   [0.53366094 0.08314502 0.54587135 0.75221531 0.69320425 0.69524475]
#   [0.51684984 0.07305047 0.54875858 0.74527825 0.6845974  0.68589776]
#   [0.50150241 0.06165591 0.55348212 0.73374258 0.67824178 0.67575084]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 70: [[0.33979455]]
# x_pred_input of day 71:
# [[[0.56589473 0.10000647 0.54468787 0.75575827 0.73452687 0.71769238]
#   [0.55905477 0.09594628 0.54486941 0.75479317 0.71860606 0.71085527]
#   [0.54870421 0.0907763  0.54490969 0.75467055 0.70460266 0.70352947]
#   [0.53366094 0.08314502 0.54587135 0.75221531 0.69320425 0.69524475]
#   [0.51684984 0.07305047 0.54875858 0.74527825 0.6845974  0.68589776]
#   [0.50150241 0.06165591 0.55348212 0.73374258 0.67824178 0.67575084]
#   [0.48892439 0.05034686 0.55911143 0.71863884 0.6733845  0.66518516]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 71: [[0.33288902]]
# x_pred_input of day 72:
# [[[0.55905477 0.09594628 0.54486941 0.75479317 0.71860606 0.71085527]
#   [0.54870421 0.0907763  0.54490969 0.75467055 0.70460266 0.70352947]
#   [0.53366094 0.08314502 0.54587135 0.75221531 0.69320425 0.69524475]
#   [0.51684984 0.07305047 0.54875858 0.74527825 0.6845974  0.68589776]
#   [0.50150241 0.06165591 0.55348212 0.73374258 0.67824178 0.67575084]
#   [0.48892439 0.05034686 0.55911143 0.71863884 0.6733845  0.66518516]
#   [0.478943   0.0401471  0.56440096 0.70152126 0.66946465 0.65452655]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 72: [[0.32713482]]
# x_pred_input of day 73:
# [[[0.54870421 0.0907763  0.54490969 0.75467055 0.70460266 0.70352947]
#   [0.53366094 0.08314502 0.54587135 0.75221531 0.69320425 0.69524475]
#   [0.51684984 0.07305047 0.54875858 0.74527825 0.6845974  0.68589776]
#   [0.50150241 0.06165591 0.55348212 0.73374258 0.67824178 0.67575084]
#   [0.48892439 0.05034686 0.55911143 0.71863884 0.6733845  0.66518516]
#   [0.478943   0.0401471  0.56440096 0.70152126 0.66946465 0.65452655]
#   [0.47062576 0.03151806 0.56827977 0.68377366 0.66590284 0.64396712]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 73: [[0.3217627]]
# x_pred_input of day 74:
# [[[0.53366094 0.08314502 0.54587135 0.75221531 0.69320425 0.69524475]
#   [0.51684984 0.07305047 0.54875858 0.74527825 0.6845974  0.68589776]
#   [0.50150241 0.06165591 0.55348212 0.73374258 0.67824178 0.67575084]
#   [0.48892439 0.05034686 0.55911143 0.71863884 0.6733845  0.66518516]
#   [0.478943   0.0401471  0.56440096 0.70152126 0.66946465 0.65452655]
#   [0.47062576 0.03151806 0.56827977 0.68377366 0.66590284 0.64396712]
#   [0.46286081 0.02441227 0.57000384 0.66640222 0.66221944 0.63355825]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# y_pred of day 74: [[0.316321]]
# x_pred_input of day 75:
# [[[0.51684984 0.07305047 0.54875858 0.74527825 0.6845974  0.68589776]
#   [0.50150241 0.06165591 0.55348212 0.73374258 0.67824178 0.67575084]
#   [0.48892439 0.05034686 0.55911143 0.71863884 0.6733845  0.66518516]
#   [0.478943   0.0401471  0.56440096 0.70152126 0.66946465 0.65452655]
#   [0.47062576 0.03151806 0.56827977 0.68377366 0.66590284 0.64396712]
#   [0.46286081 0.02441227 0.57000384 0.66640222 0.66221944 0.63355825]
#   [0.45499522 0.01854548 0.56911599 0.6501198  0.65815798 0.62327451]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# y_pred of day 75: [[0.31079197]]
# x_pred_input of day 76:
# [[[0.50150241 0.06165591 0.55348212 0.73374258 0.67824178 0.67575084]
#   [0.48892439 0.05034686 0.55911143 0.71863884 0.6733845  0.66518516]
#   [0.478943   0.0401471  0.56440096 0.70152126 0.66946465 0.65452655]
#   [0.47062576 0.03151806 0.56827977 0.68377366 0.66590284 0.64396712]
#   [0.46286081 0.02441227 0.57000384 0.66640222 0.66221944 0.63355825]
#   [0.45499522 0.01854548 0.56911599 0.6501198  0.65815798 0.62327451]
#   [0.44700347 0.01367189 0.56547862 0.63541639 0.65355102 0.6130901 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# y_pred of day 76: [[0.30540633]]
# x_pred_input of day 77:
# [[[0.48892439 0.05034686 0.55911143 0.71863884 0.6733845  0.66518516]
#   [0.478943   0.0401471  0.56440096 0.70152126 0.66946465 0.65452655]
#   [0.47062576 0.03151806 0.56827977 0.68377366 0.66590284 0.64396712]
#   [0.46286081 0.02441227 0.57000384 0.66640222 0.66221944 0.63355825]
#   [0.45499522 0.01854548 0.56911599 0.6501198  0.65815798 0.62327451]
#   [0.44700347 0.01367189 0.56547862 0.63541639 0.65355102 0.6130901 ]
#   [0.43921896 0.0097049  0.55922843 0.62257729 0.64820001 0.60301838]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 77: [[0.30043647]]
# x_pred_input of day 78:
# [[[0.478943   0.0401471  0.56440096 0.70152126 0.66946465 0.65452655]
#   [0.47062576 0.03151806 0.56827977 0.68377366 0.66590284 0.64396712]
#   [0.46286081 0.02441227 0.57000384 0.66640222 0.66221944 0.63355825]
#   [0.45499522 0.01854548 0.56911599 0.6501198  0.65815798 0.62327451]
#   [0.44700347 0.01367189 0.56547862 0.63541639 0.65355102 0.6130901 ]
#   [0.43921896 0.0097049  0.55922843 0.62257729 0.64820001 0.60301838]
#   [0.43203542 0.0067048  0.55071604 0.61170192 0.64197504 0.59311479]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 78: [[0.29606655]]
# x_pred_input of day 79:
# [[[0.47062576 0.03151806 0.56827977 0.68377366 0.66590284 0.64396712]
#   [0.46286081 0.02441227 0.57000384 0.66640222 0.66221944 0.63355825]
#   [0.45499522 0.01854548 0.56911599 0.6501198  0.65815798 0.62327451]
#   [0.44700347 0.01367189 0.56547862 0.63541639 0.65355102 0.6130901 ]
#   [0.43921896 0.0097049  0.55922843 0.62257729 0.64820001 0.60301838]
#   [0.43203542 0.0067048  0.55071604 0.61170192 0.64197504 0.59311479]
#   [0.42571905 0.00480148 0.5404533  0.60271197 0.63482527 0.58345881]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# y_pred of day 79: [[0.2923419]]
# x_pred_input of day 80:
# [[[0.46286081 0.02441227 0.57000384 0.66640222 0.66221944 0.63355825]
#   [0.45499522 0.01854548 0.56911599 0.6501198  0.65815798 0.62327451]
#   [0.44700347 0.01367189 0.56547862 0.63541639 0.65355102 0.6130901 ]
#   [0.43921896 0.0097049  0.55922843 0.62257729 0.64820001 0.60301838]
#   [0.43203542 0.0067048  0.55071604 0.61170192 0.64197504 0.59311479]
#   [0.42571905 0.00480148 0.5404533  0.60271197 0.63482527 0.58345881]
#   [0.42033535 0.00410723 0.52908858 0.59534003 0.62677587 0.57412959]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 80: [[0.28920373]]
# x_pred_input of day 81:
# [[[0.45499522 0.01854548 0.56911599 0.6501198  0.65815798 0.62327451]
#   [0.44700347 0.01367189 0.56547862 0.63541639 0.65355102 0.6130901 ]
#   [0.43921896 0.0097049  0.55922843 0.62257729 0.64820001 0.60301838]
#   [0.43203542 0.0067048  0.55071604 0.61170192 0.64197504 0.59311479]
#   [0.42571905 0.00480148 0.5404533  0.60271197 0.63482527 0.58345881]
#   [0.42033535 0.00410723 0.52908858 0.59534003 0.62677587 0.57412959]
#   [0.41579939 0.00466637 0.51729522 0.58920277 0.61791302 0.56518934]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 81: [[0.28653336]]
# x_pred_input of day 82:
# [[[0.44700347 0.01367189 0.56547862 0.63541639 0.65355102 0.6130901 ]
#   [0.43921896 0.0097049  0.55922843 0.62257729 0.64820001 0.60301838]
#   [0.43203542 0.0067048  0.55071604 0.61170192 0.64197504 0.59311479]
#   [0.42571905 0.00480148 0.5404533  0.60271197 0.63482527 0.58345881]
#   [0.42033535 0.00410723 0.52908858 0.59534003 0.62677587 0.57412959]
#   [0.41579939 0.00466637 0.51729522 0.58920277 0.61791302 0.56518934]
#   [0.41193957 0.006439   0.505614   0.58393523 0.6083979  0.55667549]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 82: [[0.28418052]]
# x_pred_input of day 83:
# [[[0.43921896 0.0097049  0.55922843 0.62257729 0.64820001 0.60301838]
#   [0.43203542 0.0067048  0.55071604 0.61170192 0.64197504 0.59311479]
#   [0.42571905 0.00480148 0.5404533  0.60271197 0.63482527 0.58345881]
#   [0.42033535 0.00410723 0.52908858 0.59534003 0.62677587 0.57412959]
#   [0.41579939 0.00466637 0.51729522 0.58920277 0.61791302 0.56518934]
#   [0.41193957 0.006439   0.505614   0.58393523 0.6083979  0.55667549]
#   [0.40853874 0.0093036  0.49422556 0.57939301 0.59843133 0.54859797]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 83: [[0.28197062]]
# x_pred_input of day 84:
# [[[0.43203542 0.0067048  0.55071604 0.61170192 0.64197504 0.59311479]
#   [0.42571905 0.00480148 0.5404533  0.60271197 0.63482527 0.58345881]
#   [0.42033535 0.00410723 0.52908858 0.59534003 0.62677587 0.57412959]
#   [0.41579939 0.00466637 0.51729522 0.58920277 0.61791302 0.56518934]
#   [0.41193957 0.006439   0.505614   0.58393523 0.6083979  0.55667549]
#   [0.40853874 0.0093036  0.49422556 0.57939301 0.59843133 0.54859797]
#   [0.4053445  0.01306378 0.48278175 0.57581211 0.58822462 0.54093798]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 84: [[0.27970868]]
# x_pred_input of day 85:
# [[[0.42571905 0.00480148 0.5404533  0.60271197 0.63482527 0.58345881]
#   [0.42033535 0.00410723 0.52908858 0.59534003 0.62677587 0.57412959]
#   [0.41579939 0.00466637 0.51729522 0.58920277 0.61791302 0.56518934]
#   [0.41193957 0.006439   0.505614   0.58393523 0.6083979  0.55667549]
#   [0.40853874 0.0093036  0.49422556 0.57939301 0.59843133 0.54859797]
#   [0.4053445  0.01306378 0.48278175 0.57581211 0.58822462 0.54093798]
#   [0.40207505 0.01745631 0.47060527 0.57369822 0.5779789  0.53364747]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 85: [[0.27718714]]
# x_pred_input of day 86:
# [[[0.42033535 0.00410723 0.52908858 0.59534003 0.62677587 0.57412959]
#   [0.41579939 0.00466637 0.51729522 0.58920277 0.61791302 0.56518934]
#   [0.41193957 0.006439   0.505614   0.58393523 0.6083979  0.55667549]
#   [0.40853874 0.0093036  0.49422556 0.57939301 0.59843133 0.54859797]
#   [0.4053445  0.01306378 0.48278175 0.57581211 0.58822462 0.54093798]
#   [0.40207505 0.01745631 0.47060527 0.57369822 0.5779789  0.53364747]
#   [0.39843036 0.02216222 0.4574326  0.57326156 0.56787549 0.52664993]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# y_pred of day 86: [[0.27425194]]
# x_pred_input of day 87:
# [[[0.41579939 0.00466637 0.51729522 0.58920277 0.61791302 0.56518934]
#   [0.41193957 0.006439   0.505614   0.58393523 0.6083979  0.55667549]
#   [0.40853874 0.0093036  0.49422556 0.57939301 0.59843133 0.54859797]
#   [0.4053445  0.01306378 0.48278175 0.57581211 0.58822462 0.54093798]
#   [0.40207505 0.01745631 0.47060527 0.57369822 0.5779789  0.53364747]
#   [0.39843036 0.02216222 0.4574326  0.57326156 0.56787549 0.52664993]
#   [0.39418776 0.02684969 0.44401838 0.57382608 0.55805588 0.51985161]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 87: [[0.2709158]]
# x_pred_input of day 88:
# [[[0.41193957 0.006439   0.505614   0.58393523 0.6083979  0.55667549]
#   [0.40853874 0.0093036  0.49422556 0.57939301 0.59843133 0.54859797]
#   [0.4053445  0.01306378 0.48278175 0.57581211 0.58822462 0.54093798]
#   [0.40207505 0.01745631 0.47060527 0.57369822 0.5779789  0.53364747]
#   [0.39843036 0.02216222 0.4574326  0.57326156 0.56787549 0.52664993]
#   [0.39418776 0.02684969 0.44401838 0.57382608 0.55805588 0.51985161]
#   [0.38936565 0.03126546 0.43164251 0.574153   0.5486062  0.51316972]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 88: [[0.2674155]]
# x_pred_input of day 89:
# [[[0.40853874 0.0093036  0.49422556 0.57939301 0.59843133 0.54859797]
#   [0.4053445  0.01306378 0.48278175 0.57581211 0.58822462 0.54093798]
#   [0.40207505 0.01745631 0.47060527 0.57369822 0.5779789  0.53364747]
#   [0.39843036 0.02216222 0.4574326  0.57326156 0.56787549 0.52664993]
#   [0.39418776 0.02684969 0.44401838 0.57382608 0.55805588 0.51985161]
#   [0.38936565 0.03126546 0.43164251 0.574153   0.5486062  0.51316972]
#   [0.38430622 0.03533454 0.42102979 0.57345177 0.5395336  0.50656704]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 89: [[0.26408866]]
# x_pred_input of day 90:
# [[[0.4053445  0.01306378 0.48278175 0.57581211 0.58822462 0.54093798]
#   [0.40207505 0.01745631 0.47060527 0.57369822 0.5779789  0.53364747]
#   [0.39843036 0.02216222 0.4574326  0.57326156 0.56787549 0.52664993]
#   [0.39418776 0.02684969 0.44401838 0.57382608 0.55805588 0.51985161]
#   [0.38936565 0.03126546 0.43164251 0.574153   0.5486062  0.51316972]
#   [0.38430622 0.03533454 0.42102979 0.57345177 0.5395336  0.50656704]
#   [0.37949755 0.03917384 0.41208588 0.57171231 0.53074841 0.50006363]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# y_pred of day 90: [[0.26110396]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#          Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# 0     0.005824  0.000000         0.261104         0.261104  0.261104  0.005824
# 1     0.005704 -0.000010         0.261104         0.261104  0.261104  0.005813
# 2     0.005645 -0.000022         0.261104         0.261104  0.261104  0.005797
# 3     0.005669 -0.000029         0.261104         0.261104  0.261104  0.005784
# 4     0.005545 -0.000044         0.261104         0.261104  0.261104  0.005762
# ...        ...       ...              ...              ...       ...       ...
# 2155  0.274252 -0.033585         0.367378         0.252056  0.329873  0.312894
# 2156  0.270916 -0.032893         0.357192         0.252259  0.324317  0.308896
# 2157  0.267415 -0.032254         0.348458         0.251823  0.318983  0.304946
# 2158  0.264089 -0.031652         0.341096         0.250744  0.313818  0.301055
# 2159  0.261104 -0.031057         0.334713         0.249258  0.308743  0.297250
#
# [2160 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
# Dateframe of Close training set
df_train = df_filtered['Close'][:train_size].copy()

# Plot the forecast for df_val, df_test and df_forecast
plt.figure(figsize=(15, 7))
plt.plot(df_train, label='Train')
plt.plot(df_test['Y_test_pred'], label='Test prediction')
plt.plot(df_test['Y_test'], label='Test')
plt.plot(df_forecast_unscale['Close'], label='Forecast next 30 days')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  0.013736590953932983
# MAPE:  7.740082940669087
# SMAPE:  7.354994782054201
