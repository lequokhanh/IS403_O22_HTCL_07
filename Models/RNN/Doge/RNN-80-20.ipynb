# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../.dataset/Dodge-USD-3.2018-3.2024.csv')
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2018-03-01  0.006042  0.006320  0.005945  0.006215   0.006215  15518400
# 1  2018-03-02  0.006174  0.006232  0.005447  0.005482   0.005482  22498100
# 2  2018-03-03  0.005494  0.005756  0.005181  0.005301   0.005301  21545000
# 3  2018-03-04  0.005234  0.005502  0.005164  0.005502   0.005502  12133500
# 4  2018-03-05  0.005462  0.005535  0.005157  0.005218   0.005218  13627700

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2018-03-01  0.006042  0.006320  0.005945  0.006215   0.006215  15518400
# 2018-03-02  0.006174  0.006232  0.005447  0.005482   0.005482  22498100
# 2018-03-03  0.005494  0.005756  0.005181  0.005301   0.005301  21545000
# 2018-03-04  0.005234  0.005502  0.005164  0.005502   0.005502  12133500
# 2018-03-05  0.005462  0.005535  0.005157  0.005218   0.005218  13627700

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2018-10-02  0.005824  0.000241         0.006478         0.005382  0.005966  0.005739
# 2018-10-03  0.005704  0.000213         0.006358         0.005417  0.005981  0.005736
# 2018-10-04  0.005645  0.000183         0.006322         0.005400  0.005979  0.005727
# 2018-10-05  0.005669  0.000159         0.006282         0.005391  0.005973  0.005722
# 2018-10-06  0.005545  0.000129         0.006110         0.005464  0.005921  0.005705
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2018-10-02  0.005824  0.000241         0.006478         0.005382  0.005966  0.005739
# 2018-10-03  0.005704  0.000213         0.006358         0.005417  0.005981  0.005736
# 2018-10-04  0.005645  0.000183         0.006322         0.005400  0.005979  0.005727
# 2018-10-05  0.005669  0.000159         0.006282         0.005391  0.005973  0.005722
# 2018-10-06  0.005545  0.000129         0.006110         0.005464  0.005921  0.005705

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (1978, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.80)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1582, 6) (396, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1575, 7, 6) (1575,)
# (389, 7, 6) (389,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1575, 7, 6) (1575,)
# (389, 7, 6) (389,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
# model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
# model.add(Dense(1))
model.add(SimpleRNN(n_neurons, return_sequences=True,
          input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(SimpleRNN(n_neurons, return_sequences=True))
model.add(SimpleRNN(n_neurons))
model.add(Dense(1))


# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# 25/25 [==============================] - 3s 39ms/step - loss: 0.0581 - val_loss: 2.5925e-04
# Epoch 2/100
# 25/25 [==============================] - 1s 30ms/step - loss: 0.0031 - val_loss: 1.0565e-04
# Epoch 3/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 4.8540e-04
# Epoch 4/100
# 25/25 [==============================] - 1s 30ms/step - loss: 0.0013 - val_loss: 2.0286e-04
# Epoch 5/100
# 25/25 [==============================] - 1s 29ms/step - loss: 0.0011 - val_loss: 7.2401e-05
# Epoch 6/100
# 25/25 [==============================] - 1s 28ms/step - loss: 9.4408e-04 - val_loss: 1.7166e-04
# Epoch 7/100
# 25/25 [==============================] - 1s 31ms/step - loss: 9.3180e-04 - val_loss: 9.0120e-05
# Epoch 8/100
# 25/25 [==============================] - 1s 28ms/step - loss: 8.5059e-04 - val_loss: 1.9841e-04
# Epoch 9/100
# 25/25 [==============================] - 1s 26ms/step - loss: 8.0081e-04 - val_loss: 2.2809e-04
# Epoch 10/100
# 25/25 [==============================] - 1s 28ms/step - loss: 7.3471e-04 - val_loss: 1.0206e-04
# Epoch 11/100
# 25/25 [==============================] - 1s 26ms/step - loss: 6.8978e-04 - val_loss: 8.4245e-05
# Epoch 12/100
# 25/25 [==============================] - 1s 25ms/step - loss: 6.2262e-04 - val_loss: 1.0845e-04
# Epoch 13/100
# 25/25 [==============================] - 1s 28ms/step - loss: 6.7155e-04 - val_loss: 3.1783e-04
# Epoch 14/100
# 25/25 [==============================] - 1s 26ms/step - loss: 7.7936e-04 - val_loss: 4.4947e-05
# Epoch 15/100
# 25/25 [==============================] - 1s 25ms/step - loss: 6.7101e-04 - val_loss: 4.4843e-05
# Epoch 16/100
# 25/25 [==============================] - 1s 29ms/step - loss: 6.3407e-04 - val_loss: 1.0165e-04
# Epoch 17/100
# 25/25 [==============================] - 1s 33ms/step - loss: 6.0327e-04 - val_loss: 3.1907e-04
# Epoch 18/100
# 25/25 [==============================] - 1s 31ms/step - loss: 7.0019e-04 - val_loss: 1.1064e-04
# Epoch 19/100
# 25/25 [==============================] - 1s 30ms/step - loss: 6.2954e-04 - val_loss: 5.2048e-04
# Epoch 20/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.7285e-04 - val_loss: 4.1339e-05
# Epoch 21/100
# 25/25 [==============================] - 1s 32ms/step - loss: 4.6624e-04 - val_loss: 8.6582e-05
# Epoch 22/100
# 25/25 [==============================] - 1s 29ms/step - loss: 4.7696e-04 - val_loss: 2.1057e-04
# Epoch 23/100
# 25/25 [==============================] - 1s 33ms/step - loss: 6.5918e-04 - val_loss: 4.2029e-05
# Epoch 24/100
# 25/25 [==============================] - 1s 32ms/step - loss: 4.6753e-04 - val_loss: 2.7309e-04
# Epoch 25/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.5970e-04 - val_loss: 1.0038e-04
# Epoch 26/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.3856e-04 - val_loss: 3.6993e-05
# Epoch 27/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.6836e-04 - val_loss: 1.5531e-04
# Epoch 28/100
# 25/25 [==============================] - 1s 29ms/step - loss: 4.7331e-04 - val_loss: 3.5847e-05
# Epoch 29/100
# 25/25 [==============================] - 1s 29ms/step - loss: 4.2764e-04 - val_loss: 1.5627e-04
# Epoch 30/100
# 25/25 [==============================] - 1s 31ms/step - loss: 6.2324e-04 - val_loss: 7.5765e-05
# Epoch 31/100
# 25/25 [==============================] - 1s 28ms/step - loss: 6.5135e-04 - val_loss: 6.7378e-05
# Epoch 32/100
# 25/25 [==============================] - 1s 28ms/step - loss: 4.2164e-04 - val_loss: 6.2937e-05
# Epoch 33/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.6010e-04 - val_loss: 2.7459e-04
# Epoch 34/100
# 25/25 [==============================] - 1s 30ms/step - loss: 5.5642e-04 - val_loss: 1.5427e-04
# Epoch 35/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.8837e-04 - val_loss: 1.3189e-04
# Epoch 36/100
# 25/25 [==============================] - 1s 34ms/step - loss: 4.0060e-04 - val_loss: 9.4813e-05
# Epoch 37/100
# 25/25 [==============================] - 1s 29ms/step - loss: 5.9200e-04 - val_loss: 5.8868e-05
# Epoch 38/100
# 25/25 [==============================] - 1s 30ms/step - loss: 5.3209e-04 - val_loss: 3.2375e-05
# Epoch 39/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.0154e-04 - val_loss: 6.3175e-05
# Epoch 40/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.8780e-04 - val_loss: 1.1981e-04
# Epoch 41/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.0370e-04 - val_loss: 4.3129e-05
# Epoch 42/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.9223e-04 - val_loss: 3.3231e-05
# Epoch 43/100
# 25/25 [==============================] - 1s 29ms/step - loss: 3.7519e-04 - val_loss: 4.8816e-05
# Epoch 44/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.2968e-04 - val_loss: 1.4850e-04
# Epoch 45/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.1205e-04 - val_loss: 4.5243e-04
# Epoch 46/100
# 25/25 [==============================] - 1s 26ms/step - loss: 5.7062e-04 - val_loss: 2.4138e-04
# Epoch 47/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.1152e-04 - val_loss: 3.1546e-05
# Epoch 48/100
# 25/25 [==============================] - 1s 29ms/step - loss: 4.0122e-04 - val_loss: 3.7800e-05
# Epoch 49/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.7094e-04 - val_loss: 4.8897e-05
# Epoch 50/100
# 25/25 [==============================] - 1s 34ms/step - loss: 4.4943e-04 - val_loss: 2.4569e-04
# Epoch 51/100
# 25/25 [==============================] - 1s 32ms/step - loss: 6.4856e-04 - val_loss: 2.8861e-05
# Epoch 52/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.2132e-04 - val_loss: 2.9531e-05
# Epoch 53/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.3747e-04 - val_loss: 4.3525e-05
# Epoch 54/100
# 25/25 [==============================] - 1s 32ms/step - loss: 3.8828e-04 - val_loss: 2.9580e-05
# Epoch 55/100
# 25/25 [==============================] - 1s 25ms/step - loss: 5.3591e-04 - val_loss: 8.3507e-05
# Epoch 56/100
# 25/25 [==============================] - 1s 26ms/step - loss: 3.8105e-04 - val_loss: 9.1811e-05
# Epoch 57/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.3021e-04 - val_loss: 2.6296e-05
# Epoch 58/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.6926e-04 - val_loss: 6.3835e-04
# Epoch 59/100
# 25/25 [==============================] - 1s 41ms/step - loss: 6.7638e-04 - val_loss: 2.6871e-05
# Epoch 60/100
# 25/25 [==============================] - 1s 34ms/step - loss: 4.3215e-04 - val_loss: 8.3181e-05
# Epoch 61/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.9603e-04 - val_loss: 2.7058e-05
# Epoch 62/100
# 25/25 [==============================] - 1s 32ms/step - loss: 5.0126e-04 - val_loss: 2.5632e-05
# Epoch 63/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.7927e-04 - val_loss: 4.7035e-05
# Epoch 64/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.2425e-04 - val_loss: 7.0151e-05
# Epoch 65/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.3467e-04 - val_loss: 6.3331e-05
# Epoch 66/100
# 25/25 [==============================] - 1s 29ms/step - loss: 4.1727e-04 - val_loss: 2.9501e-05
# Epoch 67/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.9382e-04 - val_loss: 1.3109e-04
# Epoch 68/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.8392e-04 - val_loss: 1.0287e-04
# Epoch 69/100
# 25/25 [==============================] - 1s 31ms/step - loss: 5.5984e-04 - val_loss: 2.5850e-05
# Epoch 70/100
# 25/25 [==============================] - 1s 27ms/step - loss: 5.3353e-04 - val_loss: 3.0203e-05
# Epoch 71/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.2984e-04 - val_loss: 3.5814e-05
# Epoch 72/100
# 25/25 [==============================] - 1s 32ms/step - loss: 3.6561e-04 - val_loss: 1.0038e-04
# Epoch 73/100
# 25/25 [==============================] - 1s 33ms/step - loss: 4.2642e-04 - val_loss: 3.7028e-04
# Epoch 74/100
# 25/25 [==============================] - 1s 32ms/step - loss: 4.6766e-04 - val_loss: 3.4754e-04
# Epoch 75/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.4423e-04 - val_loss: 2.2035e-04
# Epoch 76/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.7111e-04 - val_loss: 2.6163e-05
# Epoch 77/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.8003e-04 - val_loss: 2.2577e-04
# Epoch 78/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.7006e-04 - val_loss: 4.2026e-05
# Epoch 79/100
# 25/25 [==============================] - 1s 31ms/step - loss: 4.3926e-04 - val_loss: 2.9429e-05
# Epoch 80/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.3630e-04 - val_loss: 1.3598e-04
# Epoch 81/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.9207e-04 - val_loss: 8.9391e-05
# Epoch 82/100
# 25/25 [==============================] - 1s 27ms/step - loss: 5.4661e-04 - val_loss: 2.4859e-04
# Epoch 83/100
# 25/25 [==============================] - 1s 29ms/step - loss: 5.3703e-04 - val_loss: 5.6429e-05
# Epoch 84/100
# 25/25 [==============================] - 1s 29ms/step - loss: 3.8616e-04 - val_loss: 7.2025e-05
# Epoch 85/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.7607e-04 - val_loss: 4.7704e-05
# Epoch 86/100
# 25/25 [==============================] - 1s 33ms/step - loss: 3.9438e-04 - val_loss: 1.0067e-04
# Epoch 87/100
# 25/25 [==============================] - 1s 28ms/step - loss: 3.7414e-04 - val_loss: 7.5422e-05
# Epoch 88/100
# 25/25 [==============================] - 1s 27ms/step - loss: 4.7624e-04 - val_loss: 4.5958e-04
# Epoch 89/100
# 25/25 [==============================] - 1s 32ms/step - loss: 4.0777e-04 - val_loss: 2.4039e-05
# Epoch 90/100
# 25/25 [==============================] - 1s 29ms/step - loss: 4.1968e-04 - val_loss: 6.2245e-05
# Epoch 91/100
# 25/25 [==============================] - 1s 30ms/step - loss: 4.0508e-04 - val_loss: 1.7617e-04
# Epoch 92/100
# 25/25 [==============================] - 1s 32ms/step - loss: 6.1668e-04 - val_loss: 8.7557e-04
# Epoch 93/100
# 25/25 [==============================] - 1s 28ms/step - loss: 4.7801e-04 - val_loss: 4.1690e-05
# Epoch 94/100
# 25/25 [==============================] - 1s 28ms/step - loss: 3.6403e-04 - val_loss: 1.2249e-04
# Epoch 95/100
# 25/25 [==============================] - 1s 31ms/step - loss: 3.3015e-04 - val_loss: 3.8778e-05
# Epoch 96/100
# 25/25 [==============================] - 1s 27ms/step - loss: 3.6669e-04 - val_loss: 1.8745e-04
# Epoch 97/100
# 25/25 [==============================] - 1s 29ms/step - loss: 4.5588e-04 - val_loss: 4.7411e-05
# Epoch 98/100
# 25/25 [==============================] - 1s 34ms/step - loss: 3.9287e-04 - val_loss: 7.2129e-05
# Epoch 99/100
# 25/25 [==============================] - 1s 32ms/step - loss: 3.2064e-04 - val_loss: 3.7083e-05
# Epoch 100/100
# 25/25 [==============================] - 1s 33ms/step - loss: 3.7460e-04 - val_loss: 3.5172e-04

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (396, 7, 6)
# 13/13 [==============================] - 0s 5ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.1238496  0.24606981 0.12074769 0.44352172 0.17421871 0.17608308]
#   [0.12376617 0.24622726 0.12077863 0.44539325 0.1747495  0.17654806]
#   [0.12858146 0.24793906 0.12154359 0.44671271 0.17563399 0.17764182]
#   [0.14070312 0.25339602 0.12600827 0.44312304 0.17716107 0.18032575]
#   [0.16838154 0.26714779 0.13958097 0.42812941 0.18027025 0.18662289]
#   [0.16926409 0.27790114 0.14864015 0.42083617 0.18347808 0.19244366]
#   [0.20200808 0.29728901 0.16618655 0.40405644 0.18858269 0.20228694]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 1: [[0.14682116]]
# x_pred_input of day 2:
# [[[0.12376617 0.24622726 0.12077863 0.44539325 0.1747495  0.17654806]
#   [0.12858146 0.24793906 0.12154359 0.44671271 0.17563399 0.17764182]
#   [0.14070312 0.25339602 0.12600827 0.44312304 0.17716107 0.18032575]
#   [0.16838154 0.26714779 0.13958097 0.42812941 0.18027025 0.18662289]
#   [0.16926409 0.27790114 0.14864015 0.42083617 0.18347808 0.19244366]
#   [0.20200808 0.29728901 0.16618655 0.40405644 0.18858269 0.20228694]
#   [0.21264    0.31551306 0.18223443 0.39176119 0.19429351 0.21267887]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 2: [[0.16027191]]
# x_pred_input of day 3:
# [[[0.12858146 0.24793906 0.12154359 0.44671271 0.17563399 0.17764182]
#   [0.14070312 0.25339602 0.12600827 0.44312304 0.17716107 0.18032575]
#   [0.16838154 0.26714779 0.13958097 0.42812941 0.18027025 0.18662289]
#   [0.16926409 0.27790114 0.14864015 0.42083617 0.18347808 0.19244366]
#   [0.20200808 0.29728901 0.16618655 0.40405644 0.18858269 0.20228694]
#   [0.21264    0.31551306 0.18223443 0.39176119 0.19429351 0.21267887]
#   [0.23232673 0.3357739  0.20046405 0.37861984 0.20110359 0.22483285]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 3: [[0.17328787]]
# x_pred_input of day 4:
# [[[0.14070312 0.25339602 0.12600827 0.44312304 0.17716107 0.18032575]
#   [0.16838154 0.26714779 0.13958097 0.42812941 0.18027025 0.18662289]
#   [0.16926409 0.27790114 0.14864015 0.42083617 0.18347808 0.19244366]
#   [0.20200808 0.29728901 0.16618655 0.40405644 0.18858269 0.20228694]
#   [0.21264    0.31551306 0.18223443 0.39176119 0.19429351 0.21267887]
#   [0.23232673 0.3357739  0.20046405 0.37861984 0.20110359 0.22483285]
#   [0.25137707 0.35717782 0.22014464 0.36640522 0.20886085 0.23849212]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 4: [[0.1939177]]
# x_pred_input of day 5:
# [[[0.16838154 0.26714779 0.13958097 0.42812941 0.18027025 0.18662289]
#   [0.16926409 0.27790114 0.14864015 0.42083617 0.18347808 0.19244366]
#   [0.20200808 0.29728901 0.16618655 0.40405644 0.18858269 0.20228694]
#   [0.21264    0.31551306 0.18223443 0.39176119 0.19429351 0.21267887]
#   [0.23232673 0.3357739  0.20046405 0.37861984 0.20110359 0.22483285]
#   [0.25137707 0.35717782 0.22014464 0.36640522 0.20886085 0.23849212]
#   [0.2815712  0.38311789 0.24435261 0.35015009 0.21835486 0.25507096]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 5: [[0.21792433]]
# x_pred_input of day 6:
# [[[0.16926409 0.27790114 0.14864015 0.42083617 0.18347808 0.19244366]
#   [0.20200808 0.29728901 0.16618655 0.40405644 0.18858269 0.20228694]
#   [0.21264    0.31551306 0.18223443 0.39176119 0.19429351 0.21267887]
#   [0.23232673 0.3357739  0.20046405 0.37861984 0.20110359 0.22483285]
#   [0.25137707 0.35717782 0.22014464 0.36640522 0.20886085 0.23849212]
#   [0.2815712  0.38311789 0.24435261 0.35015009 0.21835486 0.25507096]
#   [0.31670764 0.41403911 0.27340995 0.33124595 0.22970517 0.27498215]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 6: [[0.24700116]]
# x_pred_input of day 7:
# [[[0.20200808 0.29728901 0.16618655 0.40405644 0.18858269 0.20228694]
#   [0.21264    0.31551306 0.18223443 0.39176119 0.19429351 0.21267887]
#   [0.23232673 0.3357739  0.20046405 0.37861984 0.20110359 0.22483285]
#   [0.25137707 0.35717782 0.22014464 0.36640522 0.20886085 0.23849212]
#   [0.2815712  0.38311789 0.24435261 0.35015009 0.21835486 0.25507096]
#   [0.31670764 0.41403911 0.27340995 0.33124595 0.22970517 0.27498215]
#   [0.35926491 0.45109731 0.30839382 0.30882378 0.24348693 0.29894558]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 7: [[0.28708884]]
# x_pred_input of day 8:
# [[[0.21264    0.31551306 0.18223443 0.39176119 0.19429351 0.21267887]
#   [0.23232673 0.3357739  0.20046405 0.37861984 0.20110359 0.22483285]
#   [0.25137707 0.35717782 0.22014464 0.36640522 0.20886085 0.23849212]
#   [0.2815712  0.38311789 0.24435261 0.35015009 0.21835486 0.25507096]
#   [0.31670764 0.41403911 0.27340995 0.33124595 0.22970517 0.27498215]
#   [0.35926491 0.45109731 0.30839382 0.30882378 0.24348693 0.29894558]
#   [0.41793783 0.49815899 0.35252623 0.28063781 0.26062709 0.32882794]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 8: [[0.33420986]]
# x_pred_input of day 9:
# [[[0.23232673 0.3357739  0.20046405 0.35335427 0.20110359 0.22483285]
#   [0.25137707 0.35717782 0.22014464 0.34195474 0.20886085 0.23849212]
#   [0.2815712  0.38311789 0.24435261 0.32678433 0.21835486 0.25507096]
#   [0.31670764 0.41403911 0.27340995 0.30914167 0.22970517 0.27498215]
#   [0.35926491 0.45109731 0.30839382 0.28821575 0.24348693 0.29894558]
#   [0.41793783 0.49815899 0.35252623 0.26191065 0.26062709 0.32882794]
#   [0.48690483 0.55611013 0.40692819 0.22907254 0.28159402 0.36550438]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 9: [[0.39280716]]
# x_pred_input of day 10:
# [[[0.25137707 0.35717782 0.22014464 0.30162908 0.20886085 0.23849212]
#   [0.2815712  0.38311789 0.24435261 0.28824767 0.21835486 0.25507096]
#   [0.31670764 0.41403911 0.27340995 0.27268556 0.22970517 0.27498215]
#   [0.35926491 0.45109731 0.30839382 0.25422737 0.24348693 0.29894558]
#   [0.41793783 0.49815899 0.35252623 0.23102434 0.26062709 0.32882794]
#   [0.48690483 0.55611013 0.40692819 0.20205873 0.28159402 0.36550438]
#   [0.57266869 0.62778757 0.47434948 0.16509166 0.30754354 0.41067569]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 10: [[0.4519431]]
# x_pred_input of day 11:
# [[[0.2815712  0.38311789 0.24435261 0.25759148 0.21835486 0.25507096]
#   [0.31670764 0.41403911 0.27340995 0.24368446 0.22970517 0.27498215]
#   [0.35926491 0.45109731 0.30839382 0.22718936 0.24348693 0.29894558]
#   [0.41793783 0.49815899 0.35252623 0.20645406 0.26062709 0.32882794]
#   [0.48690483 0.55611013 0.40692819 0.18056905 0.28159402 0.36550438]
#   [0.57266869 0.62778757 0.47434948 0.14753356 0.30754354 0.41067569]
#   [0.65922092 0.70967718 0.55169918 0.11283487 0.33804516 0.46364301]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 11: [[0.48711306]]
# x_pred_input of day 12:
# [[[0.31670764 0.41403911 0.27340995 0.22918791 0.21866632 0.27498215]
#   [0.35926491 0.45109731 0.30839382 0.21367409 0.23178578 0.29894558]
#   [0.41793783 0.49815899 0.35252623 0.19417232 0.24810224 0.32882794]
#   [0.48690483 0.55611013 0.40692819 0.16982718 0.26806157 0.36550438]
#   [0.57266869 0.62778757 0.47434948 0.13875694 0.29276405 0.41067569]
#   [0.65922092 0.70967718 0.55169918 0.10612244 0.32179986 0.46364301]
#   [0.71069618 0.78640744 0.62699272 0.08220758 0.35363758 0.51876091]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 12: [[0.4840383]]
# x_pred_input of day 13:
# [[[0.35926491 0.45109731 0.30839382 0.2147912  0.23326356 0.29894558]
#   [0.41793783 0.49815899 0.35252623 0.19518746 0.24968405 0.32882794]
#   [0.48690483 0.55611013 0.40692819 0.17071505 0.26977063 0.36550438]
#   [0.57266869 0.62778757 0.47434948 0.13948237 0.29463061 0.41067569]
#   [0.65922092 0.70967718 0.55169918 0.10667725 0.32385154 0.46364301]
#   [0.71069618 0.78640744 0.62699272 0.08263736 0.35589225 0.51876091]
#   [0.70619591 0.83870906 0.68716427 0.07673728 0.38763534 0.56800045]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 13: [[0.45647258]]
# x_pred_input of day 14:
# [[[0.41793783 0.49815899 0.35252623 0.20478586 0.26062709 0.32882794]
#   [0.48690483 0.55611013 0.40692819 0.17911    0.28159402 0.36550438]
#   [0.57266869 0.62778757 0.47434948 0.14634145 0.30754354 0.41067569]
#   [0.65922092 0.70967718 0.55169918 0.11192314 0.33804516 0.46364301]
#   [0.71069618 0.78640744 0.62699272 0.08670108 0.37149013 0.51876091]
#   [0.70619591 0.83870906 0.68716427 0.08051086 0.40462444 0.56800045]
#   [0.66585032 0.85878042 0.72873286 0.09331372 0.43566546 0.6069111 ]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 14: [[0.42168492]]
# x_pred_input of day 15:
# [[[0.48690483 0.55611013 0.40692819 0.19096078 0.28159402 0.36550438]
#   [0.57266869 0.62778757 0.47434948 0.1560241  0.30754354 0.41067569]
#   [0.65922092 0.70967718 0.55169918 0.11932851 0.33804516 0.46364301]
#   [0.71069618 0.78640744 0.62699272 0.09243764 0.37149013 0.51876091]
#   [0.70619591 0.83870906 0.68716427 0.08583784 0.40462444 0.56800045]
#   [0.66585032 0.85878042 0.72873286 0.0994878  0.43566546 0.6069111 ]
#   [0.61493461 0.84968689 0.75439634 0.12804551 0.46367956 0.63499911]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 15: [[0.39352036]]
# x_pred_input of day 16:
# [[[0.57266869 0.62778757 0.47434948 0.16485504 0.30754354 0.41067569]
#   [0.65922092 0.70967718 0.55169918 0.12608248 0.33804516 0.46364301]
#   [0.71069618 0.78640744 0.62699272 0.09766959 0.37149013 0.51876091]
#   [0.70619591 0.83870906 0.68716427 0.09069625 0.40462444 0.56800045]
#   [0.66585032 0.85878042 0.72873286 0.10511879 0.43566546 0.6069111 ]
#   [0.61493461 0.84968689 0.75439634 0.13529287 0.46367956 0.63499911]
#   [0.57371254 0.821226   0.76857325 0.17649283 0.48899018 0.65465016]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 16: [[0.383775]]
# x_pred_input of day 17:
# [[[0.65922092 0.70967718 0.55169918 0.12860106 0.33804516 0.46364301]
#   [0.71069618 0.78640744 0.62699272 0.0996206  0.37149013 0.51876091]
#   [0.70619591 0.83870906 0.68716427 0.09250796 0.40462444 0.56800045]
#   [0.66585032 0.85878042 0.72873286 0.1072186  0.43566546 0.6069111 ]
#   [0.61493461 0.84968689 0.75439634 0.13799543 0.46367956 0.63499911]
#   [0.57371254 0.821226   0.76857325 0.18001838 0.48899018 0.65465016]
#   [0.55944909 0.78731287 0.77642187 0.22873932 0.51376708 0.67043597]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 17: [[0.39202714]]
# x_pred_input of day 18:
# [[[0.71069618 0.78640744 0.62699272 0.09796356 0.37149013 0.51876091]
#   [0.70619591 0.83870906 0.68716427 0.09096923 0.40462444 0.56800045]
#   [0.66585032 0.85878042 0.72873286 0.10543518 0.43566546 0.6069111 ]
#   [0.61493461 0.84968689 0.75439634 0.13570008 0.46367956 0.63499911]
#   [0.57371254 0.821226   0.76857325 0.17702404 0.48899018 0.65465016]
#   [0.55944909 0.78731287 0.77642187 0.22493458 0.51376708 0.67043597]
#   [0.57152705 0.7586966  0.78177865 0.27646727 0.53935814 0.68640659]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 18: [[0.4131618]]
# x_pred_input of day 19:
# [[[0.70619591 0.83870906 0.68716427 0.08725225 0.40462444 0.56800045]
#   [0.66585032 0.85878042 0.72873286 0.10112713 0.43566546 0.6069111 ]
#   [0.61493461 0.84968689 0.75439634 0.13015541 0.46367956 0.63499911]
#   [0.57371254 0.821226   0.76857325 0.16979089 0.48899018 0.65465016]
#   [0.55944909 0.78731287 0.77642187 0.21574382 0.51376708 0.67043597]
#   [0.57152705 0.7586966  0.78177865 0.2651709  0.53935814 0.68640659]
#   [0.60246006 0.74112891 0.78830352 0.31339661 0.56675238 0.70517994]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 19: [[0.44574997]]
# x_pred_input of day 20:
# [[[0.66585032 0.85878042 0.72873286 0.09513346 0.43566546 0.6069111 ]
#   [0.61493461 0.84968689 0.75439634 0.12244128 0.46367956 0.63499911]
#   [0.57371254 0.821226   0.76857325 0.15972761 0.48899018 0.65465016]
#   [0.55944909 0.78731287 0.77642187 0.20295698 0.51376708 0.67043597]
#   [0.57152705 0.7586966  0.78177865 0.24945458 0.53935814 0.68640659]
#   [0.60246006 0.74112891 0.78830352 0.29482201 0.56675238 0.70517994]
#   [0.65015656 0.73826115 0.79523534 0.34547201 0.59683076 0.72883225]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 20: [[0.48554307]]
# x_pred_input of day 21:
# [[[0.61493461 0.84968689 0.75439634 0.11417795 0.44282916 0.63499911]
#   [0.57371254 0.821226   0.76857325 0.1489479  0.46700164 0.65465016]
#   [0.55944909 0.78731287 0.77642187 0.18925979 0.49066438 0.67043597]
#   [0.57152705 0.7586966  0.78177865 0.23261935 0.51510469 0.68640659]
#   [0.60246006 0.74112891 0.78830352 0.27492503 0.54126708 0.70517994]
#   [0.65015656 0.73826115 0.79523534 0.32215675 0.56999292 0.72883225]
#   [0.70839833 0.75061898 0.80780235 0.36543944 0.60174554 0.75837284]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 21: [[0.52170974]]
# x_pred_input of day 22:
# [[[0.57371254 0.821226   0.76857325 0.14033977 0.43451727 0.65465016]
#   [0.55944909 0.78731287 0.77642187 0.17832192 0.45653405 0.67043597]
#   [0.57152705 0.7586966  0.78177865 0.21917561 0.4792743  0.68640659]
#   [0.60246006 0.74112891 0.78830352 0.25903631 0.50361685 0.70517994]
#   [0.65015656 0.73826115 0.79523534 0.30353837 0.53034454 0.72883225]
#   [0.70839833 0.75061898 0.80780235 0.34431964 0.55988846 0.75837284]
#   [0.76133239 0.7729147  0.82272249 0.38700323 0.59211197 0.79249903]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 22: [[0.5468704]]
# x_pred_input of day 23:
# [[[0.55944909 0.78731287 0.77642187 0.17142947 0.43546139 0.67043597]
#   [0.57152705 0.7586966  0.78177865 0.21070409 0.45715199 0.68640659]
#   [0.60246006 0.74112891 0.78830352 0.24902411 0.48037095 0.70517994]
#   [0.65015656 0.73826115 0.79523534 0.29180609 0.50586494 0.72883225]
#   [0.70839833 0.75061898 0.80780235 0.33101109 0.53404518 0.75837284]
#   [0.76133239 0.7729147  0.82272249 0.37204489 0.56478131 0.79249903]
#   [0.79815791 0.79712731 0.83782884 0.41467092 0.59706061 0.82852249]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 23: [[0.5634478]]
# x_pred_input of day 24:
# [[[0.57152705 0.7586966  0.78177865 0.20547153 0.44365959 0.68640659]
#   [0.60246006 0.74112891 0.78830352 0.24283993 0.46619326 0.70517994]
#   [0.65015656 0.73826115 0.79523534 0.28455947 0.49093482 0.72883225]
#   [0.70839833 0.75061898 0.80780235 0.32279087 0.51828334 0.75837284]
#   [0.76133239 0.7729147  0.82272249 0.36280565 0.54811233 0.79249903]
#   [0.79815791 0.79712731 0.83782884 0.40437312 0.57943894 0.82852249]
#   [0.82242078 0.81818673 0.85011312 0.4495279  0.61133358 0.86450654]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 24: [[0.57022595]]
# x_pred_input of day 25:
# [[[0.60246006 0.74112891 0.78830352 0.24039891 0.46063443 0.70517994]
#   [0.65015656 0.73826115 0.79523534 0.28169909 0.48508098 0.72883225]
#   [0.70839833 0.75061898 0.80780235 0.31954619 0.51210341 0.75837284]
#   [0.76133239 0.7729147  0.82272249 0.35915874 0.54157672 0.79249903]
#   [0.79815791 0.79712731 0.83782884 0.40030837 0.57252979 0.82852249]
#   [0.82242078 0.81818673 0.85011312 0.44500926 0.60404413 0.86450654]
#   [0.83234142 0.83153629 0.85819666 0.49215597 0.63473756 0.89845022]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 25: [[0.57285523]]
# x_pred_input of day 26:
# [[[0.65015656 0.73826115 0.79523534 0.28060496 0.48284766 0.72883225]
#   [0.70839833 0.75061898 0.80780235 0.31830505 0.50974568 0.75837284]
#   [0.76133239 0.7729147  0.82272249 0.35776375 0.53908329 0.79249903]
#   [0.79815791 0.79712731 0.83782884 0.39875356 0.56989386 0.82852249]
#   [0.82242078 0.81818673 0.85011312 0.44328083 0.6012631  0.86450654]
#   [0.83234142 0.83153629 0.85819666 0.49024441 0.63181522 0.89845022]
#   [0.83618968 0.83657652 0.86185616 0.53877086 0.6625038  0.92969907]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 26: [[0.5747359]]
# x_pred_input of day 27:
# [[[0.70839833 0.75061898 0.80780235 0.31742321 0.50807254 0.75837284]
#   [0.76133239 0.7729147  0.82272249 0.35677258 0.53731386 0.79249903]
#   [0.79815791 0.79712731 0.83782884 0.39764883 0.56802329 0.82852249]
#   [0.82242078 0.81818673 0.85011312 0.44205274 0.59928957 0.86450654]
#   [0.83234142 0.83153629 0.85819666 0.48888622 0.62974141 0.89845022]
#   [0.83618968 0.83657652 0.86185616 0.53727822 0.66032927 0.92969907]
#   [0.83894222 0.83466719 0.86264874 0.58471461 0.6895416  0.95835658]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 27: [[0.58028126]]
# x_pred_input of day 28:
# [[[0.76133239 0.7729147  0.82272249 0.35388169 0.53216337 0.79249903]
#   [0.79815791 0.79712731 0.83782884 0.39442672 0.56257844 0.82852249]
#   [0.82242078 0.81818673 0.85011312 0.43847083 0.59354501 0.86450654]
#   [0.83234142 0.83153629 0.85819666 0.48492482 0.62370495 0.89845022]
#   [0.83618968 0.83657652 0.86185616 0.53292471 0.65399961 0.92969907]
#   [0.83894222 0.83466719 0.86264874 0.57997672 0.68293192 0.95835658]
#   [0.84705851 0.82920453 0.86551693 0.61979061 0.71174996 0.98541928]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 28: [[0.5886197]]
# x_pred_input of day 29:
# [[[0.79815791 0.79712731 0.83782884 0.38967882 0.55458485 0.81901336]
#   [0.82242078 0.81818673 0.85011312 0.43319275 0.58511142 0.85458442]
#   [0.83234142 0.83153629 0.85819666 0.47908755 0.61484282 0.88813852]
#   [0.83618968 0.83657652 0.86185616 0.52650964 0.64470702 0.91902872]
#   [0.83894222 0.83466719 0.86264874 0.57299527 0.67322824 0.94735732]
#   [0.84705851 0.82920453 0.86551693 0.6123299  0.70163681 0.97410942]
#   [0.85926279 0.82244515 0.87396892 0.64024309 0.72971032 1.        ]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 29: [[0.600253]]
# x_pred_input of day 30:
# [[[0.82242078 0.81818673 0.85011312 0.4260379  0.57373805 0.833109  ]
#   [0.83234142 0.83153629 0.85819666 0.47117468 0.60289153 0.8658199 ]
#   [0.83618968 0.83657652 0.86185616 0.51781353 0.63217523 0.89593384]
#   [0.83894222 0.83466719 0.86264874 0.56353137 0.66014205 0.92355056]
#   [0.84705851 0.82920453 0.86551693 0.60221633 0.68799842 0.94963038]
#   [0.85926279 0.82244515 0.87396892 0.62966849 0.71552624 0.97487034]
#   [0.87628942 0.81642783 0.89038136 0.64228888 0.74296521 1.        ]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 30: [[0.61178154]]
# x_pred_input of day 31:
# [[[0.83234142 0.83153629 0.85819666 0.46358676 0.59149753 0.84469475]
#   [0.83618968 0.83657652 0.86185616 0.50947452 0.6202278  0.87407394]
#   [0.83894222 0.83466719 0.86264874 0.55445611 0.64766608 0.90101684]
#   [0.84705851 0.82920453 0.86551693 0.59251808 0.67499599 0.92646034]
#   [0.85926279 0.82244515 0.87396892 0.61952814 0.70200356 0.95108447]
#   [0.87628942 0.81642783 0.89038136 0.63194529 0.72892396 0.97560099]
#   [0.89316278 0.81100705 0.91100575 0.63346207 0.75527052 1.        ]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 31: [[0.61771107]]
# x_pred_input of day 32:
# [[[0.83618968 0.83657652 0.86185616 0.50528922 0.61425699 0.85424204]
#   [0.83894222 0.83466719 0.86264874 0.54990129 0.64143113 0.88057363]
#   [0.84705851 0.82920453 0.86551693 0.58765058 0.66849794 0.90543984]
#   [0.85926279 0.82244515 0.87396892 0.61443876 0.69524552 0.92950527]
#   [0.87628942 0.81642783 0.89038136 0.6267539  0.72190676 0.95346554]
#   [0.89316278 0.81100705 0.91100575 0.62825822 0.74799969 0.97731096]
#   [0.90184133 0.80325886 0.93067744 0.62666491 0.77296381 1.        ]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 32: [[0.6135029]]
# x_pred_input of day 33:
# [[[0.83894222 0.83466719 0.86264874 0.55312606 0.64584358 0.86353001]
#   [0.84705851 0.82920453 0.86551693 0.59109672 0.67309658 0.88791493]
#   [0.85926279 0.82244515 0.87396892 0.618042   0.70002816 0.91151458]
#   [0.87628942 0.81642783 0.89038136 0.63042935 0.72687281 0.93501108]
#   [0.89316278 0.81100705 0.91100575 0.6319425  0.75314523 0.95839498]
#   [0.90184133 0.80325886 0.93067744 0.63033985 0.77828108 0.98064487]
#   [0.89568222 0.78860339 0.94744683 0.6315008  0.8013242  1.        ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 33: [[0.59541506]]
# x_pred_input of day 34:
# [[[0.84705851 0.82920453 0.86551693 0.6063814  0.69360529 0.87550249]
#   [0.85926279 0.82244515 0.87396892 0.63402342 0.72135745 0.89877222]
#   [0.87628942 0.81642783 0.89038136 0.6467311  0.74902003 0.92194026]
#   [0.89316278 0.81100705 0.91100575 0.64828337 0.77609295 0.94499727]
#   [0.90184133 0.80325886 0.93067744 0.64663927 0.80199467 0.96693612]
#   [0.89568222 0.78860339 0.94744683 0.64783025 0.8257399  0.98602068]
#   [0.86920856 0.76162198 0.95820781 0.65658082 0.845716   1.        ]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 34: [[0.56236714]]
# x_pred_input of day 35:
# [[[0.85926279 0.82244515 0.87396892 0.66546313 0.76388244 0.89284273]
#   [0.87628942 0.81642783 0.89038136 0.67880094 0.79317577 0.91585792]
#   [0.89316278 0.81100705 0.91100575 0.68043018 0.82184467 0.93876281]
#   [0.90184133 0.80325886 0.93067744 0.67870457 0.84927333 0.96055692]
#   [0.89568222 0.78860339 0.94744683 0.6799546  0.87441838 0.97951558]
#   [0.86920856 0.76162198 0.95820781 0.68913909 0.89557209 0.99340267]
#   [0.82083915 0.71765855 0.959033   0.70935373 0.91122556 1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 35: [[0.5108505]]
# x_pred_input of day 36:
# [[[0.87628942 0.81642783 0.89038136 0.73566769 0.86278124 0.91585792]
#   [0.89316278 0.81100705 0.91100575 0.73743342 0.89396599 0.93876281]
#   [0.90184133 0.80325886 0.93067744 0.73556324 0.92380167 0.96055692]
#   [0.89568222 0.78860339 0.94744683 0.73691799 0.95115333 0.97951558]
#   [0.86920856 0.76162198 0.95820781 0.74687191 0.9741634  0.99340267]
#   [0.82083915 0.71765855 0.959033   0.76878004 0.99119055 1.        ]
#   [0.74543863 0.65146861 0.94914535 0.79947474 1.         0.99666708]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 36: [[0.44288307]]
# x_pred_input of day 37:
# [[[0.89316278 0.81100705 0.91100575 0.82906795 0.89396599 0.93876281]
#   [0.90184133 0.80325886 0.93067744 0.82696538 0.92380167 0.96055692]
#   [0.89568222 0.78860339 0.94744683 0.82848848 0.95115333 0.97951558]
#   [0.86920856 0.76162198 0.95820781 0.83967929 0.9741634  0.99340267]
#   [0.82083915 0.71765855 0.959033   0.86430975 0.99119055 1.        ]
#   [0.74543863 0.65146861 0.94914535 0.89881862 1.         0.99666708]
#   [0.64596053 0.56022605 0.93826196 0.92399806 0.99932386 0.98137927]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 37: [[0.40264773]]
# x_pred_input of day 38:
# [[[0.90184133 0.80325886 0.93067744 0.88995964 0.92380167 0.96055692]
#   [0.89568222 0.78860339 0.94744683 0.89159877 0.95115333 0.97951558]
#   [0.86920856 0.76162198 0.95820781 0.90364204 0.9741634  0.99340267]
#   [0.82083915 0.71765855 0.959033   0.93014873 0.99119055 1.        ]
#   [0.74543863 0.65146861 0.94914535 0.96728632 1.         0.99666708]
#   [0.64596053 0.56022605 0.93826196 0.99438381 0.99932386 0.98137927]
#   [0.5870715  0.46454374 0.93578062 1.         0.9930203  0.96028249]]]
# 1/1 [==============================] - 0s 103ms/step
# y_pred of day 38: [[0.3828818]]
# x_pred_input of day 39:
# [[[0.89568222 0.78860339 0.94744683 0.89159877 0.95115333 0.97951558]
#   [0.86920856 0.76162198 0.95820781 0.90364204 0.9741634  0.99340267]
#   [0.82083915 0.71765855 0.959033   0.93014873 0.99119055 1.        ]
#   [0.74543863 0.65146861 0.94914535 0.96728632 1.         0.99666708]
#   [0.64596053 0.56022605 0.93826196 0.99438381 0.99932386 0.98137927]
#   [0.5870715  0.46454374 0.93578062 1.         0.9930203  0.96028249]
#   [0.55814178 0.37691662 0.94264521 0.98428614 0.98547109 0.93762595]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 39: [[0.37478045]]
# x_pred_input of day 40:
# [[[0.86920856 0.76162198 0.95820781 0.90364204 0.9741634  0.99340267]
#   [0.82083915 0.71765855 0.959033   0.93014873 0.99119055 1.        ]
#   [0.74543863 0.65146861 0.94914535 0.96728632 1.         0.99666708]
#   [0.64596053 0.56022605 0.93826196 0.99438381 0.99932386 0.98137927]
#   [0.5870715  0.46454374 0.93578062 1.         0.9930203  0.96028249]
#   [0.55814178 0.37691662 0.94264521 0.98428614 0.98547109 0.93762595]
#   [0.54628454 0.30255028 0.95534634 0.95227146 0.97937449 0.91566439]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 40: [[0.37667558]]
# x_pred_input of day 41:
# [[[0.82083915 0.71765855 0.959033   0.93014873 0.99119055 1.        ]
#   [0.74543863 0.65146861 0.94914535 0.96728632 1.         0.99666708]
#   [0.64596053 0.56022605 0.93826196 0.99438381 0.99932386 0.98137927]
#   [0.5870715  0.46454374 0.93578062 1.         0.9930203  0.96028249]
#   [0.55814178 0.37691662 0.94264521 0.98428614 0.98547109 0.93762595]
#   [0.54628454 0.30255028 0.95534634 0.95227146 0.97937449 0.91566439]
#   [0.54905828 0.24452099 0.96766431 0.91334484 0.97601549 0.89613659]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 41: [[0.38143453]]
# x_pred_input of day 42:
# [[[0.74543863 0.65146861 0.94914535 0.96728632 1.         0.99666708]
#   [0.64596053 0.56022605 0.93826196 0.99438381 0.99932386 0.98137927]
#   [0.5870715  0.46454374 0.93578062 1.         0.9930203  0.96028249]
#   [0.55814178 0.37691662 0.94264521 0.98428614 0.98547109 0.93762595]
#   [0.54628454 0.30255028 0.95534634 0.95227146 0.97937449 0.91566439]
#   [0.54905828 0.24452099 0.96766431 0.91334484 0.97601549 0.89613659]
#   [0.55602355 0.20141379 0.97540986 0.87473719 0.97511354 0.87932786]]]
# 1/1 [==============================] - 0s 29ms/step
# y_pred of day 42: [[0.3831105]]
# x_pred_input of day 43:
# [[[0.64596053 0.56022605 0.93826196 0.99438381 0.99932386 0.98137927]
#   [0.5870715  0.46454374 0.93578062 1.         0.9930203  0.96028249]
#   [0.55814178 0.37691662 0.94264521 0.98428614 0.98547109 0.93762595]
#   [0.54628454 0.30255028 0.95534634 0.95227146 0.97937449 0.91566439]
#   [0.54905828 0.24452099 0.96766431 0.91334484 0.97601549 0.89613659]
#   [0.55602355 0.20141379 0.97540986 0.87473719 0.97511354 0.87932786]
#   [0.55847651 0.16891601 0.97789181 0.8389897  0.97506394 0.86442259]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 43: [[0.380413]]
# x_pred_input of day 44:
# [[[0.5870715  0.46454374 0.93578062 1.         0.9930203  0.96028249]
#   [0.55814178 0.37691662 0.94264521 0.98428614 0.98547109 0.93762595]
#   [0.54628454 0.30255028 0.95534634 0.95227146 0.97937449 0.91566439]
#   [0.54905828 0.24452099 0.96766431 0.91334484 0.97601549 0.89613659]
#   [0.55602355 0.20141379 0.97540986 0.87473719 0.97511354 0.87932786]
#   [0.55847651 0.16891601 0.97789181 0.8389897  0.97506394 0.86442259]
#   [0.55452842 0.14286953 0.97574462 0.80602896 0.97419719 0.85044979]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 44: [[0.37598804]]
# x_pred_input of day 45:
# [[[0.55814178 0.37691662 0.94264521 0.98428614 0.98547109 0.93762595]
#   [0.54628454 0.30255028 0.95534634 0.95227146 0.97937449 0.91566439]
#   [0.54905828 0.24452099 0.96766431 0.91334484 0.97601549 0.89613659]
#   [0.55602355 0.20141379 0.97540986 0.87473719 0.97511354 0.87932786]
#   [0.55847651 0.16891601 0.97789181 0.8389897  0.97506394 0.86442259]
#   [0.55452842 0.14286953 0.97574462 0.80602896 0.97419719 0.85044979]
#   [0.54805198 0.12129298 0.97014964 0.77576411 0.97142295 0.83700876]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 45: [[0.37040022]]
# x_pred_input of day 46:
# [[[0.54628454 0.30255028 0.95534634 0.95227146 0.97937449 0.91566439]
#   [0.54905828 0.24452099 0.96766431 0.91334484 0.97601549 0.89613659]
#   [0.55602355 0.20141379 0.97540986 0.87473719 0.97511354 0.87932786]
#   [0.55847651 0.16891601 0.97789181 0.8389897  0.97506394 0.86442259]
#   [0.55452842 0.14286953 0.97574462 0.80602896 0.97419719 0.85044979]
#   [0.54805198 0.12129298 0.97014964 0.77576411 0.97142295 0.83700876]
#   [0.53987357 0.10287112 0.96173671 0.74788748 0.96579968 0.82383889]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 46: [[0.36533028]]
# x_pred_input of day 47:
# [[[0.54905828 0.24452099 0.96766431 0.91334484 0.97601549 0.89613659]
#   [0.55602355 0.20141379 0.97540986 0.87473719 0.97511354 0.87932786]
#   [0.55847651 0.16891601 0.97789181 0.8389897  0.97506394 0.86442259]
#   [0.55452842 0.14286953 0.97574462 0.80602896 0.97419719 0.85044979]
#   [0.54805198 0.12129298 0.97014964 0.77576411 0.97142295 0.83700876]
#   [0.53987357 0.10287112 0.96173671 0.74788748 0.96579968 0.82383889]
#   [0.53245313 0.08739503 0.95043647 0.72274689 0.95682832 0.81100785]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 47: [[0.36148095]]
# x_pred_input of day 48:
# [[[0.55602355 0.20141379 0.97540986 0.87473719 0.97511354 0.87932786]
#   [0.55847651 0.16891601 0.97789181 0.8389897  0.97506394 0.86442259]
#   [0.55452842 0.14286953 0.97574462 0.80602896 0.97419719 0.85044979]
#   [0.54805198 0.12129298 0.97014964 0.77576411 0.97142295 0.83700876]
#   [0.53987357 0.10287112 0.96173671 0.74788748 0.96579968 0.82383889]
#   [0.53245313 0.08739503 0.95043647 0.72274689 0.95682832 0.81100785]
#   [0.5268192  0.07502599 0.93514601 0.7014289  0.94487061 0.79870377]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 48: [[0.35982677]]
# x_pred_input of day 49:
# [[[0.55847651 0.16891601 0.97789181 0.8389897  0.97506394 0.86442259]
#   [0.55452842 0.14286953 0.97574462 0.80602896 0.97419719 0.85044979]
#   [0.54805198 0.12129298 0.97014964 0.77576411 0.97142295 0.83700876]
#   [0.53987357 0.10287112 0.96173671 0.74788748 0.96579968 0.82383889]
#   [0.53245313 0.08739503 0.95043647 0.72274689 0.95682832 0.81100785]
#   [0.5268192  0.07502599 0.93514601 0.7014289  0.94487061 0.79870377]
#   [0.52439812 0.06635215 0.91455904 0.68567244 0.93091173 0.78727283]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 49: [[0.35840598]]
# x_pred_input of day 50:
# [[[0.55452842 0.14286953 0.97574462 0.80602896 0.97419719 0.85044979]
#   [0.54805198 0.12129298 0.97014964 0.77576411 0.97142295 0.83700876]
#   [0.53987357 0.10287112 0.96173671 0.74788748 0.96579968 0.82383889]
#   [0.53245313 0.08739503 0.95043647 0.72274689 0.95682832 0.81100785]
#   [0.5268192  0.07502599 0.93514601 0.7014289  0.94487061 0.79870377]
#   [0.52439812 0.06635215 0.91455904 0.68567244 0.93091173 0.78727283]
#   [0.52231863 0.06079132 0.88686078 0.67745439 0.91560967 0.77667401]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 50: [[0.35731333]]
# x_pred_input of day 51:
# [[[0.54805198 0.12129298 0.97014964 0.77576411 0.97142295 0.83700876]
#   [0.53987357 0.10287112 0.96173671 0.74788748 0.96579968 0.82383889]
#   [0.53245313 0.08739503 0.95043647 0.72274689 0.95682832 0.81100785]
#   [0.5268192  0.07502599 0.93514601 0.7014289  0.94487061 0.79870377]
#   [0.52439812 0.06635215 0.91455904 0.68567244 0.93091173 0.78727283]
#   [0.52231863 0.06079132 0.88686078 0.67745439 0.91560967 0.77667401]
#   [0.52071942 0.05790025 0.85035092 0.67927647 0.89972021 0.76688731]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 51: [[0.355868]]
# x_pred_input of day 52:
# [[[0.53987357 0.10287112 0.96173671 0.74788748 0.96579968 0.82383889]
#   [0.53245313 0.08739503 0.95043647 0.72274689 0.95682832 0.81100785]
#   [0.5268192  0.07502599 0.93514601 0.7014289  0.94487061 0.79870377]
#   [0.52439812 0.06635215 0.91455904 0.68567244 0.93091173 0.78727283]
#   [0.52231863 0.06079132 0.88686078 0.67745439 0.91560967 0.77667401]
#   [0.52071942 0.05790025 0.85035092 0.67927647 0.89972021 0.76688731]
#   [0.51860402 0.05695389 0.80442042 0.69303649 0.88352668 0.75777171]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 52: [[0.35265672]]
# x_pred_input of day 53:
# [[[0.53245313 0.08739503 0.95043647 0.72274689 0.95682832 0.81100785]
#   [0.5268192  0.07502599 0.93514601 0.7014289  0.94487061 0.79870377]
#   [0.52439812 0.06635215 0.91455904 0.68567244 0.93091173 0.78727283]
#   [0.52231863 0.06079132 0.88686078 0.67745439 0.91560967 0.77667401]
#   [0.52071942 0.05790025 0.85035092 0.67927647 0.89972021 0.76688731]
#   [0.51860402 0.05695389 0.80442042 0.69303649 0.88352668 0.75777171]
#   [0.51390393 0.05664096 0.74988328 0.71922472 0.86695314 0.74894443]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 53: [[0.34765252]]
# x_pred_input of day 54:
# [[[0.5268192  0.07502599 0.93514601 0.7014289  0.94487061 0.79870377]
#   [0.52439812 0.06635215 0.91455904 0.68567244 0.93091173 0.78727283]
#   [0.52231863 0.06079132 0.88686078 0.67745439 0.91560967 0.77667401]
#   [0.52071942 0.05790025 0.85035092 0.67927647 0.89972021 0.76688731]
#   [0.51860402 0.05695389 0.80442042 0.69303649 0.88352668 0.75777171]
#   [0.51390393 0.05664096 0.74988328 0.71922472 0.86695314 0.74894443]
#   [0.50657972 0.05591317 0.68945048 0.75636631 0.84959229 0.74005427]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 54: [[0.3411634]]
# x_pred_input of day 55:
# [[[0.52439812 0.06635215 0.91455904 0.68567244 0.93091173 0.78727283]
#   [0.52231863 0.06079132 0.88686078 0.67745439 0.91560967 0.77667401]
#   [0.52071942 0.05790025 0.85035092 0.67927647 0.89972021 0.76688731]
#   [0.51860402 0.05695389 0.80442042 0.69303649 0.88352668 0.75777171]
#   [0.51390393 0.05664096 0.74988328 0.71922472 0.86695314 0.74894443]
#   [0.50657972 0.05591317 0.68945048 0.75636631 0.84959229 0.74005427]
#   [0.49708213 0.05411104 0.62759048 0.80076178 0.83112488 0.73083911]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 55: [[0.33438382]]
# x_pred_input of day 56:
# [[[0.52231863 0.06079132 0.88686078 0.67745439 0.91560967 0.77667401]
#   [0.52071942 0.05790025 0.85035092 0.67927647 0.89972021 0.76688731]
#   [0.51860402 0.05695389 0.80442042 0.69303649 0.88352668 0.75777171]
#   [0.51390393 0.05664096 0.74988328 0.71922472 0.86695314 0.74894443]
#   [0.50657972 0.05591317 0.68945048 0.75636631 0.84959229 0.74005427]
#   [0.49708213 0.05411104 0.62759048 0.80076178 0.83112488 0.73083911]
#   [0.48715944 0.05133954 0.57545846 0.84013357 0.81128333 0.72127745]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 56: [[0.3289189]]
# x_pred_input of day 57:
# [[[0.52071942 0.05790025 0.85035092 0.67927647 0.89972021 0.76688731]
#   [0.51860402 0.05695389 0.80442042 0.69303649 0.88352668 0.75777171]
#   [0.51390393 0.05664096 0.74988328 0.71922472 0.86695314 0.74894443]
#   [0.50657972 0.05591317 0.68945048 0.75636631 0.84959229 0.74005427]
#   [0.49708213 0.05411104 0.62759048 0.80076178 0.83112488 0.73083911]
#   [0.48715944 0.05133954 0.57545846 0.84013357 0.81128333 0.72127745]
#   [0.47916092 0.04851088 0.5529798  0.84965842 0.79017358 0.71163967]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 57: [[0.32963327]]
# x_pred_input of day 58:
# [[[0.51860402 0.05695389 0.80442042 0.69303649 0.88352668 0.75777171]
#   [0.51390393 0.05664096 0.74988328 0.71922472 0.86695314 0.74894443]
#   [0.50657972 0.05591317 0.68945048 0.75636631 0.84959229 0.74005427]
#   [0.49708213 0.05411104 0.62759048 0.80076178 0.83112488 0.73083911]
#   [0.48715944 0.05133954 0.57545846 0.84013357 0.81128333 0.72127745]
#   [0.47916092 0.04851088 0.5529798  0.84965842 0.79017358 0.71163967]
#   [0.48020647 0.04882226 0.54592143 0.84532431 0.76867463 0.70304876]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 58: [[0.33132014]]
# x_pred_input of day 59:
# [[[0.51390393 0.05664096 0.74988328 0.71922472 0.86695314 0.74894443]
#   [0.50657972 0.05591317 0.68945048 0.75636631 0.84959229 0.74005427]
#   [0.49708213 0.05411104 0.62759048 0.80076178 0.83112488 0.73083911]
#   [0.48715944 0.05133954 0.57545846 0.84013357 0.81128333 0.72127745]
#   [0.47916092 0.04851088 0.5529798  0.84965842 0.79017358 0.71163967]
#   [0.48020647 0.04882226 0.54592143 0.84532431 0.76867463 0.70304876]
#   [0.48267539 0.0520864  0.54341424 0.83874277 0.74761561 0.69558061]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 59: [[0.33116826]]
# x_pred_input of day 60:
# [[[0.50657972 0.05591317 0.68945048 0.75636631 0.84959229 0.74005427]
#   [0.49708213 0.05411104 0.62759048 0.80076178 0.83112488 0.73083911]
#   [0.48715944 0.05133954 0.57545846 0.84013357 0.81128333 0.72127745]
#   [0.47916092 0.04851088 0.5529798  0.84965842 0.79017358 0.71163967]
#   [0.48020647 0.04882226 0.54592143 0.84532431 0.76867463 0.70304876]
#   [0.48267539 0.0520864  0.54341424 0.83874277 0.74761561 0.69558061]
#   [0.48245311 0.05668864 0.54187681 0.83234705 0.72789514 0.6887963 ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 60: [[0.32894528]]
# x_pred_input of day 61:
# [[[0.49708213 0.05411104 0.62759048 0.80076178 0.83112488 0.73083911]
#   [0.48715944 0.05133954 0.57545846 0.84013357 0.81128333 0.72127745]
#   [0.47916092 0.04851088 0.5529798  0.84965842 0.79017358 0.71163967]
#   [0.48020647 0.04882226 0.54592143 0.84532431 0.76867463 0.70304876]
#   [0.48267539 0.0520864  0.54341424 0.83874277 0.74761561 0.69558061]
#   [0.48245311 0.05668864 0.54187681 0.83234705 0.72789514 0.6887963 ]
#   [0.47919952 0.06123017 0.53937207 0.82651586 0.7104751  0.68225672]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 61: [[0.32254806]]
# x_pred_input of day 62:
# [[[0.48715944 0.05133954 0.57545846 0.84013357 0.81128333 0.72127745]
#   [0.47916092 0.04851088 0.5529798  0.84965842 0.79017358 0.71163967]
#   [0.48020647 0.04882226 0.54592143 0.84532431 0.76867463 0.70304876]
#   [0.48267539 0.0520864  0.54341424 0.83874277 0.74761561 0.69558061]
#   [0.48245311 0.05668864 0.54187681 0.83234705 0.72789514 0.6887963 ]
#   [0.47919952 0.06123017 0.53937207 0.82651586 0.7104751  0.68225672]
#   [0.46983646 0.06354271 0.53543543 0.82052474 0.69642229 0.67518487]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 62: [[0.31412432]]
# x_pred_input of day 63:
# [[[0.47916092 0.04851088 0.5529798  0.84965842 0.79017358 0.71163967]
#   [0.48020647 0.04882226 0.54592143 0.84532431 0.76867463 0.70304876]
#   [0.48267539 0.0520864  0.54341424 0.83874277 0.74761561 0.69558061]
#   [0.48245311 0.05668864 0.54187681 0.83234705 0.72789514 0.6887963 ]
#   [0.47919952 0.06123017 0.53937207 0.82651586 0.7104751  0.68225672]
#   [0.46983646 0.06354271 0.53543543 0.82052474 0.69642229 0.67518487]
#   [0.45750734 0.06304865 0.53091675 0.8133737  0.68681315 0.66726553]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 63: [[0.30586338]]
# x_pred_input of day 64:
# [[[0.48020647 0.04882226 0.54592143 0.84532431 0.76867463 0.70304876]
#   [0.48267539 0.0520864  0.54341424 0.83874277 0.74761561 0.69558061]
#   [0.48245311 0.05668864 0.54187681 0.83234705 0.72789514 0.6887963 ]
#   [0.47919952 0.06123017 0.53937207 0.82651586 0.7104751  0.68225672]
#   [0.46983646 0.06354271 0.53543543 0.82052474 0.69642229 0.67518487]
#   [0.45750734 0.06304865 0.53091675 0.8133737  0.68681315 0.66726553]
#   [0.44541652 0.06044437 0.52709527 0.80413716 0.67959023 0.6586088 ]]]
# 1/1 [==============================] - 0s 50ms/step
# y_pred of day 64: [[0.298379]]
# x_pred_input of day 65:
# [[[0.48267539 0.0520864  0.54341424 0.83874277 0.74761561 0.69558061]
#   [0.48245311 0.05668864 0.54187681 0.83234705 0.72789514 0.6887963 ]
#   [0.47919952 0.06123017 0.53937207 0.82651586 0.7104751  0.68225672]
#   [0.46983646 0.06354271 0.53543543 0.82052474 0.69642229 0.67518487]
#   [0.45750734 0.06304865 0.53091675 0.8133737  0.68681315 0.66726553]
#   [0.44541652 0.06044437 0.52709527 0.80413716 0.67959023 0.6586088 ]
#   [0.43446227 0.05661266 0.52428531 0.79286107 0.67328387 0.64942512]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 65: [[0.29244664]]
# x_pred_input of day 66:
# [[[0.48245311 0.05668864 0.54187681 0.83234705 0.72789514 0.6887963 ]
#   [0.47919952 0.06123017 0.53937207 0.82651586 0.7104751  0.68225672]
#   [0.46983646 0.06354271 0.53543543 0.82052474 0.69642229 0.67518487]
#   [0.45750734 0.06304865 0.53091675 0.8133737  0.68681315 0.66726553]
#   [0.44541652 0.06044437 0.52709527 0.80413716 0.67959023 0.6586088 ]
#   [0.43446227 0.05661266 0.52428531 0.79286107 0.67328387 0.64942512]
#   [0.42577958 0.05265477 0.52233927 0.78028934 0.66713939 0.64004493]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 66: [[0.28758714]]
# x_pred_input of day 67:
# [[[0.47919952 0.06123017 0.53937207 0.82651586 0.7104751  0.68225672]
#   [0.46983646 0.06354271 0.53543543 0.82052474 0.69642229 0.67518487]
#   [0.45750734 0.06304865 0.53091675 0.8133737  0.68681315 0.66726553]
#   [0.44541652 0.06044437 0.52709527 0.80413716 0.67959023 0.6586088 ]
#   [0.43446227 0.05661266 0.52428531 0.79286107 0.67328387 0.64942512]
#   [0.42577958 0.05265477 0.52233927 0.78028934 0.66713939 0.64004493]
#   [0.41866714 0.04919048 0.52074066 0.76726524 0.66049081 0.63068065]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 67: [[0.28355294]]
# x_pred_input of day 68:
# [[[0.46983646 0.06354271 0.53543543 0.82052474 0.69642229 0.67518487]
#   [0.45750734 0.06304865 0.53091675 0.8133737  0.68681315 0.66726553]
#   [0.44541652 0.06044437 0.52709527 0.80413716 0.67959023 0.6586088 ]
#   [0.43446227 0.05661266 0.52428531 0.79286107 0.67328387 0.64942512]
#   [0.42577958 0.05265477 0.52233927 0.78028934 0.66713939 0.64004493]
#   [0.41866714 0.04919048 0.52074066 0.76726524 0.66049081 0.63068065]
#   [0.41276264 0.04657346 0.51894887 0.75447933 0.653186   0.62147978]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 68: [[0.28083575]]
# x_pred_input of day 69:
# [[[0.45750734 0.06304865 0.53091675 0.8133737  0.68681315 0.66726553]
#   [0.44541652 0.06044437 0.52709527 0.80413716 0.67959023 0.6586088 ]
#   [0.43446227 0.05661266 0.52428531 0.79286107 0.67328387 0.64942512]
#   [0.42577958 0.05265477 0.52233927 0.78028934 0.66713939 0.64004493]
#   [0.41866714 0.04919048 0.52074066 0.76726524 0.66049081 0.63068065]
#   [0.41276264 0.04657346 0.51894887 0.75447933 0.653186   0.62147978]
#   [0.40878571 0.04532199 0.51616075 0.74290029 0.64555334 0.61266457]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 69: [[0.27804112]]
# x_pred_input of day 70:
# [[[0.44541652 0.06044437 0.52709527 0.80413716 0.67959023 0.6586088 ]
#   [0.43446227 0.05661266 0.52428531 0.79286107 0.67328387 0.64942512]
#   [0.42577958 0.05265477 0.52233927 0.78028934 0.66713939 0.64004493]
#   [0.41866714 0.04919048 0.52074066 0.76726524 0.66049081 0.63068065]
#   [0.41276264 0.04657346 0.51894887 0.75447933 0.653186   0.62147978]
#   [0.40878571 0.04532199 0.51616075 0.74290029 0.64555334 0.61266457]
#   [0.40469546 0.04511516 0.51238164 0.73245937 0.63791343 0.6041843 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 70: [[0.2763216]]
# x_pred_input of day 71:
# [[[0.43446227 0.05661266 0.52428531 0.79286107 0.67328387 0.64942512]
#   [0.42577958 0.05265477 0.52233927 0.78028934 0.66713939 0.64004493]
#   [0.41866714 0.04919048 0.52074066 0.76726524 0.66049081 0.63068065]
#   [0.41276264 0.04657346 0.51894887 0.75447933 0.653186   0.62147978]
#   [0.40878571 0.04532199 0.51616075 0.74290029 0.64555334 0.61266457]
#   [0.40469546 0.04511516 0.51238164 0.73245937 0.63791343 0.6041843 ]
#   [0.40217872 0.04627763 0.50735401 0.72366956 0.63047543 0.59620119]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 71: [[0.27495533]]
# x_pred_input of day 72:
# [[[0.42577958 0.05265477 0.52233927 0.78028934 0.66713939 0.64004493]
#   [0.41866714 0.04919048 0.52074066 0.76726524 0.66049081 0.63068065]
#   [0.41276264 0.04657346 0.51894887 0.75447933 0.653186   0.62147978]
#   [0.40878571 0.04532199 0.51616075 0.74290029 0.64555334 0.61266457]
#   [0.40469546 0.04511516 0.51238164 0.73245937 0.63791343 0.6041843 ]
#   [0.40217872 0.04627763 0.50735401 0.72366956 0.63047543 0.59620119]
#   [0.40017905 0.04867991 0.50113631 0.71658667 0.62335247 0.58873168]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 72: [[0.2742746]]
# x_pred_input of day 73:
# [[[0.41866714 0.04919048 0.52074066 0.76726524 0.66049081 0.63068065]
#   [0.41276264 0.04657346 0.51894887 0.75447933 0.653186   0.62147978]
#   [0.40878571 0.04532199 0.51616075 0.74290029 0.64555334 0.61266457]
#   [0.40469546 0.04511516 0.51238164 0.73245937 0.63791343 0.6041843 ]
#   [0.40217872 0.04627763 0.50735401 0.72366956 0.63047543 0.59620119]
#   [0.40017905 0.04867991 0.50113631 0.71658667 0.62335247 0.58873168]
#   [0.3991827  0.05237591 0.49419834 0.71102534 0.61655708 0.58185064]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 73: [[0.27391347]]
# x_pred_input of day 74:
# [[[0.41276264 0.04657346 0.51894887 0.75447933 0.653186   0.62147978]
#   [0.40878571 0.04532199 0.51616075 0.74290029 0.64555334 0.61266457]
#   [0.40469546 0.04511516 0.51238164 0.73245937 0.63791343 0.6041843 ]
#   [0.40217872 0.04627763 0.50735401 0.72366956 0.63047543 0.59620119]
#   [0.40017905 0.04867991 0.50113631 0.71658667 0.62335247 0.58873168]
#   [0.3991827  0.05237591 0.49419834 0.71102534 0.61655708 0.58185064]
#   [0.39865417 0.05720646 0.48715547 0.70652663 0.61002201 0.57555973]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 74: [[0.2747644]]
# x_pred_input of day 75:
# [[[0.40878571 0.04532199 0.51616075 0.74290029 0.64555334 0.61266457]
#   [0.40469546 0.04511516 0.51238164 0.73245937 0.63791343 0.6041843 ]
#   [0.40217872 0.04627763 0.50735401 0.72366956 0.63047543 0.59620119]
#   [0.40017905 0.04867991 0.50113631 0.71658667 0.62335247 0.58873168]
#   [0.3991827  0.05237591 0.49419834 0.71102534 0.61655708 0.58185064]
#   [0.39865417 0.05720646 0.48715547 0.70652663 0.61002201 0.57555973]
#   [0.39989958 0.06348922 0.48048958 0.70293632 0.60367389 0.5700216 ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 75: [[0.275578]]
# x_pred_input of day 76:
# [[[0.40469546 0.04511516 0.51238164 0.73245937 0.63791343 0.6041843 ]
#   [0.40217872 0.04627763 0.50735401 0.72366956 0.63047543 0.59620119]
#   [0.40017905 0.04867991 0.50113631 0.71658667 0.62335247 0.58873168]
#   [0.3991827  0.05237591 0.49419834 0.71102534 0.61655708 0.58185064]
#   [0.39865417 0.05720646 0.48715547 0.70652663 0.61002201 0.57555973]
#   [0.39989958 0.06348922 0.48048958 0.70293632 0.60367389 0.5700216 ]
#   [0.40109038 0.07081911 0.4744763  0.69991246 0.59749252 0.56515782]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 76: [[0.27699333]]
# x_pred_input of day 77:
# [[[0.40217872 0.04627763 0.50735401 0.72366956 0.63047543 0.59620119]
#   [0.40017905 0.04867991 0.50113631 0.71658667 0.62335247 0.58873168]
#   [0.3991827  0.05237591 0.49419834 0.71102534 0.61655708 0.58185064]
#   [0.39865417 0.05720646 0.48715547 0.70652663 0.61002201 0.57555973]
#   [0.39989958 0.06348922 0.48048958 0.70293632 0.60367389 0.5700216 ]
#   [0.40109038 0.07081911 0.4744763  0.69991246 0.59749252 0.56515782]
#   [0.4031619  0.07919287 0.46886727 0.69766779 0.59149832 0.56101281]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 77: [[0.2784956]]
# x_pred_input of day 78:
# [[[0.40017905 0.04867991 0.50113631 0.71658667 0.62335247 0.58873168]
#   [0.3991827  0.05237591 0.49419834 0.71102534 0.61655708 0.58185064]
#   [0.39865417 0.05720646 0.48715547 0.70652663 0.61002201 0.57555973]
#   [0.39989958 0.06348922 0.48048958 0.70293632 0.60367389 0.5700216 ]
#   [0.40109038 0.07081911 0.4744763  0.69991246 0.59749252 0.56515782]
#   [0.4031619  0.07919287 0.46886727 0.69766779 0.59149832 0.56101281]
#   [0.40536065 0.08833341 0.46200386 0.69736088 0.58572409 0.55753382]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 78: [[0.28055176]]
# x_pred_input of day 79:
# [[[0.3991827  0.05237591 0.49419834 0.71102534 0.61655708 0.58185064]
#   [0.39865417 0.05720646 0.48715547 0.70652663 0.61002201 0.57555973]
#   [0.39989958 0.06348922 0.48048958 0.70293632 0.60367389 0.5700216 ]
#   [0.40109038 0.07081911 0.4744763  0.69991246 0.59749252 0.56515782]
#   [0.4031619  0.07919287 0.46886727 0.69766779 0.59149832 0.56101281]
#   [0.40536065 0.08833341 0.46200386 0.69736088 0.58572409 0.55753382]
#   [0.40837006 0.09825311 0.45333972 0.69968591 0.58034297 0.55475742]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 79: [[0.28207135]]
# x_pred_input of day 80:
# [[[0.39865417 0.05720646 0.48715547 0.70652663 0.61002201 0.57555973]
#   [0.39989958 0.06348922 0.48048958 0.70293632 0.60367389 0.5700216 ]
#   [0.40109038 0.07081911 0.4744763  0.69991246 0.59749252 0.56515782]
#   [0.4031619  0.07919287 0.46886727 0.69766779 0.59149832 0.56101281]
#   [0.40536065 0.08833341 0.46200386 0.69736088 0.58572409 0.55753382]
#   [0.40837006 0.09825311 0.45333972 0.69968591 0.58034297 0.55475742]
#   [0.41059416 0.10839647 0.44312281 0.70454665 0.57544872 0.55251982]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 80: [[0.28294918]]
# x_pred_input of day 81:
# [[[0.39989958 0.06348922 0.48048958 0.70293632 0.60367389 0.5700216 ]
#   [0.40109038 0.07081911 0.4744763  0.69991246 0.59749252 0.56515782]
#   [0.4031619  0.07919287 0.46886727 0.69766779 0.59149832 0.56101281]
#   [0.40536065 0.08833341 0.46200386 0.69736088 0.58572409 0.55753382]
#   [0.40837006 0.09825311 0.45333972 0.69968591 0.58034297 0.55475742]
#   [0.41059416 0.10839647 0.44312281 0.70454665 0.57544872 0.55251982]
#   [0.41187896 0.11827206 0.43169498 0.71173848 0.57110425 0.55065382]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 81: [[0.28339484]]
# x_pred_input of day 82:
# [[[0.40109038 0.07081911 0.4744763  0.69991246 0.59749252 0.56515782]
#   [0.4031619  0.07919287 0.46886727 0.69766779 0.59149832 0.56101281]
#   [0.40536065 0.08833341 0.46200386 0.69736088 0.58572409 0.55753382]
#   [0.40837006 0.09825311 0.45333972 0.69968591 0.58034297 0.55475742]
#   [0.41059416 0.10839647 0.44312281 0.70454665 0.57544872 0.55251982]
#   [0.41187896 0.11827206 0.43169498 0.71173848 0.57110425 0.55065382]
#   [0.41253124 0.12760482 0.42067891 0.71969146 0.567299   0.54904601]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 82: [[0.28353792]]
# x_pred_input of day 83:
# [[[0.4031619  0.07919287 0.46886727 0.69766779 0.59149832 0.56101281]
#   [0.40536065 0.08833341 0.46200386 0.69736088 0.58572409 0.55753382]
#   [0.40837006 0.09825311 0.45333972 0.69968591 0.58034297 0.55475742]
#   [0.41059416 0.10839647 0.44312281 0.70454665 0.57544872 0.55251982]
#   [0.41187896 0.11827206 0.43169498 0.71173848 0.57110425 0.55065382]
#   [0.41253124 0.12760482 0.42067891 0.71969146 0.567299   0.54904601]
#   [0.41274065 0.13625156 0.41129456 0.72701091 0.56391226 0.54761716]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 83: [[0.2837952]]
# x_pred_input of day 84:
# [[[0.40536065 0.08833341 0.46200386 0.69736088 0.58572409 0.55753382]
#   [0.40837006 0.09825311 0.45333972 0.69968591 0.58034297 0.55475742]
#   [0.41059416 0.10839647 0.44312281 0.70454665 0.57544872 0.55251982]
#   [0.41187896 0.11827206 0.43169498 0.71173848 0.57110425 0.55065382]
#   [0.41253124 0.12760482 0.42067891 0.71969146 0.567299   0.54904601]
#   [0.41274065 0.13625156 0.41129456 0.72701091 0.56391226 0.54761716]
#   [0.41311722 0.14432055 0.40402369 0.73300259 0.56049141 0.54637085]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 84: [[0.28379813]]
# x_pred_input of day 85:
# [[[0.40837006 0.09825311 0.45333972 0.69968591 0.58034297 0.55475742]
#   [0.41059416 0.10839647 0.44312281 0.70454665 0.57544872 0.55251982]
#   [0.41187896 0.11827206 0.43169498 0.71173848 0.57110425 0.55065382]
#   [0.41253124 0.12760482 0.42067891 0.71969146 0.567299   0.54904601]
#   [0.41274065 0.13625156 0.41129456 0.72701091 0.56391226 0.54761716]
#   [0.41311722 0.14432055 0.40402369 0.73300259 0.56049141 0.54637085]
#   [0.41312149 0.15171515 0.39911139 0.73711532 0.55694489 0.54524376]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 85: [[0.28427365]]
# x_pred_input of day 86:
# [[[0.41059416 0.10839647 0.44312281 0.70454665 0.57544872 0.55251982]
#   [0.41187896 0.11827206 0.43169498 0.71173848 0.57110425 0.55065382]
#   [0.41253124 0.12760482 0.42067891 0.71969146 0.567299   0.54904601]
#   [0.41274065 0.13625156 0.41129456 0.72701091 0.56391226 0.54761716]
#   [0.41311722 0.14432055 0.40402369 0.73300259 0.56049141 0.54637085]
#   [0.41312149 0.15171515 0.39911139 0.73711532 0.55694489 0.54524376]
#   [0.41381748 0.15873825 0.39639795 0.7393637  0.55344519 0.54430987]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 86: [[0.28451797]]
# x_pred_input of day 87:
# [[[0.41187896 0.11827206 0.43169498 0.71173848 0.57110425 0.55065382]
#   [0.41253124 0.12760482 0.42067891 0.71969146 0.567299   0.54904601]
#   [0.41274065 0.13625156 0.41129456 0.72701091 0.56391226 0.54761716]
#   [0.41311722 0.14432055 0.40402369 0.73300259 0.56049141 0.54637085]
#   [0.41312149 0.15171515 0.39911139 0.73711532 0.55694489 0.54524376]
#   [0.41381748 0.15873825 0.39639795 0.7393637  0.55344519 0.54430987]
#   [0.41417507 0.16527227 0.39550187 0.74003339 0.55012963 0.54350904]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 87: [[0.284575]]
# x_pred_input of day 88:
# [[[0.41253124 0.12760482 0.42067891 0.71969146 0.567299   0.54904601]
#   [0.41274065 0.13625156 0.41129456 0.72701091 0.56391226 0.54761716]
#   [0.41311722 0.14432055 0.40402369 0.73300259 0.56049141 0.54637085]
#   [0.41312149 0.15171515 0.39911139 0.73711532 0.55694489 0.54524376]
#   [0.41381748 0.15873825 0.39639795 0.7393637  0.55344519 0.54430987]
#   [0.41417507 0.16527227 0.39550187 0.74003339 0.55012963 0.54350904]
#   [0.41425851 0.1712531  0.39573225 0.73990705 0.54729574 0.54279478]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 88: [[0.28452176]]
# x_pred_input of day 89:
# [[[0.41274065 0.13625156 0.41129456 0.72701091 0.56391226 0.54761716]
#   [0.41311722 0.14432055 0.40402369 0.73300259 0.56049141 0.54637085]
#   [0.41312149 0.15171515 0.39911139 0.73711532 0.55694489 0.54524376]
#   [0.41381748 0.15873825 0.39639795 0.7393637  0.55344519 0.54430987]
#   [0.41417507 0.16527227 0.39550187 0.74003339 0.55012963 0.54350904]
#   [0.41425851 0.1712531  0.39573225 0.73990705 0.54729574 0.54279478]
#   [0.41418061 0.17667611 0.39634881 0.73975599 0.54508653 0.54213892]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 89: [[0.28409553]]
# x_pred_input of day 90:
# [[[0.41311722 0.14432055 0.40402369 0.73300259 0.56049141 0.54637085]
#   [0.41312149 0.15171515 0.39911139 0.73711532 0.55694489 0.54524376]
#   [0.41381748 0.15873825 0.39639795 0.7393637  0.55344519 0.54430987]
#   [0.41417507 0.16527227 0.39550187 0.74003339 0.55012963 0.54350904]
#   [0.41425851 0.1712531  0.39573225 0.73990705 0.54729574 0.54279478]
#   [0.41418061 0.17667611 0.39634881 0.73975599 0.54508653 0.54213892]
#   [0.41355677 0.18140998 0.39695017 0.74009254 0.54346202 0.54146857]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 90: [[0.28332573]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#          Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# 0     0.005824  0.000000         0.283326         0.283326  0.283326  0.005824
# 1     0.005704 -0.000010         0.283326         0.283326  0.283326  0.005813
# 2     0.005645 -0.000022         0.283326         0.283326  0.283326  0.005797
# 3     0.005669 -0.000029         0.283326         0.283326  0.283326  0.005784
# 4     0.005545 -0.000044         0.283326         0.283326  0.283326  0.005762
# ...        ...       ...              ...              ...       ...       ...
# 2063  0.284518 -0.011422         0.287624         0.272037  0.285291  0.288531
# 2064  0.284575 -0.010487         0.287791         0.271973  0.283830  0.288154
# 2065  0.284522 -0.009639         0.288236         0.271896  0.282692  0.287808
# 2066  0.284096 -0.008899         0.288670         0.272067  0.281855  0.287455
# 2067  0.283326 -0.008279         0.288892         0.272547  0.281276  0.287061
#
# [2068 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
# Dateframe of Close training set
df_train = df_filtered['Close'][:train_size].copy()

# Plot the forecast for df_val, df_test and df_forecast
plt.figure(figsize=(15, 7))
plt.plot(df_train, label='Train')
plt.plot(df_test['Y_test_pred'], label='Test prediction')
plt.plot(df_test['Y_test'], label='Test')
plt.plot(df_forecast_unscale['Close'], label='Forecast next 30 days')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  0.01275360945410203
# MAPE:  16.637334451464586
# SMAPE:  15.277947300902303
