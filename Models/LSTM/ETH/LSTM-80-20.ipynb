# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../.dataset/ETH-USD-3.2018-3.2024.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 1  2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2  2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 3  2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 4  2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#        Volume
# 0  1868519936
# 1  1894419968
# 2  1699369984
# 3  1697939968
# 4  1898489984

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#                 Volume
# Date
# 2018-03-01  1868519936
# 2018-03-02  1894419968
# 2018-03-03  1699369984
# 2018-03-04  1697939968
# 2018-03-05  1898489984

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('ETH/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (1978, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.80)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1582, 6) (396, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1575, 7, 6) (1575,)
# (389, 7, 6) (389,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1575, 7, 6) (1575,)
# (389, 7, 6) (389,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
# model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
# model.add(Dense(1))
model.add(LSTM(n_neurons,return_sequences=True,input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(LSTM(n_neurons,return_sequences=True))
model.add(LSTM(n_neurons))
model.add(Dense(1))


# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# 25/25 [==============================] - 9s 50ms/step - loss: 0.0317 - val_loss: 0.0057
# Epoch 2/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 9.5654e-04
# Epoch 3/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0022 - val_loss: 7.1515e-04
# Epoch 4/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 8.9455e-04
# Epoch 5/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 6.8712e-04
# Epoch 6/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 6.3277e-04
# Epoch 7/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 6.3263e-04
# Epoch 8/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 6.5780e-04
# Epoch 9/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 10/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 9.9166e-04
# Epoch 11/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 5.0359e-04
# Epoch 12/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 5.4069e-04
# Epoch 13/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 4.9666e-04
# Epoch 14/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 8.0944e-04
# Epoch 15/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 5.5503e-04
# Epoch 16/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 6.9448e-04
# Epoch 17/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 4.9054e-04
# Epoch 18/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 4.9141e-04
# Epoch 19/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 20/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 4.7646e-04
# Epoch 21/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 5.6688e-04
# Epoch 22/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 4.7164e-04
# Epoch 23/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 4.8183e-04
# Epoch 24/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 6.4084e-04
# Epoch 25/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 4.3519e-04
# Epoch 26/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 4.2744e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 6.1893e-04
# Epoch 28/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 4.0566e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 4.4884e-04
# Epoch 30/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 3.9918e-04
# Epoch 31/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 6.5878e-04
# Epoch 32/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 7.6840e-04
# Epoch 33/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 6.8795e-04
# Epoch 34/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 3.6316e-04
# Epoch 35/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 6.9500e-04
# Epoch 36/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 3.8453e-04
# Epoch 37/100
# 25/25 [==============================] - 0s 12ms/step - loss: 9.9705e-04 - val_loss: 3.9840e-04
# Epoch 38/100
# 25/25 [==============================] - 0s 12ms/step - loss: 9.7031e-04 - val_loss: 6.0194e-04
# Epoch 39/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 3.5308e-04
# Epoch 40/100
# 25/25 [==============================] - 0s 12ms/step - loss: 8.7325e-04 - val_loss: 3.3982e-04
# Epoch 41/100
# 25/25 [==============================] - 0s 16ms/step - loss: 9.0778e-04 - val_loss: 5.6149e-04
# Epoch 42/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 4.1797e-04
# Epoch 43/100
# 25/25 [==============================] - 0s 12ms/step - loss: 9.2462e-04 - val_loss: 3.6657e-04
# Epoch 44/100
# 25/25 [==============================] - 0s 12ms/step - loss: 8.0109e-04 - val_loss: 6.9976e-04
# Epoch 45/100
# 25/25 [==============================] - 0s 12ms/step - loss: 8.7807e-04 - val_loss: 3.1852e-04
# Epoch 46/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.9194e-04 - val_loss: 3.3060e-04
# Epoch 47/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.0633e-04 - val_loss: 5.0511e-04
# Epoch 48/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.1758e-04 - val_loss: 3.9531e-04
# Epoch 49/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.7592e-04 - val_loss: 2.6802e-04
# Epoch 50/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.4136e-04 - val_loss: 4.1076e-04
# Epoch 51/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.2091e-04 - val_loss: 3.4208e-04
# Epoch 52/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.1771e-04 - val_loss: 2.3466e-04
# Epoch 53/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.8722e-04 - val_loss: 2.8758e-04
# Epoch 54/100
# 25/25 [==============================] - 0s 12ms/step - loss: 8.4958e-04 - val_loss: 2.6886e-04
# Epoch 55/100
# 25/25 [==============================] - 0s 16ms/step - loss: 6.2477e-04 - val_loss: 7.2687e-04
# Epoch 56/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.1569e-04 - val_loss: 2.2643e-04
# Epoch 57/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.0600e-04 - val_loss: 5.1477e-04
# Epoch 58/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.0157e-04 - val_loss: 3.2955e-04
# Epoch 59/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.5393e-04 - val_loss: 2.1738e-04
# Epoch 60/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.0218e-04 - val_loss: 3.6856e-04
# Epoch 61/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.0537e-04 - val_loss: 2.6179e-04
# Epoch 62/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.6421e-04 - val_loss: 3.5833e-04
# Epoch 63/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.3696e-04 - val_loss: 4.1821e-04
# Epoch 64/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.3999e-04 - val_loss: 2.0138e-04
# Epoch 65/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.3185e-04 - val_loss: 2.0190e-04
# Epoch 66/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.1489e-04 - val_loss: 5.1736e-04
# Epoch 67/100
# 25/25 [==============================] - 0s 16ms/step - loss: 5.2255e-04 - val_loss: 2.8448e-04
# Epoch 68/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.9709e-04 - val_loss: 2.4526e-04
# Epoch 69/100
# 25/25 [==============================] - 0s 14ms/step - loss: 5.1590e-04 - val_loss: 2.0307e-04
# Epoch 70/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.2588e-04 - val_loss: 4.0842e-04
# Epoch 71/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.3371e-04 - val_loss: 1.9439e-04
# Epoch 72/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.7151e-04 - val_loss: 3.0889e-04
# Epoch 73/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.5300e-04 - val_loss: 1.7949e-04
# Epoch 74/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.6695e-04 - val_loss: 1.7421e-04
# Epoch 75/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.5570e-04 - val_loss: 1.8515e-04
# Epoch 76/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.9774e-04 - val_loss: 3.3227e-04
# Epoch 77/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.8755e-04 - val_loss: 2.1714e-04
# Epoch 78/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.3498e-04 - val_loss: 1.9561e-04
# Epoch 79/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.3987e-04 - val_loss: 1.9176e-04
# Epoch 80/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.6325e-04 - val_loss: 2.3020e-04
# Epoch 81/100
# 25/25 [==============================] - 0s 15ms/step - loss: 4.6283e-04 - val_loss: 2.0928e-04
# Epoch 82/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.4402e-04 - val_loss: 2.1533e-04
# Epoch 83/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.0373e-04 - val_loss: 1.7613e-04
# Epoch 84/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.3987e-04 - val_loss: 1.5502e-04
# Epoch 85/100
# 25/25 [==============================] - 0s 12ms/step - loss: 3.8747e-04 - val_loss: 1.8131e-04
# Epoch 86/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.2167e-04 - val_loss: 1.6402e-04
# Epoch 87/100
# 25/25 [==============================] - 0s 12ms/step - loss: 3.6753e-04 - val_loss: 1.6792e-04
# Epoch 88/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.0455e-04 - val_loss: 3.4844e-04
# Epoch 89/100
# 25/25 [==============================] - 0s 12ms/step - loss: 3.8113e-04 - val_loss: 1.5524e-04
# Epoch 90/100
# 25/25 [==============================] - 0s 12ms/step - loss: 3.8955e-04 - val_loss: 1.8405e-04
# Epoch 91/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.0751e-04 - val_loss: 2.0961e-04
# Epoch 92/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.1132e-04 - val_loss: 2.2040e-04
# Epoch 93/100
# 25/25 [==============================] - 0s 12ms/step - loss: 3.9756e-04 - val_loss: 1.7076e-04
# Epoch 94/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.0143e-04 - val_loss: 1.3847e-04
# Epoch 95/100
# 25/25 [==============================] - 0s 17ms/step - loss: 3.7255e-04 - val_loss: 1.6343e-04
# Epoch 96/100
# 25/25 [==============================] - 0s 11ms/step - loss: 3.6257e-04 - val_loss: 1.5283e-04
# Epoch 97/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.3859e-04 - val_loss: 1.9743e-04
# Epoch 98/100
# 25/25 [==============================] - 0s 11ms/step - loss: 4.7749e-04 - val_loss: 2.3297e-04
# Epoch 99/100
# 25/25 [==============================] - 0s 12ms/step - loss: 3.9827e-04 - val_loss: 1.3646e-04
# Epoch 100/100
# 25/25 [==============================] - 0s 11ms/step - loss: 3.8343e-04 - val_loss: 3.9089e-04

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (396, 7, 6)
# 13/13 [==============================] - 1s 4ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.61510439 0.61955538 0.63512207 0.52653685 0.57656614 0.60530042]
#   [0.64055213 0.63046936 0.64170957 0.53855599 0.58334023 0.61300222]
#   [0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140929]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043776]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.6416704 ]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088305]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123953]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 1: [[3549.7693]]
# x_pred_input of day 2:
# [[[0.64055213 0.63046936 0.64170957 0.53855599 0.58334023 0.61300228]
#   [0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140936]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.73299977 0.72536567 0.7098332  0.59034997 0.63939752 0.67309933]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 2: [[3661.512]]
# x_pred_input of day 3:
# [[[0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140936]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.73299977 0.72536567 0.7098332  0.59034997 0.63939752 0.67309933]
#   [0.75663511 0.74887502 0.72935867 0.59184008 0.65076677 0.68625465]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 3: [[3785.0154]]
# x_pred_input of day 4:
# [[[0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.73299977 0.72536567 0.7098332  0.59034997 0.63939752 0.67309933]
#   [0.75663511 0.74887502 0.72935867 0.59184008 0.65076677 0.68625465]
#   [0.78275804 0.77616263 0.75080968 0.59445805 0.66277057 0.70083739]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 4: [[3914.1475]]
# x_pred_input of day 5:
# [[[0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.73299977 0.72536567 0.7098332  0.59034997 0.63939752 0.67309933]
#   [0.75663511 0.74887502 0.72935867 0.59184008 0.65076677 0.68625465]
#   [0.78275804 0.77616263 0.75080968 0.59445805 0.66277057 0.70083739]
#   [0.81007151 0.80667654 0.77707037 0.59129456 0.67594692 0.71683376]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 5: [[4052.1074]]
# x_pred_input of day 6:
# [[[0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.73299977 0.72536567 0.7098332  0.59034997 0.63939752 0.67309933]
#   [0.75663511 0.74887502 0.72935867 0.59184008 0.65076677 0.68625465]
#   [0.78275804 0.77616263 0.75080968 0.59445805 0.66277057 0.70083739]
#   [0.81007151 0.80667654 0.77707037 0.59129456 0.67594692 0.71683376]
#   [0.83925222 0.84027553 0.80628551 0.58689439 0.68974363 0.73430073]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 6: [[4196.0703]]
# x_pred_input of day 7:
# [[[0.70873566 0.70548169 0.69610186 0.58052893 0.62836714 0.66123959]
#   [0.73299977 0.72536567 0.7098332  0.58972208 0.63939752 0.67309933]
#   [0.75663511 0.74887502 0.72935867 0.59121061 0.65076677 0.68625465]
#   [0.78275804 0.77616263 0.75080968 0.59382579 0.66277057 0.70083739]
#   [0.81007151 0.80667654 0.77707037 0.59066567 0.67594692 0.71683376]
#   [0.83925222 0.84027553 0.80628551 0.58627017 0.68974363 0.73430073]
#   [0.86970265 0.87652416 0.83726321 0.58380199 0.7046889  0.7532285 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 7: [[4338.9844]]
# x_pred_input of day 8:
# [[[0.73299977 0.72536567 0.7098332  0.5700044  0.63939752 0.67309933]
#   [0.75663511 0.74887502 0.72935867 0.57144316 0.65076677 0.68625465]
#   [0.78275804 0.77616263 0.75080968 0.57397091 0.66277057 0.70083739]
#   [0.81007151 0.80667654 0.77707037 0.57091644 0.67594692 0.71683376]
#   [0.83925222 0.84027553 0.80628551 0.56666791 0.68974363 0.73430073]
#   [0.86970265 0.87652416 0.83726321 0.56428226 0.7046889  0.7532285 ]
#   [0.89993123 0.91432811 0.86932984 0.56440938 0.72083847 0.77345519]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 8: [[4466.915]]
# x_pred_input of day 9:
# [[[0.75663511 0.74887502 0.72935867 0.55483684 0.65018746 0.68625465]
#   [0.78275804 0.77616263 0.75080968 0.55729113 0.66218057 0.70083739]
#   [0.81007151 0.80667654 0.77707037 0.55432543 0.67534519 0.71683376]
#   [0.83925222 0.84027553 0.80628551 0.55020036 0.68912962 0.73430073]
#   [0.86970265 0.87652416 0.83726321 0.54788404 0.70406159 0.7532285 ]
#   [0.89993123 0.91432811 0.86932984 0.54800746 0.72019678 0.77345519]
#   [0.92699059 0.9513836  0.90305086 0.54712681 0.73613273 0.79453193]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 9: [[4576.8955]]
# x_pred_input of day 10:
# [[[0.78275804 0.77616263 0.75080968 0.54370778 0.64590833 0.70083739]
#   [0.81007151 0.80667654 0.77707037 0.54081437 0.65874944 0.71683376]
#   [0.83925222 0.84027553 0.80628551 0.53678985 0.67219514 0.73430073]
#   [0.86970265 0.87652416 0.83726321 0.53452998 0.68676017 0.7532285 ]
#   [0.89993123 0.91432811 0.86932984 0.5346504  0.70249886 0.77345519]
#   [0.92699059 0.9513836  0.90305086 0.53379121 0.71804321 0.79453193]
#   [0.9502532  0.98559004 0.93679621 0.53391225 0.7346696  0.81598819]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 10: [[4664.9375]]
# x_pred_input of day 11:
# [[[0.81007151 0.79481377 0.77707037 0.53046402 0.64604062 0.71683376]
#   [0.83925222 0.82791866 0.80628551 0.52651652 0.65922692 0.73430073]
#   [0.86970265 0.86363423 0.83726321 0.52429991 0.67351096 0.7532285 ]
#   [0.89993123 0.90088225 0.86932984 0.52441802 0.68894601 0.77345519]
#   [0.92699059 0.93739281 0.90305086 0.52357528 0.70419047 0.79453193]
#   [0.9502532  0.97109622 0.93679621 0.523694   0.7204961  0.81598819]
#   [0.96887547 1.         0.9695259  0.52527151 0.73639993 0.83731171]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 11: [[4725.562]]
# x_pred_input of day 12:
# [[[0.83925222 0.8100614  0.80628551 0.51966809 0.65058427 0.73430073]
#   [0.86970265 0.84500663 0.83726321 0.51748031 0.66468104 0.7532285 ]
#   [0.89993123 0.88145125 0.86932984 0.51759688 0.67991374 0.77345519]
#   [0.92699059 0.91717432 0.90305086 0.5167651  0.69495834 0.79453193]
#   [0.9502532  0.95015078 0.93679621 0.51688228 0.7110502  0.81598819]
#   [0.96887547 0.97843115 0.9695259  0.51843927 0.72674552 0.83731171]
#   [0.98169851 1.         0.99847103 0.52613968 0.74255853 0.85792012]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 12: [[4760.151]]
# x_pred_input of day 13:
# [[[0.86970265 0.83375807 0.81837356 0.51366833 0.65974616 0.7532285 ]
#   [0.89993123 0.86971755 0.84971672 0.51378405 0.67486576 0.77345519]
#   [0.92699059 0.90496508 0.88267696 0.5129584  0.68979866 0.79453193]
#   [0.9502532  0.93750257 0.91566098 0.51307471 0.70577105 0.81598819]
#   [0.96887547 0.96540647 0.94765225 0.51462023 0.72134985 0.83731171]
#   [0.98169851 0.9866882  0.97594433 0.52226392 0.73704545 0.85792012]
#   [0.9890146  1.         1.         0.53508316 0.75319739 0.87731647]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 13: [[4785.8154]]
# x_pred_input of day 14:
# [[[0.89993123 0.86449126 0.83439384 0.51099108 0.67116839 0.77345519]
#   [0.92699059 0.89952699 0.8667597  0.51016991 0.68601948 0.79453193]
#   [0.9502532  0.93186895 0.89914892 0.5102856  0.70190436 0.81598819]
#   [0.96887547 0.95960517 0.9305633  0.51182271 0.71739781 0.83731171]
#   [0.98169851 0.98075902 0.95834519 0.51942485 0.73300742 0.85792012]
#   [0.9890146  0.99399082 0.98196707 0.5321744  0.74907087 0.87731647]
#   [0.99444306 1.         1.         0.55246258 0.76548477 0.89542254]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 14: [[4800.414]]
# x_pred_input of day 15:
# [[[0.92699059 0.89952699 0.85441192 0.50859724 0.68388821 0.79453193]
#   [0.9502532  0.93186895 0.88633972 0.50871256 0.69972374 0.81598819]
#   [0.96887547 0.95960517 0.91730657 0.51024495 0.71516906 0.83731171]
#   [0.98169851 0.98075902 0.94469269 0.51782365 0.73073017 0.85792012]
#   [0.9890146  0.99399082 0.96797805 0.5305339  0.74674372 0.87731647]
#   [0.99444306 1.         0.98575408 0.55075953 0.76310662 0.89542254]
#   [0.9975309  0.99920923 1.         0.57360052 0.77883334 0.91212104]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 15: [[4807.375]]
# x_pred_input of day 16:
# [[[0.9502532  0.93186895 0.87590997 0.50796592 0.69868874 0.81598819]
#   [0.96887547 0.95960517 0.90651242 0.50949605 0.71411121 0.83731171]
#   [0.98169851 0.98075902 0.93357628 0.51706363 0.7296493  0.85792012]
#   [0.9890146  0.99399082 0.95658764 0.52975522 0.74563916 0.87731647]
#   [0.99444306 1.         0.9741545  0.54995118 0.76197787 0.89542254]
#   [0.9975309  0.99920923 0.98823278 0.57275864 0.77768132 0.91212104]
#   [0.99900325 0.99235951 1.         0.59569017 0.79291389 0.92738028]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 16: [[4812.0537]]
# x_pred_input of day 17:
# [[[0.96887547 0.95960517 0.89885806 0.50899393 0.71340194 0.83731171]
#   [0.98169851 0.98075902 0.9256934  0.51655405 0.72892461 0.85792012]
#   [0.9890146  0.99399082 0.94851045 0.52923313 0.74489858 0.87731647]
#   [0.99444306 1.         0.96592899 0.54940918 0.76122106 0.89542254]
#   [0.9975309  0.99920923 0.97988839 0.57219417 0.77690892 0.91212104]
#   [0.99900325 0.99235951 0.99155625 0.59510309 0.79212636 0.92738028]
#   [0.99999287 0.98061955 1.         0.62024776 0.80681105 0.9412878 ]]]
# 1/1 [==============================] - 0s 35ms/step
# y_pred of day 17: [[4814.619]]
# x_pred_input of day 18:
# [[[0.98117309 0.98075902 0.92085218 0.51627506 0.72852785 0.85792012]
#   [0.98848527 0.99399082 0.94354991 0.52894729 0.74449314 0.87731647]
#   [0.99391082 1.         0.96087734 0.54911245 0.76080673 0.89542254]
#   [0.99699701 0.99920923 0.97476375 0.57188513 0.77648605 0.91212104]
#   [0.99846857 0.99235951 0.98637058 0.59478168 0.79169521 0.92738028]
#   [0.99945766 0.98061955 0.99477017 0.61991277 0.80637191 0.9412878 ]
#   [1.         0.96497715 1.         0.64720885 0.82142164 0.95392646]]]
# 1/1 [==============================] - 0s 29ms/step
# y_pred of day 18: [[4815.1396]]
# x_pred_input of day 19:
# [[[0.98837651 0.99399082 0.93967429 0.52888934 0.74441093 0.87731647]
#   [0.99380147 1.         0.95693056 0.54905228 0.76072272 0.89542254]
#   [0.99688732 0.99920923 0.97075992 0.57182247 0.77640031 0.91212104]
#   [0.99835871 0.99235951 0.98231908 0.59471651 0.79160779 0.92738028]
#   [0.9993477  0.98061955 0.99068417 0.61984485 0.80628286 0.9412878 ]
#   [0.99988998 0.96497715 0.99589252 0.64713794 0.82133094 0.95392646]
#   [1.         0.94625732 1.         0.67268709 0.83637794 0.96537274]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 19: [[4819.9375]]
# x_pred_input of day 20:
# [[[0.99279461 1.         0.95693056 0.54849831 0.75994921 0.89542254]
#   [0.99587733 0.99920923 0.97075992 0.57124553 0.77561086 0.91212104]
#   [0.99734724 0.99235951 0.98231908 0.59411647 0.79080288 0.92738028]
#   [0.99833522 0.98061955 0.99068417 0.61921945 0.80546303 0.9412878 ]
#   [0.99887695 0.96497715 0.99589252 0.64648501 0.82049581 0.95392646]
#   [0.99898686 0.94625732 1.         0.67200838 0.83552751 0.96537274]
#   [1.         0.92575435 0.99821217 0.70506471 0.85100056 0.97583303]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 20: [[4820.622]]
# x_pred_input of day 21:
# [[[0.99573339 0.99920923 0.97075992 0.5711633  0.77549835 0.91212104]
#   [0.99720308 0.99235951 0.98231908 0.59403095 0.79068817 0.92738028]
#   [0.99819092 0.98061955 0.99068417 0.61913032 0.80534619 0.9412878 ]
#   [0.99873257 0.96497715 0.99589252 0.64639195 0.82037679 0.95392646]
#   [0.99884247 0.94625732 1.         0.67191165 0.83540631 0.96537274]
#   [0.99985546 0.92575435 0.99821217 0.70496322 0.85087712 0.97583303]
#   [1.         0.90368926 0.99363516 0.73915108 0.86577709 0.98531195]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 21: [[4820.884]]
# x_pred_input of day 22:
# [[[0.99714798 0.99235951 0.98231908 0.59399826 0.79064432 0.92738028]
#   [0.99813577 0.98061955 0.99068417 0.61909625 0.80530153 0.9412878 ]
#   [0.99867739 0.96497715 0.99589252 0.64635638 0.82033129 0.95392646]
#   [0.99878728 0.94625732 1.         0.67187468 0.83535998 0.96537274]
#   [0.99980022 0.92575435 0.99821217 0.70492443 0.85082993 0.97583303]
#   [0.99994475 0.90368926 0.99363516 0.73911041 0.86572908 0.98531195]
#   [1.         0.88061075 0.98700334 0.77315906 0.87964988 0.9938938 ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 22: [[4824.807]]
# x_pred_input of day 23:
# [[[0.99730969 0.98061955 0.99068417 0.61858599 0.80463264 0.93964955]
#   [0.99785086 0.96497715 0.99589252 0.64582365 0.81964992 0.95226622]
#   [0.99796066 0.94625732 1.         0.67132092 0.83466612 0.96369257]
#   [0.99897276 0.92575435 0.99821217 0.70434343 0.85012323 0.97413465]
#   [0.99911717 0.90368926 0.99363516 0.73850123 0.86500999 0.98359708]
#   [0.99917238 0.88061075 0.98700334 0.77252182 0.87891923 0.99216399]
#   [1.         0.85735621 0.97836321 0.80649322 0.89232058 1.        ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 23: [[4829.785]]
# x_pred_input of day 24:
# [[[0.99680411 0.96497715 0.99589252 0.64514897 0.818787   0.94546119]
#   [0.9969138  0.94625732 1.         0.6706196  0.83378739 0.95680589]
#   [0.99792483 0.92575435 0.99821217 0.70360762 0.84922823 0.96717335]
#   [0.99806909 0.90368926 0.99363516 0.73772973 0.86409932 0.97656816]
#   [0.99812424 0.88061075 0.98700334 0.77171478 0.87799391 0.98507385]
#   [0.998951   0.85735621 0.97836321 0.8056507  0.89138116 0.99285386]
#   [1.         0.83433099 0.96824498 0.83872844 0.9042759  1.        ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 24: [[4833.5894]]
# x_pred_input of day 25:
# [[[0.99611526 0.94625732 1.         0.67008464 0.83311712 0.95058207]
#   [0.99712549 0.92575435 0.99821217 0.70304634 0.84854554 0.96088209]
#   [0.99726963 0.90368926 0.99363516 0.73714124 0.86340468 0.97021578]
#   [0.99732474 0.88061075 0.98700334 0.77109918 0.8772881  0.97866615]
#   [0.99815083 0.85735621 0.97836321 0.80500802 0.89066459 0.98639556]
#   [0.99919899 0.83433099 0.96824498 0.83805938 0.90354896 0.99349521]
#   [1.         0.81163405 0.95699111 0.86973343 0.91531677 1.        ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 25: [[4837.2197]]
# x_pred_input of day 26:
# [[[0.99636387 0.92575435 0.99821217 0.70251155 0.84789507 0.95518644]
#   [0.9965079  0.90368926 0.99363516 0.73658051 0.86274281 0.96446481]
#   [0.99656296 0.88061075 0.98700334 0.77051262 0.8766156  0.97286508]
#   [0.99738842 0.85735621 0.97836321 0.80439567 0.88998183 0.98054867]
#   [0.99843579 0.83433099 0.96824498 0.83742189 0.90285633 0.98760624]
#   [0.99923618 0.81163405 0.95699111 0.86907185 0.91461512 0.99407248]
#   [1.         0.78943612 0.94528524 0.8984046  0.92675897 1.        ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 26: [[4846.0156]]
# x_pred_input of day 27:
# [[[0.99466713 0.90368926 0.99363516 0.73522548 0.86114341 0.95914172]
#   [0.9947221  0.88061075 0.98700334 0.76909516 0.87499048 0.96749563]
#   [0.99554603 0.85735621 0.97836321 0.80291588 0.88833193 0.97513681]
#   [0.99659146 0.83433099 0.96824498 0.83588135 0.90118256 0.98215543]
#   [0.99739038 0.81163405 0.95699111 0.86747308 0.91291955 0.98858597]
#   [0.99815278 0.78943612 0.94528524 0.89675187 0.92504089 0.99448078]
#   [1.         0.76838284 0.93413209 0.92259656 0.93647857 1.        ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 27: [[4854.223]]
# x_pred_input of day 28:
# [[[0.99301049 0.88061075 0.98700334 0.76777722 0.87347949 0.9625223 ]
#   [0.99383301 0.85735621 0.97836321 0.80153998 0.8867979  0.97012421]
#   [0.99487664 0.83433099 0.96824498 0.83444896 0.89962635 0.97710675]
#   [0.99567418 0.81163405 0.95699111 0.86598655 0.91134307 0.98350424]
#   [0.99643528 0.78943612 0.94528524 0.89521517 0.92344348 0.98936874]
#   [0.99827932 0.76838284 0.93413209 0.92101557 0.9348614  0.99485959]
#   [1.         0.74840927 0.92447327 0.9423648  0.94541743 1.        ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 28: [[4863.5146]]
# x_pred_input of day 29:
# [[[0.99190085 0.85735621 0.97836321 0.79998804 0.88506766 0.96544554]
#   [0.99294245 0.83433099 0.96824498 0.8328333  0.89787107 0.9723944 ]
#   [0.99373844 0.81163405 0.95699111 0.86430983 0.90956493 0.97876104]
#   [0.99449806 0.78943612 0.94528524 0.89348186 0.92164173 0.98459726]
#   [0.99633851 0.76838284 0.93413209 0.9192323  0.93303738 0.99006162]
#   [0.99805585 0.74840927 0.92447327 0.94054019 0.94357281 0.99517724]
#   [1.         0.72961432 0.91681828 0.95718273 0.95328079 1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 29: [[4873.5654]]
# x_pred_input of day 30:
# [[[0.99085865 0.83433099 0.96824498 0.83109265 0.89598006 0.96796724]
#   [0.99165297 0.81163405 0.95699111 0.86250339 0.90764929 0.97430489]
#   [0.99241099 0.78943612 0.94528524 0.89161444 0.91970065 0.98011454]
#   [0.99424758 0.76838284 0.93413209 0.91731107 0.9310723  0.98555403]
#   [0.99596132 0.74840927 0.92447327 0.93857443 0.94158554 0.99064635]
#   [0.99790139 0.72961432 0.91681828 0.95518218 0.95127308 0.99544715]
#   [1.         0.71203058 0.91171653 0.96692336 0.96004625 1.        ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 30: [[4884.7627]]
# x_pred_input of day 31:
# [[[0.9893399  0.81163405 0.95699111 0.86049976 0.90552461 0.97008272]
#   [0.99009615 0.78943612 0.94528524 0.88954319 0.91754776 0.9758672 ]
#   [0.99192846 0.76838284 0.93413209 0.91518012 0.92889279 0.98128311]
#   [0.9936382  0.74840927 0.92447327 0.93639408 0.93938142 0.98635337]
#   [0.99557374 0.72961432 0.91681828 0.95296326 0.94904628 0.99113337]
#   [0.99766746 0.71203058 0.91171653 0.96467716 0.95779891 0.99566648]
#   [1.         0.69570731 0.90953138 0.97161877 0.96560327 1.        ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 31: [[4895.3955]]
# x_pred_input of day 32:
# [[[0.98790798 0.78943612 0.94528524 0.88758523 0.91551271 0.97184258]
#   [0.98973623 0.76838284 0.93413209 0.91316574 0.92683257 0.97723616]
#   [0.99144219 0.74840927 0.92447327 0.934333   0.93729794 0.98228551]
#   [0.99337346 0.72961432 0.91681828 0.95086571 0.94694137 0.98704579]
#   [0.99546255 0.71203058 0.91171653 0.96255382 0.95567458 0.99156021]
#   [0.99778994 0.69570731 0.90953138 0.96948016 0.96346163 0.99587586]
#   [1.         0.6805029  0.90965504 0.9728614  0.97022716 1.        ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 32: [[4905.465]]
# x_pred_input of day 33:
# [[[0.9876691  0.76838284 0.93413209 0.91126626 0.92488994 0.97340169]
#   [0.98937149 0.74840927 0.92447327 0.9323895  0.93533337 0.97843123]
#   [0.99129873 0.72961432 0.91681828 0.94888782 0.94495659 0.98317283]
#   [0.99338345 0.71203058 0.91171653 0.96055162 0.9536715  0.98766954]
#   [0.99570598 0.69570731 0.90953138 0.96746355 0.96144223 0.99196825]
#   [0.99791143 0.6805029  0.90965504 0.97083776 0.96819358 0.99607621]
#   [1.         0.66629373 0.91096556 0.97241774 0.97387298 1.        ]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 33: [[4912.0684]]
# x_pred_input of day 34:
# [[[0.98801821 0.74840927 0.92447327 0.93111932 0.93404947 0.97483808]
#   [0.98994281 0.72961432 0.91681828 0.94759517 0.94365947 0.97956227]
#   [0.99202468 0.71203058 0.91171653 0.95924308 0.95236242 0.98404246]
#   [0.99434403 0.69570731 0.90953138 0.96614559 0.96012248 0.98832538]
#   [0.99654646 0.6805029  0.90965504 0.9695152  0.96686457 0.99241826]
#   [0.99863218 0.66629373 0.91096556 0.97109304 0.97253617 0.99632764]
#   [1.         0.65269027 0.91281136 0.97169766 0.97711797 1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 34: [[4914.9688]]
# x_pred_input of day 35:
# [[[0.98934843 0.72961432 0.91681828 0.94702852 0.94309088 0.97626052]
#   [0.99142906 0.71203058 0.91171653 0.95866947 0.95178859 0.98072561]
#   [0.99374701 0.69570731 0.90953138 0.96556786 0.95954397 0.9849941 ]
#   [0.99594812 0.6805029  0.90965504 0.96893545 0.96628199 0.98907318]
#   [0.99803259 0.66629373 0.91096556 0.97051234 0.97195018 0.99296939]
#   [0.99939959 0.65269027 0.91281136 0.97111661 0.97652922 0.99662937]
#   [1.         0.63935742 0.91463372 0.97150507 0.98010925 1.        ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 35: [[4914.179]]
# x_pred_input of day 36:
# [[[0.99142906 0.71203058 0.91171653 0.95882555 0.95194473 0.97775958]
#   [0.99374701 0.69570731 0.90953138 0.96572506 0.95970139 0.98201516]
#   [0.99594812 0.6805029  0.90965504 0.9690932  0.96644051 0.9860819 ]
#   [0.99803259 0.66629373 0.91096556 0.97067035 0.97210963 0.98996633]
#   [0.99939959 0.65269027 0.91281136 0.97127471 0.97668942 0.99361524]
#   [1.         0.63935742 0.91463372 0.97166325 0.98027004 0.99697568]
#   [0.99983655 0.62603082 0.91616079 0.97221176 0.98296544 1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 36: [[4910.947]]
# x_pred_input of day 37:
# [[[0.99374701 0.69570731 0.90953138 0.96636919 0.96034638 0.97939968]
#   [0.99594812 0.6805029  0.90965504 0.96973958 0.96709004 0.9834556 ]
#   [0.99803259 0.66629373 0.91096556 0.97131778 0.97276296 0.98732967]
#   [0.99939959 0.65269027 0.91281136 0.97192255 0.97734584 0.99096886]
#   [1.         0.63935742 0.91463372 0.97231134 0.98092886 0.99432035]
#   [0.99983655 0.62603082 0.91616079 0.97286022 0.98362607 0.99733662]
#   [0.99916741 0.6126242  0.91733161 0.97363195 0.98559337 1.        ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 37: [[4902.1807]]
# x_pred_input of day 38:
# [[[0.99594812 0.6805029  0.90965504 0.97149686 0.96885591 0.98126567]
#   [0.99803259 0.66629373 0.91096556 0.97307792 0.97453919 0.98513112]
#   [0.99939959 0.65269027 0.91281136 0.97368378 0.97913043 0.9887622 ]
#   [1.         0.63935742 0.91463372 0.97407327 0.98272    0.99210623]
#   [0.99983655 0.62603082 0.91616079 0.97462315 0.98542213 0.99511578]
#   [0.99916741 0.6126242  0.91733161 0.97539628 0.98739303 0.99777323]
#   [0.99735273 0.59877122 0.91800938 0.97647047 0.988808   1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 38: [[4888.657]]
# x_pred_input of day 39:
# [[[0.99803259 0.66629373 0.91096556 0.97580582 0.97729213 0.98341924]
#   [0.99939959 0.65269027 0.91281136 0.97641338 0.98189634 0.98704402]
#   [1.         0.63935742 0.91463372 0.97680396 0.98549605 0.99038224]
#   [0.99983655 0.62603082 0.91616079 0.97735538 0.98820581 0.99338656]
#   [0.99916741 0.6126242  0.91733161 0.97813068 0.99018227 0.99603939]
#   [0.99735273 0.59877122 0.91800938 0.97920788 0.99160124 0.99826229]
#   [0.99455322 0.58426525 0.91815678 0.9805714  0.99263368 1.        ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 39: [[4870.465]]
# x_pred_input of day 40:
# [[[0.99939959 0.65269027 0.91281136 0.9801096  0.98564192 0.98585675]
#   [1.         0.63935742 0.91463372 0.98050166 0.98925536 0.98919095]
#   [0.99983655 0.62603082 0.91616079 0.98105517 0.99197546 0.99219166]
#   [0.99916741 0.6126242  0.91733161 0.9818334  0.99395946 0.99484129]
#   [0.99735273 0.59877122 0.91800938 0.98291468 0.99538384 0.99706152]
#   [0.99455322 0.58426525 0.91815678 0.98428336 0.99642021 0.99879714]
#   [0.9907872  0.56896038 0.91796101 0.9855487  0.99710289 1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 40: [[4846.252]]
# x_pred_input of day 41:
# [[[1.         0.63935742 0.91463372 0.98546671 0.99176197 0.98859854]
#   [0.99983655 0.62603082 0.91616079 0.98602302 0.99448897 0.99159746]
#   [0.99916741 0.6126242  0.91733161 0.98680519 0.996478   0.99424551]
#   [0.99735273 0.59877122 0.91800938 0.98789195 0.99790599 0.9964644 ]
#   [0.99455322 0.58426525 0.91815678 0.98926756 0.99894499 0.99819898]
#   [0.9907872  0.56896038 0.91796101 0.9905393  0.99962939 0.99940113]
#   [0.98577487 0.55262038 0.91763759 0.99143056 1.         1.        ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 41: [[4819.989]]
# x_pred_input of day 42:
# [[[0.99983655 0.62603082 0.91616079 0.99146873 0.99438756 0.99158588]
#   [0.99916741 0.6126242  0.91733161 0.99225522 0.99637638 0.9942339 ]
#   [0.99735273 0.59877122 0.91800938 0.99334798 0.99780423 0.99645277]
#   [0.99455322 0.58426525 0.91815678 0.99473119 0.99884312 0.99818733]
#   [0.9907872  0.56896038 0.91796101 0.99600996 0.99952746 0.99938946]
#   [0.98577487 0.55262038 0.91763759 0.99690613 0.99989803 0.99998833]
#   [0.9803381  0.53545686 0.91765668 0.99686622 1.         1.        ]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 42: [[4787.9277]]
# x_pred_input of day 43:
# [[[0.99916741 0.6126242  0.91733161 0.99533465 0.99637638 0.9942339 ]
#   [0.99735273 0.59877122 0.91800938 0.9964308  0.99780423 0.99645277]
#   [0.99455322 0.58426525 0.91815678 0.99781831 0.99884312 0.99818733]
#   [0.9907872  0.56896038 0.91796101 0.99910104 0.99952746 0.99938946]
#   [0.98577487 0.55262038 0.91763759 1.         0.99989803 0.99998833]
#   [0.9803381  0.53545686 0.91765668 0.99995997 1.         1.        ]
#   [0.97370111 0.51728168 0.91866192 0.99806832 0.99980496 0.99936337]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 43: [[4751.373]]
# x_pred_input of day 44:
# [[[0.99735273 0.59877122 0.91800938 0.9964308  0.99780423 0.99645277]
#   [0.99455322 0.58426525 0.91815678 0.99781831 0.99884312 0.99818733]
#   [0.9907872  0.56896038 0.91796101 0.99910104 0.99952746 0.99938946]
#   [0.98577487 0.55262038 0.91763759 1.         0.99989803 0.99998833]
#   [0.9803381  0.53545686 0.91765668 0.99995997 1.         1.        ]
#   [0.97370111 0.51728168 0.91866192 0.99806832 0.99980496 0.99936337]
#   [0.96613388 0.49808541 0.92089439 0.99394091 0.99929365 0.99804946]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 44: [[4716.794]]
# x_pred_input of day 45:
# [[[0.99455322 0.58426525 0.91815678 0.99781831 0.99884312 0.99818733]
#   [0.9907872  0.56896038 0.91796101 0.99910104 0.99952746 0.99938946]
#   [0.98577487 0.55262038 0.91763759 1.         0.99989803 0.99998833]
#   [0.9803381  0.53545686 0.91765668 0.99995997 1.         1.        ]
#   [0.97370111 0.51728168 0.91866192 0.99806832 0.99980496 0.99936337]
#   [0.96613388 0.49808541 0.92089439 0.99394091 0.99929365 0.99804946]
#   [0.95897563 0.47849941 0.92388586 0.98816292 0.99849859 0.99616266]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 45: [[4682.2812]]
# x_pred_input of day 46:
# [[[0.9907872  0.56896038 0.91796101 0.99910104 0.99952746 0.99938946]
#   [0.98577487 0.55262038 0.91763759 1.         0.99989803 0.99998833]
#   [0.9803381  0.53545686 0.91765668 0.99995997 1.         1.        ]
#   [0.97370111 0.51728168 0.91866192 0.99806832 0.99980496 0.99936337]
#   [0.96613388 0.49808541 0.92089439 0.99394091 0.99929365 0.99804946]
#   [0.95897563 0.47849941 0.92388586 0.98816292 0.99849859 0.99616266]
#   [0.95183112 0.45883771 0.92725303 0.9811641  0.99738573 0.99375887]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 46: [[4646.4497]]
# x_pred_input of day 47:
# [[[0.98577487 0.55262038 0.91763759 1.         0.99989803 0.99998833]
#   [0.9803381  0.53545686 0.91765668 0.99995997 1.         1.        ]
#   [0.97370111 0.51728168 0.91866192 0.99806832 0.99980496 0.99936337]
#   [0.96613388 0.49808541 0.92089439 0.99394091 0.99929365 0.99804946]
#   [0.95897563 0.47849941 0.92388586 0.98816292 0.99849859 0.99616266]
#   [0.95183112 0.45883771 0.92725303 0.9811641  0.99738573 0.99375887]
#   [0.9444136  0.43921292 0.93072414 0.97310873 0.99597766 0.9908607 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 47: [[4611.588]]
# x_pred_input of day 48:
# [[[0.9803381  0.53545686 0.91765668 0.99995997 1.         1.        ]
#   [0.97370111 0.51728168 0.91866192 0.99806832 0.99980496 0.99936337]
#   [0.96613388 0.49808541 0.92089439 0.99394091 0.99929365 0.99804946]
#   [0.95897563 0.47849941 0.92388586 0.98816292 0.99849859 0.99616266]
#   [0.95183112 0.45883771 0.92725303 0.9811641  0.99738573 0.99375887]
#   [0.9444136  0.43921292 0.93072414 0.97310873 0.99597766 0.9908607 ]
#   [0.93719682 0.41993469 0.93401652 0.96434287 0.99428564 0.98753482]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 48: [[4575.9565]]
# x_pred_input of day 49:
# [[[0.97370111 0.51728168 0.91866192 0.99806832 0.99980496 0.99936337]
#   [0.96613388 0.49808541 0.92089439 0.99394091 0.99929365 0.99804946]
#   [0.95897563 0.47849941 0.92388586 0.98816292 0.99849859 0.99616266]
#   [0.95183112 0.45883771 0.92725303 0.9811641  0.99738573 0.99375887]
#   [0.9444136  0.43921292 0.93072414 0.97310873 0.99597766 0.9908607 ]
#   [0.93719682 0.41993469 0.93401652 0.96434287 0.99428564 0.98753482]
#   [0.92982073 0.40107308 0.93697003 0.9550048  0.99227385 0.98380642]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 49: [[4539.7866]]
# x_pred_input of day 50:
# [[[0.96613388 0.49808541 0.92089439 0.99394091 0.99929365 0.99804946]
#   [0.95897563 0.47849941 0.92388586 0.98816292 0.99849859 0.99616266]
#   [0.95183112 0.45883771 0.92725303 0.9811641  0.99738573 0.99375887]
#   [0.9444136  0.43921292 0.93072414 0.97310873 0.99597766 0.9908607 ]
#   [0.93719682 0.41993469 0.93401652 0.96434287 0.99428564 0.98753482]
#   [0.92982073 0.40107308 0.93697003 0.9550048  0.99227385 0.98380642]
#   [0.92233316 0.38270063 0.93943481 0.94523323 0.9899294  0.97970296]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 50: [[4502.362]]
# x_pred_input of day 51:
# [[[0.95897563 0.47849941 0.92388586 0.98816292 0.99849859 0.99616266]
#   [0.95183112 0.45883771 0.92725303 0.9811641  0.99738573 0.99375887]
#   [0.9444136  0.43921292 0.93072414 0.97310873 0.99597766 0.9908607 ]
#   [0.93719682 0.41993469 0.93401652 0.96434287 0.99428564 0.98753482]
#   [0.92982073 0.40107308 0.93697003 0.9550048  0.99227385 0.98380642]
#   [0.92233316 0.38270063 0.93943481 0.94523323 0.9899294  0.97970296]
#   [0.91458581 0.36479914 0.94127849 0.93512411 0.98725164 0.97523484]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 51: [[4460.898]]
# x_pred_input of day 52:
# [[[0.95183112 0.45883771 0.92725303 0.9811641  0.99738573 0.99375887]
#   [0.9444136  0.43921292 0.93072414 0.97310873 0.99597766 0.9908607 ]
#   [0.93719682 0.41993469 0.93401652 0.96434287 0.99428564 0.98753482]
#   [0.92982073 0.40107308 0.93697003 0.9550048  0.99227385 0.98380642]
#   [0.92233316 0.38270063 0.93943481 0.94523323 0.9899294  0.97970296]
#   [0.91458581 0.36479914 0.94127849 0.93512411 0.98725164 0.97523484]
#   [0.90600234 0.34707911 0.9424806  0.92462685 0.98420932 0.97035525]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 52: [[4418.791]]
# x_pred_input of day 53:
# [[[0.9444136  0.43921292 0.93072414 0.97310873 0.99597766 0.9908607 ]
#   [0.93719682 0.41993469 0.93401652 0.96434287 0.99428564 0.98753482]
#   [0.92982073 0.40107308 0.93697003 0.9550048  0.99227385 0.98380642]
#   [0.92233316 0.38270063 0.93943481 0.94523323 0.9899294  0.97970296]
#   [0.91458581 0.36479914 0.94127849 0.93512411 0.98725164 0.97523484]
#   [0.90600234 0.34707911 0.9424806  0.92462685 0.98420932 0.97035525]
#   [0.89728574 0.32964084 0.94289947 0.91389671 0.98075549 0.9650904 ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 53: [[4376.201]]
# x_pred_input of day 54:
# [[[0.93719682 0.41993469 0.93401652 0.96434287 0.99428564 0.98753482]
#   [0.92982073 0.40107308 0.93697003 0.9550048  0.99227385 0.98380642]
#   [0.92233316 0.38270063 0.93943481 0.94523323 0.9899294  0.97970296]
#   [0.91458581 0.36479914 0.94127849 0.93512411 0.98725164 0.97523484]
#   [0.90600234 0.34707911 0.9424806  0.92462685 0.98420932 0.97035525]
#   [0.89728574 0.32964084 0.94289947 0.91389671 0.98075549 0.9650904 ]
#   [0.88846917 0.31257525 0.94248683 0.90305011 0.97689099 0.95946723]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 54: [[4332.689]]
# x_pred_input of day 55:
# [[[0.92982073 0.40107308 0.93697003 0.9550048  0.99227385 0.98380642]
#   [0.92233316 0.38270063 0.93943481 0.94523323 0.9899294  0.97970296]
#   [0.91458581 0.36479914 0.94127849 0.93512411 0.98725164 0.97523484]
#   [0.90600234 0.34707911 0.9424806  0.92462685 0.98420932 0.97035525]
#   [0.89728574 0.32964084 0.94289947 0.91389671 0.98075549 0.9650904 ]
#   [0.88846917 0.31257525 0.94248683 0.90305011 0.97689099 0.95946723]
#   [0.87946166 0.2959067  0.94123665 0.89215238 0.97259961 0.95350124]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 55: [[4287.261]]
# x_pred_input of day 56:
# [[[0.92233316 0.38270063 0.93943481 0.94523323 0.9899294  0.97970296]
#   [0.91458581 0.36479914 0.94127849 0.93512411 0.98725164 0.97523484]
#   [0.90600234 0.34707911 0.9424806  0.92462685 0.98420932 0.97035525]
#   [0.89728574 0.32964084 0.94289947 0.91389671 0.98075549 0.9650904 ]
#   [0.88846917 0.31257525 0.94248683 0.90305011 0.97689099 0.95946723]
#   [0.87946166 0.2959067  0.94123665 0.89215238 0.97259961 0.95350124]
#   [0.87005762 0.27955349 0.93918366 0.88120248 0.96785973 0.94718642]]]
# 1/1 [==============================] - 0s 35ms/step
# y_pred of day 56: [[4241.4927]]
# x_pred_input of day 57:
# [[[0.91458581 0.36479914 0.94127849 0.93512411 0.98725164 0.97523484]
#   [0.90600234 0.34707911 0.9424806  0.92462685 0.98420932 0.97035525]
#   [0.89728574 0.32964084 0.94289947 0.91389671 0.98075549 0.9650904 ]
#   [0.88846917 0.31257525 0.94248683 0.90305011 0.97689099 0.95946723]
#   [0.87946166 0.2959067  0.94123665 0.89215238 0.97259961 0.95350124]
#   [0.87005762 0.27955349 0.93918366 0.88120248 0.96785973 0.94718642]
#   [0.86058302 0.26360068 0.93628191 0.87029564 0.96265931 0.94054912]]]
# 1/1 [==============================] - 0s 28ms/step
# y_pred of day 57: [[4193.0825]]
# x_pred_input of day 58:
# [[[0.90600234 0.34707911 0.9424806  0.92462685 0.98420932 0.97035525]
#   [0.89728574 0.32964084 0.94289947 0.91389671 0.98075549 0.9650904 ]
#   [0.88846917 0.31257525 0.94248683 0.90305011 0.97689099 0.95946723]
#   [0.87946166 0.2959067  0.94123665 0.89215238 0.97259961 0.95350124]
#   [0.87005762 0.27955349 0.93918366 0.88120248 0.96785973 0.94718642]
#   [0.86058302 0.26360068 0.93628191 0.87029564 0.96265931 0.94054912]
#   [0.85056159 0.24788728 0.93267247 0.85933659 0.95698156 0.93356671]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 58: [[4144.775]]
# x_pred_input of day 59:
# [[[0.89728574 0.32964084 0.94289947 0.91389671 0.98075549 0.9650904 ]
#   [0.88846917 0.31257525 0.94248683 0.90305011 0.97689099 0.95946723]
#   [0.87946166 0.2959067  0.94123665 0.89215238 0.97259961 0.95350124]
#   [0.87005762 0.27955349 0.93918366 0.88120248 0.96785973 0.94718642]
#   [0.86058302 0.26360068 0.93628191 0.87029564 0.96265931 0.94054912]
#   [0.85056159 0.24788728 0.93267247 0.85933659 0.95698156 0.93356671]
#   [0.84056138 0.23255047 0.92840923 0.84836815 0.95083188 0.92627414]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 59: [[4093.4102]]
# x_pred_input of day 60:
# [[[0.88846917 0.31257525 0.94248683 0.90305011 0.97689099 0.95946723]
#   [0.87946166 0.2959067  0.94123665 0.89215238 0.97259961 0.95350124]
#   [0.87005762 0.27955349 0.93918366 0.88120248 0.96785973 0.94718642]
#   [0.86058302 0.26360068 0.93628191 0.87029564 0.96265931 0.94054912]
#   [0.85056159 0.24788728 0.93267247 0.85933659 0.95698156 0.93356671]
#   [0.84056138 0.23255047 0.92840923 0.84836815 0.95083188 0.92627414]
#   [0.82992831 0.21738714 0.92364505 0.83725494 0.94421356 0.91863923]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 60: [[4042.661]]
# x_pred_input of day 61:
# [[[0.87946166 0.2959067  0.94123665 0.89215238 0.97259961 0.95350124]
#   [0.87005762 0.27955349 0.93918366 0.88120248 0.96785973 0.94718642]
#   [0.86058302 0.26360068 0.93628191 0.87029564 0.96265931 0.94054912]
#   [0.85056159 0.24788728 0.93267247 0.85933659 0.95698156 0.93356671]
#   [0.84056138 0.23255047 0.92840923 0.84836815 0.95083188 0.92627414]
#   [0.82992831 0.21738714 0.92364505 0.83725494 0.94421356 0.91863923]
#   [0.81942265 0.20259219 0.91850245 0.82600122 0.93716152 0.91070701]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 61: [[3990.181]]
# x_pred_input of day 62:
# [[[0.87005762 0.27955349 0.93918366 0.88120248 0.96785973 0.94718642]
#   [0.86058302 0.26360068 0.93628191 0.87029564 0.96265931 0.94054912]
#   [0.85056159 0.24788728 0.93267247 0.85933659 0.95698156 0.93356671]
#   [0.84056138 0.23255047 0.92840923 0.84836815 0.95083188 0.92627414]
#   [0.82992831 0.21738714 0.92364505 0.83725494 0.94421356 0.91863923]
#   [0.81942265 0.20259219 0.91850245 0.82600122 0.93716152 0.91070701]
#   [0.80855872 0.18808668 0.91302339 0.81456724 0.9296916  0.90247086]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 62: [[3938.138]]
# x_pred_input of day 63:
# [[[0.86058302 0.26360068 0.93628191 0.87029564 0.96265931 0.94054912]
#   [0.85056159 0.24788728 0.93267247 0.85933659 0.95698156 0.93356671]
#   [0.84056138 0.23255047 0.92840923 0.84836815 0.95083188 0.92627414]
#   [0.82992831 0.21738714 0.92364505 0.83725494 0.94421356 0.91863923]
#   [0.81942265 0.20259219 0.91850245 0.82600122 0.93716152 0.91070701]
#   [0.80855872 0.18808668 0.91302339 0.81456724 0.9296916  0.90247086]
#   [0.79778525 0.17401561 0.9073536  0.80292307 0.92182707 0.89396855]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 63: [[3885.8564]]
# x_pred_input of day 64:
# [[[0.85056159 0.24788728 0.93267247 0.85933659 0.95698156 0.93356671]
#   [0.84056138 0.23255047 0.92840923 0.84836815 0.95083188 0.92627414]
#   [0.82992831 0.21738714 0.92364505 0.83725494 0.94421356 0.91863923]
#   [0.81942265 0.20259219 0.91850245 0.82600122 0.93716152 0.91070701]
#   [0.80855872 0.18808668 0.91302339 0.81456724 0.9296916  0.90247086]
#   [0.79778525 0.17401561 0.9073536  0.80292307 0.92182707 0.89396855]
#   [0.7869624  0.16042216 0.90162055 0.79101723 0.91361076 0.88522061]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 64: [[3833.162]]
# x_pred_input of day 65:
# [[[0.84056138 0.23255047 0.92840923 0.84836815 0.95083188 0.92627414]
#   [0.82992831 0.21738714 0.92364505 0.83725494 0.94421356 0.91863923]
#   [0.81942265 0.20259219 0.91850245 0.82600122 0.93716152 0.91070701]
#   [0.80855872 0.18808668 0.91302339 0.81456724 0.9296916  0.90247086]
#   [0.79778525 0.17401561 0.9073536  0.80292307 0.92182707 0.89396855]
#   [0.7869624  0.16042216 0.90162055 0.79101723 0.91361076 0.88522061]
#   [0.77605409 0.14731778 0.89569749 0.77893977 0.90507777 0.87624209]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 65: [[3778.0483]]
# x_pred_input of day 66:
# [[[0.82992831 0.21738714 0.92364505 0.83725494 0.94421356 0.91863923]
#   [0.81942265 0.20259219 0.91850245 0.82600122 0.93716152 0.91070701]
#   [0.80855872 0.18808668 0.91302339 0.81456724 0.9296916  0.90247086]
#   [0.79778525 0.17401561 0.9073536  0.80292307 0.92182707 0.89396855]
#   [0.7869624  0.16042216 0.90162055 0.79101723 0.91361076 0.88522061]
#   [0.77605409 0.14731778 0.89569749 0.77893977 0.90507777 0.87624209]
#   [0.76464493 0.1345114  0.88958237 0.76664054 0.89624629 0.86700613]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 66: [[3723.5576]]
# x_pred_input of day 67:
# [[[0.81942265 0.20259219 0.91850245 0.82600122 0.93716152 0.91070701]
#   [0.80855872 0.18808668 0.91302339 0.81456724 0.9296916  0.90247086]
#   [0.79778525 0.17401561 0.9073536  0.80292307 0.92182707 0.89396855]
#   [0.7869624  0.16042216 0.90162055 0.79101723 0.91361076 0.88522061]
#   [0.77605409 0.14731778 0.89569749 0.77893977 0.90507777 0.87624209]
#   [0.76464493 0.1345114  0.88958237 0.76664054 0.89624629 0.86700613]
#   [0.75336475 0.12214482 0.88324657 0.75419219 0.88717004 0.85754982]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 67: [[3669.7646]]
# x_pred_input of day 68:
# [[[0.80855872 0.18808668 0.91302339 0.81456724 0.9296916  0.90247086]
#   [0.79778525 0.17401561 0.9073536  0.80292307 0.92182707 0.89396855]
#   [0.7869624  0.16042216 0.90162055 0.79101723 0.91361076 0.88522061]
#   [0.77605409 0.14731778 0.89569749 0.77893977 0.90507777 0.87624209]
#   [0.76464493 0.1345114  0.88958237 0.76664054 0.89624629 0.86700613]
#   [0.75336475 0.12214482 0.88324657 0.75419219 0.88717004 0.85754982]
#   [0.74222902 0.11033139 0.87657249 0.74171929 0.87787123 0.84790822]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 68: [[3616.444]]
# x_pred_input of day 69:
# [[[0.79778525 0.17401561 0.9073536  0.80292307 0.92182707 0.89396855]
#   [0.7869624  0.16042216 0.90162055 0.79101723 0.91361076 0.88522061]
#   [0.77605409 0.14731778 0.89569749 0.77893977 0.90507777 0.87624209]
#   [0.76464493 0.1345114  0.88958237 0.76664054 0.89624629 0.86700613]
#   [0.75336475 0.12214482 0.88324657 0.75419219 0.88717004 0.85754982]
#   [0.74222902 0.11033139 0.87657249 0.74171929 0.87787123 0.84790822]
#   [0.73119107 0.09913175 0.86952231 0.72928993 0.86840054 0.83810852]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 69: [[3560.7666]]
# x_pred_input of day 70:
# [[[0.7869624  0.16042216 0.90162055 0.79101723 0.91361076 0.88522061]
#   [0.77605409 0.14731778 0.89569749 0.77893977 0.90507777 0.87624209]
#   [0.76464493 0.1345114  0.88958237 0.76664054 0.89624629 0.86700613]
#   [0.75336475 0.12214482 0.88324657 0.75419219 0.88717004 0.85754982]
#   [0.74222902 0.11033139 0.87657249 0.74171929 0.87787123 0.84790822]
#   [0.73119107 0.09913175 0.86952231 0.72928993 0.86840054 0.83810852]
#   [0.71966522 0.08831216 0.86212075 0.71683835 0.85877527 0.82811819]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 70: [[3506.9458]]
# x_pred_input of day 71:
# [[[0.77605409 0.14731778 0.89569749 0.77893977 0.90507777 0.87624209]
#   [0.76464493 0.1345114  0.88958237 0.76664054 0.89624629 0.86700613]
#   [0.75336475 0.12214482 0.88324657 0.75419219 0.88717004 0.85754982]
#   [0.74222902 0.11033139 0.87657249 0.74171929 0.87787123 0.84790822]
#   [0.73119107 0.09913175 0.86952231 0.72928993 0.86840054 0.83810852]
#   [0.71966522 0.08831216 0.86212075 0.71683835 0.85877527 0.82811819]
#   [0.70852372 0.07809362 0.85431412 0.7044897  0.84899443 0.81799289]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 71: [[3452.8743]]
# x_pred_input of day 72:
# [[[0.76464493 0.1345114  0.88958237 0.76664054 0.89624629 0.86700613]
#   [0.75336475 0.12214482 0.88324657 0.75419219 0.88717004 0.85754982]
#   [0.74222902 0.11033139 0.87657249 0.74171929 0.87787123 0.84790822]
#   [0.73119107 0.09913175 0.86952231 0.72928993 0.86840054 0.83810852]
#   [0.71966522 0.08831216 0.86212075 0.71683835 0.85877527 0.82811819]
#   [0.70852372 0.07809362 0.85431412 0.7044897  0.84899443 0.81799289]
#   [0.69733031 0.06843812 0.84623022 0.69218228 0.83905548 0.80774038]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 72: [[3398.9036]]
# x_pred_input of day 73:
# [[[0.75336475 0.12214482 0.88324657 0.75419219 0.88717004 0.85754982]
#   [0.74222902 0.11033139 0.87657249 0.74171929 0.87787123 0.84790822]
#   [0.73119107 0.09913175 0.86952231 0.72928993 0.86840054 0.83810852]
#   [0.71966522 0.08831216 0.86212075 0.71683835 0.85877527 0.82811819]
#   [0.70852372 0.07809362 0.85431412 0.7044897  0.84899443 0.81799289]
#   [0.69733031 0.06843812 0.84623022 0.69218228 0.83905548 0.80774038]
#   [0.68615778 0.05934357 0.83785481 0.67994758 0.82896988 0.79737484]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 73: [[3344.585]]
# x_pred_input of day 74:
# [[[0.74222902 0.11033139 0.87657249 0.74171929 0.87787123 0.84790822]
#   [0.73119107 0.09913175 0.86952231 0.72928993 0.86840054 0.83810852]
#   [0.71966522 0.08831216 0.86212075 0.71683835 0.85877527 0.82811819]
#   [0.70852372 0.07809362 0.85431412 0.7044897  0.84899443 0.81799289]
#   [0.69733031 0.06843812 0.84623022 0.69218228 0.83905548 0.80774038]
#   [0.68615778 0.05934357 0.83785481 0.67994758 0.82896988 0.79737484]
#   [0.67491323 0.05075842 0.82917937 0.66779787 0.81872699 0.78689999]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 74: [[3290.1145]]
# x_pred_input of day 75:
# [[[0.73119107 0.09913175 0.86952231 0.72928993 0.86840054 0.83810852]
#   [0.71966522 0.08831216 0.86212075 0.71683835 0.85877527 0.82811819]
#   [0.70852372 0.07809362 0.85431412 0.7044897  0.84899443 0.81799289]
#   [0.69733031 0.06843812 0.84623022 0.69218228 0.83905548 0.80774038]
#   [0.68615778 0.05934357 0.83785481 0.67994758 0.82896988 0.79737484]
#   [0.67491323 0.05075842 0.82917937 0.66779787 0.81872699 0.78689999]
#   [0.66363725 0.04265549 0.8202097  0.65574297 0.80833179 0.77632319]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 75: [[3236.256]]
# x_pred_input of day 76:
# [[[0.71966522 0.08831216 0.86212075 0.71683835 0.85877527 0.82811819]
#   [0.70852372 0.07809362 0.85431412 0.7044897  0.84899443 0.81799289]
#   [0.69733031 0.06843812 0.84623022 0.69218228 0.83905548 0.80774038]
#   [0.68615778 0.05934357 0.83785481 0.67994758 0.82896988 0.79737484]
#   [0.67491323 0.05075842 0.82917937 0.66779787 0.81872699 0.78689999]
#   [0.66363725 0.04265549 0.8202097  0.65574297 0.80833179 0.77632319]
#   [0.65248796 0.03508204 0.81097975 0.6437986  0.7977936  0.7656665 ]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 76: [[3182.2302]]
# x_pred_input of day 77:
# [[[0.70852372 0.07809362 0.85431412 0.7044897  0.84899443 0.81799289]
#   [0.69733031 0.06843812 0.84623022 0.69218228 0.83905548 0.80774038]
#   [0.68615778 0.05934357 0.83785481 0.67994758 0.82896988 0.79737484]
#   [0.67491323 0.05075842 0.82917937 0.66779787 0.81872699 0.78689999]
#   [0.66363725 0.04265549 0.8202097  0.65574297 0.80833179 0.77632319]
#   [0.65248796 0.03508204 0.81097975 0.6437986  0.7977936  0.7656665 ]
#   [0.64130401 0.02799349 0.80148073 0.63197815 0.7871212  0.75493414]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 77: [[3128.9624]]
# x_pred_input of day 78:
# [[[0.69733031 0.06843812 0.84623022 0.69218228 0.83905548 0.80774038]
#   [0.68615778 0.05934357 0.83785481 0.67994758 0.82896988 0.79737484]
#   [0.67491323 0.05075842 0.82917937 0.66779787 0.81872699 0.78689999]
#   [0.66363725 0.04265549 0.8202097  0.65574297 0.80833179 0.77632319]
#   [0.65248796 0.03508204 0.81097975 0.6437986  0.7977936  0.7656665 ]
#   [0.64130401 0.02799349 0.80148073 0.63197815 0.7871212  0.75493414]
#   [0.63027698 0.02143913 0.79178474 0.62027346 0.77635336 0.74414863]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 78: [[3076.895]]
# x_pred_input of day 79:
# [[[0.68615778 0.05934357 0.83785481 0.67994758 0.82896988 0.79737484]
#   [0.67491323 0.05075842 0.82917937 0.66779787 0.81872699 0.78689999]
#   [0.66363725 0.04265549 0.8202097  0.65574297 0.80833179 0.77632319]
#   [0.65248796 0.03508204 0.81097975 0.6437986  0.7977936  0.7656665 ]
#   [0.64130401 0.02799349 0.80148073 0.63197815 0.7871212  0.75493414]
#   [0.63027698 0.02143913 0.79178474 0.62027346 0.77635336 0.74414863]
#   [0.61949846 0.01549435 0.78184393 0.60876069 0.76550501 0.73333926]]]
# 1/1 [==============================] - 0s 33ms/step
# y_pred of day 79: [[3024.2168]]
# x_pred_input of day 80:
# [[[0.67491323 0.05075842 0.82917937 0.66779787 0.81872699 0.78689999]
#   [0.66363725 0.04265549 0.8202097  0.65574297 0.80833179 0.77632319]
#   [0.65248796 0.03508204 0.81097975 0.6437986  0.7977936  0.7656665 ]
#   [0.64130401 0.02799349 0.80148073 0.63197815 0.7871212  0.75493414]
#   [0.63027698 0.02143913 0.79178474 0.62027346 0.77635336 0.74414863]
#   [0.61949846 0.01549435 0.78184393 0.60876069 0.76550501 0.73333926]
#   [0.60859349 0.01003568 0.77179605 0.59733885 0.7545751  0.72249597]]]
# 1/1 [==============================] - 0s 33ms/step
# y_pred of day 80: [[2971.5603]]
# x_pred_input of day 81:
# [[[0.66363725 0.04265549 0.8202097  0.65574297 0.80833179 0.77632319]
#   [0.65248796 0.03508204 0.81097975 0.6437986  0.7977936  0.7656665 ]
#   [0.64130401 0.02799349 0.80148073 0.63197815 0.7871212  0.75493414]
#   [0.63027698 0.02143913 0.79178474 0.62027346 0.77635336 0.74414863]
#   [0.61949846 0.01549435 0.78184393 0.60876069 0.76550501 0.73333926]
#   [0.60859349 0.01003568 0.77179605 0.59733885 0.7545751  0.72249597]
#   [0.59769301 0.0050222  0.76160867 0.58603132 0.74357126 0.71162243]]]
# 1/1 [==============================] - 0s 55ms/step
# y_pred of day 81: [[2919.989]]
# x_pred_input of day 82:
# [[[6.52487965e-01 3.50820365e-02 8.10979751e-01 6.43798600e-01
#    7.97793599e-01 7.65666498e-01]
#   [6.41304012e-01 2.79934942e-02 8.01480733e-01 6.31978150e-01
#    7.87121195e-01 7.54934142e-01]
#   [6.30276985e-01 2.14391306e-02 7.91784740e-01 6.20273460e-01
#    7.76353364e-01 7.44148631e-01]
#   [6.19498462e-01 1.54943453e-02 7.81843931e-01 6.08760695e-01
#    7.65505010e-01 7.33339261e-01]
#   [6.08593489e-01 1.00356829e-02 7.71796050e-01 5.97338846e-01
#    7.54575097e-01 7.22495972e-01]
#   [5.97693014e-01 5.02219934e-03 7.61608670e-01 5.86031318e-01
#    7.43571259e-01 7.11622434e-01]
#   [5.87017188e-01 5.19834077e-04 7.51328539e-01 5.74845717e-01
#    7.32517754e-01 7.00743434e-01]]]
# 1/1 [==============================] - 0s 41ms/step
# y_pred of day 82: [[2868.296]]
# x_pred_input of day 83:
# [[[0.64130401 0.03142475 0.80148073 0.63197815 0.7871212  0.75493414]
#   [0.63027698 0.02489353 0.79178474 0.62027346 0.77635336 0.74414863]
#   [0.61949846 0.01896973 0.78184393 0.60876069 0.76550501 0.73333926]
#   [0.60859349 0.01353033 0.77179605 0.59733885 0.7545751  0.72249597]
#   [0.59769301 0.00853455 0.76160867 0.58603132 0.74357126 0.71162243]
#   [0.58701719 0.00404808 0.75132854 0.57484572 0.73251775 0.70074343]
#   [0.57631614 0.         0.74094167 0.56378575 0.72141635 0.68985703]]]
# 1/1 [==============================] - 0s 26ms/step
# y_pred of day 83: [[2820.5305]]
# x_pred_input of day 84:
# [[[0.63027698 0.02808052 0.79178474 0.62027346 0.77635336 0.74414863]
#   [0.61949846 0.02217608 0.78184393 0.60876069 0.76550501 0.73333926]
#   [0.60859349 0.01675446 0.77179605 0.59733885 0.7545751  0.72249597]
#   [0.59769301 0.01177501 0.76160867 0.58603132 0.74357126 0.71162243]
#   [0.58701719 0.0073032  0.75132854 0.57484572 0.73251775 0.70074343]
#   [0.57631614 0.00326835 0.74094167 0.56378575 0.72141635 0.68985703]
#   [0.56642818 0.         0.73037246 0.55302307 0.71032016 0.67904322]]]
# 1/1 [==============================] - 0s 58ms/step
# y_pred of day 84: [[2774.31]]
# x_pred_input of day 85:
# [[[0.61949846 0.02459686 0.78184393 0.60876069 0.76550501 0.73333926]
#   [0.60859349 0.01918867 0.77179605 0.59733885 0.7545751  0.72249597]
#   [0.59769301 0.01422154 0.76160867 0.58603132 0.74357126 0.71162243]
#   [0.58701719 0.0097608  0.75132854 0.57484572 0.73251775 0.70074343]
#   [0.57631614 0.00573595 0.74094167 0.56378575 0.72141635 0.68985703]
#   [0.56642818 0.00247569 0.73037246 0.55302307 0.71032016 0.67904322]
#   [0.55686004 0.         0.71962065 0.54259925 0.69924085 0.66832628]]]
# 1/1 [==============================] - 0s 30ms/step
# y_pred of day 85: [[2729.8225]]
# x_pred_input of day 86:
# [[[0.60859349 0.02082033 0.77179605 0.59733885 0.7545751  0.72249597]
#   [0.59769301 0.01586146 0.76160867 0.58603132 0.74357126 0.71162243]
#   [0.58701719 0.01140814 0.75132854 0.57484572 0.73251775 0.70074343]
#   [0.57631614 0.00738998 0.74094167 0.56378575 0.72141635 0.68985703]
#   [0.56642818 0.00413514 0.73037246 0.55302307 0.71032016 0.67904322]
#   [0.55686004 0.00166358 0.71962065 0.54259925 0.69924085 0.66832628]
#   [0.54765062 0.         0.70878007 0.53249793 0.68821713 0.65773195]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 86: [[2686.9746]]
# x_pred_input of day 87:
# [[[0.59769301 0.01670155 0.76160867 0.58603132 0.74357126 0.71162243]
#   [0.58701719 0.01225204 0.75132854 0.57484572 0.73251775 0.70074343]
#   [0.57631614 0.0082373  0.74094167 0.56378575 0.72141635 0.68985703]
#   [0.56642818 0.00498525 0.73037246 0.55302307 0.71032016 0.67904322]
#   [0.55686004 0.00251579 0.71962065 0.54259925 0.69924085 0.66832628]
#   [0.54765062 0.00085363 0.70878007 0.53249793 0.68821713 0.65773195]
#   [0.53878064 0.         0.69782272 0.52277158 0.67725729 0.64728166]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 87: [[2643.62]]
# x_pred_input of day 88:
# [[[5.87017188e-01 1.25077733e-02 7.51328539e-01 5.74845717e-01
#    7.32517754e-01 7.00743434e-01]
#   [5.76316143e-01 8.49408165e-03 7.40941673e-01 5.63785748e-01
#    7.21416353e-01 6.89857034e-01]
#   [5.66428183e-01 5.24286511e-03 7.30372459e-01 5.53023068e-01
#    7.10320165e-01 6.79043223e-01]
#   [5.56860038e-01 2.77404591e-03 7.19620652e-01 5.42599245e-01
#    6.99240850e-01 6.68326277e-01]
#   [5.47650624e-01 1.11232101e-03 7.08780067e-01 5.32497932e-01
#    6.88217132e-01 6.57731950e-01]
#   [5.38780636e-01 2.58910088e-04 6.97822715e-01 5.22771585e-01
#    6.77257292e-01 6.47281663e-01]
#   [5.29805778e-01 0.00000000e+00 6.86765070e-01 5.13376544e-01
#    6.66371226e-01 6.36951472e-01]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 88: [[2601.167]]
# x_pred_input of day 89:
# [[[5.76316143e-01 8.49408165e-03 7.40941673e-01 5.63785748e-01
#    7.21416353e-01 6.89857034e-01]
#   [5.66428183e-01 5.24286511e-03 7.30372459e-01 5.53023068e-01
#    7.10320165e-01 6.79043223e-01]
#   [5.56860038e-01 2.77404591e-03 7.19620652e-01 5.42599245e-01
#    6.99240850e-01 6.68326277e-01]
#   [5.47650624e-01 1.11232101e-03 7.08780067e-01 5.32497932e-01
#    6.88217132e-01 6.57731950e-01]
#   [5.38780636e-01 2.58910088e-04 6.97822715e-01 5.22771585e-01
#    6.77257292e-01 6.47281663e-01]
#   [5.29805778e-01 0.00000000e+00 6.86765070e-01 5.13376544e-01
#    6.66371226e-01 6.36951472e-01]
#   [5.21017513e-01 2.96146319e-04 6.75598926e-01 5.04330952e-01
#    6.55562687e-01 6.26748134e-01]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 89: [[2558.7686]]
# x_pred_input of day 90:
# [[[5.66428183e-01 5.24286511e-03 7.30372459e-01 5.53023068e-01
#    7.10320165e-01 6.79043223e-01]
#   [5.56860038e-01 2.77404591e-03 7.19620652e-01 5.42599245e-01
#    6.99240850e-01 6.68326277e-01]
#   [5.47650624e-01 1.11232101e-03 7.08780067e-01 5.32497932e-01
#    6.88217132e-01 6.57731950e-01]
#   [5.38780636e-01 2.58910088e-04 6.97822715e-01 5.22771585e-01
#    6.77257292e-01 6.47281663e-01]
#   [5.29805778e-01 0.00000000e+00 6.86765070e-01 5.13376544e-01
#    6.66371226e-01 6.36951472e-01]
#   [5.21017513e-01 2.96146319e-04 6.75598926e-01 5.04330952e-01
#    6.55562687e-01 6.26748134e-01]
#   [5.12240569e-01 1.02902873e-03 6.64465691e-01 4.95529012e-01
#    6.44834047e-01 6.16660672e-01]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 90: [[2516.7898]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#             Close        MACD  Bollinger_Upper  Bollinger_Lower         MA26  \
# 0      227.181000    0.000000      2516.789795      2516.789795  2516.789795
# 1      220.488998   -0.533835      2516.789795      2516.789795  2516.789795
# 2      222.218002   -0.808072      2516.789795      2516.789795  2516.789795
# 3      227.600998   -0.584308      2516.789795      2516.789795  2516.789795
# 4      225.119995   -0.600251      2516.789795      2516.789795  2516.789795
# ...           ...         ...              ...              ...          ...
# 2063  2686.974609 -333.426663      3783.120474      2542.923716  3323.437894
# 2064  2643.620117 -333.642311      3725.044224      2498.385513  3271.647095
# 2065  2601.166992 -333.395649      3666.398117      2455.503909  3220.225135
# 2066  2558.768555 -332.785225      3607.924857      2413.777365  3169.183293
# 2067  2516.789795 -331.863282      3549.351048      2373.335573  3118.553589
#
#             EMA20
# 0      227.181000
# 1      226.543666
# 2      226.131698
# 3      226.271632
# 4      226.161952
# ...           ...
# 2063  3155.361095
# 2064  3106.623859
# 2065  3058.485109
# 2066  3010.893057
# 2067  2963.835603
#
# [2068 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
# Dateframe of Close training set
df_train = df_filtered['Close'][:train_size].copy()

# Plot the forecast for df_val, df_test and df_forecast
plt.figure(figsize=(15, 7))
plt.plot(df_train, label='Train')
plt.plot(df_test['Y_test_pred'], label='Test prediction')
plt.plot(df_test['Y_test'], label='Test')
plt.plot(df_forecast_unscale['Close'], label='Forecast next 30 days')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  92.89795468264693
# MAPE:  4.210922065319828
# SMAPE:  4.103653470067623
