# %%
from statsmodels.graphics.tsaplots import acf, pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.ar_model import AutoReg 
from pmdarima import auto_arima
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.dates as mdates
import datetime as dt

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # Doge

# %% [markdown]
# ## Step #1: Read Data

# %%
# Read data
df = pd.read_csv('../../../Dataset/DOGE-USD.csv', parse_dates=['Date'])
df
# Out:
#            Date      Open      High       Low     Close  Adj Close      Volume
# 0    2018-03-01  0.006042  0.006320  0.005945  0.006215   0.006215    15518400
# 1    2018-03-02  0.006174  0.006232  0.005447  0.005482   0.005482    22498100
# 2    2018-03-03  0.005494  0.005756  0.005181  0.005301   0.005301    21545000
# 3    2018-03-04  0.005234  0.005502  0.005164  0.005502   0.005502    12133500
# 4    2018-03-05  0.005462  0.005535  0.005157  0.005218   0.005218    13627700
# ...         ...       ...       ...       ...       ...        ...         ...
# 2280 2024-05-28  0.169090  0.169330  0.161796  0.164962   0.164962  1410223091
# 2281 2024-05-29  0.164964  0.170269  0.162220  0.163695   0.163695  1525668595
# 2282 2024-05-30  0.163696  0.165407  0.156595  0.159544   0.159544  1452218159
# 2283 2024-05-31  0.159539  0.162226  0.154907  0.159136   0.159136   945969518
# 2284 2024-06-01  0.159136  0.161323  0.158391  0.160200   0.160200   496035603
#
# [2285 rows x 7 columns]

# %% [markdown]
# ## Step #2: Explore the Data

# %%
# Dataset Description
df = df.set_index('Date')
print(f"Dataset Shape: {df.shape}")
print(f"Dataset Info: {df.info()}")
print(f"Dataset Describe: {df.describe()}")
# Out:
# Dataset Shape: (2285, 6)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2285 entries, 2018-03-01 to 2024-06-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2285 non-null   float64
#  1   High       2285 non-null   float64
#  2   Low        2285 non-null   float64
#  3   Close      2285 non-null   float64
#  4   Adj Close  2285 non-null   float64
#  5   Volume     2285 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 125.0 KB
# Dataset Info: None
# Dataset Describe:               Open         High          Low        Close    Adj Close  \
# count  2285.000000  2285.000000  2285.000000  2285.000000  2285.000000
# mean      0.070440     0.074000     0.067026     0.070516     0.070516
# std       0.090590     0.097472     0.083922     0.090653     0.090653
# min       0.001540     0.001612     0.001247     0.001537     0.001537
# 25%       0.002757     0.002824     0.002663     0.002756     0.002756
# 50%       0.059041     0.060653     0.057824     0.059120     0.059120
# 75%       0.088926     0.092046     0.085549     0.088974     0.088974
# max       0.687801     0.737567     0.608168     0.684777     0.684777
#
#              Volume
# count  2.285000e+03
# mean   1.018695e+09
# std    3.182515e+09
# min    2.134170e+06
# 25%    5.097996e+07
# 50%    2.400790e+08
# 75%    8.053057e+08
# max    6.941068e+10

# %%
# Plotting data
plt.figure(figsize=(15, 7))
plt.plot(df.Close, label='BTC/USD Close price')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Step #3: Feature Engineering

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(df)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

df_original = df_filtered.copy()

# Create shifted features
for feature in FEATURES:
    if feature != 'Close':
        df_filtered[feature + '_shift-1'] = df_filtered[feature].shift(1)
        df_filtered = df_filtered.drop(feature, axis=1)

df_filtered = df_filtered.dropna()


print(df_filtered.tail().to_string())
print(df_filtered.head().to_string())
print(df_original.head().to_string())
print(df_original.tail().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                Close  MACD_shift-1  Bollinger_Upper_shift-1  Bollinger_Lower_shift-1  MA26_shift-1  EMA20_shift-1
# Date
# 2024-05-28  0.164962      0.004158                 0.176558                 0.134979      0.154679       0.159572
# 2024-05-29  0.163695      0.004031                 0.177157                 0.136547      0.155942       0.160086
# 2024-05-30  0.159544      0.003784                 0.177827                 0.137035      0.156617       0.160429
# 2024-05-31  0.159136      0.003216                 0.177613                 0.138800      0.156594       0.160345
# 2024-06-01  0.160200      0.002702                 0.177041                 0.140993      0.156519       0.160230
#                Close  MACD_shift-1  Bollinger_Upper_shift-1  Bollinger_Lower_shift-1  MA26_shift-1  EMA20_shift-1
# Date
# 2018-10-03  0.005704      0.000241                 0.006478                 0.005382      0.005966       0.005739
# 2018-10-04  0.005645      0.000213                 0.006358                 0.005417      0.005981       0.005736
# 2018-10-05  0.005669      0.000183                 0.006322                 0.005400      0.005979       0.005727
# 2018-10-06  0.005545      0.000159                 0.006282                 0.005391      0.005973       0.005722
# 2018-10-07  0.005562      0.000129                 0.006110                 0.005464      0.005921       0.005705
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2018-10-02  0.005824  0.000241         0.006478         0.005382  0.005966  0.005739
# 2018-10-03  0.005704  0.000213         0.006358         0.005417  0.005981  0.005736
# 2018-10-04  0.005645  0.000183         0.006322         0.005400  0.005979  0.005727
# 2018-10-05  0.005669  0.000159         0.006282         0.005391  0.005973  0.005722
# 2018-10-06  0.005545  0.000129         0.006110         0.005464  0.005921  0.005705
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2024-05-28  0.164962  0.004031         0.177157         0.136547  0.155942  0.160086
# 2024-05-29  0.163695  0.003784         0.177827         0.137035  0.156617  0.160429
# 2024-05-30  0.159544  0.003216         0.177613         0.138800  0.156594  0.160345
# 2024-05-31  0.159136  0.002702         0.177041         0.140993  0.156519  0.160230
# 2024-06-01  0.160200  0.002354         0.175927         0.144004  0.156658  0.160227

# %%
# Plot line charts
df_plot = df_filtered.copy()

ncols = 2
nrows = int(round(df_plot.shape[1] / ncols, 0))

fig, ax = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, figsize=(14, 7))
for i, ax in enumerate(fig.axes):
        sns.lineplot(data = df_plot.iloc[:, i], ax=ax)
        ax.tick_params(axis="x", rotation=30, labelsize=10, length=0)
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
fig.tight_layout()
plt.show()

# %%
# Coorelation Matrix
plt.figure(figsize=(14, 7))
sns.heatmap(df_filtered.corr(), annot=True, fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Step #4: Train & Test split

# %%
# Train-Test Split
def split_data(df, test_size=None):
    test_size = 0.2 if test_size is None else test_size
    split_row = len(df) - int(test_size * len(df))
    train_set = df.iloc[:split_row].copy()
    test_set = df.iloc[split_row:].copy()
    return train_set, test_set

train, test = split_data(df_filtered, test_size=0.3)

# %%
print(df_filtered.shape)
print(train.shape)
print(test.shape)
# Out:
# (2069, 6)
# (1449, 6)
# (620, 6)

# %% [markdown]
# ## Step #5: Model Specification

# %% [markdown]
# **ARIMAX**

# %% [markdown]
# **1. Check for stationary**

# %%
# Agugmented Dickey-Fuller test
def adf_test(dataset, name):
    dftest = adfuller(dataset, autolag='AIC', regression='ct')
    print(f"ADF Test on '{name}' -> p-value: {dftest[1]:.3f}")
    if (dftest[0] < dftest[4]["5%"] or dftest[0] < dftest[4]["1%"] or dftest[0] < dftest[4]["10%"]):
        print ("\033[92mReject Ho - Time Series is Stationary\033[0m")
        return True
    else:
        print ("\033[91mFailed to Reject Ho - Time Series is Non-Stationary\033[0m")
        return False

# %%
# Differencing all features for stationarity until all features are stationary
is_all_stationary = False
diff_order = 0
while not is_all_stationary:
    print("*"*50 + f" Differencing of order {diff_order} " + "*"*50)
    train_diff = pd.DataFrame(np.diff(train, diff_order, axis=0), columns=train.columns)
    if all([adf_test(train_diff[feature], feature) for feature in train_diff.columns]):
        is_all_stationary = True
        print(f"Dataset is stationary after differencing of order {diff_order}")
        break
    diff_order += 1
# Out:
# ************************************************** Differencing of order 0 **************************************************
# ADF Test on 'Close' -> p-value: 0.389
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'MACD_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'Bollinger_Upper_shift-1' -> p-value: 0.133
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'Bollinger_Lower_shift-1' -> p-value: 0.332
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'MA26_shift-1' -> p-value: 0.833
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'EMA20_shift-1' -> p-value: 0.319
# Failed to Reject Ho - Time Series is Non-Stationary
# ************************************************** Differencing of order 1 **************************************************
# ADF Test on 'Close' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'MACD_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'Bollinger_Upper_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'Bollinger_Lower_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'MA26_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'EMA20_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# Dataset is stationary after differencing of order 1

# %%
# Plot line charts
df_plot = train_diff.copy()

ncols = 2
nrows = int(round(df_plot.shape[1] / ncols, 0))

fig, ax = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, figsize=(14, 7))
for i, ax in enumerate(fig.axes):
        sns.lineplot(data = df_plot.iloc[:, i], ax=ax)
        ax.tick_params(axis="x", rotation=30, labelsize=10, length=0)
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
fig.tight_layout()
plt.show()

# %%
# Plot ACF and PACF
acf_plot = acf(train_diff['Close'])
pacf_plot = pacf(train_diff['Close'])
# Plot ACF
plt.figure(figsize=(8, 4))
plt.plot(acf_plot, marker='o', linestyle='--')
plt.axhline(y=0, color='gray')
plt.axhline(y=-1.96/np.sqrt(len(train_diff)), color='red', linestyle='--')
plt.axhline(y=1.96/np.sqrt(len(train_diff)), color='red', linestyle='--')
plt.title('ACF')

# Plot PACF
plt.figure(figsize=(8, 4))
plt.plot(pacf_plot, marker='o', linestyle='--')
plt.axhline(y=0, color='gray')
plt.axhline(y=-1.96/np.sqrt(len(train_diff)), color='red', linestyle='--')
plt.axhline(y=1.96/np.sqrt(len(train_diff)), color='red', linestyle='--')
plt.title('PACF')
# Out:
# Text(0.5, 1.0, 'PACF')

# %% [markdown]
# **2. Choose the “p” level of AR model and “q” level for MA model**

# %%
# Find the best ARIMA model
def _arima_fit(orders, data, exog=None):
    models = dict()
    # Print arima fit with AIC and BIC decending
    for order in tqdm_notebook(orders):
        model = ARIMA(data, order=order, exog=exog)
        model_fit = model.fit()
        models[order] = model_fit
    return models

# %%
# Estimate ARIMA models with different p, q values through PCAF and ACF plots
list_q = [0, 1, 2, 3, 5] # q values picked from PACF plot
list_p = [0, 1, 2, 3, 5] # p values picked from ACF plot
order_list = list(product(list_p, [diff_order], list_q))

models = _arima_fit(order_list, train['Close'], train.drop(columns=['Close']))
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %% [markdown]
# **3. Validation and tuning model**

# %%
# Validate the model with the validation set with AIC and BIC, then pick the best model based on RMSE
def _validate_models(models, valid, exog=None):
    # Get 10 top models based on AIC
    top_models = sorted(models.items(), key=lambda x: x[1].aic)[:10]
    print("Top 10 models based on AIC")
    for order, model in top_models:
        print(f"Order: {order} -> AIC: {model.aic:.2f}")
    # Validate the models
    best_model = None
    best_RMSE = float('inf')
    best_order = None
    for order, model in top_models:
        forecast = model.forecast(steps=len(valid), exog=exog)
        mse = np.mean((forecast - valid['Close'])**2)
        rmse = np.sqrt(mse)
        if rmse < best_RMSE:
            best_RMSE = rmse
            best_model = model
            best_order = order
    return best_model, best_order, best_RMSE
        
        

# Validate the models
best_model, best_order, best_RMSE = _validate_models(models, test, test.drop(columns=['Close']))

print(f"\nBest Order: {best_order} -> Best RMSE: {best_RMSE:.2f}")
print(best_model.summary())
# Out:
# Top 10 models based on AIC
# Order: (0, 1, 5) -> AIC: -8482.92
# Order: (1, 1, 5) -> AIC: -8480.36
# Order: (2, 1, 5) -> AIC: -8476.54
# Order: (3, 1, 5) -> AIC: -8473.03
# Order: (5, 1, 1) -> AIC: -8469.21
# Order: (5, 1, 0) -> AIC: -8465.07
# Order: (5, 1, 5) -> AIC: -8463.99
# Order: (5, 1, 3) -> AIC: -8461.14
# Order: (3, 1, 3) -> AIC: -8446.30
# Order: (2, 1, 3) -> AIC: -8439.41
#
# Best Order: (5, 1, 1) -> Best RMSE: 0.05
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1449
# Model:                 ARIMA(5, 1, 1)   Log Likelihood                4246.607
# Date:                Thu, 06 Jun 2024   AIC                          -8469.214
# Time:                        16:41:57   BIC                          -8405.879
# Sample:                    10-03-2018   HQIC                         -8445.578
#                          - 09-20-2022
# Covariance Type:                  opg
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# MACD_shift-1                0.7017      0.247      2.846      0.004       0.218       1.185
# Bollinger_Upper_shift-1     0.9057      0.085     10.687      0.000       0.740       1.072
# Bollinger_Lower_shift-1     0.9528      0.074     12.907      0.000       0.808       1.097
# MA26_shift-1               -0.4968      0.165     -3.003      0.003      -0.821      -0.173
# EMA20_shift-1              -1.5796      0.286     -5.523      0.000      -2.140      -1.019
# ar.L1                       0.1134      0.048      2.354      0.019       0.019       0.208
# ar.L2                       0.1516      0.016      9.646      0.000       0.121       0.182
# ar.L3                       0.1243      0.015      8.441      0.000       0.095       0.153
# ar.L4                       0.0174      0.014      1.262      0.207      -0.010       0.045
# ar.L5                      -0.2364      0.008    -29.026      0.000      -0.252      -0.220
# ma.L1                      -0.2359      0.059     -4.004      0.000      -0.351      -0.120
# sigma2                      0.0002   1.35e-06    123.671      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):            220413.42
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):           11880.42   Skew:                             2.56
# Prob(H) (two-sided):                  0.00   Kurtosis:                        63.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# **4. Forecasting**

# %%
# Forecast on test set
# test forecast
forecast_test_valid = best_model.forecast(steps=len(test), exog=test.drop(columns=['Close']))
forecast_test_valid.index = test.index


# Plot the overall
plt.figure(figsize=(15, 7))
plt.plot(train['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.plot(forecast_test_valid, label='Test Forecast')
# plt.plot(forecast_next_30_days, label='Next 30 days Forecast')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Create function to forecast next x days
def forecast_next_x_days(df, num_days, best_model):

    print(f"Forecasting for day {num_days}")
    # Predict 1 day ahead and use the forecasted value to create features for the next day
    df_forecast = df.copy()
    for i in range(num_days):
        # Create the forecast's exogenous variables
        future_exog_1 = df_forecast.iloc[-1].copy()
        print(f"Forecasting for day {i+1}")
        forecast_1_ahead = best_model.forecast(steps=1, exog=future_exog_1.drop('Close').values.reshape(1, -1))
        print(f"Forecasted value for day {i+1}: {forecast_1_ahead[0]}") 
        # Append the forecasted value to the dataset 
        future_exog_1['Close'] = forecast_1_ahead[0]
        df_forecast_extend = pd.DataFrame([future_exog_1], columns=df_forecast.columns)
        df_forecast = pd.concat([df_forecast, df_forecast_extend], axis=0)
        df_forecast.index = pd.date_range(start=df_forecast.index.min(), periods=len(df_forecast))
        
        # Create the features for the next day
        df_forecast = createFeatures(df_forecast)
        # Filter the data to the list of FEATURES
        df_forecast = df_forecast[FEATURES].copy()

        
    return df_forecast[-num_days:]

# %%
# Forecast next 30 days
forecast_next_30_days = forecast_next_x_days(df_original, 30, best_model)

# Forecast next 60 days
forecast_next_60_days = forecast_next_x_days(df_original, 60, best_model)

# Forecast next 90 days
forecast_next_90_days = forecast_next_x_days(df_original, 90, best_model)
# Out:
# Forecasting for day 30
# Forecasting for day 1
# Forecasted value for day 1: 0.04078398772295824
# Forecasting for day 2
# Forecasted value for day 2: 0.04207699605859777
# Forecasting for day 3
# Forecasted value for day 3: 0.04428732355222387
# Forecasting for day 4
# Forecasted value for day 4: 0.0456952992623873
# Forecasting for day 5
# Forecasted value for day 5: 0.0472700988943541
# Forecasting for day 6
# Forecasted value for day 6: 0.047958059480704
# Forecasting for day 7
# Forecasted value for day 7: 0.048470651999937386
# Forecasting for day 8
# Forecasted value for day 8: 0.04907991503192455
# Forecasting for day 9
# Forecasted value for day 9: 0.04772403473470016
# Forecasting for day 10
# Forecasted value for day 10: 0.04575601869160956
# Forecasting for day 11
# Forecasted value for day 11: 0.043689853053225425
# Forecasting for day 12
# Forecasted value for day 12: 0.041954231099786465
# Forecasting for day 13
# Forecasted value for day 13: 0.03944808235846525
# Forecasting for day 14
# Forecasted value for day 14: 0.035668111589663154
# Forecasting for day 15
# Forecasted value for day 15: 0.03259386344683808
# Forecasting for day 16
# Forecasted value for day 16: 0.02909895280829608
# Forecasting for day 17
# Forecasted value for day 17: 0.02563506818221052
# Forecasting for day 18
# Forecasted value for day 18: 0.021948559637330528
# Forecasting for day 19
# Forecasted value for day 19: 0.01852955404334991
# Forecasting for day 20
# Forecasted value for day 20: 0.015287507268156524
# Forecasting for day 21
# Forecasted value for day 21: 0.012329415533610888
# Forecasting for day 22
# Forecasted value for day 22: 0.018394919321746035
# Forecasting for day 23
# Forecasted value for day 23: 0.023848529637872415
# Forecasting for day 24
# Forecasted value for day 24: 0.028660949586436515
# Forecasting for day 25
# Forecasted value for day 25: 0.03287143170851586
# Forecasting for day 26
# Forecasted value for day 26: 0.036569527736706436
# Forecasting for day 27
# Forecasted value for day 27: 0.039897216143186344
# Forecasting for day 28
# Forecasted value for day 28: 0.040602684194782884
# Forecasting for day 29
# Forecasted value for day 29: 0.0410769204753843
# Forecasting for day 30
# Forecasted value for day 30: 0.041538062881871354
# Forecasting for day 60
# Forecasting for day 1
# Forecasted value for day 1: 0.04078398772295824
# Forecasting for day 2
# Forecasted value for day 2: 0.04207699605859777
# Forecasting for day 3
# Forecasted value for day 3: 0.04428732355222387
# Forecasting for day 4
# Forecasted value for day 4: 0.0456952992623873
# Forecasting for day 5
# Forecasted value for day 5: 0.0472700988943541
# Forecasting for day 6
# Forecasted value for day 6: 0.047958059480704
# Forecasting for day 7
# Forecasted value for day 7: 0.048470651999937386
# Forecasting for day 8
# Forecasted value for day 8: 0.04907991503192455
# Forecasting for day 9
# Forecasted value for day 9: 0.04772403473470016
# Forecasting for day 10
# Forecasted value for day 10: 0.04575601869160956
# Forecasting for day 11
# Forecasted value for day 11: 0.043689853053225425
# Forecasting for day 12
# Forecasted value for day 12: 0.041954231099786465
# Forecasting for day 13
# Forecasted value for day 13: 0.03944808235846525
# Forecasting for day 14
# Forecasted value for day 14: 0.035668111589663154
# Forecasting for day 15
# Forecasted value for day 15: 0.03259386344683808
# Forecasting for day 16
# Forecasted value for day 16: 0.02909895280829608
# Forecasting for day 17
# Forecasted value for day 17: 0.02563506818221052
# Forecasting for day 18
# Forecasted value for day 18: 0.021948559637330528
# Forecasting for day 19
# Forecasted value for day 19: 0.01852955404334991
# Forecasting for day 20
# Forecasted value for day 20: 0.015287507268156524
# Forecasting for day 21
# Forecasted value for day 21: 0.012329415533610888
# Forecasting for day 22
# Forecasted value for day 22: 0.018394919321746035
# Forecasting for day 23
# Forecasted value for day 23: 0.023848529637872415
# Forecasting for day 24
# Forecasted value for day 24: 0.028660949586436515
# Forecasting for day 25
# Forecasted value for day 25: 0.03287143170851586
# Forecasting for day 26
# Forecasted value for day 26: 0.036569527736706436
# Forecasting for day 27
# Forecasted value for day 27: 0.039897216143186344
# Forecasting for day 28
# Forecasted value for day 28: 0.040602684194782884
# Forecasting for day 29
# Forecasted value for day 29: 0.0410769204753843
# Forecasting for day 30
# Forecasted value for day 30: 0.041538062881871354
# Forecasting for day 31
# Forecasted value for day 31: 0.042046497766336316
# Forecasting for day 32
# Forecasted value for day 32: 0.04263373172552757
# Forecasting for day 33
# Forecasted value for day 33: 0.04327162589291575
# Forecasting for day 34
# Forecasted value for day 34: 0.04404182281652406
# Forecasting for day 35
# Forecasted value for day 35: 0.04507731314111493
# Forecasting for day 36
# Forecasted value for day 36: 0.046291440511032796
# Forecasting for day 37
# Forecasted value for day 37: 0.047727547995660244
# Forecasting for day 38
# Forecasted value for day 38: 0.049396111477989224
# Forecasting for day 39
# Forecasted value for day 39: 0.051340747441024674
# Forecasting for day 40
# Forecasted value for day 40: 0.05353701995772372
# Forecasting for day 41
# Forecasted value for day 41: 0.055963866862068654
# Forecasting for day 42
# Forecasted value for day 42: 0.058637088672587684
# Forecasting for day 43
# Forecasted value for day 43: 0.060606290937245955
# Forecasting for day 44
# Forecasted value for day 44: 0.06196118758682804
# Forecasting for day 45
# Forecasted value for day 45: 0.06279123636312649
# Forecasting for day 46
# Forecasted value for day 46: 0.06318905857059197
# Forecasting for day 47
# Forecasted value for day 47: 0.06323097309122733
# Forecasting for day 48
# Forecasted value for day 48: 0.06297501309415249
# Forecasting for day 49
# Forecasted value for day 49: 0.06286320058721528
# Forecasting for day 50
# Forecasted value for day 50: 0.06290197662345477
# Forecasting for day 51
# Forecasted value for day 51: 0.06307520807273892
# Forecasting for day 52
# Forecasted value for day 52: 0.06336178054166719
# Forecasting for day 53
# Forecasted value for day 53: 0.06373966515919388
# Forecasting for day 54
# Forecasted value for day 54: 0.06419313001199511
# Forecasting for day 55
# Forecasted value for day 55: 0.06465582665661526
# Forecasting for day 56
# Forecasted value for day 56: 0.065095196523722
# Forecasting for day 57
# Forecasted value for day 57: 0.06549244738875493
# Forecasting for day 58
# Forecasted value for day 58: 0.0658257373714029
# Forecasting for day 59
# Forecasted value for day 59: 0.06607279318712793
# Forecasting for day 60
# Forecasted value for day 60: 0.06620567644950595
# Forecasting for day 90
# Forecasting for day 1
# Forecasted value for day 1: 0.04078398772295824
# Forecasting for day 2
# Forecasted value for day 2: 0.04207699605859777
# Forecasting for day 3
# Forecasted value for day 3: 0.04428732355222387
# Forecasting for day 4
# Forecasted value for day 4: 0.0456952992623873
# Forecasting for day 5
# Forecasted value for day 5: 0.0472700988943541
# Forecasting for day 6
# Forecasted value for day 6: 0.047958059480704
# Forecasting for day 7
# Forecasted value for day 7: 0.048470651999937386
# Forecasting for day 8
# Forecasted value for day 8: 0.04907991503192455
# Forecasting for day 9
# Forecasted value for day 9: 0.04772403473470016
# Forecasting for day 10
# Forecasted value for day 10: 0.04575601869160956
# Forecasting for day 11
# Forecasted value for day 11: 0.043689853053225425
# Forecasting for day 12
# Forecasted value for day 12: 0.041954231099786465
# Forecasting for day 13
# Forecasted value for day 13: 0.03944808235846525
# Forecasting for day 14
# Forecasted value for day 14: 0.035668111589663154
# Forecasting for day 15
# Forecasted value for day 15: 0.03259386344683808
# Forecasting for day 16
# Forecasted value for day 16: 0.02909895280829608
# Forecasting for day 17
# Forecasted value for day 17: 0.02563506818221052
# Forecasting for day 18
# Forecasted value for day 18: 0.021948559637330528
# Forecasting for day 19
# Forecasted value for day 19: 0.01852955404334991
# Forecasting for day 20
# Forecasted value for day 20: 0.015287507268156524
# Forecasting for day 21
# Forecasted value for day 21: 0.012329415533610888
# Forecasting for day 22
# Forecasted value for day 22: 0.018394919321746035
# Forecasting for day 23
# Forecasted value for day 23: 0.023848529637872415
# Forecasting for day 24
# Forecasted value for day 24: 0.028660949586436515
# Forecasting for day 25
# Forecasted value for day 25: 0.03287143170851586
# Forecasting for day 26
# Forecasted value for day 26: 0.036569527736706436
# Forecasting for day 27
# Forecasted value for day 27: 0.039897216143186344
# Forecasting for day 28
# Forecasted value for day 28: 0.040602684194782884
# Forecasting for day 29
# Forecasted value for day 29: 0.0410769204753843
# Forecasting for day 30
# Forecasted value for day 30: 0.041538062881871354
# Forecasting for day 31
# Forecasted value for day 31: 0.042046497766336316
# Forecasting for day 32
# Forecasted value for day 32: 0.04263373172552757
# Forecasting for day 33
# Forecasted value for day 33: 0.04327162589291575
# Forecasting for day 34
# Forecasted value for day 34: 0.04404182281652406
# Forecasting for day 35
# Forecasted value for day 35: 0.04507731314111493
# Forecasting for day 36
# Forecasted value for day 36: 0.046291440511032796
# Forecasting for day 37
# Forecasted value for day 37: 0.047727547995660244
# Forecasting for day 38
# Forecasted value for day 38: 0.049396111477989224
# Forecasting for day 39
# Forecasted value for day 39: 0.051340747441024674
# Forecasting for day 40
# Forecasted value for day 40: 0.05353701995772372
# Forecasting for day 41
# Forecasted value for day 41: 0.055963866862068654
# Forecasting for day 42
# Forecasted value for day 42: 0.058637088672587684
# Forecasting for day 43
# Forecasted value for day 43: 0.060606290937245955
# Forecasting for day 44
# Forecasted value for day 44: 0.06196118758682804
# Forecasting for day 45
# Forecasted value for day 45: 0.06279123636312649
# Forecasting for day 46
# Forecasted value for day 46: 0.06318905857059197
# Forecasting for day 47
# Forecasted value for day 47: 0.06323097309122733
# Forecasting for day 48
# Forecasted value for day 48: 0.06297501309415249
# Forecasting for day 49
# Forecasted value for day 49: 0.06286320058721528
# Forecasting for day 50
# Forecasted value for day 50: 0.06290197662345477
# Forecasting for day 51
# Forecasted value for day 51: 0.06307520807273892
# Forecasting for day 52
# Forecasted value for day 52: 0.06336178054166719
# Forecasting for day 53
# Forecasted value for day 53: 0.06373966515919388
# Forecasting for day 54
# Forecasted value for day 54: 0.06419313001199511
# Forecasting for day 55
# Forecasted value for day 55: 0.06465582665661526
# Forecasting for day 56
# Forecasted value for day 56: 0.065095196523722
# Forecasting for day 57
# Forecasted value for day 57: 0.06549244738875493
# Forecasting for day 58
# Forecasted value for day 58: 0.0658257373714029
# Forecasting for day 59
# Forecasted value for day 59: 0.06607279318712793
# Forecasting for day 60
# Forecasted value for day 60: 0.06620567644950595
# Forecasting for day 61
# Forecasted value for day 61: 0.06619937355081372
# Forecasting for day 62
# Forecasted value for day 62: 0.0660312600447634
# Forecasting for day 63
# Forecasted value for day 63: 0.06567309824243198
# Forecasting for day 64
# Forecasted value for day 64: 0.06520304987398605
# Forecasting for day 65
# Forecasted value for day 65: 0.0646882505097829
# Forecasting for day 66
# Forecasted value for day 66: 0.06418382367651226
# Forecasting for day 67
# Forecasted value for day 67: 0.06373194094149721
# Forecasting for day 68
# Forecasted value for day 68: 0.0633653242703871
# Forecasting for day 69
# Forecasted value for day 69: 0.06311136389388569
# Forecasting for day 70
# Forecasted value for day 70: 0.0629358827724408
# Forecasting for day 71
# Forecasted value for day 71: 0.06280670203014033
# Forecasting for day 72
# Forecasted value for day 72: 0.06269609011957593
# Forecasting for day 73
# Forecasted value for day 73: 0.06258149456680624
# Forecasting for day 74
# Forecasted value for day 74: 0.06244530026790667
# Forecasting for day 75
# Forecasted value for day 75: 0.06227363556591582
# Forecasting for day 76
# Forecasted value for day 76: 0.06206805415652086
# Forecasting for day 77
# Forecasted value for day 77: 0.061833316154351003
# Forecasting for day 78
# Forecasted value for day 78: 0.061575454512213815
# Forecasting for day 79
# Forecasted value for day 79: 0.061301862008517796
# Forecasting for day 80
# Forecasted value for day 80: 0.061021230261380816
# Forecasting for day 81
# Forecasted value for day 81: 0.060744059826543906
# Forecasting for day 82
# Forecasted value for day 82: 0.060481304316844765
# Forecasting for day 83
# Forecasted value for day 83: 0.06024468769342254
# Forecasting for day 84
# Forecasted value for day 84: 0.06004732688942884
# Forecasting for day 85
# Forecasted value for day 85: 0.05989510429613862
# Forecasting for day 86
# Forecasted value for day 86: 0.0597879984055183
# Forecasting for day 87
# Forecasted value for day 87: 0.059721168357150335
# Forecasting for day 88
# Forecasted value for day 88: 0.059686089656658316
# Forecasting for day 89
# Forecasted value for day 89: 0.05967132692340607
# Forecasting for day 90
# Forecasted value for day 90: 0.059662872563637115

# %%
df_forecast_90 = forecast_next_90_days.copy()
df_forecast_90.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_90))

df_forecast_60 = forecast_next_60_days.copy()
df_forecast_60.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_60))

df_forecast_30 = forecast_next_30_days.copy()
df_forecast_30.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast_30))

# Label the forecasted data
forecast_30_label = f"Forecast next 30 days - " + df_forecast_30.index[-1].strftime("%Y-%m-%d")
forecast_60_label = f"Forecast next 60 days - " + df_forecast_60.index[-1].strftime("%Y-%m-%d")
forecast_90_label = f"Forecast next 90 days - " + df_forecast_90.index[-1].strftime("%Y-%m-%d")

# Add last day of original data to the forecasted data
df_forecast_30 = pd.concat([df_filtered.tail(1), df_forecast_30])
df_forecast_30.index = pd.date_range(start=df_filtered.index.max(), periods=len(df_forecast_30))

# Plot the overall with connection to forecast
plt.figure(figsize=(15, 7))
plt.plot(df_filtered['Close'], label='Train')
plt.plot(test.index, test['Close'], label='Actual Test')
plt.plot(forecast_test_valid.index, forecast_test_valid, label='Forecast Test')
plt.plot(df_forecast_90.index, df_forecast_90['Close'], label=forecast_90_label)
plt.plot(df_forecast_60.index, df_forecast_60['Close'], label=forecast_60_label)
plt.plot(df_forecast_30.index, df_forecast_30['Close'], label=forecast_30_label)
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Step #6: Model Evaluation

# %%
# Calculate the Model's RMSE, MAPE, and SMAPE
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics
rmse, mape, smape = calculate_metrics(test['Close'], forecast_test_valid)
print(f"RMSE: {rmse:.4f}")
print(f"MAPE: {mape:.2f}")
print(f"SMAPE: {smape:.2f}")
# Out:
# RMSE: 0.0524
# MAPE: 31.25
# SMAPE: 41.65
