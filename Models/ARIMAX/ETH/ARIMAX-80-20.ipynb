# %%
from statsmodels.graphics.tsaplots import acf, pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.ar_model import AutoReg 
from pmdarima import auto_arima
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.dates as mdates
import datetime as dt

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # ETH

# %% [markdown]
# ## Step #1: Read Data

# %%
# Read data
df = pd.read_csv('../../../Project/.dataset/ETH-USD-3.2018-3.2024.csv', parse_dates=['Date'])
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2018-03-01   856.012024   880.302002   851.919983   872.200012
# 1    2018-03-02   871.763977   876.377991   852.421997   856.853027
# 2    2018-03-03   856.710999   868.453979   855.206970   857.224976
# 3    2018-03-04   856.185974   867.950012   840.280029   866.677979
# 4    2018-03-05   866.846008   869.919983   853.520020   853.684021
# ...         ...          ...          ...          ...          ...
# 2188 2024-02-26  3112.529053  3197.375000  3037.954590  3178.993652
# 2189 2024-02-27  3178.405029  3287.958008  3167.830566  3244.519287
# 2190 2024-02-28  3243.893311  3485.450928  3201.575928  3385.703857
# 2191 2024-02-29  3386.802734  3518.969238  3303.905273  3341.919678
# 2192 2024-03-01  3341.965820  3452.626221  3341.851074  3435.053955
#
#         Adj Close       Volume
# 0      872.200012   1868519936
# 1      856.853027   1894419968
# 2      857.224976   1699369984
# 3      866.677979   1697939968
# 4      853.684021   1898489984
# ...           ...          ...
# 2188  3178.993652  17504464351
# 2189  3244.519287  21090315368
# 2190  3385.703857  32885894265
# 2191  3341.919678  28469171094
# 2192  3435.053955  16880101987
#
# [2193 rows x 7 columns]

# %% [markdown]
# ## Step #2: Explore the Data

# %%
# Dataset Description
df = df.set_index('Date')
print(f"Dataset Shape: {df.shape}")
print(f"Dataset Info: {df.info()}")
print(f"Dataset Describe: {df.describe()}")
# Out:
# Dataset Shape: (2193, 6)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2193 entries, 2018-03-01 to 2024-03-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2193 non-null   float64
#  1   High       2193 non-null   float64
#  2   Low        2193 non-null   float64
#  3   Close      2193 non-null   float64
#  4   Adj Close  2193 non-null   float64
#  5   Volume     2193 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 119.9 KB
# Dataset Info: None
# Dataset Describe:               Open         High          Low        Close    Adj Close  \
# count  2193.000000  2193.000000  2193.000000  2193.000000  2193.000000
# mean   1297.763470  1333.670351  1258.664921  1298.754657  1298.754657
# std    1145.088942  1178.127207  1108.612995  1145.552190  1145.552190
# min      84.279694    85.342743    82.829887    84.308296    84.308296
# 25%     228.976196   233.895996   222.996002   228.729996   228.729996
# 50%    1212.736572  1229.739014  1180.379761  1213.599976  1213.599976
# 75%    1923.694336  1971.462280  1881.856812  1924.565918  1924.565918
# max    4810.071289  4891.704590  4718.039063  4812.087402  4812.087402
#
#              Volume
# count  2.193000e+03
# mean   1.253104e+10
# std    1.011046e+10
# min    9.484880e+08
# 25%    5.512697e+09
# 50%    1.002418e+10
# 75%    1.698479e+10
# max    8.448291e+10

# %%
# Plotting data
plt.figure(figsize=(15, 7))
plt.plot(df.Close, label='BTC/USD Close price')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Step #3: Feature Engineering

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(df)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

df_original = df_filtered.copy()

# Create shifted features
for feature in FEATURES:
    if feature != 'Close':
        df_filtered[feature + '_shift-1'] = df_filtered[feature].shift(1)
        df_filtered = df_filtered.drop(feature, axis=1)

df_filtered = df_filtered.dropna()


print(df_filtered.tail().to_string())
print(df_filtered.head().to_string())
print(df_original.head().to_string())
print(df_original.tail().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('ETH/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                   Close  MACD_shift-1  Bollinger_Upper_shift-1  Bollinger_Lower_shift-1  MA26_shift-1  EMA20_shift-1
# Date
# 2024-02-26  3178.993652    166.892555              3213.636211              2287.293305   2645.699069    2791.612321
# 2024-02-27  3244.519287    176.932341              3255.792315              2325.816376   2680.177885    2828.505781
# 2024-02-28  3385.703857    188.009064              3305.231037              2358.455071   2716.358445    2868.126115
# 2024-02-29  3341.919678    205.807441              3373.219591              2387.046254   2757.807129    2917.419234
# 2024-03-01  3435.053955    213.913899              3420.740673              2424.965577   2798.033335    2957.847847
#                  Close  MACD_shift-1  Bollinger_Upper_shift-1  Bollinger_Lower_shift-1  MA26_shift-1  EMA20_shift-1
# Date
# 2018-10-03  220.488998     -5.729216               248.675597               199.022404    217.482077     228.975856
# 2018-10-04  222.218002     -5.855122               248.492314               200.119187    217.608461     228.167584
# 2018-10-05  227.600998     -5.749115               248.314508               201.343894    218.541807     227.600957
# 2018-10-06  225.119995     -5.171132               248.556886               201.554214    219.721692     227.600961
# 2018-10-07  226.119003     -4.857280               248.689311               201.874888    220.800192     227.364678
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678
#                   Close        MACD  Bollinger_Upper  Bollinger_Lower         MA26        EMA20
# Date
# 2024-02-26  3178.993652  176.932341      3255.792315      2325.816376  2680.177885  2828.505781
# 2024-02-27  3244.519287  188.009064      3305.231037      2358.455071  2716.358445  2868.126115
# 2024-02-28  3385.703857  205.807441      3373.219591      2387.046254  2757.807129  2917.419234
# 2024-02-29  3341.919678  213.913899      3420.740673      2424.965577  2798.033335  2957.847847
# 2024-03-01  3435.053955  225.256863      3476.021966      2463.066852  2842.091327  3003.296048

# %%
# Plot line charts
df_plot = df_filtered.copy()

ncols = 2
nrows = int(round(df_plot.shape[1] / ncols, 0))

fig, ax = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, figsize=(14, 7))
for i, ax in enumerate(fig.axes):
        sns.lineplot(data = df_plot.iloc[:, i], ax=ax)
        ax.tick_params(axis="x", rotation=30, labelsize=10, length=0)
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
fig.tight_layout()
plt.show()

# %%
# Coorelation Matrix
plt.figure(figsize=(14, 7))
sns.heatmap(df_filtered.corr(), annot=True, fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Step #4: Train & Test split

# %%
# Train-Test Split
def split_data(df, test_size=None):
    test_size = 0.2 if test_size is None else test_size
    split_row = len(df) - int(test_size * len(df))
    train_set = df.iloc[:split_row].copy()
    test_set = df.iloc[split_row:].copy()
    return train_set, test_set

train, test = split_data(df_filtered, test_size=0.2)

# %%
print(df_filtered.shape)
print(train.shape)
print(test.shape)
# Out:
# (1977, 6)
# (1582, 6)
# (395, 6)

# %% [markdown]
# ## Step #5: Model Specification

# %% [markdown]
# **ARIMAX**

# %% [markdown]
# **1. Check for stationary**

# %%
# Agugmented Dickey-Fuller test
def adf_test(dataset, name):
    dftest = adfuller(dataset, autolag='AIC', regression='ct')
    print(f"ADF Test on '{name}' -> p-value: {dftest[1]:.3f}")
    if (dftest[0] < dftest[4]["5%"] or dftest[0] < dftest[4]["1%"] or dftest[0] < dftest[4]["10%"]):
        print ("\033[92mReject Ho - Time Series is Stationary\033[0m")
        return True
    else:
        print ("\033[91mFailed to Reject Ho - Time Series is Non-Stationary\033[0m")
        return False

# %%
# Differencing all features for stationarity until all features are stationary
is_all_stationary = False
diff_order = 0
while not is_all_stationary:
    print("*"*50 + f" Differencing of order {diff_order} " + "*"*50)
    train_diff = pd.DataFrame(np.diff(train, diff_order, axis=0), columns=train.columns)
    if all([adf_test(train_diff[feature], feature) for feature in train_diff.columns]):
        is_all_stationary = True
        print(f"Dataset is stationary after differencing of order {diff_order}")
        break
    diff_order += 1
# Out:
# ************************************************** Differencing of order 0 **************************************************
# ADF Test on 'Close' -> p-value: 0.827
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'MACD_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'Bollinger_Upper_shift-1' -> p-value: 0.728
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'Bollinger_Lower_shift-1' -> p-value: 0.686
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'MA26_shift-1' -> p-value: 0.891
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'EMA20_shift-1' -> p-value: 0.690
# Failed to Reject Ho - Time Series is Non-Stationary
# ************************************************** Differencing of order 1 **************************************************
# ADF Test on 'Close' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'MACD_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'Bollinger_Upper_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'Bollinger_Lower_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'MA26_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'EMA20_shift-1' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# Dataset is stationary after differencing of order 1

# %%
# Plot line charts
df_plot = train_diff.copy()

ncols = 2
nrows = int(round(df_plot.shape[1] / ncols, 0))

fig, ax = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, figsize=(14, 7))
for i, ax in enumerate(fig.axes):
        sns.lineplot(data = df_plot.iloc[:, i], ax=ax)
        ax.tick_params(axis="x", rotation=30, labelsize=10, length=0)
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
fig.tight_layout()
plt.show()

# %%
# Plot ACF and PACF
acf_plot = acf(train_diff['Close'])
pacf_plot = pacf(train_diff['Close'])
# Plot ACF
plt.figure(figsize=(8, 4))
plt.plot(acf_plot, marker='o', linestyle='--')
plt.axhline(y=0, color='gray')
plt.axhline(y=-1.96/np.sqrt(len(train_diff)), color='red', linestyle='--')
plt.axhline(y=1.96/np.sqrt(len(train_diff)), color='red', linestyle='--')
plt.title('ACF')

# Plot PACF
plt.figure(figsize=(8, 4))
plt.plot(pacf_plot, marker='o', linestyle='--')
plt.axhline(y=0, color='gray')
plt.axhline(y=-1.96/np.sqrt(len(train_diff)), color='red', linestyle='--')
plt.axhline(y=1.96/np.sqrt(len(train_diff)), color='red', linestyle='--')
plt.title('PACF')
# Out:
# Text(0.5, 1.0, 'PACF')

# %% [markdown]
# **2. Choose the “p” level of AR model and “q” level for MA model**

# %%
# Find the best ARIMA model
def _arima_fit(orders, data, exog=None):
    models = dict()
    # Print arima fit with AIC and BIC decending
    for order in tqdm_notebook(orders):
        model = ARIMA(data, order=order, exog=exog)
        model_fit = model.fit()
        models[order] = model_fit
    return models

# %%
# Estimate ARIMA models with different p, q values through PCAF and ACF plots
list_q = [0, 1, 4, 5, 6] # q values picked from PACF plot
list_p = [0, 1, 4, 5, 6] # p values picked from ACF plot
order_list = list(product(list_p, [diff_order], list_q))

models = _arima_fit(order_list, train['Close'], train.drop(columns=['Close']))
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %% [markdown]
# **3. Validation and tuning model**

# %%
# Validate the model with the validation set with AIC and BIC, then pick the best model based on RMSE
def _validate_models(models, valid, exog=None):
    # Get 10 top models based on AIC
    top_models = sorted(models.items(), key=lambda x: x[1].aic)[:10]
    print("Top 10 models based on AIC")
    for order, model in top_models:
        print(f"Order: {order} -> AIC: {model.aic:.2f}")
    # Validate the models
    best_model = None
    best_RMSE = float('inf')
    best_order = None
    for order, model in top_models:
        forecast = model.forecast(steps=len(valid), exog=exog)
        mse = np.mean((forecast - valid['Close'])**2)
        rmse = np.sqrt(mse)
        if rmse < best_RMSE:
            best_RMSE = rmse
            best_model = model
            best_order = order
    return best_model, best_order, best_RMSE
        
        

# Validate the models
best_model, best_order, best_RMSE = _validate_models(models, test, test.drop(columns=['Close']))

print(f"\nBest Order: {best_order} -> Best RMSE: {best_RMSE:.2f}")
print(best_model.summary())
# Out:
# Top 10 models based on AIC
# Order: (5, 1, 5) -> AIC: 18457.14
# Order: (6, 1, 6) -> AIC: 18462.32
# Order: (6, 1, 5) -> AIC: 18462.87
# Order: (6, 1, 0) -> AIC: 18473.54
# Order: (4, 1, 6) -> AIC: 18473.96
# Order: (5, 1, 6) -> AIC: 18474.93
# Order: (5, 1, 1) -> AIC: 18475.11
# Order: (6, 1, 1) -> AIC: 18475.46
# Order: (6, 1, 4) -> AIC: 18475.65
# Order: (0, 1, 6) -> AIC: 18475.72
#
# Best Order: (4, 1, 6) -> Best RMSE: 355.24
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1582
# Model:                 ARIMA(4, 1, 6)   Log Likelihood               -9220.982
# Date:                Tue, 28 May 2024   AIC                          18473.963
# Time:                        11:58:40   BIC                          18559.816
# Sample:                    10-03-2018   HQIC                         18505.862
#                          - 01-31-2023
# Covariance Type:                  opg
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# MACD_shift-1                0.0887      0.553      0.161      0.872      -0.995       1.172
# Bollinger_Upper_shift-1    -0.3371      0.104     -3.248      0.001      -0.540      -0.134
# Bollinger_Lower_shift-1    -0.6787      0.100     -6.819      0.000      -0.874      -0.484
# MA26_shift-1                0.2586      0.272      0.951      0.341      -0.274       0.791
# EMA20_shift-1               0.9956      0.375      2.655      0.008       0.261       1.730
# ar.L1                      -0.2441      2.020     -0.121      0.904      -4.204       3.716
# ar.L2                      -0.1172      2.158     -0.054      0.957      -4.347       4.112
# ar.L3                       0.3707      2.068      0.179      0.858      -3.682       4.424
# ar.L4                       0.4447      1.009      0.441      0.659      -1.532       2.422
# ma.L1                       0.1130      2.010      0.056      0.955      -3.826       4.052
# ma.L2                       0.0519      1.885      0.028      0.978      -3.643       3.747
# ma.L3                      -0.4145      1.712     -0.242      0.809      -3.770       2.941
# ma.L4                      -0.4159      0.625     -0.665      0.506      -1.641       0.810
# ma.L5                      -0.0144      0.263     -0.055      0.956      -0.531       0.502
# ma.L6                       0.1032      0.256      0.403      0.687      -0.399       0.605
# sigma2                   6870.0424    106.141     64.726      0.000    6662.010    7078.075
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             11055.69
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):             134.24   Skew:                            -0.84
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# **4. Forecasting**

# %%
# Forecast on test set
# test forecast
forecast_test_valid = best_model.forecast(steps=len(test), exog=test.drop(columns=['Close']))
forecast_test_valid.index = test.index


# Plot the overall
plt.figure(figsize=(15, 7))
plt.plot(train['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.plot(forecast_test_valid, label='Test Forecast')
# plt.plot(forecast_next_30_days, label='Next 30 days Forecast')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Create function to forecast next x days
def forecast_next_x_days(df, num_days, best_model):

    print(f"Forecasting for day {num_days}")
    # Predict 1 day ahead and use the forecasted value to create features for the next day
    df_forecast = df.copy()
    for i in range(num_days):
        # Create the forecast's exogenous variables
        future_exog_1 = df_forecast.iloc[-1].copy()
        print(f"Forecasting for day {i+1}")
        forecast_1_ahead = best_model.forecast(steps=1, exog=future_exog_1.drop('Close').values.reshape(1, -1))
        print(f"Forecasted value for day {i+1}: {forecast_1_ahead[0]}") 
        # Append the forecasted value to the dataset 
        future_exog_1['Close'] = forecast_1_ahead[0]
        df_forecast_extend = pd.DataFrame([future_exog_1], columns=df_forecast.columns)
        df_forecast = pd.concat([df_forecast, df_forecast_extend], axis=0)
        df_forecast.index = pd.date_range(start=df_forecast.index.min(), periods=len(df_forecast))
        
        # Create the features for the next day
        df_forecast = createFeatures(df_forecast)
        # Filter the data to the list of FEATURES
        df_forecast = df_forecast[FEATURES].copy()

        
    return df_forecast[-num_days:]

# %%
# Forecast next 30 days
forecast_next_30_days = forecast_next_x_days(df_original, 30, best_model)

# Forecast next 60 days
forecast_next_60_days = forecast_next_x_days(df_original, 60, best_model)

# Forecast next 90 days
forecast_next_90_days = forecast_next_x_days(df_original, 90, best_model)
# Out:
# Forecasting for day 30
# Forecasting for day 1
# Forecasted value for day 1: 2094.9517070115294
# Forecasting for day 2
# Forecasted value for day 2: 2053.831435148887
# Forecasting for day 3
# Forecasted value for day 3: 2029.9202801718632
# Forecasting for day 4
# Forecasted value for day 4: 2007.3400005567933
# Forecasting for day 5
# Forecasted value for day 5: 1997.0406690236246
# Forecasting for day 6
# Forecasted value for day 6: 1991.3945169226818
# Forecasting for day 7
# Forecasted value for day 7: 1987.4831930698394
# Forecasting for day 8
# Forecasted value for day 8: 1985.6616970370433
# Forecasting for day 9
# Forecasted value for day 9: 1989.0452772451695
# Forecasting for day 10
# Forecasted value for day 10: 1997.0842818127703
# Forecasting for day 11
# Forecasted value for day 11: 2007.516751269237
# Forecasting for day 12
# Forecasted value for day 12: 2017.6856493669131
# Forecasting for day 13
# Forecasted value for day 13: 2029.1728942850273
# Forecasting for day 14
# Forecasted value for day 14: 2040.5792976681673
# Forecasting for day 15
# Forecasted value for day 15: 2052.9970690243235
# Forecasting for day 16
# Forecasted value for day 16: 2065.5668146324974
# Forecasting for day 17
# Forecasted value for day 17: 2075.4181986503104
# Forecasting for day 18
# Forecasted value for day 18: 2080.757777398644
# Forecasting for day 19
# Forecasted value for day 19: 2072.3961416473144
# Forecasting for day 20
# Forecasted value for day 20: 2046.3118538043107
# Forecasting for day 21
# Forecasted value for day 21: 1903.1916091112325
# Forecasting for day 22
# Forecasted value for day 22: 1879.9745875508488
# Forecasting for day 23
# Forecasted value for day 23: 1857.0532696004334
# Forecasting for day 24
# Forecasted value for day 24: 1833.8854227517054
# Forecasting for day 25
# Forecasted value for day 25: 1809.5720646974078
# Forecasting for day 26
# Forecasted value for day 26: 1786.4606577261438
# Forecasting for day 27
# Forecasted value for day 27: 1763.341202481541
# Forecasting for day 28
# Forecasted value for day 28: 1754.4887568837469
# Forecasting for day 29
# Forecasted value for day 29: 1746.975916318644
# Forecasting for day 30
# Forecasted value for day 30: 1740.839184330066
# Forecasting for day 60
# Forecasting for day 1
# Forecasted value for day 1: 2094.9517070115294
# Forecasting for day 2
# Forecasted value for day 2: 2053.831435148887
# Forecasting for day 3
# Forecasted value for day 3: 2029.9202801718632
# Forecasting for day 4
# Forecasted value for day 4: 2007.3400005567933
# Forecasting for day 5
# Forecasted value for day 5: 1997.0406690236246
# Forecasting for day 6
# Forecasted value for day 6: 1991.3945169226818
# Forecasting for day 7
# Forecasted value for day 7: 1987.4831930698394
# Forecasting for day 8
# Forecasted value for day 8: 1985.6616970370433
# Forecasting for day 9
# Forecasted value for day 9: 1989.0452772451695
# Forecasting for day 10
# Forecasted value for day 10: 1997.0842818127703
# Forecasting for day 11
# Forecasted value for day 11: 2007.516751269237
# Forecasting for day 12
# Forecasted value for day 12: 2017.6856493669131
# Forecasting for day 13
# Forecasted value for day 13: 2029.1728942850273
# Forecasting for day 14
# Forecasted value for day 14: 2040.5792976681673
# Forecasting for day 15
# Forecasted value for day 15: 2052.9970690243235
# Forecasting for day 16
# Forecasted value for day 16: 2065.5668146324974
# Forecasting for day 17
# Forecasted value for day 17: 2075.4181986503104
# Forecasting for day 18
# Forecasted value for day 18: 2080.757777398644
# Forecasting for day 19
# Forecasted value for day 19: 2072.3961416473144
# Forecasting for day 20
# Forecasted value for day 20: 2046.3118538043107
# Forecasting for day 21
# Forecasted value for day 21: 1903.1916091112325
# Forecasting for day 22
# Forecasted value for day 22: 1879.9745875508488
# Forecasting for day 23
# Forecasted value for day 23: 1857.0532696004334
# Forecasting for day 24
# Forecasted value for day 24: 1833.8854227517054
# Forecasting for day 25
# Forecasted value for day 25: 1809.5720646974078
# Forecasting for day 26
# Forecasted value for day 26: 1786.4606577261438
# Forecasting for day 27
# Forecasted value for day 27: 1763.341202481541
# Forecasting for day 28
# Forecasted value for day 28: 1754.4887568837469
# Forecasting for day 29
# Forecasted value for day 29: 1746.975916318644
# Forecasting for day 30
# Forecasted value for day 30: 1740.839184330066
# Forecasting for day 31
# Forecasted value for day 31: 1736.1454866687423
# Forecasting for day 32
# Forecasted value for day 32: 1732.6958481943607
# Forecasting for day 33
# Forecasted value for day 33: 1730.2477368441182
# Forecasting for day 34
# Forecasted value for day 34: 1728.5883014416013
# Forecasting for day 35
# Forecasted value for day 35: 1727.4179380022674
# Forecasting for day 36
# Forecasted value for day 36: 1726.334271328215
# Forecasting for day 37
# Forecasted value for day 37: 1724.7857849721024
# Forecasting for day 38
# Forecasted value for day 38: 1722.0520833010505
# Forecasting for day 39
# Forecasted value for day 39: 1717.1559968152428
# Forecasting for day 40
# Forecasted value for day 40: 1709.0118085845522
# Forecasting for day 41
# Forecasted value for day 41: 1696.287978297285
# Forecasting for day 42
# Forecasted value for day 42: 1688.5584437113282
# Forecasting for day 43
# Forecasted value for day 43: 1680.4613727561052
# Forecasting for day 44
# Forecasted value for day 44: 1672.2009405403157
# Forecasting for day 45
# Forecasted value for day 45: 1664.1084317481502
# Forecasting for day 46
# Forecasted value for day 46: 1656.6859459225248
# Forecasting for day 47
# Forecasted value for day 47: 1650.2069644264268
# Forecasting for day 48
# Forecasted value for day 48: 1645.6858506600447
# Forecasting for day 49
# Forecasted value for day 49: 1641.6204337180263
# Forecasting for day 50
# Forecasted value for day 50: 1637.9716724072573
# Forecasting for day 51
# Forecasted value for day 51: 1634.7225666515017
# Forecasting for day 52
# Forecasted value for day 52: 1631.8739330549797
# Forecasting for day 53
# Forecasted value for day 53: 1629.4024057374352
# Forecasting for day 54
# Forecasted value for day 54: 1627.2884947100392
# Forecasting for day 55
# Forecasted value for day 55: 1625.3580592667354
# Forecasting for day 56
# Forecasted value for day 56: 1623.546621644036
# Forecasting for day 57
# Forecasted value for day 57: 1621.771763239899
# Forecasting for day 58
# Forecasted value for day 58: 1619.9374047101087
# Forecasting for day 59
# Forecasted value for day 59: 1617.9511569624237
# Forecasting for day 60
# Forecasted value for day 60: 1615.760068048018
# Forecasting for day 90
# Forecasting for day 1
# Forecasted value for day 1: 2094.9517070115294
# Forecasting for day 2
# Forecasted value for day 2: 2053.831435148887
# Forecasting for day 3
# Forecasted value for day 3: 2029.9202801718632
# Forecasting for day 4
# Forecasted value for day 4: 2007.3400005567933
# Forecasting for day 5
# Forecasted value for day 5: 1997.0406690236246
# Forecasting for day 6
# Forecasted value for day 6: 1991.3945169226818
# Forecasting for day 7
# Forecasted value for day 7: 1987.4831930698394
# Forecasting for day 8
# Forecasted value for day 8: 1985.6616970370433
# Forecasting for day 9
# Forecasted value for day 9: 1989.0452772451695
# Forecasting for day 10
# Forecasted value for day 10: 1997.0842818127703
# Forecasting for day 11
# Forecasted value for day 11: 2007.516751269237
# Forecasting for day 12
# Forecasted value for day 12: 2017.6856493669131
# Forecasting for day 13
# Forecasted value for day 13: 2029.1728942850273
# Forecasting for day 14
# Forecasted value for day 14: 2040.5792976681673
# Forecasting for day 15
# Forecasted value for day 15: 2052.9970690243235
# Forecasting for day 16
# Forecasted value for day 16: 2065.5668146324974
# Forecasting for day 17
# Forecasted value for day 17: 2075.4181986503104
# Forecasting for day 18
# Forecasted value for day 18: 2080.757777398644
# Forecasting for day 19
# Forecasted value for day 19: 2072.3961416473144
# Forecasting for day 20
# Forecasted value for day 20: 2046.3118538043107
# Forecasting for day 21
# Forecasted value for day 21: 1903.1916091112325
# Forecasting for day 22
# Forecasted value for day 22: 1879.9745875508488
# Forecasting for day 23
# Forecasted value for day 23: 1857.0532696004334
# Forecasting for day 24
# Forecasted value for day 24: 1833.8854227517054
# Forecasting for day 25
# Forecasted value for day 25: 1809.5720646974078
# Forecasting for day 26
# Forecasted value for day 26: 1786.4606577261438
# Forecasting for day 27
# Forecasted value for day 27: 1763.341202481541
# Forecasting for day 28
# Forecasted value for day 28: 1754.4887568837469
# Forecasting for day 29
# Forecasted value for day 29: 1746.975916318644
# Forecasting for day 30
# Forecasted value for day 30: 1740.839184330066
# Forecasting for day 31
# Forecasted value for day 31: 1736.1454866687423
# Forecasting for day 32
# Forecasted value for day 32: 1732.6958481943607
# Forecasting for day 33
# Forecasted value for day 33: 1730.2477368441182
# Forecasting for day 34
# Forecasted value for day 34: 1728.5883014416013
# Forecasting for day 35
# Forecasted value for day 35: 1727.4179380022674
# Forecasting for day 36
# Forecasted value for day 36: 1726.334271328215
# Forecasting for day 37
# Forecasted value for day 37: 1724.7857849721024
# Forecasting for day 38
# Forecasted value for day 38: 1722.0520833010505
# Forecasting for day 39
# Forecasted value for day 39: 1717.1559968152428
# Forecasting for day 40
# Forecasted value for day 40: 1709.0118085845522
# Forecasting for day 41
# Forecasted value for day 41: 1696.287978297285
# Forecasting for day 42
# Forecasted value for day 42: 1688.5584437113282
# Forecasting for day 43
# Forecasted value for day 43: 1680.4613727561052
# Forecasting for day 44
# Forecasted value for day 44: 1672.2009405403157
# Forecasting for day 45
# Forecasted value for day 45: 1664.1084317481502
# Forecasting for day 46
# Forecasted value for day 46: 1656.6859459225248
# Forecasting for day 47
# Forecasted value for day 47: 1650.2069644264268
# Forecasting for day 48
# Forecasted value for day 48: 1645.6858506600447
# Forecasting for day 49
# Forecasted value for day 49: 1641.6204337180263
# Forecasting for day 50
# Forecasted value for day 50: 1637.9716724072573
# Forecasting for day 51
# Forecasted value for day 51: 1634.7225666515017
# Forecasting for day 52
# Forecasted value for day 52: 1631.8739330549797
# Forecasting for day 53
# Forecasted value for day 53: 1629.4024057374352
# Forecasting for day 54
# Forecasted value for day 54: 1627.2884947100392
# Forecasting for day 55
# Forecasted value for day 55: 1625.3580592667354
# Forecasting for day 56
# Forecasted value for day 56: 1623.546621644036
# Forecasting for day 57
# Forecasted value for day 57: 1621.771763239899
# Forecasting for day 58
# Forecasted value for day 58: 1619.9374047101087
# Forecasting for day 59
# Forecasted value for day 59: 1617.9511569624237
# Forecasting for day 60
# Forecasted value for day 60: 1615.760068048018
# Forecasting for day 61
# Forecasted value for day 61: 1613.4074617400615
# Forecasting for day 62
# Forecasted value for day 62: 1611.0911897568903
# Forecasting for day 63
# Forecasted value for day 63: 1608.704820366471
# Forecasting for day 64
# Forecasted value for day 64: 1606.2990631817038
# Forecasting for day 65
# Forecasted value for day 65: 1603.943476304056
# Forecasting for day 66
# Forecasted value for day 66: 1601.7124023459542
# Forecasting for day 67
# Forecasted value for day 67: 1599.6644858768864
# Forecasting for day 68
# Forecasted value for day 68: 1597.846750125899
# Forecasting for day 69
# Forecasted value for day 69: 1596.1759705727427
# Forecasting for day 70
# Forecasted value for day 70: 1594.6501422798456
# Forecasting for day 71
# Forecasted value for day 71: 1593.2640331598375
# Forecasting for day 72
# Forecasted value for day 72: 1592.0086001408715
# Forecasting for day 73
# Forecasted value for day 73: 1590.8695622529976
# Forecasting for day 74
# Forecasted value for day 74: 1589.8298069762654
# Forecasting for day 75
# Forecasted value for day 75: 1588.8612541810444
# Forecasting for day 76
# Forecasted value for day 76: 1587.9508245692246
# Forecasting for day 77
# Forecasted value for day 77: 1587.085266685152
# Forecasting for day 78
# Forecasted value for day 78: 1586.251470391087
# Forecasting for day 79
# Forecasted value for day 79: 1585.4375441354775
# Forecasting for day 80
# Forecasted value for day 80: 1584.6348322050503
# Forecasting for day 81
# Forecasted value for day 81: 1583.839179842309
# Forecasting for day 82
# Forecasted value for day 82: 1583.0513552725643
# Forecasting for day 83
# Forecasted value for day 83: 1582.2707716392551
# Forecasting for day 84
# Forecasted value for day 84: 1581.5025222400957
# Forecasting for day 85
# Forecasted value for day 85: 1580.7540776901787
# Forecasting for day 86
# Forecasted value for day 86: 1580.033531776187
# Forecasting for day 87
# Forecasted value for day 87: 1579.3476741557586
# Forecasting for day 88
# Forecasted value for day 88: 1578.7004265970756
# Forecasting for day 89
# Forecasted value for day 89: 1578.0911474659738
# Forecasting for day 90
# Forecasted value for day 90: 1577.520936678854

# %%
# Create df_forecast with index
df_forecast = forecast_next_90_days
df_forecast.index = pd.date_range(start=df_filtered.index.max() + dt.timedelta(days=1), periods=len(df_forecast))

# Plot the overall with connection to forecast
plt.figure(figsize=(15, 7))
plt.plot(df_filtered['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.plot(forecast_test_valid, label='Test Forecast')
plt.plot(df_forecast['Close'], label='Forecast')
plt.title('ETH/USD Close price')
# Out:
# Text(0.5, 1.0, 'ETH/USD Close price')

# %% [markdown]
# ## Step #6: Model Evaluation

# %%
# Calculate the Model's RMSE, MAPE, and SMAPE
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics
rmse, mape, smape = calculate_metrics(test['Close'], forecast_test_valid)
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}")
print(f"SMAPE: {smape:.2f}")
# Out:
# RMSE: 355.24
# MAPE: 11.52
# SMAPE: 12.72
