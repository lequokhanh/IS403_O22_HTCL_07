# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../../Dataset/DOGE-USD.csv')
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2018-03-01  0.006042  0.006320  0.005945  0.006215   0.006215  15518400
# 1  2018-03-02  0.006174  0.006232  0.005447  0.005482   0.005482  22498100
# 2  2018-03-03  0.005494  0.005756  0.005181  0.005301   0.005301  21545000
# 3  2018-03-04  0.005234  0.005502  0.005164  0.005502   0.005502  12133500
# 4  2018-03-05  0.005462  0.005535  0.005157  0.005218   0.005218  13627700

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2018-03-01  0.006042  0.006320  0.005945  0.006215   0.006215  15518400
# 2018-03-02  0.006174  0.006232  0.005447  0.005482   0.005482  22498100
# 2018-03-03  0.005494  0.005756  0.005181  0.005301   0.005301  21545000
# 2018-03-04  0.005234  0.005502  0.005164  0.005502   0.005502  12133500
# 2018-03-05  0.005462  0.005535  0.005157  0.005218   0.005218  13627700

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2018-10-02  0.005824  0.000241         0.006478         0.005382  0.005966  0.005739
# 2018-10-03  0.005704  0.000213         0.006358         0.005417  0.005981  0.005736
# 2018-10-04  0.005645  0.000183         0.006322         0.005400  0.005979  0.005727
# 2018-10-05  0.005669  0.000159         0.006282         0.005391  0.005973  0.005722
# 2018-10-06  0.005545  0.000129         0.006110         0.005464  0.005921  0.005705
#                Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# Date
# 2018-10-02  0.005824  0.000241         0.006478         0.005382  0.005966  0.005739
# 2018-10-03  0.005704  0.000213         0.006358         0.005417  0.005981  0.005736
# 2018-10-04  0.005645  0.000183         0.006322         0.005400  0.005979  0.005727
# 2018-10-05  0.005669  0.000159         0.006282         0.005391  0.005973  0.005722
# 2018-10-06  0.005545  0.000129         0.006110         0.005464  0.005921  0.005705

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (2070, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.80)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1656, 6) (414, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1649, 7, 6) (1649,)
# (407, 7, 6) (407,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1649, 7, 6) (1649,)
# (407, 7, 6) (407,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
model.add(Dense(1))

# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# 26/26 [==============================] - 7s 18ms/step - loss: 0.0025 - val_loss: 1.8456e-04
# Epoch 2/100
# 26/26 [==============================] - 0s 8ms/step - loss: 8.3742e-04 - val_loss: 1.6692e-04
# Epoch 3/100
# 26/26 [==============================] - 0s 6ms/step - loss: 7.6140e-04 - val_loss: 1.5222e-04
# Epoch 4/100
# 26/26 [==============================] - 0s 6ms/step - loss: 6.8005e-04 - val_loss: 1.4130e-04
# Epoch 5/100
# 26/26 [==============================] - 0s 6ms/step - loss: 6.4157e-04 - val_loss: 1.3231e-04
# Epoch 6/100
# 26/26 [==============================] - 0s 6ms/step - loss: 5.7882e-04 - val_loss: 1.3429e-04
# Epoch 7/100
# 26/26 [==============================] - 0s 6ms/step - loss: 5.5969e-04 - val_loss: 1.2160e-04
# Epoch 8/100
# 26/26 [==============================] - 0s 6ms/step - loss: 5.2502e-04 - val_loss: 1.1249e-04
# Epoch 9/100
# 26/26 [==============================] - 0s 7ms/step - loss: 5.2654e-04 - val_loss: 1.7606e-04
# Epoch 10/100
# 26/26 [==============================] - 0s 6ms/step - loss: 5.5167e-04 - val_loss: 1.4222e-04
# Epoch 11/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.7260e-04 - val_loss: 1.0157e-04
# Epoch 12/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.5829e-04 - val_loss: 9.5451e-05
# Epoch 13/100
# 26/26 [==============================] - 0s 10ms/step - loss: 4.5455e-04 - val_loss: 1.4640e-04
# Epoch 14/100
# 26/26 [==============================] - 0s 8ms/step - loss: 4.6445e-04 - val_loss: 2.2250e-04
# Epoch 15/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.3410e-04 - val_loss: 2.5467e-04
# Epoch 16/100
# 26/26 [==============================] - 0s 6ms/step - loss: 4.6582e-04 - val_loss: 1.1685e-04
# Epoch 17/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.1447e-04 - val_loss: 9.9057e-05
# Epoch 18/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.6065e-04 - val_loss: 1.4846e-04
# Epoch 19/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.2530e-04 - val_loss: 8.1062e-05
# Epoch 20/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.1115e-04 - val_loss: 1.3875e-04
# Epoch 21/100
# 26/26 [==============================] - 0s 6ms/step - loss: 4.1571e-04 - val_loss: 8.0344e-05
# Epoch 22/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.3073e-04 - val_loss: 1.0058e-04
# Epoch 23/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.7983e-04 - val_loss: 1.1734e-04
# Epoch 24/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.7572e-04 - val_loss: 1.0378e-04
# Epoch 25/100
# 26/26 [==============================] - 0s 6ms/step - loss: 4.3006e-04 - val_loss: 7.8517e-05
# Epoch 26/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7866e-04 - val_loss: 8.0588e-05
# Epoch 27/100
# 26/26 [==============================] - 0s 6ms/step - loss: 4.2558e-04 - val_loss: 1.5696e-04
# Epoch 28/100
# 26/26 [==============================] - 0s 7ms/step - loss: 4.1965e-04 - val_loss: 7.3935e-05
# Epoch 29/100
# 26/26 [==============================] - 0s 7ms/step - loss: 3.6720e-04 - val_loss: 9.3092e-05
# Epoch 30/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7105e-04 - val_loss: 1.0369e-04
# Epoch 31/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7741e-04 - val_loss: 8.0328e-05
# Epoch 32/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.9568e-04 - val_loss: 1.0684e-04
# Epoch 33/100
# 26/26 [==============================] - 0s 6ms/step - loss: 4.1661e-04 - val_loss: 1.4693e-04
# Epoch 34/100
# 26/26 [==============================] - 0s 6ms/step - loss: 4.0964e-04 - val_loss: 1.0727e-04
# Epoch 35/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.6599e-04 - val_loss: 9.9557e-05
# Epoch 36/100
# 26/26 [==============================] - 0s 7ms/step - loss: 3.5657e-04 - val_loss: 1.2154e-04
# Epoch 37/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7336e-04 - val_loss: 7.2160e-05
# Epoch 38/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7199e-04 - val_loss: 7.5524e-05
# Epoch 39/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.7321e-04 - val_loss: 8.8625e-05
# Epoch 40/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.9061e-04 - val_loss: 7.1086e-05
# Epoch 41/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7889e-04 - val_loss: 9.1081e-05
# Epoch 42/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.2495e-04 - val_loss: 8.2241e-05
# Epoch 43/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.6380e-04 - val_loss: 9.0887e-05
# Epoch 44/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.5818e-04 - val_loss: 8.5732e-05
# Epoch 45/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.5887e-04 - val_loss: 8.6740e-05
# Epoch 46/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.1451e-04 - val_loss: 7.3159e-05
# Epoch 47/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.1148e-04 - val_loss: 9.9331e-05
# Epoch 48/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7811e-04 - val_loss: 1.3257e-04
# Epoch 49/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.2576e-04 - val_loss: 2.2631e-04
# Epoch 50/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.9673e-04 - val_loss: 1.5467e-04
# Epoch 51/100
# 26/26 [==============================] - 0s 5ms/step - loss: 4.5202e-04 - val_loss: 1.6844e-04
# Epoch 52/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.9286e-04 - val_loss: 1.6978e-04
# Epoch 53/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.5556e-04 - val_loss: 8.1952e-05
# Epoch 54/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4569e-04 - val_loss: 8.5606e-05
# Epoch 55/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.5853e-04 - val_loss: 7.9721e-05
# Epoch 56/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.5847e-04 - val_loss: 1.3410e-04
# Epoch 57/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.5199e-04 - val_loss: 1.4790e-04
# Epoch 58/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7947e-04 - val_loss: 7.3630e-05
# Epoch 59/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.8237e-04 - val_loss: 1.9701e-04
# Epoch 60/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.6742e-04 - val_loss: 9.7976e-05
# Epoch 61/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.6232e-04 - val_loss: 7.0908e-05
# Epoch 62/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.6810e-04 - val_loss: 1.5433e-04
# Epoch 63/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.7107e-04 - val_loss: 9.9846e-05
# Epoch 64/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4833e-04 - val_loss: 1.0183e-04
# Epoch 65/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.3753e-04 - val_loss: 7.4016e-05
# Epoch 66/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.6444e-04 - val_loss: 1.5115e-04
# Epoch 67/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4970e-04 - val_loss: 8.0428e-05
# Epoch 68/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.5906e-04 - val_loss: 7.9704e-05
# Epoch 69/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.5873e-04 - val_loss: 1.2007e-04
# Epoch 70/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4777e-04 - val_loss: 8.5655e-05
# Epoch 71/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4054e-04 - val_loss: 9.4152e-05
# Epoch 72/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.3440e-04 - val_loss: 1.3697e-04
# Epoch 73/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.8806e-04 - val_loss: 2.1688e-04
# Epoch 74/100
# 26/26 [==============================] - 0s 7ms/step - loss: 3.4283e-04 - val_loss: 8.5846e-05
# Epoch 75/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.4988e-04 - val_loss: 7.2174e-05
# Epoch 76/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4275e-04 - val_loss: 7.7713e-05
# Epoch 77/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4936e-04 - val_loss: 8.2757e-05
# Epoch 78/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.5281e-04 - val_loss: 9.6380e-05
# Epoch 79/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4426e-04 - val_loss: 9.8994e-05
# Epoch 80/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.4777e-04 - val_loss: 9.0637e-05
# Epoch 81/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.3182e-04 - val_loss: 7.1017e-05
# Epoch 82/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.4689e-04 - val_loss: 8.8720e-05
# Epoch 83/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.2602e-04 - val_loss: 1.0561e-04
# Epoch 84/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.4199e-04 - val_loss: 7.5782e-05
# Epoch 85/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.4988e-04 - val_loss: 7.2186e-05
# Epoch 86/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.1767e-04 - val_loss: 1.0558e-04
# Epoch 87/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.2627e-04 - val_loss: 8.5290e-05
# Epoch 88/100
# 26/26 [==============================] - 0s 7ms/step - loss: 3.2650e-04 - val_loss: 2.0263e-04
# Epoch 89/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.4141e-04 - val_loss: 7.3328e-05
# Epoch 90/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.1487e-04 - val_loss: 9.2201e-05
# Epoch 91/100
# 26/26 [==============================] - 0s 7ms/step - loss: 3.2444e-04 - val_loss: 7.0932e-05
# Epoch 92/100
# 26/26 [==============================] - 0s 7ms/step - loss: 3.4101e-04 - val_loss: 1.2786e-04
# Epoch 93/100
# 26/26 [==============================] - 0s 11ms/step - loss: 3.2859e-04 - val_loss: 8.0318e-05
# Epoch 94/100
# 26/26 [==============================] - 0s 10ms/step - loss: 3.1336e-04 - val_loss: 8.3301e-05
# Epoch 95/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.0699e-04 - val_loss: 7.8341e-05
# Epoch 96/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.5224e-04 - val_loss: 1.3845e-04
# Epoch 97/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.5929e-04 - val_loss: 7.6183e-05
# Epoch 98/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.3482e-04 - val_loss: 1.3962e-04
# Epoch 99/100
# 26/26 [==============================] - 0s 6ms/step - loss: 3.3038e-04 - val_loss: 8.4300e-05
# Epoch 100/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.3004e-04 - val_loss: 1.9910e-04

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('DOGE/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (414, 7, 6)
# 13/13 [==============================] - 0s 2ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.24103243 0.26288379 0.23926162 0.58421003 0.32771357 0.33664058]
#   [0.24523301 0.26491795 0.24174481 0.58444537 0.33095653 0.33879269]
#   [0.23919121 0.26410255 0.24257393 0.58827836 0.33369168 0.33989533]
#   [0.23733681 0.26252351 0.24350212 0.58946971 0.33515258 0.34063376]
#   [0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 1: [[0.1677282]]
# x_pred_input of day 2:
# [[[0.24523301 0.26491795 0.24174481 0.58444537 0.33095653 0.33879269]
#   [0.23919121 0.26410255 0.24257393 0.58827836 0.33369168 0.33989533]
#   [0.23733681 0.26252351 0.24350212 0.58946971 0.33515258 0.34063376]
#   [0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24323986 0.25529864 0.24135698 0.6103678  0.33669974 0.3417338 ]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 2: [[0.1741524]]
# x_pred_input of day 3:
# [[[0.23919121 0.26410255 0.24257393 0.58827836 0.33369168 0.33989533]
#   [0.23733681 0.26252351 0.24350212 0.58946971 0.33515258 0.34063376]
#   [0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24323986 0.25529864 0.24135698 0.6103678  0.33669974 0.3417338 ]
#   [0.25264242 0.25988897 0.24230383 0.61572016 0.3392686  0.34443651]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 3: [[0.18150635]]
# x_pred_input of day 4:
# [[[0.23733681 0.26252351 0.24350212 0.58946971 0.33515258 0.34063376]
#   [0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24323986 0.25529864 0.24135698 0.6103678  0.33669974 0.3417338 ]
#   [0.25264242 0.25988897 0.24230383 0.61572016 0.3392686  0.34443651]
#   [0.26340576 0.26699151 0.24677825 0.61417007 0.34171517 0.3483863 ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 4: [[0.18991484]]
# x_pred_input of day 5:
# [[[0.23126134 0.25889279 0.24320575 0.59378553 0.33510155 0.34045265]
#   [0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24323986 0.25529864 0.24135698 0.6103678  0.33669974 0.3417338 ]
#   [0.25264242 0.25988897 0.24230383 0.61572016 0.3392686  0.34443651]
#   [0.26340576 0.26699151 0.24677825 0.61417007 0.34171517 0.3483863 ]
#   [0.27571254 0.27651938 0.25294167 0.61313264 0.34553485 0.35368012]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 5: [[0.1986707]]
# x_pred_input of day 6:
# [[[0.23066419 0.25560565 0.24241379 0.5991474  0.33494072 0.34020531]
#   [0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24323986 0.25529864 0.24135698 0.6103678  0.33669974 0.3417338 ]
#   [0.25264242 0.25988897 0.24230383 0.61572016 0.3392686  0.34443651]
#   [0.26340576 0.26699151 0.24677825 0.61417007 0.34171517 0.3483863 ]
#   [0.27571254 0.27651938 0.25294167 0.61313264 0.34553485 0.35368012]
#   [0.28852775 0.28801608 0.26206906 0.60755288 0.35017558 0.36026105]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 6: [[0.20787571]]
# x_pred_input of day 7:
# [[[0.23222147 0.25337615 0.24087165 0.60650803 0.33523974 0.34019921]
#   [0.24323986 0.25529864 0.24135698 0.6103678  0.33669974 0.3417338 ]
#   [0.25264242 0.25988897 0.24230383 0.61572016 0.3392686  0.34443651]
#   [0.26340576 0.26699151 0.24677825 0.61417007 0.34171517 0.3483863 ]
#   [0.27571254 0.27651938 0.25294167 0.61313264 0.34553485 0.35368012]
#   [0.28852775 0.28801608 0.26206906 0.60755288 0.35017558 0.36026105]
#   [0.30200034 0.30115346 0.27280893 0.6019837  0.35572354 0.36809839]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 7: [[0.21720564]]
# x_pred_input of day 8:
# [[[0.24323986 0.25529864 0.24135698 0.6103678  0.33669974 0.3417338 ]
#   [0.25264242 0.25988897 0.24230383 0.61572016 0.3392686  0.34443651]
#   [0.26340576 0.26699151 0.24677825 0.61417007 0.34171517 0.3483863 ]
#   [0.27571254 0.27651938 0.25294167 0.61313264 0.34553485 0.35368012]
#   [0.28852775 0.28801608 0.26206906 0.60755288 0.35017558 0.36026105]
#   [0.30200034 0.30115346 0.27280893 0.6019837  0.35572354 0.36809839]
#   [0.31565576 0.31549028 0.28450052 0.59798527 0.36144855 0.37709803]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 8: [[0.22657523]]
# x_pred_input of day 9:
# [[[0.25264242 0.25988897 0.24230383 0.61572016 0.3392686  0.34443651]
#   [0.26340576 0.26699151 0.24677825 0.61417007 0.34171517 0.3483863 ]
#   [0.27571254 0.27651938 0.25294167 0.61313264 0.34553485 0.35368012]
#   [0.28852775 0.28801608 0.26206906 0.60755288 0.35017558 0.36026105]
#   [0.30200034 0.30115346 0.27280893 0.6019837  0.35572354 0.36809839]
#   [0.31565576 0.31549028 0.28450052 0.59798527 0.36144855 0.37709803]
#   [0.32936922 0.33062368 0.29860026 0.58797127 0.36820454 0.3871574 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 9: [[0.23624726]]
# x_pred_input of day 10:
# [[[0.26340576 0.26699151 0.24677825 0.61417007 0.34171517 0.3483863 ]
#   [0.27571254 0.27651938 0.25294167 0.61313264 0.34553485 0.35368012]
#   [0.28852775 0.28801608 0.26206906 0.60755288 0.35017558 0.36026105]
#   [0.30200034 0.30115346 0.27280893 0.6019837  0.35572354 0.36809839]
#   [0.31565576 0.31549028 0.28450052 0.59798527 0.36144855 0.37709803]
#   [0.32936922 0.33062368 0.29860026 0.58797127 0.36820454 0.3871574 ]
#   [0.34352534 0.34636303 0.31380177 0.57720611 0.37492433 0.39823744]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 10: [[0.24623947]]
# x_pred_input of day 11:
# [[[0.27571254 0.27651938 0.25294167 0.61313264 0.34553485 0.35368012]
#   [0.28852775 0.28801608 0.26206906 0.60755288 0.35017558 0.36026105]
#   [0.30200034 0.30115346 0.27280893 0.6019837  0.35572354 0.36809839]
#   [0.31565576 0.31549028 0.28450052 0.59798527 0.36144855 0.37709803]
#   [0.32936922 0.33062368 0.29860026 0.58797127 0.36820454 0.3871574 ]
#   [0.34352534 0.34636303 0.31380177 0.57720611 0.37492433 0.39823744]
#   [0.35815009 0.36256111 0.33003292 0.56811939 0.38296617 0.41030644]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 11: [[0.25622538]]
# x_pred_input of day 12:
# [[[0.28852775 0.28801608 0.26206906 0.60755288 0.35017558 0.36026105]
#   [0.30200034 0.30115346 0.27280893 0.6019837  0.35572354 0.36809839]
#   [0.31565576 0.31549028 0.28450052 0.59798527 0.36144855 0.37709803]
#   [0.32936922 0.33062368 0.29860026 0.58797127 0.36820454 0.3871574 ]
#   [0.34352534 0.34636303 0.31380177 0.57720611 0.37492433 0.39823744]
#   [0.35815009 0.36256111 0.33003292 0.56811939 0.38296617 0.41030644]
#   [0.37276561 0.37893079 0.34672491 0.56226137 0.39134598 0.42326894]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 12: [[0.26608053]]
# x_pred_input of day 13:
# [[[0.30200034 0.30115346 0.27280893 0.6019837  0.35572354 0.36809839]
#   [0.31565576 0.31549028 0.28450052 0.59798527 0.36144855 0.37709803]
#   [0.32936922 0.33062368 0.29860026 0.58797127 0.36820454 0.3871574 ]
#   [0.34352534 0.34636303 0.31380177 0.57720611 0.37492433 0.39823744]
#   [0.35815009 0.36256111 0.33003292 0.56811939 0.38296617 0.41030644]
#   [0.37276561 0.37893079 0.34672491 0.56226137 0.39134598 0.42326894]
#   [0.38718976 0.39518165 0.36414613 0.55650053 0.40075316 0.43701309]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 13: [[0.2758517]]
# x_pred_input of day 14:
# [[[0.31565576 0.31549028 0.28450052 0.59798527 0.36144855 0.37709803]
#   [0.32936922 0.33062368 0.29860026 0.58797127 0.36820454 0.3871574 ]
#   [0.34352534 0.34636303 0.31380177 0.57720611 0.37492433 0.39823744]
#   [0.35815009 0.36256111 0.33003292 0.56811939 0.38296617 0.41030644]
#   [0.37276561 0.37893079 0.34672491 0.56226137 0.39134598 0.42326894]
#   [0.38718976 0.39518165 0.36414613 0.55650053 0.40075316 0.43701309]
#   [0.40149098 0.41111137 0.38236187 0.54924232 0.41130424 0.45144725]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 14: [[0.28562042]]
# x_pred_input of day 15:
# [[[0.32936922 0.33062368 0.29860026 0.58797127 0.36820454 0.3871574 ]
#   [0.34352534 0.34636303 0.31380177 0.57720611 0.37492433 0.39823744]
#   [0.35815009 0.36256111 0.33003292 0.56811939 0.38296617 0.41030644]
#   [0.37276561 0.37893079 0.34672491 0.56226137 0.39134598 0.42326894]
#   [0.38718976 0.39518165 0.36414613 0.55650053 0.40075316 0.43701309]
#   [0.40149098 0.41111137 0.38236187 0.54924232 0.41130424 0.45144725]
#   [0.41578863 0.42660671 0.40058757 0.54624686 0.42128823 0.46650523]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 15: [[0.29534987]]
# x_pred_input of day 16:
# [[[0.34352534 0.34636303 0.31380177 0.57720611 0.37492433 0.39823744]
#   [0.35815009 0.36256111 0.33003292 0.56811939 0.38296617 0.41030644]
#   [0.37276561 0.37893079 0.34672491 0.56226137 0.39134598 0.42326894]
#   [0.38718976 0.39518165 0.36414613 0.55650053 0.40075316 0.43701309]
#   [0.40149098 0.41111137 0.38236187 0.54924232 0.41130424 0.45144725]
#   [0.41578863 0.42660671 0.40058757 0.54624686 0.42128823 0.46650523]
#   [0.43002878 0.4415651  0.41908708 0.5444448  0.43168374 0.48211956]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 16: [[0.3051587]]
# x_pred_input of day 17:
# [[[0.35815009 0.36256111 0.33003292 0.56784622 0.38296617 0.41030644]
#   [0.37276561 0.37893079 0.34672491 0.56199102 0.39134598 0.42326894]
#   [0.38718976 0.39518165 0.36414613 0.55623295 0.40075316 0.43701309]
#   [0.40149098 0.41111137 0.38236187 0.54897823 0.41130424 0.45144725]
#   [0.41578863 0.42660671 0.40058757 0.54598421 0.42128823 0.46650523]
#   [0.43002878 0.4415651  0.41908708 0.54418301 0.43168374 0.48211956]
#   [0.44438514 0.45597284 0.43726102 0.54636195 0.44325468 0.49825351]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 17: [[0.31484282]]
# x_pred_input of day 18:
# [[[0.37276561 0.37893079 0.34672491 0.54899989 0.39134598 0.42326894]
#   [0.38718976 0.39518165 0.36414613 0.54337492 0.40075316 0.43701309]
#   [0.40149098 0.41111137 0.38236187 0.53628791 0.41130424 0.45144725]
#   [0.41578863 0.42660671 0.40058757 0.53336309 0.42128823 0.46650523]
#   [0.43002878 0.4415651  0.41908708 0.53160354 0.43168374 0.48211956]
#   [0.44438514 0.45597284 0.43726102 0.5337321  0.44325468 0.49825351]
#   [0.45855895 0.46972133 0.45501287 0.53920253 0.45617706 0.51483207]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 18: [[0.32433113]]
# x_pred_input of day 19:
# [[[0.38718976 0.39518165 0.36414613 0.53134065 0.40075316 0.43701309]
#   [0.40149098 0.41111137 0.38236187 0.5244106  0.41130424 0.45144725]
#   [0.41578863 0.42660671 0.40058757 0.52155056 0.42128823 0.46650523]
#   [0.43002878 0.4415651  0.41908708 0.51982997 0.43168374 0.48211956]
#   [0.44438514 0.45597284 0.43726102 0.5219114  0.44325468 0.49825351]
#   [0.45855895 0.46972133 0.45501287 0.52726066 0.45617706 0.51483207]
#   [0.47244619 0.48269675 0.47166533 0.53764724 0.4695405  0.53177284]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 19: [[0.33374402]]
# x_pred_input of day 20:
# [[[0.40149098 0.41111137 0.38236187 0.51313637 0.41130424 0.45144725]
#   [0.41578863 0.42660671 0.40058757 0.51033782 0.42128823 0.46650523]
#   [0.43002878 0.4415651  0.41908708 0.50865423 0.43168374 0.48211956]
#   [0.44438514 0.45597284 0.43726102 0.5106909  0.44325468 0.49825351]
#   [0.45855895 0.46972133 0.45501287 0.51592517 0.45617706 0.51483207]
#   [0.47244619 0.48269675 0.47166533 0.52608844 0.4695405  0.53177284]
#   [0.48622302 0.49488014 0.48729779 0.54017762 0.482842   0.5490259 ]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 20: [[0.34327176]]
# x_pred_input of day 21:
# [[[0.41578863 0.42660671 0.40058757 0.49946879 0.42128823 0.46650523]
#   [0.43002878 0.4415651  0.41908708 0.49782105 0.43168374 0.48211956]
#   [0.44438514 0.45597284 0.43726102 0.49981435 0.44325468 0.49825351]
#   [0.45855895 0.46972133 0.45501287 0.50493714 0.45617706 0.51483207]
#   [0.47244619 0.48269675 0.47166533 0.51488396 0.4695405  0.53177284]
#   [0.48622302 0.49488014 0.48729779 0.52867307 0.482842   0.5490259 ]
#   [0.50016797 0.50636273 0.50187667 0.54605531 0.49758099 0.566585  ]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 21: [[0.35280782]]
# x_pred_input of day 22:
# [[[0.43002878 0.4415651  0.41908708 0.48743083 0.43168374 0.48211956]
#   [0.44438514 0.45597284 0.43726102 0.48938252 0.44325468 0.49825351]
#   [0.45855895 0.46972133 0.45501287 0.49439839 0.45617706 0.51483207]
#   [0.47244619 0.48269675 0.47166533 0.50413761 0.4695405  0.53177284]
#   [0.48622302 0.49488014 0.48729779 0.51763892 0.482842   0.5490259 ]
#   [0.50016797 0.50636273 0.50187667 0.53465837 0.49758099 0.566585  ]
#   [0.51412508 0.51716967 0.51627243 0.55240681 0.5128749  0.58442269]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 22: [[0.36275467]]
# x_pred_input of day 23:
# [[[0.44438514 0.45597284 0.43726102 0.47895542 0.44325468 0.49825351]
#   [0.45855895 0.46972133 0.45501287 0.48386442 0.45617706 0.51483207]
#   [0.47244619 0.48269675 0.47166533 0.49339613 0.4695405  0.53177284]
#   [0.48622302 0.49488014 0.48729779 0.50660977 0.482842   0.5490259 ]
#   [0.50016797 0.50636273 0.50187667 0.5232666  0.49758099 0.566585  ]
#   [0.51412508 0.51716967 0.51627243 0.54063687 0.5128749  0.58442269]
#   [0.52868344 0.52753367 0.53036937 0.55922407 0.52934049 0.60259649]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 23: [[0.3728809]]
# x_pred_input of day 24:
# [[[0.45855895 0.46972133 0.45501287 0.47359179 0.45617706 0.51483207]
#   [0.47244619 0.48269675 0.47166533 0.48292114 0.4695405  0.53177284]
#   [0.48622302 0.49488014 0.48729779 0.49585425 0.482842   0.5490259 ]
#   [0.50016797 0.50636273 0.50187667 0.51215745 0.49758099 0.566585  ]
#   [0.51412508 0.51716967 0.51627243 0.52915894 0.5128749  0.58442269]
#   [0.52868344 0.52753367 0.53036937 0.54735153 0.52934049 0.60259649]
#   [0.54350434 0.53752405 0.54429716 0.56638152 0.54675454 0.62111107]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 24: [[0.38300866]]
# x_pred_input of day 25:
# [[[0.47244619 0.48269675 0.47166533 0.47288021 0.4695405  0.53177284]
#   [0.48622302 0.49488014 0.48729779 0.48554441 0.482842   0.5490259 ]
#   [0.50016797 0.50636273 0.50187667 0.50150863 0.49758099 0.566585  ]
#   [0.51412508 0.51716967 0.51627243 0.51815663 0.5128749  0.58442269]
#   [0.52868344 0.52753367 0.53036937 0.53597095 0.52934049 0.60259649]
#   [0.54350434 0.53752405 0.54429716 0.55460527 0.54675454 0.62111107]
#   [0.55832747 0.54710863 0.55817893 0.57366081 0.56535725 0.6399343 ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 25: [[0.3927088]]
# x_pred_input of day 26:
# [[[0.48622302 0.49488014 0.48729779 0.47606397 0.482842   0.5490259 ]
#   [0.50016797 0.50636273 0.50187667 0.49171648 0.49758099 0.566585  ]
#   [0.51412508 0.51716967 0.51627243 0.50803942 0.5128749  0.58442269]
#   [0.52868344 0.52753367 0.53036937 0.52550591 0.52934049 0.60259649]
#   [0.54350434 0.53752405 0.54429716 0.54377639 0.54675454 0.62111107]
#   [0.55832747 0.54710863 0.55817893 0.56245986 0.56535725 0.6399343 ]
#   [0.57252475 0.55604789 0.57190582 0.58155858 0.58480142 0.6589493 ]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 26: [[0.40221927]]
# x_pred_input of day 27:
# [[[0.50016797 0.50636273 0.50187667 0.4824801  0.49758099 0.566585  ]
#   [0.51412508 0.51716967 0.51627243 0.49849643 0.5128749  0.58442269]
#   [0.52868344 0.52753367 0.53036937 0.51563483 0.52934049 0.60259649]
#   [0.54350434 0.53752405 0.54429716 0.53356211 0.54675454 0.62111107]
#   [0.55832747 0.54710863 0.55817893 0.55189463 0.56535725 0.6399343 ]
#   [0.57252475 0.55604789 0.57190582 0.5706346  0.58480142 0.6589493 ]
#   [0.58644439 0.56428291 0.5854809  0.58965151 0.60494874 0.678099  ]]]
# 1/1 [==============================] - 0s 15ms/step
# y_pred of day 27: [[0.41102314]]
# x_pred_input of day 28:
# [[[0.51412508 0.51716967 0.51627243 0.48997652 0.5128749  0.58442269]
#   [0.52868344 0.52753367 0.53036937 0.50682201 0.52934049 0.60259649]
#   [0.54350434 0.53752405 0.54429716 0.52444289 0.54675454 0.62111107]
#   [0.55832747 0.54710863 0.55817893 0.54246209 0.56535725 0.6399343 ]
#   [0.57252475 0.55604789 0.57190582 0.56088177 0.58480142 0.6589493 ]
#   [0.58644439 0.56428291 0.5854809  0.57957365 0.60494874 0.678099  ]
#   [0.59932987 0.57151184 0.59870666 0.59865326 0.62520225 0.69722602]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 28: [[0.4190606]]
# x_pred_input of day 29:
# [[[0.52868344 0.52753367 0.53036937 0.49903539 0.52934049 0.60259649]
#   [0.54350434 0.53752405 0.54429716 0.51638556 0.54675454 0.62111107]
#   [0.55832747 0.54710863 0.55817893 0.53412791 0.56535725 0.6399343 ]
#   [0.57252475 0.55604789 0.57190582 0.5522646  0.58480142 0.6589493 ]
#   [0.58644439 0.56428291 0.5854809  0.57066931 0.60494874 0.678099  ]
#   [0.59932987 0.57151184 0.59870666 0.58945579 0.62520225 0.69722602]
#   [0.6110936  0.57747912 0.6113749  0.60875743 0.64559006 0.71617572]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 29: [[0.42667416]]
# x_pred_input of day 30:
# [[[0.54350434 0.53752405 0.54429716 0.50897821 0.54675454 0.62111107]
#   [0.55832747 0.54710863 0.55817893 0.52646606 0.56535725 0.6399343 ]
#   [0.57252475 0.55604789 0.57190582 0.54434259 0.58480142 0.6589493 ]
#   [0.58644439 0.56428291 0.5854809  0.56248329 0.60494874 0.678099  ]
#   [0.59932987 0.57151184 0.59870666 0.58100028 0.62520225 0.69722602]
#   [0.6110936  0.57747912 0.6113749  0.60002505 0.64559006 0.71617572]
#   [0.62223693 0.58217366 0.62345206 0.61946645 0.66599949 0.73487828]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 30: [[0.43337744]]
# x_pred_input of day 31:
# [[[0.55832747 0.54710863 0.55817893 0.51989996 0.56535725 0.6399343 ]
#   [0.57252475 0.55604789 0.57190582 0.53755353 0.58480142 0.6589493 ]
#   [0.58644439 0.56428291 0.5854809  0.55546798 0.60494874 0.678099  ]
#   [0.59932987 0.57151184 0.59870666 0.57375403 0.62520225 0.69722602]
#   [0.6110936  0.57747912 0.6113749  0.59254152 0.64559006 0.71617572]
#   [0.62223693 0.58217366 0.62345206 0.61174044 0.66599949 0.73487828]
#   [0.63204795 0.58535313 0.63478539 0.63132712 0.68626696 0.753171  ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 31: [[0.43946362]]
# x_pred_input of day 32:
# [[[0.57252475 0.55604789 0.57190582 0.53153452 0.58480142 0.6589493 ]
#   [0.58644439 0.56428291 0.5854809  0.54924838 0.60494874 0.678099  ]
#   [0.59932987 0.57151184 0.59870666 0.56732968 0.62520225 0.69722602]
#   [0.6110936  0.57747912 0.6113749  0.58590681 0.64559006 0.71617572]
#   [0.62223693 0.58217366 0.62345206 0.60489076 0.66599949 0.73487828]
#   [0.63204795 0.58535313 0.63478539 0.62425812 0.68626696 0.753171  ]
#   [0.64095576 0.58699451 0.64527881 0.64402423 0.70631219 0.77096667]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 32: [[0.44501162]]
# x_pred_input of day 33:
# [[[0.58644439 0.56428291 0.5854809  0.54369888 0.60494874 0.678099  ]
#   [0.59932987 0.57151184 0.59870666 0.56159749 0.62520225 0.69722602]
#   [0.6110936  0.57747912 0.6113749  0.57998692 0.64559006 0.71617572]
#   [0.62223693 0.58217366 0.62345206 0.59877906 0.66599949 0.73487828]
#   [0.63204795 0.58535313 0.63478539 0.61795074 0.68626696 0.753171  ]
#   [0.64095576 0.58699451 0.64527881 0.63751713 0.70631219 0.77096667]
#   [0.6490759  0.58713755 0.65484931 0.65751324 0.72605298 0.78820252]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 33: [[0.4497977]]
# x_pred_input of day 34:
# [[[0.59932987 0.57151184 0.59870666 0.55674478 0.62520225 0.69722602]
#   [0.6110936  0.57747912 0.6113749  0.57497531 0.64559006 0.71617572]
#   [0.62223693 0.58217366 0.62345206 0.59360506 0.66599949 0.73487828]
#   [0.63204795 0.58535313 0.63478539 0.61261108 0.68626696 0.753171  ]
#   [0.64095576 0.58699451 0.64527881 0.6320084  0.70631219 0.77096667]
#   [0.6490759  0.58713755 0.65484931 0.65183173 0.72605298 0.78820252]
#   [0.65608086 0.58571632 0.66336882 0.67212568 0.74541551 0.804776  ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 34: [[0.45412636]]
# x_pred_input of day 35:
# [[[0.6110936  0.57747912 0.6113749  0.57051666 0.64559006 0.71617572]
#   [0.62223693 0.58217366 0.62345206 0.58900196 0.66599949 0.73487828]
#   [0.63204795 0.58535313 0.63478539 0.6078606  0.68626696 0.753171  ]
#   [0.64095576 0.58699451 0.64527881 0.6271075  0.70631219 0.77096667]
#   [0.6490759  0.58713755 0.65484931 0.64677711 0.72605298 0.78820252]
#   [0.65608086 0.58571632 0.66336882 0.66691369 0.74541551 0.804776  ]
#   [0.66241637 0.58285237 0.67082329 0.68745393 0.7643584  0.82065661]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 35: [[0.4578489]]
# x_pred_input of day 36:
# [[[0.62223693 0.58217366 0.62345206 0.58510012 0.66599949 0.73487828]
#   [0.63204795 0.58535313 0.63478539 0.60383383 0.68626696 0.753171  ]
#   [0.64095576 0.58699451 0.64527881 0.62295323 0.70631219 0.77096667]
#   [0.6490759  0.58713755 0.65484931 0.64249254 0.72605298 0.78820252]
#   [0.65608086 0.58571632 0.66336882 0.66249572 0.74541551 0.804776  ]
#   [0.66241637 0.58285237 0.67082329 0.68289989 0.7643584  0.82065661]
#   [0.66786474 0.57858147 0.67715869 0.70367363 0.78280602 0.83578635]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 36: [[0.46067992]]
# x_pred_input of day 37:
# [[[0.63204795 0.58535313 0.63478539 0.60080699 0.68626696 0.753171  ]
#   [0.64095576 0.58699451 0.64527881 0.61983055 0.70631219 0.77096667]
#   [0.6490759  0.58713755 0.65484931 0.63927192 0.72605298 0.78820252]
#   [0.65608086 0.58571632 0.66336882 0.65917483 0.74541551 0.804776  ]
#   [0.66241637 0.58285237 0.67082329 0.67947672 0.7643584  0.82065661]
#   [0.66786474 0.57858147 0.67715869 0.70014633 0.78280602 0.83578635]
#   [0.67200825 0.57280209 0.68228345 0.72112883 0.80065749 0.85005432]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 37: [[0.46245778]]
# x_pred_input of day 38:
# [[[0.64095576 0.58699451 0.64527881 0.61788548 0.70631219 0.77096667]
#   [0.6490759  0.58713755 0.65484931 0.63726584 0.72605298 0.78820252]
#   [0.65608086 0.58571632 0.66336882 0.6571063  0.74541551 0.804776  ]
#   [0.66241637 0.58285237 0.67082329 0.67734448 0.7643584  0.82065661]
#   [0.66786474 0.57858147 0.67715869 0.69794922 0.78280602 0.83578635]
#   [0.67200825 0.57280209 0.68228345 0.71886588 0.80065749 0.85005432]
#   [0.67461035 0.5653694  0.68604717 0.74012236 0.81782567 0.86332716]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 38: [[0.46347758]]
# x_pred_input of day 39:
# [[[0.6490759  0.58713755 0.65484931 0.6361208  0.72605298 0.78820252]
#   [0.65608086 0.58571632 0.66336882 0.65592561 0.74541551 0.804776  ]
#   [0.66241637 0.58285237 0.67082329 0.67612742 0.7643584  0.82065661]
#   [0.66786474 0.57858147 0.67715869 0.69669514 0.78280602 0.83578635]
#   [0.67200825 0.57280209 0.68228345 0.71757422 0.80065749 0.85005432]
#   [0.67461035 0.5653694  0.68604717 0.73879251 0.81782567 0.86332716]
#   [0.67610295 0.55633934 0.68837591 0.76034505 0.83425833 0.87554455]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 39: [[0.46341154]]
# x_pred_input of day 40:
# [[[0.65608086 0.58571632 0.66336882 0.65600194 0.74541551 0.804776  ]
#   [0.66241637 0.58285237 0.67082329 0.67620611 0.7643584  0.82065661]
#   [0.66786474 0.57858147 0.67715869 0.69677622 0.78280602 0.83578635]
#   [0.67200825 0.57280209 0.68228345 0.71765772 0.80065749 0.85005432]
#   [0.67461035 0.5653694  0.68604717 0.73887848 0.81782567 0.86332716]
#   [0.67610295 0.55633934 0.68837591 0.76043354 0.83425833 0.87554455]
#   [0.67600629 0.5456067  0.68915332 0.78229292 0.84987208 0.88658486]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 40: [[0.46213022]]
# x_pred_input of day 41:
# [[[0.66241637 0.58285237 0.67082329 0.67773632 0.7643584  0.82065661]
#   [0.66786474 0.57858147 0.67715869 0.69835298 0.78280602 0.83578635]
#   [0.67200825 0.57280209 0.68228345 0.71928174 0.80065749 0.85005432]
#   [0.67461035 0.5653694  0.68604717 0.74055053 0.81782567 0.86332716]
#   [0.67610295 0.55633934 0.68837591 0.76215436 0.83425833 0.87554455]
#   [0.67600629 0.5456067  0.68915332 0.7840632  0.84987208 0.88658486]
#   [0.67413093 0.53304242 0.68831025 0.80613038 0.86456595 0.89631159]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 41: [[0.46006742]]
# x_pred_input of day 42:
# [[[0.66786474 0.57858147 0.67715869 0.70090647 0.78280602 0.83578635]
#   [0.67200825 0.57280209 0.68228345 0.72191175 0.80065749 0.85005432]
#   [0.67461035 0.5653694  0.68604717 0.7432583  0.81782567 0.86332716]
#   [0.67610295 0.55633934 0.68837591 0.76494113 0.83425833 0.87554455]
#   [0.67600629 0.5456067  0.68915332 0.78693008 0.84987208 0.88658486]
#   [0.67413093 0.53304242 0.68831025 0.80907794 0.86456595 0.89631159]
#   [0.67111179 0.51878758 0.68589092 0.83118809 0.87827815 0.90468995]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 42: [[0.45665607]]
# x_pred_input of day 43:
# [[[0.67200825 0.57280209 0.68228345 0.72630358 0.80065749 0.85005432]
#   [0.67461035 0.5653694  0.68604717 0.74778    0.81782567 0.86332716]
#   [0.67610295 0.55633934 0.68837591 0.76959473 0.83425833 0.87554455]
#   [0.67600629 0.5456067  0.68915332 0.79171746 0.84987208 0.88658486]
#   [0.67413093 0.53304242 0.68831025 0.81400006 0.86456595 0.89631159]
#   [0.67111179 0.51878758 0.68589092 0.83624472 0.87827815 0.90468995]
#   [0.66611889 0.50268265 0.68199439 0.85801009 0.89088981 0.91157248]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 43: [[0.45214924]]
# x_pred_input of day 44:
# [[[0.67461035 0.5653694  0.68604717 0.75383877 0.81782567 0.86332716]
#   [0.67610295 0.55633934 0.68837591 0.77583026 0.83425833 0.87554455]
#   [0.67600629 0.5456067  0.68915332 0.79813223 0.84987208 0.88658486]
#   [0.67413093 0.53304242 0.68831025 0.82059537 0.86456595 0.89631159]
#   [0.67111179 0.51878758 0.68589092 0.84302026 0.87827815 0.90468995]
#   [0.66611889 0.50268265 0.68199439 0.86496198 0.89088981 0.91157248]
#   [0.65952263 0.48475286 0.67685272 0.88588995 0.90232012 0.91687752]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 44: [[0.44677174]]
# x_pred_input of day 45:
# [[[0.67610295 0.55633934 0.68837591 0.78340392 0.83425833 0.87554455]
#   [0.67600629 0.5456067  0.68915332 0.80592361 0.84987208 0.88658486]
#   [0.67413093 0.53304242 0.68831025 0.82860604 0.86456595 0.89631159]
#   [0.67111179 0.51878758 0.68589092 0.85124984 0.87827815 0.90468995]
#   [0.66611889 0.50268265 0.68199439 0.87340575 0.89088981 0.91157248]
#   [0.65952263 0.48475286 0.67685272 0.89453802 0.90232012 0.91687752]
#   [0.65165204 0.46515346 0.67087423 0.91395289 0.91251291 0.92057719]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 45: [[0.44031554]]
# x_pred_input of day 46:
# [[[0.67600629 0.5456067  0.68915332 0.81548123 0.84987208 0.88658486]
#   [0.67413093 0.53304242 0.68831025 0.83843265 0.86456595 0.89631159]
#   [0.67111179 0.51878758 0.68589092 0.86134499 0.87827815 0.90468995]
#   [0.66611889 0.50268265 0.68199439 0.88376365 0.89088981 0.91157248]
#   [0.65952263 0.48475286 0.67685272 0.90514654 0.90232012 0.91687752]
#   [0.65165204 0.46515346 0.67087423 0.92479165 0.91251291 0.92057719]
#   [0.64220266 0.44391898 0.66461605 0.94184016 0.92138464 0.9226037 ]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 46: [[0.43274665]]
# x_pred_input of day 47:
# [[[0.67413093 0.53304242 0.68831025 0.85025381 0.86456595 0.89631159]
#   [0.67111179 0.51878758 0.68589092 0.87348919 0.87827815 0.90468995]
#   [0.66611889 0.50268265 0.68199439 0.89622394 0.89088981 0.91157248]
#   [0.65952263 0.48475286 0.67685272 0.9179083  0.90232012 0.91687752]
#   [0.65165204 0.46515346 0.67087423 0.9378304  0.91251291 0.92057719]
#   [0.64220266 0.44391898 0.66461605 0.95511927 0.92138464 0.9226037 ]
#   [0.63112471 0.42107775 0.65923565 0.96804555 0.92883313 0.92288876]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 47: [[0.42457017]]
# x_pred_input of day 48:
# [[[0.67111179 0.51878758 0.68589092 0.88699898 0.87827815 0.90468995]
#   [0.66611889 0.50268265 0.68199439 0.91008536 0.89088981 0.91157248]
#   [0.65952263 0.48475286 0.67685272 0.9321051  0.90232012 0.91687752]
#   [0.65165204 0.46515346 0.67087423 0.95233532 0.91251291 0.92057719]
#   [0.64220266 0.44391898 0.66461605 0.96989159 0.92138464 0.9226037 ]
#   [0.63112471 0.42107775 0.65923565 0.9830178  0.92883313 0.92288876]
#   [0.6191575  0.39692799 0.65628614 0.98961048 0.93480711 0.92147392]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 48: [[0.4157371]]
# x_pred_input of day 49:
# [[[0.66611889 0.50268265 0.68199439 0.91963998 0.89088981 0.91157248]
#   [0.65952263 0.48475286 0.67685272 0.9418909  0.90232012 0.91687752]
#   [0.65165204 0.46515346 0.67087423 0.9623335  0.91251291 0.92057719]
#   [0.64220266 0.44391898 0.66461605 0.98007409 0.92138464 0.9226037 ]
#   [0.63112471 0.42107775 0.65923565 0.9933381  0.92883313 0.92288876]
#   [0.6191575  0.39692799 0.65628614 1.         0.93480711 0.92147392]
#   [0.60622928 0.37169325 0.65706608 0.99828785 0.93921773 0.91838676]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 49: [[0.4069666]]
# x_pred_input of day 50:
# [[[0.65952263 0.48475286 0.67685272 0.9418909  0.90232012 0.91687752]
#   [0.65165204 0.46515346 0.67087423 0.9623335  0.91251291 0.92057719]
#   [0.64220266 0.44391898 0.66461605 0.98007409 0.92138464 0.9226037 ]
#   [0.63112471 0.42107775 0.65923565 0.9933381  0.92883313 0.92288876]
#   [0.6191575  0.39692799 0.65628614 1.         0.93480711 0.92147392]
#   [0.60622928 0.37169325 0.65706608 0.99828785 0.93921773 0.91838676]
#   [0.59339265 0.34592797 0.66123748 0.98876129 0.94205525 0.91379934]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 50: [[0.39856133]]
# x_pred_input of day 51:
# [[[0.65165204 0.46515346 0.67087423 0.9623335  0.91251291 0.92057719]
#   [0.64220266 0.44391898 0.66461605 0.98007409 0.92138464 0.9226037 ]
#   [0.63112471 0.42107775 0.65923565 0.9933381  0.92883313 0.92288876]
#   [0.6191575  0.39692799 0.65628614 1.         0.93480711 0.92147392]
#   [0.60622928 0.37169325 0.65706608 0.99828785 0.93921773 0.91838676]
#   [0.59339265 0.34592797 0.66123748 0.98876129 0.94205525 0.91379934]
#   [0.58109058 0.32022696 0.66711399 0.97399253 0.94334996 0.90792927]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 51: [[0.39065084]]
# x_pred_input of day 52:
# [[[0.64220266 0.44391898 0.66461605 0.98007409 0.92138464 0.9226037 ]
#   [0.63112471 0.42107775 0.65923565 0.9933381  0.92883313 0.92288876]
#   [0.6191575  0.39692799 0.65628614 1.         0.93480711 0.92147392]
#   [0.60622928 0.37169325 0.65706608 0.99828785 0.93921773 0.91838676]
#   [0.59339265 0.34592797 0.66123748 0.98876129 0.94205525 0.91379934]
#   [0.58109058 0.32022696 0.66711399 0.97399253 0.94334996 0.90792927]
#   [0.56951267 0.29512164 0.67320984 0.95624555 0.94317864 0.90099992]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 52: [[0.383184]]
# x_pred_input of day 53:
# [[[0.63112471 0.42107775 0.65923565 0.9933381  0.92883313 0.92288876]
#   [0.6191575  0.39692799 0.65628614 1.         0.93480711 0.92147392]
#   [0.60622928 0.37169325 0.65706608 0.99828785 0.93921773 0.91838676]
#   [0.59339265 0.34592797 0.66123748 0.98876129 0.94205525 0.91379934]
#   [0.58109058 0.32022696 0.66711399 0.97399253 0.94334996 0.90792927]
#   [0.56951267 0.29512164 0.67320984 0.95624555 0.94317864 0.90099992]
#   [0.55858408 0.27099546 0.67859775 0.93698832 0.94159402 0.89320294]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 53: [[0.37646374]]
# x_pred_input of day 54:
# [[[0.6191575  0.39692799 0.65628614 1.         0.93480711 0.92147392]
#   [0.60622928 0.37169325 0.65706608 0.99828785 0.93921773 0.91838676]
#   [0.59339265 0.34592797 0.66123748 0.98876129 0.94205525 0.91379934]
#   [0.58109058 0.32022696 0.66711399 0.97399253 0.94334996 0.90792927]
#   [0.56951267 0.29512164 0.67320984 0.95624555 0.94317864 0.90099992]
#   [0.55858408 0.27099546 0.67859775 0.93698832 0.94159402 0.89320294]
#   [0.54874823 0.24829227 0.68268787 0.91732363 0.93871706 0.88477369]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 54: [[0.370541]]
# x_pred_input of day 55:
# [[[0.60622928 0.37169325 0.65706608 0.99828785 0.93921773 0.91838676]
#   [0.59339265 0.34592797 0.66123748 0.98876129 0.94205525 0.91379934]
#   [0.58109058 0.32022696 0.66711399 0.97399253 0.94334996 0.90792927]
#   [0.56951267 0.29512164 0.67320984 0.95624555 0.94317864 0.90099992]
#   [0.55858408 0.27099546 0.67859775 0.93698832 0.94159402 0.89320294]
#   [0.54874823 0.24829227 0.68268787 0.91732363 0.93871706 0.88477369]
#   [0.54007963 0.22736956 0.68508673 0.89803461 0.93467796 0.87593556]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 55: [[0.3654977]]
# x_pred_input of day 56:
# [[[0.59339265 0.34592797 0.66123748 0.98876129 0.94205525 0.91379934]
#   [0.58109058 0.32022696 0.66711399 0.97399253 0.94334996 0.90792927]
#   [0.56951267 0.29512164 0.67320984 0.95624555 0.94317864 0.90099992]
#   [0.55858408 0.27099546 0.67859775 0.93698832 0.94159402 0.89320294]
#   [0.54874823 0.24829227 0.68268787 0.91732363 0.93871706 0.88477369]
#   [0.54007963 0.22736956 0.68508673 0.89803461 0.93467796 0.87593556]
#   [0.53269819 0.20852892 0.68553612 0.87976175 0.92958522 0.8669074 ]]]
# 1/1 [==============================] - 0s 15ms/step
# y_pred of day 56: [[0.36131176]]
# x_pred_input of day 57:
# [[[0.58109058 0.32022696 0.66711399 0.97399253 0.94334996 0.90792927]
#   [0.56951267 0.29512164 0.67320984 0.95624555 0.94317864 0.90099992]
#   [0.55858408 0.27099546 0.67859775 0.93698832 0.94159402 0.89320294]
#   [0.54874823 0.24829227 0.68268787 0.91732363 0.93871706 0.88477369]
#   [0.54007963 0.22736956 0.68508673 0.89803461 0.93467796 0.87593556]
#   [0.53269819 0.20852892 0.68553612 0.87976175 0.92958522 0.8669074 ]
#   [0.52657158 0.19197166 0.6839281  0.86298836 0.92358599 0.8578827 ]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 57: [[0.35794857]]
# x_pred_input of day 58:
# [[[0.56951267 0.29512164 0.67320984 0.95624555 0.94317864 0.90099992]
#   [0.55858408 0.27099546 0.67859775 0.93698832 0.94159402 0.89320294]
#   [0.54874823 0.24829227 0.68268787 0.91732363 0.93871706 0.88477369]
#   [0.54007963 0.22736956 0.68508673 0.89803461 0.93467796 0.87593556]
#   [0.53269819 0.20852892 0.68553612 0.87976175 0.92958522 0.8669074 ]
#   [0.52657158 0.19197166 0.6839281  0.86298836 0.92358599 0.8578827 ]
#   [0.52164916 0.17781181 0.68026792 0.84806577 0.91680012 0.84902945]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 58: [[0.35535178]]
# x_pred_input of day 59:
# [[[0.55858408 0.27099546 0.67859775 0.93698832 0.94159402 0.89320294]
#   [0.54874823 0.24829227 0.68268787 0.91732363 0.93871706 0.88477369]
#   [0.54007963 0.22736956 0.68508673 0.89803461 0.93467796 0.87593556]
#   [0.53269819 0.20852892 0.68553612 0.87976175 0.92958522 0.8669074 ]
#   [0.52657158 0.19197166 0.6839281  0.86298836 0.92358599 0.8578827 ]
#   [0.52164916 0.17781181 0.68026792 0.84806577 0.91680012 0.84902945]
#   [0.51784845 0.16608266 0.67454828 0.83529544 0.90933623 0.84048811]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 59: [[0.35359567]]
# x_pred_input of day 60:
# [[[0.54874823 0.24829227 0.68268787 0.91732363 0.93871706 0.88477369]
#   [0.54007963 0.22736956 0.68508673 0.89803461 0.93467796 0.87593556]
#   [0.53269819 0.20852892 0.68553612 0.87976175 0.92958522 0.8669074 ]
#   [0.52657158 0.19197166 0.6839281  0.86298836 0.92358599 0.8578827 ]
#   [0.52164916 0.17781181 0.68026792 0.84806577 0.91680012 0.84902945]
#   [0.51784845 0.16608266 0.67454828 0.83529544 0.90933623 0.84048811]
#   [0.5152782  0.15682046 0.66686612 0.82491177 0.90132773 0.83240097]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 60: [[0.3522037]]
# x_pred_input of day 61:
# [[[0.54007963 0.22736956 0.68508673 0.89803461 0.93467796 0.87593556]
#   [0.53269819 0.20852892 0.68553612 0.87976175 0.92958522 0.8669074 ]
#   [0.52657158 0.19197166 0.6839281  0.86298836 0.92358599 0.8578827 ]
#   [0.52164916 0.17781181 0.68026792 0.84806577 0.91680012 0.84902945]
#   [0.51784845 0.16608266 0.67454828 0.83529544 0.90933623 0.84048811]
#   [0.5152782  0.15682046 0.66686612 0.82491177 0.90132773 0.83240097]
#   [0.51324088 0.14978239 0.6574556  0.81689335 0.892843   0.82479927]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 61: [[0.35104117]]
# x_pred_input of day 62:
# [[[0.53269819 0.20852892 0.68553612 0.87976175 0.92958522 0.8669074 ]
#   [0.52657158 0.19197166 0.6839281  0.86298836 0.92358599 0.8578827 ]
#   [0.52164916 0.17781181 0.68026792 0.84806577 0.91680012 0.84902945]
#   [0.51784845 0.16608266 0.67454828 0.83529544 0.90933623 0.84048811]
#   [0.5152782  0.15682046 0.66686612 0.82491177 0.90132773 0.83240097]
#   [0.51324088 0.14978239 0.6574556  0.81689335 0.892843   0.82479927]
#   [0.51153938 0.14468415 0.64645293 0.81124534 0.8839516  0.8176837 ]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 62: [[0.35034946]]
# x_pred_input of day 63:
# [[[0.52657158 0.19197166 0.6839281  0.86298836 0.92358599 0.8578827 ]
#   [0.52164916 0.17781181 0.68026792 0.84806577 0.91680012 0.84902945]
#   [0.51784845 0.16608266 0.67454828 0.83529544 0.90933623 0.84048811]
#   [0.5152782  0.15682046 0.66686612 0.82491177 0.90132773 0.83240097]
#   [0.51324088 0.14978239 0.6574556  0.81689335 0.892843   0.82479927]
#   [0.51153938 0.14468415 0.64645293 0.81124534 0.8839516  0.8176837 ]
#   [0.51052698 0.14140401 0.6341601  0.80789854 0.87476695 0.8111043 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 63: [[0.34958526]]
# x_pred_input of day 64:
# [[[0.52164916 0.17781181 0.68026792 0.84806577 0.91680012 0.84902945]
#   [0.51784845 0.16608266 0.67454828 0.83529544 0.90933623 0.84048811]
#   [0.5152782  0.15682046 0.66686612 0.82491177 0.90132773 0.83240097]
#   [0.51324088 0.14978239 0.6574556  0.81689335 0.892843   0.82479927]
#   [0.51153938 0.14468415 0.64645293 0.81124534 0.8839516  0.8176837 ]
#   [0.51052698 0.14140401 0.6341601  0.80789854 0.87476695 0.8111043 ]
#   [0.5094085  0.13954871 0.62089264 0.80661281 0.86537068 0.80499517]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 64: [[0.34879807]]
# x_pred_input of day 65:
# [[[0.51784845 0.16608266 0.67454828 0.83529544 0.90933623 0.84048811]
#   [0.5152782  0.15682046 0.66686612 0.82491177 0.90132773 0.83240097]
#   [0.51324088 0.14978239 0.6574556  0.81689335 0.892843   0.82479927]
#   [0.51153938 0.14468415 0.64645293 0.81124534 0.8839516  0.8176837 ]
#   [0.51052698 0.14140401 0.6341601  0.80789854 0.87476695 0.8111043 ]
#   [0.5094085  0.13954871 0.62089264 0.80661281 0.86537068 0.80499517]
#   [0.50825635 0.13881915 0.60690581 0.80719775 0.85582398 0.79930681]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 65: [[0.3479117]]
# x_pred_input of day 66:
# [[[0.5152782  0.15682046 0.66686612 0.82491177 0.90132773 0.83240097]
#   [0.51324088 0.14978239 0.6574556  0.81689335 0.892843   0.82479927]
#   [0.51153938 0.14468415 0.64645293 0.81124534 0.8839516  0.8176837 ]
#   [0.51052698 0.14140401 0.6341601  0.80789854 0.87476695 0.8111043 ]
#   [0.5094085  0.13954871 0.62089264 0.80661281 0.86537068 0.80499517]
#   [0.50825635 0.13881915 0.60690581 0.80719775 0.85582398 0.79930681]
#   [0.50695903 0.13892928 0.59257188 0.80932657 0.846209   0.79397887]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 66: [[0.34683788]]
# x_pred_input of day 67:
# [[[0.51324088 0.14978239 0.6574556  0.81689335 0.892843   0.82479927]
#   [0.51153938 0.14468415 0.64645293 0.81124534 0.8839516  0.8176837 ]
#   [0.51052698 0.14140401 0.6341601  0.80789854 0.87476695 0.8111043 ]
#   [0.5094085  0.13954871 0.62089264 0.80661281 0.86537068 0.80499517]
#   [0.50825635 0.13881915 0.60690581 0.80719775 0.85582398 0.79930681]
#   [0.50695903 0.13892928 0.59257188 0.80932657 0.846209   0.79397887]
#   [0.50538739 0.13960043 0.57835478 0.81253559 0.83661128 0.78893867]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 67: [[0.34565982]]
# x_pred_input of day 68:
# [[[0.51153938 0.14468415 0.64645293 0.81124534 0.8839516  0.8176837 ]
#   [0.51052698 0.14140401 0.6341601  0.80789854 0.87476695 0.8111043 ]
#   [0.5094085  0.13954871 0.62089264 0.80661281 0.86537068 0.80499517]
#   [0.50825635 0.13881915 0.60690581 0.80719775 0.85582398 0.79930681]
#   [0.50695903 0.13892928 0.59257188 0.80932657 0.846209   0.79397887]
#   [0.50538739 0.13960043 0.57835478 0.81253559 0.83661128 0.78893867]
#   [0.50366317 0.14065027 0.56459116 0.81645618 0.82708722 0.78413748]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 68: [[0.344391]]
# x_pred_input of day 69:
# [[[0.51052698 0.14140401 0.6341601  0.80789854 0.87476695 0.8111043 ]
#   [0.5094085  0.13954871 0.62089264 0.80661281 0.86537068 0.80499517]
#   [0.50825635 0.13881915 0.60690581 0.80719775 0.85582398 0.79930681]
#   [0.50695903 0.13892928 0.59257188 0.80932657 0.846209   0.79397887]
#   [0.50538739 0.13960043 0.57835478 0.81253559 0.83661128 0.78893867]
#   [0.50366317 0.14065027 0.56459116 0.81645618 0.82708722 0.78413748]
#   [0.50180608 0.14193854 0.55172516 0.82058326 0.81774152 0.77953397]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 69: [[0.34285668]]
# x_pred_input of day 70:
# [[[0.5094085  0.13954871 0.62089264 0.80661281 0.86537068 0.80499517]
#   [0.50825635 0.13881915 0.60690581 0.80719775 0.85582398 0.79930681]
#   [0.50695903 0.13892928 0.59257188 0.80932657 0.846209   0.79397887]
#   [0.50538739 0.13960043 0.57835478 0.81253559 0.83661128 0.78893867]
#   [0.50366317 0.14065027 0.56459116 0.81645618 0.82708722 0.78413748]
#   [0.50180608 0.14193854 0.55172516 0.82058326 0.81774152 0.77953397]
#   [0.49956044 0.14326349 0.53998745 0.82453563 0.80864327 0.775055  ]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 70: [[0.34111327]]
# x_pred_input of day 71:
# [[[0.50825635 0.13881915 0.60690581 0.80719775 0.85582398 0.79930681]
#   [0.50695903 0.13892928 0.59257188 0.80932657 0.846209   0.79397887]
#   [0.50538739 0.13960043 0.57835478 0.81253559 0.83661128 0.78893867]
#   [0.50366317 0.14065027 0.56459116 0.81645618 0.82708722 0.78413748]
#   [0.50180608 0.14193854 0.55172516 0.82058326 0.81774152 0.77953397]
#   [0.49956044 0.14326349 0.53998745 0.82453563 0.80864327 0.775055  ]
#   [0.49700877 0.14449539 0.52951919 0.82800861 0.79984754 0.77064593]]]
# 1/1 [==============================] - 0s 15ms/step
# y_pred of day 71: [[0.33920726]]
# x_pred_input of day 72:
# [[[0.50695903 0.13892928 0.59257188 0.80932657 0.846209   0.79397887]
#   [0.50538739 0.13960043 0.57835478 0.81253559 0.83661128 0.78893867]
#   [0.50366317 0.14065027 0.56459116 0.81645618 0.82708722 0.78413748]
#   [0.50180608 0.14193854 0.55172516 0.82058326 0.81774152 0.77953397]
#   [0.49956044 0.14326349 0.53998745 0.82453563 0.80864327 0.775055  ]
#   [0.49700877 0.14449539 0.52951919 0.82800861 0.79984754 0.77064593]
#   [0.49421911 0.1455574  0.5204394  0.83071221 0.79143061 0.76626684]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 72: [[0.3371104]]
# x_pred_input of day 73:
# [[[0.50538739 0.13960043 0.57835478 0.81253559 0.83661128 0.78893867]
#   [0.50366317 0.14065027 0.56459116 0.81645618 0.82708722 0.78413748]
#   [0.50180608 0.14193854 0.55172516 0.82058326 0.81774152 0.77953397]
#   [0.49956044 0.14326349 0.53998745 0.82453563 0.80864327 0.775055  ]
#   [0.49700877 0.14449539 0.52951919 0.82800861 0.79984754 0.77064593]
#   [0.49421911 0.1455574  0.5204394  0.83071221 0.79143061 0.76626684]
#   [0.49115011 0.14637682 0.51293667 0.83226475 0.7834692  0.76187584]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 73: [[0.33493394]]
# x_pred_input of day 74:
# [[[0.50366317 0.14065027 0.56459116 0.81645618 0.82708722 0.78413748]
#   [0.50180608 0.14193854 0.55172516 0.82058326 0.81774152 0.77953397]
#   [0.49956044 0.14326349 0.53998745 0.82453563 0.80864327 0.775055  ]
#   [0.49700877 0.14449539 0.52951919 0.82800861 0.79984754 0.77064593]
#   [0.49421911 0.1455574  0.5204394  0.83071221 0.79143061 0.76626684]
#   [0.49115011 0.14637682 0.51293667 0.83226475 0.7834692  0.76187584]
#   [0.4879646  0.14695625 0.50704902 0.83245583 0.77600728 0.75745776]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 74: [[0.3327692]]
# x_pred_input of day 75:
# [[[0.50180608 0.14193854 0.55172516 0.82058326 0.81774152 0.77953397]
#   [0.49956044 0.14326349 0.53998745 0.82453563 0.80864327 0.775055  ]
#   [0.49700877 0.14449539 0.52951919 0.82800861 0.79984754 0.77064593]
#   [0.49421911 0.1455574  0.5204394  0.83071221 0.79143061 0.76626684]
#   [0.49115011 0.14637682 0.51293667 0.83226475 0.7834692  0.76187584]
#   [0.4879646  0.14695625 0.50704902 0.83245583 0.77600728 0.75745776]
#   [0.48479624 0.147347   0.50270735 0.83123063 0.76910047 0.75301758]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 75: [[0.3306497]]
# x_pred_input of day 76:
# [[[0.49956044 0.14326349 0.53998745 0.82453563 0.80864327 0.775055  ]
#   [0.49700877 0.14449539 0.52951919 0.82800861 0.79984754 0.77064593]
#   [0.49421911 0.1455574  0.5204394  0.83071221 0.79143061 0.76626684]
#   [0.49115011 0.14637682 0.51293667 0.83226475 0.7834692  0.76187584]
#   [0.4879646  0.14695625 0.50704902 0.83245583 0.77600728 0.75745776]
#   [0.48479624 0.147347   0.50270735 0.83123063 0.76910047 0.75301758]
#   [0.48169414 0.14760859 0.49968221 0.82874655 0.76274733 0.74856667]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 76: [[0.32849625]]
# x_pred_input of day 77:
# [[[0.49700877 0.14449539 0.52951919 0.82800861 0.79984754 0.77064593]
#   [0.49421911 0.1455574  0.5204394  0.83071221 0.79143061 0.76626684]
#   [0.49115011 0.14637682 0.51293667 0.83226475 0.7834692  0.76187584]
#   [0.4879646  0.14695625 0.50704902 0.83245583 0.77600728 0.75745776]
#   [0.48479624 0.147347   0.50270735 0.83123063 0.76910047 0.75301758]
#   [0.48169414 0.14760859 0.49968221 0.82874655 0.76274733 0.74856667]
#   [0.47854231 0.14774865 0.49767102 0.82525097 0.75691464 0.74409911]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 77: [[0.32636002]]
# x_pred_input of day 78:
# [[[0.49421911 0.1455574  0.5204394  0.83071221 0.79143061 0.76626684]
#   [0.49115011 0.14637682 0.51293667 0.83226475 0.7834692  0.76187584]
#   [0.4879646  0.14695625 0.50704902 0.83245583 0.77600728 0.75745776]
#   [0.48479624 0.147347   0.50270735 0.83123063 0.76910047 0.75301758]
#   [0.48169414 0.14760859 0.49968221 0.82874655 0.76274733 0.74856667]
#   [0.47854231 0.14774865 0.49767102 0.82525097 0.75691464 0.74409911]
#   [0.47541569 0.1478007  0.49633934 0.8210517  0.75156264 0.73962   ]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 78: [[0.3243202]]
# x_pred_input of day 79:
# [[[0.49115011 0.14637682 0.51293667 0.83226475 0.7834692  0.76187584]
#   [0.4879646  0.14695625 0.50704902 0.83245583 0.77600728 0.75745776]
#   [0.48479624 0.147347   0.50270735 0.83123063 0.76910047 0.75301758]
#   [0.48169414 0.14760859 0.49968221 0.82874655 0.76274733 0.74856667]
#   [0.47854231 0.14774865 0.49767102 0.82525097 0.75691464 0.74409911]
#   [0.47541569 0.1478007  0.49633934 0.8210517  0.75156264 0.73962   ]
#   [0.47243018 0.14783239 0.49537633 0.81644985 0.74666242 0.73515016]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 79: [[0.32238266]]
# x_pred_input of day 80:
# [[[0.4879646  0.14695625 0.50704902 0.83245583 0.77600728 0.75745776]
#   [0.48479624 0.147347   0.50270735 0.83123063 0.76910047 0.75301758]
#   [0.48169414 0.14760859 0.49968221 0.82874655 0.76274733 0.74856667]
#   [0.47854231 0.14774865 0.49767102 0.82525097 0.75691464 0.74409911]
#   [0.47541569 0.1478007  0.49633934 0.8210517  0.75156264 0.73962   ]
#   [0.47243018 0.14783239 0.49537633 0.81644985 0.74666242 0.73515016]
#   [0.46959437 0.14789995 0.49449192 0.8117048  0.74216035 0.73070964]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 80: [[0.32045543]]
# x_pred_input of day 81:
# [[[0.48479624 0.147347   0.50270735 0.83123063 0.76910047 0.75301758]
#   [0.48169414 0.14760859 0.49968221 0.82874655 0.76274733 0.74856667]
#   [0.47854231 0.14774865 0.49767102 0.82525097 0.75691464 0.74409911]
#   [0.47541569 0.1478007  0.49633934 0.8210517  0.75156264 0.73962   ]
#   [0.47243018 0.14783239 0.49537633 0.81644985 0.74666242 0.73515016]
#   [0.46959437 0.14789995 0.49449192 0.8117048  0.74216035 0.73070964]
#   [0.46677365 0.1480001  0.49357181 0.80690673 0.73799089 0.72629775]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 81: [[0.31878453]]
# x_pred_input of day 82:
# [[[0.48169414 0.14760859 0.49968221 0.82874655 0.76274733 0.74856667]
#   [0.47854231 0.14774865 0.49767102 0.82525097 0.75691464 0.74409911]
#   [0.47541569 0.1478007  0.49633934 0.8210517  0.75156264 0.73962   ]
#   [0.47243018 0.14783239 0.49537633 0.81644985 0.74666242 0.73515016]
#   [0.46959437 0.14789995 0.49449192 0.8117048  0.74216035 0.73070964]
#   [0.46677365 0.1480001  0.49357181 0.80690673 0.73799089 0.72629775]
#   [0.46432811 0.14825541 0.49249797 0.80222374 0.73410217 0.72196421]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 82: [[0.31733042]]
# x_pred_input of day 83:
# [[[0.47854231 0.14774865 0.49767102 0.82525097 0.75691464 0.74409911]
#   [0.47541569 0.1478007  0.49633934 0.8210517  0.75156264 0.73962   ]
#   [0.47243018 0.14783239 0.49537633 0.81644985 0.74666242 0.73515016]
#   [0.46959437 0.14789995 0.49449192 0.8117048  0.74216035 0.73070964]
#   [0.46677365 0.1480001  0.49357181 0.80690673 0.73799089 0.72629775]
#   [0.46432811 0.14825541 0.49249797 0.80222374 0.73410217 0.72196421]
#   [0.46219984 0.14874    0.4911058  0.79783457 0.73044086 0.7177459 ]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 83: [[0.31591895]]
# x_pred_input of day 84:
# [[[0.47541569 0.1478007  0.49633934 0.8210517  0.75156264 0.73962   ]
#   [0.47243018 0.14783239 0.49537633 0.81644985 0.74666242 0.73515016]
#   [0.46959437 0.14789995 0.49449192 0.8117048  0.74216035 0.73070964]
#   [0.46677365 0.1480001  0.49357181 0.80690673 0.73799089 0.72629775]
#   [0.46432811 0.14825541 0.49249797 0.80222374 0.73410217 0.72196421]
#   [0.46219984 0.14874    0.4911058  0.79783457 0.73044086 0.7177459 ]
#   [0.460134   0.14942043 0.48940409 0.79374905 0.72694203 0.71364058]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 84: [[0.31472316]]
# x_pred_input of day 85:
# [[[0.47243018 0.14783239 0.49537633 0.81644985 0.74666242 0.73515016]
#   [0.46959437 0.14789995 0.49449192 0.8117048  0.74216035 0.73070964]
#   [0.46677365 0.1480001  0.49357181 0.80690673 0.73799089 0.72629775]
#   [0.46432811 0.14825541 0.49249797 0.80222374 0.73410217 0.72196421]
#   [0.46219984 0.14874    0.4911058  0.79783457 0.73044086 0.7177459 ]
#   [0.460134   0.14942043 0.48940409 0.79374905 0.72694203 0.71364058]
#   [0.45838382 0.1503566  0.48735871 0.79005996 0.72355983 0.70968161]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 85: [[0.31367636]]
# x_pred_input of day 86:
# [[[0.46959437 0.14789995 0.49449192 0.8117048  0.74216035 0.73070964]
#   [0.46677365 0.1480001  0.49357181 0.80690673 0.73799089 0.72629775]
#   [0.46432811 0.14825541 0.49249797 0.80222374 0.73410217 0.72196421]
#   [0.46219984 0.14874    0.4911058  0.79783457 0.73044086 0.7177459 ]
#   [0.460134   0.14942043 0.48940409 0.79374905 0.72694203 0.71364058]
#   [0.45838382 0.1503566  0.48735871 0.79005996 0.72355983 0.70968161]
#   [0.4568517  0.15155847 0.48497146 0.78681222 0.72023668 0.70588553]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 86: [[0.3128133]]
# x_pred_input of day 87:
# [[[0.46677365 0.1480001  0.49357181 0.80690673 0.73799089 0.72629775]
#   [0.46432811 0.14825541 0.49249797 0.80222374 0.73410217 0.72196421]
#   [0.46219984 0.14874    0.4911058  0.79783457 0.73044086 0.7177459 ]
#   [0.460134   0.14942043 0.48940409 0.79374905 0.72694203 0.71364058]
#   [0.45838382 0.1503566  0.48735871 0.79005996 0.72355983 0.70968161]
#   [0.4568517  0.15155847 0.48497146 0.78681222 0.72023668 0.70588553]
#   [0.45558854 0.15304857 0.48226955 0.78403924 0.71695756 0.70227441]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 87: [[0.3120351]]
# x_pred_input of day 88:
# [[[0.46432811 0.14825541 0.49249797 0.80222374 0.73410217 0.72196421]
#   [0.46219984 0.14874    0.4911058  0.79783457 0.73044086 0.7177459 ]
#   [0.460134   0.14942043 0.48940409 0.79374905 0.72694203 0.71364058]
#   [0.45838382 0.1503566  0.48735871 0.79005996 0.72355983 0.70968161]
#   [0.4568517  0.15155847 0.48497146 0.78681222 0.72023668 0.70588553]
#   [0.45558854 0.15304857 0.48226955 0.78403924 0.71695756 0.70227441]
#   [0.45444955 0.15479079 0.47927398 0.78174814 0.71371043 0.69884801]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 88: [[0.3113257]]
# x_pred_input of day 89:
# [[[0.46219984 0.14874    0.4911058  0.79783457 0.73044086 0.7177459 ]
#   [0.460134   0.14942043 0.48940409 0.79374905 0.72694203 0.71364058]
#   [0.45838382 0.1503566  0.48735871 0.79005996 0.72355983 0.70968161]
#   [0.4568517  0.15155847 0.48497146 0.78681222 0.72023668 0.70588553]
#   [0.45558854 0.15304857 0.48226955 0.78403924 0.71695756 0.70227441]
#   [0.45444955 0.15479079 0.47927398 0.78174814 0.71371043 0.69884801]
#   [0.45341125 0.15674578 0.47600254 0.77994489 0.71046183 0.6956028 ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 89: [[0.31083184]]
# x_pred_input of day 90:
# [[[0.460134   0.14942043 0.48940409 0.79374905 0.72694203 0.71364058]
#   [0.45838382 0.1503566  0.48735871 0.79005996 0.72355983 0.70968161]
#   [0.4568517  0.15155847 0.48497146 0.78681222 0.72023668 0.70588553]
#   [0.45558854 0.15304857 0.48226955 0.78403924 0.71695756 0.70227441]
#   [0.45444955 0.15479079 0.47927398 0.78174814 0.71371043 0.69884801]
#   [0.45341125 0.15674578 0.47600254 0.77994489 0.71046183 0.6956028 ]
#   [0.45268843 0.15895517 0.47251635 0.77863701 0.70723573 0.69256563]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 90: [[0.31032318]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#          Close      MACD  Bollinger_Upper  Bollinger_Lower      MA26     EMA20
# 0     0.005824  0.000000         0.310323         0.310323  0.310323  0.005824
# 1     0.005704 -0.000010         0.310323         0.310323  0.310323  0.005813
# 2     0.005645 -0.000022         0.310323         0.310323  0.310323  0.005797
# 3     0.005669 -0.000029         0.310323         0.310323  0.310323  0.005784
# 4     0.005545 -0.000044         0.310323         0.310323  0.310323  0.005762
# ...        ...       ...              ...              ...       ...       ...
# 2155  0.312813 -0.013333         0.350301         0.306094  0.333018  0.328784
# 2156  0.312035 -0.013061         0.348137         0.304896  0.331518  0.327188
# 2157  0.311326 -0.012755         0.345774         0.303952  0.330017  0.325678
# 2158  0.310832 -0.012410         0.343256         0.303268  0.328527  0.324264
# 2159  0.310323 -0.012038         0.340641         0.302803  0.327047  0.322936
#
# [2160 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
df_forecast_90 = df_forecast_unscale.copy()
df_forecast_90.index = pd.to_datetime(df_forecast_90.index)

df_forecast_60 = df_forecast_90.head(60)
df_forecast_30 = df_forecast_90.head(30)


# Label the forecasted data
forecast_30_label = f"Forecast next 30 days - " + df_forecast_30.index[-1].strftime("%Y-%m-%d")
forecast_60_label = f"Forecast next 60 days - " + df_forecast_60.index[-1].strftime("%Y-%m-%d")
forecast_90_label = f"Forecast next 90 days - " + df_forecast_90.index[-1].strftime("%Y-%m-%d")

# Add last day of original data to the forecasted data
df_forecast_30 = pd.concat([df_filtered.tail(1), df_forecast_30])
df_forecast_30.index = pd.date_range(start=df_filtered.index.max(), periods=len(df_forecast_30))

# Plot the overall with connection to forecast
plt.figure(figsize=(15, 7))
plt.plot(df_filtered['Close'], label='Train')
plt.plot(df_test.index, df_test['Y_test'], label='Actual Test')
plt.plot(df_test.index, df_test['Y_test_pred'], label='Forecast Test')
plt.plot(df_forecast_90.index, df_forecast_90['Close'], label=forecast_90_label)
plt.plot(df_forecast_60.index, df_forecast_60['Close'], label=forecast_60_label)
plt.plot(df_forecast_30.index, df_forecast_30['Close'], label=forecast_30_label)
plt.title('BTC/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  0.009604363063586748
# MAPE:  8.997918107485708
# SMAPE:  8.555401422303069
