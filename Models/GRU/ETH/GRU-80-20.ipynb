# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read the data
data = pd.read_csv('../../.dataset/ETH-USD-3.2018-3.2024.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 1  2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2  2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 3  2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 4  2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#        Volume
# 0  1868519936
# 1  1894419968
# 2  1699369984
# 3  1697939968
# 4  1898489984

# %%
# Set the date as the index
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-01  856.012024  880.302002  851.919983  872.200012  872.200012
# 2018-03-02  871.763977  876.377991  852.421997  856.853027  856.853027
# 2018-03-03  856.710999  868.453979  855.206970  857.224976  857.224976
# 2018-03-04  856.185974  867.950012  840.280029  866.677979  866.677979
# 2018-03-05  866.846008  869.919983  853.520020  853.684021  853.684021
#
#                 Volume
# Date
# 2018-03-01  1868519936
# 2018-03-02  1894419968
# 2018-03-03  1699369984
# 2018-03-04  1697939968
# 2018-03-05  1898489984

# %%
# Feature Engineering
def createFeatures(df):
    df = pd.DataFrame(df)

    
    # df['Close_Diff'] = df['Adj Close'].diff()
        
    # Moving averages - different periods
    df['MA200'] = df['Close'].rolling(window=200).mean() 
    df['MA100'] = df['Close'].rolling(window=100).mean() 
    df['MA50'] = df['Close'].rolling(window=50).mean() 
    df['MA26'] = df['Close'].rolling(window=26).mean() 
    df['MA20'] = df['Close'].rolling(window=20).mean() 
    df['MA12'] = df['Close'].rolling(window=12).mean() 
    
    # SMA Differences - different periods
    df['DIFF-MA200-MA50'] = df['MA200'] - df['MA50']
    df['DIFF-MA200-MA100'] = df['MA200'] - df['MA100']
    df['DIFF-MA200-CLOSE'] = df['MA200'] - df['Close']
    df['DIFF-MA100-CLOSE'] = df['MA100'] - df['Close']
    df['DIFF-MA50-CLOSE'] = df['MA50'] - df['Close']
    
    # Moving Averages on high, lows, and std - different periods
    # df['MA200_low'] = df['Low'].rolling(window=200).min()
    # df['MA14_low'] = df['Low'].rolling(window=14).min()
    # df['MA200_high'] = df['High'].rolling(window=200).max()
    # df['MA14_high'] = df['High'].rolling(window=14).max()
    df['MA20dSTD'] = df['Close'].rolling(window=20).std() 
    
    # Exponential Moving Averages (EMAS) - different periods
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['EMA100'] = df['Close'].ewm(span=100, adjust=False).mean()
    df['EMA200'] = df['Close'].ewm(span=200, adjust=False).mean()

    # Shifts (one day before and two days before)
    df['close_shift-1'] = df.shift(-1)['Close']
    df['close_shift-2'] = df.shift(-2)['Close']

    # Bollinger Bands
    df['Bollinger_Upper'] = df['MA20'] + (df['MA20dSTD'] * 2)
    df['Bollinger_Lower'] = df['MA20'] - (df['MA20dSTD'] * 2)
    df['Bollinger_Middle'] = df['MA20'] 
    
    # Relative Strength Index (RSI)
    # df['K-ratio'] = 100*((df['Close'] - df['MA14_low']) / (df['MA14_high'] - df['MA14_low']) )
    # Relative Strength Index (RSI) not using the K-ratio
    # df['RSI'] = df['K-ratio'].rolling(window=3).mean() 

    # Moving Average Convergence/Divergence (MACD)
    df['MACD'] = df['EMA12'] - df['EMA26']
    
    # Replace nas 
    nareplace = df.at[df.index.max(), 'Close']    
    df.fillna((nareplace), inplace=True)
    
    # 
    return df

# %%
# List of considered Features
FEATURES = [
            # 'High',
            # 'Low',
            # 'Open',
            'Close',
            # 'Volume',
#             'Day',
#             'Month',
#             'Year',
            # 'Adj Close',
#              'close_shift-1',
#              'close_shift-2',
            'MACD',
            # 'RSI',
            # 'MA200',
#             'MA200_high',
#             'MA200_low',
            'Bollinger_Upper',
            'Bollinger_Lower',
            # 'MA100',            
#             'MA50',
            'MA26',
#             'MA14_low',
#             'MA14_high',
            # 'MA12',
            'EMA20',
            # 'EMA100',
#             'EMA200',
#               'DIFF-MA200-MA50',
#               'DIFF-MA200-MA100',
#             'DIFF-MA200-CLOSE',
#             'DIFF-MA100-CLOSE',
#             'DIFF-MA50-CLOSE',
            # 'MA20dSTD',
            # 'Close_Diff',
            # 'K-ratio'
           ]

# Create the dataset with features
df_features = createFeatures(data)

# Shift the timeframe by 10 month -> Start date is 2010-11-01
use_start_date = pd.to_datetime("2018-10-01")
df_features = df_features[df_features.index > use_start_date].copy()

# Filter the data to the list of FEATURES
df_filtered = df_features[FEATURES].copy()

# Filter the data to the list of FEATURES
print(df_filtered.head().to_string())  
    

# Filter the data to the list of FEATURES
df_filtered = df_filtered.dropna()
print(df_filtered.head().to_string())

# Create the lineplot
plt.figure(figsize=(15, 7))
plt.plot(df_filtered)
plt.title('ETH/USD Close price')
plt.grid()
plt.legend(df_filtered.columns)
plt.show()
# Out:
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678
#                  Close      MACD  Bollinger_Upper  Bollinger_Lower        MA26       EMA20
# Date
# 2018-10-02  227.181000 -5.729216       248.675597       199.022404  217.482077  228.975856
# 2018-10-03  220.488998 -5.855122       248.492314       200.119187  217.608461  228.167584
# 2018-10-04  222.218002 -5.749115       248.314508       201.343894  218.541807  227.600957
# 2018-10-05  227.600998 -5.171132       248.556886       201.554214  219.721692  227.600961
# 2018-10-06  225.119995 -4.857280       248.689311       201.874888  220.800192  227.364678

# %%
# Scale the data
df = df_filtered.copy()

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data = scaler.fit_transform(df)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_close = pd.DataFrame(df['Close'])
np_close = scaler_pred.fit_transform(df_close)

# %%
print(df_filtered.shape)
# Out:
# (1978, 6)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 7

# Training, validation, test
train_size = int(len(np_data) * 0.80)
test_size = len(np_data) - train_size
train_data, test_data = np_data[0:train_size], np_data[train_size:len(np_data)]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1582, 6) (396, 6)

# %%
# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(data, time_steps):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(data_len - time_steps):
        row = [r for r in data[i: i + time_steps]]
        x.append(row)
        label = data[i + time_steps][0]
        y.append(label)
    return np.array(x), np.array(y)
    

# Generate training data and test data
X_train, y_train = partition_dataset(train_data, sequence_length)
X_test, y_test = partition_dataset(test_data, sequence_length)

# %%
# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1575, 7, 6) (1575,)
# (389, 7, 6) (389,)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
x_train = X_train.reshape(X_train.shape[0], X_train.shape[1], len(FEATURES))
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], len(FEATURES))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1575, 7, 6) (1575,)
# (389, 7, 6) (389,)

# %%
# Configure the neural network model
model = Sequential()

# Configure the Neural Network Model with n Neurons - inputshape = t Timestamps x f Features
n_neurons = X_train.shape[1] * x_train.shape[2]
print('timesteps: ' + str(x_train.shape[1]) + ',' + ' features:' + str(x_train.shape[2]))
model.add(GRU(n_neurons, input_shape=(x_train.shape[1], x_train.shape[2]))) 
model.add(Dense(1))



# Configure the Model   
optimizer='adam'; loss='mean_squared_error'; epochs = 100; batch_size = 64

# uncomment to customize the learning rate
learn_rate = "standard" # 0.05

parameter_list = ['epochs ' + str(epochs), 'batch_size ' + str(batch_size), 'optimizer ' + str(optimizer) + ' with learn rate ' + str(learn_rate), 'loss ' + str(loss)]
print('Parameters: ' + str(parameter_list))

# Compile and Training the model
model.compile(optimizer=optimizer, loss=loss)
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test, y_test), verbose=1)

# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(12, 6), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
# Out:
# timesteps: 7, features:6
# Parameters: ['epochs 100', 'batch_size 64', 'optimizer adam with learn rate standard', 'loss mean_squared_error']
# Epoch 1/100
# 25/25 [==============================] - 4s 29ms/step - loss: 0.0162 - val_loss: 0.0038
# Epoch 2/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0023 - val_loss: 5.8876e-04
# Epoch 3/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 4.0686e-04
# Epoch 4/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.6131e-04 - val_loss: 3.4694e-04
# Epoch 5/100
# 25/25 [==============================] - 0s 9ms/step - loss: 8.1798e-04 - val_loss: 3.1687e-04
# Epoch 6/100
# 25/25 [==============================] - 0s 11ms/step - loss: 7.4348e-04 - val_loss: 2.9072e-04
# Epoch 7/100
# 25/25 [==============================] - 0s 10ms/step - loss: 7.0096e-04 - val_loss: 2.9232e-04
# Epoch 8/100
# 25/25 [==============================] - 0s 10ms/step - loss: 6.4240e-04 - val_loss: 3.7753e-04
# Epoch 9/100
# 25/25 [==============================] - 0s 9ms/step - loss: 6.2012e-04 - val_loss: 2.2843e-04
# Epoch 10/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.9549e-04 - val_loss: 2.2084e-04
# Epoch 11/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.6693e-04 - val_loss: 2.0182e-04
# Epoch 12/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.4632e-04 - val_loss: 2.3129e-04
# Epoch 13/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.3068e-04 - val_loss: 1.8794e-04
# Epoch 14/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.0832e-04 - val_loss: 2.0139e-04
# Epoch 15/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.0426e-04 - val_loss: 1.9269e-04
# Epoch 16/100
# 25/25 [==============================] - 0s 7ms/step - loss: 4.8502e-04 - val_loss: 1.7384e-04
# Epoch 17/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.7655e-04 - val_loss: 2.0228e-04
# Epoch 18/100
# 25/25 [==============================] - 0s 6ms/step - loss: 5.0202e-04 - val_loss: 1.6226e-04
# Epoch 19/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.7239e-04 - val_loss: 1.8119e-04
# Epoch 20/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.5047e-04 - val_loss: 2.8694e-04
# Epoch 21/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.5572e-04 - val_loss: 1.8875e-04
# Epoch 22/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.4269e-04 - val_loss: 1.6776e-04
# Epoch 23/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.5600e-04 - val_loss: 1.4697e-04
# Epoch 24/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.6346e-04 - val_loss: 1.7624e-04
# Epoch 25/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.7749e-04 - val_loss: 1.7630e-04
# Epoch 26/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.3321e-04 - val_loss: 1.3900e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.0123e-04 - val_loss: 1.4414e-04
# Epoch 28/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.1544e-04 - val_loss: 1.3896e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.0109e-04 - val_loss: 1.3800e-04
# Epoch 30/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.3223e-04 - val_loss: 1.7033e-04
# Epoch 31/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.9277e-04 - val_loss: 1.3876e-04
# Epoch 32/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.8228e-04 - val_loss: 2.3914e-04
# Epoch 33/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.2106e-04 - val_loss: 1.7539e-04
# Epoch 34/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.3366e-04 - val_loss: 1.2843e-04
# Epoch 35/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.0505e-04 - val_loss: 1.3203e-04
# Epoch 36/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.1749e-04 - val_loss: 1.6710e-04
# Epoch 37/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.8513e-04 - val_loss: 1.6102e-04
# Epoch 38/100
# 25/25 [==============================] - 0s 9ms/step - loss: 3.8251e-04 - val_loss: 1.9028e-04
# Epoch 39/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.7876e-04 - val_loss: 1.2309e-04
# Epoch 40/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.6908e-04 - val_loss: 1.2606e-04
# Epoch 41/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.7015e-04 - val_loss: 1.4550e-04
# Epoch 42/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.6464e-04 - val_loss: 1.2206e-04
# Epoch 43/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.9226e-04 - val_loss: 1.3902e-04
# Epoch 44/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.8706e-04 - val_loss: 2.7496e-04
# Epoch 45/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.1453e-04 - val_loss: 1.3858e-04
# Epoch 46/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.6191e-04 - val_loss: 1.6596e-04
# Epoch 47/100
# 25/25 [==============================] - 0s 5ms/step - loss: 4.1526e-04 - val_loss: 1.3839e-04
# Epoch 48/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.0217e-04 - val_loss: 1.2173e-04
# Epoch 49/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.5864e-04 - val_loss: 1.1882e-04
# Epoch 50/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.4812e-04 - val_loss: 1.2135e-04
# Epoch 51/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4897e-04 - val_loss: 1.1860e-04
# Epoch 52/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.8771e-04 - val_loss: 1.1780e-04
# Epoch 53/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.7689e-04 - val_loss: 1.4268e-04
# Epoch 54/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.5010e-04 - val_loss: 1.1754e-04
# Epoch 55/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4930e-04 - val_loss: 1.1888e-04
# Epoch 56/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.7306e-04 - val_loss: 1.3619e-04
# Epoch 57/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.8011e-04 - val_loss: 1.1838e-04
# Epoch 58/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.7424e-04 - val_loss: 1.2523e-04
# Epoch 59/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.5544e-04 - val_loss: 1.3107e-04
# Epoch 60/100
# 25/25 [==============================] - 0s 6ms/step - loss: 4.3832e-04 - val_loss: 1.2755e-04
# Epoch 61/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.8309e-04 - val_loss: 1.1718e-04
# Epoch 62/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4182e-04 - val_loss: 1.2304e-04
# Epoch 63/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.5737e-04 - val_loss: 1.3399e-04
# Epoch 64/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.6468e-04 - val_loss: 1.6974e-04
# Epoch 65/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.3824e-04 - val_loss: 1.3128e-04
# Epoch 66/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4533e-04 - val_loss: 1.3066e-04
# Epoch 67/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.3131e-04 - val_loss: 1.5869e-04
# Epoch 68/100
# 25/25 [==============================] - 0s 10ms/step - loss: 3.7720e-04 - val_loss: 1.1681e-04
# Epoch 69/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.4772e-04 - val_loss: 1.5447e-04
# Epoch 70/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.5499e-04 - val_loss: 1.5054e-04
# Epoch 71/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.3195e-04 - val_loss: 1.1394e-04
# Epoch 72/100
# 25/25 [==============================] - 0s 8ms/step - loss: 3.3426e-04 - val_loss: 1.6963e-04
# Epoch 73/100
# 25/25 [==============================] - 0s 8ms/step - loss: 3.5892e-04 - val_loss: 1.3124e-04
# Epoch 74/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.7588e-04 - val_loss: 1.3382e-04
# Epoch 75/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.4866e-04 - val_loss: 2.8279e-04
# Epoch 76/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.9076e-04 - val_loss: 1.1860e-04
# Epoch 77/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.2805e-04 - val_loss: 1.1804e-04
# Epoch 78/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.4431e-04 - val_loss: 2.0812e-04
# Epoch 79/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.7677e-04 - val_loss: 1.1355e-04
# Epoch 80/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.2248e-04 - val_loss: 1.1811e-04
# Epoch 81/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.5824e-04 - val_loss: 1.6487e-04
# Epoch 82/100
# 25/25 [==============================] - 0s 9ms/step - loss: 3.5356e-04 - val_loss: 3.5257e-04
# Epoch 83/100
# 25/25 [==============================] - 0s 9ms/step - loss: 3.6816e-04 - val_loss: 1.4704e-04
# Epoch 84/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.5057e-04 - val_loss: 3.5879e-04
# Epoch 85/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.6391e-04 - val_loss: 1.9661e-04
# Epoch 86/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4155e-04 - val_loss: 1.9369e-04
# Epoch 87/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4058e-04 - val_loss: 1.4702e-04
# Epoch 88/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4804e-04 - val_loss: 2.3038e-04
# Epoch 89/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.7721e-04 - val_loss: 1.2637e-04
# Epoch 90/100
# 25/25 [==============================] - 0s 7ms/step - loss: 3.3708e-04 - val_loss: 1.1467e-04
# Epoch 91/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.3022e-04 - val_loss: 1.4682e-04
# Epoch 92/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.3390e-04 - val_loss: 1.6205e-04
# Epoch 93/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4372e-04 - val_loss: 1.2571e-04
# Epoch 94/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.3307e-04 - val_loss: 1.1500e-04
# Epoch 95/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.7675e-04 - val_loss: 2.1495e-04
# Epoch 96/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4596e-04 - val_loss: 1.9058e-04
# Epoch 97/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.4687e-04 - val_loss: 1.1932e-04
# Epoch 98/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.2991e-04 - val_loss: 1.3430e-04
# Epoch 99/100
# 25/25 [==============================] - 0s 5ms/step - loss: 3.5527e-04 - val_loss: 1.2462e-04
# Epoch 100/100
# 25/25 [==============================] - 0s 6ms/step - loss: 3.5574e-04 - val_loss: 1.1434e-04

# %%
# Get x_val, x_test for the prediction from the last sequence_length days of the training set and the first sequence_length days of the validation set
x_test_pred = np.concatenate((x_train[-sequence_length:], x_test))
print(x_test_pred.shape)
# Predict the values
y_test_pred = model.predict(x_test_pred)

# Inverse the scaling of the predicted values
y_test_pred_unscaled = scaler_pred.inverse_transform(y_test_pred)


# Create a dataframe for the test set matching sliding window
day_test = pd.to_datetime(df_filtered.index[-len(y_test_pred):])
df_test = pd.DataFrame(day_test, columns=['Date'])
df_test['Y_test_pred'] = y_test_pred_unscaled
df_test['Y_test'] = df_filtered['Close'][-len(y_test_pred):].values
df_test.set_index('Date', inplace=True)


# # Plot df_val and df_test
plt.figure(figsize=(15, 7))
plt.plot(df_test['Y_test_pred'], label='Y_test_pred')
plt.plot(df_test['Y_test'], label='Y_test')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()
# Out:
# (396, 7, 6)
# 13/13 [==============================] - 0s 2ms/step

# %%
df_temp = pd.DataFrame(np_data, columns=FEATURES)
# Loop to predict the next day
i = 1
num_days = 90
while i <= num_days:
    # Get the last sequence_length days
    x_pred = df_temp[-sequence_length:]
    x_pred_input = x_pred.values
    x_pred_input = x_pred_input.reshape(1, sequence_length, len(FEATURES))
    print("x_pred_input of day " + str(i) + ": \n" + str(x_pred_input))
    # Predict the value
    y_pred = model.predict(x_pred_input)
    y_pred_unscaled = scaler_pred.inverse_transform(y_pred)
    print("y_pred of day " + str(i) + ": " + str(y_pred_unscaled))
    # unscaling the data df_temp
    df_temp = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
    # Add the predicted value to the df_temp dataframe
    df_temp = pd.concat([df_temp, pd.DataFrame(y_pred_unscaled, columns=['Close'])], ignore_index=True)
    # Create features for the predicted value
    df_temp = createFeatures(df_temp)
    df_temp = df_temp[FEATURES].copy()
    df_temp = df_temp.dropna()
    # Scale the data
    df_temp = pd.DataFrame(scaler.fit_transform(df_temp), columns=FEATURES)

    # Increment the counter
    i += 1
# Out:
# x_pred_input of day 1:
# [[[0.61510439 0.61955538 0.63512207 0.52653685 0.57656614 0.60530042]
#   [0.64055213 0.63046936 0.64170957 0.53855599 0.58334023 0.61300222]
#   [0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140929]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043776]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.6416704 ]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088305]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123953]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 1: [[3419.513]]
# x_pred_input of day 2:
# [[[0.64055213 0.63046936 0.64170957 0.53855599 0.58334023 0.61300228]
#   [0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140936]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70544849 0.71201094 0.70326597 0.59487003 0.63824891 0.67027246]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 2: [[3415.9265]]
# x_pred_input of day 3:
# [[[0.65457486 0.64337293 0.65044849 0.54789037 0.5912452  0.62140936]
#   [0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70544849 0.71201094 0.70326597 0.59487003 0.63824891 0.67027246]
#   [0.70468991 0.71338508 0.71131634 0.6038224  0.64745256 0.67836723]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 3: [[3406.9893]]
# x_pred_input of day 4:
# [[[0.66843457 0.65760921 0.66069708 0.55579894 0.59954033 0.63043782]
#   [0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70544849 0.71201094 0.70326597 0.59487003 0.63824891 0.67027246]
#   [0.70468991 0.71338508 0.71131634 0.6038224  0.64745256 0.67836723]
#   [0.70279954 0.71015606 0.71599386 0.61688666 0.6561229  0.68549711]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 4: [[3394.5295]]
# x_pred_input of day 5:
# [[[0.69829734 0.68048445 0.67479104 0.56272676 0.60904328 0.64167046]
#   [0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70544849 0.71201094 0.70326597 0.59487003 0.63824891 0.67027246]
#   [0.70468991 0.71338508 0.71131634 0.6038224  0.64745256 0.67836723]
#   [0.70279954 0.71015606 0.71599386 0.61688666 0.6561229  0.68549711]
#   [0.70016411 0.70299622 0.72123244 0.62570468 0.66471721 0.69167754]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 5: [[3380.5056]]
# x_pred_input of day 6:
# [[[0.68903629 0.69090322 0.68464211 0.57191485 0.61826595 0.65088311]
#   [0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70544849 0.71201094 0.70326597 0.59487003 0.63824891 0.67027246]
#   [0.70468991 0.71338508 0.71131634 0.6038224  0.64745256 0.67836723]
#   [0.70279954 0.71015606 0.71599386 0.61688666 0.6561229  0.68549711]
#   [0.70016411 0.70299622 0.72123244 0.62570468 0.66471721 0.69167754]
#   [0.69719783 0.6926779  0.72526701 0.63446408 0.67259168 0.69696502]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 6: [[3365.423]]
# x_pred_input of day 7:
# [[[0.70873566 0.70548169 0.69610186 0.58114703 0.62836714 0.66123959]
#   [0.70544849 0.71201094 0.70326597 0.59487003 0.63824891 0.67027246]
#   [0.70468991 0.71338508 0.71131634 0.6038224  0.64745256 0.67836723]
#   [0.70279954 0.71015606 0.71599386 0.61688666 0.6561229  0.68549711]
#   [0.70016411 0.70299622 0.72123244 0.62570468 0.66471721 0.69167754]
#   [0.69719783 0.6926779  0.72526701 0.63446408 0.67259168 0.69696502]
#   [0.69400764 0.67989404 0.72682578 0.64625319 0.68021222 0.70142159]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 7: [[3346.9453]]
# x_pred_input of day 8:
# [[[0.70544849 0.71201094 0.70326597 0.59487003 0.63824891 0.67027246]
#   [0.70468991 0.71338508 0.71131634 0.6038224  0.64745256 0.67836723]
#   [0.70279954 0.71015606 0.71599386 0.61688666 0.6561229  0.68549711]
#   [0.70016411 0.70299622 0.72123244 0.62570468 0.66471721 0.69167754]
#   [0.69719783 0.6926779  0.72526701 0.63446408 0.67259168 0.69696502]
#   [0.69400764 0.67989404 0.72682578 0.64625319 0.68021222 0.70142159]
#   [0.69009929 0.66497608 0.72549781 0.66138117 0.6876139  0.70505272]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 8: [[3325.7578]]
# x_pred_input of day 9:
# [[[0.70468991 0.71338508 0.71131634 0.6038224  0.64745256 0.67836723]
#   [0.70279954 0.71015606 0.71599386 0.61688666 0.6561229  0.68549711]
#   [0.70016411 0.70299622 0.72123244 0.62570468 0.66471721 0.69167754]
#   [0.69719783 0.6926779  0.72526701 0.63446408 0.67259168 0.69696502]
#   [0.69400764 0.67989404 0.72682578 0.64625319 0.68021222 0.70142159]
#   [0.69009929 0.66497608 0.72549781 0.66138117 0.6876139  0.70505272]
#   [0.6856178  0.64827828 0.72450819 0.67336319 0.69350123 0.70787822]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 9: [[3303.4055]]
# x_pred_input of day 10:
# [[[0.70279954 0.71015606 0.71599386 0.61688666 0.6561229  0.68549711]
#   [0.70016411 0.70299622 0.72123244 0.62570468 0.66471721 0.69167754]
#   [0.69719783 0.6926779  0.72526701 0.63446408 0.67259168 0.69696502]
#   [0.69400764 0.67989404 0.72682578 0.64625319 0.68021222 0.70142159]
#   [0.69009929 0.66497608 0.72549781 0.66138117 0.6876139  0.70505272]
#   [0.6856178  0.64827828 0.72450819 0.67336319 0.69350123 0.70787822]
#   [0.68088994 0.63025689 0.72344635 0.68332328 0.69933193 0.70994951]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 10: [[3280.8608]]
# x_pred_input of day 11:
# [[[0.70016411 0.70299622 0.72123244 0.62570468 0.66471721 0.69167754]
#   [0.69719783 0.6926779  0.72526701 0.63446408 0.67259168 0.69696502]
#   [0.69400764 0.67989404 0.72682578 0.64625319 0.68021222 0.70142159]
#   [0.69009929 0.66497608 0.72549781 0.66138117 0.6876139  0.70505272]
#   [0.6856178  0.64827828 0.72450819 0.67336319 0.69350123 0.70787822]
#   [0.68088994 0.63025689 0.72344635 0.68332328 0.69933193 0.70994951]
#   [0.67612138 0.61138414 0.72272058 0.69064984 0.70376706 0.71133428]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 11: [[3260.7786]]
# x_pred_input of day 12:
# [[[0.69719783 0.6926779  0.72526701 0.63446408 0.67259168 0.69696502]
#   [0.69400764 0.67989404 0.72682578 0.64625319 0.68021222 0.70142159]
#   [0.69009929 0.66497608 0.72549781 0.66138117 0.6876139  0.70505272]
#   [0.6856178  0.64827828 0.72450819 0.67336319 0.69350123 0.70787822]
#   [0.68088994 0.63025689 0.72344635 0.68332328 0.69933193 0.70994951]
#   [0.67612138 0.61138414 0.72272058 0.69064984 0.70376706 0.71133428]
#   [0.67187366 0.59231192 0.71992858 0.70095047 0.70761527 0.71215132]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 12: [[3240.5928]]
# x_pred_input of day 13:
# [[[0.69400764 0.67989404 0.72682578 0.64625319 0.68021222 0.70142159]
#   [0.69009929 0.66497608 0.72549781 0.66138117 0.6876139  0.70505272]
#   [0.6856178  0.64827828 0.72450819 0.67336319 0.69350123 0.70787822]
#   [0.68088994 0.63025689 0.72344635 0.68332328 0.69933193 0.70994951]
#   [0.67612138 0.61138414 0.72272058 0.69064984 0.70376706 0.71133428]
#   [0.67187366 0.59231192 0.71992858 0.70095047 0.70761527 0.71215132]
#   [0.66760405 0.57329014 0.71585712 0.71224172 0.71146791 0.71245248]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 13: [[3219.7888]]
# x_pred_input of day 14:
# [[[0.69009929 0.66497608 0.72549781 0.66138117 0.6876139  0.70505272]
#   [0.6856178  0.64827828 0.72450819 0.67336319 0.69350123 0.70787822]
#   [0.68088994 0.63025689 0.72344635 0.68332328 0.69933193 0.70994951]
#   [0.67612138 0.61138414 0.72272058 0.69064984 0.70376706 0.71133428]
#   [0.67187366 0.59231192 0.71992858 0.70095047 0.70761527 0.71215132]
#   [0.66760405 0.57329014 0.71585712 0.71224172 0.71146791 0.71245248]
#   [0.66320368 0.55446128 0.70754533 0.72918105 0.71528717 0.71227346]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 14: [[3197.296]]
# x_pred_input of day 15:
# [[[0.6856178  0.64827828 0.72450819 0.67336319 0.69350123 0.70787822]
#   [0.68088994 0.63025689 0.72344635 0.68332328 0.69933193 0.70994951]
#   [0.67612138 0.61138414 0.72272058 0.69064984 0.70376706 0.71133428]
#   [0.67187366 0.59231192 0.71992858 0.70095047 0.70761527 0.71215132]
#   [0.66760405 0.57329014 0.71585712 0.71224172 0.71146791 0.71245248]
#   [0.66320368 0.55446128 0.70754533 0.72918105 0.71528717 0.71227346]
#   [0.65844608 0.53582497 0.70044318 0.74244767 0.71809394 0.71162334]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 15: [[3172.1392]]
# x_pred_input of day 16:
# [[[0.68088994 0.63025689 0.72344635 0.68332328 0.69933193 0.70994951]
#   [0.67612138 0.61138414 0.72272058 0.69064984 0.70376706 0.71133428]
#   [0.67187366 0.59231192 0.71992858 0.70095047 0.70761527 0.71215132]
#   [0.66760405 0.57329014 0.71585712 0.71224172 0.71146791 0.71245248]
#   [0.66320368 0.55446128 0.70754533 0.72918105 0.71528717 0.71227346]
#   [0.65844608 0.53582497 0.70044318 0.74244767 0.71809394 0.71162334]
#   [0.65312503 0.5172788  0.69855451 0.74609559 0.72010945 0.71048917]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 16: [[3152.1375]]
# x_pred_input of day 17:
# [[[0.67612138 0.61138414 0.72272058 0.69064984 0.70376706 0.71133428]
#   [0.67187366 0.59231192 0.71992858 0.70095047 0.70761527 0.71215132]
#   [0.66760405 0.57329014 0.71585712 0.71224172 0.71146791 0.71245248]
#   [0.66320368 0.55446128 0.70754533 0.72918105 0.71528717 0.71227346]
#   [0.65844608 0.53582497 0.70044318 0.74244767 0.71809394 0.71162334]
#   [0.65312503 0.5172788  0.69855451 0.74609559 0.72010945 0.71048917]
#   [0.64889435 0.49954312 0.69928124 0.7445954  0.72133193 0.70902894]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 17: [[3137.854]]
# x_pred_input of day 18:
# [[[0.67187366 0.59231192 0.71992858 0.70095047 0.70761527 0.71215132]
#   [0.66760405 0.57329014 0.71585712 0.71224172 0.71146791 0.71245248]
#   [0.66320368 0.55446128 0.70754533 0.72918105 0.71528717 0.71227346]
#   [0.65844608 0.53582497 0.70044318 0.74244767 0.71809394 0.71162334]
#   [0.65312503 0.5172788  0.69855451 0.74609559 0.72010945 0.71048917]
#   [0.64889435 0.49954312 0.69928124 0.7445954  0.72133193 0.70902894]
#   [0.64587318 0.48323084 0.70122399 0.73974    0.72280895 0.70739779]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 18: [[3129.3257]]
# x_pred_input of day 19:
# [[[0.66760405 0.57329014 0.71585712 0.71224172 0.71146791 0.71245248]
#   [0.66320368 0.55446128 0.70754533 0.72918105 0.71528717 0.71227346]
#   [0.65844608 0.53582497 0.70044318 0.74244767 0.71809394 0.71162334]
#   [0.65312503 0.5172788  0.69855451 0.74609559 0.72010945 0.71048917]
#   [0.64889435 0.49954312 0.69928124 0.7445954  0.72133193 0.70902894]
#   [0.64587318 0.48323084 0.70122399 0.73974    0.72280895 0.70739779]
#   [0.6440693  0.46880969 0.70112591 0.73364243 0.72420501 0.70573691]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 19: [[3123.1528]]
# x_pred_input of day 20:
# [[[0.66320368 0.55446128 0.70754533 0.72918105 0.71528717 0.71227346]
#   [0.65844608 0.53582497 0.70044318 0.74244767 0.71809394 0.71162334]
#   [0.65312503 0.5172788  0.69855451 0.74609559 0.72010945 0.71048917]
#   [0.64889435 0.49954312 0.69928124 0.7445954  0.72133193 0.70902894]
#   [0.64587318 0.48323084 0.70122399 0.73974    0.72280895 0.70739779]
#   [0.6440693  0.46880969 0.70112591 0.73364243 0.72420501 0.70573691]
#   [0.64276365 0.45627605 0.70150651 0.72789671 0.72598181 0.70410024]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 20: [[3119.0693]]
# x_pred_input of day 21:
# [[[0.65844608 0.53582497 0.70044318 0.74244767 0.71809394 0.71162334]
#   [0.65312503 0.5172788  0.69855451 0.74609559 0.72010945 0.71048917]
#   [0.64889435 0.49954312 0.69928124 0.7445954  0.72133193 0.70902894]
#   [0.64587318 0.48323084 0.70122399 0.73974    0.72280895 0.70739779]
#   [0.6440693  0.46880969 0.70112591 0.73364243 0.72420501 0.70573691]
#   [0.64276365 0.45627605 0.70150651 0.72789671 0.72598181 0.70410024]
#   [0.64189992 0.44557828 0.69825918 0.72403592 0.72709892 0.70253082]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 21: [[3115.3567]]
# x_pred_input of day 22:
# [[[0.65312503 0.5172788  0.69855451 0.74609559 0.72010945 0.71048917]
#   [0.64889435 0.49954312 0.69928124 0.7445954  0.72133193 0.70902894]
#   [0.64587318 0.48323084 0.70122399 0.73974    0.72280895 0.70739779]
#   [0.6440693  0.46880969 0.70112591 0.73364243 0.72420501 0.70573691]
#   [0.64276365 0.45627605 0.70150651 0.72789671 0.72598181 0.70410024]
#   [0.64189992 0.44557828 0.69825918 0.72403592 0.72709892 0.70253082]
#   [0.64111464 0.43647879 0.69477239 0.72074163 0.72712237 0.7010303 ]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 22: [[3110.2366]]
# x_pred_input of day 23:
# [[[0.64889435 0.49954312 0.69928124 0.7445954  0.72133193 0.70902894]
#   [0.64587318 0.48323084 0.70122399 0.73974    0.72280895 0.70739779]
#   [0.6440693  0.46880969 0.70112591 0.73364243 0.72420501 0.70573691]
#   [0.64276365 0.45627605 0.70150651 0.72789671 0.72598181 0.70410024]
#   [0.64189992 0.44557828 0.69825918 0.72403592 0.72709892 0.70253082]
#   [0.64111464 0.43647879 0.69477239 0.72074163 0.72712237 0.7010303 ]
#   [0.64003165 0.42859092 0.69057978 0.7182352  0.72651606 0.69956157]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 23: [[3104.1167]]
# x_pred_input of day 24:
# [[[0.64587318 0.48323084 0.70122399 0.73974    0.72280895 0.70739779]
#   [0.6440693  0.46880969 0.70112591 0.73364243 0.72420501 0.70573691]
#   [0.64276365 0.45627605 0.70150651 0.72789671 0.72598181 0.70410024]
#   [0.64189992 0.44557828 0.69825918 0.72403592 0.72709892 0.70253082]
#   [0.64111464 0.43647879 0.69477239 0.72074163 0.72712237 0.7010303 ]
#   [0.64003165 0.42859092 0.69057978 0.7182352  0.72651606 0.69956157]
#   [0.6387372  0.4216397  0.6859037  0.71636216 0.72527798 0.6980999 ]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 24: [[3096.1885]]
# x_pred_input of day 25:
# [[[0.6440693  0.46880969 0.70112591 0.73364243 0.72420501 0.70573691]
#   [0.64276365 0.45627605 0.70150651 0.72789671 0.72598181 0.70410024]
#   [0.64189992 0.44557828 0.69825918 0.72403592 0.72709892 0.70253082]
#   [0.64111464 0.43647879 0.69477239 0.72074163 0.72712237 0.7010303 ]
#   [0.64003165 0.42859092 0.69057978 0.7182352  0.72651606 0.69956157]
#   [0.6387372  0.4216397  0.6859037  0.71636216 0.72527798 0.6980999 ]
#   [0.63706026 0.41531615 0.68091682 0.7149622  0.72272501 0.69660537]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 25: [[3088.0063]]
# x_pred_input of day 26:
# [[[0.64276365 0.45627605 0.70150651 0.72789671 0.72598181 0.70410024]
#   [0.64189992 0.44557828 0.69825918 0.72403592 0.72709892 0.70253082]
#   [0.64111464 0.43647879 0.69477239 0.72074163 0.72712237 0.7010303 ]
#   [0.64003165 0.42859092 0.69057978 0.7182352  0.72651606 0.69956157]
#   [0.6387372  0.4216397  0.6859037  0.71636216 0.72527798 0.6980999 ]
#   [0.63706026 0.41531615 0.68091682 0.7149622  0.72272501 0.69660537]
#   [0.63532961 0.40953039 0.67568164 0.71399403 0.72048598 0.69507561]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 26: [[3077.6357]]
# x_pred_input of day 27:
# [[[0.64189992 0.44557828 0.69825918 0.72403592 0.72709892 0.70253082]
#   [0.64111464 0.43647879 0.69477239 0.72074163 0.72712237 0.7010303 ]
#   [0.64003165 0.42859092 0.69057978 0.7182352  0.72651606 0.69956157]
#   [0.6387372  0.4216397  0.6859037  0.71636216 0.72527798 0.6980999 ]
#   [0.63706026 0.41531615 0.68091682 0.7149622  0.72272501 0.69660537]
#   [0.63532961 0.40953039 0.67568164 0.71399403 0.72048598 0.69507561]
#   [0.63313606 0.40400753 0.67026787 0.71334877 0.71733423 0.69346648]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 27: [[3067.2305]]
# x_pred_input of day 28:
# [[[0.64111464 0.43647879 0.69477239 0.72074163 0.72712237 0.7010303 ]
#   [0.64003165 0.42859092 0.69057978 0.7182352  0.72651606 0.69956157]
#   [0.6387372  0.4216397  0.6859037  0.71636216 0.72527798 0.6980999 ]
#   [0.63706026 0.41531615 0.68091682 0.7149622  0.72272501 0.69660537]
#   [0.63532961 0.40953039 0.67568164 0.71399403 0.72048598 0.69507561]
#   [0.63313606 0.40400753 0.67026787 0.71334877 0.71733423 0.69346648]
#   [0.63093518 0.39875003 0.66485422 0.71289897 0.71422777 0.69178478]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 28: [[3055.027]]
# x_pred_input of day 29:
# [[[0.64003165 0.42859092 0.69057978 0.7182352  0.72651606 0.69956157]
#   [0.6387372  0.4216397  0.6859037  0.71636216 0.72527798 0.6980999 ]
#   [0.63706026 0.41531615 0.68091682 0.7149622  0.72272501 0.69660537]
#   [0.63532961 0.40953039 0.67568164 0.71399403 0.72048598 0.69507561]
#   [0.63313606 0.40400753 0.67026787 0.71334877 0.71733423 0.69346648]
#   [0.63093518 0.39875003 0.66485422 0.71289897 0.71422777 0.69178478]
#   [0.62835398 0.393576   0.65965257 0.71241907 0.71104533 0.6899984 ]]]
# 1/1 [==============================] - 0s 25ms/step
# y_pred of day 29: [[3042.5918]]
# x_pred_input of day 30:
# [[[0.6387372  0.4216397  0.6859037  0.71636216 0.72527798 0.6980999 ]
#   [0.63706026 0.41531615 0.68091682 0.7149622  0.72272501 0.69660537]
#   [0.63532961 0.40953039 0.67568164 0.71399403 0.72048598 0.69507561]
#   [0.63313606 0.40400753 0.67026787 0.71334877 0.71733423 0.69346648]
#   [0.63093518 0.39875003 0.66485422 0.71289897 0.71422777 0.69178478]
#   [0.62835398 0.393576   0.65965257 0.71241907 0.71104533 0.6899984 ]
#   [0.62572371 0.38850255 0.65479153 0.71178133 0.70783204 0.68811227]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 30: [[3028.5205]]
# x_pred_input of day 31:
# [[[0.63706026 0.41531615 0.68091682 0.7149622  0.72272501 0.69660537]
#   [0.63532961 0.40953039 0.67568164 0.71399403 0.72048598 0.69507561]
#   [0.63313606 0.40400753 0.67026787 0.71334877 0.71733423 0.69346648]
#   [0.63093518 0.39875003 0.66485422 0.71289897 0.71422777 0.69178478]
#   [0.62835398 0.393576   0.65965257 0.71241907 0.71104533 0.6899984 ]
#   [0.62572371 0.38850255 0.65479153 0.71178133 0.70783204 0.68811227]
#   [0.62274741 0.38339798 0.65039296 0.71080833 0.70460454 0.6861004 ]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 31: [[3014.523]]
# x_pred_input of day 32:
# [[[0.63532961 0.40953039 0.67568164 0.71399403 0.72048598 0.69507561]
#   [0.63313606 0.40400753 0.67026787 0.71334877 0.71733423 0.69346648]
#   [0.63093518 0.39875003 0.66485422 0.71289897 0.71422777 0.69178478]
#   [0.62835398 0.393576   0.65965257 0.71241907 0.71104533 0.6899984 ]
#   [0.62572371 0.38850255 0.65479153 0.71178133 0.70783204 0.68811227]
#   [0.62274741 0.38339798 0.65039296 0.71080833 0.70460454 0.6861004 ]
#   [0.61978671 0.37833477 0.64638468 0.70952658 0.70137727 0.68397635]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 32: [[3001.3792]]
# x_pred_input of day 33:
# [[[0.63313606 0.40400753 0.67026787 0.71334877 0.71733423 0.69346648]
#   [0.63093518 0.39875003 0.66485422 0.71289897 0.71422777 0.69178478]
#   [0.62835398 0.393576   0.65965257 0.71241907 0.71104533 0.6899984 ]
#   [0.62572371 0.38850255 0.65479153 0.71178133 0.70783204 0.68811227]
#   [0.62274741 0.38339798 0.65039296 0.71080833 0.70460454 0.6861004 ]
#   [0.61978671 0.37833477 0.64638468 0.70952658 0.70137727 0.68397635]
#   [0.61700659 0.37344919 0.64281524 0.70790251 0.6981671  0.68176934]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 33: [[2988.8137]]
# x_pred_input of day 34:
# [[[0.63093518 0.39875003 0.66485422 0.71289897 0.71422777 0.69178478]
#   [0.62835398 0.393576   0.65965257 0.71241907 0.71104533 0.6899984 ]
#   [0.62572371 0.38850255 0.65479153 0.71178133 0.70783204 0.68811227]
#   [0.62274741 0.38339798 0.65039296 0.71080833 0.70460454 0.6861004 ]
#   [0.61978671 0.37833477 0.64638468 0.70952658 0.70137727 0.68397635]
#   [0.61700659 0.37344919 0.64281524 0.70790251 0.6981671  0.68176934]
#   [0.6143488  0.36881775 0.63976294 0.70587359 0.69500906 0.67949983]]]
# 1/1 [==============================] - 0s 15ms/step
# y_pred of day 34: [[2975.9253]]
# x_pred_input of day 35:
# [[[0.62835398 0.393576   0.65965257 0.71241907 0.71104533 0.6899984 ]
#   [0.62572371 0.38850255 0.65479153 0.71178133 0.70783204 0.68811227]
#   [0.62274741 0.38339798 0.65039296 0.71080833 0.70460454 0.6861004 ]
#   [0.61978671 0.37833477 0.64638468 0.70952658 0.70137727 0.68397635]
#   [0.61700659 0.37344919 0.64281524 0.70790251 0.6981671  0.68176934]
#   [0.6143488  0.36881775 0.63976294 0.70587359 0.69500906 0.67949983]
#   [0.61162269 0.3644051  0.63737312 0.70330304 0.69192421 0.67716675]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 35: [[2964.248]]
# x_pred_input of day 36:
# [[[0.62572371 0.38850255 0.65479153 0.71178133 0.70783204 0.68811227]
#   [0.62274741 0.38339798 0.65039296 0.71080833 0.70460454 0.6861004 ]
#   [0.61978671 0.37833477 0.64638468 0.70952658 0.70137727 0.68397635]
#   [0.61700659 0.37344919 0.64281524 0.70790251 0.6981671  0.68176934]
#   [0.6143488  0.36881775 0.63976294 0.70587359 0.69500906 0.67949983]
#   [0.61162269 0.3644051  0.63737312 0.70330304 0.69192421 0.67716675]
#   [0.60915277 0.36033832 0.63574119 0.70017322 0.68893349 0.67480244]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 36: [[2953.174]]
# x_pred_input of day 37:
# [[[0.62274741 0.38339798 0.65039296 0.71080833 0.70460454 0.6861004 ]
#   [0.61978671 0.37833477 0.64638468 0.70952658 0.70137727 0.68397635]
#   [0.61700659 0.37344919 0.64281524 0.70790251 0.6981671  0.68176934]
#   [0.6143488  0.36881775 0.63976294 0.70587359 0.69500906 0.67949983]
#   [0.61162269 0.3644051  0.63737312 0.70330304 0.69192421 0.67716675]
#   [0.60915277 0.36033832 0.63574119 0.70017322 0.68893349 0.67480244]
#   [0.60681045 0.35665072 0.63456178 0.6967308  0.68604392 0.67242298]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 37: [[2942.5403]]
# x_pred_input of day 38:
# [[[0.61978671 0.37833477 0.64638468 0.70952658 0.70137727 0.68397635]
#   [0.61700659 0.37344919 0.64281524 0.70790251 0.6981671  0.68176934]
#   [0.6143488  0.36881775 0.63976294 0.70587359 0.69500906 0.67949983]
#   [0.61162269 0.3644051  0.63737312 0.70330304 0.69192421 0.67716675]
#   [0.60915277 0.36033832 0.63574119 0.70017322 0.68893349 0.67480244]
#   [0.60681045 0.35665072 0.63456178 0.6967308  0.68604392 0.67242298]
#   [0.60456124 0.35334735 0.63355326 0.69317705 0.68323766 0.67003935]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 38: [[2931.4487]]
# x_pred_input of day 39:
# [[[0.61700659 0.37344919 0.64281524 0.70790251 0.6981671  0.68176934]
#   [0.6143488  0.36881775 0.63976294 0.70587359 0.69500906 0.67949983]
#   [0.61162269 0.3644051  0.63737312 0.70330304 0.69192421 0.67716675]
#   [0.60915277 0.36033832 0.63574119 0.70017322 0.68893349 0.67480244]
#   [0.60681045 0.35665072 0.63456178 0.6967308  0.68604392 0.67242298]
#   [0.60456124 0.35334735 0.63355326 0.69317705 0.68323766 0.67003935]
#   [0.6022152  0.35033574 0.63249092 0.68962411 0.6805116  0.66764203]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 39: [[2920.4224]]
# x_pred_input of day 40:
# [[[0.6143488  0.36881775 0.63976294 0.70587359 0.69500906 0.67949983]
#   [0.61162269 0.3644051  0.63737312 0.70330304 0.69192421 0.67716675]
#   [0.60915277 0.36033832 0.63574119 0.70017322 0.68893349 0.67480244]
#   [0.60681045 0.35665072 0.63456178 0.6967308  0.68604392 0.67242298]
#   [0.60456124 0.35334735 0.63355326 0.69317705 0.68323766 0.67003935]
#   [0.6022152  0.35033574 0.63249092 0.68962411 0.6805116  0.66764203]
#   [0.59988295 0.34759371 0.63127235 0.68613618 0.67787176 0.66523372]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 40: [[2911.2917]]
# x_pred_input of day 41:
# [[[0.61162269 0.3644051  0.63737312 0.70330304 0.69192421 0.67716675]
#   [0.60915277 0.36033832 0.63574119 0.70017322 0.68893349 0.67480244]
#   [0.60681045 0.35665072 0.63456178 0.6967308  0.68604392 0.67242298]
#   [0.60456124 0.35334735 0.63355326 0.69317705 0.68323766 0.67003935]
#   [0.6022152  0.35033574 0.63249092 0.68962411 0.6805116  0.66764203]
#   [0.59988295 0.34759371 0.63127235 0.68613618 0.67787176 0.66523372]
#   [0.59795168 0.3452885  0.62975336 0.6828771  0.67534975 0.66285662]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 41: [[2902.147]]
# x_pred_input of day 42:
# [[[0.60915277 0.36033832 0.63574119 0.70017322 0.68893349 0.67480244]
#   [0.60681045 0.35665072 0.63456178 0.6967308  0.68604392 0.67242298]
#   [0.60456124 0.35334735 0.63355326 0.69317705 0.68323766 0.67003935]
#   [0.6022152  0.35033574 0.63249092 0.68962411 0.6805116  0.66764203]
#   [0.59988295 0.34759371 0.63127235 0.68613618 0.67787176 0.66523372]
#   [0.59795168 0.3452885  0.62975336 0.6828771  0.67534975 0.66285662]
#   [0.59601741 0.34335035 0.62790588 0.67987037 0.67296894 0.66050745]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 42: [[2892.4436]]
# x_pred_input of day 43:
# [[[0.60681045 0.35665072 0.63456178 0.6967308  0.68604392 0.67242298]
#   [0.60456124 0.35334735 0.63355326 0.69317705 0.68323766 0.67003935]
#   [0.6022152  0.35033574 0.63249092 0.68962411 0.6805116  0.66764203]
#   [0.59988295 0.34759371 0.63127235 0.68613618 0.67787176 0.66523372]
#   [0.59795168 0.3452885  0.62975336 0.6828771  0.67534975 0.66285662]
#   [0.59601741 0.34335035 0.62790588 0.67987037 0.67296894 0.66050745]
#   [0.593965   0.3416646  0.62578483 0.67707235 0.67067893 0.65817142]]]
# 1/1 [==============================] - 0s 26ms/step
# y_pred of day 43: [[2881.235]]
# x_pred_input of day 44:
# [[[0.60456124 0.35334735 0.63355326 0.69317705 0.68323766 0.67003935]
#   [0.6022152  0.35033574 0.63249092 0.68962411 0.6805116  0.66764203]
#   [0.59988295 0.34759371 0.63127235 0.68613618 0.67787176 0.66523372]
#   [0.59795168 0.3452885  0.62975336 0.6828771  0.67534975 0.66285662]
#   [0.59601741 0.34335035 0.62790588 0.67987037 0.67296894 0.66050745]
#   [0.593965   0.3416646  0.62578483 0.67707235 0.67067893 0.65817142]
#   [0.59159422 0.34004149 0.62344916 0.67440189 0.66841605 0.65581462]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 44: [[2871.0366]]
# x_pred_input of day 45:
# [[[0.6022152  0.35033574 0.63249092 0.68962411 0.6805116  0.66764203]
#   [0.59988295 0.34759371 0.63127235 0.68613618 0.67787176 0.66523372]
#   [0.59795168 0.3452885  0.62975336 0.6828771  0.67534975 0.66285662]
#   [0.59601741 0.34335035 0.62790588 0.67987037 0.67296894 0.66050745]
#   [0.593965   0.3416646  0.62578483 0.67707235 0.67067893 0.65817142]
#   [0.59159422 0.34004149 0.62344916 0.67440189 0.66841605 0.65581462]
#   [0.58943708 0.33858952 0.62093783 0.67188175 0.66613843 0.65346094]]]
# 1/1 [==============================] - 0s 48ms/step
# y_pred of day 45: [[2859.6516]]
# x_pred_input of day 46:
# [[[0.59988295 0.34759371 0.63127235 0.68613618 0.67787176 0.66523372]
#   [0.59795168 0.3452885  0.62975336 0.6828771  0.67534975 0.66285662]
#   [0.59601741 0.34335035 0.62790588 0.67987037 0.67296894 0.66050745]
#   [0.593965   0.3416646  0.62578483 0.67707235 0.67067893 0.65817142]
#   [0.59159422 0.34004149 0.62344916 0.67440189 0.66841605 0.65581462]
#   [0.58943708 0.33858952 0.62093783 0.67188175 0.66613843 0.65346094]
#   [0.58702897 0.33716651 0.61827643 0.66945941 0.66381485 0.65108435]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 46: [[2847.7053]]
# x_pred_input of day 47:
# [[[0.59795168 0.3452885  0.62975336 0.6828771  0.67534975 0.66285662]
#   [0.59601741 0.34335035 0.62790588 0.67987037 0.67296894 0.66050745]
#   [0.593965   0.3416646  0.62578483 0.67707235 0.67067893 0.65817142]
#   [0.59159422 0.34004149 0.62344916 0.67440189 0.66841605 0.65581462]
#   [0.58943708 0.33858952 0.62093783 0.67188175 0.66613843 0.65346094]
#   [0.58702897 0.33716651 0.61827643 0.66945941 0.66381485 0.65108435]
#   [0.58450214 0.33572488 0.61557134 0.66704995 0.66142194 0.64867483]]]
# 1/1 [==============================] - 0s 22ms/step
# y_pred of day 47: [[2835.7747]]
# x_pred_input of day 48:
# [[[0.59601741 0.34335035 0.62790588 0.67987037 0.67296894 0.66050745]
#   [0.593965   0.3416646  0.62578483 0.67707235 0.67067893 0.65817142]
#   [0.59159422 0.34004149 0.62344916 0.67440189 0.66841605 0.65581462]
#   [0.58943708 0.33858952 0.62093783 0.67188175 0.66613843 0.65346094]
#   [0.58702897 0.33716651 0.61827643 0.66945941 0.66381485 0.65108435]
#   [0.58450214 0.33572488 0.61557134 0.66704995 0.66142194 0.64867483]
#   [0.58197862 0.33428668 0.61281675 0.66466141 0.65895656 0.64623587]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 48: [[2823.723]]
# x_pred_input of day 49:
# [[[0.593965   0.3416646  0.62578483 0.67707235 0.67067893 0.65817142]
#   [0.59159422 0.34004149 0.62344916 0.67440189 0.66841605 0.65581462]
#   [0.58943708 0.33858952 0.62093783 0.67188175 0.66613843 0.65346094]
#   [0.58702897 0.33716651 0.61827643 0.66945941 0.66381485 0.65108435]
#   [0.58450214 0.33572488 0.61557134 0.66704995 0.66142194 0.64867483]
#   [0.58197862 0.33428668 0.61281675 0.66466141 0.65895656 0.64623587]
#   [0.57942948 0.33285515 0.61010216 0.66222977 0.65643006 0.64376764]]]
# 1/1 [==============================] - 0s 24ms/step
# y_pred of day 49: [[2812.0264]]
# x_pred_input of day 50:
# [[[0.59159422 0.34004149 0.62344916 0.67440189 0.66841605 0.65581462]
#   [0.58943708 0.33858952 0.62093783 0.67188175 0.66613843 0.65346094]
#   [0.58702897 0.33716651 0.61827643 0.66945941 0.66381485 0.65108435]
#   [0.58450214 0.33572488 0.61557134 0.66704995 0.66142194 0.64867483]
#   [0.58197862 0.33428668 0.61281675 0.66466141 0.65895656 0.64623587]
#   [0.57942948 0.33285515 0.61010216 0.66222977 0.65643006 0.64376764]
#   [0.57695548 0.33148157 0.60743262 0.65976337 0.65385438 0.64128064]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 50: [[2800.7996]]
# x_pred_input of day 51:
# [[[0.58943708 0.33858952 0.62093783 0.67188175 0.66613843 0.65346094]
#   [0.58702897 0.33716651 0.61827643 0.66945941 0.66381485 0.65108435]
#   [0.58450214 0.33572488 0.61557134 0.66704995 0.66142194 0.64867483]
#   [0.58197862 0.33428668 0.61281675 0.66466141 0.65895656 0.64623587]
#   [0.57942948 0.33285515 0.61010216 0.66222977 0.65643006 0.64376764]
#   [0.57695548 0.33148157 0.60743262 0.65976337 0.65385438 0.64128064]
#   [0.57458083 0.33021721 0.6048848  0.65722364 0.65124961 0.63878685]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 51: [[2789.2258]]
# x_pred_input of day 52:
# [[[0.58702897 0.33716651 0.61827643 0.66945941 0.66381485 0.65108435]
#   [0.58450214 0.33572488 0.61557134 0.66704995 0.66142194 0.64867483]
#   [0.58197862 0.33428668 0.61281675 0.66466141 0.65895656 0.64623587]
#   [0.57942948 0.33285515 0.61010216 0.66222977 0.65643006 0.64376764]
#   [0.57695548 0.33148157 0.60743262 0.65976337 0.65385438 0.64128064]
#   [0.57458083 0.33021721 0.6048848  0.65722364 0.65124961 0.63878685]
#   [0.57213281 0.32901727 0.60247422 0.65458221 0.64861494 0.63627938]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 52: [[2777.9402]]
# x_pred_input of day 53:
# [[[0.58450214 0.33572488 0.61557134 0.66704995 0.66142194 0.64867483]
#   [0.58197862 0.33428668 0.61281675 0.66466141 0.65895656 0.64623587]
#   [0.57942948 0.33285515 0.61010216 0.66222977 0.65643006 0.64376764]
#   [0.57695548 0.33148157 0.60743262 0.65976337 0.65385438 0.64128064]
#   [0.57458083 0.33021721 0.6048848  0.65722364 0.65124961 0.63878685]
#   [0.57213281 0.32901727 0.60247422 0.65458221 0.64861494 0.63627938]
#   [0.56974572 0.32791099 0.60015866 0.65187474 0.6459722  0.6337658 ]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 53: [[2766.3188]]
# x_pred_input of day 54:
# [[[0.58197862 0.33428668 0.61281675 0.66466141 0.65895656 0.64623587]
#   [0.57942948 0.33285515 0.61010216 0.66222977 0.65643006 0.64376764]
#   [0.57695548 0.33148157 0.60743262 0.65976337 0.65385438 0.64128064]
#   [0.57458083 0.33021721 0.6048848  0.65722364 0.65124961 0.63878685]
#   [0.57213281 0.32901727 0.60247422 0.65458221 0.64861494 0.63627938]
#   [0.56974572 0.32791099 0.60015866 0.65187474 0.6459722  0.6337658 ]
#   [0.56728762 0.3268563  0.59792386 0.64909575 0.64331873 0.63123939]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 54: [[2755.4104]]
# x_pred_input of day 55:
# [[[0.57942948 0.33285515 0.61010216 0.66222977 0.65643006 0.64376764]
#   [0.57695548 0.33148157 0.60743262 0.65976337 0.65385438 0.64128064]
#   [0.57458083 0.33021721 0.6048848  0.65722364 0.65124961 0.63878685]
#   [0.57213281 0.32901727 0.60247422 0.65458221 0.64861494 0.63627938]
#   [0.56974572 0.32791099 0.60015866 0.65187474 0.6459722  0.6337658 ]
#   [0.56728762 0.3268563  0.59792386 0.64909575 0.64331873 0.63123939]
#   [0.56498031 0.32592714 0.59576972 0.64627045 0.64067669 0.62871686]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 55: [[2744.1265]]
# x_pred_input of day 56:
# [[[0.57695548 0.33148157 0.60743262 0.65976337 0.65385438 0.64128064]
#   [0.57458083 0.33021721 0.6048848  0.65722364 0.65124961 0.63878685]
#   [0.57213281 0.32901727 0.60247422 0.65458221 0.64861494 0.63627938]
#   [0.56974572 0.32791099 0.60015866 0.65187474 0.6459722  0.6337658 ]
#   [0.56728762 0.3268563  0.59792386 0.64909575 0.64331873 0.63123939]
#   [0.56498031 0.32592714 0.59576972 0.64627045 0.64067669 0.62871686]
#   [0.56259358 0.3250684  0.59365292 0.64341104 0.63804479 0.62618968]]]
# 1/1 [==============================] - 0s 21ms/step
# y_pred of day 56: [[2732.1816]]
# x_pred_input of day 57:
# [[[0.57458083 0.33021721 0.6048848  0.65722364 0.65124961 0.63878685]
#   [0.57213281 0.32901727 0.60247422 0.65458221 0.64861494 0.63627938]
#   [0.56974572 0.32791099 0.60015866 0.65187474 0.6459722  0.6337658 ]
#   [0.56728762 0.3268563  0.59792386 0.64909575 0.64331873 0.63123939]
#   [0.56498031 0.32592714 0.59576972 0.64627045 0.64067669 0.62871686]
#   [0.56259358 0.3250684  0.59365292 0.64341104 0.63804479 0.62618968]
#   [0.56006706 0.32420688 0.59156198 0.64050029 0.63543165 0.62364395]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 57: [[2721.2693]]
# x_pred_input of day 58:
# [[[0.57213281 0.32901727 0.60247422 0.65458221 0.64861494 0.63627938]
#   [0.56974572 0.32791099 0.60015866 0.65187474 0.6459722  0.6337658 ]
#   [0.56728762 0.3268563  0.59792386 0.64909575 0.64331873 0.63123939]
#   [0.56498031 0.32592714 0.59576972 0.64627045 0.64067669 0.62871686]
#   [0.56259358 0.3250684  0.59365292 0.64341104 0.63804479 0.62618968]
#   [0.56006706 0.32420688 0.59156198 0.64050029 0.63543165 0.62364395]
#   [0.55775892 0.32345885 0.58944634 0.63761167 0.63284571 0.62110385]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 58: [[2710.0105]]
# x_pred_input of day 59:
# [[[0.56974572 0.32791099 0.60015866 0.65187474 0.6459722  0.6337658 ]
#   [0.56728762 0.3268563  0.59792386 0.64909575 0.64331873 0.63123939]
#   [0.56498031 0.32592714 0.59576972 0.64627045 0.64067669 0.62871686]
#   [0.56259358 0.3250684  0.59365292 0.64341104 0.63804479 0.62618968]
#   [0.56006706 0.32420688 0.59156198 0.64050029 0.63543165 0.62364395]
#   [0.55775892 0.32345885 0.58944634 0.63761167 0.63284571 0.62110385]
#   [0.55537751 0.32277274 0.58733573 0.63471312 0.6302764  0.61856133]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 59: [[2698.7434]]
# x_pred_input of day 60:
# [[[0.56728762 0.3268563  0.59792386 0.64909575 0.64331873 0.63123939]
#   [0.56498031 0.32592714 0.59576972 0.64627045 0.64067669 0.62871686]
#   [0.56259358 0.3250684  0.59365292 0.64341104 0.63804479 0.62618968]
#   [0.56006706 0.32420688 0.59156198 0.64050029 0.63543165 0.62364395]
#   [0.55775892 0.32345885 0.58944634 0.63761167 0.63284571 0.62110385]
#   [0.55537751 0.32277274 0.58733573 0.63471312 0.6302764  0.61856133]
#   [0.55299435 0.32214212 0.58522655 0.63180707 0.62771853 0.61601642]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 60: [[2688.9138]]
# x_pred_input of day 61:
# [[[0.56498031 0.32592714 0.59576972 0.64627045 0.64067669 0.62871686]
#   [0.56259358 0.3250684  0.59365292 0.64341104 0.63804479 0.62618968]
#   [0.56006706 0.32420688 0.59156198 0.64050029 0.63543165 0.62364395]
#   [0.55775892 0.32345885 0.58944634 0.63761167 0.63284571 0.62110385]
#   [0.55537751 0.32277274 0.58733573 0.63471312 0.6302764  0.61856133]
#   [0.55299435 0.32214212 0.58522655 0.63180707 0.62771853 0.61601642]
#   [0.55091523 0.32170953 0.58299301 0.62902944 0.62518764 0.61350056]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 61: [[2677.9006]]
# x_pred_input of day 62:
# [[[0.56259358 0.3250684  0.59365292 0.64341104 0.63804479 0.62618968]
#   [0.56006706 0.32420688 0.59156198 0.64050029 0.63543165 0.62364395]
#   [0.55775892 0.32345885 0.58944634 0.63761167 0.63284571 0.62110385]
#   [0.55537751 0.32277274 0.58733573 0.63471312 0.6302764  0.61856133]
#   [0.55299435 0.32214212 0.58522655 0.63180707 0.62771853 0.61601642]
#   [0.55091523 0.32170953 0.58299301 0.62902944 0.62518764 0.61350056]
#   [0.54858577 0.32131567 0.58066175 0.62632075 0.6226626  0.6109853 ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 62: [[2667.8127]]
# x_pred_input of day 63:
# [[[0.56006706 0.32420688 0.59156198 0.64050029 0.63543165 0.62364395]
#   [0.55775892 0.32345885 0.58944634 0.63761167 0.63284571 0.62110385]
#   [0.55537751 0.32277274 0.58733573 0.63471312 0.6302764  0.61856133]
#   [0.55299435 0.32214212 0.58522655 0.63180707 0.62771853 0.61601642]
#   [0.55091523 0.32170953 0.58299301 0.62902944 0.62518764 0.61350056]
#   [0.54858577 0.32131567 0.58066175 0.62632075 0.6226626  0.6109853 ]
#   [0.54645202 0.32105153 0.57822987 0.62372037 0.62014626 0.60849065]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 63: [[2656.6702]]
# x_pred_input of day 64:
# [[[0.55775892 0.32345885 0.58944634 0.63761167 0.63284571 0.62110385]
#   [0.55537751 0.32277274 0.58733573 0.63471312 0.6302764  0.61856133]
#   [0.55299435 0.32214212 0.58522655 0.63180707 0.62771853 0.61601642]
#   [0.55091523 0.32170953 0.58299301 0.62902944 0.62518764 0.61350056]
#   [0.54858577 0.32131567 0.58066175 0.62632075 0.6226626  0.6109853 ]
#   [0.54645202 0.32105153 0.57822987 0.62372037 0.62014626 0.60849065]
#   [0.54409519 0.32078388 0.57579433 0.62112585 0.61762543 0.60599177]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 64: [[2645.613]]
# x_pred_input of day 65:
# [[[0.55537751 0.32277274 0.58733573 0.63471312 0.6302764  0.61856133]
#   [0.55299435 0.32214212 0.58522655 0.63180707 0.62771853 0.61601642]
#   [0.55091523 0.32170953 0.58299301 0.62902944 0.62518764 0.61350056]
#   [0.54858577 0.32131567 0.58066175 0.62632075 0.6226626  0.6109853 ]
#   [0.54645202 0.32105153 0.57822987 0.62372037 0.62014626 0.60849065]
#   [0.54409519 0.32078388 0.57579433 0.62112585 0.61762543 0.60599177]
#   [0.54175643 0.32052529 0.57330311 0.61857562 0.61510491 0.60349092]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 65: [[2635.7087]]
# x_pred_input of day 66:
# [[[0.55299435 0.32214212 0.58522655 0.63180707 0.62771853 0.61601642]
#   [0.55091523 0.32170953 0.58299301 0.62902944 0.62518764 0.61350056]
#   [0.54858577 0.32131567 0.58066175 0.62632075 0.6226626  0.6109853 ]
#   [0.54645202 0.32105153 0.57822987 0.62372037 0.62014626 0.60849065]
#   [0.54409519 0.32078388 0.57579433 0.62112585 0.61762543 0.60599177]
#   [0.54175643 0.32052529 0.57330311 0.61857562 0.61510491 0.60349092]
#   [0.53966152 0.32039496 0.57078381 0.61609408 0.61259428 0.60101329]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 66: [[2624.5784]]
# x_pred_input of day 67:
# [[[0.55091523 0.32170953 0.58299301 0.62902944 0.62518764 0.61350056]
#   [0.54858577 0.32131567 0.58066175 0.62632075 0.6226626  0.6109853 ]
#   [0.54645202 0.32105153 0.57822987 0.62372037 0.62014626 0.60849065]
#   [0.54409519 0.32078388 0.57579433 0.62112585 0.61762543 0.60599177]
#   [0.54175643 0.32052529 0.57330311 0.61857562 0.61510491 0.60349092]
#   [0.53966152 0.32039496 0.57078381 0.61609408 0.61259428 0.60101329]
#   [0.53730727 0.32024088 0.56829909 0.6135919  0.61006601 0.59853007]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 67: [[2613.4512]]
# x_pred_input of day 68:
# [[[0.54858577 0.32131567 0.58066175 0.62632075 0.6226626  0.6109853 ]
#   [0.54645202 0.32105153 0.57822987 0.62372037 0.62014626 0.60849065]
#   [0.54409519 0.32078388 0.57579433 0.62112585 0.61762543 0.60599177]
#   [0.54175643 0.32052529 0.57330311 0.61857562 0.61510491 0.60349092]
#   [0.53966152 0.32039496 0.57078381 0.61609408 0.61259428 0.60101329]
#   [0.53730727 0.32024088 0.56829909 0.6135919  0.61006601 0.59853007]
#   [0.53495369 0.32007028 0.56585142 0.61106588 0.60752027 0.59604187]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 68: [[2603.7935]]
# x_pred_input of day 69:
# [[[0.54645202 0.32105153 0.57822987 0.62372037 0.62014626 0.60849065]
#   [0.54409519 0.32078388 0.57579433 0.62112585 0.61762543 0.60599177]
#   [0.54175643 0.32052529 0.57330311 0.61857562 0.61510491 0.60349092]
#   [0.53966152 0.32039496 0.57078381 0.61609408 0.61259428 0.60101329]
#   [0.53730727 0.32024088 0.56829909 0.6135919  0.61006601 0.59853007]
#   [0.53495369 0.32007028 0.56585142 0.61106588 0.60752027 0.59604187]
#   [0.53291093 0.32003935 0.56341446 0.60858535 0.60497493 0.59358104]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 69: [[2593.0325]]
# x_pred_input of day 70:
# [[[0.54409519 0.32078388 0.57579433 0.62112585 0.61762543 0.60599177]
#   [0.54175643 0.32052529 0.57330311 0.61857562 0.61510491 0.60349092]
#   [0.53966152 0.32039496 0.57078381 0.61609408 0.61259428 0.60101329]
#   [0.53730727 0.32024088 0.56829909 0.6135919  0.61006601 0.59853007]
#   [0.53495369 0.32007028 0.56585142 0.61106588 0.60752027 0.59604187]
#   [0.53291093 0.32003935 0.56341446 0.60858535 0.60497493 0.59358104]
#   [0.53063481 0.32000507 0.56100587 0.60609433 0.60243353 0.59112104]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 70: [[2583.1719]]
# x_pred_input of day 71:
# [[[0.54175643 0.32052529 0.57330311 0.61857562 0.61510491 0.60349092]
#   [0.53966152 0.32039496 0.57078381 0.61609408 0.61259428 0.60101329]
#   [0.53730727 0.32024088 0.56829909 0.6135919  0.61006601 0.59853007]
#   [0.53495369 0.32007028 0.56585142 0.61106588 0.60752027 0.59604187]
#   [0.53291093 0.32003935 0.56341446 0.60858535 0.60497493 0.59358104]
#   [0.53063481 0.32000507 0.56100587 0.60609433 0.60243353 0.59112104]
#   [0.52854914 0.32006088 0.55858409 0.60365183 0.59989511 0.58868132]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 71: [[2572.116]]
# x_pred_input of day 72:
# [[[0.53966152 0.32039496 0.57078381 0.61609408 0.61259428 0.60101329]
#   [0.53730727 0.32024088 0.56829909 0.6135919  0.61006601 0.59853007]
#   [0.53495369 0.32007028 0.56585142 0.61106588 0.60752027 0.59604187]
#   [0.53291093 0.32003935 0.56341446 0.60858535 0.60497493 0.59358104]
#   [0.53063481 0.32000507 0.56100587 0.60609433 0.60243353 0.59112104]
#   [0.52854914 0.32006088 0.55858409 0.60365183 0.59989511 0.58868132]
#   [0.52621064 0.32006409 0.55620017 0.60117762 0.5973596  0.58623402]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 72: [[2562.6807]]
# x_pred_input of day 73:
# [[[0.53730727 0.32024088 0.56829909 0.6135919  0.61006601 0.59853007]
#   [0.53495369 0.32007028 0.56585142 0.61106588 0.60752027 0.59604187]
#   [0.53291093 0.32003935 0.56341446 0.60858535 0.60497493 0.59358104]
#   [0.53063481 0.32000507 0.56100587 0.60609433 0.60243353 0.59112104]
#   [0.52854914 0.32006088 0.55858409 0.60365183 0.59989511 0.58868132]
#   [0.52621064 0.32006409 0.55620017 0.60117762 0.5973596  0.58623402]
#   [0.52421492 0.3201922  0.5538027  0.59876408 0.59484622 0.58381503]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 73: [[2553.4424]]
# x_pred_input of day 74:
# [[[0.53495369 0.32007028 0.56585142 0.61106588 0.60752027 0.59604187]
#   [0.53291093 0.32003935 0.56341446 0.60858535 0.60497493 0.59358104]
#   [0.53063481 0.32000507 0.56100587 0.60609433 0.60243353 0.59112104]
#   [0.52854914 0.32006088 0.55858409 0.60365183 0.59989511 0.58868132]
#   [0.52621064 0.32006409 0.55620017 0.60117762 0.5973596  0.58623402]
#   [0.52421492 0.3201922  0.5538027  0.59876408 0.59484622 0.58381503]
#   [0.52226088 0.32043691 0.55141057 0.59640205 0.59235659 0.58142593]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 74: [[2544.129]]
# x_pred_input of day 75:
# [[[0.53291093 0.32003935 0.56341446 0.60858535 0.60497493 0.59358104]
#   [0.53063481 0.32000507 0.56100587 0.60609433 0.60243353 0.59112104]
#   [0.52854914 0.32006088 0.55858409 0.60365183 0.59989511 0.58868132]
#   [0.52621064 0.32006409 0.55620017 0.60117762 0.5973596  0.58623402]
#   [0.52421492 0.3201922  0.5538027  0.59876408 0.59484622 0.58381503]
#   [0.52226088 0.32043691 0.55141057 0.59640205 0.59235659 0.58142593]
#   [0.52029093 0.32076247 0.54899869 0.59410175 0.58989111 0.57906223]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 75: [[2534.6665]]
# x_pred_input of day 76:
# [[[0.53063481 0.32000507 0.56100587 0.60609433 0.60243353 0.59112104]
#   [0.52854914 0.32006088 0.55858409 0.60365183 0.59989511 0.58868132]
#   [0.52621064 0.32006409 0.55620017 0.60117762 0.5973596  0.58623402]
#   [0.52421492 0.3201922  0.5538027  0.59876408 0.59484622 0.58381503]
#   [0.52226088 0.32043691 0.55141057 0.59640205 0.59235659 0.58142593]
#   [0.52029093 0.32076247 0.54899869 0.59410175 0.58989111 0.57906223]
#   [0.51828949 0.3211324  0.54659498 0.59183604 0.58744532 0.5767183 ]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 76: [[2523.511]]
# x_pred_input of day 77:
# [[[0.52854914 0.32006088 0.55858409 0.60365183 0.59989511 0.58868132]
#   [0.52621064 0.32006409 0.55620017 0.60117762 0.5973596  0.58623402]
#   [0.52421492 0.3201922  0.5538027  0.59876408 0.59484622 0.58381503]
#   [0.52226088 0.32043691 0.55141057 0.59640205 0.59235659 0.58142593]
#   [0.52029093 0.32076247 0.54899869 0.59410175 0.58989111 0.57906223]
#   [0.51828949 0.3211324  0.54659498 0.59183604 0.58744532 0.5767183 ]
#   [0.51592992 0.32135928 0.5442795  0.58948632 0.58500017 0.57435549]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 77: [[2514.067]]
# x_pred_input of day 78:
# [[[0.52621064 0.32006409 0.55620017 0.60117762 0.5973596  0.58623402]
#   [0.52421492 0.3201922  0.5538027  0.59876408 0.59484622 0.58381503]
#   [0.52226088 0.32043691 0.55141057 0.59640205 0.59235659 0.58142593]
#   [0.52029093 0.32076247 0.54899869 0.59410175 0.58989111 0.57906223]
#   [0.51828949 0.3211324  0.54659498 0.59183604 0.58744532 0.5767183 ]
#   [0.51592992 0.32135928 0.5442795  0.58948632 0.58500017 0.57435549]
#   [0.51393234 0.32164698 0.54196324 0.58717309 0.58257379 0.57201276]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 78: [[2504.6223]]
# x_pred_input of day 79:
# [[[0.52421492 0.3201922  0.5538027  0.59876408 0.59484622 0.58381503]
#   [0.52226088 0.32043691 0.55141057 0.59640205 0.59235659 0.58142593]
#   [0.52029093 0.32076247 0.54899869 0.59410175 0.58989111 0.57906223]
#   [0.51828949 0.3211324  0.54659498 0.59183604 0.58744532 0.5767183 ]
#   [0.51592992 0.32135928 0.5442795  0.58948632 0.58500017 0.57435549]
#   [0.51393234 0.32164698 0.54196324 0.58717309 0.58257379 0.57201276]
#   [0.51193467 0.32197899 0.53966888 0.58487823 0.58016365 0.56968817]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 79: [[2494.443]]
# x_pred_input of day 80:
# [[[0.52226088 0.32043691 0.55141057 0.59640205 0.59235659 0.58142593]
#   [0.52029093 0.32076247 0.54899869 0.59410175 0.58989111 0.57906223]
#   [0.51828949 0.3211324  0.54659498 0.59183604 0.58744532 0.5767183 ]
#   [0.51592992 0.32135928 0.5442795  0.58948632 0.58500017 0.57435549]
#   [0.51393234 0.32164698 0.54196324 0.58717309 0.58257379 0.57201276]
#   [0.51193467 0.32197899 0.53966888 0.58487823 0.58016365 0.56968817]
#   [0.5097816  0.32226662 0.53742109 0.58255528 0.57776623 0.56736406]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 80: [[2484.8838]]
# x_pred_input of day 81:
# [[[0.52029093 0.32076247 0.54899869 0.59410175 0.58989111 0.57906223]
#   [0.51828949 0.3211324  0.54659498 0.59183604 0.58744532 0.5767183 ]
#   [0.51592992 0.32135928 0.5442795  0.58948632 0.58500017 0.57435549]
#   [0.51393234 0.32164698 0.54196324 0.58717309 0.58257379 0.57201276]
#   [0.51193467 0.32197899 0.53966888 0.58487823 0.58016365 0.56968817]
#   [0.5097816  0.32226662 0.53742109 0.58255528 0.57776623 0.56736406]
#   [0.50775966 0.32257975 0.5351375  0.58028073 0.5753807  0.56505384]]]
# 1/1 [==============================] - 0s 105ms/step
# y_pred of day 81: [[2475.4802]]
# x_pred_input of day 82:
# [[[0.51828949 0.3211324  0.54659498 0.59183604 0.58744532 0.5767183 ]
#   [0.51592992 0.32135928 0.5442795  0.58948632 0.58500017 0.57435549]
#   [0.51393234 0.32164698 0.54196324 0.58717309 0.58257379 0.57201276]
#   [0.51193467 0.32197899 0.53966888 0.58487823 0.58016365 0.56968817]
#   [0.5097816  0.32226662 0.53742109 0.58255528 0.57776623 0.56736406]
#   [0.50775966 0.32257975 0.5351375  0.58028073 0.5753807  0.56505384]
#   [0.50577065 0.32292526 0.53287428 0.57802137 0.57301175 0.56275955]]]
# 1/1 [==============================] - 0s 27ms/step
# y_pred of day 82: [[2466.598]]
# x_pred_input of day 83:
# [[[0.51592992 0.32135928 0.5442795  0.58948632 0.58500017 0.57435549]
#   [0.51393234 0.32164698 0.54196324 0.58717309 0.58257379 0.57201276]
#   [0.51193467 0.32197899 0.53966888 0.58487823 0.58016365 0.56968817]
#   [0.5097816  0.32226662 0.53742109 0.58255528 0.57776623 0.56736406]
#   [0.50775966 0.32257975 0.5351375  0.58028073 0.5753807  0.56505384]
#   [0.50577065 0.32292526 0.53287428 0.57802137 0.57301175 0.56275955]
#   [0.5038919  0.32334565 0.53057849 0.5758293  0.57066981 0.560491  ]]]
# 1/1 [==============================] - 0s 23ms/step
# y_pred of day 83: [[2457.1775]]
# x_pred_input of day 84:
# [[[0.51393234 0.32164698 0.54196324 0.58717309 0.58257379 0.57201276]
#   [0.51193467 0.32197899 0.53966888 0.58487823 0.58016365 0.56968817]
#   [0.5097816  0.32226662 0.53742109 0.58255528 0.57776623 0.56736406]
#   [0.50775966 0.32257975 0.5351375  0.58028073 0.5753807  0.56505384]
#   [0.50577065 0.32292526 0.53287428 0.57802137 0.57301175 0.56275955]
#   [0.5038919  0.32334565 0.53057849 0.5758293  0.57066981 0.560491  ]
#   [0.50189934 0.32376474 0.52832013 0.5736352  0.56834103 0.55823406]]]
# 1/1 [==============================] - 0s 20ms/step
# y_pred of day 84: [[2447.9683]]
# x_pred_input of day 85:
# [[[0.51193467 0.32197899 0.53966888 0.58487823 0.58016365 0.56968817]
#   [0.5097816  0.32226662 0.53742109 0.58255528 0.57776623 0.56736406]
#   [0.50775966 0.32257975 0.5351375  0.58028073 0.5753807  0.56505384]
#   [0.50577065 0.32292526 0.53287428 0.57802137 0.57301175 0.56275955]
#   [0.5038919  0.32334565 0.53057849 0.5758293  0.57066981 0.560491  ]
#   [0.50189934 0.32376474 0.52832013 0.5736352  0.56834103 0.55823406]
#   [0.49995144 0.32419969 0.52609638 0.57144543 0.56603031 0.55599221]]]
# 1/1 [==============================] - 0s 18ms/step
# y_pred of day 85: [[2438.9417]]
# x_pred_input of day 86:
# [[[0.5097816  0.32226662 0.53742109 0.58255528 0.57776623 0.56736406]
#   [0.50775966 0.32257975 0.5351375  0.58028073 0.5753807  0.56505384]
#   [0.50577065 0.32292526 0.53287428 0.57802137 0.57301175 0.56275955]
#   [0.5038919  0.32334565 0.53057849 0.5758293  0.57066981 0.560491  ]
#   [0.50189934 0.32376474 0.52832013 0.5736352  0.56834103 0.55823406]
#   [0.49995144 0.32419969 0.52609638 0.57144543 0.56603031 0.55599221]
#   [0.49804217 0.32466084 0.52385189 0.56930117 0.56373936 0.55376797]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 86: [[2429.7888]]
# x_pred_input of day 87:
# [[[0.50775966 0.32257975 0.5351375  0.58028073 0.5753807  0.56505384]
#   [0.50577065 0.32292526 0.53287428 0.57802137 0.57301175 0.56275955]
#   [0.5038919  0.32334565 0.53057849 0.5758293  0.57066981 0.560491  ]
#   [0.50189934 0.32376474 0.52832013 0.5736352  0.56834103 0.55823406]
#   [0.49995144 0.32419969 0.52609638 0.57144543 0.56603031 0.55599221]
#   [0.49804217 0.32466084 0.52385189 0.56930117 0.56373936 0.55376797]
#   [0.4961062  0.3251243  0.52165438 0.5671499  0.56145437 0.55155692]]]
# 1/1 [==============================] - 0s 17ms/step
# y_pred of day 87: [[2420.83]]
# x_pred_input of day 88:
# [[[0.50577065 0.32292526 0.53287428 0.57802137 0.57301175 0.56275955]
#   [0.5038919  0.32334565 0.53057849 0.5758293  0.57066981 0.560491  ]
#   [0.50189934 0.32376474 0.52832013 0.5736352  0.56834103 0.55823406]
#   [0.49995144 0.32419969 0.52609638 0.57144543 0.56603031 0.55599221]
#   [0.49804217 0.32466084 0.52385189 0.56930117 0.56373936 0.55376797]
#   [0.4961062  0.3251243  0.52165438 0.5671499  0.56145437 0.55155692]
#   [0.49421128 0.32560421 0.51950643 0.56499325 0.5591875  0.54936202]]]
# 1/1 [==============================] - 0s 19ms/step
# y_pred of day 88: [[2411.5762]]
# x_pred_input of day 89:
# [[[0.5038919  0.32334565 0.53057849 0.5758293  0.57066981 0.560491  ]
#   [0.50189934 0.32376474 0.52832013 0.5736352  0.56834103 0.55823406]
#   [0.49995144 0.32419969 0.52609638 0.57144543 0.56603031 0.55599221]
#   [0.49804217 0.32466084 0.52385189 0.56930117 0.56373936 0.55376797]
#   [0.4961062  0.3251243  0.52165438 0.5671499  0.56145437 0.55155692]
#   [0.49421128 0.32560421 0.51950643 0.56499325 0.5591875  0.54936202]
#   [0.49225394 0.32606127 0.51734976 0.56285658 0.55692798 0.54717533]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 89: [[2402.8628]]
# x_pred_input of day 90:
# [[[0.50189934 0.32376474 0.52832013 0.5736352  0.56834103 0.55823406]
#   [0.49995144 0.32419969 0.52609638 0.57144543 0.56603031 0.55599221]
#   [0.49804217 0.32466084 0.52385189 0.56930117 0.56373936 0.55376797]
#   [0.4961062  0.3251243  0.52165438 0.5671499  0.56145437 0.55155692]
#   [0.49421128 0.32560421 0.51950643 0.56499325 0.5591875  0.54936202]
#   [0.49225394 0.32606127 0.51734976 0.56285658 0.55692798 0.54717533]
#   [0.49041092 0.32655063 0.51522804 0.56072867 0.55468989 0.54500779]]]
# 1/1 [==============================] - 0s 16ms/step
# y_pred of day 90: [[2394.2734]]

# %%
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_temp), columns=FEATURES)
df_forecast_unscale
# Out:
#             Close       MACD  Bollinger_Upper  Bollinger_Lower         MA26  \
# 0      227.181000   0.000000      2394.273438      2394.273438  2394.273438
# 1      220.488998  -0.533835      2394.273438      2394.273438  2394.273438
# 2      222.218002  -0.808072      2394.273438      2394.273438  2394.273438
# 3      227.600998  -0.584308      2394.273438      2394.273438  2394.273438
# 4      225.119995  -0.600251      2394.273438      2394.273438  2394.273438
# ...           ...        ...              ...              ...          ...
# 2063  2429.788818 -70.685112      2634.495894      2405.300590  2550.240328
# 2064  2420.830078 -70.311714      2624.134294      2396.400081  2540.352999
# 2065  2411.576172 -69.956096      2613.730625      2387.582022  2530.497746
# 2066  2402.862793 -69.575342      2603.495547      2378.800131  2520.735924
# 2067  2394.273438 -69.169339      2593.234486      2370.171349  2511.069017
#
#             EMA20
# 0      227.181000
# 1      226.543666
# 2      226.131698
# 3      226.271632
# 4      226.161952
# ...           ...
# 2063  2521.966605
# 2064  2512.334555
# 2065  2502.738518
# 2066  2493.226544
# 2067  2483.802439
#
# [2068 rows x 6 columns]

# %%
# Get the df_temp with the predicted values
df_forecast = df_temp[-num_days:]

# Unscale the data
df_forecast_unscale = pd.DataFrame(scaler.inverse_transform(df_forecast), columns=FEATURES)

# Create dataframe forecast with the predicted values and the dates
day_forecast = pd.to_datetime(df_filtered.index[-1] + pd.DateOffset(1))
df_forecast_unscale['Date'] = pd.date_range(start=day_forecast, periods=num_days, freq='D')
df_forecast_unscale.set_index('Date', inplace=True)

# %%
# Dateframe of Close training set
df_train = df_filtered['Close'][:train_size].copy()

# Plot the forecast for df_val, df_test and df_forecast
plt.figure(figsize=(15, 7))
plt.plot(df_train, label='Train')
plt.plot(df_test['Y_test_pred'], label='Test prediction')
plt.plot(df_test['Y_test'], label='Test')
plt.plot(df_forecast_unscale['Close'], label='Forecast next 30 days')
plt.title('ETH/USD Close price')
plt.grid()
plt.legend()
plt.show()

# %%
# Model Evaluation
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    smape = np.mean((np.abs(y_pred - y_true) * 200 / (np.abs(y_pred) + np.abs(y_true))))
    return rmse, mape, smape

# Calculate the metrics df_test
rmse, mape, smape = calculate_metrics(df_test['Y_test'], df_test['Y_test_pred'])
print('Metrics for Test Data:')
print('RMSE: ', rmse)
print('MAPE: ', mape)
print('SMAPE: ', smape)
# Out:
# Metrics for Test Data:
# RMSE:  50.6540139675618
# MAPE:  1.776931165133021
# SMAPE:  1.7847415738048547
